# %%
import matplotlib.pyplot as plt

# %%
def plot_runtimes(df_quick_sort, df_merge_sort, df_heap_sort, labels, title):
    plt.figure(figsize=(10,6))
    plt.scatter(labels,df_quick_sort, alpha = 0.5)
    plt.plot(labels, df_quick_sort, label="quick sort", alpha = 0.5)
    plt.scatter(labels,df_merge_sort, alpha = 0.5)
    plt.plot(labels, df_merge_sort, label="merge sort", alpha = 0.5)
    plt.scatter(labels,df_heap_sort, alpha = 0.5)
    plt.plot(labels, df_heap_sort, label="heap sort", alpha = 0.5)
    plt.legend(loc='upper left',fontsize=24)
    plt.title(title,fontsize=24)
    plt.ylabel("Runtime in seconds",fontsize=24)
    plt.xlabel("Number of samples",fontsize=24)
    plt.xticks(fontsize=22)
    plt.yticks(fontsize=22)
    plt.show()

# %%
labels = [10000,50000,100000,500000,1000000]

# %%
# runtimes for discrete uniform distrbution
quick_sort_discrete_uniform = [0.00098873,0.00276759,0.005413802,0.043178958,0.085296794]
merge_sort_discrete_uniform = [0.00132126,0.00497102,0.009434038,0.067570474,0.13789313]
heap_sort_discrete_uniform = [0.00136766,0.004936446,0.008636554,0.059908832,0.136865392]
plot_runtimes(quick_sort_discrete_uniform, merge_sort_discrete_uniform, heap_sort_discrete_uniform, labels, "Sorting on discrete uniform distribution")

# %%
# runtimes for discrete binomial distrbution
quick_sort_discrete_binomial = [0.001057268,0.003205416,0.005943456,0.041737016,0.097320312]
merge_sort_discrete_binomial = [0.001223516,0.00534181,0.011483848,0.075788036,0.167324546]
heap_sort_discrete_binomial = [0.001409862,0.005480822,0.010361002,0.073470286,0.180309752]
plot_runtimes(quick_sort_discrete_binomial, merge_sort_discrete_binomial, heap_sort_discrete_binomial, labels, "Sorting on binomial distribution")

# %%
# runtimes for poisson
quick_sort_poisson = [0.000991904,0.003145058,0.005211368,0.038654988,0.084529336]
merge_sort_poisson = [0.001263808,0.005436848,0.010470468,0.069392358,0.15507706]
heap_sort_poisson = [0.00136264,0.005050942,0.00947822,0.060086972,0.14831081]
plot_runtimes(quick_sort_poisson, merge_sort_poisson, heap_sort_poisson, labels, "Sorting on Poisson distribution")

# %%
# runtimes for dates
quick_sort_dates = [0.001525052,0.006509314,0.014057906,0.100194848,0.226968042]
merge_sort_dates = [0.001622154,0.007238926,0.014922276,0.102818184,0.237193398]
heap_sort_dates = [0.00188469,0.010777248,0.023019618,0.245909208,0.637785182]
plot_runtimes(quick_sort_dates, merge_sort_dates, heap_sort_dates, labels, "Sorting on dates")

# %%
# runtimes for strings
quick_sort_strings = [0.008179818,0.051057106,0.129876372,0.873709862,2.349968598]
merge_sort_strings = [0.007367194,0.046924684,0.113877288,0.78589951,2.139950978]
heap_sort_strings = [0.01125665,0.081877284,0.226259684,1.673892712,4.350216586]
plot_runtimes(quick_sort_strings, merge_sort_strings, heap_sort_strings, labels, "Sorting on strings")

# %%
# runtimes for uniform continious distribution
quick_sort_cont_uniform = [0.001415492,0.005719156,0.012209716,0.087110714,0.253115664]
merge_sort_cont_uniform = [0.001478806,0.006228454,0.013920246,0.09591967,0.251624044]
heap_sort_cont_uniform = [0.001578398,0.008929184,0.020967008,0.204197316,0.646880568]
plot_runtimes(quick_sort_cont_uniform, merge_sort_cont_uniform, heap_sort_cont_uniform, labels, "Sorting on continuous uniform distribution")

# %%
# runtimes for normal distribution
quick_sort_normal_dist = [0.00140775,0.005586248,0.012202878,0.087848116,0.224049284]
merge_sort_normal_dist = [0.001379764,0.00615778,0.013424132,0.095694604,0.24063048]
heap_sort_normal_dist = [0.001655988,0.008996334,0.021207708,0.202504502,0.628941938]
plot_runtimes(quick_sort_normal_dist, merge_sort_normal_dist, heap_sort_normal_dist, labels, "Sorting on normal distribution")

# %%
# runtimes for Sorting on continious uniform sorted distribution
quick_sort_sorted_uniform = [0.000729798,0.00181672,0.003781188,0.028782136,0.05923457]
merge_sort_sorted_uniform = [0.000613858,0.001310052,0.002746518,0.022832142,0.046362678]
heap_sort_sorted_uniform = [0.00116155,0.004657556,0.009900496,0.062759412,0.130457982]
plot_runtimes(quick_sort_sorted_uniform, merge_sort_sorted_uniform, heap_sort_sorted_uniform, labels, "Sorting on continuous uniform sorted distribution")

# %%
# runtimes for Sorting on continious uniform reverse sorted distribution
quick_sort_reverse_sorted = [0.000828766,0.002338706,0.004175826,0.032655502,0.068043088]
merge_sort_reverse_sorted = [0.000601262,0.001418288,0.002330962,0.022700466,0.046738764]
heap_sort_reverse_sorted = [0.001210416,0.005147126,0.010303368,0.066739418,0.141393438]
plot_runtimes(quick_sort_reverse_sorted, merge_sort_reverse_sorted, heap_sort_reverse_sorted, labels, "Sorting on continuous uniform reverse sorted distribution")

# %%
# runtimes for Sorting on continious uniform nearly sorted distribution
quick_sort_nealry_sorted = [0.001165442,0.00455948,0.009436496,0.062329298,0.13449624]
merge_sort_nealry_sorted = [0.001055164,0.004612826,0.009715646,0.06688422,0.145253228]
heap_sort_nealry_sorted = [0.001434898,0.006463992,0.013943076,0.104524296,0.237655962]
plot_runtimes(quick_sort_nealry_sorted, merge_sort_nealry_sorted, heap_sort_nealry_sorted, labels, "Sorting on continuous uniform nearly sorted distribution")

# %%
# runtimes for Zipf distribution
quick_sort_zipf = [0.000791168,0.002449674,0.004652732,0.034740266,0.075094252]
merge_sort_zipf = [0.001027034,0.00382772,0.007840506,0.054734864,0.120263974]
heap_sort_zipf = [0.000914064,0.003432736,0.006387142,0.049853896,0.111380546]
plot_runtimes(quick_sort_zipf, merge_sort_zipf, heap_sort_zipf, labels, "Sorting on Zipf distribution")

# %%
# runtimes for Zipf+ normal distribution
quick_sort_zipf_normal = [0.005014228,0.023401694,0.057660782,0.07838378,0.169139504]
merge_sort_zipf_normal = [0.005231318,0.024005064,0.051360732,0.077184828,0.173270966]
heap_sort_zipf_normal = [0.005361712,0.023375014,0.049799948,0.079827152,0.16840109]
plot_runtimes(quick_sort_zipf_normal, merge_sort_zipf_normal, heap_sort_zipf_normal, labels, "Sorting on Zipf + normal distribution")

# %%
# runtimes for Zipf+ binomial distribution
quick_sort_zipf_binom = [0.002269602,0.004718296,0.011185184,0.079306036,0.17734847]
merge_sort_zipf_binom = [0.00224073,0.005605822,0.011456782,0.07557868,0.167823712]
heap_sort_zipf_binom = [0.002306932,0.005362862,0.012081788,0.075490564,0.166688098]
plot_runtimes(quick_sort_zipf_binom, merge_sort_zipf_binom, heap_sort_zipf_binom, labels, "Sorting on Zipf + binomial distribution")

# %%
# runtimes for Zipf+ discrete uniform
quick_sort_zipf_discrete_uniform = [0.002356206,0.005139064,0.011024542,0.075079224,0.16125449]
merge_sort_zipf_discrete_uniform = [0.002223504,0.00490714,0.010560626,0.075228264,0.161878242]
heap_sort_zipf_discrete_uniform = [0.002207192,0.00464306,0.01189148,0.076048554,0.161869444]
plot_runtimes(quick_sort_zipf_discrete_uniform, merge_sort_zipf_discrete_uniform, heap_sort_zipf_discrete_uniform, labels, "Sorting on Zipf + discrete uniform distribution")

# %%
# runtimes for Zipf + Poisson
quick_sort_zipf_poisson = [0.002329378,0.005179446,0.009703518,0.086474226,0.165114934]
merge_sort_zipf_poisson = [0.002195462,0.00522556,0.009781132,0.085353718,0.15994479]
heap_sort_zipf_poisson = [0.002639454,0.004908722,0.009719844,0.088102322,0.159633948]
plot_runtimes(quick_sort_zipf_poisson, merge_sort_zipf_poisson, heap_sort_zipf_poisson, labels, "Sorting on Zipf + Poisson distribution")

# %%
# runtimes for Zipf + Dates
quick_sort_zipf_dates = [0.004910812,0.022120122,0.047767204,0.446528482,0.972024566]
merge_sort_zipf_dates = [0.00490448,0.022045484,0.04861789,0.44452438,1.036326496]
heap_sort_zipf_dates = [0.004910282,0.022103108,0.05091805,0.458254152,0.984011514]
plot_runtimes(quick_sort_zipf_dates, merge_sort_zipf_dates, heap_sort_zipf_dates, labels, "Sorting on Zipf + dates distribution")

# %%
# runtimes for Zipf + strings
quick_sort_zipf_strings = [0.012022806,0.056169022,0.098674598,0.336616036,0.648920632]
merge_sort_zipf_strings = [0.011835932,0.056663358,0.095655006,0.351075038,0.692119256]
heap_sort_zipf_strings = [0.012217604,0.056748016,0.096902186,0.329909146,0.67565435]
plot_runtimes(quick_sort_zipf_strings, merge_sort_zipf_strings, heap_sort_zipf_strings, labels, "Sorting on Zipf + strings")

# %%
# runtimes for discrete_uni + poisson
quick_sort_discrete_uniform_poisson = [0.00223641,0.00451517,0.008620166,0.069199756,0.15372824]
merge_sort_discrete_uniform_poisson = [0.00215171,0.004521732,0.008416162,0.070565618,0.152478072]
heap_sort_discrete_uniform_poisson = [0.002089004,0.00452456,0.008522454,0.069036784,0.152617652]
plot_runtimes(quick_sort_discrete_uniform_poisson, merge_sort_discrete_uniform_poisson, heap_sort_discrete_uniform_poisson, labels, "Sorting on discrete uniform + Poisson distribution")

# %%
# runtimes for discrete_uni + strings
quick_sort_discrete_uniform_strings = [0.011857406,0.070070372,0.098833824,0.354076838,0.690776064]
merge_sort_discrete_uniform_strings = [0.011917432,0.059717416,0.097099034,0.38501736,0.686640882]
heap_sort_discrete_uniform_strings = [0.011640132,0.060241022,0.10198259,0.365032662,0.680990274]
plot_runtimes(quick_sort_discrete_uniform_strings, merge_sort_discrete_uniform_strings, heap_sort_discrete_uniform_strings, labels, "Sorting on discrete uniform + strings distribution")

# %%
# runtimes for discrete_uni + reverse sorted uniform distrbution
quick_sort_discrete_reverse_sorted = [0.003947026,0.016665076,0.04180561,0.324030894,0.692425588]
merge_sort_discrete_reverse_sorted = [0.003749724,0.019964142,0.036129458,0.322234108,0.738053038]
heap_sort_discrete_reverse_sorted = [0.003763438,0.018338386,0.036847886,0.330779074,0.665672806]
plot_runtimes(quick_sort_discrete_reverse_sorted, merge_sort_discrete_reverse_sorted, heap_sort_discrete_reverse_sorted, labels, "Sorting on discrete uniform + uniform reverse sorted distribution")

# %%
# runtimes for discrete_uni + nerly sorted uniform distrbution
quick_sort_discrete_nearly_sorted = [0.00459311,0.020960592,0.04644608,0.37446235,0.80819754]
merge_sort_discrete_nearly_sorted = [0.004535836,0.020267552,0.045604954,0.373833338,0.8076975]
heap_sort_discrete_nearly_sorted = [0.004473822,0.021088826,0.046475046,0.384988066,0.807871332]
plot_runtimes(quick_sort_discrete_nearly_sorted, merge_sort_discrete_nearly_sorted, heap_sort_discrete_nearly_sorted, labels, "Sorting on discrete uniform + uniform nearly sorted distribution")
