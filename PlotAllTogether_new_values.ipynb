# %%
import matplotlib.pyplot as plt

# %%
def plot_runtimes(df_quick_sort, df_merge_sort, df_heap_sort, labels, title):
    plt.figure(figsize=(10,6))
    plt.scatter(labels,df_quick_sort, alpha = 0.5)
    plt.plot(labels, df_quick_sort, label="quick sort", alpha = 0.5)
    plt.scatter(labels,df_merge_sort, alpha = 0.5)
    plt.plot(labels, df_merge_sort, label="merge sort", alpha = 0.5)
    plt.scatter(labels,df_heap_sort, alpha = 0.5)
    plt.plot(labels, df_heap_sort, label="heap sort", alpha = 0.5)
    plt.legend(loc='upper left',fontsize=24)
    #plt.title(title,fontsize=24)
    plt.ylabel("Runtime in seconds",fontsize=24)
    plt.xlabel("Number of samples",fontsize=24)
    plt.xticks(fontsize=22)
    plt.yticks(fontsize=22)
    plt.show()

# %%
labels = [10000,50000,100000,500000,1000000]

# %%
# runtimes for discrete uniform distrbution
quick_sort_discrete_uniform = [0.000890265,0.002682093,0.005078771,0.037699034,0.08297684]
merge_sort_discrete_uniform = [0.001135807,0.00451346,0.009194787,0.063599549,0.136915255]
heap_sort_discrete_uniform = [0.001195106,0.004377296,0.008493937,0.05885784,0.134893187
]
plot_runtimes(quick_sort_discrete_uniform, merge_sort_discrete_uniform, heap_sort_discrete_uniform, labels, "Sorting on discrete uniform distribution")

# %%
# runtimes for discrete binomial distrbution
quick_sort_discrete_binomial = [0.000900869,0.002939504,0.005636176,0.041052819,0.09634545]
merge_sort_discrete_binomial = [0.001198575,0.005276733,0.010257237,0.072610096,0.164859601]
heap_sort_discrete_binomial = [0.001304146,0.005101555,0.010134613,0.068805616,0.161825628]
plot_runtimes(quick_sort_discrete_binomial, merge_sort_discrete_binomial, heap_sort_discrete_binomial, labels, "Sorting on binomial distribution")

# %%
# runtimes for poisson
quick_sort_poisson = [0.000846227,0.002661398,0.004846556,0.038422316,0.079293609]
merge_sort_poisson = [0.001201262,0.004781885,0.009626386,0.067084242,0.144731014]
heap_sort_poisson = [0.001178785,0.004419769,0.008436618,0.05919634,0.13632442]
plot_runtimes(quick_sort_poisson, merge_sort_poisson, heap_sort_poisson, labels, "Sorting on Poisson distribution")

# %%
# runtimes for dates
quick_sort_dates = [0.001353955,0.006306231,0.012294042,0.088564573,0.20059743]
merge_sort_dates = [0.001441882,0.006379443,0.013199496,0.09677283,0.218207989]
heap_sort_dates = [0.00190026,0.010025918,0.022000368,0.21679865,0.572005073]
plot_runtimes(quick_sort_dates, merge_sort_dates, heap_sort_dates, labels, "Sorting on dates")

# %%
# runtimes for strings
quick_sort_strings = [0.007632377,0.051554978,0.117840993,0.841016674,1.952786585]
merge_sort_strings = [0.007380778,0.046866555,0.106538468,0.765209158,1.793337504]
heap_sort_strings = [0.011677663,0.081283767,0.210305808,1.634438253,3.79346575]
plot_runtimes(quick_sort_strings, merge_sort_strings, heap_sort_strings, labels, "Sorting on strings")

# %%
# runtimes for uniform continious distribution
quick_sort_cont_uniform = [0.001273137,0.005532763,0.011513883,0.090996538,0.195227409]
merge_sort_cont_uniform = [0.001383411,0.006146742,0.012868856,0.093997219,0.213650428]
heap_sort_cont_uniform = [0.001582687,0.00884993,0.020129661,0.200712398,0.544684724]
plot_runtimes(quick_sort_cont_uniform, merge_sort_cont_uniform, heap_sort_cont_uniform, labels, "Sorting on continuous uniform distribution")

# %%
# runtimes for normal distribution
quick_sort_normal_dist = [0.001253855,0.005961015,0.011678741,0.087458106,0.195589058]
merge_sort_normal_dist = [0.001372647,0.006397788,0.01291959,0.093903788,0.216784165]
heap_sort_normal_dist = [0.00158862,0.009232656,0.020087881,0.199984079,0.547309802]
plot_runtimes(quick_sort_normal_dist, merge_sort_normal_dist, heap_sort_normal_dist, labels, "Sorting on normal distribution")

# %%
# runtimes for Sorting on continious uniform sorted distribution
quick_sort_sorted_uniform = [0.000666658,0.001817727,0.003206311,0.028333238,0.057936698]
merge_sort_sorted_uniform = [0.000622205,0.001285246,0.002282699,0.022047388,0.044851418]
heap_sort_sorted_uniform = [0.001331027,0.004612814,0.009121452,0.061982165,0.126937729]
plot_runtimes(quick_sort_sorted_uniform, merge_sort_sorted_uniform, heap_sort_sorted_uniform, labels, "Sorting on continuous uniform sorted distribution")

# %%
# runtimes for Sorting on continious uniform reverse sorted distribution
quick_sort_reverse_sorted = [0.00073403,0.002139349,0.003972858,0.031987042,0.066336367]
merge_sort_reverse_sorted = [0.000634501,0.001306111,0.002347575,0.022189255,0.045212666]
heap_sort_reverse_sorted = [0.001198793,0.004899127,0.00991257,0.065728364,0.139230881]
plot_runtimes(quick_sort_reverse_sorted, merge_sort_reverse_sorted, heap_sort_reverse_sorted, labels, "Sorting on continuous uniform reverse sorted distribution")

# %%
# runtimes for Sorting on continious uniform nearly sorted distribution
quick_sort_nealry_sorted = [0.001054618,0.004315208,0.008789778,0.061939189,0.132763337
]
merge_sort_nealry_sorted = [0.001051085,0.004544827,0.00924237,0.066254671,0.144296165
]
heap_sort_nealry_sorted = [0.001363067,0.006793429,0.013454436,0.104354271,0.236048836
]
plot_runtimes(quick_sort_nealry_sorted, merge_sort_nealry_sorted, heap_sort_nealry_sorted, labels, "Sorting on continuous uniform nearly sorted distribution")

# %%
# runtimes for Zipf distribution
quick_sort_zipf = [0.000795226,0.002448346,0.00449447,0.033867308,0.073154283
]
merge_sort_zipf = [0.000990199,0.003794411,0.00758242,0.053742766,0.117976322
]
heap_sort_zipf = [0.000906608,0.003135656,0.006109378,0.048192445,0.108928144
]
plot_runtimes(quick_sort_zipf, merge_sort_zipf, heap_sort_zipf, labels, "Sorting on Zipf distribution")

# %%
# runtimes for Zipf+ normal distribution
quick_sort_zipf_normal = [0.004933813,0.02412433,0.050899884,0.438347012,0.983121252
]
merge_sort_zipf_normal = [0.004832127,0.023961322,0.04983893,0.42080441,0.9777172
]
heap_sort_zipf_normal = [0.004814195,0.02375698,0.049470524,0.420003964,0.984764912
]
plot_runtimes(quick_sort_zipf_normal, merge_sort_zipf_normal, heap_sort_zipf_normal, labels, "Sorting on Zipf + normal distribution")

# %%
# runtimes for Zipf+ binomial distribution
quick_sort_zipf_binom = [0.002213705,0.004800606,0.010123438,0.076953744,0.164527886
]
merge_sort_zipf_binom = [0.002205253,0.004706692,0.010139522,0.077338592,0.165557386
]
heap_sort_zipf_binom = [0.002141017,0.00465533,0.010085744,0.076830892,0.164815036
]
plot_runtimes(quick_sort_zipf_binom, merge_sort_zipf_binom, heap_sort_zipf_binom, labels, "Sorting on Zipf + binomial distribution")

# %%
# runtimes for Zipf+ discrete uniform
quick_sort_zipf_discrete_uniform = [0.002328049,0.004690832,0.009823904,0.075614574,0.158895818
]
merge_sort_zipf_discrete_uniform = [0.002183641,0.005205994,0.009672426,0.075631028,0.159076426
]
heap_sort_zipf_discrete_uniform = [0.002205816,0.004880488,0.009718078,0.076349894,0.158905306
]
plot_runtimes(quick_sort_zipf_discrete_uniform, merge_sort_zipf_discrete_uniform, heap_sort_zipf_discrete_uniform, labels, "Sorting on Zipf + discrete uniform distribution")

# %%
# runtimes for Zipf + Poisson
quick_sort_zipf_poisson = [0.002335864,0.004806828,0.009542404,0.075221268,0.159664064
]
merge_sort_zipf_poisson = [0.002607786,0.004533118,0.00953103,0.074937596,0.15719293
]
heap_sort_zipf_poisson = [0.002351048,0.004571222,0.00959442,0.074932034,0.1571175
]
plot_runtimes(quick_sort_zipf_poisson, merge_sort_zipf_poisson, heap_sort_zipf_poisson, labels, "Sorting on Zipf + Poisson distribution")

# %%
# runtimes for Zipf + Dates
quick_sort_zipf_dates = [0.005106562,0.024734928,0.048789092,0.408395612,0.960630354
]
merge_sort_zipf_dates = [0.005019524,0.02225804,0.047036052,0.413715256,0.956776536
]
heap_sort_zipf_dates = [0.004786341,0.022581386,0.047266372,0.406265378,0.95842227
]
plot_runtimes(quick_sort_zipf_dates, merge_sort_zipf_dates, heap_sort_zipf_dates, labels, "Sorting on Zipf + dates distribution")

# %%
# runtimes for Zipf + strings
quick_sort_zipf_strings = [0.012739248,0.054361292,0.093150356,0.32282503,0.639741138
]
merge_sort_zipf_strings = [0.012397676,0.055323734,0.093854534,0.325827212,0.629916476
]
heap_sort_zipf_strings = [0.01184578,0.055185528,0.092964546,0.325818686,0.63402698
]
plot_runtimes(quick_sort_zipf_strings, merge_sort_zipf_strings, heap_sort_zipf_strings, labels, "Sorting on Zipf + strings")

# %%
# runtimes for discrete_uni + poisson
quick_sort_discrete_uniform_poisson = [0.002141326,0.00449439,0.008469332,0.069357258,0.148706246
]
merge_sort_discrete_uniform_poisson = [0.002089358,0.004426498,0.008385416,0.068876808,0.148250844
]
heap_sort_discrete_uniform_poisson = [0.002087683,0.00441144,0.008332696,0.068883788,0.148495416
]
plot_runtimes(quick_sort_discrete_uniform_poisson, merge_sort_discrete_uniform_poisson, heap_sort_discrete_uniform_poisson, labels, "Sorting on discrete uniform + Poisson distribution")

# %%
# runtimes for discrete_uni + strings
quick_sort_discrete_uniform_strings = [0.012076036,0.056419026,0.093978078,0.346146608,0.671459342
]
merge_sort_discrete_uniform_strings = [0.012915725,0.059491632,0.104600746,0.351567676,0.674513098
]
heap_sort_discrete_uniform_strings = [0.013275323,0.056299032,0.095850952,0.349988004,0.673317506
]
plot_runtimes(quick_sort_discrete_uniform_strings, merge_sort_discrete_uniform_strings, heap_sort_discrete_uniform_strings, labels, "Sorting on discrete uniform + strings distribution")

# %%
# runtimes for discrete_uni + reverse sorted uniform distrbution
quick_sort_discrete_reverse_sorted = [0.003993079,0.016317696,0.034435292,0.30268316,0.664182964
]
merge_sort_discrete_reverse_sorted = [0.00384194,0.015747884,0.0333196,0.303729644,0.65790161
]
heap_sort_discrete_reverse_sorted = [0.003756251,0.015643478,0.033135542,0.302494582,0.653962586
]
plot_runtimes(quick_sort_discrete_reverse_sorted, merge_sort_discrete_reverse_sorted, heap_sort_discrete_reverse_sorted, labels, "Sorting on discrete uniform + uniform reverse sorted distribution")

# %%
# runtimes for discrete_uni + nerly sorted uniform distrbution
quick_sort_discrete_nearly_sorted = [0.004465606,0.020107748,0.043035838,0.368182644,0.800662272
]
merge_sort_discrete_nearly_sorted = [0.004631484,0.019889074,0.043456126,0.368079332,0.80442874
]
heap_sort_discrete_nearly_sorted = [0.004735457,0.01986118,0.042700294,0.375226038,0.801900018
]
plot_runtimes(quick_sort_discrete_nearly_sorted, merge_sort_discrete_nearly_sorted, heap_sort_discrete_nearly_sorted, labels, "Sorting on discrete uniform + uniform nearly sorted distribution")
