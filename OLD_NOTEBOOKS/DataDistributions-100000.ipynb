# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import special
from sklearn.datasets import make_blobs
import time
import scipy.stats as stats
from random import choice, shuffle
from string import ascii_lowercase, digits
from datetime import datetime
import random
import timeit

from scipy.stats import beta
from scipy.stats import betabinom, binom

# %%
# Set Parameters
n_samples = 100000
num_bins = 20
length_strings = 3
p=0.5
n_binomial = 100
n_discrete = 10
lambda_param = 4

# %%
def plot_distribution(dist, n_samples, title, num_bins):
    weights = np.ones_like(dist)/float(len(dist))
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))
    #fig.suptitle(title,fontsize=26, y=1.05)
    count, bins, ignored = ax1.hist(dist, num_bins, weights=weights)
    #ax1.plot(bins, np.ones_like(bins), linewidth=2, color='r')
    #ax1.set_title('Probability Distribution',fontsize=26)
    ax1.set_ylabel('Frequency',fontsize=26)
    ax1.set_xlabel('Observation Value',fontsize=26)
    plt.setp(ax1.get_yticklabels(), fontsize=20)
    plt.setp(ax1.get_xticklabels(), fontsize=20)
    y = np.arange(0,n_samples)
    ax2.scatter(y,dist,s=10)
    #ax2.set_title('Sample Values',fontsize=26)
    ax2.set_ylabel('Observation Value',fontsize=26)
    ax2.set_xlabel('Number of Observation',fontsize=26)
    plt.setp(ax2.get_xticklabels(), fontsize=20)
    plt.setp(ax2.get_yticklabels(), fontsize=20)
    fig.tight_layout()
    """
    plt.figure(figsize=(8,6))
    count, bins, ignored = plt.hist(dist, num_bins, weights=weights)
    #plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
    plt.ylabel('Frequency',fontsize=26)
    plt.xlabel('Observation Value',fontsize=26)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.show()
    plt.figure(figsize=(8,6))
    y = np.arange(0,n_samples)
    plt.scatter(y,dist,s=10)
    plt.ylabel('Observation Value',fontsize=26)
    plt.xlabel('Number of Observation',fontsize=26)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.show()

# %%
def poission_distribution(n_samples=n_samples, lambda_param=lambda_param, display = True):
    poission =  np.random.poisson(lambda_param, n_samples)
    if display==True:
        plot_distribution(poission, n_samples, "Poisson Distribution",15)
    return poission
poission = poission_distribution()

# %%
def discrete_binomial_distribution(n_samples=n_samples, p=p, n=n_binomial, display = True):
    discrete_binomial_distribution = binom.rvs(n, p, size=n_samples)
    if display==True:
        plot_distribution(discrete_binomial_distribution, n_samples, "Binomial Distribution", num_bins)
        
    return discrete_binomial_distribution
discrete_binomial = discrete_binomial_distribution()

# %%
def discrete_uniform_distribution(n_samples=n_samples, n=n_discrete, display = True):
    discrete_uniform_distribution = np.random.randint(n, size=n_samples)
    
    if display == True:
        plot_distribution(discrete_uniform_distribution, n_samples, "Discrete Uniform Distribution", num_bins)
        
    return discrete_uniform_distribution
discrete_uniform = discrete_uniform_distribution()

# %%
def create_dates(n_samples=n_samples):
    sample_dates = pd.date_range(end = datetime.today(), periods = n_samples).to_pydatetime().tolist()
    shuffle(sample_dates)
    return sample_dates
sample_dates=create_dates()
sample_dates
# Out:
# [datetime.datetime(1767, 1, 15, 11, 4, 5, 326882),
#  datetime.datetime(1977, 11, 6, 11, 4, 5, 326882),
#  datetime.datetime(1998, 10, 27, 11, 4, 5, 326882),
#  datetime.datetime(1818, 9, 12, 11, 4, 5, 326882),
#  datetime.datetime(1885, 11, 13, 11, 4, 5, 326882),
#  datetime.datetime(1941, 3, 30, 11, 4, 5, 326882),
#  datetime.datetime(1925, 6, 4, 11, 4, 5, 326882),
#  datetime.datetime(1957, 2, 24, 11, 4, 5, 326882),
#  datetime.datetime(1977, 5, 14, 11, 4, 5, 326882),
#  datetime.datetime(1766, 2, 7, 11, 4, 5, 326882),
#  datetime.datetime(1933, 2, 12, 11, 4, 5, 326882),
#  datetime.datetime(1923, 9, 10, 11, 4, 5, 326882),
#  datetime.datetime(1933, 2, 19, 11, 4, 5, 326882),
#  datetime.datetime(1914, 10, 2, 11, 4, 5, 326882),
#  datetime.datetime(1761, 10, 12, 11, 4, 5, 326882),
#  datetime.datetime(1874, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(2005, 4, 14, 11, 4, 5, 326882),
#  datetime.datetime(1954, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1926, 5, 24, 11, 4, 5, 326882),
#  datetime.datetime(1905, 8, 15, 11, 4, 5, 326882),
#  datetime.datetime(1924, 11, 29, 11, 4, 5, 326882),
#  datetime.datetime(1867, 10, 28, 11, 4, 5, 326882),
#  datetime.datetime(1981, 8, 11, 11, 4, 5, 326882),
#  datetime.datetime(2007, 1, 19, 11, 4, 5, 326882),
#  datetime.datetime(1791, 4, 2, 11, 4, 5, 326882),
#  datetime.datetime(1895, 7, 1, 11, 4, 5, 326882),
#  datetime.datetime(1916, 6, 17, 11, 4, 5, 326882),
#  datetime.datetime(1774, 12, 29, 11, 4, 5, 326882),
#  datetime.datetime(1990, 3, 1, 11, 4, 5, 326882),
#  datetime.datetime(1968, 9, 8, 11, 4, 5, 326882),
#  datetime.datetime(1995, 10, 14, 11, 4, 5, 326882),
#  datetime.datetime(2005, 4, 19, 11, 4, 5, 326882),
#  datetime.datetime(1901, 2, 12, 11, 4, 5, 326882),
#  datetime.datetime(1967, 6, 20, 11, 4, 5, 326882),
#  datetime.datetime(1786, 8, 14, 11, 4, 5, 326882),
#  datetime.datetime(1952, 4, 1, 11, 4, 5, 326882),
#  datetime.datetime(1885, 1, 11, 11, 4, 5, 326882),
#  datetime.datetime(1982, 4, 15, 11, 4, 5, 326882),
#  datetime.datetime(1748, 2, 21, 11, 4, 5, 326882),
#  datetime.datetime(1827, 4, 23, 11, 4, 5, 326882),
#  datetime.datetime(1767, 4, 10, 11, 4, 5, 326882),
#  datetime.datetime(1897, 10, 25, 11, 4, 5, 326882),
#  datetime.datetime(2007, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1866, 7, 6, 11, 4, 5, 326882),
#  datetime.datetime(1752, 2, 26, 11, 4, 5, 326882),
#  datetime.datetime(1761, 10, 2, 11, 4, 5, 326882),
#  datetime.datetime(2013, 10, 21, 11, 4, 5, 326882),
#  datetime.datetime(1871, 1, 6, 11, 4, 5, 326882),
#  datetime.datetime(1938, 4, 2, 11, 4, 5, 326882),
#  datetime.datetime(1982, 12, 5, 11, 4, 5, 326882),
#  datetime.datetime(1789, 7, 25, 11, 4, 5, 326882),
#  datetime.datetime(1861, 5, 23, 11, 4, 5, 326882),
#  datetime.datetime(2009, 11, 5, 11, 4, 5, 326882),
#  datetime.datetime(1819, 12, 23, 11, 4, 5, 326882),
#  datetime.datetime(2015, 4, 3, 11, 4, 5, 326882),
#  datetime.datetime(1994, 2, 1, 11, 4, 5, 326882),
#  datetime.datetime(1783, 4, 17, 11, 4, 5, 326882),
#  datetime.datetime(1816, 7, 16, 11, 4, 5, 326882),
#  datetime.datetime(1849, 4, 23, 11, 4, 5, 326882),
#  datetime.datetime(1748, 7, 8, 11, 4, 5, 326882),
#  datetime.datetime(1774, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(1893, 7, 20, 11, 4, 5, 326882),
#  datetime.datetime(1775, 11, 25, 11, 4, 5, 326882),
#  datetime.datetime(1880, 2, 21, 11, 4, 5, 326882),
#  datetime.datetime(1926, 5, 2, 11, 4, 5, 326882),
#  datetime.datetime(2015, 12, 8, 11, 4, 5, 326882),
#  datetime.datetime(1844, 7, 4, 11, 4, 5, 326882),
#  datetime.datetime(1987, 4, 15, 11, 4, 5, 326882),
#  datetime.datetime(1988, 10, 30, 11, 4, 5, 326882),
#  datetime.datetime(2008, 5, 21, 11, 4, 5, 326882),
#  datetime.datetime(1799, 12, 1, 11, 4, 5, 326882),
#  datetime.datetime(1760, 4, 22, 11, 4, 5, 326882),
#  datetime.datetime(1802, 7, 19, 11, 4, 5, 326882),
#  datetime.datetime(1992, 4, 1, 11, 4, 5, 326882),
#  datetime.datetime(1949, 10, 16, 11, 4, 5, 326882),
#  datetime.datetime(1943, 1, 13, 11, 4, 5, 326882),
#  datetime.datetime(1956, 1, 14, 11, 4, 5, 326882),
#  datetime.datetime(2015, 6, 30, 11, 4, 5, 326882),
#  datetime.datetime(1957, 4, 21, 11, 4, 5, 326882),
#  datetime.datetime(2019, 1, 14, 11, 4, 5, 326882),
#  datetime.datetime(1913, 4, 19, 11, 4, 5, 326882),
#  datetime.datetime(1938, 9, 25, 11, 4, 5, 326882),
#  datetime.datetime(1851, 4, 9, 11, 4, 5, 326882),
#  datetime.datetime(1825, 9, 11, 11, 4, 5, 326882),
#  datetime.datetime(1987, 6, 19, 11, 4, 5, 326882),
#  datetime.datetime(1897, 2, 22, 11, 4, 5, 326882),
#  datetime.datetime(1948, 3, 30, 11, 4, 5, 326882),
#  datetime.datetime(1782, 12, 11, 11, 4, 5, 326882),
#  datetime.datetime(1962, 5, 10, 11, 4, 5, 326882),
#  datetime.datetime(1884, 8, 5, 11, 4, 5, 326882),
#  datetime.datetime(1828, 10, 3, 11, 4, 5, 326882),
#  datetime.datetime(1935, 10, 17, 11, 4, 5, 326882),
#  datetime.datetime(1834, 2, 20, 11, 4, 5, 326882),
#  datetime.datetime(1916, 9, 22, 11, 4, 5, 326882),
#  datetime.datetime(1937, 5, 14, 11, 4, 5, 326882),
#  datetime.datetime(2009, 8, 12, 11, 4, 5, 326882),
#  datetime.datetime(1801, 11, 5, 11, 4, 5, 326882),
#  datetime.datetime(1850, 7, 29, 11, 4, 5, 326882),
#  datetime.datetime(1953, 2, 6, 11, 4, 5, 326882),
#  datetime.datetime(1846, 7, 22, 11, 4, 5, 326882),
#  datetime.datetime(2018, 7, 5, 11, 4, 5, 326882),
#  datetime.datetime(1887, 3, 8, 11, 4, 5, 326882),
#  datetime.datetime(1802, 7, 24, 11, 4, 5, 326882),
#  datetime.datetime(1770, 2, 21, 11, 4, 5, 326882),
#  datetime.datetime(1882, 1, 20, 11, 4, 5, 326882),
#  datetime.datetime(1878, 10, 15, 11, 4, 5, 326882),
#  datetime.datetime(1757, 7, 20, 11, 4, 5, 326882),
#  datetime.datetime(1989, 2, 21, 11, 4, 5, 326882),
#  datetime.datetime(1826, 1, 6, 11, 4, 5, 326882),
#  datetime.datetime(2021, 10, 15, 11, 4, 5, 326882),
#  datetime.datetime(2006, 1, 31, 11, 4, 5, 326882),
#  datetime.datetime(1981, 10, 21, 11, 4, 5, 326882),
#  datetime.datetime(1802, 3, 22, 11, 4, 5, 326882),
#  datetime.datetime(1828, 12, 6, 11, 4, 5, 326882),
#  datetime.datetime(1922, 4, 17, 11, 4, 5, 326882),
#  datetime.datetime(1857, 11, 10, 11, 4, 5, 326882),
#  datetime.datetime(1970, 4, 24, 11, 4, 5, 326882),
#  datetime.datetime(1887, 3, 12, 11, 4, 5, 326882),
#  datetime.datetime(1874, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(2010, 8, 9, 11, 4, 5, 326882),
#  datetime.datetime(1877, 9, 20, 11, 4, 5, 326882),
#  datetime.datetime(1858, 12, 17, 11, 4, 5, 326882),
#  datetime.datetime(1805, 3, 16, 11, 4, 5, 326882),
#  datetime.datetime(1863, 3, 17, 11, 4, 5, 326882),
#  datetime.datetime(1759, 7, 3, 11, 4, 5, 326882),
#  datetime.datetime(1883, 8, 11, 11, 4, 5, 326882),
#  datetime.datetime(1869, 4, 5, 11, 4, 5, 326882),
#  datetime.datetime(1929, 12, 12, 11, 4, 5, 326882),
#  datetime.datetime(1827, 4, 14, 11, 4, 5, 326882),
#  datetime.datetime(1756, 8, 1, 11, 4, 5, 326882),
#  datetime.datetime(1785, 9, 4, 11, 4, 5, 326882),
#  datetime.datetime(1854, 4, 9, 11, 4, 5, 326882),
#  datetime.datetime(1978, 11, 2, 11, 4, 5, 326882),
#  datetime.datetime(1907, 2, 7, 11, 4, 5, 326882),
#  datetime.datetime(2009, 7, 7, 11, 4, 5, 326882),
#  datetime.datetime(2007, 11, 4, 11, 4, 5, 326882),
#  datetime.datetime(1799, 11, 6, 11, 4, 5, 326882),
#  datetime.datetime(1964, 10, 5, 11, 4, 5, 326882),
#  datetime.datetime(2002, 1, 31, 11, 4, 5, 326882),
#  datetime.datetime(1906, 9, 28, 11, 4, 5, 326882),
#  datetime.datetime(1895, 7, 21, 11, 4, 5, 326882),
#  datetime.datetime(1802, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1814, 2, 23, 11, 4, 5, 326882),
#  datetime.datetime(1875, 2, 5, 11, 4, 5, 326882),
#  datetime.datetime(1990, 7, 23, 11, 4, 5, 326882),
#  datetime.datetime(1905, 2, 11, 11, 4, 5, 326882),
#  datetime.datetime(1970, 3, 10, 11, 4, 5, 326882),
#  datetime.datetime(1927, 9, 5, 11, 4, 5, 326882),
#  datetime.datetime(1788, 12, 9, 11, 4, 5, 326882),
#  datetime.datetime(1863, 1, 28, 11, 4, 5, 326882),
#  datetime.datetime(2005, 8, 8, 11, 4, 5, 326882),
#  datetime.datetime(1965, 3, 12, 11, 4, 5, 326882),
#  datetime.datetime(1913, 3, 20, 11, 4, 5, 326882),
#  datetime.datetime(1986, 10, 7, 11, 4, 5, 326882),
#  datetime.datetime(1938, 5, 16, 11, 4, 5, 326882),
#  datetime.datetime(2014, 10, 23, 11, 4, 5, 326882),
#  datetime.datetime(1975, 8, 30, 11, 4, 5, 326882),
#  datetime.datetime(2021, 9, 16, 11, 4, 5, 326882),
#  datetime.datetime(1786, 7, 3, 11, 4, 5, 326882),
#  datetime.datetime(1757, 12, 30, 11, 4, 5, 326882),
#  datetime.datetime(1869, 8, 31, 11, 4, 5, 326882),
#  datetime.datetime(1951, 3, 5, 11, 4, 5, 326882),
#  datetime.datetime(1883, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1932, 5, 21, 11, 4, 5, 326882),
#  datetime.datetime(1870, 2, 2, 11, 4, 5, 326882),
#  datetime.datetime(1808, 6, 16, 11, 4, 5, 326882),
#  datetime.datetime(1785, 4, 7, 11, 4, 5, 326882),
#  datetime.datetime(1848, 1, 5, 11, 4, 5, 326882),
#  datetime.datetime(1880, 9, 4, 11, 4, 5, 326882),
#  datetime.datetime(1793, 7, 13, 11, 4, 5, 326882),
#  datetime.datetime(1802, 7, 13, 11, 4, 5, 326882),
#  datetime.datetime(1896, 10, 15, 11, 4, 5, 326882),
#  datetime.datetime(1767, 12, 16, 11, 4, 5, 326882),
#  datetime.datetime(1846, 4, 28, 11, 4, 5, 326882),
#  datetime.datetime(1990, 11, 24, 11, 4, 5, 326882),
#  datetime.datetime(1764, 5, 19, 11, 4, 5, 326882),
#  datetime.datetime(1930, 11, 16, 11, 4, 5, 326882),
#  datetime.datetime(2004, 6, 11, 11, 4, 5, 326882),
#  datetime.datetime(1984, 12, 9, 11, 4, 5, 326882),
#  datetime.datetime(1830, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1903, 8, 25, 11, 4, 5, 326882),
#  datetime.datetime(1827, 10, 13, 11, 4, 5, 326882),
#  datetime.datetime(1815, 6, 13, 11, 4, 5, 326882),
#  datetime.datetime(2018, 11, 3, 11, 4, 5, 326882),
#  datetime.datetime(1992, 1, 7, 11, 4, 5, 326882),
#  datetime.datetime(1812, 7, 19, 11, 4, 5, 326882),
#  datetime.datetime(1826, 8, 10, 11, 4, 5, 326882),
#  datetime.datetime(1784, 5, 1, 11, 4, 5, 326882),
#  datetime.datetime(1981, 11, 8, 11, 4, 5, 326882),
#  datetime.datetime(1828, 8, 21, 11, 4, 5, 326882),
#  datetime.datetime(1954, 11, 15, 11, 4, 5, 326882),
#  datetime.datetime(1790, 7, 18, 11, 4, 5, 326882),
#  datetime.datetime(1966, 2, 7, 11, 4, 5, 326882),
#  datetime.datetime(2015, 4, 26, 11, 4, 5, 326882),
#  datetime.datetime(1971, 6, 7, 11, 4, 5, 326882),
#  datetime.datetime(2016, 1, 20, 11, 4, 5, 326882),
#  datetime.datetime(1978, 10, 21, 11, 4, 5, 326882),
#  datetime.datetime(1913, 6, 25, 11, 4, 5, 326882),
#  datetime.datetime(1842, 3, 22, 11, 4, 5, 326882),
#  datetime.datetime(1954, 12, 3, 11, 4, 5, 326882),
#  datetime.datetime(2001, 4, 5, 11, 4, 5, 326882),
#  datetime.datetime(1919, 11, 26, 11, 4, 5, 326882),
#  datetime.datetime(2018, 11, 12, 11, 4, 5, 326882),
#  datetime.datetime(1950, 11, 8, 11, 4, 5, 326882),
#  datetime.datetime(1923, 12, 21, 11, 4, 5, 326882),
#  datetime.datetime(1845, 11, 23, 11, 4, 5, 326882),
#  datetime.datetime(1803, 7, 7, 11, 4, 5, 326882),
#  datetime.datetime(1765, 10, 18, 11, 4, 5, 326882),
#  datetime.datetime(1767, 2, 19, 11, 4, 5, 326882),
#  datetime.datetime(1998, 5, 11, 11, 4, 5, 326882),
#  datetime.datetime(1847, 6, 25, 11, 4, 5, 326882),
#  datetime.datetime(1901, 12, 25, 11, 4, 5, 326882),
#  datetime.datetime(1842, 11, 2, 11, 4, 5, 326882),
#  datetime.datetime(1899, 12, 30, 11, 4, 5, 326882),
#  datetime.datetime(1930, 6, 29, 11, 4, 5, 326882),
#  datetime.datetime(1886, 1, 20, 11, 4, 5, 326882),
#  datetime.datetime(1973, 3, 13, 11, 4, 5, 326882),
#  datetime.datetime(1804, 7, 21, 11, 4, 5, 326882),
#  datetime.datetime(1794, 7, 3, 11, 4, 5, 326882),
#  datetime.datetime(1817, 5, 19, 11, 4, 5, 326882),
#  datetime.datetime(1786, 1, 1, 11, 4, 5, 326882),
#  datetime.datetime(1758, 12, 19, 11, 4, 5, 326882),
#  datetime.datetime(1911, 10, 17, 11, 4, 5, 326882),
#  datetime.datetime(1901, 1, 28, 11, 4, 5, 326882),
#  datetime.datetime(1849, 7, 10, 11, 4, 5, 326882),
#  datetime.datetime(1825, 6, 29, 11, 4, 5, 326882),
#  datetime.datetime(1958, 3, 1, 11, 4, 5, 326882),
#  datetime.datetime(1958, 5, 4, 11, 4, 5, 326882),
#  datetime.datetime(1976, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1866, 9, 12, 11, 4, 5, 326882),
#  datetime.datetime(1889, 4, 3, 11, 4, 5, 326882),
#  datetime.datetime(1916, 12, 12, 11, 4, 5, 326882),
#  datetime.datetime(1951, 9, 18, 11, 4, 5, 326882),
#  datetime.datetime(1762, 11, 15, 11, 4, 5, 326882),
#  datetime.datetime(1817, 4, 6, 11, 4, 5, 326882),
#  datetime.datetime(1832, 6, 20, 11, 4, 5, 326882),
#  datetime.datetime(1811, 9, 2, 11, 4, 5, 326882),
#  datetime.datetime(1906, 1, 27, 11, 4, 5, 326882),
#  datetime.datetime(1849, 10, 7, 11, 4, 5, 326882),
#  datetime.datetime(1992, 5, 7, 11, 4, 5, 326882),
#  datetime.datetime(1855, 8, 26, 11, 4, 5, 326882),
#  datetime.datetime(1765, 6, 4, 11, 4, 5, 326882),
#  datetime.datetime(2004, 8, 9, 11, 4, 5, 326882),
#  datetime.datetime(1841, 11, 21, 11, 4, 5, 326882),
#  datetime.datetime(1808, 6, 27, 11, 4, 5, 326882),
#  datetime.datetime(1988, 2, 4, 11, 4, 5, 326882),
#  datetime.datetime(2010, 5, 26, 11, 4, 5, 326882),
#  datetime.datetime(1819, 6, 22, 11, 4, 5, 326882),
#  datetime.datetime(1979, 5, 2, 11, 4, 5, 326882),
#  datetime.datetime(1997, 6, 13, 11, 4, 5, 326882),
#  datetime.datetime(1772, 1, 13, 11, 4, 5, 326882),
#  datetime.datetime(1873, 3, 20, 11, 4, 5, 326882),
#  datetime.datetime(1929, 4, 17, 11, 4, 5, 326882),
#  datetime.datetime(1784, 9, 4, 11, 4, 5, 326882),
#  datetime.datetime(1894, 3, 9, 11, 4, 5, 326882),
#  datetime.datetime(2009, 2, 17, 11, 4, 5, 326882),
#  datetime.datetime(1753, 4, 16, 11, 4, 5, 326882),
#  datetime.datetime(1758, 9, 6, 11, 4, 5, 326882),
#  datetime.datetime(1852, 7, 28, 11, 4, 5, 326882),
#  datetime.datetime(1970, 9, 8, 11, 4, 5, 326882),
#  datetime.datetime(1843, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1859, 4, 16, 11, 4, 5, 326882),
#  datetime.datetime(1886, 12, 30, 11, 4, 5, 326882),
#  datetime.datetime(1796, 9, 23, 11, 4, 5, 326882),
#  datetime.datetime(1847, 8, 25, 11, 4, 5, 326882),
#  datetime.datetime(1760, 2, 23, 11, 4, 5, 326882),
#  datetime.datetime(1825, 7, 15, 11, 4, 5, 326882),
#  datetime.datetime(1976, 10, 2, 11, 4, 5, 326882),
#  datetime.datetime(1937, 7, 3, 11, 4, 5, 326882),
#  datetime.datetime(1931, 3, 10, 11, 4, 5, 326882),
#  datetime.datetime(2001, 8, 10, 11, 4, 5, 326882),
#  datetime.datetime(1850, 3, 16, 11, 4, 5, 326882),
#  datetime.datetime(1866, 4, 27, 11, 4, 5, 326882),
#  datetime.datetime(1928, 7, 12, 11, 4, 5, 326882),
#  datetime.datetime(1812, 10, 27, 11, 4, 5, 326882),
#  datetime.datetime(1937, 6, 25, 11, 4, 5, 326882),
#  datetime.datetime(1959, 3, 19, 11, 4, 5, 326882),
#  datetime.datetime(1783, 1, 21, 11, 4, 5, 326882),
#  datetime.datetime(1770, 1, 30, 11, 4, 5, 326882),
#  datetime.datetime(2021, 9, 15, 11, 4, 5, 326882),
#  datetime.datetime(1909, 4, 14, 11, 4, 5, 326882),
#  datetime.datetime(1996, 8, 15, 11, 4, 5, 326882),
#  datetime.datetime(1953, 12, 7, 11, 4, 5, 326882),
#  datetime.datetime(1938, 1, 19, 11, 4, 5, 326882),
#  datetime.datetime(1927, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1876, 9, 18, 11, 4, 5, 326882),
#  datetime.datetime(1794, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1910, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1773, 6, 28, 11, 4, 5, 326882),
#  datetime.datetime(1882, 9, 26, 11, 4, 5, 326882),
#  datetime.datetime(1917, 12, 4, 11, 4, 5, 326882),
#  datetime.datetime(1750, 1, 6, 11, 4, 5, 326882),
#  datetime.datetime(1804, 1, 8, 11, 4, 5, 326882),
#  datetime.datetime(1991, 4, 12, 11, 4, 5, 326882),
#  datetime.datetime(1844, 12, 9, 11, 4, 5, 326882),
#  datetime.datetime(1873, 3, 29, 11, 4, 5, 326882),
#  datetime.datetime(1780, 8, 19, 11, 4, 5, 326882),
#  datetime.datetime(1894, 2, 15, 11, 4, 5, 326882),
#  datetime.datetime(1950, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1773, 11, 5, 11, 4, 5, 326882),
#  datetime.datetime(1810, 7, 31, 11, 4, 5, 326882),
#  datetime.datetime(1851, 8, 22, 11, 4, 5, 326882),
#  datetime.datetime(1841, 12, 11, 11, 4, 5, 326882),
#  datetime.datetime(1892, 6, 21, 11, 4, 5, 326882),
#  datetime.datetime(1914, 4, 4, 11, 4, 5, 326882),
#  datetime.datetime(1756, 6, 13, 11, 4, 5, 326882),
#  datetime.datetime(1794, 3, 8, 11, 4, 5, 326882),
#  datetime.datetime(1904, 2, 26, 11, 4, 5, 326882),
#  datetime.datetime(1813, 4, 11, 11, 4, 5, 326882),
#  datetime.datetime(1973, 9, 27, 11, 4, 5, 326882),
#  datetime.datetime(1802, 1, 21, 11, 4, 5, 326882),
#  datetime.datetime(1795, 9, 6, 11, 4, 5, 326882),
#  datetime.datetime(1846, 6, 14, 11, 4, 5, 326882),
#  datetime.datetime(1823, 2, 20, 11, 4, 5, 326882),
#  datetime.datetime(1768, 10, 4, 11, 4, 5, 326882),
#  datetime.datetime(1994, 1, 14, 11, 4, 5, 326882),
#  datetime.datetime(1793, 10, 16, 11, 4, 5, 326882),
#  datetime.datetime(1775, 10, 27, 11, 4, 5, 326882),
#  datetime.datetime(1796, 1, 23, 11, 4, 5, 326882),
#  datetime.datetime(1914, 12, 6, 11, 4, 5, 326882),
#  datetime.datetime(1855, 12, 21, 11, 4, 5, 326882),
#  datetime.datetime(1867, 5, 28, 11, 4, 5, 326882),
#  datetime.datetime(1989, 8, 23, 11, 4, 5, 326882),
#  datetime.datetime(1834, 8, 4, 11, 4, 5, 326882),
#  datetime.datetime(1904, 11, 27, 11, 4, 5, 326882),
#  datetime.datetime(1994, 2, 8, 11, 4, 5, 326882),
#  datetime.datetime(1791, 11, 20, 11, 4, 5, 326882),
#  datetime.datetime(1834, 5, 2, 11, 4, 5, 326882),
#  datetime.datetime(2010, 8, 12, 11, 4, 5, 326882),
#  datetime.datetime(1782, 8, 27, 11, 4, 5, 326882),
#  datetime.datetime(1984, 6, 27, 11, 4, 5, 326882),
#  datetime.datetime(1840, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1769, 1, 15, 11, 4, 5, 326882),
#  datetime.datetime(1819, 3, 3, 11, 4, 5, 326882),
#  datetime.datetime(1815, 8, 24, 11, 4, 5, 326882),
#  datetime.datetime(1751, 10, 12, 11, 4, 5, 326882),
#  datetime.datetime(1980, 6, 20, 11, 4, 5, 326882),
#  datetime.datetime(1749, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1783, 12, 19, 11, 4, 5, 326882),
#  datetime.datetime(1908, 12, 2, 11, 4, 5, 326882),
#  datetime.datetime(1938, 10, 15, 11, 4, 5, 326882),
#  datetime.datetime(1824, 6, 28, 11, 4, 5, 326882),
#  datetime.datetime(2001, 5, 9, 11, 4, 5, 326882),
#  datetime.datetime(1898, 4, 24, 11, 4, 5, 326882),
#  datetime.datetime(1842, 8, 9, 11, 4, 5, 326882),
#  datetime.datetime(1751, 7, 5, 11, 4, 5, 326882),
#  datetime.datetime(1941, 9, 9, 11, 4, 5, 326882),
#  datetime.datetime(1786, 7, 18, 11, 4, 5, 326882),
#  datetime.datetime(2010, 8, 5, 11, 4, 5, 326882),
#  datetime.datetime(2004, 3, 13, 11, 4, 5, 326882),
#  datetime.datetime(1788, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1770, 7, 20, 11, 4, 5, 326882),
#  datetime.datetime(1777, 11, 17, 11, 4, 5, 326882),
#  datetime.datetime(1748, 7, 10, 11, 4, 5, 326882),
#  datetime.datetime(1841, 9, 24, 11, 4, 5, 326882),
#  datetime.datetime(1786, 11, 21, 11, 4, 5, 326882),
#  datetime.datetime(1774, 1, 11, 11, 4, 5, 326882),
#  datetime.datetime(1865, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1895, 1, 13, 11, 4, 5, 326882),
#  datetime.datetime(1910, 12, 27, 11, 4, 5, 326882),
#  datetime.datetime(1988, 6, 17, 11, 4, 5, 326882),
#  datetime.datetime(1782, 1, 20, 11, 4, 5, 326882),
#  datetime.datetime(1759, 6, 16, 11, 4, 5, 326882),
#  datetime.datetime(1810, 8, 26, 11, 4, 5, 326882),
#  datetime.datetime(1893, 2, 23, 11, 4, 5, 326882),
#  datetime.datetime(1882, 1, 9, 11, 4, 5, 326882),
#  datetime.datetime(1959, 9, 21, 11, 4, 5, 326882),
#  datetime.datetime(1768, 6, 1, 11, 4, 5, 326882),
#  datetime.datetime(1913, 7, 29, 11, 4, 5, 326882),
#  datetime.datetime(1977, 9, 9, 11, 4, 5, 326882),
#  datetime.datetime(1880, 7, 26, 11, 4, 5, 326882),
#  datetime.datetime(1925, 7, 10, 11, 4, 5, 326882),
#  datetime.datetime(2016, 6, 2, 11, 4, 5, 326882),
#  datetime.datetime(1770, 10, 3, 11, 4, 5, 326882),
#  datetime.datetime(2018, 9, 2, 11, 4, 5, 326882),
#  datetime.datetime(1906, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1822, 2, 5, 11, 4, 5, 326882),
#  datetime.datetime(1803, 4, 28, 11, 4, 5, 326882),
#  datetime.datetime(1753, 2, 20, 11, 4, 5, 326882),
#  datetime.datetime(1838, 6, 2, 11, 4, 5, 326882),
#  datetime.datetime(1939, 11, 27, 11, 4, 5, 326882),
#  datetime.datetime(1815, 5, 16, 11, 4, 5, 326882),
#  datetime.datetime(1923, 9, 4, 11, 4, 5, 326882),
#  datetime.datetime(1865, 2, 24, 11, 4, 5, 326882),
#  datetime.datetime(1860, 12, 1, 11, 4, 5, 326882),
#  datetime.datetime(1989, 8, 30, 11, 4, 5, 326882),
#  datetime.datetime(1925, 12, 1, 11, 4, 5, 326882),
#  datetime.datetime(2018, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1914, 4, 7, 11, 4, 5, 326882),
#  datetime.datetime(1953, 2, 12, 11, 4, 5, 326882),
#  datetime.datetime(1962, 11, 12, 11, 4, 5, 326882),
#  datetime.datetime(1842, 4, 26, 11, 4, 5, 326882),
#  datetime.datetime(1864, 5, 31, 11, 4, 5, 326882),
#  datetime.datetime(1833, 1, 13, 11, 4, 5, 326882),
#  datetime.datetime(1821, 7, 16, 11, 4, 5, 326882),
#  datetime.datetime(1871, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1755, 8, 14, 11, 4, 5, 326882),
#  datetime.datetime(1885, 8, 17, 11, 4, 5, 326882),
#  datetime.datetime(1890, 1, 15, 11, 4, 5, 326882),
#  datetime.datetime(2000, 9, 10, 11, 4, 5, 326882),
#  datetime.datetime(1984, 3, 11, 11, 4, 5, 326882),
#  datetime.datetime(1832, 3, 24, 11, 4, 5, 326882),
#  datetime.datetime(1927, 2, 6, 11, 4, 5, 326882),
#  datetime.datetime(2021, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1750, 7, 28, 11, 4, 5, 326882),
#  datetime.datetime(1880, 1, 8, 11, 4, 5, 326882),
#  datetime.datetime(1763, 11, 24, 11, 4, 5, 326882),
#  datetime.datetime(1923, 2, 11, 11, 4, 5, 326882),
#  datetime.datetime(1972, 10, 8, 11, 4, 5, 326882),
#  datetime.datetime(1759, 3, 10, 11, 4, 5, 326882),
#  datetime.datetime(1950, 5, 24, 11, 4, 5, 326882),
#  datetime.datetime(1827, 2, 13, 11, 4, 5, 326882),
#  datetime.datetime(1795, 10, 15, 11, 4, 5, 326882),
#  datetime.datetime(1802, 10, 1, 11, 4, 5, 326882),
#  datetime.datetime(2013, 1, 29, 11, 4, 5, 326882),
#  datetime.datetime(1778, 3, 7, 11, 4, 5, 326882),
#  datetime.datetime(1944, 5, 4, 11, 4, 5, 326882),
#  datetime.datetime(1907, 1, 23, 11, 4, 5, 326882),
#  datetime.datetime(1981, 3, 19, 11, 4, 5, 326882),
#  datetime.datetime(1871, 12, 1, 11, 4, 5, 326882),
#  datetime.datetime(1907, 12, 4, 11, 4, 5, 326882),
#  datetime.datetime(1958, 6, 3, 11, 4, 5, 326882),
#  datetime.datetime(1848, 2, 26, 11, 4, 5, 326882),
#  datetime.datetime(1805, 6, 2, 11, 4, 5, 326882),
#  datetime.datetime(1837, 10, 1, 11, 4, 5, 326882),
#  datetime.datetime(1904, 2, 9, 11, 4, 5, 326882),
#  datetime.datetime(1813, 9, 16, 11, 4, 5, 326882),
#  datetime.datetime(1892, 3, 21, 11, 4, 5, 326882),
#  datetime.datetime(1862, 10, 20, 11, 4, 5, 326882),
#  datetime.datetime(1836, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1769, 1, 21, 11, 4, 5, 326882),
#  datetime.datetime(1786, 6, 13, 11, 4, 5, 326882),
#  datetime.datetime(1997, 1, 27, 11, 4, 5, 326882),
#  datetime.datetime(1769, 1, 29, 11, 4, 5, 326882),
#  datetime.datetime(2015, 5, 30, 11, 4, 5, 326882),
#  datetime.datetime(1783, 2, 27, 11, 4, 5, 326882),
#  datetime.datetime(2021, 9, 3, 11, 4, 5, 326882),
#  datetime.datetime(1992, 9, 20, 11, 4, 5, 326882),
#  datetime.datetime(1881, 11, 30, 11, 4, 5, 326882),
#  datetime.datetime(1795, 11, 18, 11, 4, 5, 326882),
#  datetime.datetime(1818, 10, 4, 11, 4, 5, 326882),
#  datetime.datetime(1780, 8, 7, 11, 4, 5, 326882),
#  datetime.datetime(1810, 7, 3, 11, 4, 5, 326882),
#  datetime.datetime(2003, 6, 22, 11, 4, 5, 326882),
#  datetime.datetime(1789, 12, 27, 11, 4, 5, 326882),
#  datetime.datetime(1761, 10, 1, 11, 4, 5, 326882),
#  datetime.datetime(1793, 2, 24, 11, 4, 5, 326882),
#  datetime.datetime(1949, 4, 26, 11, 4, 5, 326882),
#  datetime.datetime(2007, 11, 20, 11, 4, 5, 326882),
#  datetime.datetime(1981, 6, 17, 11, 4, 5, 326882),
#  datetime.datetime(1946, 3, 31, 11, 4, 5, 326882),
#  datetime.datetime(1912, 6, 11, 11, 4, 5, 326882),
#  datetime.datetime(1941, 6, 9, 11, 4, 5, 326882),
#  datetime.datetime(1782, 4, 29, 11, 4, 5, 326882),
#  datetime.datetime(1846, 4, 9, 11, 4, 5, 326882),
#  datetime.datetime(1821, 8, 16, 11, 4, 5, 326882),
#  datetime.datetime(1826, 1, 3, 11, 4, 5, 326882),
#  datetime.datetime(1832, 6, 30, 11, 4, 5, 326882),
#  datetime.datetime(1965, 3, 30, 11, 4, 5, 326882),
#  datetime.datetime(2002, 7, 22, 11, 4, 5, 326882),
#  datetime.datetime(1848, 3, 26, 11, 4, 5, 326882),
#  datetime.datetime(1911, 7, 11, 11, 4, 5, 326882),
#  datetime.datetime(1770, 8, 22, 11, 4, 5, 326882),
#  datetime.datetime(1952, 12, 31, 11, 4, 5, 326882),
#  datetime.datetime(1931, 11, 16, 11, 4, 5, 326882),
#  datetime.datetime(1857, 10, 12, 11, 4, 5, 326882),
#  datetime.datetime(1899, 2, 25, 11, 4, 5, 326882),
#  datetime.datetime(1838, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1911, 11, 16, 11, 4, 5, 326882),
#  datetime.datetime(1849, 1, 15, 11, 4, 5, 326882),
#  datetime.datetime(1916, 8, 17, 11, 4, 5, 326882),
#  datetime.datetime(1817, 8, 11, 11, 4, 5, 326882),
#  datetime.datetime(2018, 11, 26, 11, 4, 5, 326882),
#  datetime.datetime(1787, 11, 30, 11, 4, 5, 326882),
#  datetime.datetime(1857, 4, 2, 11, 4, 5, 326882),
#  datetime.datetime(1893, 4, 27, 11, 4, 5, 326882),
#  datetime.datetime(1846, 3, 4, 11, 4, 5, 326882),
#  datetime.datetime(1812, 10, 22, 11, 4, 5, 326882),
#  datetime.datetime(1887, 10, 21, 11, 4, 5, 326882),
#  datetime.datetime(1834, 8, 18, 11, 4, 5, 326882),
#  datetime.datetime(1960, 7, 27, 11, 4, 5, 326882),
#  datetime.datetime(1821, 6, 4, 11, 4, 5, 326882),
#  datetime.datetime(1927, 11, 28, 11, 4, 5, 326882),
#  datetime.datetime(1765, 3, 7, 11, 4, 5, 326882),
#  datetime.datetime(1905, 9, 7, 11, 4, 5, 326882),
#  datetime.datetime(1871, 11, 20, 11, 4, 5, 326882),
#  datetime.datetime(2015, 1, 21, 11, 4, 5, 326882),
#  datetime.datetime(1968, 12, 6, 11, 4, 5, 326882),
#  datetime.datetime(1798, 2, 6, 11, 4, 5, 326882),
#  datetime.datetime(1765, 8, 4, 11, 4, 5, 326882),
#  datetime.datetime(2017, 7, 6, 11, 4, 5, 326882),
#  datetime.datetime(1941, 9, 13, 11, 4, 5, 326882),
#  datetime.datetime(1795, 6, 14, 11, 4, 5, 326882),
#  datetime.datetime(1781, 6, 26, 11, 4, 5, 326882),
#  datetime.datetime(1850, 8, 12, 11, 4, 5, 326882),
#  datetime.datetime(1991, 3, 12, 11, 4, 5, 326882),
#  datetime.datetime(1926, 1, 10, 11, 4, 5, 326882),
#  datetime.datetime(2013, 1, 30, 11, 4, 5, 326882),
#  datetime.datetime(1925, 1, 20, 11, 4, 5, 326882),
#  datetime.datetime(1971, 8, 5, 11, 4, 5, 326882),
#  datetime.datetime(1785, 2, 15, 11, 4, 5, 326882),
#  datetime.datetime(1983, 8, 9, 11, 4, 5, 326882),
#  datetime.datetime(1811, 4, 17, 11, 4, 5, 326882),
#  datetime.datetime(1944, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1826, 8, 17, 11, 4, 5, 326882),
#  datetime.datetime(1809, 4, 13, 11, 4, 5, 326882),
#  datetime.datetime(1856, 10, 12, 11, 4, 5, 326882),
#  datetime.datetime(1793, 7, 27, 11, 4, 5, 326882),
#  datetime.datetime(1871, 12, 22, 11, 4, 5, 326882),
#  datetime.datetime(1754, 3, 29, 11, 4, 5, 326882),
#  datetime.datetime(1852, 12, 15, 11, 4, 5, 326882),
#  datetime.datetime(1886, 9, 14, 11, 4, 5, 326882),
#  datetime.datetime(1983, 6, 14, 11, 4, 5, 326882),
#  datetime.datetime(1865, 11, 6, 11, 4, 5, 326882),
#  datetime.datetime(1940, 8, 26, 11, 4, 5, 326882),
#  datetime.datetime(1939, 12, 8, 11, 4, 5, 326882),
#  datetime.datetime(1967, 2, 3, 11, 4, 5, 326882),
#  datetime.datetime(1936, 3, 13, 11, 4, 5, 326882),
#  datetime.datetime(1971, 10, 3, 11, 4, 5, 326882),
#  datetime.datetime(1876, 3, 24, 11, 4, 5, 326882),
#  datetime.datetime(1830, 2, 25, 11, 4, 5, 326882),
#  datetime.datetime(1960, 10, 7, 11, 4, 5, 326882),
#  datetime.datetime(1950, 3, 7, 11, 4, 5, 326882),
#  datetime.datetime(1818, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1985, 10, 14, 11, 4, 5, 326882),
#  datetime.datetime(1837, 8, 4, 11, 4, 5, 326882),
#  datetime.datetime(1794, 1, 3, 11, 4, 5, 326882),
#  datetime.datetime(1987, 1, 4, 11, 4, 5, 326882),
#  datetime.datetime(1927, 6, 28, 11, 4, 5, 326882),
#  datetime.datetime(1846, 7, 4, 11, 4, 5, 326882),
#  datetime.datetime(1997, 1, 17, 11, 4, 5, 326882),
#  datetime.datetime(1908, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1812, 5, 4, 11, 4, 5, 326882),
#  datetime.datetime(1771, 9, 11, 11, 4, 5, 326882),
#  datetime.datetime(1787, 5, 15, 11, 4, 5, 326882),
#  datetime.datetime(1853, 9, 21, 11, 4, 5, 326882),
#  datetime.datetime(1849, 10, 15, 11, 4, 5, 326882),
#  datetime.datetime(1767, 5, 18, 11, 4, 5, 326882),
#  datetime.datetime(1872, 1, 23, 11, 4, 5, 326882),
#  datetime.datetime(1980, 4, 7, 11, 4, 5, 326882),
#  datetime.datetime(1810, 5, 22, 11, 4, 5, 326882),
#  datetime.datetime(2021, 9, 7, 11, 4, 5, 326882),
#  datetime.datetime(2007, 8, 5, 11, 4, 5, 326882),
#  datetime.datetime(1905, 2, 14, 11, 4, 5, 326882),
#  datetime.datetime(1854, 10, 13, 11, 4, 5, 326882),
#  datetime.datetime(1911, 3, 15, 11, 4, 5, 326882),
#  datetime.datetime(1917, 9, 20, 11, 4, 5, 326882),
#  datetime.datetime(1954, 1, 3, 11, 4, 5, 326882),
#  datetime.datetime(1846, 11, 12, 11, 4, 5, 326882),
#  datetime.datetime(1981, 11, 28, 11, 4, 5, 326882),
#  datetime.datetime(1896, 5, 28, 11, 4, 5, 326882),
#  datetime.datetime(1871, 9, 5, 11, 4, 5, 326882),
#  datetime.datetime(1827, 1, 20, 11, 4, 5, 326882),
#  datetime.datetime(1968, 8, 29, 11, 4, 5, 326882),
#  datetime.datetime(1942, 12, 19, 11, 4, 5, 326882),
#  datetime.datetime(1754, 8, 18, 11, 4, 5, 326882),
#  datetime.datetime(1781, 8, 21, 11, 4, 5, 326882),
#  datetime.datetime(2018, 3, 23, 11, 4, 5, 326882),
#  datetime.datetime(1854, 6, 1, 11, 4, 5, 326882),
#  datetime.datetime(1817, 10, 10, 11, 4, 5, 326882),
#  datetime.datetime(1754, 3, 16, 11, 4, 5, 326882),
#  datetime.datetime(1894, 6, 15, 11, 4, 5, 326882),
#  datetime.datetime(1840, 11, 19, 11, 4, 5, 326882),
#  datetime.datetime(1975, 3, 11, 11, 4, 5, 326882),
#  datetime.datetime(1892, 10, 24, 11, 4, 5, 326882),
#  datetime.datetime(1986, 1, 10, 11, 4, 5, 326882),
#  datetime.datetime(1930, 9, 22, 11, 4, 5, 326882),
#  datetime.datetime(1825, 7, 25, 11, 4, 5, 326882),
#  datetime.datetime(1932, 11, 30, 11, 4, 5, 326882),
#  datetime.datetime(1895, 10, 20, 11, 4, 5, 326882),
#  datetime.datetime(1768, 7, 25, 11, 4, 5, 326882),
#  datetime.datetime(1762, 8, 16, 11, 4, 5, 326882),
#  datetime.datetime(1964, 3, 4, 11, 4, 5, 326882),
#  datetime.datetime(1768, 1, 16, 11, 4, 5, 326882),
#  datetime.datetime(1820, 11, 27, 11, 4, 5, 326882),
#  datetime.datetime(1815, 1, 2, 11, 4, 5, 326882),
#  datetime.datetime(1999, 6, 2, 11, 4, 5, 326882),
#  datetime.datetime(1828, 12, 3, 11, 4, 5, 326882),
#  datetime.datetime(1996, 5, 14, 11, 4, 5, 326882),
#  datetime.datetime(1968, 6, 11, 11, 4, 5, 326882),
#  datetime.datetime(1979, 5, 23, 11, 4, 5, 326882),
#  datetime.datetime(1976, 6, 19, 11, 4, 5, 326882),
#  datetime.datetime(1784, 8, 10, 11, 4, 5, 326882),
#  datetime.datetime(1953, 1, 2, 11, 4, 5, 326882),
#  datetime.datetime(1934, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1908, 11, 4, 11, 4, 5, 326882),
#  datetime.datetime(1839, 8, 21, 11, 4, 5, 326882),
#  datetime.datetime(1798, 12, 5, 11, 4, 5, 326882),
#  datetime.datetime(1961, 9, 15, 11, 4, 5, 326882),
#  datetime.datetime(1898, 4, 21, 11, 4, 5, 326882),
#  datetime.datetime(1871, 11, 17, 11, 4, 5, 326882),
#  datetime.datetime(1925, 6, 26, 11, 4, 5, 326882),
#  datetime.datetime(1937, 7, 16, 11, 4, 5, 326882),
#  datetime.datetime(1951, 4, 19, 11, 4, 5, 326882),
#  datetime.datetime(1832, 3, 10, 11, 4, 5, 326882),
#  datetime.datetime(1994, 10, 13, 11, 4, 5, 326882),
#  datetime.datetime(1977, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1891, 12, 27, 11, 4, 5, 326882),
#  datetime.datetime(1962, 1, 14, 11, 4, 5, 326882),
#  datetime.datetime(2001, 3, 12, 11, 4, 5, 326882),
#  datetime.datetime(1987, 8, 23, 11, 4, 5, 326882),
#  datetime.datetime(1772, 6, 12, 11, 4, 5, 326882),
#  datetime.datetime(1795, 7, 12, 11, 4, 5, 326882),
#  datetime.datetime(1995, 2, 10, 11, 4, 5, 326882),
#  datetime.datetime(1937, 3, 3, 11, 4, 5, 326882),
#  datetime.datetime(1991, 5, 8, 11, 4, 5, 326882),
#  datetime.datetime(1906, 2, 16, 11, 4, 5, 326882),
#  datetime.datetime(1755, 5, 6, 11, 4, 5, 326882),
#  datetime.datetime(1879, 3, 9, 11, 4, 5, 326882),
#  datetime.datetime(1988, 9, 10, 11, 4, 5, 326882),
#  datetime.datetime(1916, 8, 5, 11, 4, 5, 326882),
#  datetime.datetime(1985, 10, 30, 11, 4, 5, 326882),
#  datetime.datetime(1748, 4, 11, 11, 4, 5, 326882),
#  datetime.datetime(1780, 3, 15, 11, 4, 5, 326882),
#  datetime.datetime(1847, 8, 10, 11, 4, 5, 326882),
#  datetime.datetime(1864, 8, 20, 11, 4, 5, 326882),
#  datetime.datetime(1791, 6, 15, 11, 4, 5, 326882),
#  datetime.datetime(1968, 10, 22, 11, 4, 5, 326882),
#  datetime.datetime(1852, 12, 28, 11, 4, 5, 326882),
#  datetime.datetime(1974, 6, 5, 11, 4, 5, 326882),
#  datetime.datetime(1942, 3, 20, 11, 4, 5, 326882),
#  datetime.datetime(1985, 2, 15, 11, 4, 5, 326882),
#  datetime.datetime(1975, 2, 4, 11, 4, 5, 326882),
#  datetime.datetime(1950, 12, 14, 11, 4, 5, 326882),
#  datetime.datetime(1849, 7, 5, 11, 4, 5, 326882),
#  datetime.datetime(1750, 3, 22, 11, 4, 5, 326882),
#  datetime.datetime(1749, 11, 2, 11, 4, 5, 326882),
#  datetime.datetime(1758, 3, 24, 11, 4, 5, 326882),
#  datetime.datetime(1923, 1, 6, 11, 4, 5, 326882),
#  datetime.datetime(1944, 9, 30, 11, 4, 5, 326882),
#  datetime.datetime(1994, 2, 17, 11, 4, 5, 326882),
#  datetime.datetime(1852, 10, 3, 11, 4, 5, 326882),
#  datetime.datetime(1847, 4, 13, 11, 4, 5, 326882),
#  datetime.datetime(1763, 12, 27, 11, 4, 5, 326882),
#  datetime.datetime(1877, 1, 27, 11, 4, 5, 326882),
#  datetime.datetime(1963, 4, 3, 11, 4, 5, 326882),
#  datetime.datetime(1787, 4, 6, 11, 4, 5, 326882),
#  datetime.datetime(1760, 6, 14, 11, 4, 5, 326882),
#  datetime.datetime(1981, 6, 25, 11, 4, 5, 326882),
#  datetime.datetime(1764, 8, 6, 11, 4, 5, 326882),
#  datetime.datetime(1784, 8, 12, 11, 4, 5, 326882),
#  datetime.datetime(1997, 8, 30, 11, 4, 5, 326882),
#  datetime.datetime(1916, 7, 4, 11, 4, 5, 326882),
#  datetime.datetime(2019, 2, 7, 11, 4, 5, 326882),
#  datetime.datetime(1838, 7, 28, 11, 4, 5, 326882),
#  datetime.datetime(1935, 6, 11, 11, 4, 5, 326882),
#  datetime.datetime(2005, 10, 21, 11, 4, 5, 326882),
#  datetime.datetime(1825, 10, 20, 11, 4, 5, 326882),
#  datetime.datetime(1858, 7, 8, 11, 4, 5, 326882),
#  datetime.datetime(1834, 11, 26, 11, 4, 5, 326882),
#  datetime.datetime(1917, 4, 15, 11, 4, 5, 326882),
#  datetime.datetime(1748, 2, 14, 11, 4, 5, 326882),
#  datetime.datetime(1787, 10, 9, 11, 4, 5, 326882),
#  datetime.datetime(1804, 4, 13, 11, 4, 5, 326882),
#  datetime.datetime(1850, 11, 12, 11, 4, 5, 326882),
#  datetime.datetime(1995, 9, 4, 11, 4, 5, 326882),
#  datetime.datetime(1829, 3, 20, 11, 4, 5, 326882),
#  datetime.datetime(1983, 8, 4, 11, 4, 5, 326882),
#  datetime.datetime(1955, 12, 18, 11, 4, 5, 326882),
#  datetime.datetime(1860, 8, 26, 11, 4, 5, 326882),
#  datetime.datetime(1844, 6, 27, 11, 4, 5, 326882),
#  datetime.datetime(1805, 10, 22, 11, 4, 5, 326882),
#  datetime.datetime(1987, 4, 24, 11, 4, 5, 326882),
#  datetime.datetime(1926, 1, 26, 11, 4, 5, 326882),
#  datetime.datetime(1968, 12, 21, 11, 4, 5, 326882),
#  datetime.datetime(1943, 12, 29, 11, 4, 5, 326882),
#  datetime.datetime(1804, 11, 5, 11, 4, 5, 326882),
#  datetime.datetime(1971, 12, 6, 11, 4, 5, 326882),
#  datetime.datetime(2019, 2, 5, 11, 4, 5, 326882),
#  datetime.datetime(1949, 1, 3, 11, 4, 5, 326882),
#  datetime.datetime(1818, 3, 27, 11, 4, 5, 326882),
#  datetime.datetime(1915, 12, 30, 11, 4, 5, 326882),
#  datetime.datetime(1901, 10, 23, 11, 4, 5, 326882),
#  datetime.datetime(1906, 6, 17, 11, 4, 5, 326882),
#  datetime.datetime(1823, 7, 31, 11, 4, 5, 326882),
#  datetime.datetime(1926, 4, 16, 11, 4, 5, 326882),
#  datetime.datetime(2008, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(1862, 9, 16, 11, 4, 5, 326882),
#  datetime.datetime(1818, 11, 20, 11, 4, 5, 326882),
#  datetime.datetime(1895, 4, 2, 11, 4, 5, 326882),
#  datetime.datetime(1944, 5, 10, 11, 4, 5, 326882),
#  datetime.datetime(1794, 5, 2, 11, 4, 5, 326882),
#  datetime.datetime(1961, 1, 11, 11, 4, 5, 326882),
#  datetime.datetime(1899, 8, 27, 11, 4, 5, 326882),
#  datetime.datetime(1788, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1762, 6, 3, 11, 4, 5, 326882),
#  datetime.datetime(1812, 4, 1, 11, 4, 5, 326882),
#  datetime.datetime(1767, 12, 29, 11, 4, 5, 326882),
#  datetime.datetime(1947, 2, 19, 11, 4, 5, 326882),
#  datetime.datetime(1946, 4, 3, 11, 4, 5, 326882),
#  datetime.datetime(1982, 10, 23, 11, 4, 5, 326882),
#  datetime.datetime(2021, 6, 27, 11, 4, 5, 326882),
#  datetime.datetime(1981, 6, 19, 11, 4, 5, 326882),
#  datetime.datetime(1863, 8, 11, 11, 4, 5, 326882),
#  datetime.datetime(1882, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(1993, 3, 30, 11, 4, 5, 326882),
#  datetime.datetime(1748, 12, 1, 11, 4, 5, 326882),
#  datetime.datetime(1950, 3, 1, 11, 4, 5, 326882),
#  datetime.datetime(1881, 1, 7, 11, 4, 5, 326882),
#  datetime.datetime(1875, 7, 31, 11, 4, 5, 326882),
#  datetime.datetime(1835, 4, 1, 11, 4, 5, 326882),
#  datetime.datetime(1936, 11, 10, 11, 4, 5, 326882),
#  datetime.datetime(1857, 5, 16, 11, 4, 5, 326882),
#  datetime.datetime(1871, 5, 15, 11, 4, 5, 326882),
#  datetime.datetime(1966, 6, 19, 11, 4, 5, 326882),
#  datetime.datetime(2020, 11, 14, 11, 4, 5, 326882),
#  datetime.datetime(1869, 1, 30, 11, 4, 5, 326882),
#  datetime.datetime(1844, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1758, 4, 18, 11, 4, 5, 326882),
#  datetime.datetime(1894, 8, 14, 11, 4, 5, 326882),
#  datetime.datetime(1884, 3, 13, 11, 4, 5, 326882),
#  datetime.datetime(1947, 1, 11, 11, 4, 5, 326882),
#  datetime.datetime(1937, 7, 25, 11, 4, 5, 326882),
#  datetime.datetime(1837, 9, 9, 11, 4, 5, 326882),
#  datetime.datetime(1780, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1808, 6, 21, 11, 4, 5, 326882),
#  datetime.datetime(1882, 2, 2, 11, 4, 5, 326882),
#  datetime.datetime(1993, 10, 26, 11, 4, 5, 326882),
#  datetime.datetime(1865, 6, 15, 11, 4, 5, 326882),
#  datetime.datetime(1788, 5, 2, 11, 4, 5, 326882),
#  datetime.datetime(1951, 12, 21, 11, 4, 5, 326882),
#  datetime.datetime(2002, 2, 4, 11, 4, 5, 326882),
#  datetime.datetime(1884, 9, 7, 11, 4, 5, 326882),
#  datetime.datetime(1805, 7, 1, 11, 4, 5, 326882),
#  datetime.datetime(1966, 9, 6, 11, 4, 5, 326882),
#  datetime.datetime(1831, 12, 14, 11, 4, 5, 326882),
#  datetime.datetime(1946, 5, 18, 11, 4, 5, 326882),
#  datetime.datetime(2016, 4, 8, 11, 4, 5, 326882),
#  datetime.datetime(1809, 12, 4, 11, 4, 5, 326882),
#  datetime.datetime(1995, 8, 20, 11, 4, 5, 326882),
#  datetime.datetime(1894, 1, 1, 11, 4, 5, 326882),
#  datetime.datetime(1901, 12, 4, 11, 4, 5, 326882),
#  datetime.datetime(1877, 5, 9, 11, 4, 5, 326882),
#  datetime.datetime(1817, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1823, 7, 10, 11, 4, 5, 326882),
#  datetime.datetime(1779, 8, 27, 11, 4, 5, 326882),
#  datetime.datetime(1802, 7, 22, 11, 4, 5, 326882),
#  datetime.datetime(1811, 8, 20, 11, 4, 5, 326882),
#  datetime.datetime(1751, 10, 3, 11, 4, 5, 326882),
#  datetime.datetime(1932, 11, 19, 11, 4, 5, 326882),
#  datetime.datetime(1818, 7, 4, 11, 4, 5, 326882),
#  datetime.datetime(1774, 12, 15, 11, 4, 5, 326882),
#  datetime.datetime(1892, 7, 6, 11, 4, 5, 326882),
#  datetime.datetime(1968, 9, 10, 11, 4, 5, 326882),
#  datetime.datetime(1762, 10, 6, 11, 4, 5, 326882),
#  datetime.datetime(1971, 12, 9, 11, 4, 5, 326882),
#  datetime.datetime(1907, 11, 18, 11, 4, 5, 326882),
#  datetime.datetime(1977, 5, 20, 11, 4, 5, 326882),
#  datetime.datetime(1855, 7, 22, 11, 4, 5, 326882),
#  datetime.datetime(1819, 12, 21, 11, 4, 5, 326882),
#  datetime.datetime(1819, 12, 10, 11, 4, 5, 326882),
#  datetime.datetime(1793, 10, 13, 11, 4, 5, 326882),
#  datetime.datetime(1783, 5, 23, 11, 4, 5, 326882),
#  datetime.datetime(1949, 4, 27, 11, 4, 5, 326882),
#  datetime.datetime(1874, 9, 29, 11, 4, 5, 326882),
#  datetime.datetime(1895, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1931, 10, 28, 11, 4, 5, 326882),
#  datetime.datetime(1860, 5, 23, 11, 4, 5, 326882),
#  datetime.datetime(1772, 12, 16, 11, 4, 5, 326882),
#  datetime.datetime(1796, 8, 28, 11, 4, 5, 326882),
#  datetime.datetime(1771, 3, 9, 11, 4, 5, 326882),
#  datetime.datetime(1923, 9, 7, 11, 4, 5, 326882),
#  datetime.datetime(1867, 6, 1, 11, 4, 5, 326882),
#  datetime.datetime(1883, 4, 26, 11, 4, 5, 326882),
#  datetime.datetime(1871, 8, 24, 11, 4, 5, 326882),
#  datetime.datetime(1826, 3, 29, 11, 4, 5, 326882),
#  datetime.datetime(1910, 7, 1, 11, 4, 5, 326882),
#  datetime.datetime(1968, 5, 23, 11, 4, 5, 326882),
#  datetime.datetime(1791, 1, 5, 11, 4, 5, 326882),
#  datetime.datetime(1926, 2, 18, 11, 4, 5, 326882),
#  datetime.datetime(1898, 11, 23, 11, 4, 5, 326882),
#  datetime.datetime(1764, 8, 13, 11, 4, 5, 326882),
#  datetime.datetime(1954, 8, 19, 11, 4, 5, 326882),
#  datetime.datetime(1824, 8, 30, 11, 4, 5, 326882),
#  datetime.datetime(1880, 7, 3, 11, 4, 5, 326882),
#  datetime.datetime(1939, 3, 6, 11, 4, 5, 326882),
#  datetime.datetime(1769, 3, 2, 11, 4, 5, 326882),
#  datetime.datetime(1930, 7, 28, 11, 4, 5, 326882),
#  datetime.datetime(2003, 10, 5, 11, 4, 5, 326882),
#  datetime.datetime(1996, 8, 13, 11, 4, 5, 326882),
#  datetime.datetime(1860, 10, 16, 11, 4, 5, 326882),
#  datetime.datetime(1896, 8, 3, 11, 4, 5, 326882),
#  datetime.datetime(1869, 5, 24, 11, 4, 5, 326882),
#  datetime.datetime(1834, 3, 24, 11, 4, 5, 326882),
#  datetime.datetime(1764, 6, 25, 11, 4, 5, 326882),
#  datetime.datetime(1884, 8, 9, 11, 4, 5, 326882),
#  datetime.datetime(1829, 11, 25, 11, 4, 5, 326882),
#  datetime.datetime(1847, 1, 23, 11, 4, 5, 326882),
#  datetime.datetime(1927, 1, 31, 11, 4, 5, 326882),
#  datetime.datetime(1814, 8, 9, 11, 4, 5, 326882),
#  datetime.datetime(1761, 5, 23, 11, 4, 5, 326882),
#  datetime.datetime(1847, 2, 2, 11, 4, 5, 326882),
#  datetime.datetime(1863, 9, 28, 11, 4, 5, 326882),
#  datetime.datetime(1828, 2, 25, 11, 4, 5, 326882),
#  datetime.datetime(1782, 2, 8, 11, 4, 5, 326882),
#  datetime.datetime(1774, 2, 25, 11, 4, 5, 326882),
#  datetime.datetime(1896, 7, 25, 11, 4, 5, 326882),
#  datetime.datetime(1767, 3, 5, 11, 4, 5, 326882),
#  datetime.datetime(1806, 11, 11, 11, 4, 5, 326882),
#  datetime.datetime(1864, 6, 6, 11, 4, 5, 326882),
#  datetime.datetime(1889, 5, 5, 11, 4, 5, 326882),
#  datetime.datetime(1958, 2, 13, 11, 4, 5, 326882),
#  datetime.datetime(1802, 3, 25, 11, 4, 5, 326882),
#  datetime.datetime(1862, 11, 15, 11, 4, 5, 326882),
#  datetime.datetime(1814, 8, 11, 11, 4, 5, 326882),
#  datetime.datetime(1800, 2, 23, 11, 4, 5, 326882),
#  datetime.datetime(1919, 1, 15, 11, 4, 5, 326882),
#  datetime.datetime(1798, 3, 7, 11, 4, 5, 326882),
#  datetime.datetime(1965, 6, 9, 11, 4, 5, 326882),
#  datetime.datetime(1769, 12, 25, 11, 4, 5, 326882),
#  datetime.datetime(1810, 6, 22, 11, 4, 5, 326882),
#  datetime.datetime(1855, 8, 5, 11, 4, 5, 326882),
#  datetime.datetime(1826, 1, 11, 11, 4, 5, 326882),
#  datetime.datetime(1815, 6, 5, 11, 4, 5, 326882),
#  datetime.datetime(1909, 3, 20, 11, 4, 5, 326882),
#  datetime.datetime(1770, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1874, 1, 31, 11, 4, 5, 326882),
#  datetime.datetime(1838, 11, 14, 11, 4, 5, 326882),
#  datetime.datetime(1963, 6, 3, 11, 4, 5, 326882),
#  datetime.datetime(1781, 11, 21, 11, 4, 5, 326882),
#  datetime.datetime(1871, 5, 4, 11, 4, 5, 326882),
#  datetime.datetime(1972, 9, 10, 11, 4, 5, 326882),
#  datetime.datetime(1981, 6, 16, 11, 4, 5, 326882),
#  datetime.datetime(1865, 1, 28, 11, 4, 5, 326882),
#  datetime.datetime(1895, 5, 21, 11, 4, 5, 326882),
#  datetime.datetime(1756, 4, 21, 11, 4, 5, 326882),
#  datetime.datetime(1940, 2, 3, 11, 4, 5, 326882),
#  datetime.datetime(1990, 4, 2, 11, 4, 5, 326882),
#  datetime.datetime(1762, 5, 3, 11, 4, 5, 326882),
#  datetime.datetime(1935, 2, 8, 11, 4, 5, 326882),
#  datetime.datetime(1929, 3, 26, 11, 4, 5, 326882),
#  datetime.datetime(1986, 9, 19, 11, 4, 5, 326882),
#  datetime.datetime(1807, 7, 22, 11, 4, 5, 326882),
#  datetime.datetime(1824, 10, 12, 11, 4, 5, 326882),
#  datetime.datetime(1835, 5, 19, 11, 4, 5, 326882),
#  datetime.datetime(1951, 7, 31, 11, 4, 5, 326882),
#  datetime.datetime(1782, 6, 20, 11, 4, 5, 326882),
#  datetime.datetime(1872, 12, 19, 11, 4, 5, 326882),
#  datetime.datetime(1777, 2, 28, 11, 4, 5, 326882),
#  datetime.datetime(1925, 1, 31, 11, 4, 5, 326882),
#  datetime.datetime(1779, 2, 5, 11, 4, 5, 326882),
#  datetime.datetime(1799, 7, 12, 11, 4, 5, 326882),
#  datetime.datetime(1797, 5, 20, 11, 4, 5, 326882),
#  datetime.datetime(1835, 9, 1, 11, 4, 5, 326882),
#  datetime.datetime(1889, 4, 6, 11, 4, 5, 326882),
#  datetime.datetime(1823, 12, 24, 11, 4, 5, 326882),
#  datetime.datetime(1845, 6, 26, 11, 4, 5, 326882),
#  datetime.datetime(1916, 8, 22, 11, 4, 5, 326882),
#  datetime.datetime(1989, 1, 21, 11, 4, 5, 326882),
#  datetime.datetime(1907, 4, 21, 11, 4, 5, 326882),
#  datetime.datetime(1833, 5, 21, 11, 4, 5, 326882),
#  datetime.datetime(1933, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(1931, 9, 28, 11, 4, 5, 326882),
#  datetime.datetime(1934, 10, 29, 11, 4, 5, 326882),
#  datetime.datetime(1980, 1, 24, 11, 4, 5, 326882),
#  datetime.datetime(2001, 9, 9, 11, 4, 5, 326882),
#  datetime.datetime(2008, 9, 22, 11, 4, 5, 326882),
#  datetime.datetime(1908, 11, 14, 11, 4, 5, 326882),
#  datetime.datetime(1755, 7, 17, 11, 4, 5, 326882),
#  datetime.datetime(1845, 3, 26, 11, 4, 5, 326882),
#  datetime.datetime(1751, 7, 31, 11, 4, 5, 326882),
#  datetime.datetime(1989, 9, 30, 11, 4, 5, 326882),
#  datetime.datetime(1882, 3, 5, 11, 4, 5, 326882),
#  datetime.datetime(1940, 3, 14, 11, 4, 5, 326882),
#  datetime.datetime(2000, 5, 1, 11, 4, 5, 326882),
#  datetime.datetime(1866, 11, 21, 11, 4, 5, 326882),
#  datetime.datetime(1759, 4, 29, 11, 4, 5, 326882),
#  datetime.datetime(1918, 12, 6, 11, 4, 5, 326882),
#  datetime.datetime(1810, 10, 16, 11, 4, 5, 326882),
#  datetime.datetime(1970, 1, 2, 11, 4, 5, 326882),
#  datetime.datetime(1839, 7, 18, 11, 4, 5, 326882),
#  datetime.datetime(2008, 7, 26, 11, 4, 5, 326882),
#  datetime.datetime(1843, 8, 6, 11, 4, 5, 326882),
#  datetime.datetime(2021, 5, 20, 11, 4, 5, 326882),
#  datetime.datetime(1996, 9, 30, 11, 4, 5, 326882),
#  datetime.datetime(1837, 7, 17, 11, 4, 5, 326882),
#  datetime.datetime(1956, 11, 1, 11, 4, 5, 326882),
#  datetime.datetime(1931, 11, 5, 11, 4, 5, 326882),
#  datetime.datetime(1985, 4, 27, 11, 4, 5, 326882),
#  datetime.datetime(1787, 1, 25, 11, 4, 5, 326882),
#  datetime.datetime(1797, 3, 10, 11, 4, 5, 326882),
#  datetime.datetime(1800, 5, 11, 11, 4, 5, 326882),
#  datetime.datetime(1839, 3, 28, 11, 4, 5, 326882),
#  datetime.datetime(1816, 9, 13, 11, 4, 5, 326882),
#  datetime.datetime(1841, 10, 25, 11, 4, 5, 326882),
#  datetime.datetime(1907, 6, 2, 11, 4, 5, 326882),
#  datetime.datetime(1801, 5, 16, 11, 4, 5, 326882),
#  datetime.datetime(1790, 2, 8, 11, 4, 5, 326882),
#  datetime.datetime(1867, 4, 3, 11, 4, 5, 326882),
#  datetime.datetime(1916, 12, 1, 11, 4, 5, 326882),
#  datetime.datetime(1801, 5, 5, 11, 4, 5, 326882),
#  datetime.datetime(1934, 6, 29, 11, 4, 5, 326882),
#  datetime.datetime(1927, 1, 24, 11, 4, 5, 326882),
#  datetime.datetime(1860, 9, 23, 11, 4, 5, 326882),
#  datetime.datetime(1819, 6, 3, 11, 4, 5, 326882),
#  datetime.datetime(1780, 1, 8, 11, 4, 5, 326882),
#  datetime.datetime(1963, 6, 24, 11, 4, 5, 326882),
#  datetime.datetime(1798, 11, 5, 11, 4, 5, 326882),
#  datetime.datetime(1756, 12, 24, 11, 4, 5, 326882),
#  datetime.datetime(1754, 4, 21, 11, 4, 5, 326882),
#  datetime.datetime(1900, 12, 9, 11, 4, 5, 326882),
#  datetime.datetime(1861, 7, 23, 11, 4, 5, 326882),
#  datetime.datetime(1831, 5, 30, 11, 4, 5, 326882),
#  datetime.datetime(1892, 1, 21, 11, 4, 5, 326882),
#  datetime.datetime(1853, 11, 25, 11, 4, 5, 326882),
#  datetime.datetime(1792, 5, 2, 11, 4, 5, 326882),
#  datetime.datetime(1979, 3, 19, 11, 4, 5, 326882),
#  datetime.datetime(1879, 5, 28, 11, 4, 5, 326882),
#  datetime.datetime(1903, 8, 15, 11, 4, 5, 326882),
#  datetime.datetime(1951, 6, 20, 11, 4, 5, 326882),
#  datetime.datetime(1806, 10, 31, 11, 4, 5, 326882),
#  datetime.datetime(1781, 10, 1, 11, 4, 5, 326882),
#  datetime.datetime(1984, 4, 24, 11, 4, 5, 326882),
#  datetime.datetime(2008, 5, 11, 11, 4, 5, 326882),
#  datetime.datetime(1980, 8, 26, 11, 4, 5, 326882),
#  datetime.datetime(1786, 6, 11, 11, 4, 5, 326882),
#  datetime.datetime(1812, 11, 28, 11, 4, 5, 326882),
#  datetime.datetime(1849, 8, 3, 11, 4, 5, 326882),
#  datetime.datetime(1815, 9, 15, 11, 4, 5, 326882),
#  datetime.datetime(1802, 12, 29, 11, 4, 5, 326882),
#  datetime.datetime(1866, 10, 12, 11, 4, 5, 326882),
#  datetime.datetime(1910, 5, 14, 11, 4, 5, 326882),
#  datetime.datetime(1905, 11, 15, 11, 4, 5, 326882),
#  datetime.datetime(1818, 8, 18, 11, 4, 5, 326882),
#  datetime.datetime(1850, 2, 20, 11, 4, 5, 326882),
#  datetime.datetime(1792, 12, 4, 11, 4, 5, 326882),
#  datetime.datetime(1996, 9, 3, 11, 4, 5, 326882),
#  datetime.datetime(1864, 3, 24, 11, 4, 5, 326882),
#  datetime.datetime(1972, 7, 19, 11, 4, 5, 326882),
#  datetime.datetime(1956, 4, 1, 11, 4, 5, 326882),
#  datetime.datetime(2009, 8, 2, 11, 4, 5, 326882),
#  datetime.datetime(1964, 9, 9, 11, 4, 5, 326882),
#  datetime.datetime(1999, 1, 17, 11, 4, 5, 326882),
#  datetime.datetime(1772, 12, 2, 11, 4, 5, 326882),
#  datetime.datetime(1842, 2, 27, 11, 4, 5, 326882),
#  datetime.datetime(1808, 8, 7, 11, 4, 5, 326882),
#  datetime.datetime(1870, 10, 7, 11, 4, 5, 326882),
#  datetime.datetime(1818, 4, 24, 11, 4, 5, 326882),
#  datetime.datetime(1833, 2, 11, 11, 4, 5, 326882),
#  datetime.datetime(1941, 5, 18, 11, 4, 5, 326882),
#  datetime.datetime(1791, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(1848, 8, 19, 11, 4, 5, 326882),
#  datetime.datetime(1918, 6, 1, 11, 4, 5, 326882),
#  datetime.datetime(1966, 3, 19, 11, 4, 5, 326882),
#  datetime.datetime(1959, 12, 30, 11, 4, 5, 326882),
#  datetime.datetime(2015, 7, 9, 11, 4, 5, 326882),
#  datetime.datetime(1913, 3, 4, 11, 4, 5, 326882),
#  datetime.datetime(1979, 11, 30, 11, 4, 5, 326882),
#  datetime.datetime(1976, 10, 7, 11, 4, 5, 326882),
#  datetime.datetime(1860, 5, 27, 11, 4, 5, 326882),
#  datetime.datetime(1896, 6, 10, 11, 4, 5, 326882),
#  datetime.datetime(1895, 10, 18, 11, 4, 5, 326882),
#  datetime.datetime(1824, 10, 28, 11, 4, 5, 326882),
#  datetime.datetime(1797, 10, 11, 11, 4, 5, 326882),
#  datetime.datetime(1890, 2, 14, 11, 4, 5, 326882),
#  datetime.datetime(1900, 7, 24, 11, 4, 5, 326882),
#  datetime.datetime(1780, 3, 21, 11, 4, 5, 326882),
#  datetime.datetime(1804, 9, 8, 11, 4, 5, 326882),
#  datetime.datetime(1948, 8, 13, 11, 4, 5, 326882),
#  datetime.datetime(1932, 2, 4, 11, 4, 5, 326882),
#  datetime.datetime(1978, 10, 14, 11, 4, 5, 326882),
#  datetime.datetime(1856, 2, 21, 11, 4, 5, 326882),
#  datetime.datetime(1809, 8, 3, 11, 4, 5, 326882),
#  datetime.datetime(1900, 10, 17, 11, 4, 5, 326882),
#  datetime.datetime(1952, 3, 3, 11, 4, 5, 326882),
#  datetime.datetime(1944, 8, 10, 11, 4, 5, 326882),
#  datetime.datetime(1782, 5, 17, 11, 4, 5, 326882),
#  datetime.datetime(1981, 2, 5, 11, 4, 5, 326882),
#  datetime.datetime(1840, 4, 11, 11, 4, 5, 326882),
#  datetime.datetime(1845, 4, 10, 11, 4, 5, 326882),
#  datetime.datetime(1798, 8, 15, 11, 4, 5, 326882),
#  datetime.datetime(1760, 2, 8, 11, 4, 5, 326882),
#  datetime.datetime(1991, 4, 20, 11, 4, 5, 326882),
#  datetime.datetime(1917, 4, 6, 11, 4, 5, 326882),
#  datetime.datetime(1870, 3, 5, 11, 4, 5, 326882),
#  datetime.datetime(1890, 5, 4, 11, 4, 5, 326882),
#  datetime.datetime(1999, 12, 17, 11, 4, 5, 326882),
#  datetime.datetime(2017, 6, 11, 11, 4, 5, 326882),
#  datetime.datetime(1856, 12, 11, 11, 4, 5, 326882),
#  datetime.datetime(1924, 7, 4, 11, 4, 5, 326882),
#  datetime.datetime(1861, 10, 17, 11, 4, 5, 326882),
#  datetime.datetime(1808, 1, 22, 11, 4, 5, 326882),
#  datetime.datetime(1884, 8, 1, 11, 4, 5, 326882),
#  datetime.datetime(1948, 10, 14, 11, 4, 5, 326882),
#  datetime.datetime(1955, 11, 27, 11, 4, 5, 326882),
#  datetime.datetime(1825, 1, 17, 11, 4, 5, 326882),
#  datetime.datetime(1909, 11, 3, 11, 4, 5, 326882),
#  datetime.datetime(2007, 11, 3, 11, 4, 5, 326882),
#  datetime.datetime(1868, 6, 8, 11, 4, 5, 326882),
#  datetime.datetime(2001, 2, 27, 11, 4, 5, 326882),
#  datetime.datetime(1972, 9, 8, 11, 4, 5, 326882),
#  datetime.datetime(1935, 4, 7, 11, 4, 5, 326882),
#  datetime.datetime(1819, 6, 23, 11, 4, 5, 326882),
#  datetime.datetime(2002, 7, 26, 11, 4, 5, 326882),
#  datetime.datetime(1870, 8, 16, 11, 4, 5, 326882),
#  datetime.datetime(1863, 3, 12, 11, 4, 5, 326882),
#  datetime.datetime(1913, 12, 28, 11, 4, 5, 326882),
#  datetime.datetime(2002, 5, 19, 11, 4, 5, 326882),
#  datetime.datetime(1768, 7, 19, 11, 4, 5, 326882),
#  datetime.datetime(2000, 4, 20, 11, 4, 5, 326882),
#  ...]

# %%
def create_strings(n_samples=n_samples, length_strings=length_strings):
    chars = ascii_lowercase + digits
    sample_strings = [''.join(choice(chars) for _ in range(length_strings)) for _ in range(n_samples)]
    #print(lst)
    return sample_strings
sample_strings=create_strings()
sample_strings
# Out:
# ['qk1',
#  'a1u',
#  'osm',
#  'xmt',
#  'l8g',
#  'j2f',
#  '9j4',
#  'ezv',
#  'lot',
#  'u6g',
#  'qz0',
#  'ak4',
#  'zm8',
#  'dew',
#  'ces',
#  'rnq',
#  'bky',
#  'wa4',
#  'mxn',
#  'ey4',
#  '3kz',
#  '9mk',
#  'mij',
#  '4lm',
#  'vcj',
#  '2w5',
#  'io8',
#  'bvd',
#  'c97',
#  'k5q',
#  'mu1',
#  'lox',
#  'oqq',
#  'i2o',
#  '86u',
#  'ao2',
#  'elo',
#  'xgt',
#  'rhb',
#  'ceg',
#  '1oq',
#  '44s',
#  'uyr',
#  '5m8',
#  '27l',
#  'bob',
#  '5c1',
#  'ack',
#  'ya5',
#  'jeq',
#  'myr',
#  '4oz',
#  '9lo',
#  '0ph',
#  '21w',
#  'x9m',
#  'j2z',
#  '380',
#  'tvd',
#  '0jo',
#  'j2r',
#  'uoo',
#  '3t7',
#  '4dy',
#  'opa',
#  'tsr',
#  'a32',
#  'f5x',
#  'zdj',
#  'zi6',
#  'lgx',
#  '29p',
#  'p1z',
#  '9w5',
#  '5fz',
#  '0xq',
#  't30',
#  'czy',
#  '46q',
#  '26o',
#  'oqg',
#  '9cp',
#  'x18',
#  'oa2',
#  '1wh',
#  'i0d',
#  '8cu',
#  '7sx',
#  '7x6',
#  '5f2',
#  '676',
#  'jvy',
#  '38t',
#  'eem',
#  'vma',
#  'af9',
#  'j5i',
#  'giv',
#  'bvy',
#  'rpd',
#  '2gk',
#  'zrl',
#  'ti8',
#  'o5m',
#  'l52',
#  'gry',
#  '4hm',
#  'ixn',
#  '8m2',
#  '6eu',
#  'x3g',
#  '3mq',
#  'xe3',
#  'nb1',
#  'hvb',
#  'drz',
#  'kj6',
#  '472',
#  'vgm',
#  'g7h',
#  '559',
#  's68',
#  'zhk',
#  'ckt',
#  'e0w',
#  'xoo',
#  'kcq',
#  '0uc',
#  'u7l',
#  '9v2',
#  '6jm',
#  'wo8',
#  '5py',
#  'z1n',
#  'dpq',
#  't88',
#  '0f3',
#  '6or',
#  '9sm',
#  '851',
#  'v0l',
#  '4sn',
#  'ae7',
#  '0ez',
#  '25a',
#  '04o',
#  'sn5',
#  '43v',
#  'pbl',
#  'xyj',
#  'dpz',
#  'en2',
#  'lve',
#  'uss',
#  't3e',
#  'zkn',
#  '5fg',
#  'hce',
#  '4ta',
#  'h8i',
#  'alr',
#  'zi9',
#  'x6k',
#  'kof',
#  'lhv',
#  'dz4',
#  't6y',
#  '1oc',
#  'rlv',
#  'rwf',
#  'ty1',
#  'x3t',
#  'vg3',
#  'pn1',
#  'd2s',
#  'x8t',
#  'vir',
#  'h97',
#  '5sj',
#  'ibo',
#  'qqv',
#  'dfu',
#  'mqj',
#  'mim',
#  'g45',
#  'pmj',
#  '3kj',
#  'knv',
#  '6fd',
#  '4qb',
#  '6pa',
#  '6wc',
#  'tnw',
#  'fqm',
#  '60b',
#  'lu9',
#  'soo',
#  'ky3',
#  '5bf',
#  '6q4',
#  '7fw',
#  '4xg',
#  'gf6',
#  'c1w',
#  'kgb',
#  'klk',
#  'o6c',
#  'yen',
#  '8pf',
#  'ith',
#  '0bt',
#  'njn',
#  'box',
#  'l7t',
#  'kko',
#  'ngc',
#  '3xe',
#  'vq6',
#  'k1q',
#  'oqy',
#  'nsp',
#  'c0o',
#  '0tk',
#  '71q',
#  'nnq',
#  'ii1',
#  'wzx',
#  '6uw',
#  '51e',
#  '33o',
#  'f8a',
#  'm8k',
#  'c7k',
#  'ld7',
#  'pej',
#  '927',
#  'k18',
#  'k1k',
#  '8fy',
#  'vqa',
#  '0vp',
#  '9ie',
#  'nra',
#  '0pr',
#  '9hf',
#  'vk5',
#  '6qu',
#  'qa5',
#  'x6p',
#  '7p1',
#  '09w',
#  'rkz',
#  'wpd',
#  'c2r',
#  'y0s',
#  'eu6',
#  'qyf',
#  '4iu',
#  'r9f',
#  'dta',
#  'gdl',
#  '8qz',
#  'u33',
#  'su8',
#  'mh8',
#  '0y2',
#  '8re',
#  'cbd',
#  'bao',
#  'dje',
#  'tc3',
#  '09x',
#  '251',
#  'spr',
#  'yd0',
#  '5jz',
#  'wn3',
#  'iph',
#  'x6o',
#  '1ow',
#  'wl5',
#  'qas',
#  '2hr',
#  '4ss',
#  'itt',
#  'qxt',
#  'aah',
#  'pxq',
#  '3et',
#  'lky',
#  'g3y',
#  'owz',
#  '84z',
#  'q24',
#  'dzq',
#  'pj9',
#  'act',
#  'bum',
#  'lnf',
#  'c6m',
#  'e23',
#  'iw0',
#  'dp5',
#  'e0n',
#  'c7n',
#  'n5a',
#  'h99',
#  'fj4',
#  'qvl',
#  'tgq',
#  'r51',
#  'vtt',
#  'cbj',
#  '9xt',
#  '8nk',
#  'q5c',
#  '8rm',
#  'pb8',
#  'mjz',
#  '84u',
#  '3xk',
#  'h9x',
#  'v32',
#  '1bg',
#  '063',
#  'mfa',
#  'l4c',
#  'mc0',
#  'z9h',
#  'vvr',
#  '2ny',
#  'otr',
#  '104',
#  'kyv',
#  'y5x',
#  'i8w',
#  'tic',
#  'n4n',
#  'u8j',
#  'ntg',
#  'a6b',
#  'jl5',
#  'm9y',
#  'ff9',
#  '03v',
#  'fcj',
#  'cxy',
#  'w5v',
#  'gmw',
#  '5wr',
#  'kdz',
#  'g8l',
#  'm8b',
#  'rqf',
#  'wj5',
#  '91z',
#  'q0k',
#  'vzs',
#  'd32',
#  '3sq',
#  'qud',
#  '9vb',
#  '56n',
#  '35b',
#  'l5l',
#  'lh7',
#  'zdc',
#  'vn6',
#  'd2d',
#  '07a',
#  'pgm',
#  '727',
#  'o8h',
#  'iha',
#  'wka',
#  'b5c',
#  'qjt',
#  '6q9',
#  'rsg',
#  '1me',
#  's9n',
#  '5cb',
#  'c3c',
#  'spc',
#  'jwq',
#  'mc1',
#  'hdg',
#  'wq9',
#  'bsn',
#  '9gy',
#  '1p2',
#  'syv',
#  '0w8',
#  'rps',
#  'hdv',
#  'x8t',
#  'tjp',
#  'lew',
#  'cdw',
#  '7zq',
#  'nzo',
#  'e2m',
#  'meh',
#  'oeg',
#  'uao',
#  'wjz',
#  'eel',
#  'j4o',
#  'bwb',
#  'lg9',
#  'sp7',
#  '6dd',
#  '6h9',
#  'u70',
#  'sq9',
#  'jaz',
#  '2z3',
#  'des',
#  '3lf',
#  'vex',
#  '62v',
#  'zwx',
#  'fif',
#  'n4o',
#  'nvo',
#  '2yz',
#  'vce',
#  'c6v',
#  'ssg',
#  'hww',
#  '0q9',
#  'boi',
#  '4ku',
#  'umi',
#  'blr',
#  '1j5',
#  'ofq',
#  'kk6',
#  '8h2',
#  'ps5',
#  'rue',
#  'if4',
#  's9w',
#  'n8y',
#  'y34',
#  'ie2',
#  'cty',
#  '5p9',
#  'k8v',
#  'ije',
#  '0fd',
#  'ybb',
#  'zty',
#  'f6m',
#  'hzs',
#  'pzm',
#  'ork',
#  'jp5',
#  'nln',
#  '5nl',
#  'ckc',
#  'ra6',
#  'ad3',
#  '20k',
#  'u5j',
#  'jds',
#  '331',
#  '073',
#  'wub',
#  'hny',
#  'v9p',
#  'edx',
#  'pn5',
#  'yja',
#  '16y',
#  'tgb',
#  '527',
#  '9rj',
#  '5ga',
#  '8io',
#  'h7g',
#  '0kj',
#  'enn',
#  'p2j',
#  'y06',
#  '8s4',
#  '2wc',
#  '7p9',
#  'lc9',
#  'bws',
#  '77j',
#  '62r',
#  'pxg',
#  '48c',
#  '5on',
#  'wki',
#  'xko',
#  '5ua',
#  '4ky',
#  'xzi',
#  'zzg',
#  '9tc',
#  '89k',
#  '5cu',
#  '53k',
#  'tmn',
#  'xck',
#  'xa3',
#  '1pd',
#  'qve',
#  '5pz',
#  '0fo',
#  'p8j',
#  '892',
#  'ekp',
#  '8rd',
#  'xyn',
#  'ed6',
#  'h25',
#  'mn7',
#  'p9x',
#  'nyu',
#  '83q',
#  'obx',
#  'zic',
#  'use',
#  'tfb',
#  'g5f',
#  'ra3',
#  '64u',
#  '57s',
#  'wvp',
#  'xc7',
#  'zkl',
#  '0o3',
#  'z6r',
#  'qex',
#  '8as',
#  'er2',
#  'ug1',
#  'rt0',
#  '8ez',
#  'h7w',
#  'oor',
#  'fz2',
#  '6no',
#  'hwk',
#  'd9n',
#  'tem',
#  '35k',
#  'uiw',
#  'vtm',
#  '1bk',
#  '227',
#  'g4p',
#  '304',
#  '8uc',
#  '2ud',
#  'gk3',
#  'chk',
#  'umh',
#  'kuw',
#  'evj',
#  '8vc',
#  'i6n',
#  'zkq',
#  'x12',
#  'vkr',
#  'th5',
#  'mye',
#  'eyh',
#  'mne',
#  '5ew',
#  'x6d',
#  'qv5',
#  '5sk',
#  'auv',
#  'vyi',
#  '1r1',
#  'eig',
#  'a4f',
#  'bm8',
#  'tx6',
#  'yda',
#  '9x2',
#  '38e',
#  'b97',
#  'p8n',
#  'frf',
#  'pas',
#  'gy1',
#  '8ll',
#  'bid',
#  'y4l',
#  'esv',
#  'qhz',
#  'q35',
#  'xv7',
#  '4gr',
#  'jjj',
#  'lrg',
#  'lfj',
#  '8e9',
#  'fgl',
#  'z2s',
#  'obe',
#  'pdu',
#  'to6',
#  'r0n',
#  'ylj',
#  'ia8',
#  '7hp',
#  'cc2',
#  'dsu',
#  '7zw',
#  'tza',
#  'yna',
#  '1mq',
#  'ecc',
#  'iz1',
#  '81u',
#  'c21',
#  '56y',
#  '4ya',
#  '262',
#  'o2u',
#  '8xp',
#  '2as',
#  'hsk',
#  'tti',
#  'qhc',
#  'geo',
#  'vnm',
#  'wu3',
#  'nkr',
#  '6gc',
#  'hso',
#  '45m',
#  'wys',
#  'uq0',
#  '0b0',
#  'o0i',
#  '9cm',
#  'trv',
#  'qhl',
#  'y1m',
#  'hpa',
#  'kip',
#  'zj9',
#  'osn',
#  'zg3',
#  'rqi',
#  'x3o',
#  'rll',
#  '66q',
#  'k4g',
#  '0r3',
#  'qsh',
#  'ph3',
#  '527',
#  'ba1',
#  'uok',
#  'ulw',
#  '3vu',
#  '67w',
#  'fwc',
#  'n2r',
#  'iaf',
#  'j46',
#  'tzb',
#  'g8k',
#  'q7j',
#  'pkf',
#  'lja',
#  'rkd',
#  'ri2',
#  'mfe',
#  'otm',
#  '6t9',
#  'g74',
#  '620',
#  'cy2',
#  'd51',
#  'ps4',
#  'eny',
#  'qxz',
#  'rpf',
#  'gp4',
#  'ug0',
#  'j6q',
#  'jti',
#  'hk3',
#  'dg4',
#  'm7e',
#  'x0l',
#  'cqp',
#  '19x',
#  '9re',
#  'yqd',
#  '2x2',
#  'kvh',
#  'xyt',
#  '0ez',
#  'en0',
#  'cqe',
#  'k3h',
#  'r99',
#  'ixk',
#  '6co',
#  '9ce',
#  'rrk',
#  'a6a',
#  'kfv',
#  '36e',
#  'zjn',
#  'g8y',
#  'z1i',
#  '55n',
#  'g41',
#  'rfs',
#  'x32',
#  'e9b',
#  'did',
#  '3aw',
#  'ief',
#  'nm5',
#  '5t5',
#  'jxk',
#  'dib',
#  'v3r',
#  'dqm',
#  'fwa',
#  'h1r',
#  'la0',
#  '5qz',
#  '4th',
#  'ezx',
#  'cjq',
#  '0ak',
#  'd6o',
#  'd3o',
#  'upk',
#  '3o8',
#  '1bv',
#  '38v',
#  'wlc',
#  'afz',
#  '7cm',
#  'srd',
#  'vv8',
#  'kv4',
#  'xjn',
#  '03u',
#  'yn2',
#  'x7c',
#  'jr3',
#  'kq0',
#  'abe',
#  'qer',
#  'zbx',
#  'x2z',
#  'oy5',
#  'v84',
#  '4uv',
#  'v2n',
#  'tns',
#  'fda',
#  '1tb',
#  'qrs',
#  'mgb',
#  '6pi',
#  '9ws',
#  'cc6',
#  '80h',
#  'osx',
#  '7r2',
#  's4w',
#  'u63',
#  'r34',
#  '73y',
#  'x5p',
#  'v6f',
#  'c36',
#  'aba',
#  'o7e',
#  'qv7',
#  'kfb',
#  'f46',
#  'fud',
#  'as1',
#  '8sr',
#  'pe4',
#  '5gb',
#  'j9l',
#  'ahz',
#  't80',
#  'q1c',
#  'm4e',
#  'rw8',
#  'azt',
#  'c5n',
#  'm9s',
#  'rqz',
#  '48h',
#  '142',
#  'vlk',
#  'ybh',
#  '9wx',
#  'bdv',
#  'd9i',
#  'p23',
#  '80p',
#  '4sm',
#  'ybb',
#  'c5p',
#  'r0u',
#  'swf',
#  '9zg',
#  'tuv',
#  'dce',
#  '5kq',
#  'df0',
#  'gqm',
#  'cf5',
#  'c6o',
#  'pzn',
#  '891',
#  'ugr',
#  'bgh',
#  '8ec',
#  'fbo',
#  'm4p',
#  '4h2',
#  'zxe',
#  'jff',
#  '7na',
#  '4rx',
#  '5bs',
#  'iio',
#  'sst',
#  '0rj',
#  'zy3',
#  'a40',
#  's87',
#  'qlr',
#  'tk0',
#  '62z',
#  'xwa',
#  'slh',
#  'p4f',
#  'l75',
#  'kjy',
#  'sbo',
#  '6n7',
#  'tay',
#  'g4j',
#  'bnz',
#  'kux',
#  'xxy',
#  'e4j',
#  'idx',
#  '5sr',
#  '9b2',
#  'vnt',
#  'tl4',
#  'a09',
#  'cv0',
#  '2by',
#  'ibc',
#  'dxr',
#  '5jp',
#  'x5d',
#  '09r',
#  'oqm',
#  'of8',
#  '41d',
#  'a47',
#  'rtr',
#  'tll',
#  'cs7',
#  'zop',
#  '7jq',
#  '1rf',
#  'vxx',
#  '4qc',
#  'exb',
#  'xug',
#  'f1j',
#  '1hs',
#  '5c6',
#  'owp',
#  'eao',
#  'i4z',
#  'v8o',
#  '903',
#  'rj6',
#  'lgc',
#  'kyo',
#  't7g',
#  'ycn',
#  'f0x',
#  'w8m',
#  'fwx',
#  'eky',
#  'tye',
#  'l1a',
#  '2at',
#  'ro1',
#  'vi5',
#  'mhj',
#  'dub',
#  'p9t',
#  '21m',
#  'ksy',
#  '3bt',
#  'l8j',
#  'xki',
#  'vak',
#  'p87',
#  'l96',
#  'gp7',
#  'erl',
#  'bce',
#  'jyt',
#  '5ps',
#  '9n5',
#  'cgi',
#  'ko0',
#  'byx',
#  'ofe',
#  'qlw',
#  'peo',
#  'z02',
#  'u5h',
#  '8ac',
#  'kw7',
#  'hdk',
#  'nxk',
#  'nwo',
#  't9g',
#  'tgr',
#  '46z',
#  '0x9',
#  'qmr',
#  '03n',
#  'iwf',
#  'v4a',
#  '9z6',
#  'ua4',
#  'cmd',
#  'otq',
#  'nqz',
#  'x2o',
#  'd6z',
#  'dqr',
#  '1xu',
#  '0zk',
#  'g5u',
#  '2k7',
#  'dnr',
#  'seb',
#  'k9d',
#  'za3',
#  'w3e',
#  'hih',
#  'rab',
#  'nd9',
#  'kud',
#  'il1',
#  'wl7',
#  '3ly',
#  '6rw',
#  'zas',
#  'wsp',
#  'n9n',
#  'da0',
#  'dt0',
#  'l5d',
#  'ghr',
#  'ule',
#  're5',
#  'wo5',
#  'dv3',
#  'f33',
#  'zku',
#  'lj8',
#  '9xc',
#  'dt6',
#  'u5w',
#  '42x',
#  'azs',
#  'gt8',
#  'jn6',
#  'n40',
#  '8xu',
#  '3jh',
#  'hsa',
#  '26x',
#  '9sd',
#  'ign',
#  ...]

# %%
# Create uniform distribution
def uniform_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1.):
    sample_uniform = (np.random.uniform(low,high,n_samples))
    if display==True:
        plot_distribution(sample_uniform, n_samples, "Continuous Uniform Distribution", num_bins)
    return sample_uniform

sample_uniform=uniform_distribution()

# %%
def normal_distribution(n_samples=n_samples, num_bins=num_bins, display = True, mu=0., sigma=1.):
    # Normal distribution
    sample_normal = np.random.normal(mu, sigma, n_samples)
    if display == True:
        plot_distribution(sample_normal, n_samples, "Normal Distribution", num_bins)
    return sample_normal

sample_normal = normal_distribution()

# %%
def uniform_sorted_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1.):
    #Sorted Uniform distribution
    sample_uniform_sorted = np.sort(np.random.uniform(low,high,n_samples))
    if display == True:
        plot_distribution(sample_uniform_sorted, n_samples, "Sorted Continuous Uniform Distribution", num_bins)
    return sample_uniform_sorted
sample_uniform_sorted = uniform_sorted_distribution()

# %%
def uniform_reverse_sorted_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1.):
    # Reverse Sorted Uniform distribution
    sample_uniform_reverse_sorted = np.sort(np.random.uniform(low,high,n_samples))[::-1]
    if display == True:
        plot_distribution(sample_uniform_reverse_sorted, n_samples, "Reverse Sorted Continuous Uniform Distribution", num_bins)
    return sample_uniform_reverse_sorted
sample_uniform_reverse_sorted = uniform_reverse_sorted_distribution()

# %%
def uniform_nearly_sorted_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1., mean_noise= 0., std_noice = 0.01):
    # Nearly Uniform distribution
    sample_uniform_nearly_sorted = np.sort(np.random.uniform(low,high,n_samples))
    noise = np.random.normal(mean_noise,std_noice,n_samples)
    sample_uniform_nearly_sorted = sample_uniform_nearly_sorted + noise
    if display==True:
        plot_distribution(sample_uniform_nearly_sorted, n_samples, "Nearly Sorted Continuous Uniform Distribution", num_bins)
    return sample_uniform_nearly_sorted
sample_uniform_nearly_sorted = uniform_nearly_sorted_distribution()

# %%
def zipf_distribution(n_samples=n_samples, num_bins=num_bins, display = True, a=2.):
    # ZipF Distribution
    sample_zipf = np.random.zipf(a, n_samples)
    if display==True:
        # Plot
        """
        weights = np.ones_like(sample_zipf[sample_zipf<50])/float(len(sample_zipf[sample_zipf<50]))
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))
        #fig.suptitle('Zipf Distribution',fontsize=26,y=1.05)
        count, bins, ignored = ax1.hist(sample_zipf[sample_zipf<50], 20, weights=weights)
        #ax1.plot(bins, np.ones_like(bins), linewidth=2, color='r')
        #ax1.set_title('Probability Distribution',fontsize=26)
        ax1.set_ylabel('Frequency',fontsize=26)
        ax1.set_xlabel('Value',fontsize=26)
        plt.setp(ax1.get_yticklabels(), fontsize=20)
        plt.setp(ax1.get_xticklabels(), fontsize=20)
        y = np.arange(0,n_samples)
        ax2.scatter(y,sample_zipf,s=10)
        #ax2.set_title('Observation Value',fontsize=26)
        ax2.set_ylabel('Observation Value',fontsize=26)
        ax2.set_xlabel('Observation Number',fontsize=26)
        plt.setp(ax2.get_xticklabels(), fontsize=20)
        plt.setp(ax2.get_yticklabels(), fontsize=20)
        fig.tight_layout()
        """
        weights = np.ones_like(sample_zipf[sample_zipf<50])/float(len(sample_zipf[sample_zipf<50]))
        plt.figure(figsize=(8,6))
        count, bins, ignored = plt.hist(sample_zipf[sample_zipf<50], 20, weights=weights)
        #plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
        plt.ylabel('Frequency',fontsize=26)
        plt.xlabel('Observation Value',fontsize=26)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        plt.show()
        plt.figure(figsize=(8,6))
        y = np.arange(0,n_samples)
        plt.scatter(y,sample_zipf,s=10)
        plt.ylabel('Observation Value',fontsize=26)
        plt.xlabel('Number of Observation',fontsize=26)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        plt.show()

    return sample_zipf
sample_zipf = zipf_distribution()

# %%
def create_df_distribution(n_samples=n_samples, dist_type="Uniform"):
    df_distribion = pd.DataFrame().astype(np.float64)
    if dist_type == "Uniform":
        sample_uniform= uniform_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform"] = sample_uniform
    if dist_type == "Normal":
        sample_normal = normal_distribution(display=False, n_samples=n_samples)
        df_distribion["Normal"] = sample_normal
    if dist_type == "Uniform_Sorted":
        sample_uniform_sorted = uniform_sorted_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform_Sorted"] = sample_uniform_sorted
    if dist_type == "Uniform_Reverse_Sorted":
        sample_uniform_reverse_sorted = uniform_reverse_sorted_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform_Reverse_Sorted"] = sample_uniform_reverse_sorted
    if dist_type == "Uniform_Nearly_Sorted":
        sample_uniform_nearly_sorted = uniform_nearly_sorted_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform_Nearly_Sorted"] = sample_uniform_nearly_sorted
    if dist_type == "Zipf":
        sample_zipf = zipf_distribution(display=False, n_samples=n_samples)
        df_distribion["Zipf"] = sample_zipf
    if dist_type == "Dates":
        sample_dates = create_dates(n_samples=n_samples)
        df_distribion["Dates"] = sample_dates
    if dist_type == "Strings":
        sample_strings = create_strings(n_samples=n_samples)
        df_distribion["Strings"] = sample_strings
    if dist_type == "Discrete_Uniform":
        sample_discrete = discrete_uniform_distribution(n_samples=n_samples, n=n_discrete, display=False)
        df_distribion["Discrete_Uniform"] = sample_discrete
    if dist_type == "Discrete_Binomial":
        sample_bionmial = discrete_binomial_distribution(n_samples=n_samples, p=p, n=n_binomial, display=False)
        df_distribion["Discrete_Binomial"] = sample_bionmial
    if dist_type == "Poisson":
        poisson =  poission_distribution(n_samples=n_samples, lambda_param=lambda_param, display = False)
        df_distribion["Poisson"] = poisson
              
    return df_distribion

# %%
def quick_sort(df, columns):
    sorted_df = df.sort_values(columns, kind="quicksort")
    return sorted_df
def merge_sort(df, columns):
    sorted_df = df.sort_values(columns, kind="mergesort")
    return sorted_df
def heap_sort(df, columns):
    sorted_df = df.sort_values(columns, kind="heapsort")
    return sorted_df

choices = [quick_sort,merge_sort,heap_sort]
choices_names = ["quicksort","mergesort","heapsort"]

# %%
def evaluate_sorts(distribution_type="Uniform", second_col = None, repetitions=50):
    if second_col == None:
        measures = pd.DataFrame().astype(np.float64)
        for i, sorting_algorithm in enumerate(choices):
            algorithm_times = []
            for n in range(repetitions):
                distribion = create_df_distribution(n_samples=n_samples, dist_type=distribution_type)
                start_time = time.perf_counter()
                #sorted_df = distribion.sort_values([distribution_type],kind=sorting_algorithm)
                sorted_df = sorting_algorithm(distribion, [distribution_type])
                exeuction_time = (time.perf_counter() - start_time)
                algorithm_times.append(exeuction_time)
            measures[choices_names[i]] = algorithm_times
            print("The time of",choices_names[i], "is", np.mean(algorithm_times))
            print("It has a STD of", np.std(algorithm_times))
    else:
        measures = pd.DataFrame().astype(np.float64)
        for i, sorting_algorithm in enumerate(choices):
            algorithm_times = []
            for n in range(repetitions):
                distribion_1 = create_df_distribution(n_samples=n_samples, dist_type=distribution_type)
                distribion_2 = create_df_distribution(n_samples=n_samples, dist_type=second_col)
                df_distribions = pd.concat([distribion_1, distribion_2], axis=1)
                #print(df_distribions)
                start_time = time.perf_counter()
                #sorted_df = df_distribions.sort_values([distribution_type, second_col],kind=sorting_algorithm)
                sorted_df = sorting_algorithm(df_distribions, [distribution_type, second_col])
                exeuction_time = (time.perf_counter() - start_time)
                algorithm_times.append(exeuction_time)
            measures[choices_names[i]] = algorithm_times
            print("The time of",choices_names[i], "is", np.mean(algorithm_times))
            print("It has a STD of", np.std(algorithm_times))
    return measures

# %%
print("Discrete_Uniform")
df_discrete_uniform = evaluate_sorts(distribution_type="Discrete_Uniform")
# Out:
# Discrete_Uniform
# The time of quicksort is 0.005413801999999919
# It has a STD of 0.0005893786658807691
# The time of mergesort is 0.009434037999999987
# It has a STD of 0.0003468465089290202
# The time of heapsort is 0.008636554000000558
# It has a STD of 0.00012683465332377527

# %%
print("Discrete_Binomial")
df_discrete_binomial = evaluate_sorts(distribution_type="Discrete_Binomial")
# Out:
# Discrete_Binomial
# The time of quicksort is 0.005943455999999685
# It has a STD of 0.0006542546715633125
# The time of mergesort is 0.01148384799999974
# It has a STD of 0.001040038584137335
# The time of heapsort is 0.010361001999998792
# It has a STD of 0.0007600584520913565

# %%
print("Poisson")
df_poisson= evaluate_sorts(distribution_type="Poisson")
# Out:
# Poisson
# The time of quicksort is 0.005211367999999936
# It has a STD of 0.0006444972693312209
# The time of mergesort is 0.01047046800000004
# It has a STD of 0.0007917294842150838
# The time of heapsort is 0.009478220000000875
# It has a STD of 0.0009289666588199377

# %%
print("Dates")
df_dates = evaluate_sorts(distribution_type="Dates")
# Out:
# Dates
# The time of quicksort is 0.01405790599999989
# It has a STD of 0.0012693524018809084
# The time of mergesort is 0.014922276000001204
# It has a STD of 0.0012785652786700687
# The time of heapsort is 0.023019617999999298
# It has a STD of 0.00029774137682934076

# %%
print("Strings")
df_strings = evaluate_sorts(distribution_type="Strings")
# Out:
# Strings
# The time of quicksort is 0.12987637200000193
# It has a STD of 0.018296081962782793
# The time of mergesort is 0.11387728799999934
# It has a STD of 0.015265867936105876
# The time of heapsort is 0.22625968400000432
# It has a STD of 0.024696851031532793

# %%
print("Uniform")
df_uniform = evaluate_sorts(distribution_type="Uniform")
# Out:
# Uniform
# The time of quicksort is 0.012209716000000412
# It has a STD of 0.001198191013211752
# The time of mergesort is 0.01392024599999786
# It has a STD of 0.001488278285966335
# The time of heapsort is 0.02096700800000349
# It has a STD of 0.0006174404229814522

# %%
print("Normal")
df_normal = evaluate_sorts(distribution_type="Normal")
# Out:
# Normal
# The time of quicksort is 0.012202878000001078
# It has a STD of 0.0008537996583021415
# The time of mergesort is 0.013424132000000668
# It has a STD of 0.00039964995055305063
# The time of heapsort is 0.021207707999996616
# It has a STD of 0.000863347224430167

# %%
print("Uniform_Sorted")
df_uniform_sorted = evaluate_sorts(distribution_type="Uniform_Sorted")
# Out:
# Uniform_Sorted
# The time of quicksort is 0.003781188000003226
# It has a STD of 0.0008245728359920486
# The time of mergesort is 0.002746518000000151
# It has a STD of 0.0007523830792044247
# The time of heapsort is 0.009900496000002477
# It has a STD of 0.0037492262666288163

# %%
print("Uniform_Reverse_Sorted")
df_uniform_reverse_sorted = evaluate_sorts(distribution_type="Uniform_Reverse_Sorted")
# Out:
# Uniform_Reverse_Sorted
# The time of quicksort is 0.004175825999998892
# It has a STD of 0.00043094510546415685
# The time of mergesort is 0.002330961999998067
# It has a STD of 0.0002372514479531355
# The time of heapsort is 0.010303368000003843
# It has a STD of 0.00120500101716754

# %%
print("Uniform_Nearly_Sorted")
df_uniform_nearly_sorted = evaluate_sorts(distribution_type="Uniform_Nearly_Sorted")
# Out:
# Uniform_Nearly_Sorted
# The time of quicksort is 0.009436496000000148
# It has a STD of 0.0007840200066211768
# The time of mergesort is 0.00971564600000022
# It has a STD of 0.00036450749249441523
# The time of heapsort is 0.013943076000001043
# It has a STD of 0.00031363738141825757

# %%
print("Zipf")
df_zipf = evaluate_sorts(distribution_type="Zipf")
# Out:
# Zipf
# The time of quicksort is 0.004652731999997855
# It has a STD of 0.00032345605416810226
# The time of mergesort is 0.007840505999997732
# It has a STD of 0.0002334644627433892
# The time of heapsort is 0.006387142000001518
# It has a STD of 0.0002574868704163109

# %%
print("Zipf + Normal")
df_zipf_normal = evaluate_sorts(distribution_type="Zipf", second_col="Normal")
# Out:
# Zipf + Normal
# The time of quicksort is 0.05766078200016636
# It has a STD of 0.013568420040263955
# The time of mergesort is 0.05136073200032115
# It has a STD of 0.003579045863352104
# The time of heapsort is 0.04979994799985434
# It has a STD of 0.001921416399398874

# %%
print("Zipf + Discrete_Binomial")
df_zipf_binomial = evaluate_sorts(distribution_type="Zipf", second_col="Discrete_Binomial")
# Out:
# Zipf + Discrete_Binomial
# The time of quicksort is 0.011185184000001413
# It has a STD of 0.001665206302697143
# The time of mergesort is 0.01145678199999736
# It has a STD of 0.0019413429825423508
# The time of heapsort is 0.012081788000001552
# It has a STD of 0.00203156642644724

# %%
print("Zipf + Discrete_Uniform")
df_zipf_discrete_uniform = evaluate_sorts(distribution_type="Zipf", second_col="Discrete_Uniform")
# Out:
# Zipf + Discrete_Uniform
# The time of quicksort is 0.0110245419999967
# It has a STD of 0.0018622678473392959
# The time of mergesort is 0.01056062599999791
# It has a STD of 0.0014345068472187373
# The time of heapsort is 0.01189147999999932
# It has a STD of 0.002001103168955084

# %%
print("Zipf + Poisson")
df_zipf_poisson = evaluate_sorts(distribution_type="Zipf", second_col="Poisson")
# Out:
# Zipf + Poisson
# The time of quicksort is 0.0097035180007515
# It has a STD of 0.0004930602753989621
# The time of mergesort is 0.009781132000207436
# It has a STD of 0.0006221770429417192
# The time of heapsort is 0.009719843999919249
# It has a STD of 0.0007449462282878498

# %%
print("Zipf + Dates")
df_zipf_dates = evaluate_sorts(distribution_type="Zipf", second_col="Dates")
# Out:
# Zipf + Dates
# The time of quicksort is 0.04776720400000158
# It has a STD of 0.001092114916292564
# The time of mergesort is 0.04861788999999817
# It has a STD of 0.0034646658513204456
# The time of heapsort is 0.05091804999999454
# It has a STD of 0.005130414021819259

# %%
print("Zipf + Strings")
df_zipf_strings = evaluate_sorts(distribution_type="Zipf", second_col="Strings")
# Out:
# Zipf + Strings
# The time of quicksort is 0.09867459800000575
# It has a STD of 0.009138732344770917
# The time of mergesort is 0.09565500600000178
# It has a STD of 0.0030021265558542783
# The time of heapsort is 0.09690218600000435
# It has a STD of 0.006779234137339726

# %%
print("Discrete_Uniform + Poisson")
df_discrete_poisson = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Poisson")
# Out:
# Discrete_Uniform + Poisson
# The time of quicksort is 0.00862016599999606
# It has a STD of 0.0005772173263573625
# The time of mergesort is 0.008416161999998622
# It has a STD of 0.0003596339010022426
# The time of heapsort is 0.008522454000003564
# It has a STD of 0.0007571599657235608

# %%
print("Discrete_Uniform + Strings")
df_discrete_strings = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Strings")
# Out:
# Discrete_Uniform + Strings
# The time of quicksort is 0.09883382400000187
# It has a STD of 0.010261382725958107
# The time of mergesort is 0.09709903400000258
# It has a STD of 0.00319620030816014
# The time of heapsort is 0.10198258999999439
# It has a STD of 0.017677914282165752

# %%
print("Discrete_Uniform + Uniform_Reverse_Sorted")
df_discrete_uniform_reverse_sorted = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Uniform_Reverse_Sorted")
# Out:
# Discrete_Uniform + Uniform_Reverse_Sorted
# The time of quicksort is 0.04180561000000125
# It has a STD of 0.01193325860153107
# The time of mergesort is 0.03612945800000034
# It has a STD of 0.003289428154927377
# The time of heapsort is 0.036847886000001606
# It has a STD of 0.010783349349006531

# %%
print("Discrete_Uniform + Uniform_Nearly_Sorted")
df_discrete_uniform_nearly_sorted = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Uniform_Nearly_Sorted")
# Out:
# Discrete_Uniform + Uniform_Nearly_Sorted
# The time of quicksort is 0.046446080000001756
# It has a STD of 0.006704892529428317
# The time of mergesort is 0.04560495400000377
# It has a STD of 0.005553125977834977
# The time of heapsort is 0.046475046000010706
# It has a STD of 0.006485136889971895

# %%
def calculate_stats(df_dist, sort_algo):
    df_sort_algo = df_dist[sort_algo]
    std_sort_algo = np.std(df_sort_algo) 
    mean_sort_algo = np.mean(df_sort_algo) 
    return df_sort_algo, std_sort_algo,mean_sort_algo

def plot_runtimes(sort_dist, std_sort_algo, mean_sort_algo,algo_name):
    # Plot
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    fig.suptitle(algo_name)
    count, bins, ignored = ax1.hist(sort_dist, 20)
    ax2.plot(sort_dist)
    plt.show()
def plot_runtimes_together(df, bins = 5,title=None):
    weights_quicksort = np.ones_like(df["quicksort"])/float(len(df["quicksort"]))
    weights_mergesort = np.ones_like(df["mergesort"])/float(len(df["mergesort"]))
    weights_heapsort = np.ones_like(df["heapsort"])/float(len(df["heapsort"]))
    plt.figure(figsize=(16,6))
    plt.hist(df["quicksort"], bins, alpha = 0.5, label='quick sort',weights=weights_quicksort)
    plt.hist(df["mergesort"], bins, alpha = 0.5, label='merge sort',weights=weights_mergesort)
    plt.hist(df["heapsort"], bins, alpha = 0.5, label='heap sort',weights=weights_heapsort)
    plt.legend(loc='upper right',fontsize=26)
    plt.title(title,fontsize=26)
    plt.ylabel("Frequency",fontsize=26)
    plt.xlabel("Runtime in seconds",fontsize=26)
    plt.xticks(fontsize=26)
    plt.yticks(fontsize=26)
    plt.show()

# %%
plot_runtimes_together(df_normal, title="Sorting a single column: normal distribution")
plot_runtimes_together(df_uniform, title="Sorting a single column: continious uniform distribution")
plot_runtimes_together(df_uniform_sorted, title="Sorting a single column: continious uniform sorted distribution")
plot_runtimes_together(df_uniform_reverse_sorted, title="Sorting a single column: continious uniform reverse sorted distribution")
plot_runtimes_together(df_uniform_nearly_sorted, title="Sorting a single column: continious uniform nearly sorted distribution")
plot_runtimes_together(df_dates, title="Sorting a single column: dates")
plot_runtimes_together(df_strings, title="Sorting a single column: strings")

# %%
plot_runtimes_together(df_discrete_uniform, title="Sorting a single column: discrete uniform distribution")
plot_runtimes_together(df_discrete_binomial, title="Sorting a single column: binomial distribution")
plot_runtimes_together(df_poisson, title="Sorting a single column: Poisson distribution")
plot_runtimes_together(df_zipf, title="Sorting a single column: Zipf distribution")

# %%
plot_runtimes_together(df_zipf_normal, title="Sorting by two columns: Zipf + normal distribution")
plot_runtimes_together(df_zipf_binomial, title="Sorting by two columns: Zipf + binomial distribution")
plot_runtimes_together(df_zipf_discrete_uniform, title="Sorting by two columns: Zipf + discrete uniform distribution")
plot_runtimes_together(df_zipf_poisson, title="Sorting by two columns: Zipf + Poisson distribution")
plot_runtimes_together(df_zipf_dates, title="Sorting by two columns: Zipf + dates")

# %%
plot_runtimes_together(df_discrete_poisson, title="Sorting by two columns: discrete uniform distribution + Poisson distributon")
plot_runtimes_together(df_discrete_strings, title="Sorting by two columns: discrete uniform distribution + strings")
plot_runtimes_together(df_discrete_uniform_reverse_sorted, title="Sorting by two columns: discrete uniform distribution + reverse sorted uniform distribution")
plot_runtimes_together(df_discrete_uniform_nearly_sorted, title="Sorting by two columns: discrete uniform distribution + nearly sorted uniform distribution")
