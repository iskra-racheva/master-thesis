# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy.stats import t
from scipy.stats import uniform
from scipy.stats import ttest_1samp # library for p-value estimation
import ruptures as rpt # library for change point detection
# %matplotlib inline
# %run ./master_experminet-functions.ipynb
# load functions for the creation of the different distributions

# %%
# define arms
def quick_sort(df):
    sorted_df = df.sort_values(kind="quicksort")
    return sorted_df
def merge_sort(df):
    sorted_df = df.sort_values(kind="mergesort")
    return sorted_df
def heap_sort(df):
    sorted_df = df.sort_values(kind="heapsort")
    return sorted_df

# %%
n_samples = 500000
choices = [quick_sort,merge_sort,heap_sort]
choices_names = ["quick_sort","merge_sort","heap_sort"]
dist_types = ["Uniform","Normal","Uniform_Sorted","Uniform_Reverse_Sorted","Uniform_Nearly_Sorted","Zipf"]

# %%
#list_distributions = 1000*["Uniform_Sorted"] + 1000*["Normal"] # at first quick sort -> then merge sort 
list_distributions = 500*["Uniform"] +  500*["Uniform_Sorted"] + 500*["Normal"] + 500*["Uniform_Reverse_Sorted"]
#list_distributions = 100*["Uniform"] +  100*["Uniform_Sorted"] + 100*["Normal"] + 100*["Uniform_Reverse_Sorted"]

# %%
def plot_history(rewards,cum_rewards,sample_count, sample_mean):

    q_values = {"quick_sort": sample_mean[0], "merge_sort": sample_mean[1], "heap_sort":sample_mean[2]} ## 
    arm_counts = {"quick_sort": sample_count[0], "merge_sort": sample_count[1], "heap_sort":sample_count[2]} ##
    print("Average rewards per algo", q_values)
    print("Count per chosen algo", arm_counts)
    
    fig = plt.figure(figsize=[30,8])
    ax2 = fig.add_subplot(121)
    ax2.plot(cum_rewards, label="avg rewards")
    ax2.set_title("Cummulative Rewards")
    labels = list(arm_counts.keys())
    ax3 = fig.add_subplot(122)
    ax3.bar([i for i in range(len(arm_counts.values()))], arm_counts.values(), label=[i for i in ((list(arm_counts.keys())))])
    ax3.set_title("Chosen Actions")
    plt.show()

# %%
# help function to return the humber of consecutive elements in a list 
def count_consec(listrand):
    count=1
    consec_list=[]
    for i in range(len(listrand[:-1])):
        if listrand[i]+1 == listrand[i+1]:
            count+=1
        else:
            consec_list.append(count)
            count=1

    # Account for the last iteration
    consec_list.append(count)     

    return consec_list

# %%
def TS_stationary(list_distributions, n_samples, var_multiplier = 5): # initialize
    total_reward = 0
    num_choices = len(choices)
    sample_count = [0 for i in range(num_choices)]
    sample_rewards = [0 for i in range(num_choices)]
    sample_mean = [0.0 for i in range(num_choices)]
    sample_var = [0.0 for i in range(num_choices)]
    arm_rewards = {0: [], 1:[], 2:[]}
    rewards = []
    cum_rewards = []
    var_multiplier = 5
    list_iteration_results = []

    len_result = 1

    for n, elem in enumerate(list_distributions):
        dist_type = elem
        distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
        print("\n")
        print("Iteration:", n)
        theta = {}
        for i in range(len(choices)):
            if sample_count[i] >= 2:
                theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=np.sqrt(sample_var[i]/sample_count[i])*var_multiplier)
                print(choices_names[i],"Theta", theta[i])

            else:
                print("Less than two values for",choices_names[i])
                theta[i] = uniform.rvs(loc=0, scale=1)
                print(choices_names[i],"Theta", theta[i])

        choice = np.argmin([theta[i] for i in range(len(choices))])
        alg = choices[choice]
        alg_name = choices_names[choice]
        start_time = time.perf_counter()
        sorted_dist = alg(distribion[dist_type])
        reward = ((time.perf_counter() - start_time))*(1)
        print("\n")
        print("Chosen algorithm is: ", alg_name, "with reward:", reward)
        arm_rewards[choice].append(reward)
        sample_count[choice] += 1
        sample_rewards[choice] += reward
        sample_mean[choice] = np.mean(arm_rewards[choice])
        sample_var[choice] = np.var(arm_rewards[choice]).astype('float64')
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
        total_reward += reward
        rewards.append(reward)
        cum_rewards.append(sum(rewards)/len(rewards))
        array_rewards = np.array(rewards)

    list_iteration_results.extend([sample_mean, sample_count,rewards,cum_rewards,n])
    return list_iteration_results, total_reward

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
import bayesian_changepoint_detection.online_changepoint_detection as oncd
from functools import partial
import matplotlib.cm as cm

# %% [markdown]
# ## Thompson Sampling

# %% [markdown]
# # Probabs sampled from t Student distribution

# %% [markdown]
# ### Quick sort should be the fastest at first 500 itreations, then merge sort for for the next 500, then again quick sort for the next 500, then again merge sort for the next 500: i.e. change points/restart experiment at iteration 500, 1000 and 1500

# %% [markdown]
# ### First Variant: One sample t-test:
# The One Sample t Test determines whether the sample mean is statistically different from a known or hypothesised population mean or in other words: the p_value is the estimated probability of achieving this value by chance from the sample set.  Generally, if we receive a p-value of less than a selected significance level, we can reject the null hypothesis and state that there is a significant difference, i.e. the sample comes from a different distribution.

# %%
def TS_ttest(list_distributions, n_samples, var_multiplier=5,p_val_multiplier=20,num_consec_elem=5):# initialize
    total_reward = 0
    num_choices = len(choices)
    sample_count = [0 for i in range(num_choices)]
    sample_rewards = [0 for i in range(num_choices)]
    sample_mean = [0.0 for i in range(num_choices)]
    sample_var = [0.0 for i in range(num_choices)]
    arm_rewards = {0: [], 1:[], 2:[]}
    rewards = []
    cum_rewards = []
    var_multiplier = var_multiplier
    n_consecutive_list = [] # this list is to check whether
    list_iteration_results = []
    p_val_multiplier = p_val_multiplier
    num_consec_elem = num_consec_elem

    for n, elem in enumerate(list_distributions):
        dist_type = elem
        distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
        print("\n")
        print("Iteration:", n)
        theta = {}
        for i in range(len(choices)):
            if sample_count[i] >= 2:
                theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=np.sqrt(sample_var[i]/sample_count[i])*var_multiplier)
                print(choices_names[i],"Theta", theta[i])

            else:
                print("Less than two values for",choices_names[i])
                theta[i] = uniform.rvs(loc=0, scale=1)
                print(choices_names[i],"Theta", theta[i])

        choice = np.argmin([theta[i] for i in range(len(choices))])
        alg = choices[choice]
        alg_name = choices_names[choice]
        start_time = time.perf_counter()
        sorted_dist = alg(distribion[dist_type])
        reward = ((time.perf_counter() - start_time))*(1)
        print("\n")
        print("Chosen algorithm is: ", alg_name, "with reward:", reward)
        arm_rewards[choice].append(reward)
        sample_count[choice] += 1
        sample_rewards[choice] += reward
        sample_mean[choice] = np.mean(arm_rewards[choice])
        sample_var[choice] = np.var(arm_rewards[choice]).astype('float64')
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
        total_reward += reward
        rewards.append(reward)
        cum_rewards.append(sum(rewards)/len(rewards))

        tset, pval = ttest_1samp(arm_rewards[choice], reward)
        print("\n")
        print("p-value: ", pval)
        print("Significance level: ", (sample_var[choice]**p_val_multiplier))

        if pval < sample_var[choice]**p_val_multiplier:
            n_consecutive_list.append(n)
            if any(i >= num_consec_elem for i in count_consec(n_consecutive_list)):
                    print("RESTART EXPERIMENT AT ITERATION:", n)

                    list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
                    sample_count = [0 for i in range(num_choices)]
                    sample_rewards = [0 for i in range(num_choices)]
                    sample_mean = [0.0 for i in range(num_choices)]
                    sample_var = [0.0 for i in range(num_choices)]
                    arm_rewards = {0: [], 1:[], 2:[]}
                    rewards = []
                    cum_rewards = []
                    n_consecutive_list = []

    list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
    return list_iteration_results, total_reward

# %%
list_iteration_results_TS_ttest, total_reward_TS_ttest = TS_ttest(list_distributions=list_distributions, n_samples=n_samples)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.1285131754329084
# Less than two values for merge_sort
# merge_sort Theta 0.0953831877858986
# Less than two values for heap_sort
# heap_sort Theta 0.08411301250014591
#
#
# Chosen algorithm is:  heap_sort with reward: 0.2147711000000001
# Sample mean is:  0.2147711000000001 Sample variance is: 0.0
#
#
# p-value:  nan
# Significance level:  0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.9014474289143597
# Less than two values for merge_sort
# merge_sort Theta 0.9515093111901851
# Less than two values for heap_sort
# heap_sort Theta 0.44606446397752153
# C:\Users\iRacheva\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3584: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# Chosen algorithm is:  heap_sort with reward: 0.22961030000000449
# Sample mean is:  0.2221907000000023 Sample variance is: 5.5050464160032516e-05
#
#
# p-value:  0.49999999999999956
# Significance level:  6.534610433818219e-86
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.2844625703859459
# Less than two values for merge_sort
# merge_sort Theta 0.43186713089333906
# heap_sort Theta 0.23957152304868207
#
#
# Chosen algorithm is:  heap_sort with reward: 0.2733634000000009
# Sample mean is:  0.2392482666666685 Sample variance is: 0.000618621470615546
#
#
# p-value:  0.19195282816524442
# Significance level:  6.7375155639317926e-65
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.7951231893408129
# Less than two values for merge_sort
# merge_sort Theta 0.3169587921273086
# heap_sort Theta 0.2926371561953969
#
#
# Chosen algorithm is:  heap_sort with reward: 0.219529399999999
# Sample mean is:  0.23431855000000112 Sample variance is: 0.0005368724222025139
#
#
# p-value:  0.34962706245791875
# Significance level:  3.9575090641888764e-66
#
#
# Iteration: 4
# Less than two values for quick_sort
# quick_sort Theta 0.21213483540938405
# Less than two values for merge_sort
# merge_sort Theta 0.9785315746730745
# heap_sort Theta 0.24904267117041004
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09762849999999901
# Sample mean is:  0.09762849999999901 Sample variance is: 0.0
#
#
# p-value:  nan
# Significance level:  0.0
#
#
# Iteration: 5
# Less than two values for quick_sort
# quick_sort Theta 0.086355661734549
# Less than two values for merge_sort
# merge_sort Theta 0.8055865572977513
# heap_sort Theta 0.33419190454401193
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10707510000000298
# Sample mean is:  0.10235180000000099 Sample variance is: 2.2309562890018745e-05
#
#
# p-value:  0.49999999999999956
# Significance level:  9.328702111641879e-94
#
#
# Iteration: 6
# quick_sort Theta 0.11693379905996447
# Less than two values for merge_sort
# merge_sort Theta 0.13175962996698176
# heap_sort Theta 0.28894832436759643
#
#
# Chosen algorithm is:  quick_sort with reward: 0.12487130000000235
# Sample mean is:  0.10985830000000145 Sample variance is: 0.00012756812642669276
#
#
# p-value:  0.20089143065451343
# Significance level:  1.3026973904190121e-78
#
#
# Iteration: 7
# quick_sort Theta 0.12072091994267378
# Less than two values for merge_sort
# merge_sort Theta 0.0013364083372477964
# heap_sort Theta 0.21089384948283554
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10460059999999771
# Sample mean is:  0.10460059999999771 Sample variance is: 0.0
#
#
# p-value:  nan
# Significance level:  0.0
#
#
# Iteration: 8
# quick_sort Theta 0.1832862145513906
# Less than two values for merge_sort
# merge_sort Theta 0.9378995333113133
# heap_sort Theta 0.27960273661461565
#
#
# Chosen algorithm is:  quick_sort with reward: 0.1189476000000056
# Sample mean is:  0.11213062500000248 Sample variance is: 0.00011116647753690871
#
#
# p-value:  0.3443449918349802
# Significance level:  8.307625164817721e-80
#
#
# Iteration: 9
# quick_sort Theta 0.1056242573847446
# Less than two values for merge_sort
# merge_sort Theta 0.46435654903023094
# heap_sort Theta 0.2521352431586562
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09788660000000249
# Sample mean is:  0.10928182000000249 Sample variance is: 0.00012139594174162694
#
#
# p-value:  0.10741538114592547
# Significance level:  4.83151543078006e-79
#
#
# Iteration: 10
# quick_sort Theta 0.13212902494403392
# Less than two values for merge_sort
# merge_sort Theta 0.8950689557249815
# heap_sort Theta 0.28153006549699117
#
#
# Chosen algorithm is:  quick_sort with reward: 0.11943289999999962
# Sample mean is:  0.11097366666666868 Sample variance is: 0.00011547501050223659
#
#
# p-value:  0.13868035563243197
# Significance level:  1.7772978205986533e-79
#
#
# Iteration: 11
# quick_sort Theta 0.09008027247017278
# Less than two values for merge_sort
# merge_sort Theta 0.9289365602730644
# heap_sort Theta 0.4038211445864054
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10142880000000076
# Sample mean is:  0.10961011428571611 Sample variance is: 0.00011013423100409686
#
#
# p-value:  0.10476911513506315
# Significance level:  6.89360626957005e-80
#
#
# Iteration: 12
# quick_sort Theta 0.10608846958174473
# Less than two values for merge_sort
# merge_sort Theta 0.27368989505720753
# heap_sort Theta 0.2447530900048519
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10008129999999937
# Sample mean is:  0.10841901250000152 Sample variance is: 0.00010629851637611219
#
#
# p-value:  0.06967558295985117
# Significance level:  3.3926890811745775e-80
#
#
# Iteration: 13
# quick_sort Theta 0.10086204707500071
# Less than two values for merge_sort
# merge_sort Theta 0.012246827620877587
# heap_sort Theta 0.27961008746178645
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10731529999999623
# Sample mean is:  0.10595794999999697 Sample variance is: 1.842399022497985e-06
#
#
# p-value:  0.49999999999999956
# Significance level:  2.030831498442492e-115
#
#
# Iteration: 14
# quick_sort Theta 0.10469357654369815
# merge_sort Theta 0.10360928055599071
# heap_sort Theta 0.22725963528018875
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10353360000000578
# Sample mean is:  0.10514983333333323 Sample variance is: 2.5343711088780564e-06
#
#
# p-value:  0.28756599455347803
# Significance level:  1.1950998228964069e-112
#
#
# Iteration: 15
# quick_sort Theta 0.14384617899232566
# merge_sort Theta 0.10671170108429133
# heap_sort Theta 0.22791635100076243
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10279990000000083
# Sample mean is:  0.10456235000000014 Sample variance is: 2.936188332491059e-06
#
#
# p-value:  0.1728573337185225
# Significance level:  2.2681834204962793e-111
#
#
# Iteration: 16
# quick_sort Theta 0.13712832348141088
# merge_sort Theta 0.10701437816439464
# heap_sort Theta 0.2257349850839371
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10662349999999776
# Sample mean is:  0.10497457999999966 Sample variance is: 3.02868495759128e-06
#
#
# p-value:  0.1309967481041839
# Significance level:  4.217761433886465e-111
#
#
# Iteration: 17
# quick_sort Theta 0.12109732694471029
# merge_sort Theta 0.09974254642214332
# heap_sort Theta 0.1530615000272541
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11057230000000118
# Sample mean is:  0.10590753333333325 Sample variance is: 6.875913742217312e-06
#
#
# p-value:  0.010553170162343155
# Significance level:  5.5796684981569823e-104
#
#
# Iteration: 18
# quick_sort Theta 0.11765237222500362
# merge_sort Theta 0.09964290249544128
# heap_sort Theta -0.1139129668199379
#
#
# Chosen algorithm is:  heap_sort with reward: 0.21230590000000404
# Sample mean is:  0.22991602000000172 Sample variance is: 0.0005070270193655906
#
#
# p-value:  0.1928295675957097
# Significance level:  1.2607299447240198e-66
#
#
# Iteration: 19
# quick_sort Theta 0.13263986330001387
# merge_sort Theta 0.10676529808712079
# heap_sort Theta 0.23494538208392168
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10155669999999617
# Sample mean is:  0.10528598571428509 Sample variance is: 8.211569006938558e-06
#
#
# p-value:  0.018889244417234118
# Significance level:  1.943224322210272e-102
#
#
# Iteration: 20
# quick_sort Theta 0.1881904788382377
# merge_sort Theta 0.10676467215118245
# heap_sort Theta 0.36009917517804046
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10383900000000068
# Sample mean is:  0.10510511249999954 Sample variance is: 7.414128718593148e-06
#
#
# p-value:  0.2583413149362137
# Significance level:  2.5188507396997023e-103
#
#
# Iteration: 21
# quick_sort Theta 0.04109928803300174
# merge_sort Theta 0.1035430387793597
# heap_sort Theta 0.25057898614193796
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09648409999999785
# Sample mean is:  0.10709291111111223 Sample variance is: 0.00010855592926101268
#
#
# p-value:  0.02051311476453912
# Significance level:  5.165007862293676e-80
#
#
# Iteration: 22
# quick_sort Theta 0.04520056264358495
# merge_sort Theta 0.11519170338739511
# heap_sort Theta 0.22523950888550626
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09347759999999994
# Sample mean is:  0.105731380000001 Sample variance is: 0.00011438423903362542
#
#
# p-value:  0.007422963223318363
# Significance level:  1.470021700065747e-79
#
#
# Iteration: 23
# quick_sort Theta 0.12088194976405722
# merge_sort Theta 0.1063356717981318
# heap_sort Theta 0.21277198630644195
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10726360000000312
# Sample mean is:  0.10534494444444438 Sample variance is: 7.050491531359016e-06
#
#
# p-value:  0.07523215257335822
# Significance level:  9.212720712574253e-104
#
#
# Iteration: 24
# quick_sort Theta 0.1114227270366431
# merge_sort Theta 0.10841936700203526
# heap_sort Theta 0.23828473999820907
# Chosen algorithm is:  merge_sort with reward: 0.10624220000000406
# Sample mean is:  0.10543467000000036 Sample variance is: 6.417898456101558e-06
#
#
# p-value:  0.3639123543249432
# Significance level:  1.4055840756886916e-104
#
#
# Iteration: 25
# quick_sort Theta 0.13010888365070294
# merge_sort Theta 0.11091719521223962
# heap_sort Theta 0.1714814881604413
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10159820000000508
# Sample mean is:  0.10508590000000079 Sample variance is: 7.05085827090751e-06
#
#
# p-value:  0.001968892331291029
# Significance level:  9.222309658599142e-104
#
#
# Iteration: 26
# quick_sort Theta 0.0949684691196387
# merge_sort Theta 0.09888117733557727
# heap_sort Theta 0.20160166858593925
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09858030000000184
# Sample mean is:  0.1050812818181829 Sample variance is: 0.00010821194830878244
#
#
# p-value:  0.07634755437718987
# Significance level:  4.847349430580819e-80
#
#
# Iteration: 27
# quick_sort Theta 0.07501020548536506
# merge_sort Theta 0.10414525885678959
# heap_sort Theta 0.23108707215576482
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09762049999999789
# Sample mean is:  0.1044595500000008 Sample variance is: 0.0001034463409408572
#
#
# p-value:  0.047513670976927394
# Significance level:  1.9692582426010153e-80
#
#
# Iteration: 28
# quick_sort Theta 0.09431407164521036
# merge_sort Theta 0.10719962435882031
# heap_sort Theta 0.2551522676884378
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09426489999999887
# Sample mean is:  0.10367534615384681 Sample variance is: 0.00010286863816712545
#
#
# p-value:  0.007435433195233779
# Significance level:  1.7605963970395943e-80
#
#
# Iteration: 29
# quick_sort Theta 0.12506223762739507
# merge_sort Theta 0.11111426415150087
# heap_sort Theta 0.21246487047392779
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11107069999999908
# Sample mean is:  0.10558463333333397 Sample variance is: 9.199371063885882e-06
#
#
# p-value:  8.939047868783264e-05
# Significance level:  1.8843550523398535e-101
#
#
# Iteration: 30
# quick_sort Theta 0.0899281427875113
# merge_sort Theta 0.10036679620242842
# heap_sort Theta 0.1975622392550053
#
#
# Chosen algorithm is:  quick_sort with reward: 0.11459800000000087
# Sample mean is:  0.10445553571428638 Sample variance is: 0.00010343392305089071
#
#
# p-value:  0.0032585381396542917
# Significance level:  1.9645357623842978e-80
#
#
# Iteration: 31
# quick_sort Theta 0.10078761343700468
# merge_sort Theta 0.11642437524532215
# heap_sort Theta 0.2785929493587588
#
#
# Chosen algorithm is:  quick_sort with reward: 0.11186800000000119
# Sample mean is:  0.10494970000000071 Sample variance is: 9.995710495868898e-05
#
#
# p-value:  0.021425007531117035
# Significance level:  9.91455861632528e-81
#
#
# Iteration: 32
# quick_sort Theta 0.10823898559533435
# merge_sort Theta 0.10227327789312433
# heap_sort Theta 0.19406718859394703
#
#
# Chosen algorithm is:  merge_sort with reward: 0.12121090000000123
# Sample mean is:  0.10678665384615453 Sample variance is: 2.582996689479144e-05
#
#
# p-value:  4.3015878493069584e-07
# Significance level:  1.7477406648533736e-92
#
#
# Iteration: 33
# quick_sort Theta 0.10560424696982838
# merge_sort Theta 0.10277768912396708
# heap_sort Theta 0.20248578129867206
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11289279999999735
# Sample mean is:  0.10722280714285759 Sample variance is: 2.645795533637349e-05
#
#
# p-value:  0.0015866765554440275
# Significance level:  2.8256969299363867e-92
#
#
# Iteration: 34
# quick_sort Theta 0.10940582303765983
# merge_sort Theta 0.10432854800140855
# heap_sort Theta 0.165427137652261
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10878660000000195
# Sample mean is:  0.10732706000000054 Sample variance is: 2.4846252862396504e-05
#
#
# p-value:  0.2917465248684709
# Significance level:  8.039295923895046e-93
#
#
# Iteration: 35
# quick_sort Theta 0.09238793361838832
# merge_sort Theta 0.10388645273953015
# heap_sort Theta 0.22355065419901377
#
#
# Chosen algorithm is:  quick_sort with reward: 0.1024546000000015
# Sample mean is:  0.10479375625000076 Sample variance is: 9.40745626962316e-05
#
#
# p-value:  0.3650730203693401
# Significance level:  2.947434507275633e-81
#
#
# Iteration: 36
# quick_sort Theta 0.10349231947052683
# merge_sort Theta 0.11209213978003056
# heap_sort Theta 0.17237211724745577
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09792610000000224
# Sample mean is:  0.10438977647058909 Sample variance is: 9.115195948534704e-05
#
#
# p-value:  0.015514036621250248
# Significance level:  1.56790657599929e-81
#
#
# Iteration: 37
# quick_sort Theta 0.10477207267407594
# merge_sort Theta 0.10120332807827404
# heap_sort Theta 0.17161138846065488
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10656490000000218
# Sample mean is:  0.10727942500000065 Sample variance is: 2.3327398456871578e-05
#
#
# p-value:  0.5751560523731218
# Significance level:  2.2768066582989847e-93
#
#
# Iteration: 38
# quick_sort Theta 0.10204094437044245
# merge_sort Theta 0.11118533408662341
# heap_sort Theta 0.22990111168598495
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09640890000000013
# Sample mean is:  0.10394639444444526 Sample variance is: 8.942995129498704e-05
#
#
# p-value:  0.00435685033109772
# Significance level:  1.070680479055687e-81
#
#
# Iteration: 39
# quick_sort Theta 0.09346324411106519
# merge_sort Theta 0.1057946037791108
# heap_sort Theta -0.05071093608856175
#
#
# Chosen algorithm is:  heap_sort with reward: 0.2308857999999958
# Sample mean is:  0.23007765000000072 Sample variance is: 0.0004226531374224905
#
#
# p-value:  0.9333686805010708
# Significance level:  3.3088870546710837e-68
#
#
# Iteration: 40
# quick_sort Theta 0.08524743418194987
# merge_sort Theta 0.10835979040226554
# heap_sort Theta 0.351696011764814
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09952359999999771
# Sample mean is:  0.10371361578947433 Sample variance is: 8.56984579929269e-05
#
#
# p-value:  0.0708101651779582
# Significance level:  4.5652036007516154e-82
#
#
# Iteration: 41
# quick_sort Theta 0.10889720752165867
# merge_sort Theta 0.09465566863715145
# heap_sort Theta 0.23976836378199723
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10878840000000167
# Sample mean is:  0.10736818823529483 Sample variance is: 2.208126113868207e-05
#
#
# p-value:  0.24425239183900585
# Significance level:  7.59412037848903e-94
#
#
# Iteration: 42
# quick_sort Theta 0.09640222260626982
# merge_sort Theta 0.10489903222949626
# heap_sort Theta 0.26700191933227213
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10775639999999953
# Sample mean is:  0.10391575500000058 Sample variance is: 8.2189880041492e-05
#
#
# p-value:  0.08044242451251411
# Significance level:  1.9786406704817782e-82
#
#
# Iteration: 43
# quick_sort Theta 0.1228335610037052
# merge_sort Theta 0.11456054789834012
# heap_sort Theta 0.21527406727712403
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10282959999999974
# Sample mean is:  0.1071160444444451 Sample variance is: 2.193532476024449e-05
#
#
# p-value:  0.001515433285933687
# Significance level:  6.650914631535721e-94
#
#
# Iteration: 44
# quick_sort Theta 0.11037390170730421
# merge_sort Theta 0.11310796192762843
# heap_sort Theta 0.29889053448074715
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09529099999999602
# Sample mean is:  0.10350505238095276 Sample variance is: 8.164960905584741e-05
#
#
# p-value:  0.0006038582175057593
# Significance level:  1.73413216184623e-82
#
#
# Iteration: 45
# quick_sort Theta 0.10087487168670428
# merge_sort Theta 0.09844160723771862
# heap_sort Theta 0.2367378344423052
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10565090000000055
# Sample mean is:  0.10703893157894802 Sample variance is: 2.08878690758426e-05
#
#
# p-value:  0.2138841769131206
# Significance level:  2.4996703206728277e-94
#
#
# Iteration: 46
# quick_sort Theta 0.1160259727721568
# merge_sort Theta 0.10433711303405245
# heap_sort Theta 0.2549992302735819
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10278569999999831
# Sample mean is:  0.10682627000000053 Sample variance is: 2.0702749618098778e-05
#
#
# p-value:  0.001029108717661043
# Significance level:  2.091994771670942e-94
#
#
# Iteration: 47
# quick_sort Theta 0.10570271760653303
# merge_sort Theta 0.11687706056813371
# heap_sort Theta 0.20398512844544386
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09647269999999963
# Sample mean is:  0.10318540000000033 Sample variance is: 8.008399372729202e-05
#
#
# p-value:  0.0024708979110366516
# Significance level:  1.1773740483544069e-82
#
#
# Iteration: 48
# quick_sort Theta 0.09686835866282296
# merge_sort Theta 0.11410890062996754
# heap_sort Theta 0.29916202560629707
# Chosen algorithm is:  quick_sort with reward: 0.11092909999999989
# Sample mean is:  0.10352208260869597 Sample variance is: 7.909589489449832e-05
#
#
# p-value:  0.0007575464273746766
# Significance level:  9.184994082475274e-83
#
#
# Iteration: 49
# quick_sort Theta 0.10950656154919704
# merge_sort Theta 0.11282406186644213
# heap_sort Theta -0.001232915580086702
#
#
# Chosen algorithm is:  heap_sort with reward: 0.2323738999999989
# Sample mean is:  0.23040568571428618 Sample variance is: 0.0003629197623697867
#
#
# p-value:  0.8086608449545567
# Significance level:  1.5711308518313934e-69
#
#
# Iteration: 50
# quick_sort Theta 0.10466248648504381
# merge_sort Theta 0.10657623339722631
# heap_sort Theta 0.15887382396936686
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09424609999999944
# Sample mean is:  0.10313558333333361 Sample variance is: 7.923601147390696e-05
#
#
# p-value:  7.870347234472894e-05
# Significance level:  9.515949402828915e-83
#
#
# Iteration: 51
# quick_sort Theta 0.09709510401434622
# merge_sort Theta 0.11073335200098033
# heap_sort Theta 0.279640461350143
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09608099999999808
# Sample mean is:  0.10285340000000019 Sample variance is: 7.797762942161852e-05
#
#
# p-value:  0.0009708893265423544
# Significance level:  6.908767274626535e-83
#
#
# Iteration: 52
# quick_sort Theta 0.0998638698660284
# merge_sort Theta 0.1037862483222181
# heap_sort Theta 0.22209157300576005
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0977930000000029
# Sample mean is:  0.10265876923076953 Sample variance is: 7.592551823676237e-05
#
#
# p-value:  0.009891805920942354
# Significance level:  4.052801175058243e-83
#
#
# Iteration: 53
# quick_sort Theta 0.09991113175618377
# merge_sort Theta 0.1023851606391177
# heap_sort Theta 0.20838630862412902
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09898829999999492
# Sample mean is:  0.10252282592592603 Sample variance is: 7.359395714119728e-05
#
#
# p-value:  0.0454995629965644
# Significance level:  2.1719164300728455e-83
#
#
# Iteration: 54
# quick_sort Theta 0.11442510501439046
# merge_sort Theta 0.12109245392347555
# heap_sort Theta 0.2151176200303775
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09581439999999475
# Sample mean is:  0.10228323928571419 Sample variance is: 7.251544899954751e-05
#
#
# p-value:  0.0005087832868242355
# Significance level:  1.616630646316385e-83
#
#
# Iteration: 55
# quick_sort Theta 0.09249742990045909
# merge_sort Theta 0.10898889595327083
# heap_sort Theta 0.21203329179028285
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0973417000000012
# Sample mean is:  0.1021128413793103 Sample variance is: 7.082790877761644e-05
#
#
# p-value:  0.005619527018819305
# Significance level:  1.009458304942081e-83
#
#
# Iteration: 56
# quick_sort Theta 0.10826148350582505
# merge_sort Theta 0.11486146447331808
# heap_sort Theta 0.16867728296993134
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0929284999999993
# Sample mean is:  0.1018066966666666 Sample variance is: 7.118499145234034e-05
#
#
# p-value:  3.988775862949282e-06
# Significance level:  1.1162686926466531e-83
#
#
# Iteration: 57
# quick_sort Theta 0.10688573383945643
# merge_sort Theta 0.10599851236913886
# heap_sort Theta 0.2787834081735361
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10449530000000351
# Sample mean is:  0.10671527142857211 Sample variance is: 1.9963318055372358e-05
#
#
# p-value:  0.03798284290634218
# Significance level:  1.01077506565082e-94
#
#
# Iteration: 58
# quick_sort Theta 0.11257502812493778
# merge_sort Theta 0.10160727796920774
# heap_sort Theta 0.2133819843201028
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10622890000000496
# Sample mean is:  0.10669316363636451 Sample variance is: 1.906615835140307e-05
#
#
# p-value:  0.6311357932959497
# Significance level:  4.0296183311588506e-95
#
#
# Iteration: 59
# quick_sort Theta 0.10636284402697789
# merge_sort Theta 0.10275140096874519
# heap_sort Theta 0.19083429321360817
#
#
# Chosen algorithm is:  merge_sort with reward: 0.1301605999999964
# Sample mean is:  0.10771348695652241 Sample variance is: 4.114050785329761e-05
#
#
# p-value:  7.904225738413326e-14
# Significance level:  1.9292698155891606e-88
#
#
# Iteration: 60
# quick_sort Theta 0.09833475983209344
# merge_sort Theta 0.10939198627464869
# heap_sort Theta 0.1690268249319858
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10386520000000132
# Sample mean is:  0.10187309999999998 Sample variance is: 6.902098348582415e-05
#
#
# p-value:  0.19902109692479505
# Significance level:  6.02036560576551e-84
#
#
# Iteration: 61
# quick_sort Theta 0.10734523075333692
# merge_sort Theta 0.10716592295153916
# heap_sort Theta 0.2302600875029738
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11089690000000019
# Sample mean is:  0.10784612916666732 Sample variance is: 3.9830981012055766e-05
#
#
# p-value:  0.0296787305551604
# Significance level:  1.0102295291024757e-88
#
#
# Iteration: 62
# quick_sort Theta 0.09910815692711687
# merge_sort Theta 0.1028212570119006
# heap_sort Theta 0.231095212303758
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0995406999999986
# Sample mean is:  0.10180021249999993 Sample variance is: 6.702876796923609e-05
#
#
# p-value:  0.1345327835941535
# Significance level:  3.351388208023055e-84
#
#
# Iteration: 63
# quick_sort Theta 0.09942553975676915
# merge_sort Theta 0.10510987841118119
# heap_sort Theta 0.19058334733217908
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10183800000000076
# Sample mean is:  0.10180135757575753 Sample variance is: 6.499763514064124e-05
#
#
# p-value:  0.9796479220277852
# Significance level:  1.8111362085398682e-84
#
#
# Iteration: 64
# quick_sort Theta 0.09851222385054306
# merge_sort Theta 0.11217609539952737
# heap_sort Theta 0.21738024803185618
#
#
# Chosen algorithm is:  quick_sort with reward: 0.11375449999999887
# Sample mean is:  0.10215292058823522 Sample variance is: 6.716462619694465e-05
#
#
# p-value:  2.184208290271113e-09
# Significance level:  3.4898924297616018e-84
#
#
# Iteration: 65
# quick_sort Theta 0.098883281626057
# merge_sort Theta 0.0990048079906282
# heap_sort Theta 0.2523226310614439
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10636800000000335
# Sample mean is:  0.10227335142857145 Sample variance is: 6.573875884537106e-05
#
#
# p-value:  0.005794389771351433
# Significance level:  2.2721134155129625e-84
#
#
# Iteration: 66
# quick_sort Theta 0.10263977983112021
# merge_sort Theta 0.10617556416026382
# heap_sort Theta 0.2737095019034082
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10038470000000643
# Sample mean is:  0.10222088888888908 Sample variance is: 6.400901334322471e-05
#
#
# p-value:  0.1832220416188297
# Significance level:  1.3329770054775822e-84
#
#
# Iteration: 67
# quick_sort Theta 0.1040581945558851
# merge_sort Theta 0.10629992464681447
# heap_sort Theta 0.18717633921632937
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10064170000000416
# Sample mean is:  0.10217820810810842 Sample variance is: 6.234461937535376e-05
#
#
# p-value:  0.25065144494533603
# Significance level:  7.870087425764577e-85
#
#
# Iteration: 68
# quick_sort Theta 0.10133121670456546
# merge_sort Theta 0.10030485326061826
# heap_sort Theta 0.17738502120913174
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11277559999999909
# Sample mean is:  0.10804330800000059 Sample variance is: 3.9170849587125606e-05
#
#
# p-value:  0.0011085728072540342
# Significance level:  7.232023415446872e-89
#
#
# Iteration: 69
# quick_sort Theta 0.10960379840845327
# merge_sort Theta 0.1063478656994711
# heap_sort Theta 0.3277689417713981
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10374360000000138
# Sample mean is:  0.10787793461538524 Sample variance is: 3.834798735763769e-05
#
#
# p-value:  0.002643492960164545
# Significance level:  4.729895115694011e-89
#
#
# Iteration: 70
# quick_sort Theta 0.11029553142139743
# merge_sort Theta 0.10746279469641633
# heap_sort Theta 0.22192536948535327
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10478769999999571
# Sample mean is:  0.10776348148148192 Sample variance is: 3.726827904594458e-05
#
#
# p-value:  0.019691308512808394
# Significance level:  2.6716943505057018e-89
#
#
# Iteration: 71
# quick_sort Theta 0.10109475099695597
# merge_sort Theta 0.11759091837763049
# heap_sort Theta 0.27697697398043997
#
#
# Chosen algorithm is:  quick_sort with reward: 0.1082394000000022
# Sample mean is:  0.1023377131578951 Sample variance is: 6.164532035063068e-05
#
#
# p-value:  5.243945750805353e-05
# Significance level:  6.280616505754236e-85
#
#
# Iteration: 72
# quick_sort Theta 0.09654032344696463
# merge_sort Theta 0.10184575289243339
# heap_sort Theta 0.1684331327555213
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09634410000000315
# Sample mean is:  0.1021840307692312 Sample variance is: 6.0962165621117654e-05
#
#
# p-value:  4.443232893882463e-05
# Significance level:  5.025829252846804e-85
# Iteration: 73
# quick_sort Theta 0.1076918376781095
# merge_sort Theta 0.11240712294219037
# heap_sort Theta 0.18810049798180342
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10694569999999715
# Sample mean is:  0.10230307250000034 Sample variance is: 5.999077789350578e-05
#
#
# p-value:  0.0005850581131958602
# Significance level:  3.6449356751572777e-85
#
#
# Iteration: 74
# quick_sort Theta 0.10656566909529623
# merge_sort Theta 0.10622750224351418
# heap_sort Theta 0.28102523022479153
#
#
# Chosen algorithm is:  merge_sort with reward: 0.12109810000000465
# Sample mean is:  0.10823971785714345 Sample variance is: 4.20608983886051e-05
#
#
# p-value:  7.467804524017317e-11
# Significance level:  3.003107599234142e-88
#
#
# Iteration: 75
# quick_sort Theta 0.09714186401614773
# merge_sort Theta 0.1087359581576886
# heap_sort Theta 0.22184111593374603
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10104030000000108
# Sample mean is:  0.10227227317073208 Sample variance is: 5.8565532136121164e-05
#
#
# p-value:  0.31472735406011715
# Significance level:  2.253418597463656e-85
#
#
# Iteration: 76
# quick_sort Theta 0.10306864666227687
# merge_sort Theta 0.10091094387034669
# heap_sort Theta 0.1872698310390845
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10473340000000064
# Sample mean is:  0.10811881034482818 Sample variance is: 4.1019844125060935e-05
#
#
# p-value:  0.00922141306926016
# Significance level:  1.8191986054636188e-88
#
#
# Iteration: 77
# quick_sort Theta 0.10968593532145793
# merge_sort Theta 0.11254750175029733
# heap_sort Theta 0.19095435227118415
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09805529999999862
# Sample mean is:  0.10217186904761937 Sample variance is: 5.758443520976801e-05
#
#
# p-value:  0.0012259438066180182
# Significance level:  1.6073195694280798e-85
#
#
# Iteration: 78
# quick_sort Theta 0.10782622419779112
# merge_sort Theta 0.10978579865680056
# heap_sort Theta 0.22832027554390782
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10356130000000263
# Sample mean is:  0.10220418139534922 Sample variance is: 5.628911398617712e-05
#
#
# p-value:  0.2476925079688014
# Significance level:  1.019737181575374e-85
#
#
# Iteration: 79
# quick_sort Theta 0.09905818830752139
# merge_sort Theta 0.11002135042464321
# heap_sort Theta 0.215450366662835
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10534390000000116
# Sample mean is:  0.10227553863636403 Sample variance is: 5.522876574238234e-05
#
#
# p-value:  0.009688893670878829
# Significance level:  6.971187334796192e-86
#
#
# Iteration: 80
# quick_sort Theta 0.10704209152626816
# merge_sort Theta 0.10930054100660294
# heap_sort Theta 0.18408273628797964
#
#
# Chosen algorithm is:  quick_sort with reward: 0.17413210000000134
# Sample mean is:  0.10387235111111152 Sample variance is: 0.00016619310333540187
#
#
# p-value:  2.3261842470707553e-34
# Significance level:  2.5838062848102015e-76
#
#
# Iteration: 81
# quick_sort Theta 0.10457801375136086
# merge_sort Theta 0.10135122770184726
# heap_sort Theta 0.21012060069376134
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10707829999999774
# Sample mean is:  0.10808412666666717 Sample variance is: 3.968740175595144e-05
#
#
# p-value:  0.3969533011705618
# Significance level:  9.398387587987518e-89
#
#
# Iteration: 82
# quick_sort Theta 0.11490019086359086
# merge_sort Theta 0.11668358385517226
# heap_sort Theta 0.21074904586501003
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0976843000000045
# Sample mean is:  0.10373782826087007 Sample variance is: 0.0001633945476603011
#
#
# p-value:  0.002689810830422841
# Significance level:  1.8397177895355062e-76
#
#
# Iteration: 83
# quick_sort Theta 0.10982794196975121
# merge_sort Theta 0.11595324534751292
# heap_sort Theta 0.23330020011276864
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09554869999999482
# Sample mean is:  0.10356359148936209 Sample variance is: 0.00016131455673994204
#
#
# p-value:  9.382066196313023e-05
# Significance level:  1.4238727626175636e-76
#
#
# Iteration: 84
# quick_sort Theta 0.08992957814196492
# merge_sort Theta 0.1043335090716895
# heap_sort Theta 0.25645872615518767
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10987010000000197
# Sample mean is:  0.10369497708333375 Sample variance is: 0.00015876515900011443
#
#
# p-value:  0.0015553038634713314
# Significance level:  1.0353902075905332e-76
#
#
# Iteration: 85
# quick_sort Theta 0.11898213464334417
# merge_sort Theta 0.11029165041535789
# heap_sort Theta 0.16683893509128456
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11161409999999705
# Sample mean is:  0.10819799677419394 Sample variance is: 3.879615503127517e-05
#
#
# p-value:  0.005336236411926904
# Significance level:  5.967242983446412e-89
#
#
# Iteration: 86
# quick_sort Theta 0.114102557097993
# merge_sort Theta 0.10919608229552381
# heap_sort Theta 0.21789465501269767
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10325340000000693
# Sample mean is:  0.10804347812500059 Sample variance is: 3.832393158795243e-05
#
#
# p-value:  0.00015409163759854931
# Significance level:  4.670905971242802e-89
#
#
# Iteration: 87
# quick_sort Theta 0.11025144235799181
# merge_sort Theta 0.11311826137066795
# heap_sort Theta 0.27440585496865855
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09734589999999343
# Sample mean is:  0.10356540408163292 Sample variance is: 0.00015633093352734632
#
#
# p-value:  0.0011908522964127822
# Significance level:  7.601484696655388e-77
#
#
# Iteration: 88
# quick_sort Theta 0.1211102827653992
# merge_sort Theta 0.10271755217404005
# heap_sort Theta -0.027618152337595875
#
#
# Chosen algorithm is:  heap_sort with reward: 0.22033090000000044
# Sample mean is:  0.22914633750000046 Sample variance is: 0.00032865649754733583
#
#
# p-value:  0.23916811490309997
# Significance level:  2.1619440691152203e-70
#
#
# Iteration: 89
# quick_sort Theta 0.10884722041577502
# merge_sort Theta 0.10381994766413175
# heap_sort Theta 0.2849038991396899
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11013239999999769
# Sample mean is:  0.10810677878787929 Sample variance is: 3.72908234931797e-05
#
#
# p-value:  0.06974192525670275
# Significance level:  2.704204180406589e-89
#
#
# Iteration: 90
# quick_sort Theta 0.11410034589327057
# merge_sort Theta 0.11860047742908741
# heap_sort Theta 0.21385536559119125
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09852969999999317
# Sample mean is:  0.10346469000000014 Sample variance is: 0.00015370133784251716
#
#
# p-value:  0.007560032697716702
# Significance level:  5.414432623523672e-77
#
#
# Iteration: 91
# quick_sort Theta 0.09630750622782112
# merge_sort Theta 0.10330021628238578
# heap_sort Theta 0.22688466902336957
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0980343000000019
# Sample mean is:  0.10335821176470605 Sample variance is: 0.00015125446684968193
#
#
# p-value:  0.0035440718474835896
# Significance level:  3.927934002574462e-77
#
#
# Iteration: 92
# quick_sort Theta 0.11783156261794711
# merge_sort Theta 0.10572669611252987
# heap_sort Theta 0.17094869126471487
#
#
# Chosen algorithm is:  merge_sort with reward: 0.113903999999998
# Sample mean is:  0.10827728529411808 Sample variance is: 3.715342603301169e-05
#
#
# p-value:  7.547395037348387e-06
# Significance level:  2.5117554413716786e-89
#
#
# Iteration: 93
# quick_sort Theta 0.09967109055935616
# merge_sort Theta 0.10469425849318688
# heap_sort Theta 0.2075902174101913
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10990480000000247
# Sample mean is:  0.1034841076923079 Sample variance is: 0.000149154066116496
#
#
# p-value:  0.00044644175592215967
# Significance level:  2.969627284752848e-77
#
#
# Iteration: 94
# quick_sort Theta 0.10438988078438605
# merge_sort Theta 0.1114066414137307
# heap_sort Theta 0.23727619619589066
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10169309999999854
# Sample mean is:  0.1034503150943398 Sample variance is: 0.00014639921931714714
#
#
# p-value:  0.2998202365507252
# Significance level:  2.0453857056967068e-77
#
#
# Iteration: 95
# quick_sort Theta 0.09737243003588489
# merge_sort Theta 0.10367679750676825
# heap_sort Theta 0.18927607984668735
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09408309999999886
# Sample mean is:  0.1032768481481483 Sample variance is: 0.00014528293407843913
#
#
# p-value:  9.221027107853286e-07
# Significance level:  1.7550602989908335e-77
#
#
# Iteration: 96
# quick_sort Theta 0.10665101674377041
# merge_sort Theta 0.10304109025730751
# heap_sort Theta 0.34058016179372164
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10506540000000086
# Sample mean is:  0.10818551714285758 Sample variance is: 3.637822695684177e-05
#
#
# p-value:  0.0048163052479536115
# Significance level:  1.6475194945377965e-89
#
#
# Iteration: 97
# quick_sort Theta 0.09556348760783893
# merge_sort Theta 0.11063624419836864
# heap_sort Theta 0.24525750279085948
# Chosen algorithm is:  quick_sort with reward: 0.10072259999999744
# Sample mean is:  0.10323040727272738 Sample variance is: 0.00014275789095123643
#
#
# p-value:  0.12882201945415378
# Significance level:  1.2359544477284382e-77
#
#
# Iteration: 98
# quick_sort Theta 0.09551144264041772
# merge_sort Theta 0.10259949705634391
# heap_sort Theta 0.24652728122770193
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09919550000000044
# Sample mean is:  0.10315835535714298 Sample variance is: 0.0001404941742182018
#
#
# p-value:  0.016250333981958708
# Significance level:  8.977725451481832e-78
#
#
# Iteration: 99
# quick_sort Theta 0.10697486036057595
# merge_sort Theta 0.10140294938426228
# heap_sort Theta 0.20832750922695648
#
#
# Chosen algorithm is:  merge_sort with reward: 0.11047849999999926
# Sample mean is:  0.10824921111111152 Sample variance is: 3.550971290820272e-05
#
#
# p-value:  0.03349546888955851
# Significance level:  1.0161158409312526e-89
#
#
# Iteration: 100
# quick_sort Theta 0.10576767913396345
# merge_sort Theta 0.10549275154351032
# heap_sort Theta 0.22211327510015416
#
#
# Chosen algorithm is:  merge_sort with reward: 0.1191643999999954
# Sample mean is:  0.10854421621621649 Sample variance is: 3.768299937107855e-05
#
#
# p-value:  2.2702710928670503e-12
# Significance level:  3.333567563320196e-89
#
#
# Iteration: 101
# quick_sort Theta 0.10540508808138316
# merge_sort Theta 0.10955479924181102
# heap_sort Theta 0.2400403125508557
#
#
# Chosen algorithm is:  quick_sort with reward: 0.1546249999999958
# Sample mean is:  0.10406127894736845 Sample variance is: 0.00018368454069219665
#
#
# p-value:  1.4989684992957136e-34
# Significance level:  1.9118425924770524e-75
#
#
# Iteration: 102
# quick_sort Theta 0.0961203461395052
# merge_sort Theta 0.10769674452293884
# heap_sort Theta 0.2623221300252384
#
#
# Chosen algorithm is:  quick_sort with reward: 0.13468510000000578
# Sample mean is:  0.1045892758620691 Sample variance is: 0.00019640806814287973
#
#
# p-value:  5.177571826301534e-23
# Significance level:  7.297707953970514e-75
#
#
# Iteration: 103
# quick_sort Theta 0.09503785477841073
# merge_sort Theta 0.10870081490002202
# heap_sort Theta 0.1458255351437885
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09653529999999932
# Sample mean is:  0.1044527677966103 Sample variance is: 0.0001941599160476211
#
#
# p-value:  6.033517312829112e-05
# Significance level:  5.796842634009626e-75
#
#
# Iteration: 104
# quick_sort Theta 0.10779684170662508
# merge_sort Theta 0.11334731265434554
# heap_sort Theta 0.3162934936494809
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09755560000000685
# Sample mean is:  0.10433781500000024 Sample variance is: 0.0001917035520282873
#
#
# p-value:  0.00038909675285835407
# Significance level:  4.493690918182974e-75
#
#
# Iteration: 105
# quick_sort Theta 0.08825063322990621
# merge_sort Theta 0.11472749532509288
# heap_sort Theta 0.22108816607383977
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10151749999999993
# Sample mean is:  0.10429158032786909 Sample variance is: 0.0001886891295419202
#
#
# p-value:  0.12300559425537685
# Significance level:  3.2729368062824243e-75
#
#
# Iteration: 106
# quick_sort Theta 0.1069269419077851
# merge_sort Theta 0.1034651983623594
# heap_sort Theta 0.2531322689364618
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10789180000000442
# Sample mean is:  0.10852704736842143 Sample variance is: 3.670224795827283e-05
#
#
# p-value:  0.5275193811706591
# Significance level:  1.9672216675263143e-89
#
#
# Iteration: 107
# quick_sort Theta 0.10564995685414917
# merge_sort Theta 0.10886223160420368
# heap_sort Theta 0.21403488250840894
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09599320000000944
# Sample mean is:  0.10415773548387135 Sample variance is: 0.00018673853746294393
#
#
# p-value:  1.7239241430685535e-05
# Significance level:  2.6587595432696776e-75
#
#
# Iteration: 108
# quick_sort Theta 0.10380320555893661
# merge_sort Theta 0.1102141557513405
# heap_sort Theta 0.20007334161462753
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09662509999999713
# Sample mean is:  0.10403816984127016 Sample variance is: 0.00018466078215291008
#
#
# p-value:  6.252007009896029e-05
# Significance level:  2.1256581131560116e-75
#
#
# Iteration: 109
# quick_sort Theta 0.08101640600906015
# merge_sort Theta 0.11747323887307227
# heap_sort Theta 0.25948188392287813
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09696959999999422
# Sample mean is:  0.10392772343750023 Sample variance is: 0.0001825439571424307
#
#
# p-value:  0.00012564802072768372
# Significance level:  1.6879097291631109e-75
#
#
# Iteration: 110
# quick_sort Theta 0.09698772449524656
# merge_sort Theta 0.11565084036770308
# heap_sort Theta 0.27498979744331853
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09559020000000373
# Sample mean is:  0.10379945384615413 Sample variance is: 0.00018078858620711085
#
#
# p-value:  7.26044128352203e-06
# Significance level:  1.3912980313117895e-75
#
#
# Iteration: 111
# quick_sort Theta 0.11379084908920443
# merge_sort Theta 0.10722515050347238
# heap_sort Theta 0.22767241532142013
#
#
# Chosen algorithm is:  merge_sort with reward: 0.1052786999999995
# Sample mean is:  0.10844375641025678 Sample variance is: 3.602478525834702e-05
#
#
# p-value:  0.002414699121180943
# Significance level:  1.3552768304950277e-89
#
#
# Iteration: 112
# quick_sort Theta 0.10439708923593792
# merge_sort Theta 0.11170812867691014
# heap_sort Theta 0.1892601306004162
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09334720000001084
# Sample mean is:  0.10364108636363681 Sample variance is: 0.00017967958207269964
#
#
# p-value:  4.5255023523845867e-08
# Significance level:  1.2301967500091605e-75
#
#
# Iteration: 113
# quick_sort Theta 0.1127970686274841
# merge_sort Theta 0.10693559537344761
# heap_sort Theta 0.228242500272132
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10808160000000555
# Sample mean is:  0.1084347025000005 Sample variance is: 3.5127362585234567e-05
#
#
# p-value:  0.711863935972411
# Significance level:  8.182968337851293e-90
#
#
# Iteration: 114
# quick_sort Theta 0.09966308912475294
# merge_sort Theta 0.11701672083379025
# heap_sort Theta 0.27485193652924433
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09766729999999768
# Sample mean is:  0.10355192537313473 Sample variance is: 0.00017752247629264695
#
#
# p-value:  0.0006338225663122054
# Significance level:  9.661998068810878e-76
#
#
# Iteration: 115
# quick_sort Theta 0.10152894098922693
# merge_sort Theta 0.10569462452544398
# heap_sort Theta 0.23964576767178775
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09542809999999236
# Sample mean is:  0.10343245735294146 Sample variance is: 0.0001758681163671608
#
#
# p-value:  5.477752379339796e-06
# Significance level:  8.012024010951156e-76
#
#
# Iteration: 116
# quick_sort Theta 0.09682871520794371
# merge_sort Theta 0.10840108928295411
# heap_sort Theta 0.23817028885347005
#
#
# Chosen algorithm is:  quick_sort with reward: 0.11184149999999704
# Sample mean is:  0.10355432753623212 Sample variance is: 0.00017432926231359763
#
#
# p-value:  2.1853249455212724e-06
# Significance level:  6.720565966217928e-76
#
#
# Iteration: 117
# quick_sort Theta 0.09967497976535311
# merge_sort Theta 0.10610100078570708
# heap_sort Theta 0.21487746625743065
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10086189999999817
# Sample mean is:  0.10351586428571449 Sample variance is: 0.0001719409243737326
#
#
# p-value:  0.09723757836491279
# Significance level:  5.10017577960037e-76
#
#
# Iteration: 118
# quick_sort Theta 0.10162731528820501
# merge_sort Theta 0.10697853448009445
# heap_sort Theta 0.12762688633249064
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09397730000000593
# Sample mean is:  0.10338151830985945 Sample variance is: 0.00017078264009953037
#
#
# p-value:  7.201085409977438e-08
# Significance level:  4.455274418126194e-76
#
#
# Iteration: 119
# quick_sort Theta 0.1169238435796466
# merge_sort Theta 0.09875349878406382
# heap_sort Theta 0.2366345824381332
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10399549999999635
# Sample mean is:  0.10832642926829307 Sample variance is: 3.473952135230601e-05
#
#
# p-value:  3.616471243691686e-05
# Significance level:  6.553549849236408e-90
#
#
# Iteration: 120
# quick_sort Theta 0.10364875275916241
# merge_sort Theta 0.1156348501758138
# heap_sort Theta 0.2593264531333015
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09949260000000493
# Sample mean is:  0.1033275055555559 Sample variance is: 0.00016861779279858614
#
#
# p-value:  0.01517705031956418
# Significance level:  3.4519778634184755e-76
#
#
# Iteration: 121
# quick_sort Theta 0.10230831505574103
# merge_sort Theta 0.10566339285251007
# heap_sort Theta 0.24662876502962683
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0939718000000056
# Sample mean is:  0.10319934520547988 Sample variance is: 0.00016749056544439927
#
#
# p-value:  5.898474704350788e-08
# Significance level:  3.0186097802575055e-76
#
#
# Iteration: 122
# quick_sort Theta 0.09229181036922514
# merge_sort Theta 0.10234004491627711
# heap_sort Theta 0.2382159733850695
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09571579999999358
# Sample mean is:  0.10309821621621655 Sample variance is: 0.0001659737557151482
#
#
# p-value:  5.688746248254088e-06
# Significance level:  2.5164507177285638e-76
#
#
# Iteration: 123
# quick_sort Theta 0.1032894960086092
# merge_sort Theta 0.1099482070391421
# heap_sort Theta 0.2223420117467552
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09705180000000269
# Sample mean is:  0.1030175973333337 Sample variance is: 0.00016424172822213155
#
#
# p-value:  0.00014637846119767154
# Significance level:  2.0401876974714704e-76
#
#
# Iteration: 124
# quick_sort Theta 0.09721353844775618
# merge_sort Theta 0.10138345513528507
# heap_sort Theta 0.28248985641898106
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09245719999999835
# Sample mean is:  0.10287864473684244 Sample variance is: 0.00016352873965616235
#
#
# p-value:  7.238559467285092e-10
# Significance level:  1.8701730381151572e-76
#
#
# Iteration: 125
# quick_sort Theta 0.10295302539122884
# merge_sort Theta 0.10599583477996814
# heap_sort Theta 0.2326361820253087
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0974032999999963
# Sample mean is:  0.10280753636363665 Sample variance is: 0.00016178927624673593
#
#
# p-value:  0.00040028640010185645
# Significance level:  1.5100615327688602e-76
#
#
# Iteration: 126
# quick_sort Theta 0.11264153778506925
# merge_sort Theta 0.10339808734884871
# heap_sort Theta 0.16200287659552365
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10213889999999992
# Sample mean is:  0.10817910714285753 Sample variance is: 3.4802246045893596e-05
#
#
# p-value:  7.006440820911491e-08
# Significance level:  6.794311616455108e-90
#
#
# Iteration: 127
# quick_sort Theta 0.09438619116576336
# merge_sort Theta 0.11155990441146553
# heap_sort Theta 0.20525737716861064
#
#
# Chosen algorithm is:  quick_sort with reward: 0.096344600000009
# Sample mean is:  0.10272467820512861 Sample variance is: 0.00016024369628760674
#
#
# p-value:  3.16056884957594e-05
# Significance level:  1.2462899201871053e-76
#
#
# Iteration: 128
# quick_sort Theta 0.1041578883220916
# merge_sort Theta 0.11213237806246891
# heap_sort Theta 0.1660452535391535
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09640340000001402
# Sample mean is:  0.10264466202531702 Sample variance is: 0.00015871469701324404
#
#
# p-value:  3.7141832064798933e-05
# Significance level:  1.0288282658777434e-76
#
#
# Iteration: 129
# quick_sort Theta 0.11455145103450781
# merge_sort Theta 0.1042521460058297
# heap_sort Theta 0.20725696408504107
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10240929999999082
# Sample mean is:  0.1080449255813955 Sample variance is: 3.474908852701493e-05
#
#
# p-value:  2.0762440328966868e-07
# Significance level:  6.589741059155613e-90
#
#
# Iteration: 130
# quick_sort Theta 0.1077496170497812
# merge_sort Theta 0.11190389659743073
# heap_sort Theta 0.23951650253995455
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09658099999998626
# Sample mean is:  0.10256886625000039 Sample variance is: 0.0001571846182654906
#
#
# p-value:  5.908856003308811e-05
# Significance level:  8.476194113854693e-77
#
#
# Iteration: 131
# quick_sort Theta 0.09537279544943263
# merge_sort Theta 0.10758815420403219
# heap_sort Theta 0.2353793552787488
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10171710000000189
# Sample mean is:  0.10255835061728436 Sample variance is: 0.00015525291370522027
#
#
# p-value:  0.5476321630024601
# Significance level:  6.6190428212219425e-77
#
#
# Iteration: 132
# quick_sort Theta 0.09532301238220264
# merge_sort Theta 0.10737434858465811
# heap_sort Theta 0.22811552417943137
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0948661000000044
# Sample mean is:  0.10246454268292729 Sample variance is: 0.00015407237970171855
#
#
# p-value:  4.1469145565435847e-07
# Significance level:  5.6819290837919255e-77
#
#
# Iteration: 133
# quick_sort Theta 0.09644315068236617
# merge_sort Theta 0.10695960197864415
# heap_sort Theta 0.26675425267123565
#
#
# ...
#
#
# Iteration: 1955
# quick_sort Theta 0.04115167109585818
# merge_sort Theta 0.02802177302551999
# heap_sort Theta 0.07285216670560993
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026778800000045067
# Sample mean is:  0.02769330967741748 Sample variance is: 4.536944488611547e-06
#
#
# p-value:  1.6954496587358965e-16
# Significance level:  1.365429591206493e-107
#
#
# Iteration: 1956
# quick_sort Theta 0.03505282118617951
# merge_sort Theta 0.0270142289882053
# heap_sort Theta 0.07291277418243679
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0298565999999596
# Sample mean is:  0.027698664356433672 Sample variance is: 4.537269480704855e-06
#
#
# p-value:  8.791513509492972e-64
# Significance level:  1.367387102169522e-107
#
#
# Iteration: 1957
# quick_sort Theta 0.04072281507596548
# merge_sort Theta 0.028463992000149447
# heap_sort Theta 0.07336734347065087
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02562510000001339
# Sample mean is:  0.02769354444444251 Sample variance is: 4.536656599698679e-06
#
#
# p-value:  3.01220562222851e-60
# Significance level:  1.3636977861581864e-107
#
#
# Iteration: 1958
# quick_sort Theta 0.03645569891329455
# merge_sort Theta 0.029050619250821013
# heap_sort Theta 0.07249149614003594
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02890980000000809
# Sample mean is:  0.027696540147781345 Sample variance is: 4.529117135255125e-06
#
#
# p-value:  1.4146018598330735e-26
# Significance level:  1.3190797620330717e-107
#
#
# Iteration: 1959
# quick_sort Theta 0.035093329075612224
# merge_sort Theta 0.028134405454471146
# heap_sort Theta 0.0755663271769199
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02547989999999345
# Sample mean is:  0.02769109385749194 Sample variance is: 4.530031886959837e-06
#
#
# p-value:  1.5869261840063422e-66
# Significance level:  1.3244183232927406e-107
#
#
# Iteration: 1960
# quick_sort Theta 0.0403268054889157
# merge_sort Theta 0.028750281092984345
# heap_sort Theta 0.07238530872156176
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028472000000022035
# Sample mean is:  0.027693007843135393 Sample variance is: 4.520419847433699e-06
#
#
# p-value:  8.31983079456241e-13
# Significance level:  1.269332680176264e-107
#
#
# Iteration: 1961
# quick_sort Theta 0.03550101421165995
# merge_sort Theta 0.028405619016045176
# heap_sort Theta 0.07524438947582039
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026856199999997443
# Sample mean is:  0.027690961858188846 Sample variance is: 4.511075386364393e-06
#
#
# p-value:  1.997185967201302e-14
# Significance level:  1.2178721423079577e-107
#
#
# Iteration: 1962
# quick_sort Theta 0.032627721196463386
# merge_sort Theta 0.02711405618351344
# heap_sort Theta 0.0738452986500234
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02783599999997932
# Sample mean is:  0.02769131560975419 Sample variance is: 4.500123945800342e-06
#
#
# p-value:  0.16854390014831366
# Significance level:  1.1600842006373519e-107
#
#
# Iteration: 1963
# quick_sort Theta 0.03698483387583265
# merge_sort Theta 0.026897373110876203
# heap_sort Theta 0.07424213662705359
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026309200000014243
# Sample mean is:  0.027687952798051658 Sample variance is: 4.493811225163701e-06
#
#
# p-value:  2.8065561115875575e-33
# Significance level:  1.1279672616141394e-107
# Iteration: 1964
# quick_sort Theta 0.03399348284925815
# merge_sort Theta 0.02704913086026055
# heap_sort Theta 0.0727282612710483
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02976610000001756
# Sample mean is:  0.027692996844658372 Sample variance is: 4.4933607453009155e-06
#
#
# p-value:  7.102384733170101e-62
# Significance level:  1.1257079636496114e-107
#
#
# Iteration: 1965
# quick_sort Theta 0.04106781585595642
# merge_sort Theta 0.028201929672130272
# heap_sort Theta 0.07564425685778833
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0261084000000551
# Sample mean is:  0.027689160048424467 Sample variance is: 4.488545991401207e-06
#
#
# p-value:  1.6636832682367658e-41
# Significance level:  1.1018274552154617e-107
#
#
# Iteration: 1966
# quick_sort Theta 0.02761720885528189
# merge_sort Theta 0.02765959308091757
# heap_sort Theta 0.07240608759063924
#
#
# Chosen algorithm is:  quick_sort with reward: 0.037185799999974734
# Sample mean is:  0.0368018500000062 Sample variance is: 2.5524883285234017e-06
#
#
# p-value:  0.48923424211814337
# Significance level:  1.3780827555822232e-112
#
#
# Iteration: 1967
# quick_sort Theta 0.04093103041043541
# merge_sort Theta 0.02807405920222026
# heap_sort Theta 0.07259696152970994
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025748099999987062
# Sample mean is:  0.02768447149758283 Sample variance is: 4.486782869086025e-06
#
#
# p-value:  1.9455601412775996e-56
# Significance level:  1.0932036187708825e-107
#
#
# Iteration: 1968
# quick_sort Theta 0.03609448566936914
# merge_sort Theta 0.02737820521923816
# heap_sort Theta 0.07267659857466639
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02699030000002267
# Sample mean is:  0.02768279879517907 Sample variance is: 4.477129688499534e-06
#
#
# p-value:  8.778944609767331e-11
# Significance level:  1.0471128626846514e-107
#
#
# Iteration: 1969
# quick_sort Theta 0.03920136019838903
# merge_sort Theta 0.027129019961049716
# heap_sort Theta 0.0763390927763607
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025673299999994015
# Sample mean is:  0.027677968269229105 Sample variance is: 4.476050959613174e-06
#
#
# p-value:  1.0376385578776414e-59
# Significance level:  1.0420785249752725e-107
#
#
# Iteration: 1970
# quick_sort Theta 0.03678391355738281
# merge_sort Theta 0.027490384561326357
# heap_sort Theta 0.0727766583656596
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028635399999984656
# Sample mean is:  0.027680264268583436 Sample variance is: 4.4675100154808195e-06
#
#
# p-value:  1.5377106501631567e-18
# Significance level:  1.0030225478415312e-107
#
#
# Iteration: 1971
# quick_sort Theta 0.0361805737192319
# merge_sort Theta 0.028077534719830193
# heap_sort Theta 0.07801652448328905
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026452599999970516
# Sample mean is:  0.02767732727272551 Sample variance is: 4.460419211404449e-06
#
#
# p-value:  4.349597911918435e-28
# Significance level:  9.716582753982462e-108
#
#
# Iteration: 1972
# quick_sort Theta 0.035273968357958964
# merge_sort Theta 0.02786817874014962
# heap_sort Theta 0.07324516594542547
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02890109999998458
# Sample mean is:  0.027680247971358585 Sample variance is: 4.453339560342985e-06
#
#
# p-value:  4.831151821830847e-28
# Significance level:  9.412743272461975e-108
#
#
# Iteration: 1973
# quick_sort Theta 0.03465022478809328
# merge_sort Theta 0.02774126662363163
# heap_sort Theta 0.07268717370864525
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025510800000006384
# Sample mean is:  0.027675082619045843 Sample variance is: 4.453915653145282e-06
#
#
# p-value:  2.2258361267945957e-67
# Significance level:  9.437126245334306e-108
#
#
# Iteration: 1974
# quick_sort Theta 0.03591809072997545
# merge_sort Theta 0.027832758944527466
# heap_sort Theta 0.07554021045546358
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026128700000015215
# Sample mean is:  0.027671409501185913 Sample variance is: 4.449002834868984e-06
#
#
# p-value:  5.467786656418452e-41
# Significance level:  9.231104120594341e-108
#
#
# Iteration: 1975
# quick_sort Theta 0.03755974412803175
# merge_sort Theta 0.026907479627350715
# heap_sort Theta 0.07682435206042637
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026607699999999568
# Sample mean is:  0.02766888886255751 Sample variance is: 4.441135047761845e-06
#
#
# p-value:  1.8733015003354539e-22
# Significance level:  8.910038721283529e-108
#
#
# Iteration: 1976
# quick_sort Theta 0.03756137907636867
# merge_sort Theta 0.02743601052165317
# heap_sort Theta 0.07144558051212249
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028335599999991246
# Sample mean is:  0.027670465011818583 Sample variance is: 4.431684262553215e-06
#
#
# p-value:  2.4035288403118935e-10
# Significance level:  8.538394685925857e-108
#
#
# Iteration: 1977
# quick_sort Theta 0.040983378787273116
# merge_sort Theta 0.027292018914264558
# heap_sort Theta 0.0739373273464713
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02584779999995135
# Sample mean is:  0.027666166273583048 Sample variance is: 4.429048857654995e-06
#
#
# p-value:  3.5565704622048947e-53
# Significance level:  8.437415217054303e-108
#
#
# Iteration: 1978
# quick_sort Theta 0.03418353574430305
# merge_sort Theta 0.028670837136750865
# heap_sort Theta 0.07497344413596219
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028311800000039966
# Sample mean is:  0.027667685411762944 Sample variance is: 4.4196060652885006e-06
#
#
# p-value:  7.078443898219189e-10
# Significance level:  8.084836065265841e-108
#
#
# Iteration: 1979
# quick_sort Theta 0.036094008629347314
# merge_sort Theta 0.027997868886796565
# heap_sort Theta 0.07382942041430521
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025682600000038747
# Sample mean is:  0.027663025586852793 Sample variance is: 4.418459839645546e-06
#
#
# p-value:  1.3074920928684068e-60
# Significance level:  8.043003153580273e-108
#
#
# Iteration: 1980
# quick_sort Theta 0.03740145195410689
# merge_sort Theta 0.02750758581908929
# heap_sort Theta 0.07508847486051641
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02940649999999323
# Sample mean is:  0.027667108665103708 Sample variance is: 4.4152142294515706e-06
#
#
# p-value:  3.1765569844262627e-50
# Significance level:  7.925663221264315e-108
#
#
# Iteration: 1981
# quick_sort Theta 0.038759807907403306
# merge_sort Theta 0.02663841786256567
# heap_sort Theta 0.07485130574705759
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025668499999994765
# Sample mean is:  0.027662439018689904 Sample variance is: 4.414209298542718e-06
#
#
# p-value:  1.5864300701240283e-61
# Significance level:  7.889662496608654e-108
#
#
# Iteration: 1982
# quick_sort Theta 0.03122562500991502
# merge_sort Theta 0.027613177183207067
# heap_sort Theta 0.07316336685638043
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026643700000022363
# Sample mean is:  0.027660064335662708 Sample variance is: 4.406333309515576e-06
#
#
# p-value:  2.3351756898957135e-21
# Significance level:  7.612843647513162e-108
#
#
# Iteration: 1983
# quick_sort Theta 0.03501601944993489
# merge_sort Theta 0.028305312556584965
# heap_sort Theta 0.07359887175819536
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025376999999991767
# Sample mean is:  0.027654754883719285 Sample variance is: 4.408179652843304e-06
#
#
# p-value:  1.77846188343199e-74
# Significance level:  7.676896978586315e-108
#
#
# Iteration: 1984
# quick_sort Theta 0.02749319936853188
# merge_sort Theta 0.02795528840513878
# heap_sort Theta 0.07395480096945356
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03790249999997286
# Sample mean is:  0.03690190909091226 Sample variance is: 2.4205621517507467e-06
#
#
# p-value:  0.06936801403229996
# Significance level:  4.7678739613315323e-113
#
#
# Iteration: 1985
# quick_sort Theta 0.03699083517549883
# merge_sort Theta 0.027842435312848576
# heap_sort Theta 0.07168423153344398
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0257565999999656
# Sample mean is:  0.027650350812063244 Sample variance is: 4.406292072100271e-06
#
#
# p-value:  1.4313654583389938e-57
# Significance level:  7.611418852502772e-108
#
#
# Iteration: 1986
# quick_sort Theta 0.041485526235046644
# merge_sort Theta 0.028082363960642967
# heap_sort Theta 0.06915376479110148
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02587639999995872
# Sample mean is:  0.027646244444442632 Sample variance is: 4.403359953853721e-06
#
#
# p-value:  3.082611128266254e-52
# Significance level:  7.510757992650707e-108
#
#
# Iteration: 1987
# quick_sort Theta 0.03982024655804747
# merge_sort Theta 0.02698404087309829
# heap_sort Theta 0.0747777178447239
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026323499999989508
# Sample mean is:  0.027643189607388468 Sample variance is: 4.397221968040178e-06
#
#
# p-value:  3.5932307784663935e-33
# Significance level:  7.304117984605648e-108
# Iteration: 1988
# quick_sort Theta 0.038118848055786025
# merge_sort Theta 0.027694365396680104
# heap_sort Theta 0.07154714341235706
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027809799999999996
# Sample mean is:  0.02764357350230232 Sample variance is: 4.387153933694563e-06
#
#
# p-value:  0.09938155420638255
# Significance level:  6.976819036500704e-108
#
#
# Iteration: 1989
# quick_sort Theta 0.03890201444546441
# merge_sort Theta 0.027969312914119245
# heap_sort Theta 0.07375510706355536
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025681800000029398
# Sample mean is:  0.027639063678159163 Sample variance is: 4.38589543734289e-06
#
#
# p-value:  3.83652798114705e-61
# Significance level:  6.936900607352594e-108
#
#
# Iteration: 1990
# quick_sort Theta 0.036181147295763175
# merge_sort Theta 0.028362200912359165
# heap_sort Theta 0.07274308301420573
#
#
# Chosen algorithm is:  merge_sort with reward: 0.029085399999985384
# Sample mean is:  0.027642380963300964 Sample variance is: 4.380622949747708e-06
#
#
# p-value:  1.2359883355739104e-38
# Significance level:  6.772008293676862e-108
#
#
# Iteration: 1991
# quick_sort Theta 0.03658629434188683
# merge_sort Theta 0.027665533874535082
# heap_sort Theta 0.07324102766933141
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02641280000000279
# Sample mean is:  0.027639567276886098 Sample variance is: 4.374050379359389e-06
#
#
# p-value:  7.574912555987235e-30
# Significance level:  6.571668030097893e-108
#
#
# Iteration: 1992
# quick_sort Theta 0.039389834644680724
# merge_sort Theta 0.028645171126023015
# heap_sort Theta 0.07086194469723645
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028149999999982356
# Sample mean is:  0.027640732648400015 Sample variance is: 4.3646574486326605e-06
#
#
# p-value:  5.178606020491416e-07
# Significance level:  6.2951095603734365e-108
#
#
# Iteration: 1993
# quick_sort Theta 0.037187370381646684
# merge_sort Theta 0.02783407075114171
# heap_sort Theta 0.07466587154058801
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025730799999962528
# Sample mean is:  0.027636382004553914 Sample variance is: 4.363005685161616e-06
#
#
# p-value:  1.4319250402787768e-59
# Significance level:  6.247633972502988e-108
#
#
# Iteration: 1994
# quick_sort Theta 0.0412365553016961
# merge_sort Theta 0.027933880591665225
# heap_sort Theta 0.07387124905456387
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02765849999997272
# Sample mean is:  0.02763643227272532 Sample variance is: 4.3530908724541806e-06
#
#
# p-value:  0.8247198897493906
# Significance level:  5.96972968545648e-108
#
#
# Iteration: 1995
# quick_sort Theta 0.03665518392708296
# merge_sort Theta 0.02831521646302312
# heap_sort Theta 0.0754959199880311
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026722099999972215
# Sample mean is:  0.02763435895691409 Sample variance is: 4.34511131901424e-06
#
#
# p-value:  1.6938281326588151e-18
# Significance level:  5.754639807012523e-108
#
#
# Iteration: 1996
# quick_sort Theta 0.03688711442911015
# merge_sort Theta 0.027493873155307505
# heap_sort Theta 0.06765812079964595
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027462200000002213
# Sample mean is:  0.027633969457011576 Sample variance is: 4.3353476546059454e-06
#
#
# p-value:  0.08389790435988412
# Significance level:  5.501468008320441e-108
#
#
# Iteration: 1997
# quick_sort Theta 0.03785979651612816
# merge_sort Theta 0.027552365823924282
# heap_sort Theta 0.07126548805407103
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026405300000021725
# Sample mean is:  0.027631195936792637 Sample variance is: 4.3289613639521126e-06
#
#
# p-value:  1.8593881599167193e-30
# Significance level:  5.341634828363182e-108
#
#
# Iteration: 1998
# quick_sort Theta 0.03584677098320925
# merge_sort Theta 0.027014872687792995
# heap_sort Theta 0.07276700721282513
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027239000000008673
# Sample mean is:  0.02763031261261069 Sample variance is: 4.319557106863651e-06
#
#
# p-value:  8.631102048007398e-05
# Significance level:  5.1142788025368055e-108
#
#
# Iteration: 1999
# quick_sort Theta 0.03689916040916477
# merge_sort Theta 0.027320338105212696
# heap_sort Theta 0.07355398853405398
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025857700000017303
# Sample mean is:  0.027626329213481265 Sample variance is: 4.3168953930297705e-06
#
#
# p-value:  1.6588049086197812e-54
# Significance level:  5.05161796756568e-108

# %%
for elem in list_iteration_results_TS_ttest:
    sample_mean, sample_count,rewards,cum_rewards,n = elem
    print("Iteration", n)
    plot_history(rewards,cum_rewards, sample_count, sample_mean)
print("Total reward", np.round(total_reward_TS_ttest,4))
# Out:
# Iteration 504
# Average rewards per algo {'quick_sort': 0.10000854545454595, 'merge_sort': 0.10834946704545483, 'heap_sort': 0.23188101000000003}
# Count per chosen algo {'quick_sort': 407, 'merge_sort': 88, 'heap_sort': 10}
# Iteration 1003
# Average rewards per algo {'quick_sort': 0.03339624736842426, 'merge_sort': 0.028230254184100002, 'heap_sort': 0.06619760000000241}
# Count per chosen algo {'quick_sort': 19, 'merge_sort': 478, 'heap_sort': 2}
# Iteration 1502
# Average rewards per algo {'quick_sort': 0.09689065965665183, 'merge_sort': 0.10843259333333416, 'heap_sort': 0.21584093333333007}
# Count per chosen algo {'quick_sort': 466, 'merge_sort': 30, 'heap_sort': 3}
# Iteration 1999
# Average rewards per algo {'quick_sort': 0.03690190909091226, 'merge_sort': 0.027626329213481265, 'heap_sort': 0.07315157560975094}
# Count per chosen algo {'quick_sort': 11, 'merge_sort': 445, 'heap_sort': 41}
# Total reward 131.5684

# %% [markdown]
# ### Second Variant: Change point detection

# %% [markdown]
# ## Offline changepoint detection - not adjustable to out case but works properly

# %%
list_iteration_results_TS_stationary, total_reward_TS_stationary = TS_stationary(list_distributions=list_distributions, n_samples=n_samples)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.6925881694982287
# Less than two values for merge_sort
# merge_sort Theta 0.6306707203315884
# Less than two values for heap_sort
# heap_sort Theta 0.3293921212477817
#
#
# Chosen algorithm is:  heap_sort with reward: 0.22295780000001741
# Sample mean is:  0.22295780000001741 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.9385424390993243
# Less than two values for merge_sort
# merge_sort Theta 0.7623088641616333
# Less than two values for heap_sort
# heap_sort Theta 0.35679252441277354
#
#
# Chosen algorithm is:  heap_sort with reward: 0.2186360000000036
# Sample mean is:  0.2207969000000105 Sample variance is: 4.66948881002984e-06
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.8960732265729581
# Less than two values for merge_sort
# merge_sort Theta 0.6974465989806551
# heap_sort Theta 0.22665786842334004
#
#
# Chosen algorithm is:  heap_sort with reward: 0.215635299999974
# Sample mean is:  0.219076366666665 Sample variance is: 9.033462442325882e-06
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.7097325339208305
# Less than two values for merge_sort
# merge_sort Theta 0.9908755324171716
# heap_sort Theta 0.21595428286083568
#
#
# Chosen algorithm is:  heap_sort with reward: 0.21635259999999334
# Sample mean is:  0.2183954249999971 Sample variance is: 8.166141491957845e-06
#
#
# Iteration: 4
# Less than two values for quick_sort
# quick_sort Theta 0.43360989875868106
# Less than two values for merge_sort
# merge_sort Theta 0.7074128892440187
# heap_sort Theta 0.2070894330628181
#
#
# Chosen algorithm is:  heap_sort with reward: 0.22221769999998742
# Sample mean is:  0.21915987999999514 Sample variance is: 8.870478981654446e-06
#
#
# Iteration: 5
# Less than two values for quick_sort
# quick_sort Theta 0.07174345938697102
# Less than two values for merge_sort
# merge_sort Theta 0.5586944702009149
# heap_sort Theta 0.21263506831730553
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0930834000000118
# Sample mean is:  0.0930834000000118 Sample variance is: 0.0
#
#
# Iteration: 6
# Less than two values for quick_sort
# quick_sort Theta 0.9034435872688098
# Less than two values for merge_sort
# merge_sort Theta 0.23782993151801135
# heap_sort Theta 0.21218557215989955
#
#
# Chosen algorithm is:  heap_sort with reward: 0.22527750000000424
# Sample mean is:  0.22017948333333 Sample variance is: 1.259002060478303e-05
#
#
# Iteration: 7
# Less than two values for quick_sort
# quick_sort Theta 0.9286157152074948
# Less than two values for merge_sort
# merge_sort Theta 0.7329690942513554
# heap_sort Theta 0.21233906740129543
#
#
# Chosen algorithm is:  heap_sort with reward: 0.21486570000001848
# Sample mean is:  0.2194203714285712 Sample variance is: 1.4248951536350269e-05
#
#
# Iteration: 8
# Less than two values for quick_sort
# quick_sort Theta 0.19162636028209468
# Less than two values for merge_sort
# merge_sort Theta 0.35077480486792656
# heap_sort Theta 0.21059145205901347
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09366049999999859
# Sample mean is:  0.0933719500000052 Sample variance is: 8.326110249618693e-08
#
#
# Iteration: 9
# quick_sort Theta 0.09600487872538918
# Less than two values for merge_sort
# merge_sort Theta 0.9206010600199204
# heap_sort Theta 0.20737487663587456
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10325629999999819
# Sample mean is:  0.0966667333333362 Sample variance is: 2.176670182885556e-05
#
#
# Iteration: 10
# quick_sort Theta 0.13213499266741086
# Less than two values for merge_sort
# merge_sort Theta 0.9170971671867121
# heap_sort Theta 0.22078665621299198
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09293990000003305
# Sample mean is:  0.09573502500001041 Sample variance is: 1.8929267626807818e-05
#
#
# Iteration: 11
# quick_sort Theta 0.10448700760316879
# Less than two values for merge_sort
# merge_sort Theta 0.5507426745082871
# heap_sort Theta 0.22023345518794918
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09834839999996348
# Sample mean is:  0.09625770000000103 Sample variance is: 1.6236170723907005e-05
#
#
# Iteration: 12
# quick_sort Theta 0.10245946694743902
# Less than two values for merge_sort
# merge_sort Theta 0.18175281877644955
# heap_sort Theta 0.22202387016424238
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09697109999996201
# Sample mean is:  0.09637659999999452 Sample variance is: 1.3600828319914771e-05
#
#
# Iteration: 13
# quick_sort Theta 0.11950356079940318
# Less than two values for merge_sort
# merge_sort Theta 0.2885353373860179
# heap_sort Theta 0.22946068010356885
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09399439999998549
# Sample mean is:  0.09603628571427894 Sample variance is: 1.2352735724013848e-05
#
#
# Iteration: 14
# quick_sort Theta 0.1014093157096543
# Less than two values for merge_sort
# merge_sort Theta 0.919089466858512
# heap_sort Theta 0.22275125907617274
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09653229999997848
# Sample mean is:  0.09609828749999139 Sample variance is: 1.0835553308532837e-05
#
#
# Iteration: 15
# quick_sort Theta 0.10125062312731556
# Less than two values for merge_sort
# merge_sort Theta 0.842923885262776
# heap_sort Theta 0.2200601623114638
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09284860000002482
# Sample mean is:  0.09573721111110621 Sample variance is: 1.067461220980094e-05
#
#
# Iteration: 16
# quick_sort Theta 0.09604573819134324
# Less than two values for merge_sort
# merge_sort Theta 0.6302653934623067
# heap_sort Theta 0.22333411165359152
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09622910000001639
# Sample mean is:  0.09578639999999723 Sample variance is: 9.628926909933842e-06
#
#
# Iteration: 17
# quick_sort Theta 0.10045745471968376
# Less than two values for merge_sort
# merge_sort Theta 0.5000226137196353
# heap_sort Theta 0.21175938094265398
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09636069999999108
# Sample mean is:  0.09583860909090576 Sample variance is: 8.780827809856628e-06
#
#
# Iteration: 18
# quick_sort Theta 0.09032042841113117
# Less than two values for merge_sort
# merge_sort Theta 0.7837186206770372
# heap_sort Theta 0.22765865090209952
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09423229999998739
# Sample mean is:  0.0957047499999959 Sample variance is: 8.246192977446611e-06
#
#
# Iteration: 19
# quick_sort Theta 0.09780896670440105
# Less than two values for merge_sort
# merge_sort Theta 0.40009451195275636
# heap_sort Theta 0.22258453519771346
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09854419999999209
# Sample mean is:  0.09592316923076484 Sample variance is: 8.184353965156283e-06
#
#
# Iteration: 20
# quick_sort Theta 0.09253586791074844
# Less than two values for merge_sort
# merge_sort Theta 0.7611233772737591
# heap_sort Theta 0.2220322281483383
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09331250000002456
# Sample mean is:  0.09573669285714052 Sample variance is: 8.051811946320336e-06
#
#
# Iteration: 21
# quick_sort Theta 0.09374991504600494
# Less than two values for merge_sort
# merge_sort Theta 0.7296599121508854
# heap_sort Theta 0.21675786465001753
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09773190000004206
# Sample mean is:  0.0958697066666673 Sample variance is: 7.762721912579845e-06
#
#
# Iteration: 22
# quick_sort Theta 0.0867247684814898
# Less than two values for merge_sort
# merge_sort Theta 0.600637957724997
# heap_sort Theta 0.19815471059951942
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09894700000000967
# Sample mean is:  0.0960620375000012 Sample variance is: 7.832419034807276e-06
#
#
# Iteration: 23
# quick_sort Theta 0.09294170907450248
# Less than two values for merge_sort
# merge_sort Theta 0.01003444253779584
# heap_sort Theta 0.22867285825595715
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10335220000001755
# Sample mean is:  0.10335220000001755 Sample variance is: 0.0
#
#
# Iteration: 24
# quick_sort Theta 0.09557714094050164
# Less than two values for merge_sort
# merge_sort Theta 0.8635713410096503
# heap_sort Theta 0.22135895649766113
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09814590000001999
# Sample mean is:  0.09618461764706113 Sample variance is: 7.6121027825997684e-06
#
#
# Iteration: 25
# quick_sort Theta 0.09675658706980017
# Less than two values for merge_sort
# merge_sort Theta 0.8349731181657124
# heap_sort Theta 0.22690993981726162
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09716609999998127
# Sample mean is:  0.09623914444444558 Sample variance is: 7.239752101327534e-06
#
#
# Iteration: 26
# quick_sort Theta 0.09677715762098076
# Less than two values for merge_sort
# merge_sort Theta 0.9166025894216331
# heap_sort Theta 0.22863997376263595
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09320669999999609
# Sample mean is:  0.09607954210526402 Sample variance is: 7.317224837147155e-06
#
#
# Iteration: 27
# quick_sort Theta 0.09414113529009385
# Less than two values for merge_sort
# merge_sort Theta 0.8919718704143856
# heap_sort Theta 0.20734324544837554
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09684729999997899
# Sample mean is:  0.09611792999999977 Sample variance is: 6.979362574072412e-06
#
#
# Iteration: 28
# quick_sort Theta 0.09591820356840347
# Less than two values for merge_sort
# merge_sort Theta 0.9857925196573754
# heap_sort Theta 0.22008323431183513
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09765089999996235
# Sample mean is:  0.09619092857142657 Sample variance is: 6.7535878039141e-06
#
#
# Iteration: 29
# quick_sort Theta 0.09382203353510796
# Less than two values for merge_sort
# merge_sort Theta 0.8208436766797131
# heap_sort Theta 0.19936159006400858
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09334709999995994
# Sample mean is:  0.0960616636363599 Sample variance is: 6.797504432293393e-06
#
#
# Iteration: 30
# quick_sort Theta 0.09270859194883524
# Less than two values for merge_sort
# merge_sort Theta 0.5799327360067191
# heap_sort Theta 0.21734749129111805
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09616820000002235
# Sample mean is:  0.09606629565217131 Sample variance is: 6.502432783874614e-06
#
#
# Iteration: 31
# quick_sort Theta 0.09402575622181716
# Less than two values for merge_sort
# merge_sort Theta 0.7085134198099079
# heap_sort Theta 0.22335675451656087
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0938543999999979
# Sample mean is:  0.09597413333333076 Sample variance is: 6.426857623870087e-06
#
#
# Iteration: 32
# quick_sort Theta 0.09498921934146613
# Less than two values for merge_sort
# merge_sort Theta 0.5932391902335048
# heap_sort Theta 0.23009748027889326
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09819389999995565
# Sample mean is:  0.09606292399999575 Sample variance is: 6.35899409859883e-06
#
#
# Iteration: 33
# quick_sort Theta 0.09614951919288879
# Less than two values for merge_sort
# merge_sort Theta 0.26380186424580854
# heap_sort Theta 0.22667655201820897
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09301720000001978
# Sample mean is:  0.09594578076922744 Sample variance is: 6.457480815369789e-06
#
#
# Iteration: 34
# quick_sort Theta 0.09400076820048665
# Less than two values for merge_sort
# merge_sort Theta 0.8016456721437295
# heap_sort Theta 0.2011316579921821
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09543690000003835
# Sample mean is:  0.09592693333333155 Sample variance is: 6.227550731081078e-06
#
#
# Iteration: 35
# quick_sort Theta 0.09476130158047028
# Less than two values for merge_sort
# merge_sort Theta 0.762619386803735
# heap_sort Theta 0.23744835043262083
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09625890000000936
# Sample mean is:  0.0959387892857129 Sample variance is: 6.008933422356497e-06
#
#
# Iteration: 36
# quick_sort Theta 0.09333682410203287
# Less than two values for merge_sort
# merge_sort Theta 0.8887697260343714
# heap_sort Theta 0.21709268018222344
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09352410000002465
# Sample mean is:  0.09585552413793054 Sample variance is: 5.995855196971666e-06
#
#
# Iteration: 37
# quick_sort Theta 0.09574602534048131
# Less than two values for merge_sort
# merge_sort Theta 0.925743939842407
# heap_sort Theta 0.21217861463316726
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09761290000000145
# Sample mean is:  0.0959141033333329 Sample variance is: 5.89550749895827e-06
#
#
# Iteration: 38
# quick_sort Theta 0.09737396501906496
# Less than two values for merge_sort
# merge_sort Theta 0.5693947140864433
# heap_sort Theta 0.21661665875678443
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09310840000000553
# Sample mean is:  0.09582359677419332 Sample variance is: 5.95107295512021e-06
#
#
# Iteration: 39
# quick_sort Theta 0.09977220313418479
# Less than two values for merge_sort
# merge_sort Theta 0.8075438554467244
# heap_sort Theta 0.22198346873164987
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09709890000004862
# Sample mean is:  0.0958634500000013 Sample variance is: 5.814338593099055e-06
#
#
# Iteration: 40
# quick_sort Theta 0.09572254227936246
# Less than two values for merge_sort
# merge_sort Theta 0.5213409105107686
# heap_sort Theta 0.2198071674376128
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09224409999995942
# Sample mean is:  0.09575377272727276 Sample variance is: 6.0230778474217654e-06
#
#
# Iteration: 41
# quick_sort Theta 0.0963523134622245
# Less than two values for merge_sort
# merge_sort Theta 0.05031075482678016
# heap_sort Theta 0.23032339836672105
#
#
# Chosen algorithm is:  merge_sort with reward: 0.1059280000000058
# Sample mean is:  0.10464010000001167 Sample variance is: 1.6586864099848654e-06
#
#
# Iteration: 42
# quick_sort Theta 0.09673538145646211
# merge_sort Theta 0.1120407194696669
# heap_sort Theta 0.2188608873677862
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09713920000001508
# Sample mean is:  0.09579452058823576 Sample variance is: 5.90072130867919e-06
#
#
# Iteration: 43
# quick_sort Theta 0.09364783435948602
# merge_sort Theta 0.10646114603063367
# heap_sort Theta 0.22353731372626287
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09319709999999759
# Sample mean is:  0.09572030857142895 Sample variance is: 5.919381668198494e-06
#
#
# Iteration: 44
# quick_sort Theta 0.09415955733307546
# merge_sort Theta 0.1094151635868928
# heap_sort Theta 0.22965789044327395
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09616379999999936
# Sample mean is:  0.09573262777777813 Sample variance is: 5.760266099215e-06
#
#
# Iteration: 45
# quick_sort Theta 0.09486825223763483
# merge_sort Theta 0.11055124928762745
# heap_sort Theta 0.21528817211598872
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09631589999997914
# Sample mean is:  0.09574839189189167 Sample variance is: 5.613529494244901e-06
#
#
# Iteration: 46
# quick_sort Theta 0.09555681699965794
# merge_sort Theta 0.11156275678535808
# heap_sort Theta 0.22335183589904092
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09283209999995279
# Sample mean is:  0.0956716473684196 Sample variance is: 5.683724743539407e-06
#
#
# Iteration: 47
# quick_sort Theta 0.09672856709873622
# merge_sort Theta 0.09057542663889073
# heap_sort Theta 0.228994511877185
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10403179999997292
# Sample mean is:  0.10443733333333209 Sample variance is: 1.1880195822226096e-06
#
#
# Iteration: 48
# quick_sort Theta 0.09380883094026941
# merge_sort Theta 0.1080517977692424
# heap_sort Theta 0.18909266554943752
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09246130000002495
# Sample mean is:  0.09558933076923 Sample variance is: 5.795477066735189e-06
#
#
# Iteration: 49
# quick_sort Theta 0.09904667115910798
# merge_sort Theta 0.10499352301153528
# heap_sort Theta 0.23019095980475232
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09624609999997347
# Sample mean is:  0.09560574999999857 Sample variance is: 5.661104194489063e-06
#
#
# Iteration: 50
# quick_sort Theta 0.09542989113657453
# merge_sort Theta 0.1027486204553655
# heap_sort Theta 0.23523634007459374
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09654729999999745
# Sample mean is:  0.09562871463414489 Sample variance is: 5.544123459287316e-06
#
#
# Iteration: 51
# quick_sort Theta 0.09393274485787671
# merge_sort Theta 0.10833208732315285
# heap_sort Theta 0.2373612038328412
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09351820000000544
# Sample mean is:  0.095578464285713 Sample variance is: 5.515649517999063e-06
#
#
# Iteration: 52
# quick_sort Theta 0.09658991539676125
# merge_sort Theta 0.09984319081897707
# heap_sort Theta 0.22233805214783353
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09812590000001364
# Sample mean is:  0.09563770697674324 Sample variance is: 5.534785849477055e-06
#
#
# Iteration: 53
# quick_sort Theta 0.09839241084038222
# merge_sort Theta 0.10501601462237106
# heap_sort Theta 0.23586269508768246
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09917250000000877
# Sample mean is:  0.09571804318181747 Sample variance is: 5.6865132133551805e-06
#
#
# Iteration: 54
# quick_sort Theta 0.09632288247689168
# merge_sort Theta 0.10419141480898779
# heap_sort Theta 0.22620957454901688
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09295079999998279
# Sample mean is:  0.0956565488888878 Sample variance is: 5.7265343678268236e-06
#
#
# Iteration: 55
# quick_sort Theta 0.09755880602819232
# merge_sort Theta 0.10099264892094457
# heap_sort Theta 0.23263158843317305
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0971749999999929
# Sample mean is:  0.09568955869565096 Sample variance is: 5.651078620679707e-06
#
#
# Iteration: 56
# quick_sort Theta 0.09489587729840533
# merge_sort Theta 0.09975830195400628
# heap_sort Theta 0.21085037789027275
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09332349999999678
# Sample mean is:  0.09563921702127534 Sample variance is: 5.647419977577383e-06
#
#
# Iteration: 57
# quick_sort Theta 0.09420064771883963
# merge_sort Theta 0.0988234988705017
# heap_sort Theta 0.1958080667759749
# Chosen algorithm is:  quick_sort with reward: 0.09604870000003984
# Sample mean is:  0.09564774791666626 Sample variance is: 5.5331858749912225e-06
#
#
# Iteration: 58
# quick_sort Theta 0.09511050845920459
# merge_sort Theta 0.10716308549834574
# heap_sort Theta 0.21310229196344688
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09319759999999633
# Sample mean is:  0.09559774489795872 Sample variance is: 5.54027820451076e-06
#
#
# Iteration: 59
# quick_sort Theta 0.09633823256975894
# merge_sort Theta 0.1065945401858975
# heap_sort Theta 0.2183303251270001
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0973538000000076
# Sample mean is:  0.09563286599999969 Sample variance is: 5.489913739040609e-06
#
#
# Iteration: 60
# quick_sort Theta 0.09650348733763574
# merge_sort Theta 0.10905433700034087
# heap_sort Theta 0.2039861362513671
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09679540000001907
# Sample mean is:  0.0956556607843138 Sample variance is: 5.4082484812047695e-06
#
#
# Iteration: 61
# quick_sort Theta 0.09265377077130559
# merge_sort Theta 0.10902041512598497
# heap_sort Theta 0.20763507284381288
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09307849999999007
# Sample mean is:  0.09560609999999989 Sample variance is: 5.429513541152408e-06
#
#
# Iteration: 62
# quick_sort Theta 0.09658693394043552
# merge_sort Theta 0.1085038658694704
# heap_sort Theta 0.20871556420287526
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09753729999999905
# Sample mean is:  0.09564253773584892 Sample variance is: 5.396110736310384e-06
#
#
# Iteration: 63
# quick_sort Theta 0.09615072797614481
# merge_sort Theta 0.10971370677974793
# heap_sort Theta 0.2200849678608762
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09304389999999785
# Sample mean is:  0.09559441481481465 Sample variance is: 5.418920982742232e-06
#
#
# Iteration: 64
# quick_sort Theta 0.09575765824708642
# merge_sort Theta 0.1062381117751012
# heap_sort Theta 0.20881494733660935
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09552660000002788
# Sample mean is:  0.09559318181818216 Sample variance is: 5.3204772418499426e-06
#
#
# Iteration: 65
# quick_sort Theta 0.0990504669045438
# merge_sort Theta 0.10645645982411435
# heap_sort Theta 0.21348795198718812
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09312779999999066
# Sample mean is:  0.0955491571428573 Sample variance is: 5.332068181734256e-06
#
#
# Iteration: 66
# quick_sort Theta 0.09847678965829389
# merge_sort Theta 0.09879091461114174
# heap_sort Theta 0.2263666605403954
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09564979999998968
# Sample mean is:  0.09555092280701753 Sample variance is: 5.238697709830251e-06
#
#
# Iteration: 67
# quick_sort Theta 0.09448309922516161
# merge_sort Theta 0.10323158628037174
# heap_sort Theta 0.22769801943635845
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09591370000003963
# Sample mean is:  0.09555717758620756 Sample variance is: 5.1506053044976505e-06
#
#
# Iteration: 68
# quick_sort Theta 0.09519355685563624
# merge_sort Theta 0.10746314543965525
# heap_sort Theta 0.22230773422792804
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09373930000003838
# Sample mean is:  0.09552636610169622 Sample variance is: 5.1183690690181395e-06
#
#
# Iteration: 69
# quick_sort Theta 0.09722188011153506
# merge_sort Theta 0.11090414201455298
# heap_sort Theta 0.225516466613869
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0963997000000063
# Sample mean is:  0.09554092166666805 Sample variance is: 5.0455629216951465e-06
#
#
# Iteration: 70
# quick_sort Theta 0.09833074189027914
# merge_sort Theta 0.10247969647272534
# heap_sort Theta 0.24174201453973843
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09265179999999873
# Sample mean is:  0.0954935590163948 Sample variance is: 5.097442013892321e-06
#
#
# Iteration: 71
# quick_sort Theta 0.09419368543637857
# merge_sort Theta 0.10467004109644619
# heap_sort Theta 0.2161537481940744
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09874789999997802
# Sample mean is:  0.09554604838709774 Sample variance is: 5.1832883834609645e-06
#
#
# Iteration: 72
# quick_sort Theta 0.09476779429538794
# merge_sort Theta 0.10467262034399683
# heap_sort Theta 0.22249210906496839
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0971102999999971
# Sample mean is:  0.09557087777777869 Sample variance is: 5.139236880454257e-06
#
#
# Iteration: 73
# quick_sort Theta 0.09685967102215083
# merge_sort Theta 0.09444711661584866
# heap_sort Theta 0.2159328614954868
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10311130000002322
# Sample mean is:  0.10410582500000487 Sample variance is: 1.2207080118631238e-06
#
#
# Iteration: 74
# quick_sort Theta 0.09325348690389551
# merge_sort Theta 0.10401121931183724
# heap_sort Theta 0.22022269277936643
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09790570000001253
# Sample mean is:  0.09560735937500109 Sample variance is: 5.142783441158714e-06
#
#
# Iteration: 75
# quick_sort Theta 0.09351474008871745
# merge_sort Theta 0.10625385887044944
# heap_sort Theta 0.2206689839516267
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09343180000001894
# Sample mean is:  0.09557388923077059 Sample variance is: 5.135359731417965e-06
#
#
# Iteration: 76
# quick_sort Theta 0.09781739491488453
# merge_sort Theta 0.0995504828727311
# heap_sort Theta 0.23017884584320158
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09789059999997107
# Sample mean is:  0.0956089909090918 Sample variance is: 5.137639559001719e-06
#
#
# Iteration: 77
# quick_sort Theta 0.09303373352913807
# merge_sort Theta 0.102661241414228
# heap_sort Theta 0.22191827166019057
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09723040000000083
# Sample mean is:  0.09563319104477702 Sample variance is: 5.09961104498798e-06
#
#
# Iteration: 78
# quick_sort Theta 0.09536889940612728
# merge_sort Theta 0.10234271666114808
# heap_sort Theta 0.2208573459068045
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0935053000000039
# Sample mean is:  0.09560189852941271 Sample variance is: 5.090224606608943e-06
#
#
# Iteration: 79
# quick_sort Theta 0.09434414623260057
# merge_sort Theta 0.10287492467893845
# heap_sort Theta 0.23835137076164403
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09609320000004118
# Sample mean is:  0.09560901884058123 Sample variance is: 5.019900756015962e-06
#
#
# Iteration: 80
# quick_sort Theta 0.09538620842836198
# merge_sort Theta 0.09852572542461205
# heap_sort Theta 0.20916560977868048
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09280389999997851
# Sample mean is:  0.09556894571428691 Sample variance is: 5.05899191419194e-06
#
#
# Iteration: 81
# quick_sort Theta 0.09545171822339048
# merge_sort Theta 0.10004253518314382
# heap_sort Theta 0.21661600584016427
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09583859999997912
# Sample mean is:  0.09557274366197273 Sample variance is: 4.988748215413486e-06
#
#
# Iteration: 82
# quick_sort Theta 0.09588580819698053
# merge_sort Theta 0.1031446374769367
# heap_sort Theta 0.21609697528530591
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09288760000004004
# Sample mean is:  0.09553545000000144 Sample variance is: 5.018208068604199e-06
#
#
# Iteration: 83
# quick_sort Theta 0.09587462287200806
# merge_sort Theta 0.1022295754790646
# heap_sort Theta 0.21546440601069095
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09679650000003903
# Sample mean is:  0.0955527246575362 Sample variance is: 4.9709512854138685e-06
#
#
# Iteration: 84
# quick_sort Theta 0.09653321995564922
# merge_sort Theta 0.1019319648921479
# heap_sort Theta 0.22619467307824762
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09416060000000925
# Sample mean is:  0.09553391216216421 Sample variance is: 4.929611696738242e-06
#
#
# Iteration: 85
# quick_sort Theta 0.09805066098547437
# merge_sort Theta 0.1019400676602244
# heap_sort Theta 0.21852607340609764
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09700270000001865
# Sample mean is:  0.09555349600000226 Sample variance is: 4.89226451691232e-06
#
#
# Iteration: 86
# quick_sort Theta 0.09139778152300974
# merge_sort Theta 0.1052941390386641
# heap_sort Theta 0.2232777292340005
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09629749999999149
# Sample mean is:  0.09556328552631792 Sample variance is: 4.835080227285356e-06
#
#
# Iteration: 87
# quick_sort Theta 0.09531578203496498
# merge_sort Theta 0.09857340827608183
# heap_sort Theta 0.22463305358052202
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0925197000000253
# Sample mean is:  0.09552375844156087 Sample variance is: 4.891028650214051e-06
#
#
# Iteration: 88
# quick_sort Theta 0.0950796397107984
# merge_sort Theta 0.10500577983967535
# heap_sort Theta 0.21633764288799334
# Chosen algorithm is:  quick_sort with reward: 0.0983921000000123
# Sample mean is:  0.0955605320512846 Sample variance is: 4.932450129351239e-06
#
#
# Iteration: 89
# quick_sort Theta 0.09529641429223262
# merge_sort Theta 0.10676005945932876
# heap_sort Theta 0.2054761502797856
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09345810000002075
# Sample mean is:  0.09553391898734456 Sample variance is: 4.92525795520213e-06
#
#
# Iteration: 90
# quick_sort Theta 0.09574191243136342
# merge_sort Theta 0.10295297694488112
# heap_sort Theta 0.2117228409783134
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09641479999999092
# Sample mean is:  0.09554493000000264 Sample variance is: 4.873270380342859e-06
#
#
# Iteration: 91
# quick_sort Theta 0.09685974124304612
# merge_sort Theta 0.10114476871884044
# heap_sort Theta 0.22195093304030203
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0934568999999783
# Sample mean is:  0.0955191518518542 Sample variance is: 4.866267582243843e-06
#
#
# Iteration: 92
# quick_sort Theta 0.09442458082613508
# merge_sort Theta 0.10036174504000091
# heap_sort Theta 0.2203211792343235
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09597719999999299
# Sample mean is:  0.09552473780488027 Sample variance is: 4.80945028819909e-06
#
#
# Iteration: 93
# quick_sort Theta 0.0956617019514466
# merge_sort Theta 0.09686550773036683
# heap_sort Theta 0.22092018901734295
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0965296000000535
# Sample mean is:  0.0955368445783161 Sample variance is: 4.763524168972079e-06
#
#
# Iteration: 94
# quick_sort Theta 0.09542783144438065
# merge_sort Theta 0.05901271044803191
# heap_sort Theta 0.21981601080049315
#
#
# Chosen algorithm is:  merge_sort with reward: 0.102512900000022
# Sample mean is:  0.1037872400000083 Sample variance is: 1.382552018381767e-06
#
#
# Iteration: 95
# quick_sort Theta 0.09643688554429558
# merge_sort Theta 0.10527845247283271
# heap_sort Theta 0.21616970415562212
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09574939999998833
# Sample mean is:  0.09553937500000267 Sample variance is: 4.707346999727575e-06
#
#
# Iteration: 96
# quick_sort Theta 0.09411366404358283
# merge_sort Theta 0.10323795606446429
# heap_sort Theta 0.21904060115111726
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09625320000003512
# Sample mean is:  0.09554777294117953 Sample variance is: 4.657890581734433e-06
#
#
# Iteration: 97
# quick_sort Theta 0.09636568692526741
# merge_sort Theta 0.10160260160924575
# heap_sort Theta 0.2075634240357748
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09281669999995756
# Sample mean is:  0.09551601627907229 Sample variance is: 4.689450338338568e-06
#
#
# Iteration: 98
# quick_sort Theta 0.09530463048991493
# merge_sort Theta 0.10225704665703397
# heap_sort Theta 0.210489073066176
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0970998000000236
# Sample mean is:  0.09553422068965793 Sample variance is: 4.66404905888198e-06
#
#
# Iteration: 99
# quick_sort Theta 0.09829383336774661
# merge_sort Theta 0.09794477991905613
# heap_sort Theta 0.23173154843234306
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10489439999997785
# Sample mean is:  0.1039717666666699 Sample variance is: 1.322377135530998e-06
#
#
# Iteration: 100
# quick_sort Theta 0.09527502352393137
# merge_sort Theta 0.10972579072749514
# heap_sort Theta 0.21876718175026855
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09294509999995171
# Sample mean is:  0.09550479886363855 Sample variance is: 4.686359516024107e-06
#
#
# Iteration: 101
# quick_sort Theta 0.0955779599458713
# merge_sort Theta 0.10262131726432841
# heap_sort Theta 0.20500386749231453
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09644720000000007
# Sample mean is:  0.0955153876404516 Sample variance is: 4.6435705442318615e-06
#
#
# Iteration: 102
# quick_sort Theta 0.09465855125684199
# merge_sort Theta 0.10670274784780319
# heap_sort Theta 0.2451785070509697
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09541869999998198
# Sample mean is:  0.09551431333333527 Sample variance is: 4.592078034047055e-06
#
#
# Iteration: 103
# quick_sort Theta 0.09504225516265212
# merge_sort Theta 0.10733475609168522
# heap_sort Theta 0.1974243866449776
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09353390000001127
# Sample mean is:  0.09549255054945259 Sample variance is: 4.584241326677702e-06
#
#
# Iteration: 104
# quick_sort Theta 0.09596900856147841
# merge_sort Theta 0.10066426796384191
# heap_sort Theta 0.21700361523664682
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09692140000004201
# Sample mean is:  0.0955080815217416 Sample variance is: 4.556362826727156e-06
#
#
# Iteration: 105
# quick_sort Theta 0.09426445885337725
# merge_sort Theta 0.10358623964932707
# heap_sort Theta 0.22682803124659592
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09345309999997653
# Sample mean is:  0.09548598494623875 Sample variance is: 4.552289473756362e-06
#
#
# Iteration: 106
# quick_sort Theta 0.09531916718162123
# merge_sort Theta 0.10374720401127635
# heap_sort Theta 0.22378778204619623
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09730430000001888
# Sample mean is:  0.09550532872340663 Sample variance is: 4.538659761839614e-06
#
#
# Iteration: 107
# quick_sort Theta 0.09421397511694708
# merge_sort Theta 0.09923913413417979
# heap_sort Theta 0.21861511991421173
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09542420000002494
# Sample mean is:  0.09550447473684472 Sample variance is: 4.490952949472018e-06
#
#
# Iteration: 108
# quick_sort Theta 0.09556264866270707
# merge_sort Theta 0.108412532802734
# heap_sort Theta 0.21806723717425047
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09305729999999812
# Sample mean is:  0.09547898333333589 Sample variance is: 4.505904296602378e-06
#
#
# Iteration: 109
# quick_sort Theta 0.09523410865145
# merge_sort Theta 0.1064141647492538
# heap_sort Theta 0.22558118307526978
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09770689999999149
# Sample mean is:  0.0955019515463942 Sample variance is: 4.510095400852724e-06
#
#
# Iteration: 110
# quick_sort Theta 0.0960620530449701
# merge_sort Theta 0.09915057868234528
# heap_sort Theta 0.21305588766898642
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09253959999995232
# Sample mean is:  0.09547172346938969 Sample variance is: 4.552706473232252e-06
#
#
# Iteration: 111
# quick_sort Theta 0.09494113589123047
# merge_sort Theta 0.10425610264659302
# heap_sort Theta 0.2154156370762243
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0970634999999902
# Sample mean is:  0.09548780202020384 Sample variance is: 4.53205447919494e-06
#
#
# Iteration: 112
# quick_sort Theta 0.09624069585199109
# merge_sort Theta 0.10596557772682673
# heap_sort Theta 0.2140450137179511
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09299690000000282
# Sample mean is:  0.09546289300000182 Sample variance is: 4.548159403857983e-06
#
#
# Iteration: 113
# quick_sort Theta 0.09496486010978218
# merge_sort Theta 0.1035493867849054
# heap_sort Theta 0.22764135676004357
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09615320000000338
# Sample mean is:  0.09546972772277412 Sample variance is: 4.507799466169075e-06
#
#
# Iteration: 114
# quick_sort Theta 0.09606274750926423
# merge_sort Theta 0.09817848010676464
# heap_sort Theta 0.22115352538514796
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09658310000003212
# Sample mean is:  0.09548064313725704 Sample variance is: 4.4756391273623845e-06
#
#
# Iteration: 115
# quick_sort Theta 0.0937141793041489
# merge_sort Theta 0.1030097823195623
# heap_sort Theta 0.20638119638489866
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09319910000004938
# Sample mean is:  0.09545849223301231 Sample variance is: 4.482233901304272e-06
#
#
# Iteration: 116
# quick_sort Theta 0.09456829774666319
# merge_sort Theta 0.10334516765435148
# heap_sort Theta 0.21198346711797314
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09750610000003235
# Sample mean is:  0.09547818076923366 Sample variance is: 4.47906225963666e-06
#
#
# Iteration: 117
# quick_sort Theta 0.0962442387211214
# merge_sort Theta 0.09663000219251627
# heap_sort Theta 0.23233860423901226
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09319759999999633
# Sample mean is:  0.09545646095238378 Sample variance is: 4.485466570005797e-06
#
#
# Iteration: 118
# quick_sort Theta 0.09538842879909142
# merge_sort Theta 0.10489280686783535
# heap_sort Theta 0.22869333825191676
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09893669999996746
# Sample mean is:  0.0954892933962289 Sample variance is: 4.556337631375826e-06
#
#
# Iteration: 119
# quick_sort Theta 0.0948968766190317
# merge_sort Theta 0.0904109690177223
# heap_sort Theta 0.21458139525978784
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10267950000002202
# Sample mean is:  0.10378715714286305 Sample variance is: 1.3379501738505531e-06
# Iteration: 120
# quick_sort Theta 0.09755605923704364
# merge_sort Theta 0.10566656559156627
# heap_sort Theta 0.2215434883715999
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09631230000002233
# Sample mean is:  0.09549698504673164 Sample variance is: 4.520026154360441e-06
#
#
# Iteration: 121
# quick_sort Theta 0.09525702211767265
# merge_sort Theta 0.10206712598752801
# heap_sort Theta 0.21326164921146026
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0970702999999844
# Sample mean is:  0.09551155277778028 Sample variance is: 4.5008814706444645e-06
#
#
# Iteration: 122
# quick_sort Theta 0.09563910079330828
# merge_sort Theta 0.10496924027616283
# heap_sort Theta 0.233574982126532
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09294900000003281
# Sample mean is:  0.09548804311926884 Sample variance is: 4.519281016767165e-06
#
#
# Iteration: 123
# quick_sort Theta 0.09477057356905827
# merge_sort Theta 0.1026453547392299
# heap_sort Theta 0.21285846675845332
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09741839999998092
# Sample mean is:  0.0955055918181844 Sample variance is: 4.511763938753039e-06
#
#
# Iteration: 124
# quick_sort Theta 0.09763891194970839
# merge_sort Theta 0.10276779998382322
# heap_sort Theta 0.21970625448787828
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09322229999997944
# Sample mean is:  0.09548502162162399 Sample variance is: 4.517662045300998e-06
#
#
# Iteration: 125
# quick_sort Theta 0.09694555875261789
# merge_sort Theta 0.10236767123302894
# heap_sort Theta 0.2203100591930703
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09617120000001478
# Sample mean is:  0.0954911482142882 Sample variance is: 4.481492177321093e-06
#
#
# Iteration: 126
# quick_sort Theta 0.09480423402222167
# merge_sort Theta 0.10100460445989291
# heap_sort Theta 0.21280384774885155
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09305889999995998
# Sample mean is:  0.09546962389380742 Sample variance is: 4.493722148194789e-06
#
#
# Iteration: 127
# quick_sort Theta 0.09623449813028565
# merge_sort Theta 0.10742635393221182
# heap_sort Theta 0.23004861197466783
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09630329999998821
# Sample mean is:  0.09547693684210726 Sample variance is: 4.460346683910216e-06
#
#
# Iteration: 128
# quick_sort Theta 0.09622054055497814
# merge_sort Theta 0.1041752150501075
# heap_sort Theta 0.20630919677696263
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09596980000003441
# Sample mean is:  0.09548122260869792 Sample variance is: 4.423654989232614e-06
#
#
# Iteration: 129
# quick_sort Theta 0.09585590504043111
# merge_sort Theta 0.10574269654025212
# heap_sort Theta 0.21487402349221435
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09325119999999743
# Sample mean is:  0.0954619982758643 Sample variance is: 4.428021154312152e-06
#
#
# Iteration: 130
# quick_sort Theta 0.09549230824784916
# merge_sort Theta 0.10781567447693208
# heap_sort Theta 0.23238190280152368
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09582359999996015
# Sample mean is:  0.09546508888889076 Sample variance is: 4.391282838769915e-06
#
#
# Iteration: 131
# quick_sort Theta 0.09518620943991611
# merge_sort Theta 0.0939604081744294
# heap_sort Theta 0.21754976793313882
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10222690000000512
# Sample mean is:  0.10359212500000581 Sample variance is: 1.436969159351647e-06
#
#
# Iteration: 132
# quick_sort Theta 0.09534785050523419
# merge_sort Theta 0.1021154945094232
# heap_sort Theta 0.22112540639766434
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09605120000003353
# Sample mean is:  0.09547005593220553 Sample variance is: 4.35695514518143e-06
#
#
# Iteration: 133
# quick_sort Theta 0.0958357850347398
# merge_sort Theta 0.10493143208969258
# heap_sort Theta 0.22550537987708197
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09668790000000627
# Sample mean is:  0.09548028991596856 Sample variance is: 4.332700738726642e-06
#
#
# Iteration: 134
# quick_sort Theta 0.09555279737634616
# merge_sort Theta 0.10187885709192351
# heap_sort Theta 0.21786570200290345
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09309100000001536
# Sample mean is:  0.09546037916666895 Sample variance is: 4.343771013820212e-06
#
#
# Iteration: 135
# quick_sort Theta 0.09418477802756405
# merge_sort Theta 0.10528191598601981
# heap_sort Theta 0.21823761157617455
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09743680000002541
# Sample mean is:  0.09547671322314297 Sample variance is: 4.3398882479292764e-06
#
#
# Iteration: 136
# quick_sort Theta 0.09643522004207178
# merge_sort Theta 0.09685044134602962
# heap_sort Theta 0.21987201312369503
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09629990000001953
# Sample mean is:  0.09548346065574032 Sample variance is: 4.3098242628834e-06
#
#
# Iteration: 137
# quick_sort Theta 0.0955136222195597
# merge_sort Theta 0.10420163038118477
# heap_sort Theta 0.242242621892101
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09293080000003329
# Sample mean is:  0.09546270731707603 Sample variance is: 4.32733057125111e-06
#
#
# Iteration: 138
# quick_sort Theta 0.0952427820298394
# merge_sort Theta 0.10535514392681754
# heap_sort Theta 0.22301802259836834
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09804040000000214
# Sample mean is:  0.09548349516129317 Sample variance is: 4.345585283528751e-06
#
#
# Iteration: 139
# quick_sort Theta 0.09702018452340469
# merge_sort Theta 0.10183819317774113
# heap_sort Theta 0.2232028597716465
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09324029999999084
# Sample mean is:  0.09546554960000277 Sample variance is: 4.350753954344015e-06
#
#
# Iteration: 140
# quick_sort Theta 0.0955672536464289
# merge_sort Theta 0.1023647733514864
# heap_sort Theta 0.21882751494131847
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09637290000000576
# Sample mean is:  0.09547275079365358 Sample variance is: 4.3227063098051404e-06
#
#
# Iteration: 141
# quick_sort Theta 0.09840383901748691
# merge_sort Theta 0.1049023328516011
# heap_sort Theta 0.21386519095402734
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09612370000002102
# Sample mean is:  0.09547787637795568 Sample variance is: 4.291979475666809e-06
#
#
# Iteration: 142
# quick_sort Theta 0.09482828027953495
# merge_sort Theta 0.10477148799660646
# heap_sort Theta 0.20699798907525893
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09221469999999954
# Sample mean is:  0.0954523828125029 Sample variance is: 4.340988464709064e-06
#
#
# Iteration: 143
# quick_sort Theta 0.09664428813266494
# merge_sort Theta 0.10485012471779193
# heap_sort Theta 0.22286158221059021
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0982485999999767
# Sample mean is:  0.09547405891473137 Sample variance is: 4.367478627540119e-06
#
#
# Iteration: 144
# quick_sort Theta 0.09305111825715238
# merge_sort Theta 0.10104451368252812
# heap_sort Theta 0.2164654022111576
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09298350000000255
# Sample mean is:  0.09545490076923346 Sample variance is: 4.381230093618085e-06
#
#
# Iteration: 145
# quick_sort Theta 0.09568356582865718
# merge_sort Theta 0.09940792975901802
# heap_sort Theta 0.21290845211357495
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09802849999999808
# Sample mean is:  0.09547454656488816 Sample variance is: 4.397960036384416e-06
#
#
# Iteration: 146
# quick_sort Theta 0.09563529143032914
# merge_sort Theta 0.10362110582206373
# heap_sort Theta 0.21460248115187244
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09664630000003172
# Sample mean is:  0.09548342348485137 Sample variance is: 4.37496491907325e-06
#
#
# Iteration: 147
# quick_sort Theta 0.09497056826926904
# merge_sort Theta 0.10211588063992075
# heap_sort Theta 0.2163985226367957
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0935628999999949
# Sample mean is:  0.09546898345864943 Sample variance is: 4.369594341083544e-06
#
#
# Iteration: 148
# quick_sort Theta 0.09565005482107698
# merge_sort Theta 0.10132832589641246
# heap_sort Theta 0.2134563700838814
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09761380000003328
# Sample mean is:  0.09548498955224186 Sample variance is: 4.371059367358248e-06
#
#
# Iteration: 149
# quick_sort Theta 0.09475399265138627
# merge_sort Theta 0.10198800744663414
# heap_sort Theta 0.20512050429180861
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0929887000000349
# Sample mean is:  0.0954664985185218 Sample variance is: 4.384498205779095e-06
#
#
# Iteration: 150
# quick_sort Theta 0.09459751467011784
# merge_sort Theta 0.10463886970137852
# heap_sort Theta 0.2171908877634806
# Chosen algorithm is:  quick_sort with reward: 0.09648350000003347
# Sample mean is:  0.09547397647059175 Sample variance is: 4.3598084169503026e-06
#
#
# Iteration: 151
# quick_sort Theta 0.09607825936327162
# merge_sort Theta 0.10578575564873803
# heap_sort Theta 0.22309421525461026
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09289830000000165
# Sample mean is:  0.09545517591241225 Sample variance is: 4.376055692197486e-06
#
#
# Iteration: 152
# quick_sort Theta 0.09667711201609885
# merge_sort Theta 0.10481092082039654
# heap_sort Theta 0.22143804550776366
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09590140000000247
# Sample mean is:  0.09545840942029334 Sample variance is: 4.345777557234039e-06
#
#
# Iteration: 153
# quick_sort Theta 0.0971832193591071
# merge_sort Theta 0.10417432897327832
# heap_sort Theta 0.21133887006157204
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09943160000000262
# Sample mean is:  0.09548699352518333 Sample variance is: 4.427266015717335e-06
#
#
# Iteration: 154
# quick_sort Theta 0.09621880374924772
# merge_sort Theta 0.09934376415089227
# heap_sort Theta 0.21614518730044882
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09247189999996408
# Sample mean is:  0.09546545714286034 Sample variance is: 4.460113078168786e-06
#
#
# Iteration: 155
# quick_sort Theta 0.0969492756419265
# merge_sort Theta 0.10118438777890826
# heap_sort Theta 0.2214246030332294
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09651669999999513
# Sample mean is:  0.0954729127659606 Sample variance is: 4.436263154736009e-06
#
#
# Iteration: 156
# quick_sort Theta 0.0931386916277017
# merge_sort Theta 0.10287572454571103
# heap_sort Theta 0.20099466379270878
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09298009999997703
# Sample mean is:  0.09545535774648183 Sample variance is: 4.448475062868761e-06
#
#
# Iteration: 157
# quick_sort Theta 0.0949224428832057
# merge_sort Theta 0.10184233166509599
# heap_sort Theta 0.226389372417969
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09729169999997112
# Sample mean is:  0.09546819930070204 Sample variance is: 4.440783428746148e-06
#
#
# Iteration: 158
# quick_sort Theta 0.09475233823916335
# merge_sort Theta 0.10420970147758297
# heap_sort Theta 0.2189006625757329
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09334839999996802
# Sample mean is:  0.09545347847222471 Sample variance is: 4.440933154056799e-06
#
#
# Iteration: 159
# quick_sort Theta 0.09515071841442546
# merge_sort Theta 0.10654601881303337
# heap_sort Theta 0.2162251510992712
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09595100000001366
# Sample mean is:  0.09545690965517499 Sample variance is: 4.4120013432235106e-06
#
#
# Iteration: 160
# quick_sort Theta 0.09573089055021877
# merge_sort Theta 0.10068124047689546
# heap_sort Theta 0.22934820886208468
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09615430000002334
# Sample mean is:  0.09546168630137257 Sample variance is: 4.385090526531218e-06
#
#
# Iteration: 161
# quick_sort Theta 0.09559500612348773
# merge_sort Theta 0.10124991858109018
# heap_sort Theta 0.22782028049302433
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09349659999998039
# Sample mean is:  0.0954483183673495 Sample variance is: 4.381350421098302e-06
#
#
# Iteration: 162
# quick_sort Theta 0.0956281628519109
# merge_sort Theta 0.10237102845834727
# heap_sort Theta 0.22139174697419847
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09584110000002966
# Sample mean is:  0.09545097229730004 Sample variance is: 4.3527820736316364e-06
#
#
# Iteration: 163
# quick_sort Theta 0.09288659762017573
# merge_sort Theta 0.10347148742264005
# heap_sort Theta 0.22464533426689767
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09300680000001194
# Sample mean is:  0.09543456845637864 Sample variance is: 4.363393498676266e-06
#
#
# Iteration: 164
# quick_sort Theta 0.09632754112477575
# merge_sort Theta 0.10537679788269944
# heap_sort Theta 0.2047336012766733
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0964081000000192
# Sample mean is:  0.09544105866666958 Sample variance is: 4.340580510298558e-06
#
#
# Iteration: 165
# quick_sort Theta 0.09613541268033249
# merge_sort Theta 0.10662448206337236
# heap_sort Theta 0.22082370618852626
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09528920000002472
# Sample mean is:  0.09544005298013551 Sample variance is: 4.311986654815913e-06
#
#
# Iteration: 166
# quick_sort Theta 0.09565633924023605
# merge_sort Theta 0.10516225184967168
# heap_sort Theta 0.21336590138214728
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09303410000001122
# Sample mean is:  0.09542422434210837 Sample variance is: 4.321450734611441e-06
#
#
# Iteration: 167
# quick_sort Theta 0.09517159452456253
# merge_sort Theta 0.10020065505590396
# heap_sort Theta 0.23211031178823063
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09701539999997522
# Sample mean is:  0.09543462418300946 Sample variance is: 4.309645775564964e-06
#
#
# Iteration: 168
# quick_sort Theta 0.09509405260952819
# merge_sort Theta 0.10353850247872658
# heap_sort Theta 0.23047526878174596
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09370389999997997
# Sample mean is:  0.09542338571428849 Sample variance is: 4.3009854491530335e-06
#
#
# Iteration: 169
# quick_sort Theta 0.09527378528384373
# merge_sort Theta 0.1051102982215357
# heap_sort Theta 0.2160694059569637
#
#
# ...
# Sample mean is:  0.06563606346652845 Sample variance is: 0.0009597810837037993
#
#
# Iteration: 1942
# quick_sort Theta 0.07040224210179716
# merge_sort Theta 0.1060949990812717
# heap_sort Theta 0.22665668256080534
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03516700000000128
# Sample mean is:  0.06562026001037362 Sample variance is: 0.0009597645386977386
#
#
# Iteration: 1943
# quick_sort Theta 0.061864108534359086
# merge_sort Theta 0.10322113095601661
# heap_sort Theta 0.2125455618834087
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03575680000005832
# Sample mean is:  0.06560477869362384 Sample variance is: 0.0009597290795890845
#
#
# Iteration: 1944
# quick_sort Theta 0.06581213130961437
# merge_sort Theta 0.10403986645442949
# heap_sort Theta 0.2216652376808797
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03522720000000845
# Sample mean is:  0.06558903901554425 Sample variance is: 0.0009597096962079386
#
#
# Iteration: 1945
# quick_sort Theta 0.064863530470728
# merge_sort Theta 0.10519326140318473
# heap_sort Theta 0.2202683160019195
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03589840000006461
# Sample mean is:  0.06557366323148651 Sample variance is: 0.0009596689752509657
#
#
# Iteration: 1946
# quick_sort Theta 0.0647084240218123
# merge_sort Theta 0.1017988014131123
# heap_sort Theta 0.21604062802625784
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03532289999998284
# Sample mean is:  0.06555800548654267 Sample variance is: 0.0009596456657489483
#
#
# Iteration: 1947
# quick_sort Theta 0.06779519600170145
# merge_sort Theta 0.10723706065568825
# heap_sort Theta 0.21929400489867099
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03520389999994222
# Sample mean is:  0.06554230237972083 Sample variance is: 0.0009596256188789959
#
#
# Iteration: 1948
# quick_sort Theta 0.0704831248652377
# merge_sort Theta 0.10560731056460763
# heap_sort Theta 0.22792312219444236
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03564400000004753
# Sample mean is:  0.06552684307135492 Sample variance is: 0.0009595913999851134
#
#
# Iteration: 1949
# quick_sort Theta 0.06854020166604685
# merge_sort Theta 0.10065332763754233
# heap_sort Theta 0.2452953431304518
#
#
# Chosen algorithm is:  quick_sort with reward: 0.037032799999906274
# Sample mean is:  0.06551211746770043 Sample variance is: 0.0009595148622582855
#
#
# Iteration: 1950
# quick_sort Theta 0.07076897560751383
# merge_sort Theta 0.10369993347428207
# heap_sort Theta 0.22924533255293073
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0362492999998949
# Sample mean is:  0.06549700237603318 Sample variance is: 0.0009594613267798388
#
#
# Iteration: 1951
# quick_sort Theta 0.061889174454521044
# merge_sort Theta 0.10656600532032778
# heap_sort Theta 0.21535319536864173
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03537529999994149
# Sample mean is:  0.06548145167785244 Sample variance is: 0.0009594341647838405
#
#
# Iteration: 1952
# quick_sort Theta 0.06885233028230604
# merge_sort Theta 0.10850462052363688
# heap_sort Theta 0.21806114784826058
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03527299999996103
# Sample mean is:  0.06546586424148614 Sample variance is: 0.0009594097300654059
#
#
# Iteration: 1953
# quick_sort Theta 0.05912444608057745
# merge_sort Theta 0.10448335815435948
# heap_sort Theta 0.20975335445893722
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03519919999996546
# Sample mean is:  0.06545025482207328 Sample variance is: 0.0009593871353202729
#
#
# Iteration: 1954
# quick_sort Theta 0.06675642992770388
# merge_sort Theta 0.10253795004671101
# heap_sort Theta 0.21989481461675878
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03607769999996435
# Sample mean is:  0.06543511432989695 Sample variance is: 0.0009593370915710569
#
#
# Iteration: 1955
# quick_sort Theta 0.06628540103642791
# merge_sort Theta 0.10589117704188197
# heap_sort Theta 0.20667438468250027
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035434800000075484
# Sample mean is:  0.06541965821741377 Sample variance is: 0.0009593062920244749
#
#
# Iteration: 1956
# quick_sort Theta 0.06761235575299203
# merge_sort Theta 0.10210047724943283
# heap_sort Theta 0.22104073753591164
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0351516000000629
# Sample mean is:  0.06540407219361494 Sample variance is: 0.0009592838292528729
#
#
# Iteration: 1957
# quick_sort Theta 0.06762007058815202
# merge_sort Theta 0.10417752735043025
# heap_sort Theta 0.21441413417812705
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03578929999991942
# Sample mean is:  0.06538883041688118 Sample variance is: 0.0009592412659595561
#
#
# Iteration: 1958
# quick_sort Theta 0.06603340967431319
# merge_sort Theta 0.10330615222744778
# heap_sort Theta 0.2257147154663345
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035204199999952834
# Sample mean is:  0.06537330334362143 Sample variance is: 0.0009592162669721484
#
#
# Iteration: 1959
# quick_sort Theta 0.06377049780075311
# merge_sort Theta 0.10186676852930292
# heap_sort Theta 0.20837642978219617
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03512540000008357
# Sample mean is:  0.06535775172236512 Sample variance is: 0.0009591932587386117
#
#
# Iteration: 1960
# quick_sort Theta 0.06005773473524043
# merge_sort Theta 0.10335680936508598
# heap_sort Theta 0.20367821248749712
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03676930000005996
# Sample mean is:  0.06534306084275449 Sample variance is: 0.0009591201273530193
#
#
# Iteration: 1961
# quick_sort Theta 0.0668178370089857
# merge_sort Theta 0.10496234172836452
# heap_sort Theta 0.2232844191172426
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03585940000004939
# Sample mean is:  0.06532791771956871 Sample variance is: 0.0009590737584031613
#
#
# Iteration: 1962
# quick_sort Theta 0.06813993480859533
# merge_sort Theta 0.1028325683384732
# heap_sort Theta 0.21873414336393818
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03511130000003959
# Sample mean is:  0.06531240610882973 Sample variance is: 0.0009590498885466897
#
#
# Iteration: 1963
# quick_sort Theta 0.062167169963462526
# merge_sort Theta 0.10381252692357457
# heap_sort Theta 0.21418828332987483
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03517469999997047
# Sample mean is:  0.06529694294510019 Sample variance is: 0.00095902360092056
#
#
# Iteration: 1964
# quick_sort Theta 0.07103816970567112
# merge_sort Theta 0.10208843228500482
# heap_sort Theta 0.21318285376312202
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03525830000000951
# Sample mean is:  0.06528153851282066 Sample variance is: 0.0009589942848902119
# Iteration: 1965
# quick_sort Theta 0.06464161696385105
# merge_sort Theta 0.10620554706862077
# heap_sort Theta 0.2294121238007944
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03513329999998405
# Sample mean is:  0.06526608580215287 Sample variance is: 0.0009589683782415856
#
#
# Iteration: 1966
# quick_sort Theta 0.0656202824112923
# merge_sort Theta 0.10378400107793688
# heap_sort Theta 0.2223292028581732
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03510819999996784
# Sample mean is:  0.0652506360655739 Sample variance is: 0.0009589427961547129
#
#
# Iteration: 1967
# quick_sort Theta 0.07317776137379753
# merge_sort Theta 0.1040974687058865
# heap_sort Theta 0.21325395873480743
#
#
# Chosen algorithm is:  quick_sort with reward: 0.036581300000079864
# Sample mean is:  0.06523595642601143 Sample variance is: 0.0009588724260465519
#
#
# Iteration: 1968
# quick_sort Theta 0.06143043628117876
# merge_sort Theta 0.1031972617447152
# heap_sort Theta 0.21365191151618662
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035167699999988145
# Sample mean is:  0.06522056837256925 Sample variance is: 0.0009588441583528557
#
#
# Iteration: 1969
# quick_sort Theta 0.06642630336765461
# merge_sort Theta 0.10285057114802329
# heap_sort Theta 0.2173960796623955
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03612909999992553
# Sample mean is:  0.06520568782608707 Sample variance is: 0.0009587863764995443
#
#
# Iteration: 1970
# quick_sort Theta 0.061988322756245495
# merge_sort Theta 0.10643217356081909
# heap_sort Theta 0.22572503953902695
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03541849999999158
# Sample mean is:  0.0651904592024541 Sample variance is: 0.000958749585376955
#
#
# Iteration: 1971
# quick_sort Theta 0.06818084404869622
# merge_sort Theta 0.09816629324731684
# heap_sort Theta 0.214367024219168
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035229899999990266
# Sample mean is:  0.06517514977005631 Sample variance is: 0.0009587181223433276
#
#
# Iteration: 1972
# quick_sort Theta 0.057876902208794094
# merge_sort Theta 0.10213575974086875
# heap_sort Theta 0.22111034346804356
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03509959999996681
# Sample mean is:  0.06515978942798784 Sample variance is: 0.0009586902156022131
#
#
# Iteration: 1973
# quick_sort Theta 0.0662009379064943
# merge_sort Theta 0.10163291639777716
# heap_sort Theta 0.2101414878232673
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035611899999935304
# Sample mean is:  0.06514470627871369 Sample variance is: 0.0009586462859844608
#
#
# Iteration: 1974
# quick_sort Theta 0.06467568533335845
# merge_sort Theta 0.10779865666479545
# heap_sort Theta 0.21827201445476907
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03518189999999777
# Sample mean is:  0.06512941913265312 Sample variance is: 0.000958614992835642
#
#
# Iteration: 1975
# quick_sort Theta 0.06565526276926884
# merge_sort Theta 0.10470853387529254
# heap_sort Theta 0.21703786333901265
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03516989999991438
# Sample mean is:  0.06511414145843958 Sample variance is: 0.0009585836313272567
#
#
# Iteration: 1976
# quick_sort Theta 0.058301569751649546
# merge_sort Theta 0.10374131840078579
# heap_sort Theta 0.22306961167813374
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03797080000003916
# Sample mean is:  0.06510030693170238 Sample variance is: 0.0009584703804806294
#
#
# Iteration: 1977
# quick_sort Theta 0.0672839159607741
# merge_sort Theta 0.10354170465364565
# heap_sort Theta 0.23286910323152188
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03528879999998935
# Sample mean is:  0.06508512022414674 Sample variance is: 0.0009584346203310732
#
#
# Iteration: 1978
# quick_sort Theta 0.06863998536799862
# merge_sort Theta 0.09824380112014373
# heap_sort Theta 0.2176911354433336
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03751379999994242
# Sample mean is:  0.06507108187372708 Sample variance is: 0.0009583334777764497
#
#
# Iteration: 1979
# quick_sort Theta 0.06505571735317187
# merge_sort Theta 0.10258302711984618
# heap_sort Theta 0.21957657216350013
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03499250000004395
# Sample mean is:  0.06505577470737915 Sample variance is: 0.0009583059598079507
#
#
# Iteration: 1980
# quick_sort Theta 0.06430018733288216
# merge_sort Theta 0.10370760903132485
# heap_sort Theta 0.2228357041816494
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0369197999999642
# Sample mean is:  0.06504146342828078 Sample variance is: 0.0009582209773314204
#
#
# Iteration: 1981
# quick_sort Theta 0.06427312830772282
# merge_sort Theta 0.10243358204765891
# heap_sort Theta 0.21895089386563196
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03510429999994358
# Sample mean is:  0.06502624372140313 Sample variance is: 0.0009581892321061798
#
#
# Iteration: 1982
# quick_sort Theta 0.06780595620517418
# merge_sort Theta 0.1034939764325902
# heap_sort Theta 0.22312789642385922
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035229800000024625
# Sample mean is:  0.0650111032520325 Sample variance is: 0.0009581532502434721
#
#
# Iteration: 1983
# quick_sort Theta 0.0711470474951639
# merge_sort Theta 0.10267144403441725
# heap_sort Theta 0.21337842565381587
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0351516000000629
# Sample mean is:  0.06499593844591164 Sample variance is: 0.0009581192146267293
#
#
# Iteration: 1984
# quick_sort Theta 0.061021336375974324
# merge_sort Theta 0.10199163685008113
# heap_sort Theta 0.2158310737479703
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035811299999977564
# Sample mean is:  0.06498112390862945 Sample variance is: 0.0009580649971392567
#
#
# Iteration: 1985
# quick_sort Theta 0.06893268127864485
# merge_sort Theta 0.1014424738015014
# heap_sort Theta 0.22117593912375877
#
#
# Chosen algorithm is:  quick_sort with reward: 0.036430600000016966
# Sample mean is:  0.06496663860984274 Sample variance is: 0.0009579922695164497
#
#
# Iteration: 1986
# quick_sort Theta 0.06770348193975007
# merge_sort Theta 0.10101138949150212
# heap_sort Theta 0.2180079709654879
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03606160000003911
# Sample mean is:  0.06495198088235297 Sample variance is: 0.0009579299395495829
#
#
# Iteration: 1987
# quick_sort Theta 0.0627450628945647
# merge_sort Theta 0.10648878273934927
# heap_sort Theta 0.2095354558489048
#
#
# Chosen algorithm is:  quick_sort with reward: 0.06421520000003511
# Sample mean is:  0.06495160745058293 Sample variance is: 0.0009574446950647283
#
#
# Iteration: 1988
# quick_sort Theta 0.0668822971678205
# merge_sort Theta 0.10474977300822719
# heap_sort Theta 0.24931651629341228
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03811870000004092
# Sample mean is:  0.06493801428571436 Sample variance is: 0.0009573242267177422
#
#
# Iteration: 1989
# quick_sort Theta 0.06798553030137049
# merge_sort Theta 0.10450880124091733
# heap_sort Theta 0.20690450349863881
#
#
# Chosen algorithm is:  quick_sort with reward: 0.039240699999936623
# Sample mean is:  0.06492500298734181 Sample variance is: 0.0009571736917199503
#
#
# Iteration: 1990
# quick_sort Theta 0.0709387943651291
# merge_sort Theta 0.10522040711520704
# heap_sort Theta 0.22084776018066987
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03589209999995546
# Sample mean is:  0.06491031022267209 Sample variance is: 0.0009571156498123306
#
#
# Iteration: 1991
# quick_sort Theta 0.07413231604224557
# merge_sort Theta 0.10236925505632116
# heap_sort Theta 0.22429158534872284
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03608150000002297
# Sample mean is:  0.06489572812341936 Sample variance is: 0.000957051696481258
#
#
# Iteration: 1992
# quick_sort Theta 0.06382627190397411
# merge_sort Theta 0.10551319591010266
# heap_sort Theta 0.22497385490686347
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03604589999997643
# Sample mean is:  0.06488114277047524 Sample variance is: 0.0009569884204960939
#
#
# Iteration: 1993
# quick_sort Theta 0.058366332305119555
# merge_sort Theta 0.102584283208862
# heap_sort Theta 0.2195619010767052
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03570279999996728
# Sample mean is:  0.0648663987872663 Sample variance is: 0.0009569348363936892
#
#
# Iteration: 1994
# quick_sort Theta 0.06530037078678133
# merge_sort Theta 0.10494254631972953
# heap_sort Theta 0.21231489569906173
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0361280000000761
# Sample mean is:  0.06485188444444448 Sample variance is: 0.0009568684442772679
#
#
# Iteration: 1995
# quick_sort Theta 0.07021751309736084
# merge_sort Theta 0.10306653994706412
# heap_sort Theta 0.22379959013745593
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03683040000009896
# Sample mean is:  0.06483773932357405 Sample variance is: 0.0009567815885371886
# Iteration: 1996
# quick_sort Theta 0.07096340433109313
# merge_sort Theta 0.1034116832468051
# heap_sort Theta 0.21411882572869398
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03576399999997193
# Sample mean is:  0.06482307043390523 Sample variance is: 0.0009567251174222769
#
#
# Iteration: 1997
# quick_sort Theta 0.06390527016143471
# merge_sort Theta 0.10235269964981948
# heap_sort Theta 0.22913061324746514
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0359581000000162
# Sample mean is:  0.06480851422087755 Sample variance is: 0.0009566626066991648
#
#
# Iteration: 1998
# quick_sort Theta 0.0682682399439687
# merge_sort Theta 0.09945209103394338
# heap_sort Theta 0.21193815920362374
#
#
# Chosen algorithm is:  quick_sort with reward: 0.035799799999949755
# Sample mean is:  0.06479389289314522 Sample variance is: 0.000956604350019797
#
#
# Iteration: 1999
# quick_sort Theta 0.06324406143367868
# merge_sort Theta 0.10670181070406162
# heap_sort Theta 0.22445725072505804
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03536410000003798
# Sample mean is:  0.06477906680100763 Sample variance is: 0.000956558542478684

# %%
sample_mean_TS_stationary, sample_count_TS_stationary,rewards_TS_stationary,cum_rewards_TS_stationary,n_TS_stationary = list_iteration_results_TS_stationary
plot_history(rewards_TS_stationary,cum_rewards_TS_stationary, sample_count_TS_stationary, sample_mean_TS_stationary)
print("Total reward", np.round(total_reward_TS_stationary,4))
# Out:
# Average rewards per algo {'quick_sort': 0.06477906680100763, 'merge_sort': 0.10359212500000581, 'heap_sort': 0.2194203714285712}
# Count per chosen algo {'quick_sort': 1985, 'merge_sort': 8, 'heap_sort': 7}
# Total reward 130.9511

# %%
array_rewards = np.array(rewards_TS_stationary)
algo = rpt.Pelt(model="rbf").fit(array_rewards)
result = algo.predict(100)
result
# Out:
# [500, 1000, 1500, 2000]

# %%
array_rewards_ma = moving_average(array_rewards, 3)
R, maxes = oncd.online_changepoint_detection(array_rewards_ma, partial(oncd.constant_hazard, 250), oncd.StudentT(0.1, .01, 1, 0))
Nw=3
for i, elem in enumerate(R[Nw,Nw:-1]):
    if elem > 0.2 and i!=0:
        print(i,elem)
        
fig, ax = plt.subplots(figsize=[18, 16])
ax = fig.add_subplot(3, 1, 1)
ax.plot(array_rewards_ma)
ax = fig.add_subplot(3, 1, 2, sharex=ax)
sparsity = 5  # only plot every fifth data for faster display
ax.pcolor(np.array(range(0, len(R[:,0]), sparsity)), 
          np.array(range(0, len(R[:,0]), sparsity)), 
          -np.log(R[0:-1:sparsity, 0:-1:sparsity]), 
          cmap=cm.Greys, vmin=0, vmax=30)
ax = fig.add_subplot(3, 1, 3, sharex=ax)
Nw=10;
ax.plot(R[Nw,Nw:-1])
# Out:
# 498 0.621880544447753
# 499 0.280715031185518
# 998 0.8131938427490619
# 1498 0.44302946778657565
# 1499 0.46614238696954524
# C:\Users\iRacheva\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Online changepoint detection: Bayesian Online change detection algorithm (https://arxiv.org/abs/0710.3742, https://nbviewer.jupyter.org/github/hildensia/bayesian_changepoint_detection/blob/master/Example%20Code.ipynb)

# %%
def TS_obcp(list_distributions, n_samples, var_multiplier = 5):
    # initialize
    total_reward = 0
    num_choices = len(choices)
    sample_count = [0 for i in range(num_choices)]
    sample_rewards = [0 for i in range(num_choices)]
    sample_mean = [0.0 for i in range(num_choices)]
    sample_var = [0.0 for i in range(num_choices)]
    arm_rewards = {0: [], 1:[], 2:[]}
    rewards = []
    cum_rewards = []
    var_multiplier = var_multiplier
    list_iteration_results = []

    for n, elem in enumerate(list_distributions):
        dist_type = elem
        distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
        print("\n")
        print("Iteration:", n)
        theta = {}
        for i in range(len(choices)):
            if sample_count[i] >= 2:
                theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=np.sqrt(sample_var[i]/sample_count[i])*var_multiplier)
                print(choices_names[i],"Theta", theta[i])

            else:
                print("Less than two values for",choices_names[i])
                theta[i] = uniform.rvs(loc=0, scale=1)
                print(choices_names[i],"Theta", theta[i])

        choice = np.argmin([theta[i] for i in range(len(choices))])
        alg = choices[choice]
        alg_name = choices_names[choice]
        start_time = time.perf_counter()
        sorted_dist = alg(distribion[dist_type])
        reward = ((time.perf_counter() - start_time))*(1)
        print("\n")
        print("Chosen algorithm is: ", alg_name, "with reward:", reward)
        arm_rewards[choice].append(reward)
        sample_count[choice] += 1
        sample_rewards[choice] += reward
        sample_mean[choice] = np.mean(arm_rewards[choice])
        sample_var[choice] = np.var(arm_rewards[choice]).astype('float64')
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
        total_reward += reward
        rewards.append(reward)
        cum_rewards.append(sum(rewards)/len(rewards))

        array_rewards = np.array(rewards)
        #print(array_rewards)   
        if(len(array_rewards)>4):
            array_rewards_ma = moving_average(array_rewards, 3)
            R, maxes = oncd.online_changepoint_detection(array_rewards_ma, partial(oncd.constant_hazard, 250), oncd.StudentT(0.1, .01, 1, 0))
            Nw=3
            #print("R",R)
            for i, elem in enumerate(R[Nw,Nw:-1]):
                if elem > 0.2 and i!=0:
                        print("RESTART EXPERIMENT AT ITERATION:", n)

                        list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
                        sample_count = [0 for i in range(num_choices)]
                        sample_rewards = [0 for i in range(num_choices)]
                        sample_mean = [0.0 for i in range(num_choices)]
                        sample_var = [0.0 for i in range(num_choices)]
                        arm_rewards = {0: [], 1:[], 2:[]}
                        rewards = []
                        cum_rewards = []
                        n_consecutive_list = []


    list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
    return list_iteration_results, total_reward

# %%
list_iteration_results_obcp, total_reward_obcp = TS_obcp(list_distributions=list_distributions, n_samples=n_samples)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.8200888082452084
# Less than two values for merge_sort
# merge_sort Theta 0.5820789704951671
# Less than two values for heap_sort
# heap_sort Theta 0.02768969293123369
#
#
# Chosen algorithm is:  heap_sort with reward: 0.2125017000000753
# Sample mean is:  0.2125017000000753 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.26409389256058147
# Less than two values for merge_sort
# merge_sort Theta 0.7463218145315923
# Less than two values for heap_sort
# heap_sort Theta 0.34588250704481194
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0931430000000546
# Sample mean is:  0.0931430000000546 Sample variance is: 0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.2724252897440381
# Less than two values for merge_sort
# merge_sort Theta 0.9955357794866952
# Less than two values for heap_sort
# heap_sort Theta 0.33362755577945924
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09953550000000178
# Sample mean is:  0.09633925000002819 Sample variance is: 1.0216014062331162e-05
#
#
# Iteration: 3
# quick_sort Theta 0.08781508494329997
# Less than two values for merge_sort
# merge_sort Theta 0.13797930917118406
# Less than two values for heap_sort
# heap_sort Theta 0.33289819992033487
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09972849999996924
# Sample mean is:  0.09746900000000853 Sample variance is: 9.363346166465322e-06
#
#
# Iteration: 4
# quick_sort Theta 0.08908019049333515
# Less than two values for merge_sort
# merge_sort Theta 0.21569723317586653
# Less than two values for heap_sort
# heap_sort Theta 0.44289177880041886
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09295259999998962
# Sample mean is:  0.09633990000000381 Sample variance is: 1.084711005488104e-05
#
#
# Iteration: 5
# quick_sort Theta 0.12442226790032374
# Less than two values for merge_sort
# merge_sort Theta 0.14513858530817159
# Less than two values for heap_sort
# heap_sort Theta 0.35614931236705716
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10172139999997398
# Sample mean is:  0.09741619999999784 Sample variance is: 1.331137480385347e-05
#
#
# Iteration: 6
# quick_sort Theta 0.10043498271161946
# Less than two values for merge_sort
# merge_sort Theta 0.4247456043864293
# Less than two values for heap_sort
# heap_sort Theta 0.9504476344676126
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09252719999994952
# Sample mean is:  0.09660136666665646 Sample variance is: 1.4412579142165746e-05
#
#
# Iteration: 7
# quick_sort Theta 0.09401033591648722
# Less than two values for merge_sort
# merge_sort Theta 0.5218481439278769
# Less than two values for heap_sort
# heap_sort Theta 0.13988053885566187
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10259930000006534
# Sample mean is:  0.09745821428571487 Sample variance is: 1.6758766318429917e-05
#
#
# Iteration: 8
# quick_sort Theta 0.11118581152048253
# Less than two values for merge_sort
# merge_sort Theta 0.4024950446150165
# Less than two values for heap_sort
# heap_sort Theta 0.48813360979808207
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09259850000000824
# Sample mean is:  0.09685075000000154 Sample variance is: 1.7247010537546604e-05
#
#
# Iteration: 9
# quick_sort Theta 0.0993372038483053
# Less than two values for merge_sort
# merge_sort Theta 0.84696839969465
# Less than two values for heap_sort
# heap_sort Theta 0.8162677096591965
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10163860000000113
# Sample mean is:  0.09738273333333483 Sample variance is: 1.759472616892993e-05
#
#
# Iteration: 10
# quick_sort Theta 0.09814473615895769
# Less than two values for merge_sort
# merge_sort Theta 0.8433853872074157
# Less than two values for heap_sort
# heap_sort Theta 0.8573721119279152
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09836400000006051
# Sample mean is:  0.0974808600000074 Sample variance is: 1.592191313644736e-05
#
#
# Iteration: 11
# quick_sort Theta 0.0973314130175711
# Less than two values for merge_sort
# merge_sort Theta 0.40561172946114843
# Less than two values for heap_sort
# heap_sort Theta 0.4595730177368885
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0941298000000188
# Sample mean is:  0.09717621818182662 Sample variance is: 1.540253286152434e-05
#
#
# Iteration: 12
# quick_sort Theta 0.0960280199054015
# Less than two values for merge_sort
# merge_sort Theta 0.33947545667969037
# Less than two values for heap_sort
# heap_sort Theta 0.39904545861050456
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09671869999999672
# Sample mean is:  0.09713809166667413 Sample variance is: 1.4134978399131717e-05
#
#
# Iteration: 13
# quick_sort Theta 0.08915974085140074
# Less than two values for merge_sort
# merge_sort Theta 0.25621204628408467
# Less than two values for heap_sort
# heap_sort Theta 0.23507790719320687
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09556640000005245
# Sample mean is:  0.09701719230770323 Sample variance is: 1.3223072228424165e-05
#
#
# Iteration: 14
# quick_sort Theta 0.09632550462382194
# Less than two values for merge_sort
# merge_sort Theta 0.03386230529619583
# Less than two values for heap_sort
# heap_sort Theta 0.49956956437939704
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10325850000003811
# Sample mean is:  0.10325850000003811 Sample variance is: 0.0
#
#
# Iteration: 15
# quick_sort Theta 0.09120260306917595
# Less than two values for merge_sort
# merge_sort Theta 0.746729987321403
# Less than two values for heap_sort
# heap_sort Theta 0.09515503455200991
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0958663000000115
# Sample mean is:  0.09693498571429668 Sample variance is: 1.2366420081244643e-05
#
#
# Iteration: 16
# quick_sort Theta 0.09599852524059549
# Less than two values for merge_sort
# merge_sort Theta 0.030120998257529452
# Less than two values for heap_sort
# heap_sort Theta 0.4908978271951464
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10559169999999085
# Sample mean is:  0.10442510000001448 Sample variance is: 1.3609555599448661e-06
#
#
# Iteration: 17
# quick_sort Theta 0.09404901800681965
# merge_sort Theta 0.10368787577268299
# Less than two values for heap_sort
# heap_sort Theta 0.3735033536943828
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09283619999996517
# Sample mean is:  0.09666173333334124 Sample variance is: 1.2587328167597717e-05
#
#
# Iteration: 18
# quick_sort Theta 0.091379957299247
# merge_sort Theta 0.10973290610524514
# Less than two values for heap_sort
# heap_sort Theta 0.8142324847370093
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09672220000004472
# Sample mean is:  0.09666551250001021 Sample variance is: 1.1800834388633538e-05
#
#
# Iteration: 19
# quick_sort Theta 0.09738730145511595
# merge_sort Theta 0.09950277711833991
# Less than two values for heap_sort
# heap_sort Theta 0.7815300667899208
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09718199999997523
# Sample mean is:  0.09669589411765521 Sample variance is: 1.1121436342942022e-05
#
#
# Iteration: 20
# quick_sort Theta 0.09746775313987877
# merge_sort Theta 0.09928338424960566
# Less than two values for heap_sort
# heap_sort Theta 0.8655738482229678
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0938611999999921
# Sample mean is:  0.09653841111111837 Sample variance is: 1.0925194023248129e-05
#
#
# Iteration: 21
# quick_sort Theta 0.0906147041534999
# merge_sort Theta 0.10401314713559906
# Less than two values for heap_sort
# heap_sort Theta 0.9955673688081118
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09665780000000268
# Sample mean is:  0.09654469473684912 Sample variance is: 1.0350894522640064e-05
#
#
# Iteration: 22
# quick_sort Theta 0.0900342724873168
# merge_sort Theta 0.10257126129569705
# Less than two values for heap_sort
# heap_sort Theta 0.9434434928798804
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09347730000001775
# Sample mean is:  0.09639132500000755 Sample variance is: 1.028027304390625e-05
#
#
# Iteration: 23
# quick_sort Theta 0.10247755280641353
# merge_sort Theta 0.08721629919257931
# Less than two values for heap_sort
# heap_sort Theta 0.655261613856735
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10362099999997554
# Sample mean is:  0.10415706666666817 Sample variance is: 1.0509874421993837e-06
#
#
# Iteration: 24
# quick_sort Theta 0.09317851626533682
# merge_sort Theta 0.10867462761130357
# Less than two values for heap_sort
# heap_sort Theta 0.35497669504986606
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09690860000000612
# Sample mean is:  0.09641595714286463 Sample variance is: 9.802871081526294e-06
#
#
# Iteration: 25
# quick_sort Theta 0.09937425765189047
# merge_sort Theta 0.105063546143001
# Less than two values for heap_sort
# heap_sort Theta 0.45328022757849395
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09310609999999997
# Sample mean is:  0.09626550909091623 Sample variance is: 9.832612975402404e-06
#
#
# Iteration: 26
# quick_sort Theta 0.09745152442808593
# merge_sort Theta 0.10370988529868978
# Less than two values for heap_sort
# heap_sort Theta 0.9645363535359459
# Chosen algorithm is:  quick_sort with reward: 0.09656429999995453
# Sample mean is:  0.09627850000000486 Sample variance is: 9.40882086524526e-06
#
#
# Iteration: 27
# quick_sort Theta 0.09298587646442365
# merge_sort Theta 0.09500590536958281
# Less than two values for heap_sort
# heap_sort Theta 0.5736579270329595
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0938108000000284
# Sample mean is:  0.09617567916667251 Sample variance is: 9.259945509171377e-06
#
#
# Iteration: 28
# quick_sort Theta 0.09323021316316035
# merge_sort Theta 0.10453271140518604
# Less than two values for heap_sort
# heap_sort Theta 0.9085152885775558
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09638670000003913
# Sample mean is:  0.09618412000000717 Sample variance is: 8.891257632821727e-06
#
#
# Iteration: 29
# quick_sort Theta 0.09771714921822575
# merge_sort Theta 0.10624460669146445
# Less than two values for heap_sort
# heap_sort Theta 0.614321955654021
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09755059999997684
# Sample mean is:  0.09623667692308292 Sample variance is: 8.61834193948528e-06
#
#
# Iteration: 30
# quick_sort Theta 0.09491656258250208
# merge_sort Theta 0.09920184267362038
# Less than two values for heap_sort
# heap_sort Theta 0.47811517840383255
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0925045000000182
# Sample mean is:  0.0960984481481546 Sample variance is: 8.795931139547528e-06
#
#
# Iteration: 31
# quick_sort Theta 0.09915866069480718
# merge_sort Theta 0.11119452074395696
# Less than two values for heap_sort
# heap_sort Theta 0.3943215550319047
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09563939999998183
# Sample mean is:  0.09608205357143415 Sample variance is: 8.489047859644302e-06
#
#
# Iteration: 32
# quick_sort Theta 0.09587374951428382
# merge_sort Theta 0.10812741904233286
# Less than two values for heap_sort
# heap_sort Theta 0.6839768432109856
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09609010000008311
# Sample mean is:  0.09608233103449101 Sample variance is: 8.196324226981647e-06
#
#
# Iteration: 33
# quick_sort Theta 0.09671598267686915
# merge_sort Theta 0.10781261430845496
# Less than two values for heap_sort
# heap_sort Theta 0.7682679466592692
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09464680000007775
# Sample mean is:  0.09603448000001057 Sample variance is: 7.989515342940198e-06
#
#
# Iteration: 34
# quick_sort Theta 0.09336559379044108
# merge_sort Theta 0.10354878536347262
# Less than two values for heap_sort
# heap_sort Theta 0.4480443378160107
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09584069999993972
# Sample mean is:  0.09602822903226635 Sample variance is: 7.732961279487208e-06
#
#
# Iteration: 35
# quick_sort Theta 0.09474776654252179
# merge_sort Theta 0.09844460112861228
# Less than two values for heap_sort
# heap_sort Theta 0.745367998914316
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09650950000002467
# Sample mean is:  0.09604326875000879 Sample variance is: 7.4983182259061815e-06
#
#
# Iteration: 36
# quick_sort Theta 0.09511537386278537
# merge_sort Theta 0.1117737551332541
# Less than two values for heap_sort
# heap_sort Theta 0.7189353220078586
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0936464999999771
# Sample mean is:  0.09597063939394723 Sample variance is: 7.439897209066152e-06
#
#
# Iteration: 37
# quick_sort Theta 0.09811714758849047
# merge_sort Theta 0.10687404114336961
# Less than two values for heap_sort
# heap_sort Theta 0.6815058169051386
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09481600000003709
# Sample mean is:  0.0959366794117734 Sample variance is: 7.259134955762289e-06
#
#
# Iteration: 38
# quick_sort Theta 0.09494795690495901
# merge_sort Theta 0.10743057001414207
# Less than two values for heap_sort
# heap_sort Theta 0.2085996592907925
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09807769999997618
# Sample mean is:  0.0959978514285792 Sample variance is: 7.178959631646368e-06
#
#
# Iteration: 39
# quick_sort Theta 0.0928875874811719
# merge_sort Theta 0.11823040957098226
# Less than two values for heap_sort
# heap_sort Theta 0.22551462857068283
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09410200000002078
# Sample mean is:  0.09594518888889701 Sample variance is: 7.0766110943250505e-06
#
#
# Iteration: 40
# quick_sort Theta 0.0963229651556883
# merge_sort Theta 0.10672199824578968
# Less than two values for heap_sort
# heap_sort Theta 0.6896550887477958
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09646049999992101
# Sample mean is:  0.09595911621622198 Sample variance is: 6.892334271089978e-06
#
#
# Iteration: 41
# quick_sort Theta 0.09103864238901287
# merge_sort Theta 0.09580806127542778
# Less than two values for heap_sort
# heap_sort Theta 0.1924841896216335
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09905889999993178
# Sample mean is:  0.09604068947368803 Sample variance is: 6.95716231777373e-06
#
#
# Iteration: 42
# quick_sort Theta 0.09266012613493395
# merge_sort Theta 0.1046810290338796
# Less than two values for heap_sort
# heap_sort Theta 0.47514023026142216
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0933025000000498
# Sample mean is:  0.09597047948718448 Sample variance is: 6.966092344178377e-06
#
#
# Iteration: 43
# quick_sort Theta 0.0960716126812727
# merge_sort Theta 0.11101134348107058
# Less than two values for heap_sort
# heap_sort Theta 0.47046415591540536
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09902150000004895
# Sample mean is:  0.0960467550000061 Sample variance is: 7.018840235965709e-06
#
#
# Iteration: 44
# quick_sort Theta 0.09404762783770501
# merge_sort Theta 0.10337982156902956
# Less than two values for heap_sort
# heap_sort Theta 0.6689481730042257
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09652540000001864
# Sample mean is:  0.09605842926829909 Sample variance is: 6.853100552305322e-06
#
#
# Iteration: 45
# quick_sort Theta 0.09602109639693443
# merge_sort Theta 0.10156934649332265
# Less than two values for heap_sort
# heap_sort Theta 0.32171542506355066
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09332439999991493
# Sample mean is:  0.09599333333333757 Sample variance is: 6.86366820222528e-06
#
#
# Iteration: 46
# quick_sort Theta 0.09595902761824932
# merge_sort Theta 0.1087421003483975
# Less than two values for heap_sort
# heap_sort Theta 0.8274034296321969
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09854040000004716
# Sample mean is:  0.09605256744186569 Sample variance is: 6.851412555226989e-06
#
#
# Iteration: 47
# quick_sort Theta 0.09662915860679908
# merge_sort Theta 0.10636089023794147
# Less than two values for heap_sort
# heap_sort Theta 0.4903208931766221
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09896870000000035
# Sample mean is:  0.0961188431818233 Sample variance is: 6.8845750029152e-06
#
#
# Iteration: 48
# quick_sort Theta 0.09884210766598615
# merge_sort Theta 0.10053722709377089
# Less than two values for heap_sort
# heap_sort Theta 0.3527834759794204
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09391379999999572
# Sample mean is:  0.09606984222222713 Sample variance is: 6.8372325851140575e-06
#
#
# Iteration: 49
# quick_sort Theta 0.09761602656794847
# merge_sort Theta 0.10472422158965464
# Less than two values for heap_sort
# heap_sort Theta 0.8399662906710729
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09479659999999512
# Sample mean is:  0.09604216304348295 Sample variance is: 6.7230732562511525e-06
#
#
# Iteration: 50
# quick_sort Theta 0.09427114569111968
# merge_sort Theta 0.10528469082757691
# Less than two values for heap_sort
# heap_sort Theta 0.044830914278836786
#
#
# Chosen algorithm is:  heap_sort with reward: 0.21323559999996178
# Sample mean is:  0.21286865000001853 Sample variance is: 1.3465230245834723e-07
#
#
# Iteration: 51
# quick_sort Theta 0.09938616127240911
# merge_sort Theta 0.11026218141701778
# heap_sort Theta 0.21336070485746303
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09395400000005338
# Sample mean is:  0.09599773404255892 Sample variance is: 6.6708302060789784e-06
#
#
# Iteration: 52
# quick_sort Theta 0.09605841901431786
# merge_sort Theta 0.1034331342507036
# heap_sort Theta 0.20273496067360294
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09456829999999172
# Sample mean is:  0.0959679541666721 Sample variance is: 6.573536104153875e-06
#
#
# Iteration: 53
# quick_sort Theta 0.09461993433340478
# merge_sort Theta 0.11571300589160054
# heap_sort Theta 0.21219384770677135
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09645499999999174
# Sample mean is:  0.09597789387755618 Sample variance is: 6.444124603027949e-06
#
#
# Iteration: 54
# quick_sort Theta 0.09547476392040322
# merge_sort Theta 0.10874550815556945
# heap_sort Theta 0.21246838721970135
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09283370000002833
# Sample mean is:  0.09591501000000563 Sample variance is: 6.5090068317012685e-06
# Iteration: 55
# quick_sort Theta 0.09669658807922386
# merge_sort Theta 0.10248477498971152
# heap_sort Theta 0.2048720614846711
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09630990000005113
# Sample mean is:  0.09592275294118298 Sample variance is: 6.384376903669756e-06
#
#
# Iteration: 56
# quick_sort Theta 0.09452814086649623
# merge_sort Theta 0.07933971554755236
# heap_sort Theta 0.2269744148067391
#
#
# Chosen algorithm is:  merge_sort with reward: 0.1058727000000772
# Sample mean is:  0.10458597500002043 Sample variance is: 1.340127656906575e-06
#
#
# Iteration: 57
# quick_sort Theta 0.09917938440855278
# merge_sort Theta 0.10078663113610903
# heap_sort Theta 0.21189421569685807
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09292500000003656
# Sample mean is:  0.09586510384616094 Sample variance is: 6.431094750752938e-06
#
#
# Iteration: 58
# quick_sort Theta 0.0929453293525202
# merge_sort Theta 0.10545133255840143
# heap_sort Theta 0.2127710401848923
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09536360000004152
# Sample mean is:  0.0958556415094417 Sample variance is: 6.314409202803158e-06
#
#
# Iteration: 59
# quick_sort Theta 0.09401838404143083
# merge_sort Theta 0.10338774192225858
# heap_sort Theta 0.22107336035053676
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09711219999996956
# Sample mean is:  0.09587891111111814 Sample variance is: 6.2261738402430965e-06
#
#
# Iteration: 60
# quick_sort Theta 0.09673040966787319
# merge_sort Theta 0.10364195608050905
# heap_sort Theta 0.21782786764647946
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09396010000000388
# Sample mean is:  0.09584402363637061 Sample variance is: 6.17869601780143e-06
#
#
# Iteration: 61
# quick_sort Theta 0.09673215287379888
# merge_sort Theta 0.10554070412897978
# heap_sort Theta 0.21314177309556065
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09463000000005195
# Sample mean is:  0.09582234464286492 Sample variance is: 6.094210992108776e-06
#
#
# Iteration: 62
# quick_sort Theta 0.0964150142939686
# merge_sort Theta 0.09270969815098863
# heap_sort Theta 0.19752204741317522
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10557540000002064
# Sample mean is:  0.10478386000002046 Sample variance is: 1.2287360184253266e-06
#
#
# Iteration: 63
# quick_sort Theta 0.09552577095766208
# merge_sort Theta 0.10716071513106579
# heap_sort Theta 0.2073553320550584
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09343780000006063
# Sample mean is:  0.0957805105263245 Sample variance is: 6.085300234967284e-06
#
#
# Iteration: 64
# quick_sort Theta 0.09267482334376625
# merge_sort Theta 0.1039278432304961
# heap_sort Theta 0.21181177903081672
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09497010000006867
# Sample mean is:  0.09576653793104423 Sample variance is: 5.9915095702742616e-06
#
#
# Iteration: 65
# quick_sort Theta 0.10064457919808308
# merge_sort Theta 0.10001066184956665
# heap_sort Theta 0.2148577122489497
#
#
# Chosen algorithm is:  merge_sort with reward: 0.10587310000005346
# Sample mean is:  0.10496540000002597 Sample variance is: 1.1887305400310863e-06
#
#
# Iteration: 66
# quick_sort Theta 0.095637823210779
# merge_sort Theta 0.11089575415926507
# heap_sort Theta 0.20354865003463413
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09346719999996367
# Sample mean is:  0.09572756610170388 Sample variance is: 5.978049162572325e-06
#
#
# Iteration: 67
# quick_sort Theta 0.0943002158809973
# merge_sort Theta 0.10549207042689196
# heap_sort Theta 0.21417817986522694
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09585170000002563
# Sample mean is:  0.09572963500000924 Sample variance is: 5.878667549934463e-06
#
#
# Iteration: 68
# quick_sort Theta 0.09477576472150404
# merge_sort Theta 0.10390187194954358
# heap_sort Theta 0.21380774941175226
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09692050000001018
# Sample mean is:  0.09574915737705844 Sample variance is: 5.805163343094268e-06
#
#
# Iteration: 69
# quick_sort Theta 0.09698241930074977
# merge_sort Theta 0.10607733360774467
# heap_sort Theta 0.21290362539209065
#
#
# Chosen algorithm is:  quick_sort with reward: 0.093660899999918
# Sample mean is:  0.0957154758064594 Sample variance is: 5.780733016349269e-06
#
#
# Iteration: 70
# quick_sort Theta 0.09640484297896408
# merge_sort Theta 0.112753321555047
# heap_sort Theta 0.21328797103479016
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09511939999993047
# Sample mean is:  0.09570601428572084 Sample variance is: 5.6945256126536295e-06
#
#
# Iteration: 71
# quick_sort Theta 0.09156023144861652
# merge_sort Theta 0.10644029857112323
# heap_sort Theta 0.21255998460069286
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09786550000001171
# Sample mean is:  0.09573975625000664 Sample variance is: 5.6772754196493386e-06
#
#
# Iteration: 72
# quick_sort Theta 0.09467751610541414
# merge_sort Theta 0.10269483188903167
# heap_sort Theta 0.2144123426761861
#
#
# Chosen algorithm is:  quick_sort with reward: 0.1040979999999081
# Sample mean is:  0.09586834461538973 Sample variance is: 6.648170654446941e-06
#
#
# Iteration: 73
# quick_sort Theta 0.09466123759822308
# merge_sort Theta 0.10399393909790591
# heap_sort Theta 0.21221369566433002
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09772810000004029
# Sample mean is:  0.09589652272727837 Sample variance is: 6.599051185370813e-06
#
#
# Iteration: 74
# quick_sort Theta 0.09842078245125828
# merge_sort Theta 0.10377674852263541
# heap_sort Theta 0.21588841662127675
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09648830000003272
# Sample mean is:  0.09590535522388666 Sample variance is: 6.505706741854742e-06
#
#
# Iteration: 75
# quick_sort Theta 0.09648211080049765
# merge_sort Theta 0.10258060094288059
# heap_sort Theta 0.21243167283061412
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09373849999997219
# Sample mean is:  0.09587348970588791 Sample variance is: 6.4780671367872765e-06
#
#
# Iteration: 76
# quick_sort Theta 0.09637350542700833
# merge_sort Theta 0.10608861275905491
# heap_sort Theta 0.21247342559026225
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09446129999992081
# Sample mean is:  0.09585302318841013 Sample variance is: 6.4126658327807985e-06
#
#
# Iteration: 77
# quick_sort Theta 0.09680007959080793
# merge_sort Theta 0.09980446498090913
# heap_sort Theta 0.21786228592450133
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09714680000001863
# Sample mean is:  0.09587150571429025 Sample variance is: 6.344626980524676e-06
#
#
# Iteration: 78
# quick_sort Theta 0.09552559174638445
# merge_sort Theta 0.10450249784349441
# heap_sort Theta 0.21633333066027005
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09271679999994831
# Sample mean is:  0.09582707323944037 Sample variance is: 6.393463174627011e-06
#
#
# Iteration: 79
# quick_sort Theta 0.09853257404772055
# merge_sort Theta 0.10377213252104082
# heap_sort Theta 0.2048318235374028
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09575619999998253
# Sample mean is:  0.09582608888889234 Sample variance is: 6.304733870145513e-06
#
#
# Iteration: 80
# quick_sort Theta 0.09582808933974914
# merge_sort Theta 0.104961609618767
# heap_sort Theta 0.21396754055866382
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09623479999993378
# Sample mean is:  0.09583168767123537 Sample variance is: 6.2206245909344356e-06
#
#
# Iteration: 81
# quick_sort Theta 0.09749318594374033
# merge_sort Theta 0.10716270058075969
# heap_sort Theta 0.1926332983657017
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09313910000003034
# Sample mean is:  0.09579530135135422 Sample variance is: 6.2332114885003585e-06
#
#
# Iteration: 82
# quick_sort Theta 0.09540008013622522
# merge_sort Theta 0.10638395543510619
# heap_sort Theta 0.21099031795427184
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09543250000001535
# Sample mean is:  0.09579046400000303 Sample variance is: 6.1518335996260375e-06
#
#
# Iteration: 83
# quick_sort Theta 0.0957662450051781
# merge_sort Theta 0.10344025150412661
# heap_sort Theta 0.2125347622602381
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09962689999997565
# Sample mean is:  0.09584094342105531 Sample variance is: 6.2620013169165265e-06
#
#
# Iteration: 84
# quick_sort Theta 0.0957265891980982
# merge_sort Theta 0.10742542329261642
# heap_sort Theta 0.21669683143161958
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09353390000001127
# Sample mean is:  0.0958109818181846 Sample variance is: 6.248901645629243e-06
#
#
# Iteration: 85
# quick_sort Theta 0.09623926390336385
# merge_sort Theta 0.10477041890782497
# heap_sort Theta 0.20190477837350126
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09629600000005212
# Sample mean is:  0.09581720000000342 Sample variance is: 6.171764787422479e-06
#
#
# Iteration: 86
# quick_sort Theta 0.09648267502092826
# merge_sort Theta 0.10769826932996988
# heap_sort Theta 0.21372614262536982
# Chosen algorithm is:  quick_sort with reward: 0.09645030000001498
# Sample mean is:  0.0958252139240542 Sample variance is: 6.098650574856348e-06
#
#
# Iteration: 87
# quick_sort Theta 0.09651934993109175
# merge_sort Theta 0.10435432693390112
# heap_sort Theta 0.211617961438647
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09397819999992407
# Sample mean is:  0.09580212625000258 Sample variance is: 6.064527657426662e-06
#
#
# Iteration: 88
# quick_sort Theta 0.09664397308630164
# merge_sort Theta 0.10291983019618851
# heap_sort Theta 0.21193126717372626
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09580870000002051
# Sample mean is:  0.0958022074074102 Sample variance is: 5.989657472528565e-06
#
#
# Iteration: 89
# quick_sort Theta 0.0946153339743123
# merge_sort Theta 0.10081257038443812
# heap_sort Theta 0.2167475293224299
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09627690000002076
# Sample mean is:  0.09580799634146643 Sample variance is: 5.919327321563139e-06
#
#
# Iteration: 90
# quick_sort Theta 0.09486594744486654
# merge_sort Theta 0.10481285482330546
# heap_sort Theta 0.2137763233329941
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09257349999995768
# Sample mean is:  0.09576902650602656 Sample variance is: 5.972539267003032e-06
#
#
# Iteration: 91
# quick_sort Theta 0.095648820465186
# merge_sort Theta 0.10734907978195422
# heap_sort Theta 0.2121740063035796
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0961095000000114
# Sample mean is:  0.09577307976190734 Sample variance is: 5.902801206371024e-06
#
#
# Iteration: 92
# quick_sort Theta 0.09537021529553054
# merge_sort Theta 0.10524936652731749
# heap_sort Theta 0.21236781505213884
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09584970000003068
# Sample mean is:  0.0957739811764735 Sample variance is: 5.833424740346558e-06
#
#
# Iteration: 93
# quick_sort Theta 0.09411967582301517
# merge_sort Theta 0.1038733938065664
# heap_sort Theta 0.21341872043633245
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09280609999996159
# Sample mean is:  0.09573947093023498 Sample variance is: 5.866825573222593e-06
#
#
# Iteration: 94
# quick_sort Theta 0.094634726845555
# merge_sort Theta 0.10472811964855326
# heap_sort Theta 0.21311012472243945
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0955648999999994
# Sample mean is:  0.09573746436781848 Sample variance is: 5.799737057693778e-06
#
#
# Iteration: 95
# quick_sort Theta 0.09665235873044051
# merge_sort Theta 0.1058286932460287
# heap_sort Theta 0.2127717839632496
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09589059999996152
# Sample mean is:  0.09573920454545647 Sample variance is: 5.734094409749862e-06
#
#
# Iteration: 96
# quick_sort Theta 0.09824011581958834
# merge_sort Theta 0.10081850987403762
# heap_sort Theta 0.2134630993215981
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09317190000001574
# Sample mean is:  0.09571035842696837 Sample variance is: 5.742891055235008e-06
#
#
# Iteration: 97
# quick_sort Theta 0.09513025073883541
# merge_sort Theta 0.10356106560411958
# heap_sort Theta 0.1975995024041448
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09763069999996787
# Sample mean is:  0.09573169555555726 Sample variance is: 5.719600456642536e-06
#
#
# Iteration: 98
# quick_sort Theta 0.09540823648265966
# merge_sort Theta 0.10580612811545523
# heap_sort Theta 0.21266958821721363
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09562719999996716
# Sample mean is:  0.09573054725274857 Sample variance is: 5.656866378312376e-06
#
#
# Iteration: 99
# quick_sort Theta 0.09470429070021436
# merge_sort Theta 0.10700925480619583
# heap_sort Theta 0.21191296273690324
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09304899999995087
# Sample mean is:  0.09570140000000077 Sample variance is: 5.672688873476964e-06
#
#
# Iteration: 100
# quick_sort Theta 0.09503699929499376
# merge_sort Theta 0.10562952872497772
# heap_sort Theta 0.21238750799061087
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09623680000004242
# Sample mean is:  0.09570715698924853 Sample variance is: 5.61474136804174e-06
#
#
# Iteration: 101
# quick_sort Theta 0.09596298569878131
# merge_sort Theta 0.10588305283359851
# heap_sort Theta 0.2109099518249555
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09625010000002021
# Sample mean is:  0.09571293297872482 Sample variance is: 5.558112747954375e-06
#
#
# Iteration: 102
# quick_sort Theta 0.09513081462210139
# merge_sort Theta 0.10767659490123094
# heap_sort Theta 0.21172781890288522
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09357299999999213
# Sample mean is:  0.09569040736842238 Sample variance is: 5.547302191208702e-06
#
#
# Iteration: 103
# quick_sort Theta 0.09567774951394706
# merge_sort Theta 0.1049716353421449
# heap_sort Theta 0.20956964237035666
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09417880000000878
# Sample mean is:  0.09567466145833474 Sample variance is: 5.513071493409981e-06
#
#
# Iteration: 104
# quick_sort Theta 0.09594476407698238
# merge_sort Theta 0.10744666470778913
# heap_sort Theta 0.21051148525417562
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09591199999999844
# Sample mean is:  0.09567710824742405 Sample variance is: 5.456810435395494e-06
#
#
# Iteration: 105
# quick_sort Theta 0.09666084216140892
# merge_sort Theta 0.1074860356634047
# heap_sort Theta 0.21474396436604426
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0928159999999707
# Sample mean is:  0.09564791326530718 Sample variance is: 5.483806353396835e-06
#
#
# Iteration: 106
# quick_sort Theta 0.09528850872803815
# merge_sort Theta 0.10880391514592799
# heap_sort Theta 0.2113929670106088
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09623390000001564
# Sample mean is:  0.09565383232323353 Sample variance is: 5.4318478242092655e-06
#
#
# Iteration: 107
# quick_sort Theta 0.09569529141657153
# merge_sort Theta 0.09923781996991013
# heap_sort Theta 0.21217052058328786
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09560369999996965
# Sample mean is:  0.0956533310000009 Sample variance is: 5.377554227140547e-06
#
#
# Iteration: 108
# quick_sort Theta 0.09706778691280145
# merge_sort Theta 0.10467230227356839
# heap_sort Theta 0.21972379795955616
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09254180000004908
# Sample mean is:  0.0956225237623776 Sample variance is: 5.419219704978496e-06
#
#
# Iteration: 109
# quick_sort Theta 0.09524449817709
# merge_sort Theta 0.10318089333214304
# heap_sort Theta 0.2096280696730689
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10086619999992763
# Sample mean is:  0.09567393235294182 Sample variance is: 5.633017261591446e-06
#
#
# Iteration: 110
# quick_sort Theta 0.09782215145008875
# merge_sort Theta 0.10529804789348249
# heap_sort Theta 0.23658310728344228
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09762910000006286
# Sample mean is:  0.09569291456310805 Sample variance is: 5.615080852499887e-06
#
#
# Iteration: 111
# quick_sort Theta 0.09567366545794292
# merge_sort Theta 0.10382420669158623
# heap_sort Theta 0.21206112012373568
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09551399999998011
# Sample mean is:  0.09569119423077027 Sample variance is: 5.5613945234219126e-06
#
#
# Iteration: 112
# quick_sort Theta 0.09571895117688888
# merge_sort Theta 0.10594943092343598
# heap_sort Theta 0.2136933880068256
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09391200000004574
# Sample mean is:  0.095674249523811 Sample variance is: 5.538289663063421e-06
#
#
# Iteration: 113
# quick_sort Theta 0.09497567966086982
# merge_sort Theta 0.10585620122497995
# heap_sort Theta 0.2130089556383324
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09812650000003487
# Sample mean is:  0.09569738396226593 Sample variance is: 5.5422378828498214e-06
#
#
# Iteration: 114
# quick_sort Theta 0.0971818664570082
# merge_sort Theta 0.10416619392957614
# heap_sort Theta 0.2132986886971366
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09352499999999964
# Sample mean is:  0.09567708130841299 Sample variance is: 5.5341342289903875e-06
#
#
# Iteration: 115
# quick_sort Theta 0.09457910306568348
# merge_sort Theta 0.10614529575034205
# heap_sort Theta 0.2137022432056562
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09679259999995793
# Sample mean is:  0.09568741018518655 Sample variance is: 5.494307614796796e-06
#
#
# Iteration: 116
# quick_sort Theta 0.09634963403505756
# merge_sort Theta 0.10648441086200437
# heap_sort Theta 0.22147939621597834
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09616930000004231
# Sample mean is:  0.09569183119266228 Sample variance is: 5.446012016084787e-06
#
#
# Iteration: 117
# quick_sort Theta 0.0941798243089165
# merge_sort Theta 0.10669715671754262
# heap_sort Theta 0.21283172417830465
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09298539999997502
# Sample mean is:  0.09566722727272876 Sample variance is: 5.462486279432927e-06
# Iteration: 118
# quick_sort Theta 0.09544743753332642
# merge_sort Theta 0.10781681724897228
# heap_sort Theta 0.21371345487731988
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09808559999999034
# Sample mean is:  0.09568901441441581 Sample variance is: 5.46548944104796e-06
#
#
# Iteration: 119
# quick_sort Theta 0.09590961412926281
# merge_sort Theta 0.1030807633189334
# heap_sort Theta 0.21360715483916434
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09702809999998863
# Sample mean is:  0.09570097053571557 Sample variance is: 5.432557749036791e-06
#
#
# Iteration: 120
# quick_sort Theta 0.09549995209177767
# merge_sort Theta 0.10873478424913129
# heap_sort Theta 0.21570488082062345
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09384660000000622
# Sample mean is:  0.09568456017699248 Sample variance is: 5.414643602567532e-06
#
#
# Iteration: 121
# quick_sort Theta 0.09553893907436374
# merge_sort Theta 0.10444568843743807
# heap_sort Theta 0.21223688821831377
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09446400000001631
# Sample mean is:  0.09567385350877339 Sample variance is: 5.3801002289727605e-06
#
#
# Iteration: 122
# quick_sort Theta 0.09649766443308451
# merge_sort Theta 0.10298075761792903
# heap_sort Theta 0.2879371769294509
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0968283000000838
# Sample mean is:  0.09568389217391521 Sample variance is: 5.34480507567342e-06
#
#
# Iteration: 123
# quick_sort Theta 0.09514280461528084
# merge_sort Theta 0.1033121326594354
# heap_sort Theta 0.21496072464975516
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09282669999993232
# Sample mean is:  0.09565926120689812 Sample variance is: 5.368497891511323e-06
#
#
# Iteration: 124
# quick_sort Theta 0.0968651708692861
# merge_sort Theta 0.0986662078940713
# heap_sort Theta 0.2127742938183377
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09449150000000373
# Sample mean is:  0.09564928034188193 Sample variance is: 5.334168943458665e-06
#
#
# Iteration: 125
# quick_sort Theta 0.09741820535675332
# merge_sort Theta 0.1080171956035503
# heap_sort Theta 0.21310851376694842
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09546550000004572
# Sample mean is:  0.0956477228813579 Sample variance is: 5.289247926848149e-06
#
#
# Iteration: 126
# quick_sort Theta 0.09721644509795278
# merge_sort Theta 0.10584972031209171
# heap_sort Theta 0.19946146907094467
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09282640000003539
# Sample mean is:  0.09562401428571653 Sample variance is: 5.3111279711377206e-06
#
#
# Iteration: 127
# quick_sort Theta 0.09506284190262468
# merge_sort Theta 0.09976161107884958
# heap_sort Theta 0.26556057407625183
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09431930000005195
# Sample mean is:  0.09561314166666932 Sample variance is: 5.28093601892677e-06
#
#
# Iteration: 128
# quick_sort Theta 0.0936429280999728
# merge_sort Theta 0.1034100727977861
# heap_sort Theta 0.21195111266863734
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09641740000006394
# Sample mean is:  0.09561978842975523 Sample variance is: 5.242593454739216e-06
#
#
# Iteration: 129
# quick_sort Theta 0.09668475133472289
# merge_sort Theta 0.10494304755705144
# heap_sort Theta 0.21304985808381735
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09374879999995755
# Sample mean is:  0.09560445245901918 Sample variance is: 5.228079609049795e-06
#
#
# Iteration: 130
# quick_sort Theta 0.0963578712389598
# merge_sort Theta 0.10578111530754367
# heap_sort Theta 0.2101259249268043
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09239919999993162
# Sample mean is:  0.09557839349593716 Sample variance is: 5.26842138272408e-06
#
#
# Iteration: 131
# quick_sort Theta 0.09476615920876477
# merge_sort Theta 0.09824594984099176
# heap_sort Theta 0.21139405557239063
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09702560000005178
# Sample mean is:  0.09559006451613164 Sample variance is: 5.242688277131279e-06
#
#
# Iteration: 132
# quick_sort Theta 0.09513351469650334
# merge_sort Theta 0.1042245004368699
# heap_sort Theta 0.213323666406149
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09316839999996773
# Sample mean is:  0.09557069120000233 Sample variance is: 5.247287117767161e-06
#
#
# Iteration: 133
# quick_sort Theta 0.09730287641534685
# merge_sort Theta 0.10407846700724006
# heap_sort Theta 0.21237781932395552
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09295819999999821
# Sample mean is:  0.09554995714285944 Sample variance is: 5.259379622612444e-06
#
#
# Iteration: 134
# quick_sort Theta 0.0958222807718329
# merge_sort Theta 0.10832631376252003
# heap_sort Theta 0.21462979527081721
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09578069999997751
# Sample mean is:  0.09555177401575013 Sample variance is: 5.218383114053834e-06
#
#
# Iteration: 135
# quick_sort Theta 0.09409840905533691
# merge_sort Theta 0.10694305373316967
# heap_sort Theta 0.2080149314111115
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09340579999991405
# Sample mean is:  0.09553500859375141 Sample variance is: 5.2133115765742724e-06
#
#
# Iteration: 136
# quick_sort Theta 0.09552178312295964
# merge_sort Theta 0.1035536248470557
# heap_sort Theta 0.21837105096697768
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09343660000001819
# Sample mean is:  0.09551874186046666 Sample variance is: 5.206767954843749e-06
#
#
# Iteration: 137
# quick_sort Theta 0.09607169131979462
# merge_sort Theta 0.10358078428515449
# heap_sort Theta 0.2125516628306947
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09783229999993637
# Sample mean is:  0.0955365384615395 Sample variance is: 5.207572645909871e-06
#
#
# Iteration: 138
# quick_sort Theta 0.09515715898684486
# merge_sort Theta 0.10324232077238717
# heap_sort Theta 0.21333897950708083
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09353520000001936
# Sample mean is:  0.09552126106870347 Sample variance is: 5.198162018106629e-06
#
#
# Iteration: 139
# quick_sort Theta 0.09650942687076641
# merge_sort Theta 0.1075182322651961
# heap_sort Theta 0.21258424266084575
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09461349999992308
# Sample mean is:  0.09551438409090968 Sample variance is: 5.164977362706438e-06
#
#
# Iteration: 140
# quick_sort Theta 0.09470610983408803
# merge_sort Theta 0.10468219189774257
# heap_sort Theta 0.1966885657031404
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09594160000006013
# Sample mean is:  0.09551759624060255 Sample variance is: 5.127504909991201e-06
#
#
# Iteration: 141
# quick_sort Theta 0.09577456611314207
# merge_sort Theta 0.10238654392970839
# heap_sort Theta 0.21224379944208133
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09269890000007308
# Sample mean is:  0.09549656119403142 Sample variance is: 5.148088881481457e-06
#
#
# Iteration: 142
# quick_sort Theta 0.0954984960343165
# merge_sort Theta 0.1065940066290872
# heap_sort Theta 0.21299745825266803
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0938071000000491
# Sample mean is:  0.0954840466666686 Sample variance is: 5.130941084712199e-06
#
#
# Iteration: 143
# quick_sort Theta 0.09558395235396247
# merge_sort Theta 0.10922786171210327
# heap_sort Theta 0.21322349010935976
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09711879999997564
# Sample mean is:  0.09549606691176644 Sample variance is: 5.112719226185032e-06
#
#
# Iteration: 144
# quick_sort Theta 0.09559562223108717
# merge_sort Theta 0.0996896665641844
# heap_sort Theta 0.21024280624159494
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09293480000008003
# Sample mean is:  0.09547737153284902 Sample variance is: 5.122934445975485e-06
#
#
# Iteration: 145
# quick_sort Theta 0.09431530040456065
# merge_sort Theta 0.10909467847501428
# heap_sort Theta 0.23008320057980589
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09507989999997335
# Sample mean is:  0.09547449130434993 Sample variance is: 5.086948245719213e-06
#
#
# Iteration: 146
# quick_sort Theta 0.09562343660032487
# merge_sort Theta 0.10733904449299467
# heap_sort Theta 0.2151062225052226
#
#
# Chosen algorithm is:  quick_sort with reward: 0.10105480000004263
# Sample mean is:  0.09551463741007434 Sample variance is: 5.272767448817286e-06
#
#
# Iteration: 147
# quick_sort Theta 0.0956669636785429
# merge_sort Theta 0.10725543858793486
# heap_sort Theta 0.2091038497943981
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09460469999999077
# Sample mean is:  0.09550813785714517 Sample variance is: 5.240976766353668e-06
#
#
# Iteration: 148
# quick_sort Theta 0.09535023895655842
# merge_sort Theta 0.10337764698374809
# heap_sort Theta 0.21330007102090537
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09458900000004178
# Sample mean is:  0.09550161914893876 Sample variance is: 5.209755816300583e-06
#
#
# Iteration: 149
# quick_sort Theta 0.0950442816747801
# merge_sort Theta 0.11191014754812866
# heap_sort Theta 0.21271356943255376
# Chosen algorithm is:  quick_sort with reward: 0.0976596000000427
# Sample mean is:  0.09551681619718597 Sample variance is: 5.205631383894385e-06
#
#
# Iteration: 150
# quick_sort Theta 0.09387136567235177
# merge_sort Theta 0.10374161499303769
# heap_sort Theta 0.21445761641984812
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09331029999998464
# Sample mean is:  0.09550138601398875 Sample variance is: 5.203037225820727e-06
#
#
# Iteration: 151
# quick_sort Theta 0.09692790377484391
# merge_sort Theta 0.10302026785795335
# heap_sort Theta 0.19528018943633335
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09367889999998624
# Sample mean is:  0.09548872986111373 Sample variance is: 5.18981050626384e-06
#
#
# Iteration: 152
# quick_sort Theta 0.09568774212277538
# merge_sort Theta 0.10619285341779813
# heap_sort Theta 0.21626091177858203
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0956784999999627
# Sample mean is:  0.09549003862069201 Sample variance is: 5.1542653603041726e-06
#
#
# Iteration: 153
# quick_sort Theta 0.09613956652362515
# merge_sort Theta 0.10566581810791571
# heap_sort Theta 0.21354294870139742
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09262360000002445
# Sample mean is:  0.09547040547945455 Sample variance is: 5.1748539069580236e-06
#
#
# Iteration: 154
# quick_sort Theta 0.09481133876850686
# merge_sort Theta 0.10441584823158574
# heap_sort Theta 0.2127564987821336
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09333860000003824
# Sample mean is:  0.09545590340136328 Sample variance is: 5.170356118424509e-06
#
#
# Iteration: 155
# quick_sort Theta 0.0956258277107873
# merge_sort Theta 0.1032962998413454
# heap_sort Theta 0.21282707834587516
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09578229999999621
# Sample mean is:  0.09545810878378648 Sample variance is: 5.136136245396489e-06
#
#
# Iteration: 156
# quick_sort Theta 0.09592118529535583
# merge_sort Theta 0.10556647037411455
# heap_sort Theta 0.21241103809204703
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09257370000000265
# Sample mean is:  0.09543875033557317 Sample variance is: 5.157128460889818e-06
#
#
# Iteration: 157
# quick_sort Theta 0.09526467808281791
# merge_sort Theta 0.1048199781252978
# heap_sort Theta 0.21483484392176092
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09330900000009024
# Sample mean is:  0.09542455200000328 Sample variance is: 5.152784921694195e-06
#
#
# Iteration: 158
# quick_sort Theta 0.09612057830474457
# merge_sort Theta 0.1042573377060622
# heap_sort Theta 0.21573856494390964
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09542030000000068
# Sample mean is:  0.09542452384106287 Sample variance is: 5.118660637178155e-06
#
#
# Iteration: 159
# quick_sort Theta 0.09520464247581212
# merge_sort Theta 0.10660652747190986
# heap_sort Theta 0.2118616604856952
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09584879999999885
# Sample mean is:  0.09542731513158219 Sample variance is: 5.086161724966599e-06
#
#
# Iteration: 160
# quick_sort Theta 0.09594781435909995
# merge_sort Theta 0.10247423518776531
# heap_sort Theta 0.2110752308883344
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0936523999999963
# Sample mean is:  0.09541571437908816 Sample variance is: 5.073374611556314e-06
#
#
# Iteration: 161
# quick_sort Theta 0.0953044561742667
# merge_sort Theta 0.10213120769356514
# heap_sort Theta 0.21369375896314075
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09318069999994805
# Sample mean is:  0.09540120129870414 Sample variance is: 5.072656934413865e-06
#
#
# Iteration: 162
# quick_sort Theta 0.09410091019775185
# merge_sort Theta 0.10735996582241347
# heap_sort Theta 0.21079104146673064
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09612189999995735
# Sample mean is:  0.09540585096774448 Sample variance is: 5.043259506498611e-06
#
#
# Iteration: 163
# quick_sort Theta 0.0954320526545113
# merge_sort Theta 0.10492035878832255
# heap_sort Theta 0.20838783163700672
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09294089999991684
# Sample mean is:  0.09539005000000199 Sample variance is: 5.049629860066343e-06
#
#
# Iteration: 164
# quick_sort Theta 0.09636245160299622
# merge_sort Theta 0.10619811333748262
# heap_sort Theta 0.2128318801671382
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0931554999999662
# Sample mean is:  0.095375817197454 Sample variance is: 5.049067948815767e-06
#
#
# Iteration: 165
# quick_sort Theta 0.09564792964104193
# merge_sort Theta 0.10406314644257941
# heap_sort Theta 0.21303653050208446
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09856549999994968
# Sample mean is:  0.09539600506329257 Sample variance is: 5.081097161114733e-06
#
#
# Iteration: 166
# quick_sort Theta 0.0959358793631505
# merge_sort Theta 0.10507069529714651
# heap_sort Theta 0.21159992470983396
#
#
# Chosen algorithm is:  quick_sort with reward: 0.09694130000002588
# Sample mean is:  0.09540572389937266 Sample variance is: 5.0640645876065145e-06
#
#
# Iteration: 167
# quick_sort Theta 0.09536103240343369
# ...
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028038400000014008
# Sample mean is:  0.027628488277510056 Sample variance is: 3.4810042462421283e-06
#
#
# Iteration: 1943
# quick_sort Theta 0.036141856446578025
# merge_sort Theta 0.028027984117849236
# heap_sort Theta 0.0656051042663146
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02855899999997291
# Sample mean is:  0.027630709069210443 Sample variance is: 3.474757901007494e-06
#
#
# Iteration: 1944
# quick_sort Theta 0.0384410851997514
# merge_sort Theta 0.026556880961784914
# heap_sort Theta 0.08108377091642449
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028244099999938044
# Sample mean is:  0.027632169523807416 Sample variance is: 3.4673783645867485e-06
#
#
# Iteration: 1945
# quick_sort Theta 0.03039216637178419
# merge_sort Theta 0.027365984762119686
# heap_sort Theta 0.06098981266953872
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028524700000048142
# Sample mean is:  0.027634289548691595 Sample variance is: 3.461030003778227e-06
#
#
# Iteration: 1946
# quick_sort Theta 0.038055702235876024
# merge_sort Theta 0.027360225639419634
# heap_sort Theta 0.07967194403949324
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027233400000000074
# Sample mean is:  0.02763333957345773 Sample variance is: 3.453208443568106e-06
# Iteration: 1947
# quick_sort Theta 0.04331292203749389
# merge_sort Theta 0.027588668292427357
# heap_sort Theta 0.07239882937867961
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02826099999992948
# Sample mean is:  0.027634823404253172 Sample variance is: 3.4459739703423867e-06
#
#
# Iteration: 1948
# quick_sort Theta 0.03946977983745616
# merge_sort Theta 0.028258512957037032
# heap_sort Theta 0.06417431324933562
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02863809999996647
# Sample mean is:  0.027637189622639287 Sample variance is: 3.440215045780209e-06
#
#
# Iteration: 1949
# quick_sort Theta 0.040777974050796285
# merge_sort Theta 0.027641199577438193
# heap_sort Theta 0.07283245412498268
#
#
# Chosen algorithm is:  merge_sort with reward: 0.030057599999963713
# Sample mean is:  0.027642884705880052 Sample variance is: 3.44587242674563e-06
#
#
# Iteration: 1950
# quick_sort Theta 0.035509948045645404
# merge_sort Theta 0.02727485303192643
# heap_sort Theta 0.06977652193333636
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02728500000000622
# Sample mean is:  0.027642044600936687 Sample variance is: 3.438083479269673e-06
#
#
# Iteration: 1951
# quick_sort Theta 0.03755984746364431
# merge_sort Theta 0.02677303033985271
# heap_sort Theta 0.06312916816263169
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027126800000019102
# Sample mean is:  0.027640837939107838 Sample variance is: 3.430652031479304e-06
#
#
# Iteration: 1952
# quick_sort Theta 0.03507176454014174
# merge_sort Theta 0.02714256519614415
# heap_sort Theta 0.0745761188326037
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02805450000005294
# Sample mean is:  0.027641804439250236 Sample variance is: 3.4230353596679606e-06
#
#
# Iteration: 1953
# quick_sort Theta 0.031743233730806446
# merge_sort Theta 0.02772971186129994
# heap_sort Theta 0.07061210168751036
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028481999999939944
# Sample mean is:  0.0276437629370607 Sample variance is: 3.4166979417177718e-06
#
#
# Iteration: 1954
# quick_sort Theta 0.04090814123109042
# merge_sort Theta 0.027826580136379557
# heap_sort Theta 0.07278470249882278
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025569600000039827
# Sample mean is:  0.027638939302323442 Sample variance is: 3.4187338694926546e-06
#
#
# Iteration: 1955
# quick_sort Theta 0.03841243576186995
# merge_sort Theta 0.027785105525822817
# heap_sort Theta 0.06844076670954025
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027971999999977015
# Sample mean is:  0.02763971206496301 Sample variance is: 3.4110585520494174e-06
#
#
# Iteration: 1956
# quick_sort Theta 0.03354647343644707
# merge_sort Theta 0.02799091211268452
# heap_sort Theta 0.07333479576032449
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02932620000001407
# Sample mean is:  0.02764361597222007 Sample variance is: 3.409731235175655e-06
#
#
# Iteration: 1957
# quick_sort Theta 0.03387215396663591
# merge_sort Theta 0.027908035630444555
# heap_sort Theta 0.08458591511810226
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02824220000002242
# Sample mean is:  0.027644998383369732 Sample variance is: 3.4026821453694897e-06
#
#
# Iteration: 1958
# quick_sort Theta 0.04579806080731508
# merge_sort Theta 0.028285462714646013
# heap_sort Theta 0.0713711648467337
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027550300000029893
# Sample mean is:  0.027644780184329778 Sample variance is: 3.3948624794140554e-06
#
#
# Iteration: 1959
# quick_sort Theta 0.04294485035823298
# merge_sort Theta 0.027952871157725954
# heap_sort Theta 0.07889676997424327
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02814910000006421
# Sample mean is:  0.027645939540228016 Sample variance is: 3.387641539899056e-06
#
#
# Iteration: 1960
# quick_sort Theta 0.04263507574453381
# merge_sort Theta 0.027618942038077077
# heap_sort Theta 0.10546559096503684
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02693910000004962
# Sample mean is:  0.027644318348622104 Sample variance is: 3.381015013920459e-06
#
#
# Iteration: 1961
# quick_sort Theta 0.03692152974750205
# merge_sort Theta 0.027316736889622294
# heap_sort Theta 0.06388615140871645
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028300899999976536
# Sample mean is:  0.027645820823796827 Sample variance is: 3.3742623776580864e-06
#
#
# Iteration: 1962
# quick_sort Theta 0.03596577264340282
# merge_sort Theta 0.027608072714577006
# heap_sort Theta 0.05995678476523551
#
#
# Chosen algorithm is:  merge_sort with reward: 0.029381400000033864
# Sample mean is:  0.027649783333331616 Sample variance is: 3.3734201298277107e-06
#
#
# Iteration: 1963
# quick_sort Theta 0.036129431920372816
# merge_sort Theta 0.02727113450217509
# heap_sort Theta 0.08641850447701054
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026616800000056173
# Sample mean is:  0.027647430296125975 Sample variance is: 3.3681609129456626e-06
#
#
# Iteration: 1964
# quick_sort Theta 0.039121775187514855
# merge_sort Theta 0.027075545601592286
# heap_sort Theta 0.07767081393178848
#
#
# Chosen algorithm is:  merge_sort with reward: 0.025637999999958083
# Sample mean is:  0.02764286340908923 Sample variance is: 3.369661986493483e-06
#
#
# Iteration: 1965
# quick_sort Theta 0.03946917339145118
# merge_sort Theta 0.028452631319250854
# heap_sort Theta 0.04566822486956699
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028088900000057038
# Sample mean is:  0.02764387482993043 Sample variance is: 3.362471137339934e-06
#
#
# Iteration: 1966
# quick_sort Theta 0.0470734332676347
# merge_sort Theta 0.02797500306226406
# heap_sort Theta 0.08079003477021092
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027402600000073107
# Sample mean is:  0.027643328959274644 Sample variance is: 3.3549951434515473e-06
#
#
# Iteration: 1967
# quick_sort Theta 0.03727044425349795
# merge_sort Theta 0.02798631986682545
# heap_sort Theta 0.0961860065827825
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026447300000086216
# Sample mean is:  0.027640629119637647 Sample variance is: 3.3506435882402036e-06
#
#
# Iteration: 1968
# quick_sort Theta 0.0392945205775888
# merge_sort Theta 0.02812790721502811
# heap_sort Theta 0.049621570727454115
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026978600000006736
# Sample mean is:  0.027639138063061904 Sample variance is: 3.3440819932945435e-06
#
#
# Iteration: 1969
# quick_sort Theta 0.0405891311637685
# merge_sort Theta 0.02724118534527427
# heap_sort Theta 0.07441061932409575
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027076999999962936
# Sample mean is:  0.027637874831459432 Sample variance is: 3.3372757171105523e-06
#
#
# Iteration: 1970
# quick_sort Theta 0.04308272578007638
# merge_sort Theta 0.02740206353434128
# heap_sort Theta 0.043179210309338925
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02793429999996988
# Sample mean is:  0.027638539461882102 Sample variance is: 3.329989607581922e-06
#
#
# Iteration: 1971
# quick_sort Theta 0.026645678844994233
# merge_sort Theta 0.028448994130196966
# heap_sort Theta 0.09599091248797344
#
#
# Chosen algorithm is:  quick_sort with reward: 0.03914190000000417
# Sample mean is:  0.03798001250000027 Sample variance is: 1.1156565774914633e-05
#
#
# Iteration: 1972
# quick_sort Theta 0.04917955914718649
# merge_sort Theta 0.028122459067272364
# heap_sort Theta 0.07207327122290211
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028352900000072623
# Sample mean is:  0.02764013758389148 Sample variance is: 3.323679047706403e-06
#
#
# Iteration: 1973
# quick_sort Theta 0.0397928574866606
# merge_sort Theta 0.027100080790626205
# heap_sort Theta 0.09336613469099177
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028462199999921722
# Sample mean is:  0.027641972544641544 Sample variance is: 3.3177652064471966e-06
#
#
# Iteration: 1974
# quick_sort Theta 0.04041199346788113
# merge_sort Theta 0.027356161674957864
# heap_sort Theta 0.08499498140624306
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02652100000000246
# Sample mean is:  0.02763947594654658 Sample variance is: 3.3131683592789745e-06
#
#
# Iteration: 1975
# quick_sort Theta 0.04989604986596441
# merge_sort Theta 0.02746008837966387
# heap_sort Theta 0.07674889460757035
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026876000000015665
# Sample mean is:  0.027637779333332068 Sample variance is: 3.3070982078084684e-06
#
#
# Iteration: 1976
# quick_sort Theta 0.039682837909019594
# merge_sort Theta 0.02800051857361079
# heap_sort Theta 0.06494914510370824
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026251600000023245
# Sample mean is:  0.027634705764965527 Sample variance is: 3.3040164659444663e-06
# Iteration: 1977
# quick_sort Theta 0.03989201561601964
# merge_sort Theta 0.027532074034193152
# heap_sort Theta 0.07017452842142023
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026861300000064148
# Sample mean is:  0.02763299469026442 Sample variance is: 3.298027122263493e-06
#
#
# Iteration: 1978
# quick_sort Theta 0.03605571273625448
# merge_sort Theta 0.02764055578928319
# heap_sort Theta 0.07364444762826412
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027146799999968607
# Sample mean is:  0.027631921412802397 Sample variance is: 3.291267379068802e-06
#
#
# Iteration: 1979
# quick_sort Theta 0.051511026646176024
# merge_sort Theta 0.02758949263375513
# heap_sort Theta 0.06359053743076076
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026170100000058483
# Sample mean is:  0.027628701541849217 Sample variance is: 3.2887144001863838e-06
#
#
# Iteration: 1980
# quick_sort Theta 0.04530052642148607
# merge_sort Theta 0.027722910053623033
# heap_sort Theta 0.06120936105982892
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02643579999994472
# Sample mean is:  0.02762607978021866 Sample variance is: 3.2846070863072633e-06
#
#
# Iteration: 1981
# quick_sort Theta 0.03663890837837421
# merge_sort Theta 0.02717235929441538
# heap_sort Theta 0.06774259479373289
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028461600000014187
# Sample mean is:  0.02762791206140242 Sample variance is: 3.278931551314725e-06
#
#
# Iteration: 1982
# quick_sort Theta 0.03640578074780358
# merge_sort Theta 0.02797406647082238
# heap_sort Theta 0.07478435086418218
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026290199999948527
# Sample mean is:  0.02762498490153053 Sample variance is: 3.2756637751899508e-06
#
#
# Iteration: 1983
# quick_sort Theta 0.036882054675186515
# merge_sort Theta 0.02716889391415304
# heap_sort Theta 0.07386579003586442
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02789189999998598
# Sample mean is:  0.02762556768558829 Sample variance is: 3.268666885104207e-06
#
#
# Iteration: 1984
# quick_sort Theta 0.034259636046098434
# merge_sort Theta 0.026548537578455985
# heap_sort Theta 0.06684830311036888
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028256100000021434
# Sample mean is:  0.027626941394334335 Sample variance is: 3.262409887166702e-06
#
#
# Iteration: 1985
# quick_sort Theta 0.036161919579597336
# merge_sort Theta 0.02787394043999124
# heap_sort Theta 0.06254091415845142
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026221000000077765
# Sample mean is:  0.027623884999998995 Sample variance is: 3.2596054615267112e-06
#
#
# Iteration: 1986
# quick_sort Theta 0.03811627159460794
# merge_sort Theta 0.027543276428749614
# heap_sort Theta 0.06960203977284778
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027931899999998677
# Sample mean is:  0.02762455314533522 Sample variance is: 3.252740086211987e-06
#
#
# Iteration: 1987
# quick_sort Theta 0.041205746718935087
# merge_sort Theta 0.027998014351516144
# heap_sort Theta 0.07353723419524634
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026272999999946478
# Sample mean is:  0.027621627705626584 Sample variance is: 3.249644852297179e-06
#
#
# Iteration: 1988
# quick_sort Theta 0.041827411001548735
# merge_sort Theta 0.026540137733696765
# heap_sort Theta 0.06380441332498173
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027941100000020924
# Sample mean is:  0.02762231771058208 Sample variance is: 3.2428461422693645e-06
#
#
# Iteration: 1989
# quick_sort Theta 0.030338187819395054
# merge_sort Theta 0.02757042741671914
# heap_sort Theta 0.07078578804988238
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028946499999960906
# Sample mean is:  0.027625171551722984 Sample variance is: 3.2396281112075966e-06
#
#
# Iteration: 1990
# quick_sort Theta 0.03731788057198158
# merge_sort Theta 0.027701209766117993
# heap_sort Theta 0.06404677422374125
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027983599999970465
# Sample mean is:  0.027625942365590184 Sample variance is: 3.2329368564972463e-06
#
#
# Iteration: 1991
# quick_sort Theta 0.03958402737394939
# merge_sort Theta 0.02772172411887322
# heap_sort Theta 0.09962277479939632
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02654810000001362
# Sample mean is:  0.027623629399140447 Sample variance is: 3.2284868871738663e-06
#
#
# Iteration: 1992
# quick_sort Theta 0.04462950305010229
# merge_sort Theta 0.028104128326716566
# heap_sort Theta 0.0796656244338811
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02688630000000103
# Sample mean is:  0.027622050535330726 Sample variance is: 3.2227352889146742e-06
#
#
# Iteration: 1993
# quick_sort Theta 0.04108911370588263
# merge_sort Theta 0.027113498497076834
# heap_sort Theta 0.0668552606792906
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02770579999992151
# Sample mean is:  0.027622229487178143 Sample variance is: 3.2158640574975437e-06
#
#
# Iteration: 1994
# quick_sort Theta 0.03606704107803971
# merge_sort Theta 0.028307585048776045
# heap_sort Theta 0.0735056817680685
#
#
# Chosen algorithm is:  merge_sort with reward: 0.027167499999904976
# Sample mean is:  0.027621259914710608 Sample variance is: 3.209447157616749e-06
#
#
# Iteration: 1995
# quick_sort Theta 0.04187819936406695
# merge_sort Theta 0.027045758930264632
# heap_sort Theta 0.06953177594169399
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026105099999995218
# Sample mean is:  0.027618034042551642 Sample variance is: 3.2074990784493353e-06
#
#
# Iteration: 1996
# quick_sort Theta 0.03854339079142129
# merge_sort Theta 0.027957385092415937
# heap_sort Theta 0.08460360826562653
#
#
# Chosen algorithm is:  merge_sort with reward: 0.026988500000015847
# Sample mean is:  0.027616697452227786 Sample variance is: 3.2015287442734377e-06
#
#
# Iteration: 1997
# quick_sort Theta 0.040602101893076996
# merge_sort Theta 0.027949922732606124
# heap_sort Theta 0.06591155474049998
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02614579999999478
# Sample mean is:  0.027613581144066274 Sample variance is: 3.199319902750084e-06
#
#
# Iteration: 1998
# quick_sort Theta 0.036443637028477485
# merge_sort Theta 0.028375418244793203
# heap_sort Theta 0.07733335917607952
#
#
# Chosen algorithm is:  merge_sort with reward: 0.028316900000049827
# Sample mean is:  0.027615068076108522 Sample variance is: 3.1935995892682425e-06
#
#
# Iteration: 1999
# quick_sort Theta 0.03303492539524295
# merge_sort Theta 0.02775138527128315
# heap_sort Theta 0.061044908121155095
#
#
# Chosen algorithm is:  merge_sort with reward: 0.02624619999994593
# Sample mean is:  0.02761218016877485 Sample variance is: 3.190806861539367e-06

# %%
for elem in list_iteration_results_obcp:
    sample_mean, sample_count,rewards,cum_rewards,n = elem
    print("Up to iteration", n)
    plot_history(rewards,cum_rewards, sample_count, sample_mean)
print("Total reward", np.round(total_reward_obcp,4))
# Out:
# Up to iteration 426
# Average rewards per algo {'quick_sort': 0.09572422211538377, 'merge_sort': 0.1051307250000093, 'heap_sort': 0.21275456666667955}
# Count per chosen algo {'quick_sort': 416, 'merge_sort': 8, 'heap_sort': 3}
# Up to iteration 1003
# Average rewards per algo {'quick_sort': 0.053480262500004094, 'merge_sort': 0.031252436729858966, 'heap_sort': 0.21337209999997717}
# Count per chosen algo {'quick_sort': 152, 'merge_sort': 422, 'heap_sort': 3}
# Up to iteration 1503
# Average rewards per algo {'quick_sort': 0.09760283197424777, 'merge_sort': 0.10949909999998145, 'heap_sort': 0.21240880000001047}
# Count per chosen algo {'quick_sort': 466, 'merge_sort': 28, 'heap_sort': 6}
# Up to iteration 1999
# Average rewards per algo {'quick_sort': 0.03798001250000027, 'merge_sort': 0.02761218016877485, 'heap_sort': 0.07449343333331626}
# Count per chosen algo {'quick_sort': 16, 'merge_sort': 474, 'heap_sort': 6}
# Total reward 127.2244
