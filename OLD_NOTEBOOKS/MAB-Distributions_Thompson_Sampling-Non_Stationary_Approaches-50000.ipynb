# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy.stats import t
from scipy.stats import uniform
from scipy.stats import ttest_1samp # library for p-value estimation
import ruptures as rpt # library for change point detection
# %matplotlib inline
# %run ./master_experminet-functions.ipynb
# load functions for the creation of the different distributions

# %%
# define arms
def quick_sort(df):
    sorted_df = df.sort_values(kind="quicksort")
    return sorted_df
def merge_sort(df):
    sorted_df = df.sort_values(kind="mergesort")
    return sorted_df
def heap_sort(df):
    sorted_df = df.sort_values(kind="heapsort")
    return sorted_df

# %%
n_samples = 50000
choices = [quick_sort,merge_sort,heap_sort]
choices_names = ["quick_sort","merge_sort","heap_sort"]
dist_types = ["Uniform","Normal","Uniform_Sorted","Uniform_Reverse_Sorted","Uniform_Nearly_Sorted","Zipf"]

# %%
#list_distributions = 1000*["Uniform_Sorted"] + 1000*["Normal"] # at first quick sort -> then merge sort 
list_distributions = 500*["Uniform"] +  500*["Uniform_Sorted"] + 500*["Normal"] + 500*["Uniform_Reverse_Sorted"]
#list_distributions = 100*["Uniform"] +  100*["Uniform_Sorted"] + 100*["Normal"] + 100*["Uniform_Reverse_Sorted"]

# %%
def plot_history(rewards,cum_rewards,sample_count, sample_mean):

    q_values = {"quick_sort": sample_mean[0], "merge_sort": sample_mean[1], "heap_sort":sample_mean[2]} ## 
    arm_counts = {"quick_sort": sample_count[0], "merge_sort": sample_count[1], "heap_sort":sample_count[2]} ##
    print("Average rewards per algo", q_values)
    print("Count per chosen algo", arm_counts)
    
    fig = plt.figure(figsize=[30,8])
    ax2 = fig.add_subplot(121)
    ax2.plot(cum_rewards, label="avg rewards")
    ax2.set_title("Cummulative Rewards")
    labels = list(arm_counts.keys())
    ax3 = fig.add_subplot(122)
    ax3.bar([i for i in range(len(arm_counts.values()))], arm_counts.values(), label=[i for i in ((list(arm_counts.keys())))])
    ax3.set_title("Chosen Actions")
    plt.show()

# %%
# help function to return the humber of consecutive elements in a list 
def count_consec(listrand):
    count=1
    consec_list=[]
    for i in range(len(listrand[:-1])):
        if listrand[i]+1 == listrand[i+1]:
            count+=1
        else:
            consec_list.append(count)
            count=1

    # Account for the last iteration
    consec_list.append(count)     

    return consec_list

# %%
def TS_stationary(list_distributions, n_samples, var_multiplier = 5): # initialize
    total_reward = 0
    num_choices = len(choices)
    sample_count = [0 for i in range(num_choices)]
    sample_rewards = [0 for i in range(num_choices)]
    sample_mean = [0.0 for i in range(num_choices)]
    sample_var = [0.0 for i in range(num_choices)]
    arm_rewards = {0: [], 1:[], 2:[]}
    rewards = []
    cum_rewards = []
    var_multiplier = 5
    list_iteration_results = []

    len_result = 1

    for n, elem in enumerate(list_distributions):
        dist_type = elem
        distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
        print("\n")
        print("Iteration:", n)
        theta = {}
        for i in range(len(choices)):
            if sample_count[i] >= 2:
                theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=np.sqrt(sample_var[i]/sample_count[i])*var_multiplier)
                print(choices_names[i],"Theta", theta[i])

            else:
                print("Less than two values for",choices_names[i])
                theta[i] = uniform.rvs(loc=0, scale=1)
                print(choices_names[i],"Theta", theta[i])

        choice = np.argmin([theta[i] for i in range(len(choices))])
        alg = choices[choice]
        alg_name = choices_names[choice]
        start_time = time.perf_counter() #time.time()
        sorted_dist = alg(distribion[dist_type])
        reward = ((time.perf_counter() - start_time))*(1)
        print("\n")
        print("Chosen algorithm is: ", alg_name, "with reward:", reward)
        arm_rewards[choice].append(reward)
        sample_count[choice] += 1
        sample_rewards[choice] += reward
        sample_mean[choice] = np.mean(arm_rewards[choice])
        sample_var[choice] = np.var(arm_rewards[choice]).astype('float64')
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
        total_reward += reward
        rewards.append(reward)
        cum_rewards.append(sum(rewards)/len(rewards))
        array_rewards = np.array(rewards)

    list_iteration_results.extend([sample_mean, sample_count,rewards,cum_rewards,n])
    return list_iteration_results, total_reward

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
import bayesian_changepoint_detection.online_changepoint_detection as oncd
from functools import partial
import matplotlib.cm as cm

# %% [markdown]
# ## Thompson Sampling

# %% [markdown]
# # Probabs sampled from t Student distribution

# %% [markdown]
# ### Quick sort should be the fastest at first 500 itreations, then merge sort for for the next 500, then again quick sort for the next 500, then again merge sort for the next 500: i.e. change points/restart experiment at iteration 500, 1000 and 1500

# %% [markdown]
# ### First Variant: One sample t-test:
# The One Sample t Test determines whether the sample mean is statistically different from a known or hypothesised population mean or in other words: the p_value is the estimated probability of achieving this value by chance from the sample set.  Generally, if we receive a p-value of less than a selected significance level, we can reject the null hypothesis and state that there is a significant difference, i.e. the sample comes from a different distribution.

# %%
def TS_ttest(list_distributions, n_samples, var_multiplier=5,p_val_multiplier=20,num_consec_elem=5):# initialize
    total_reward = 0
    num_choices = len(choices)
    sample_count = [0 for i in range(num_choices)]
    sample_rewards = [0 for i in range(num_choices)]
    sample_mean = [0.0 for i in range(num_choices)]
    sample_var = [0.0 for i in range(num_choices)]
    arm_rewards = {0: [], 1:[], 2:[]}
    rewards = []
    cum_rewards = []
    var_multiplier = var_multiplier
    n_consecutive_list = [] # this list is to check whether
    list_iteration_results = []
    p_val_multiplier = p_val_multiplier
    num_consec_elem = num_consec_elem

    for n, elem in enumerate(list_distributions):
        dist_type = elem
        distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
        print("\n")
        print("Iteration:", n)
        theta = {}
        for i in range(len(choices)):
            if sample_count[i] >= 2:
                theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=np.sqrt(sample_var[i]/sample_count[i])*var_multiplier)
                print(choices_names[i],"Theta", theta[i])

            else:
                print("Less than two values for",choices_names[i])
                theta[i] = uniform.rvs(loc=0, scale=1)
                print(choices_names[i],"Theta", theta[i])

        choice = np.argmin([theta[i] for i in range(len(choices))])
        alg = choices[choice]
        alg_name = choices_names[choice]
        start_time = time.perf_counter()
        sorted_dist = alg(distribion[dist_type])
        reward = ((time.perf_counter() - start_time))*(1)
        print("\n")
        print("Chosen algorithm is: ", alg_name, "with reward:", reward)
        arm_rewards[choice].append(reward)
        sample_count[choice] += 1
        sample_rewards[choice] += reward
        sample_mean[choice] = np.mean(arm_rewards[choice])
        sample_var[choice] = np.var(arm_rewards[choice]).astype('float64')
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
        total_reward += reward
        rewards.append(reward)
        cum_rewards.append(sum(rewards)/len(rewards))

        tset, pval = ttest_1samp(arm_rewards[choice], reward)
        print("\n")
        print("p-value: ", pval)
        print("Significance level: ", (sample_var[choice]**p_val_multiplier))

        if pval < sample_var[choice]**p_val_multiplier:
            n_consecutive_list.append(n)
            if any(i >= num_consec_elem for i in count_consec(n_consecutive_list)):
                    print("RESTART EXPERIMENT AT ITERATION:", n)

                    list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
                    sample_count = [0 for i in range(num_choices)]
                    sample_rewards = [0 for i in range(num_choices)]
                    sample_mean = [0.0 for i in range(num_choices)]
                    sample_var = [0.0 for i in range(num_choices)]
                    arm_rewards = {0: [], 1:[], 2:[]}
                    rewards = []
                    cum_rewards = []
                    n_consecutive_list = []

    list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
    return list_iteration_results, total_reward

# %%
list_iteration_results_TS_ttest, total_reward_TS_ttest = TS_ttest(list_distributions=list_distributions, n_samples=n_samples)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.04539094446825653
# Less than two values for merge_sort
# merge_sort Theta 0.8104771316852433
# Less than two values for heap_sort
# heap_sort Theta 0.14387612016055362
#
#
# Chosen algorithm is:  quick_sort with reward: 0.009883900000204449
# Sample mean is:  0.009883900000204449 Sample variance is: 0.0
#
#
# p-value:  nan
# Significance level:  0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.03686998122841978
# Less than two values for merge_sort
# merge_sort Theta 0.5411226754174537
# Less than two values for heap_sort
# heap_sort Theta 0.0072684779065788074
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011219700000310695
# Sample mean is:  0.011219700000310695 Sample variance is: 0.0
#
#
# p-value:  nan
# Significance level:  0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.8774841838503137
# Less than two values for merge_sort
# merge_sort Theta 0.32985929825523963
# Less than two values for heap_sort
# heap_sort Theta 0.8935595714251168
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0112130999996225
# Sample mean is:  0.0112130999996225 Sample variance is: 0.0
#
#
# p-value:  nan
# Significance level:  0.0
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.14036063240101293
# Less than two values for merge_sort
# merge_sort Theta 0.2487358565081954
# Less than two values for heap_sort
# heap_sort Theta 0.9147757640644444
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008015999999770429
# Sample mean is:  0.008949949999987439 Sample variance is: 8.722626029053526e-07
#
#
# p-value:  0.49999999999999956
# Significance level:  6.500474538821812e-122
#
#
# Iteration: 4
# quick_sort Theta 0.008077258964263171
# Less than two values for merge_sort
# merge_sort Theta 0.7945452268940829
# Less than two values for heap_sort
# heap_sort Theta 0.06425564596715883
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071247000000767
# Sample mean is:  0.008341533333350526 Sample variance is: 1.3218500824200464e-06
#
#
# p-value:  0.27313175492421865
# Significance level:  2.6524307187425093e-118
#
#
# Iteration: 5
# quick_sort Theta 0.005239823827248568
# Less than two values for merge_sort
# merge_sort Theta 0.5328247931529099
# Less than two values for heap_sort
# heap_sort Theta 0.5104473534223368
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005941400000210706
# Sample mean is:  0.007741500000065571 Sample variance is: 2.0715075649741966e-06
#
#
# p-value:  0.11887143305127669
# Significance level:  2.1170468689249724e-114
#
#
# Iteration: 6
# quick_sort Theta 0.008197626446289219
# Less than two values for merge_sort
# merge_sort Theta 0.7199633772282851
# Less than two values for heap_sort
# heap_sort Theta 0.12709876574245826
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005972699999801989
# Sample mean is:  0.007387740000012855 Sample variance is: 2.157790602528549e-06
#
#
# p-value:  0.12630681654149384
# Significance level:  4.788350659685832e-114
#
#
# Iteration: 7
# quick_sort Theta 0.008479176464848363
# Less than two values for merge_sort
# merge_sort Theta 0.99193015271341
# Less than two values for heap_sort
# heap_sort Theta 0.5013124532131835
#
#
# Chosen algorithm is:  quick_sort with reward: 0.010057299999971292
# Sample mean is:  0.007832666666672594 Sample variance is: 2.7879575289651923e-06
#
#
# p-value:  0.03082815884453599
# Significance level:  8.048650530606693e-112
#
#
# Iteration: 8
# quick_sort Theta 0.001893332694438015
# Less than two values for merge_sort
# merge_sort Theta 0.8112191740898286
# Less than two values for heap_sort
# heap_sort Theta 0.47115300651526404
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006881899999825691
# Sample mean is:  0.007696842857123036 Sample variance is: 2.5003665254134917e-06
#
#
# p-value:  0.25364784047718336
# Significance level:  9.121652427578638e-113
#
#
# Iteration: 9
# quick_sort Theta 0.011796826427056963
# Less than two values for merge_sort
# merge_sort Theta 0.6206104816432308
# Less than two values for heap_sort
# heap_sort Theta 0.7028498283661697
#
#
# Chosen algorithm is:  quick_sort with reward: 0.010221000000001368
# Sample mean is:  0.008012362499982828 Sample variance is: 2.8846892249493973e-06
#
#
# p-value:  0.010829570659277317
# Significance level:  1.5921377760886842e-111
#
#
# Iteration: 10
# quick_sort Theta 0.004593175373431353
# Less than two values for merge_sort
# C:\Users\iRacheva\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3584: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\iRacheva\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# merge_sort Theta 0.3049259507338816
# Less than two values for heap_sort
# heap_sort Theta 0.7416327432718646
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00982060000023921
# Sample mean is:  0.008213277777789093 Sample variance is: 2.887103790802768e-06
#
#
# p-value:  0.028118291452132668
# Significance level:  1.6190040651371275e-111
#
#
# Iteration: 11
# quick_sort Theta 0.010069536718214922
# Less than two values for merge_sort
# merge_sort Theta 0.531479120348454
# Less than two values for heap_sort
# heap_sort Theta 0.9595527656197961
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008047000000260596
# Sample mean is:  0.008196650000036243 Sample variance is: 2.600881758659475e-06
#
#
# p-value:  0.7870109065385867
# Significance level:  2.006375309741515e-112
#
#
# Iteration: 12
# quick_sort Theta 0.007782696953797823
# Less than two values for merge_sort
# merge_sort Theta 0.2131490526599511
# Less than two values for heap_sort
# heap_sort Theta 0.35882773388389866
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007525700000314828
# Sample mean is:  0.008135654545516114 Sample variance is: 2.4016424171388753e-06
#
#
# p-value:  0.24164412980030342
# Significance level:  4.0753687138541027e-113
#
#
# Iteration: 13
# quick_sort Theta 0.008143523580552228
# Less than two values for merge_sort
# merge_sort Theta 0.6805493786619211
# Less than two values for heap_sort
# heap_sort Theta 0.4972790371713832
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0070430999999189225
# Sample mean is:  0.008044608333383016 Sample variance is: 2.2926890892256074e-06
#
#
# p-value:  0.05063964888675559
# Significance level:  1.6102869893374018e-113
#
#
# Iteration: 14
# quick_sort Theta 0.007810574598974425
# Less than two values for merge_sort
# merge_sort Theta 0.9459224649879097
# Less than two values for heap_sort
# heap_sort Theta 0.26108390821801164
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006483699999989767
# Sample mean is:  0.007924538461583534 Sample variance is: 2.2893296794217314e-06
#
#
# p-value:  0.006355240019439891
# Significance level:  1.563748017752614e-113
#
#
# Iteration: 15
# quick_sort Theta 0.01080080885285649
# Less than two values for merge_sort
# merge_sort Theta 0.6276575832361071
# Less than two values for heap_sort
# heap_sort Theta 0.8685322247497145
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006355800000164891
# Sample mean is:  0.007812485714339346 Sample variance is: 2.2890317670362184e-06
#
#
# p-value:  0.0041343247759624375
# Significance level:  1.5596832083903533e-113
#
#
# Iteration: 16
# quick_sort Theta 0.006168692318486966
# Less than two values for merge_sort
# merge_sort Theta 0.6267375898315738
# Less than two values for heap_sort
# heap_sort Theta 0.7803595502597646
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008282799999960844
# Sample mean is:  0.007843840000047446 Sample variance is: 2.1501929264855165e-06
#
#
# p-value:  0.2815263340682779
# Significance level:  4.4621953206619275e-114
#
#
# Iteration: 17
# quick_sort Theta 0.008961164327963136
# Less than two values for merge_sort
# merge_sort Theta 0.09874246546513299
# Less than two values for heap_sort
# heap_sort Theta 0.021288658768703894
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008960600000136765
# Sample mean is:  0.007913637500053028 Sample variance is: 2.088881233685611e-06
#
#
# p-value:  0.013309502973013117
# Significance level:  2.5019289075580327e-114
#
#
# Iteration: 18
# quick_sort Theta 0.00988011811926414
# Less than two values for merge_sort
# merge_sort Theta 0.9927872041145653
# Less than two values for heap_sort
# heap_sort Theta 0.9829858032699077
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007620699999733915
# Sample mean is:  0.007896405882387198 Sample variance is: 1.9707567253563233e-06
#
#
# p-value:  0.44359303583620036
# Significance level:  7.8101674635368245e-115
#
#
# Iteration: 19
# quick_sort Theta 0.011353536496206077
# Less than two values for merge_sort
# merge_sort Theta 0.8102462707497223
# Less than two values for heap_sort
# heap_sort Theta 0.3084391677359182
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006201700000019628
# Sample mean is:  0.007802255555588999 Sample variance is: 2.0119630692298332e-06
#
#
# p-value:  0.000228101005805657
# Significance level:  1.181408509009974e-114
#
#
# Iteration: 20
# quick_sort Theta 0.007329524425108846
# Less than two values for merge_sort
# merge_sort Theta 0.3930225661936825
# Less than two values for heap_sort
# heap_sort Theta 0.04367384157267984
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006890800000292074
# Sample mean is:  0.007754284210573371 Sample variance is: 1.947492775079425e-06
#
#
# p-value:  0.01716633594305677
# Significance level:  6.159097846154941e-115
#
#
# Iteration: 21
# quick_sort Theta 0.00917258580133965
# Less than two values for merge_sort
# merge_sort Theta 0.5974815346510602
# Less than two values for heap_sort
# heap_sort Theta 0.8533196118196037
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00717609999992419
# Sample mean is:  0.007725375000040913 Sample variance is: 1.8659972429440444e-06
#
#
# p-value:  0.09577283937126055
# Significance level:  2.619509360029522e-115
#
#
# Iteration: 22
# quick_sort Theta 0.007700802917375423
# Less than two values for merge_sort
# merge_sort Theta 0.08991736546922935
# Less than two values for heap_sort
# heap_sort Theta 0.7356438964279728
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071220999998331536
# Sample mean is:  0.007696647619078638 Sample variance is: 1.793645479714313e-06
#
#
# p-value:  0.06942889689504328
# Significance level:  1.1877694406930986e-115
#
#
# Iteration: 23
# quick_sort Theta 0.00811638773161234
# Less than two values for merge_sort
# merge_sort Theta 0.8514046873621943
# Less than two values for heap_sort
# heap_sort Theta 0.4252702170089907
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007132500000352593
# Sample mean is:  0.007671004545500182 Sample variance is: 1.7259250514008522e-06
#
#
# p-value:  0.07428172222255887
# Significance level:  5.500962058038495e-116
#
#
# Iteration: 24
# quick_sort Theta 0.007172356173930777
# Less than two values for merge_sort
# merge_sort Theta 0.44163501707744457
# Less than two values for heap_sort
# heap_sort Theta 0.3756944796872589
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006605799999761075
# Sample mean is:  0.00762469130438109 Sample variance is: 1.6980729904397405e-06
#
#
# p-value:  0.001352512910068884
# Significance level:  3.9730779231770995e-116
#
#
# Iteration: 25
# quick_sort Theta 0.008850174458928163
# Less than two values for merge_sort
# merge_sort Theta 0.011414004032810121
# Less than two values for heap_sort
# heap_sort Theta 0.607431631491857
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007052800000110437
# Sample mean is:  0.00760086250003648 Sample variance is: 1.640379623250774e-06
#
#
# p-value:  0.051700404269094564
# Significance level:  1.9901569019884e-116
#
#
# Iteration: 26
# quick_sort Theta 0.00795688137854817
# Less than two values for merge_sort
# merge_sort Theta 0.7022612907303067
# Less than two values for heap_sort
# heap_sort Theta 0.6757036662918826
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007373099999767874
# Sample mean is:  0.007591752000025736 Sample variance is: 1.5767564673714414e-06
#
#
# p-value:  0.4020627397448644
# Significance level:  9.021783901314359e-117
#
#
# Iteration: 27
# quick_sort Theta 0.00836986232476243
# Less than two values for merge_sort
# merge_sort Theta 0.5726129886714943
# Less than two values for heap_sort
# heap_sort Theta 0.6547337473005057
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006336899999951129
# Sample mean is:  0.0075434884615613275 Sample variance is: 1.5743462164847898e-06
#
#
# p-value:  6.125551525723435e-05
# Significance level:  8.749936385511146e-117
#
#
# Iteration: 28
# quick_sort Theta 0.006028506517345161
# Less than two values for merge_sort
# merge_sort Theta 0.35610858574353854
# Less than two values for heap_sort
# heap_sort Theta 0.5149197094250406
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006538200000250072
# Sample mean is:  0.007506255555586837 Sample variance is: 1.552080618825661e-06
#
#
# p-value:  0.0005159798764315393
# Significance level:  6.580903405942171e-117
#
#
# Iteration: 29
# quick_sort Theta 0.004665371643579904
# Less than two values for merge_sort
# merge_sort Theta 0.42506289719576085
# Less than two values for heap_sort
# heap_sort Theta 0.6486374549148334
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006620500000281027
# Sample mean is:  0.007474621428611629 Sample variance is: 1.5236685538693716e-06
#
#
# p-value:  0.0012768354414087405
# Significance level:  4.547891443273715e-117
#
#
# Iteration: 30
# quick_sort Theta 0.007487408089965446
# Less than two values for merge_sort
# merge_sort Theta 0.9542547621770633
# Less than two values for heap_sort
# heap_sort Theta 0.9408799365835618
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00709210000013627
# Sample mean is:  0.007461431034526272 Sample variance is: 1.4759998807999156e-06
#
#
# p-value:  0.11891981707685997
# Significance level:  2.408387964768682e-117
#
#
# Iteration: 31
# quick_sort Theta 0.0054068333772713814
# Less than two values for merge_sort
# merge_sort Theta 0.1801008002232397
# Less than two values for heap_sort
# heap_sort Theta 0.1839888698029476
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007079499999690597
# Sample mean is:  0.00744870000003175 Sample variance is: 1.4315001827129728e-06
#
#
# p-value:  0.10733756319582656
# Significance level:  1.3056541569661633e-117
#
#
# Iteration: 32
# quick_sort Theta 0.008860243958352172
# Less than two values for merge_sort
# merge_sort Theta 0.7711395337377951
# Less than two values for heap_sort
# heap_sort Theta 0.34672547765306105
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007103099999767437
# Sample mean is:  0.007437551612926449 Sample variance is: 1.3890513535156559e-06
#
#
# p-value:  0.13060033219543193
# Significance level:  7.1509878446838605e-118
#
#
# Iteration: 33
# quick_sort Theta 0.006507759286456048
# Less than two values for merge_sort
# merge_sort Theta 0.8939485578943493
# Less than two values for heap_sort
# heap_sort Theta 0.41313626327873154
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0061203000000205066
# Sample mean is:  0.007396387500023138 Sample variance is: 1.3981725086429033e-06
#
#
# p-value:  1.1970756340188391e-06
# Significance level:  8.151080317761056e-118
#
#
# Iteration: 34
# quick_sort Theta 0.00880734177662702
# Less than two values for merge_sort
# merge_sort Theta 0.11878744389057982
# Less than two values for heap_sort
# heap_sort Theta 0.5056624024927554
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006029600000147184
# Sample mean is:  0.007354969696996594 Sample variance is: 1.4106975457860931e-06
#
#
# p-value:  4.4070370693619854e-07
# Significance level:  9.742675010447282e-118
#
#
# Iteration: 35
# quick_sort Theta 0.008553183834494089
# Less than two values for merge_sort
# merge_sort Theta 0.36851819599552593
# Less than two values for heap_sort
# heap_sort Theta 0.8103252827183685
# Chosen algorithm is:  quick_sort with reward: 0.007497499999772117
# Sample mean is:  0.007359161764725286 Sample variance is: 1.3697863647490508e-06
#
#
# p-value:  0.5018696848141926
# Significance level:  5.4082502128137925e-118
#
#
# Iteration: 36
# quick_sort Theta 0.006720511959026952
# Less than two values for merge_sort
# merge_sort Theta 0.35867561071308407
# Less than two values for heap_sort
# heap_sort Theta 0.27382203118738546
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008194400000320456
# Sample mean is:  0.00738302571431372 Sample variance is: 1.3500122065291224e-06
#
#
# p-value:  0.00026342127298294973
# Significance level:  4.043467029903902e-118
#
#
# Iteration: 37
# quick_sort Theta 0.0077329007877844835
# Less than two values for merge_sort
# merge_sort Theta 0.7125745971743997
# Less than two values for heap_sort
# heap_sort Theta 0.8815704080118618
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006410800000139716
# Sample mean is:  0.007356019444475553 Sample variance is: 1.3380387188288846e-06
#
#
# p-value:  2.6439152136249652e-05
# Significance level:  3.3835579255191364e-118
#
#
# Iteration: 38
# quick_sort Theta 0.006486254677526137
# Less than two values for merge_sort
# merge_sort Theta 0.49110001372292633
# Less than two values for heap_sort
# heap_sort Theta 0.4986105487375616
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007203900000149588
# Sample mean is:  0.0073519081081424185 Sample variance is: 1.3024840213238772e-06
#
#
# p-value:  0.44157844918577815
# Significance level:  1.974458831547542e-118
#
#
# Iteration: 39
# quick_sort Theta 0.007012395836517752
# Less than two values for merge_sort
# merge_sort Theta 0.7731543601893194
# Less than two values for heap_sort
# heap_sort Theta 0.8543931800393371
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007289900000159832
# Sample mean is:  0.007350276315827087 Sample variance is: 1.2683066476338143e-06
#
#
# p-value:  0.7461834560057896
# Significance level:  1.160073149482791e-118
#
#
# Iteration: 40
# quick_sort Theta 0.006377464678342186
# Less than two values for merge_sort
# merge_sort Theta 0.008329667459330281
# Less than two values for heap_sort
# heap_sort Theta 0.7448233054838013
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0064421000001857465
# Sample mean is:  0.007326989743631156 Sample variance is: 1.2563920132573334e-06
#
#
# p-value:  2.0127442379259427e-05
# Significance level:  9.605132041677272e-119
#
#
# Iteration: 41
# quick_sort Theta 0.006210498580357741
# Less than two values for merge_sort
# merge_sort Theta 0.01613881825424035
# Less than two values for heap_sort
# heap_sort Theta 0.2968742446936159
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0070899000002100365
# Sample mean is:  0.007321062500045628 Sample variance is: 1.2263523693702651e-06
#
#
# p-value:  0.20001537145043846
# Significance level:  5.919778947307932e-119
#
#
# Iteration: 42
# quick_sort Theta 0.005898089743162712
# Less than two values for merge_sort
# merge_sort Theta 0.6986473370855555
# Less than two values for heap_sort
# heap_sort Theta 0.4642069856466158
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007169800000156101
# Sample mean is:  0.007317373170780029 Sample variance is: 1.1969857819881903e-06
#
#
# p-value:  0.3986911600147637
# Significance level:  3.6456908326366676e-119
#
#
# Iteration: 43
# quick_sort Theta 0.008433503958398161
# Less than two values for merge_sort
# merge_sort Theta 0.46373590596179626
# Less than two values for heap_sort
# heap_sort Theta 0.7885638014340492
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0061428000003616035
# Sample mean is:  0.007289407142912924 Sample variance is: 1.2005521678134934e-06
#
#
# p-value:  4.3685816024876596e-08
# Significance level:  3.869195959833219e-119
#
#
# Iteration: 44
# quick_sort Theta 0.007823333009939426
# Less than two values for merge_sort
# merge_sort Theta 0.6456976558398045
# Less than two values for heap_sort
# heap_sort Theta 0.8677307888554234
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006280800000240561
# Sample mean is:  0.007265951162850776 Sample variance is: 1.195740035985753e-06
#
#
# p-value:  6.777675051461919e-07
# Significance level:  3.570552410760696e-119
#
#
# Iteration: 45
# quick_sort Theta 0.007449410257541935
# Less than two values for merge_sort
# merge_sort Theta 0.5388337030398012
# Less than two values for heap_sort
# heap_sort Theta 0.37562844215422697
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0072248000001309265
# Sample mean is:  0.0072650159091525975 Sample variance is: 1.1686017381546236e-06
#
#
# p-value:  0.8084306121428215
# Significance level:  2.2559556559410678e-119
#
#
# Iteration: 46
# quick_sort Theta 0.007115548567397538
# Less than two values for merge_sort
# merge_sort Theta 0.1201085264219166
# Less than two values for heap_sort
# heap_sort Theta 0.19613080904938296
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006142200000340381
# Sample mean is:  0.007240064444512326 Sample variance is: 1.1700261364986442e-06
#
#
# p-value:  2.8228068936352775e-08
# Significance level:  2.3115924422411967e-119
#
#
# Iteration: 47
# quick_sort Theta 0.006198668110217674
# Less than two values for merge_sort
# merge_sort Theta 0.7536497943734914
# Less than two values for heap_sort
# heap_sort Theta 0.6630447173386016
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007360500000231696
# Sample mean is:  0.007242682608767095 Sample variance is: 1.144899250988118e-06
#
#
# p-value:  0.4639616799313977
# Significance level:  1.497426190983076e-119
#
#
# Iteration: 48
# quick_sort Theta 0.0070149151691968606
# Less than two values for merge_sort
# merge_sort Theta 0.11369724398800063
# Less than two values for heap_sort
# heap_sort Theta 0.5167861118239593
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006394100000306935
# Sample mean is:  0.0072246276596509215 Sample variance is: 1.1355348270854866e-06
#
#
# p-value:  3.346130343626875e-06
# Significance level:  1.2706009426891796e-119
#
#
# Iteration: 49
# quick_sort Theta 0.008008100737092815
# Less than two values for merge_sort
# merge_sort Theta 0.9693038600264601
# Less than two values for heap_sort
# heap_sort Theta 0.6472178038301188
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00681880000001911
# Sample mean is:  0.007216172916741925 Sample variance is: 1.1152375373710947e-06
#
#
# p-value:  0.013076988047323598
# Significance level:  8.858242703426142e-120
#
#
# Iteration: 50
# quick_sort Theta 0.007641145623324028
# Less than two values for merge_sort
# merge_sort Theta 0.19574662021951394
# Less than two values for heap_sort
# heap_sort Theta 0.61236862145397
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007043900000098802
# Sample mean is:  0.007212657142932882 Sample variance is: 1.0930708995716926e-06
#
#
# p-value:  0.269004254261678
# Significance level:  5.928797919420858e-120
#
#
# Iteration: 51
# quick_sort Theta 0.006939178528526024
# Less than two values for merge_sort
# merge_sort Theta 0.028645277235067046
# Less than two values for heap_sort
# heap_sort Theta 0.773704814714287
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006959400000141613
# Sample mean is:  0.007207592000077057 Sample variance is: 1.0724666095156048e-06
#
#
# p-value:  0.09978948505501888
# Significance level:  4.0520574332344315e-120
#
#
# Iteration: 52
# quick_sort Theta 0.0070440980841884595
# Less than two values for merge_sort
# merge_sort Theta 0.9540054417708971
# Less than two values for heap_sort
# heap_sort Theta 0.7548205663759597
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005819500000143307
# Sample mean is:  0.007180374509882277 Sample variance is: 1.088477441091425e-06
#
#
# p-value:  2.2698963722126774e-12
# Significance level:  5.4499014951078715e-120
#
#
# Iteration: 53
# quick_sort Theta 0.00760333276269277
# Less than two values for merge_sort
# merge_sort Theta 0.9462074449214153
# Less than two values for heap_sort
# heap_sort Theta 0.4458737064817152
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007065400000101363
# Sample mean is:  0.00717816346161726 Sample variance is: 1.0677945080648395e-06
#
#
# p-value:  0.4393991727507629
# Significance level:  3.7132454438309496e-120
#
#
# Iteration: 54
# quick_sort Theta 0.0074439647379402835
# Less than two values for merge_sort
# merge_sort Theta 0.45749869775929786
# Less than two values for heap_sort
# heap_sort Theta 0.33562058115537285
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005843100000220147
# Sample mean is:  0.0071529735849871256 Sample variance is: 1.0806429958762887e-06
#
#
# p-value:  2.5532875790053953e-12
# Significance level:  4.716771732231923e-120
#
#
# Iteration: 55
# quick_sort Theta 0.006879353682468823
# Less than two values for merge_sort
# merge_sort Theta 0.10330514338646313
# Less than two values for heap_sort
# heap_sort Theta 0.9645706547856239
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059326999999029795
# Sample mean is:  0.0071303759260040855 Sample variance is: 1.0876957606954755e-06
#
#
# p-value:  2.9863144720981795e-11
# Significance level:  5.372157260376043e-120
#
#
# Iteration: 56
# quick_sort Theta 0.006203458729766357
# Less than two values for merge_sort
# merge_sort Theta 0.5890533631681754
# Less than two values for heap_sort
# heap_sort Theta 0.04640953047534058
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007889299999987998
# Sample mean is:  0.007144174545531066 Sample variance is: 1.0782011767832951e-06
#
#
# p-value:  2.4175781932450635e-06
# Significance level:  4.508125834387584e-120
#
#
# Iteration: 57
# quick_sort Theta 0.00682209069626348
# Less than two values for merge_sort
# merge_sort Theta 0.9946229627116592
# Less than two values for heap_sort
# heap_sort Theta 0.30674205961466805
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0068827000000055705
# Sample mean is:  0.007139505357218111 Sample variance is: 1.0601466569133375e-06
#
#
# p-value:  0.06973179208526865
# Significance level:  3.216021648030764e-120
#
#
# Iteration: 58
# quick_sort Theta 0.007015661356562658
# Less than two values for merge_sort
# merge_sort Theta 0.0535734357679325
# Less than two values for heap_sort
# heap_sort Theta 0.04341763495767914
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006111200000304962
# Sample mean is:  0.007121464912359985 Sample variance is: 1.0597732211949907e-06
#
#
# p-value:  9.351522863292906e-10
# Significance level:  3.193440490653556e-120
#
#
# Iteration: 59
# quick_sort Theta 0.0073638339970028095
# Less than two values for merge_sort
# merge_sort Theta 0.2968283649256477
# Less than two values for heap_sort
# heap_sort Theta 0.7600509655272288
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005989299999782816
# Sample mean is:  0.007101944827660378 Sample variance is: 1.0632201903861712e-06
#
#
# p-value:  3.923496777541336e-11
# Significance level:  3.4077231448786114e-120
#
#
# Iteration: 60
# quick_sort Theta 0.006004013016675553
# Less than two values for merge_sort
# merge_sort Theta 0.6880822890835505
# Less than two values for heap_sort
# heap_sort Theta 0.7029958731975474
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007115100000191887
# Sample mean is:  0.007102167796686336 Sample variance is: 1.0452023926740042e-06
#
#
# p-value:  0.9235862244417977
# Significance level:  2.4210731136564796e-120
# Iteration: 61
# quick_sort Theta 0.007754013171496221
# Less than two values for merge_sort
# merge_sort Theta 0.41062761202527487
# Less than two values for heap_sort
# heap_sort Theta 0.9407089170655897
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008473000000321917
# Sample mean is:  0.007125015000080263 Sample variance is: 1.058580040268587e-06
#
#
# p-value:  2.0275188759670027e-14
# Significance level:  3.1222956250252145e-120
#
#
# Iteration: 62
# quick_sort Theta 0.006933844152873919
# Less than two values for merge_sort
# merge_sort Theta 0.2634392375472844
# Less than two values for heap_sort
# heap_sort Theta 0.017896851476813636
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005947499999820138
# Sample mean is:  0.0071057114754858345 Sample variance is: 1.0635838328227048e-06
#
#
# p-value:  3.1763712145864763e-12
# Significance level:  3.431109220585316e-120
#
#
# Iteration: 63
# quick_sort Theta 0.0067350449603391545
# Less than two values for merge_sort
# merge_sort Theta 0.11279806351877186
# Less than two values for heap_sort
# heap_sort Theta 0.3361824659917574
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007597900000291702
# Sample mean is:  0.007113650000079478 Sample variance is: 1.050273485410108e-06
#
#
# p-value:  0.0004792568196182866
# Significance level:  2.6671536391132364e-120
#
#
# Iteration: 64
# quick_sort Theta 0.007196339604010715
# Less than two values for merge_sort
# merge_sort Theta 0.85339791273489
# Less than two values for heap_sort
# heap_sort Theta 0.5508544290895445
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006003500000133499
# Sample mean is:  0.007096028571508907 Sample variance is: 1.0528543918869853e-06
#
#
# p-value:  8.55839686103897e-12
# Significance level:  2.8013428335131632e-120
#
#
# Iteration: 65
# quick_sort Theta 0.006955916467459364
# Less than two values for merge_sort
# merge_sort Theta 0.5783250593732585
# Less than two values for heap_sort
# heap_sort Theta 0.9820455805589258
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005864799999926618
# Sample mean is:  0.007076790625077933 Sample variance is: 1.059719752735254e-06
#
#
# p-value:  1.6457529831733581e-13
# Significance level:  3.19021967839299e-120
#
#
# Iteration: 66
# quick_sort Theta 0.007533319186254342
# Less than two values for merge_sort
# merge_sort Theta 0.8849535742093342
# Less than two values for heap_sort
# heap_sort Theta 0.7340010994902967
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006338700000014796
# Sample mean is:  0.007065435384692347 Sample variance is: 1.051668626913668e-06
#
#
# p-value:  3.694561603154989e-07
# Significance level:  2.7389138188604525e-120
#
#
# Iteration: 67
# quick_sort Theta 0.006916843036078158
# Less than two values for merge_sort
# merge_sort Theta 0.2376339467683144
# Less than two values for heap_sort
# heap_sort Theta 0.8847604029009726
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007106300000032206
# Sample mean is:  0.007066054545530829 Sample variance is: 1.0357591721879666e-06
#
#
# p-value:  0.7508860700792487
# Significance level:  2.0191833565372983e-120
#
#
# Iteration: 68
# quick_sort Theta 0.007189301749674398
# Less than two values for merge_sort
# merge_sort Theta 0.6505785775359821
# Less than two values for heap_sort
# heap_sort Theta 0.6225896829417751
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006768799999917974
# Sample mean is:  0.007061617910521682 Sample variance is: 1.0215992062592477e-06
#
#
# p-value:  0.021580942736888004
# Significance level:  1.5332428091124823e-120
#
#
# Iteration: 69
# quick_sort Theta 0.006592596837659844
# Less than two values for merge_sort
# merge_sort Theta 0.1467256002685503
# Less than two values for heap_sort
# heap_sort Theta 0.21239060482779537
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007965199999944161
# Sample mean is:  0.007074905882424954 Sample variance is: 1.0184058917393845e-06
#
#
# p-value:  6.078623567192363e-10
# Significance level:  1.4401842700124195e-120
#
#
# Iteration: 70
# quick_sort Theta 0.006912021578034339
# Less than two values for merge_sort
# merge_sort Theta 0.18004619069534056
# Less than two values for heap_sort
# heap_sort Theta 0.6380874443696946
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007297900000139634
# Sample mean is:  0.007078137681232413 Sample variance is: 1.004356613662171e-06
#
#
# p-value:  0.07498597058923706
# Significance level:  1.0908345242489678e-120
#
#
# Iteration: 71
# quick_sort Theta 0.0076904661868078695
# Less than two values for merge_sort
# merge_sort Theta 0.2858911934943039
# Less than two values for heap_sort
# heap_sort Theta 0.5096468057905799
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006349299999783398
# Sample mean is:  0.00706772571435457 Sample variance is: 9.974888867827314e-07
#
#
# p-value:  9.018723709778795e-08
# Significance level:  9.509579566813707e-121
#
#
# Iteration: 72
# quick_sort Theta 0.007795976588882687
# Less than two values for merge_sort
# merge_sort Theta 0.19621632775787268
# Less than two values for heap_sort
# heap_sort Theta 0.9830901616917257
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071791999998822575
# Sample mean is:  0.007069295774714115 Sample variance is: 9.836123037995536e-07
#
#
# p-value:  0.3570328663616662
# Significance level:  7.185864968147108e-121
#
#
# Iteration: 73
# quick_sort Theta 0.00708245926465091
# Less than two values for merge_sort
# merge_sort Theta 0.6092654953970695
# Less than two values for heap_sort
# heap_sort Theta 0.6539497250687066
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007965199999944161
# Sample mean is:  0.007081738888953421 Sample variance is: 9.809440293323795e-07
#
#
# p-value:  1.316243439324906e-10
# Significance level:  6.805884311813418e-121
#
#
# Iteration: 74
# quick_sort Theta 0.007194882256606158
# Less than two values for merge_sort
# merge_sort Theta 0.25027890315087875
# Less than two values for heap_sort
# heap_sort Theta 0.5842479874304717
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006206999999903928
# Sample mean is:  0.0070697561644458935 Sample variance is: 9.778446093263475e-07
#
#
# p-value:  1.9828338421037346e-10
# Significance level:  6.388470862986413e-121
#
#
# Iteration: 75
# quick_sort Theta 0.006650315482942022
# Less than two values for merge_sort
# merge_sort Theta 0.0811408004665104
# Less than two values for heap_sort
# heap_sort Theta 0.8937419282120734
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00666750000027605
# Sample mean is:  0.007064320270335491 Sample variance is: 9.667875659530043e-07
#
#
# p-value:  0.0009405046633369566
# Significance level:  5.08886728066698e-121
#
#
# Iteration: 76
# quick_sort Theta 0.007215894326049446
# Less than two values for merge_sort
# merge_sort Theta 0.6008208938473792
# Less than two values for heap_sort
# heap_sort Theta 0.5720969859049736
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006593300000076852
# Sample mean is:  0.0070580400000653755 Sample variance is: 9.568157578788926e-07
#
#
# p-value:  0.00010969303534804202
# Significance level:  4.135865269764142e-121
#
#
# Iteration: 77
# quick_sort Theta 0.00628053890530692
# Less than two values for merge_sort
# merge_sort Theta 0.4683330921147637
# Less than two values for heap_sort
# heap_sort Theta 0.5313029161921922
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008440800000244053
# Sample mean is:  0.007076234210594042 Sample variance is: 9.690532741112784e-07
#
#
# p-value:  3.8977345877491928e-19
# Significance level:  5.332772596039581e-121
#
#
# Iteration: 78
# quick_sort Theta 0.007385673606523888
# Less than two values for merge_sort
# merge_sort Theta 0.6807637045036289
# Less than two values for heap_sort
# heap_sort Theta 0.5052980003357123
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006679600000097707
# Sample mean is:  0.007071083116951232 Sample variance is: 9.584847328497793e-07
#
#
# p-value:  0.0008178932765605136
# Significance level:  4.282565291180825e-121
#
#
# Iteration: 79
# quick_sort Theta 0.007745869228576036
# Less than two values for merge_sort
# merge_sort Theta 0.5238203741062236
# Less than two values for heap_sort
# heap_sort Theta 0.2385520482203084
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007888900000125432
# Sample mean is:  0.0070815679487867995 Sample variance is: 9.546612078377617e-07
#
#
# p-value:  2.7784092821829106e-10
# Significance level:  3.953534307844133e-121
#
#
# Iteration: 80
# quick_sort Theta 0.006839862375432006
# Less than two values for merge_sort
# merge_sort Theta 0.3729493083080637
# Less than two values for heap_sort
# heap_sort Theta 0.5600550912723258
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0073284999998577405
# Sample mean is:  0.007084693670952254 Sample variance is: 9.433389595975461e-07
#
#
# p-value:  0.029537883087352876
# Significance level:  3.114263965414e-121
#
#
# Iteration: 81
# quick_sort Theta 0.008053076706292673
# Less than two values for merge_sort
# merge_sort Theta 0.5801497672598539
# Less than two values for heap_sort
# heap_sort Theta 0.9435872028155833
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008095499999853928
# Sample mean is:  0.007097328750063525 Sample variance is: 9.441591953102746e-07
#
#
# p-value:  5.410202728148368e-14
# Significance level:  3.168870875991051e-121
#
#
# Iteration: 82
# quick_sort Theta 0.006605408349364678
# Less than two values for merge_sort
# merge_sort Theta 0.8931424624671356
# Less than two values for heap_sort
# heap_sort Theta 0.9452482840146583
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0077836000000388594
# Sample mean is:  0.007105801234631122 Sample variance is: 9.382455485282725e-07
#
#
# p-value:  1.807379309832589e-08
# Significance level:  2.794668191714173e-121
#
#
# Iteration: 83
# quick_sort Theta 0.007372097339531626
# Less than two values for merge_sort
# merge_sort Theta 0.8973191275331673
# Less than two values for heap_sort
# heap_sort Theta 0.08659945796091828
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006886499999836815
# Sample mean is:  0.007103126829328752 Sample variance is: 9.2738287758521e-07
#
#
# p-value:  0.04621045565114886
# Significance level:  2.214019612805522e-121
#
#
# Iteration: 84
# quick_sort Theta 0.0072401627469057045
# Less than two values for merge_sort
# merge_sort Theta 0.4107277091613861
# Less than two values for heap_sort
# heap_sort Theta 0.44687307199202586
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006259599999793863
# Sample mean is:  0.007092963855478934 Sample variance is: 9.246790449761712e-07
#
#
# p-value:  1.3979063438022028e-11
# Significance level:  2.08843188748855e-121
#
#
# Iteration: 85
# quick_sort Theta 0.006989928118562118
# Less than two values for merge_sort
# merge_sort Theta 0.8335199486352969
# Less than two values for heap_sort
# heap_sort Theta 0.08036459226537429
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007415800000217132
# Sample mean is:  0.0070968071429162935 Sample variance is: 9.148969423484788e-07
#
#
# p-value:  0.0031802148902701274
# Significance level:  1.6882762968232244e-121
#
#
# Iteration: 86
# quick_sort Theta 0.007150500193602703
# Less than two values for merge_sort
# merge_sort Theta 0.10242721491978057
# Less than two values for heap_sort
# heap_sort Theta 0.3773225884532351
#
#
# Chosen algorithm is:  quick_sort with reward: 0.009132399999998597
# Sample mean is:  0.007120755294176086 Sample variance is: 9.523086206050822e-07
#
#
# p-value:  5.479069970566535e-32
# Significance level:  3.7631741293893173e-121
#
#
# Iteration: 87
# quick_sort Theta 0.006884318929340074
# Less than two values for merge_sort
# merge_sort Theta 0.5227964484140704
# Less than two values for heap_sort
# heap_sort Theta 0.6183384592137168
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006519699999898876
# Sample mean is:  0.007113766279126351 Sample variance is: 9.453872027175956e-07
#
#
# p-value:  2.2452259216227463e-07
# Significance level:  3.2523283373691175e-121
#
#
# Iteration: 88
# quick_sort Theta 0.006798022207186576
# Less than two values for merge_sort
# merge_sort Theta 0.5120402459406199
# Less than two values for heap_sort
# heap_sort Theta 0.6028055760264961
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0070703000001230976
# Sample mean is:  0.007113266666724015 Sample variance is: 9.345421498256499e-07
#
#
# p-value:  0.681236912438218
# Significance level:  2.5821286421676163e-121
#
#
# Iteration: 89
# quick_sort Theta 0.0071089248843392554
# Less than two values for merge_sort
# merge_sort Theta 0.9722129180691245
# Less than two values for heap_sort
# heap_sort Theta 0.6918343169534968
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0058859999999185675
# Sample mean is:  0.007099320454601225 Sample variance is: 9.408435771024635e-07
#
#
# p-value:  1.7458657031030595e-19
# Significance level:  2.9535783012773744e-121
#
#
# Iteration: 90
# quick_sort Theta 0.008082118178501532
# Less than two values for merge_sort
# merge_sort Theta 0.22816069475995526
# Less than two values for heap_sort
# heap_sort Theta 0.2554676750723517
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006427899999835063
# Sample mean is:  0.007091776404547672 Sample variance is: 9.352806177817691e-07
#
#
# p-value:  6.138191962219414e-09
# Significance level:  2.623243995097756e-121
#
#
# Iteration: 91
# quick_sort Theta 0.006864522623159334
# Less than two values for merge_sort
# merge_sort Theta 0.14078738509249622
# Less than two values for heap_sort
# heap_sort Theta 0.6482650401499227
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007209400000192545
# Sample mean is:  0.007093083333388171 Sample variance is: 9.250406285240047e-07
#
#
# p-value:  0.25696248588181986
# Significance level:  2.1048257800375636e-121
#
#
# Iteration: 92
# quick_sort Theta 0.006785713660379752
# Less than two values for merge_sort
# merge_sort Theta 0.9264207789222896
# Less than two values for heap_sort
# heap_sort Theta 0.23554586026791302
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005928799999765033
# Sample mean is:  0.007080289011040664 Sample variance is: 9.296078684817453e-07
#
#
# p-value:  5.164029532542035e-19
# Significance level:  2.3227144471491823e-121
#
#
# Iteration: 93
# quick_sort Theta 0.007251338765658809
# Less than two values for merge_sort
# merge_sort Theta 0.4278766929766512
# Less than two values for heap_sort
# heap_sort Theta 0.8210403992269001
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006079900000258931
# Sample mean is:  0.007069415217445211 Sample variance is: 9.302632193599266e-07
#
#
# p-value:  7.122635530909141e-16
# Significance level:  2.3556838483387442e-121
#
#
# Iteration: 94
# quick_sort Theta 0.006920643003403868
# Less than two values for merge_sort
# merge_sort Theta 0.7079264651671063
# Less than two values for heap_sort
# heap_sort Theta 0.9663308921073206
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007386700000097335
# Sample mean is:  0.007072826881774803 Sample variance is: 9.213312187660278e-07
#
#
# p-value:  0.002296613620035395
# Significance level:  1.942297470160448e-121
#
#
# Iteration: 95
# quick_sort Theta 0.006512441007193353
# Less than two values for merge_sort
# merge_sort Theta 0.20856376891594364
# Less than two values for heap_sort
# heap_sort Theta 0.2177369101115877
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006709899999805202
# Sample mean is:  0.007068965957498531 Sample variance is: 9.129161492945493e-07
#
#
# p-value:  0.00047266724376021277
# Significance level:  1.6166566553452217e-121
#
#
# Iteration: 96
# quick_sort Theta 0.007480258954044222
# Less than two values for merge_sort
# merge_sort Theta 0.29712788846143556
# Less than two values for heap_sort
# heap_sort Theta 0.8336392705770767
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008275499999854219
# Sample mean is:  0.007081666315839117 Sample variance is: 9.184686212038188e-07
#
#
# p-value:  7.905384472272046e-21
# Significance level:  1.825099184130908e-121
#
#
# Iteration: 97
# quick_sort Theta 0.006672146868886105
# Less than two values for merge_sort
# merge_sort Theta 0.27521487646905984
# Less than two values for heap_sort
# heap_sort Theta 0.18431888499688787
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007708699999966484
# Sample mean is:  0.007088197916715444 Sample variance is: 9.129541116836707e-07
#
#
# p-value:  8.070917209806805e-09
# Significance level:  1.6180017164412838e-121
#
#
# Iteration: 98
# quick_sort Theta 0.007574842869209434
# Less than two values for merge_sort
# merge_sort Theta 0.40823877551901533
# Less than two values for heap_sort
# heap_sort Theta 0.7944042470746391
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008821000000352797
# Sample mean is:  0.007106061855722014 Sample variance is: 9.341777640408019e-07
#
#
# p-value:  2.0451484627890524e-31
# Significance level:  2.562067183620656e-121
#
#
# Iteration: 99
# quick_sort Theta 0.0069937709475147046
# Less than two values for merge_sort
# merge_sort Theta 0.08696004878287655
# Less than two values for heap_sort
# heap_sort Theta 0.2762806468275657
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006571000000349159
# Sample mean is:  0.007100602040871271 Sample variance is: 9.275368669629467e-07
#
#
# p-value:  4.426846916827089e-07
# Significance level:  2.2213838601998405e-121
#
#
# Iteration: 100
# quick_sort Theta 0.007213144318967487
# Less than two values for merge_sort
# merge_sort Theta 0.8557627183948785
# Less than two values for heap_sort
# heap_sort Theta 0.41276872660348796
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007816299999831244
# Sample mean is:  0.007107831313183998 Sample variance is: 9.232895207615078e-07
#
#
# p-value:  7.683584886500782e-11
# Significance level:  2.026553754108557e-121
#
#
# Iteration: 101
# quick_sort Theta 0.0070396499960846265
# Less than two values for merge_sort
# merge_sort Theta 0.5895030401025029
# Less than two values for heap_sort
# heap_sort Theta 0.456220530449436
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007645599999705155
# Sample mean is:  0.0071132090000492094 Sample variance is: 9.169196576398995e-07
#
#
# p-value:  2.588054806655836e-07
# Significance level:  1.7645162873896308e-121
#
#
# Iteration: 102
# quick_sort Theta 0.006788923829664024
# Less than two values for merge_sort
# merge_sort Theta 0.9901262825749014
# Less than two values for heap_sort
# heap_sort Theta 0.028090471890891644
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0067761000000245986
# Sample mean is:  0.0071098712871776795 Sample variance is: 9.089552779092975e-07
#
#
# p-value:  0.0006943752751555504
# Significance level:  1.4820072046518298e-121
#
#
# Iteration: 103
# quick_sort Theta 0.006506359646547432
# Less than two values for merge_sort
# merge_sort Theta 0.2907361445443071
# Less than two values for heap_sort
# heap_sort Theta 0.7521490615054535
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007547000000158732
# Sample mean is:  0.00711415686279514 Sample variance is: 9.018989336509557e-07
#
#
# p-value:  1.327548714304464e-05
# Significance level:  1.268111581340449e-121
#
#
# Iteration: 104
# quick_sort Theta 0.007355015428399709
# Less than two values for merge_sort
# merge_sort Theta 0.48452524082768744
# Less than two values for heap_sort
# heap_sort Theta 0.6658850496896357
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006567899999936344
# Sample mean is:  0.0071088533981071905 Sample variance is: 8.960115605692728e-07
#
#
# p-value:  8.498731458093292e-08
# Significance level:  1.1124288963322237e-121
#
#
# Iteration: 105
# quick_sort Theta 0.006740376374538976
# Less than two values for merge_sort
# merge_sort Theta 0.37045754632944916
# Less than two values for heap_sort
# heap_sort Theta 0.644427658506391
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006990700000187644
# Sample mean is:  0.00710771730774258 Sample variance is: 8.875290070301739e-07
#
#
# p-value:  0.2103010672126204
# Significance level:  9.197104462760918e-122
#
#
# Iteration: 106
# quick_sort Theta 0.007646055910533921
# Less than two values for merge_sort
# merge_sort Theta 0.5829500185098518
# Less than two values for heap_sort
# heap_sort Theta 0.4196633702504866
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005915800000366289
# Sample mean is:  0.007096365714338996 Sample variance is: 8.924776517915924e-07
#
#
# p-value:  5.678785474133412e-23
# Significance level:  1.0278908454933826e-121
#
#
# Iteration: 107
# quick_sort Theta 0.007678335801092942
# Less than two values for merge_sort
# merge_sort Theta 0.26816378187075174
# Less than two values for heap_sort
# heap_sort Theta 0.5828195936256333
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007441699999617413
# Sample mean is:  0.0070996235849548305 Sample variance is: 8.851724920026915e-07
#
#
# p-value:  0.0003156072650376119
# Significance level:  8.720837274449384e-122
#
#
# Iteration: 108
# quick_sort Theta 0.0068111859751259695
# Less than two values for merge_sort
# merge_sort Theta 0.7771490216544437
# Less than two values for heap_sort
# heap_sort Theta 0.18620846146272618
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00901930000009088
# Sample mean is:  0.007117564486030868 Sample variance is: 9.110187006210557e-07
#
#
# p-value:  1.0712611745095652e-38
# Significance level:  1.5507644545626623e-121
#
#
# Iteration: 109
# quick_sort Theta 0.007890830391467563
# Less than two values for merge_sort
# merge_sort Theta 0.20685612572438972
# Less than two values for heap_sort
# heap_sort Theta 0.061997601247482215
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006217900000137888
# Sample mean is:  0.007109234259309637 Sample variance is: 9.100083587452732e-07
#
#
# p-value:  2.925691437567321e-16
# Significance level:  1.5167277396920233e-121
# Iteration: 110
# quick_sort Theta 0.006267890540254332
# Less than two values for merge_sort
# merge_sort Theta 0.7470662344556582
# Less than two values for heap_sort
# heap_sort Theta 0.5923422186341143
#
#
# Chosen algorithm is:  quick_sort with reward: 0.009032400000251073
# Sample mean is:  0.007126877981703595 Sample variance is: 9.35280159717152e-07
#
#
# p-value:  5.5896162745129585e-39
# Significance level:  2.623218299928998e-121
#
#
# Iteration: 111
# quick_sort Theta 0.007051562696569198
# Less than two values for merge_sort
# merge_sort Theta 0.12840339580147886
# Less than two values for heap_sort
# ...
#
#
# p-value:  1.045852671911031e-55
# Significance level:  1.9850625118415905e-132
#
#
# Iteration: 1963
# quick_sort Theta 0.003202015184019984
# Less than two values for merge_sort
# merge_sort Theta 0.22325896239550558
# Less than two values for heap_sort
# heap_sort Theta 0.8955168359272871
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002682300000287796
# Sample mean is:  0.0032263770742225447 Sample variance is: 2.600295050803837e-07
#
#
# p-value:  1.9146240558439408e-77
# Significance level:  1.9973427045391606e-132
#
#
# Iteration: 1964
# quick_sort Theta 0.003207646724191216
# Less than two values for merge_sort
# merge_sort Theta 0.6239831369006176
# Less than two values for heap_sort
# heap_sort Theta 0.5733468707677465
# Chosen algorithm is:  quick_sort with reward: 0.0037549999997281702
# Sample mean is:  0.003227528758156108 Sample variance is: 2.600704721517552e-07
#
#
# p-value:  2.3208067921958335e-74
# Significance level:  2.0036456712097005e-132
#
#
# Iteration: 1965
# quick_sort Theta 0.0032292673551573697
# Less than two values for merge_sort
# merge_sort Theta 0.4231166788784385
# Less than two values for heap_sort
# heap_sort Theta 0.21113176428803215
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002908899999965797
# Sample mean is:  0.003226836086942651 Sample variance is: 2.597253267352891e-07
#
#
# p-value:  1.2041298129550623e-34
# Significance level:  1.9511291875106517e-132
#
#
# Iteration: 1966
# quick_sort Theta 0.003451731889212907
# Less than two values for merge_sort
# merge_sort Theta 0.4145505930095702
# Less than two values for heap_sort
# heap_sort Theta 0.28069726997720534
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0035990000001220324
# Sample mean is:  0.003227643383934363 Sample variance is: 2.594617263117102e-07
#
#
# p-value:  1.6634473688192198e-44
# Significance level:  1.9119039314019418e-132
#
#
# Iteration: 1967
# quick_sort Theta 0.003175007165991475
# Less than two values for merge_sort
# merge_sort Theta 0.9280166233604868
# Less than two values for heap_sort
# heap_sort Theta 0.7139042922929962
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0026861000001190405
# Sample mean is:  0.003226471212107923 Sample variance is: 2.5953352875401574e-07
#
#
# p-value:  1.762772864146576e-77
# Significance level:  1.922513656406613e-132
#
#
# Iteration: 1968
# quick_sort Theta 0.003321679962548768
# Less than two values for merge_sort
# merge_sort Theta 0.4413145708765869
# Less than two values for heap_sort
# heap_sort Theta 0.32734931351164487
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002696600000035687
# Sample mean is:  0.003225326781844268 Sample variance is: 2.5957807210601993e-07
#
#
# p-value:  2.4312511748452784e-75
# Significance level:  1.9291235902003576e-132
#
#
# Iteration: 1969
# quick_sort Theta 0.003190214060187269
# Less than two values for merge_sort
# merge_sort Theta 0.1651232685778784
# Less than two values for heap_sort
# heap_sort Theta 0.4457570985288303
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0035910000001422304
# Sample mean is:  0.0032261148706768067 Sample variance is: 2.593061985014826e-07
#
#
# p-value:  1.377651150745035e-43
# Significance level:  1.889113131686762e-132
#
#
# Iteration: 1970
# quick_sort Theta 0.0032040521163424376
# Less than two values for merge_sort
# merge_sort Theta 0.7679482722706812
# Less than two values for heap_sort
# heap_sort Theta 0.5147946517298821
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002728099999785627
# Sample mean is:  0.00322504387095446 Sample variance is: 2.5928077751081337e-07
#
#
# p-value:  2.0349557098612033e-69
# Significance level:  1.8854126086347573e-132
#
#
# Iteration: 1971
# quick_sort Theta 0.0031202286049055606
# Less than two values for merge_sort
# merge_sort Theta 0.9739807931777981
# Less than two values for heap_sort
# heap_sort Theta 0.36391787442465484
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0037225999999463966
# Sample mean is:  0.003226111587969464 Sample variance is: 2.5925449011777e-07
#
#
# p-value:  1.771293770621285e-69
# Significance level:  1.8815932067618326e-132
#
#
# Iteration: 1972
# quick_sort Theta 0.003211050558418345
# Less than two values for merge_sort
# merge_sort Theta 0.7815355694472007
# Less than two values for heap_sort
# heap_sort Theta 0.9502475890572828
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0035083000002487097
# Sample mean is:  0.003226715845811604 Sample variance is: 2.588694907502022e-07
#
#
# p-value:  6.952015712268576e-29
# Significance level:  1.8264903720027425e-132
#
#
# Iteration: 1973
# quick_sort Theta 0.003326817611903052
# Less than two values for merge_sort
# merge_sort Theta 0.8362461800424321
# Less than two values for heap_sort
# heap_sort Theta 0.20007637635251319
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002744500000062544
# Sample mean is:  0.003225685470072824 Sample variance is: 2.5881215264685386e-07
#
#
# p-value:  8.459699852252183e-67
# Significance level:  1.8184162324902017e-132
#
#
# Iteration: 1974
# quick_sort Theta 0.00323066826205332
# Less than two values for merge_sort
# merge_sort Theta 0.605048988983516
# Less than two values for heap_sort
# heap_sort Theta 0.38745866513192706
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0027612000003500725
# Sample mean is:  0.0032246950959369546 Sample variance is: 2.5871934792306066e-07
#
#
# p-value:  2.0142166307054232e-63
# Significance level:  1.8054196265913663e-132
#
#
# Iteration: 1975
# quick_sort Theta 0.0032090276326117977
# Less than two values for merge_sort
# merge_sort Theta 0.02812212133006342
# Less than two values for heap_sort
# heap_sort Theta 0.6223051168903984
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0037175000002207526
# Sample mean is:  0.003225743617009899 Sample variance is: 2.5868449815590345e-07
#
#
# p-value:  3.204064695069701e-69
# Significance level:  1.800562007327725e-132
#
#
# Iteration: 1976
# quick_sort Theta 0.0033851928761197457
# Less than two values for merge_sort
# merge_sort Theta 0.3123853845576937
# Less than two values for heap_sort
# heap_sort Theta 0.6149397095220449
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0026978999999300868
# Sample mean is:  0.0032246229299248037 Sample variance is: 2.587255657533799e-07
#
#
# p-value:  2.1899540346056584e-76
# Significance level:  1.8062876216883416e-132
#
#
# Iteration: 1977
# quick_sort Theta 0.0031562013783996215
# Less than two values for merge_sort
# merge_sort Theta 0.7446207957026688
# Less than two values for heap_sort
# heap_sort Theta 0.2949833952098846
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0036595999999917694
# Sample mean is:  0.0032255444915139284 Sample variance is: 2.585774272524704e-07
#
#
# p-value:  5.935015840099604e-58
# Significance level:  1.785715225216236e-132
#
#
# Iteration: 1978
# quick_sort Theta 0.0029976928786673916
# Less than two values for merge_sort
# merge_sort Theta 0.548217681804785
# Less than two values for heap_sort
# heap_sort Theta 0.4918411009113496
#
#
# Chosen algorithm is:  quick_sort with reward: 0.003703400000176771
# Sample mean is:  0.003226554756859939 Sample variance is: 2.5851249215531645e-07
#
#
# p-value:  1.123212726797914e-66
# Significance level:  1.7767678568312777e-132
#
#
# Iteration: 1979
# quick_sort Theta 0.0031754999405111044
# Less than two values for merge_sort
# merge_sort Theta 0.3375759922365632
# Less than two values for heap_sort
# heap_sort Theta 0.19110815224762012
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0027058999999098887
# Sample mean is:  0.0032254563291026603 Sample variance is: 2.5853780224422443e-07
#
#
# p-value:  1.8864188453962244e-75
# Significance level:  1.7802502420697798e-132
#
#
# Iteration: 1980
# quick_sort Theta 0.0032497927327129594
# Less than two values for merge_sort
# merge_sort Theta 0.7738466027882412
# Less than two values for heap_sort
# heap_sort Theta 0.9044854355184377
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0027776000001722423
# Sample mean is:  0.0032245134736733332 Sample variance is: 2.584148869291666e-07
#
#
# p-value:  6.369965339931767e-61
# Significance level:  1.763398971397505e-132
#
#
# Iteration: 1981
# quick_sort Theta 0.003297034757115782
# Less than two values for merge_sort
# merge_sort Theta 0.5358177229547589
# Less than two values for heap_sort
# heap_sort Theta 0.8782464257333995
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0026708000000326138
# Sample mean is:  0.0032233502100732477 Sample variance is: 2.5851476005780805e-07
#
#
# p-value:  1.8366058622597146e-82
# Significance level:  1.777079630708443e-132
#
#
# Iteration: 1982
# quick_sort Theta 0.00342553383299117
# Less than two values for merge_sort
# merge_sort Theta 0.9436743967886821
# Less than two values for heap_sort
# heap_sort Theta 0.5139619910820525
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0036058000000593893
# Sample mean is:  0.0032241519916036167 Sample variance is: 2.5827879871739867e-07
#
#
# p-value:  3.614520214383553e-48
# Significance level:  1.74491853457333e-132
#
#
# Iteration: 1983
# quick_sort Theta 0.003129882590939314
# Less than two values for merge_sort
# merge_sort Theta 0.38986676642782825
# Less than two values for heap_sort
# heap_sort Theta 0.07970424807605614
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0036496000002443907
# Sample mean is:  0.0032250420501990997 Sample variance is: 2.581163479552271e-07
#
#
# p-value:  7.836112206787898e-57
# Significance level:  1.7230990158328102e-132
#
#
# Iteration: 1984
# quick_sort Theta 0.003260190943751175
# Less than two values for merge_sort
# merge_sort Theta 0.7544032558247026
# Less than two values for heap_sort
# heap_sort Theta 0.5405091438169833
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002693600000384322
# Sample mean is:  0.003223932567840405 Sample variance is: 2.581658775560145e-07
#
#
# p-value:  1.6448747443586607e-78
# Significance level:  1.729723947902762e-132
#
#
# Iteration: 1985
# quick_sort Theta 0.0030658722463693874
# Less than two values for merge_sort
# merge_sort Theta 0.5207231609936092
# Less than two values for heap_sort
# heap_sort Theta 0.18753917121099362
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002682099999674392
# Sample mean is:  0.003222803749990059 Sample variance is: 2.5823838802287803e-07
#
#
# p-value:  8.853642661204029e-81
# Significance level:  1.7394663907224164e-132
#
#
# Iteration: 1986
# quick_sort Theta 0.0033256428116400115
# Less than two values for merge_sort
# merge_sort Theta 0.7385385021153211
# Less than two values for heap_sort
# heap_sort Theta 0.3848548644752712
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002681500000107917
# Sample mean is:  0.0032216783783686823 Sample variance is: 2.583094112946762e-07
#
#
# p-value:  8.039845219530649e-81
# Significance level:  1.7490595359225955e-132
#
#
# Iteration: 1987
# quick_sort Theta 0.0033117633206667277
# Less than two values for merge_sort
# merge_sort Theta 0.42543121173228116
# Less than two values for heap_sort
# heap_sort Theta 0.5288098813801051
#
#
# Chosen algorithm is:  quick_sort with reward: 0.003762400000141497
# Sample mean is:  0.003222800207459497 Sample variance is: 2.583788383978145e-07
#
#
# p-value:  7.489467798795801e-81
# Significance level:  1.758485649899648e-132
#
#
# Iteration: 1988
# quick_sort Theta 0.0032801893430761614
# Less than two values for merge_sort
# merge_sort Theta 0.48621702283319657
# Less than two values for heap_sort
# heap_sort Theta 0.030781725989926567
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0027347999998710293
# Sample mean is:  0.003221789855062834 Sample variance is: 2.583359239299661e-07
#
#
# p-value:  3.5586217048207304e-70
# Significance level:  1.7526534755603662e-132
#
#
# Iteration: 1989
# quick_sort Theta 0.0031778443814648406
# Less than two values for merge_sort
# merge_sort Theta 0.9742373533339975
# Less than two values for heap_sort
# heap_sort Theta 0.4683381528851046
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0028100000004087633
# Sample mean is:  0.0032209390495780113 Sample variance is: 2.5815180121798085e-07
#
#
# p-value:  9.414002989658942e-55
# Significance level:  1.7278386816205736e-132
#
#
# Iteration: 1990
# quick_sort Theta 0.0030235432491125887
# Less than two values for merge_sort
# merge_sort Theta 0.3305756580761966
# Less than two values for heap_sort
# heap_sort Theta 0.021604892524906494
#
#
# Chosen algorithm is:  quick_sort with reward: 0.003591099999994185
# Sample mean is:  0.0032217022680324776 Sample variance is: 2.579014606289634e-07
#
#
# p-value:  1.4283874604053273e-46
# Significance level:  1.694634468317465e-132
#
#
# Iteration: 1991
# quick_sort Theta 0.003084421870292602
# Less than two values for merge_sort
# merge_sort Theta 0.21195544641492192
# Less than two values for heap_sort
# heap_sort Theta 0.1364925135608993
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0027162999999745807
# Sample mean is:  0.0032206623456702186 Sample variance is: 2.5789529686931037e-07
#
#
# p-value:  2.6923079171890465e-74
# Significance level:  1.6938246281327646e-132
#
#
# Iteration: 1992
# quick_sort Theta 0.003227027474044917
# Less than two values for merge_sort
# merge_sort Theta 0.19451103497667643
# Less than two values for heap_sort
# heap_sort Theta 0.2855747933535395
# Chosen algorithm is:  quick_sort with reward: 0.004037400000015623
# Sample mean is:  0.0032223394250425912 Sample variance is: 2.587326590156832e-07
#
#
# p-value:  2.5227211563623536e-136
# Significance level:  1.8072783092117238e-132
#
#
# Iteration: 1993
# quick_sort Theta 0.0032795911119735555
# Less than two values for merge_sort
# merge_sort Theta 0.7507529289750504
# Less than two values for heap_sort
# heap_sort Theta 0.41905410600741744
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002650900000389811
# Sample mean is:  0.003221168442615024 Sample variance is: 2.588702434654929e-07
#
#
# p-value:  4.310743747149459e-88
# Significance level:  1.8265965927246286e-132
#
#
# Iteration: 1994
# quick_sort Theta 0.0031699801702609323
# Less than two values for merge_sort
# merge_sort Theta 0.6487713481685221
# Less than two values for heap_sort
# heap_sort Theta 0.344590411287345
#
#
# Chosen algorithm is:  quick_sort with reward: 0.003654199999800767
# Sample mean is:  0.0032220539877217433 Sample variance is: 2.5872354125092584e-07
#
#
# p-value:  1.4603298468599384e-59
# Significance level:  1.8060049621924823e-132
#
#
# Iteration: 1995
# quick_sort Theta 0.003237381422935912
# Less than two values for merge_sort
# merge_sort Theta 0.6687202540310336
# Less than two values for heap_sort
# heap_sort Theta 0.32936064162308576
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0036534999999275897
# Sample mean is:  0.0032229344897874695 Sample variance is: 2.585746478449919e-07
#
#
# p-value:  2.222555493088531e-59
# Significance level:  1.785331377057357e-132
#
#
# Iteration: 1996
# quick_sort Theta 0.003374064087595679
# Less than two values for merge_sort
# merge_sort Theta 0.020031071750446827
# Less than two values for heap_sort
# heap_sort Theta 0.33931289367462447
#
#
# Chosen algorithm is:  quick_sort with reward: 0.002680699999928038
# Sample mean is:  0.003221830142557613 Sample variance is: 2.586456148083144e-07
#
#
# p-value:  1.3604606940485183e-82
# Significance level:  1.7951568133834584e-132
#
#
# Iteration: 1997
# quick_sort Theta 0.0033174792708624773
# Less than two values for merge_sort
# merge_sort Theta 0.6150627123574796
# Less than two values for heap_sort
# heap_sort Theta 0.42084954046139267
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0026880999998866173
# Sample mean is:  0.003220745325194461 Sample variance is: 2.586977352364877e-07
#
#
# p-value:  5.747600867819581e-81
# Significance level:  1.8024056256690642e-132
#
#
# Iteration: 1998
# quick_sort Theta 0.003295246072307296
# Less than two values for merge_sort
# merge_sort Theta 0.3527087393294117
# Less than two values for heap_sort
# heap_sort Theta 0.502541434610914
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0037440999999489577
# Sample mean is:  0.003221806896542847 Sample variance is: 2.5872744477406e-07
#
#
# p-value:  6.0489279425557e-79
# Significance level:  1.8065500067346192e-132
#
#
# Iteration: 1999
# quick_sort Theta 0.0032712939582756843
# Less than two values for merge_sort
# merge_sort Theta 0.7760885123835518
# Less than two values for heap_sort
# heap_sort Theta 0.09536311726090052
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0036407999996299623
# Sample mean is:  0.003222655060719137 Sample variance is: 2.5855836056499193e-07
#
#
# p-value:  2.8367858905418796e-57
# Significance level:  1.78308360847896e-132

# %%
for elem in list_iteration_results_TS_ttest:
    sample_mean, sample_count,rewards,cum_rewards,n = elem
    print("Iteration", n)
    plot_history(rewards,cum_rewards, sample_count, sample_mean)
print("Total reward", np.round(total_reward_TS_ttest,4))
# Out:
# Iteration 518
# Average rewards per algo {'quick_sort': 0.006769709333347136, 'merge_sort': 0.007589619672112573, 'heap_sort': 0.009168912500001625}
# Count per chosen algo {'quick_sort': 450, 'merge_sort': 61, 'heap_sort': 8}
# Iteration 1004
# Average rewards per algo {'quick_sort': 0.002346899999793095, 'merge_sort': 0.0029630355648504933, 'heap_sort': 0.005573471428566076}
# Count per chosen algo {'quick_sort': 1, 'merge_sort': 478, 'heap_sort': 7}
# Iteration 1504
# Average rewards per algo {'quick_sort': 0.006199110606071982, 'merge_sort': 0.006901629032199708, 'heap_sort': 0.009945171428691018}
# Count per chosen algo {'quick_sort': 462, 'merge_sort': 31, 'heap_sort': 7}
# Iteration 1999
# Average rewards per algo {'quick_sort': 0.003222655060719137, 'merge_sort': 0.0, 'heap_sort': 0.006365899999764224}
# Count per chosen algo {'quick_sort': 494, 'merge_sort': 0, 'heap_sort': 1}
# Total reward 9.7863

# %% [markdown]
# ### Second Variant: Change point detection

# %% [markdown]
# ## Offline changepoint detection - not adjustable to out case but works properly

# %%
list_iteration_results_TS_stationary, total_reward_TS_stationary = TS_stationary(list_distributions=list_distributions, n_samples=n_samples)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.9571820834968096
# Less than two values for merge_sort
# merge_sort Theta 0.3519201965977784
# Less than two values for heap_sort
# heap_sort Theta 0.34147286066946914
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010407199999917793
# Sample mean is:  0.010407199999917793 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.01006673116642054
# Less than two values for merge_sort
# merge_sort Theta 0.8660902094256219
# Less than two values for heap_sort
# heap_sort Theta 0.3870618359103243
#
#
# Chosen algorithm is:  quick_sort with reward: 0.009207799999785493
# Sample mean is:  0.009207799999785493 Sample variance is: 0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.06325774729187861
# Less than two values for merge_sort
# merge_sort Theta 0.403663375981973
# Less than two values for heap_sort
# heap_sort Theta 0.08911168958393001
#
#
# Chosen algorithm is:  quick_sort with reward: 0.009222000000136177
# Sample mean is:  0.009214899999960835 Sample variance is: 5.041000248985426e-11
#
#
# Iteration: 3
# quick_sort Theta 0.00883224075833685
# Less than two values for merge_sort
# merge_sort Theta 0.6037787555686268
# Less than two values for heap_sort
# heap_sort Theta 0.251681978224504
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0070316000001184875
# Sample mean is:  0.00848713333334672 Sample variance is: 1.0593222487375698e-06
#
#
# Iteration: 4
# quick_sort Theta 0.008289829466433953
# Less than two values for merge_sort
# merge_sort Theta 0.9884519779846318
# Less than two values for heap_sort
# heap_sort Theta 0.11190028849612133
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007181800000125804
# Sample mean is:  0.00816080000004149 Sample variance is: 1.113972019831482e-06
#
#
# Iteration: 5
# quick_sort Theta 0.003970801110947881
# Less than two values for merge_sort
# merge_sort Theta 0.5841016986457013
# Less than two values for heap_sort
# heap_sort Theta 0.7499901919399078
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007110999999895284
# Sample mean is:  0.00795084000001225 Sample variance is: 1.0675104223143016e-06
#
#
# Iteration: 6
# quick_sort Theta 0.00890351580510848
# Less than two values for merge_sort
# merge_sort Theta 0.18188062964821894
# Less than two values for heap_sort
# heap_sort Theta 0.6445345562444383
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00708249999979671
# Sample mean is:  0.007806116666642993 Sample variance is: 9.94316234702796e-07
#
#
# Iteration: 7
# quick_sort Theta 0.006318287003095292
# Less than two values for merge_sort
# merge_sort Theta 0.8333830255758414
# Less than two values for heap_sort
# heap_sort Theta 0.15170320204924292
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005809700000099838
# Sample mean is:  0.007520914285708257 Sample variance is: 1.3403134468617372e-06
#
#
# Iteration: 8
# quick_sort Theta 0.008090105455373203
# Less than two values for merge_sort
# merge_sort Theta 0.9299099583839096
# Less than two values for heap_sort
# heap_sort Theta 0.7277227372296666
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059948999996777275
# Sample mean is:  0.00733016249995444 Sample variance is: 1.4274779723819085e-06
#
#
# Iteration: 9
# quick_sort Theta 0.009017086923607327
# Less than two values for merge_sort
# merge_sort Theta 0.7811211760103605
# Less than two values for heap_sort
# heap_sort Theta 0.020519622681702154
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005940099999861559
# Sample mean is:  0.007175711111055231 Sample variance is: 1.4597111610470763e-06
#
#
# Iteration: 10
# quick_sort Theta 0.007058099366711547
# Less than two values for merge_sort
# merge_sort Theta 0.3101997908156293
# Less than two values for heap_sort
# heap_sort Theta 0.7461340749232636
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005949000000327942
# Sample mean is:  0.007053039999982502 Sample variance is: 1.4491738583687288e-06
#
#
# Iteration: 11
# quick_sort Theta 0.00752310213706867
# Less than two values for merge_sort
# merge_sort Theta 0.8462042998083058
# Less than two values for heap_sort
# heap_sort Theta 0.22803844233067283
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005905699999857461
# Sample mean is:  0.006948736363607499 Sample variance is: 1.4262232659456979e-06
#
#
# Iteration: 12
# quick_sort Theta 0.00277429142756396
# Less than two values for merge_sort
# merge_sort Theta 0.7281741625453033
# Less than two values for heap_sort
# heap_sort Theta 0.5276651955123651
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005909900000006019
# Sample mean is:  0.006862166666640708 Sample variance is: 1.3898087638790302e-06
#
#
# Iteration: 13
# quick_sort Theta 0.008031236506336742
# Less than two values for merge_sort
# merge_sort Theta 0.6249478723666481
# Less than two values for heap_sort
# heap_sort Theta 0.5760302591963107
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007883199999923818
# Sample mean is:  0.00694070769227787 Sample variance is: 1.3569247099244457e-06
#
#
# Iteration: 14
# quick_sort Theta 0.004179184023603578
# Less than two values for merge_sort
# merge_sort Theta 0.15333194167173125
# Less than two values for heap_sort
# heap_sort Theta 0.315009554684649
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059297999996488215
# Sample mean is:  0.006868499999947224 Sample variance is: 1.3277828771707386e-06
#
#
# Iteration: 15
# quick_sort Theta 0.007216143584180242
# Less than two values for merge_sort
# merge_sort Theta 0.17051858058086755
# Less than two values for heap_sort
# heap_sort Theta 0.9021141611191531
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005849099999977625
# Sample mean is:  0.006800539999949251 Sample variance is: 1.3039238810888324e-06
#
#
# Iteration: 16
# quick_sort Theta 0.005860474324254779
# Less than two values for merge_sort
# merge_sort Theta 0.027856977170656272
# Less than two values for heap_sort
# heap_sort Theta 0.37096389802602714
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005999999999858119
# Sample mean is:  0.006750506249943555 Sample variance is: 1.2599792806152676e-06
#
#
# Iteration: 17
# quick_sort Theta 0.009014583875148158
# Less than two values for merge_sort
# merge_sort Theta 0.0784420670253565
# Less than two values for heap_sort
# heap_sort Theta 0.3170467412980864
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005840799999987212
# Sample mean is:  0.006696994117593182 Sample variance is: 1.231679625282723e-06
#
#
# Iteration: 18
# quick_sort Theta 0.008875478942070861
# Less than two values for merge_sort
# merge_sort Theta 0.49582685459446674
# Less than two values for heap_sort
# heap_sort Theta 0.7072450566979709
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0058339000001979
# Sample mean is:  0.0066490444444045555 Sample variance is: 1.2023388891349167e-06
#
#
# Iteration: 19
# quick_sort Theta 0.006808586401570999
# Less than two values for merge_sort
# merge_sort Theta 0.3791651111678248
# Less than two values for heap_sort
# heap_sort Theta 0.3120018263731795
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007033400000182155
# Sample mean is:  0.0066692736841823235 Sample variance is: 1.1464238935256772e-06
#
#
# Iteration: 20
# quick_sort Theta 0.006368816840980608
# Less than two values for merge_sort
# merge_sort Theta 0.03678712480133983
# Less than two values for heap_sort
# heap_sort Theta 0.7106138839955203
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005914100000154576
# Sample mean is:  0.006631514999980936 Sample variance is: 1.1161913452691753e-06
#
#
# Iteration: 21
# quick_sort Theta 0.006668692278170202
# Less than two values for merge_sort
# merge_sort Theta 0.8694295089100019
# Less than two values for heap_sort
# heap_sort Theta 0.9858406566510299
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005984299999909126
# Sample mean is:  0.006600695238072755 Sample variance is: 1.0820365309283732e-06
#
#
# Iteration: 22
# quick_sort Theta 0.004504485404656549
# Less than two values for merge_sort
# merge_sort Theta 0.19020869594185552
# Less than two values for heap_sort
# heap_sort Theta 0.36769032788754685
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005853199999819481
# Sample mean is:  0.006566718181788515 Sample variance is: 1.057096299678401e-06
#
#
# Iteration: 23
# quick_sort Theta 0.00871370760035207
# Less than two values for merge_sort
# merge_sort Theta 0.6473003626238873
# Less than two values for heap_sort
# heap_sort Theta 0.7538155348267452
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005859699999746226
# Sample mean is:  0.006535978260830155 Sample variance is: 1.0319243312883091e-06
#
#
# Iteration: 24
# quick_sort Theta 0.0072769039196288205
# Less than two values for merge_sort
# merge_sort Theta 0.059150105360512906
# Less than two values for heap_sort
# heap_sort Theta 0.21245670589824606
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006900699999732751
# Sample mean is:  0.006551174999951097 Sample variance is: 9.94239124389225e-07
#
#
# Iteration: 25
# quick_sort Theta 0.006192949961215041
# Less than two values for merge_sort
# merge_sort Theta 0.21308376469609602
# Less than two values for heap_sort
# heap_sort Theta 0.8612698655241188
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005958100000043487
# Sample mean is:  0.006527451999954792 Sample variance is: 9.679762969054478e-07
#
#
# Iteration: 26
# quick_sort Theta 0.005916073259454595
# Less than two values for merge_sort
# merge_sort Theta 0.31467576208857073
# Less than two values for heap_sort
# heap_sort Theta 0.46512868366057314
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00720339999998032
# Sample mean is:  0.006553449999955774 Sample variance is: 9.476438394334377e-07
#
#
# Iteration: 27
# quick_sort Theta 0.006460628614334919
# Less than two values for merge_sort
# merge_sort Theta 0.08983127706537786
# Less than two values for heap_sort
# heap_sort Theta 0.46822243249451123
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0058561000000736385
# Sample mean is:  0.006527622222182361 Sample variance is: 9.298898461769538e-07
#
#
# Iteration: 28
# quick_sort Theta 0.006957222522964505
# Less than two values for merge_sort
# merge_sort Theta 0.8026899616684505
# Less than two values for heap_sort
# heap_sort Theta 0.16575723567487832
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007302399999844056
# Sample mean is:  0.00655529285709885 Sample variance is: 9.173524235181807e-07
#
#
# Iteration: 29
# quick_sort Theta 0.006450380831078732
# Less than two values for merge_sort
# merge_sort Theta 0.10821962285425546
# Less than two values for heap_sort
# heap_sort Theta 0.6154601035473888
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006656999999904656
# Sample mean is:  0.006558799999954223 Sample variance is: 8.86063982756122e-07
#
#
# Iteration: 30
# quick_sort Theta 0.0054883288423401184
# Less than two values for merge_sort
# merge_sort Theta 0.5497363886314698
# Less than two values for heap_sort
# heap_sort Theta 0.6341195684700209
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00587870000026669
# Sample mean is:  0.006536129999964639 Sample variance is: 8.714324547505566e-07
#
#
# Iteration: 31
# quick_sort Theta 0.00640954736221171
# Less than two values for merge_sort
# merge_sort Theta 0.15286921329983694
# Less than two values for heap_sort
# heap_sort Theta 0.9334013222007557
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005875099999684608
# Sample mean is:  0.006514806451568509 Sample variance is: 8.569625418898274e-07
#
#
# Iteration: 32
# quick_sort Theta 0.0069539293937770155
# Less than two values for merge_sort
# merge_sort Theta 0.43653758150883415
# Less than two values for heap_sort
# heap_sort Theta 0.018497399204037257
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006018399999902613
# Sample mean is:  0.006499293749953949 Sample variance is: 8.37642423708623e-07
#
#
# Iteration: 33
# quick_sort Theta 0.007050955708838665
# Less than two values for merge_sort
# merge_sort Theta 0.15854697150159835
# Less than two values for heap_sort
# heap_sort Theta 0.43003999559869344
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059847000002264394
# Sample mean is:  0.006483699999962207 Sample variance is: 8.20040601201636e-07
#
#
# Iteration: 34
# quick_sort Theta 0.005547966556436778
# Less than two values for merge_sort
# merge_sort Theta 0.052615263732768036
# Less than two values for heap_sort
# heap_sort Theta 0.39698637897478795
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006905200000346667
# Sample mean is:  0.006496097058797044 Sample variance is: 8.00993433225719e-07
#
#
# Iteration: 35
# quick_sort Theta 0.006695599983709437
# Less than two values for merge_sort
# merge_sort Theta 0.9332096666718266
# Less than two values for heap_sort
# heap_sort Theta 0.8967780548194999
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005933399999776157
# Sample mean is:  0.006480019999967876 Sample variance is: 7.868959484624093e-07
#
#
# Iteration: 36
# quick_sort Theta 0.006513025602002288
# Less than two values for merge_sort
# merge_sort Theta 0.25303327440542
# Less than two values for heap_sort
# heap_sort Theta 0.7383478266325793
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006842300000243995
# Sample mean is:  0.0064900833333088786 Sample variance is: 7.685822013994118e-07
#
#
# Iteration: 37
# quick_sort Theta 0.006261740719363773
# Less than two values for merge_sort
# merge_sort Theta 0.16445560411562665
# Less than two values for heap_sort
# heap_sort Theta 0.6108240663831583
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006840200000169716
# Sample mean is:  0.0064995459459267395 Sample variance is: 7.510331868217028e-07
#
#
# Iteration: 38
# quick_sort Theta 0.005682913444937867
# Less than two values for merge_sort
# merge_sort Theta 0.5638030590120124
# Less than two values for heap_sort
# heap_sort Theta 0.6495969990447316
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006241700000373385
# Sample mean is:  0.006492760526306914 Sample variance is: 7.329727066079859e-07
#
#
# Iteration: 39
# quick_sort Theta 0.006512592599331308
# Less than two values for merge_sort
# merge_sort Theta 0.18191306419584063
# Less than two values for heap_sort
# heap_sort Theta 0.08907743356653353
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006527699999878678
# Sample mean is:  0.006493656410244652 Sample variance is: 7.142090337488146e-07
#
#
# Iteration: 40
# quick_sort Theta 0.006885940446374839
# Less than two values for merge_sort
# merge_sort Theta 0.8853901506722319
# Less than two values for heap_sort
# heap_sort Theta 0.4632861336187246
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006094600000324135
# Sample mean is:  0.0064836799999966385 Sample variance is: 7.002354296011239e-07
#
#
# Iteration: 41
# quick_sort Theta 0.005532210955132667
# Less than two values for merge_sort
# merge_sort Theta 0.6310910136053288
# Less than two values for heap_sort
# heap_sort Theta 0.1860428750758092
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005934700000125304
# Sample mean is:  0.006470290243902216 Sample variance is: 6.903279394147486e-07
#
#
# Iteration: 42
# quick_sort Theta 0.006758596063084313
# Less than two values for merge_sort
# merge_sort Theta 0.5370765596089132
# Less than two values for heap_sort
# heap_sort Theta 0.9502618912319508
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006570199999714532
# Sample mean is:  0.006472669047612033 Sample variance is: 6.741235668955571e-07
#
#
# Iteration: 43
# quick_sort Theta 0.0062821274188872515
# Less than two values for merge_sort
# merge_sort Theta 0.7339042745340875
# Less than two values for heap_sort
# heap_sort Theta 0.6245688880519478
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006707700000333716
# Sample mean is:  0.00647813488372184 Sample variance is: 6.59701039946101e-07
#
#
# Iteration: 44
# quick_sort Theta 0.0069611800912910745
# Less than two values for merge_sort
# merge_sort Theta 0.7877293736038904
# Less than two values for heap_sort
# heap_sort Theta 0.5224063328035573
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00809129999970537
# Sample mean is:  0.0065147977272669196 Sample variance is: 7.025068906556551e-07
#
#
# Iteration: 45
# quick_sort Theta 0.007604361364599828
# Less than two values for merge_sort
# merge_sort Theta 0.8840264946093672
# Less than two values for heap_sort
# heap_sort Theta 0.3020468282230163
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006677100000160863
# Sample mean is:  0.006518404444442341 Sample variance is: 6.874679964053357e-07
#
#
# Iteration: 46
# quick_sort Theta 0.007233973183512073
# Less than two values for merge_sort
# merge_sort Theta 0.2504810030217729
# Less than two values for heap_sort
# heap_sort Theta 0.15310432283877717
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0061361999996734085
# Sample mean is:  0.006510095652164755 Sample variance is: 6.756296612717843e-07
#
#
# Iteration: 47
# quick_sort Theta 0.00525045143373446
# Less than two values for merge_sort
# merge_sort Theta 0.005253577681378796
# Less than two values for heap_sort
# heap_sort Theta 0.6347837833617564
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007051600000067992
# Sample mean is:  0.00652161702126908 Sample variance is: 6.673606916135405e-07
#
#
# Iteration: 48
# quick_sort Theta 0.00670635339328563
# Less than two values for merge_sort
# merge_sort Theta 0.23902604362881197
# Less than two values for heap_sort
# heap_sort Theta 0.6016877518309331
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006631100000049628
# Sample mean is:  0.006523897916660341 Sample variance is: 6.537018606095279e-07
#
#
# Iteration: 49
# quick_sort Theta 0.006878919888749602
# Less than two values for merge_sort
# merge_sort Theta 0.2667529766797371
# Less than two values for heap_sort
# heap_sort Theta 0.07461722866870657
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0062944000001152745
# Sample mean is:  0.006519214285710442 Sample variance is: 6.414139534573672e-07
#
#
# Iteration: 50
# quick_sort Theta 0.006382238516290481
# Less than two values for merge_sort
# merge_sort Theta 0.2142370652913932
# Less than two values for heap_sort
# heap_sort Theta 0.11156523024812814
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00672439999971175
# Sample mean is:  0.006523317999990468 Sample variance is: 6.294108574619323e-07
#
#
# Iteration: 51
# quick_sort Theta 0.005939047941823837
# Less than two values for merge_sort
# merge_sort Theta 0.4264170461330591
# Less than two values for heap_sort
# heap_sort Theta 0.86500263402685
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006820400000378868
# Sample mean is:  0.006529143137252985 Sample variance is: 6.187660793062922e-07
#
#
# Iteration: 52
# quick_sort Theta 0.0070234409146443764
# Less than two values for merge_sort
# merge_sort Theta 0.008257772671600883
# Less than two values for heap_sort
# heap_sort Theta 0.6198950310114341
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006513299999824085
# Sample mean is:  0.006528838461533199 Sample variance is: 6.068714658193306e-07
#
#
# Iteration: 53
# quick_sort Theta 0.006875138117459222
# Less than two values for merge_sort
# merge_sort Theta 0.5190379792670299
# Less than two values for heap_sort
# heap_sort Theta 0.42390577916876304
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006732400000146299
# Sample mean is:  0.006532679245280616 Sample variance is: 5.961881450331817e-07
#
#
# Iteration: 54
# quick_sort Theta 0.0065804514547874475
# Less than two values for merge_sort
# merge_sort Theta 0.8679657214413279
# Less than two values for heap_sort
# heap_sort Theta 0.8409722132077138
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0070472000002155255
# Sample mean is:  0.00654220740740904 Sample variance is: 5.899592751267767e-07
#
#
# Iteration: 55
# quick_sort Theta 0.006926195519873306
# Less than two values for merge_sort
# merge_sort Theta 0.2551120793763819
# Less than two values for heap_sort
# heap_sort Theta 0.18663921510699344
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005994900000132475
# Sample mean is:  0.006532256363640375 Sample variance is: 5.845799995443823e-07
#
#
# Iteration: 56
# quick_sort Theta 0.006995651107472158
# Less than two values for merge_sort
# merge_sort Theta 0.9611312712173556
# Less than two values for heap_sort
# heap_sort Theta 0.6643854453187363
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007102200000190351
# Sample mean is:  0.006542433928578768 Sample variance is: 5.798381265252255e-07
#
#
# Iteration: 57
# quick_sort Theta 0.00703549413471205
# Less than two values for merge_sort
# merge_sort Theta 0.22761771198568603
# Less than two values for heap_sort
# heap_sort Theta 0.3223169616757755
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006053899999642454
# Sample mean is:  0.006533863157895675 Sample variance is: 5.737791819799781e-07
# Iteration: 58
# quick_sort Theta 0.005848057603282164
# Less than two values for merge_sort
# merge_sort Theta 0.5193820565227429
# Less than two values for heap_sort
# heap_sort Theta 0.016244682135157174
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0065094999999928405
# Sample mean is:  0.006533443103449074 Sample variance is: 5.638964948701542e-07
#
#
# Iteration: 59
# quick_sort Theta 0.005672914683012571
# Less than two values for merge_sort
# merge_sort Theta 0.7937872774043756
# Less than two values for heap_sort
# heap_sort Theta 0.6032439871056217
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005821100000048318
# Sample mean is:  0.006521369491527027 Sample variance is: 5.627937092414535e-07
#
#
# Iteration: 60
# quick_sort Theta 0.007017618030128167
# Less than two values for merge_sort
# merge_sort Theta 0.815515296496083
# Less than two values for heap_sort
# heap_sort Theta 0.8384935516961719
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005870099999810918
# Sample mean is:  0.0065105149999984254 Sample variance is: 5.603651932817541e-07
#
#
# Iteration: 61
# quick_sort Theta 0.006322550547756968
# Less than two values for merge_sort
# merge_sort Theta 0.6573030751054617
# Less than two values for heap_sort
# heap_sort Theta 0.5388130589451913
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059519000001273525
# Sample mean is:  0.006501357377049719 Sample variance is: 5.562106021220312e-07
#
#
# Iteration: 62
# quick_sort Theta 0.0072175343454041006
# Less than two values for merge_sort
# merge_sort Theta 0.21496760785853286
# Less than two values for heap_sort
# heap_sort Theta 0.34838224360124115
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0070172000000638945
# Sample mean is:  0.0065096774193564 Sample variance is: 5.514620727212092e-07
#
#
# Iteration: 63
# quick_sort Theta 0.006228827670410993
# Less than two values for merge_sort
# merge_sort Theta 0.15865402954472163
# Less than two values for heap_sort
# heap_sort Theta 0.11444896335295673
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005944399999862071
# Sample mean is:  0.006500704761904109 Sample variance is: 5.477002385564207e-07
#
#
# Iteration: 64
# quick_sort Theta 0.005901106529043382
# Less than two values for merge_sort
# merge_sort Theta 0.21172114532454145
# Less than two values for heap_sort
# heap_sort Theta 0.19359265418992655
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006874000000152591
# Sample mean is:  0.006506537500001741 Sample variance is: 5.412857348530577e-07
#
#
# Iteration: 65
# quick_sort Theta 0.0065421882750390445
# Less than two values for merge_sort
# merge_sort Theta 0.9854165308108233
# Less than two values for heap_sort
# heap_sort Theta 0.8565149421906301
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005909299999984796
# Sample mean is:  0.006497349230770711 Sample variance is: 5.383614166627257e-07
#
#
# Iteration: 66
# quick_sort Theta 0.006114471494818594
# Less than two values for merge_sort
# merge_sort Theta 0.5166991909309179
# Less than two values for heap_sort
# heap_sort Theta 0.9744376411438461
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006570300000021234
# Sample mean is:  0.006498454545456325 Sample variance is: 5.302838373371942e-07
#
#
# Iteration: 67
# quick_sort Theta 0.00618542086301933
# Less than two values for merge_sort
# merge_sort Theta 0.6912127604550795
# Less than two values for heap_sort
# heap_sort Theta 0.7524007919381209
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006586199999674136
# Sample mean is:  0.006499764179101367 Sample variance is: 5.224823524565922e-07
#
#
# Iteration: 68
# quick_sort Theta 0.006019230348942296
# Less than two values for merge_sort
# merge_sort Theta 0.06818524710896678
# Less than two values for heap_sort
# heap_sort Theta 0.279736627614931
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006983100000070408
# Sample mean is:  0.0065068720588215 Sample variance is: 5.181837593756411e-07
#
#
# Iteration: 69
# quick_sort Theta 0.0063272681241815475
# Less than two values for merge_sort
# merge_sort Theta 0.5245217520196035
# Less than two values for heap_sort
# heap_sort Theta 0.9080345785357452
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006419699999696604
# Sample mean is:  0.006505608695645777 Sample variance is: 5.10782383702409e-07
#
#
# Iteration: 70
# quick_sort Theta 0.0063484792209251165
# Less than two values for merge_sort
# merge_sort Theta 0.17304019865219478
# Less than two values for heap_sort
# heap_sort Theta 0.19753709992834256
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006517799999983254
# Sample mean is:  0.006505782857136312 Sample variance is: 5.034875854301708e-07
#
#
# Iteration: 71
# quick_sort Theta 0.005984075970464797
# Less than two values for merge_sort
# merge_sort Theta 0.9739418795574084
# Less than two values for heap_sort
# heap_sort Theta 0.059619672406288404
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006554399999913585
# Sample mean is:  0.006506467605626133 Sample variance is: 4.964290326220941e-07
#
#
# Iteration: 72
# quick_sort Theta 0.006110682828633851
# Less than two values for merge_sort
# merge_sort Theta 0.20899933151068073
# Less than two values for heap_sort
# heap_sort Theta 0.9407484650708399
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006633100000271952
# Sample mean is:  0.006508226388885103 Sample variance is: 4.897538105639814e-07
#
#
# Iteration: 73
# quick_sort Theta 0.0062814579178756816
# Less than two values for merge_sort
# merge_sort Theta 0.27322835040004023
# Less than two values for heap_sort
# heap_sort Theta 0.43397721011151447
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007154200000059063
# Sample mean is:  0.006517075342462829 Sample variance is: 4.886827407731792e-07
#
#
# Iteration: 74
# quick_sort Theta 0.006672621528034007
# Less than two values for merge_sort
# merge_sort Theta 0.8876227955009205
# Less than two values for heap_sort
# heap_sort Theta 0.9232163593736533
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006123000000116008
# Sample mean is:  0.006511749999998682 Sample variance is: 4.841491468342321e-07
#
#
# Iteration: 75
# quick_sort Theta 0.006338533759129109
# Less than two values for merge_sort
# merge_sort Theta 0.09673385814815327
# Less than two values for heap_sort
# heap_sort Theta 0.38998148907147656
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007170599999881233
# Sample mean is:  0.006520534666663783 Sample variance is: 4.83404432139295e-07
#
#
# Iteration: 76
# quick_sort Theta 0.005939980489046592
# Less than two values for merge_sort
# merge_sort Theta 0.21481983913437985
# Less than two values for heap_sort
# heap_sort Theta 0.3389441384754046
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007060699999783537
# Sample mean is:  0.0065276421052574635 Sample variance is: 4.808325237581042e-07
#
#
# Iteration: 77
# quick_sort Theta 0.007529917747368964
# Less than two values for merge_sort
# merge_sort Theta 0.5661266737295969
# Less than two values for heap_sort
# heap_sort Theta 0.6594245978795725
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006875500000205648
# Sample mean is:  0.006532159740256791 Sample variance is: 4.761390315025025e-07
#
#
# Iteration: 78
# quick_sort Theta 0.006524798649151045
# Less than two values for merge_sort
# merge_sort Theta 0.03245358773641016
# Less than two values for heap_sort
# heap_sort Theta 0.7241735171421139
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006269399999837333
# Sample mean is:  0.006528791025636029 Sample variance is: 4.709084992858808e-07
#
#
# Iteration: 79
# quick_sort Theta 0.006372116522441407
# Less than two values for merge_sort
# merge_sort Theta 0.02866440141540172
# Less than two values for heap_sort
# heap_sort Theta 0.880933755179324
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007120000000213622
# Sample mean is:  0.006536274683542074 Sample variance is: 4.693160327873805e-07
#
#
# Iteration: 80
# quick_sort Theta 0.006512695490415419
# Less than two values for merge_sort
# merge_sort Theta 0.5834820732387759
# Less than two values for heap_sort
# heap_sort Theta 0.3529269465471676
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007205500000054599
# Sample mean is:  0.00654463999999848 Sample variance is: 4.689778854113887e-07
#
#
# Iteration: 81
# quick_sort Theta 0.006702370103805459
# Less than two values for merge_sort
# merge_sort Theta 0.906758739321458
# Less than two values for heap_sort
# heap_sort Theta 0.5862622157568633
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0069813000000067404
# Sample mean is:  0.006550030864196113 Sample variance is: 4.6551294831799654e-07
#
#
# Iteration: 82
# quick_sort Theta 0.0062524059456408815
# Less than two values for merge_sort
# merge_sort Theta 0.3938564694258979
# Less than two values for heap_sort
# heap_sort Theta 0.7394838825724069
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0060310000003482855
# Sample mean is:  0.006543701219515042 Sample variance is: 4.630811776882644e-07
#
#
# Iteration: 83
# quick_sort Theta 0.0066958175783477444
# Less than two values for merge_sort
# merge_sort Theta 0.9490793514463884
# Less than two values for heap_sort
# heap_sort Theta 0.5282293043150809
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005968200000097568
# Sample mean is:  0.006536767469883507 Sample variance is: 4.6144419087494685e-07
#
#
# Iteration: 84
# quick_sort Theta 0.007272322827546364
# Less than two values for merge_sort
# merge_sort Theta 0.4505333280378421
# Less than two values for heap_sort
# heap_sort Theta 0.5781221959315272
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007042599999749655
# Sample mean is:  0.006542789285715246 Sample variance is: 4.5896057572089084e-07
#
#
# Iteration: 85
# quick_sort Theta 0.006859971496492556
# Less than two values for merge_sort
# merge_sort Theta 0.08618474300101986
# Less than two values for heap_sort
# heap_sort Theta 0.062258399800860675
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007036799999696086
# Sample mean is:  0.006548601176467962 Sample variance is: 4.5639839776214547e-07
#
#
# Iteration: 86
# quick_sort Theta 0.006528764723343316
# Less than two values for merge_sort
# merge_sort Theta 0.45755114857714174
# Less than two values for heap_sort
# heap_sort Theta 0.4032640917820841
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007086600000093313
# Sample mean is:  0.006554856976742676 Sample variance is: 4.5441791780018586e-07
#
#
# Iteration: 87
# quick_sort Theta 0.006337742638105886
# Less than two values for merge_sort
# merge_sort Theta 0.10870679407472228
# Less than two values for heap_sort
# heap_sort Theta 0.22697438995834318
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00586730000031821
# Sample mean is:  0.00654695402299067 Sample variance is: 4.5456599765125733e-07
#
#
# Iteration: 88
# quick_sort Theta 0.006361247283676123
# Less than two values for merge_sort
# merge_sort Theta 0.13963789059947085
# Less than two values for heap_sort
# heap_sort Theta 0.5750619297251784
# Chosen algorithm is:  quick_sort with reward: 0.006289100000230974
# Sample mean is:  0.006544023863641128 Sample variance is: 4.501474424924675e-07
#
#
# Iteration: 89
# quick_sort Theta 0.00667814926694565
# Less than two values for merge_sort
# merge_sort Theta 0.26428617689414424
# Less than two values for heap_sort
# heap_sort Theta 0.7119525269011268
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005860600000232807
# Sample mean is:  0.006536344943827551 Sample variance is: 4.5027859729626176e-07
#
#
# Iteration: 90
# quick_sort Theta 0.006294179702830263
# Less than two values for merge_sort
# merge_sort Theta 0.004605330709891109
# Less than two values for heap_sort
# heap_sort Theta 0.6576123346986871
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006495500000255561
# Sample mean is:  0.006495500000255561 Sample variance is: 0.0
#
#
# Iteration: 91
# quick_sort Theta 0.006382021152218581
# Less than two values for merge_sort
# merge_sort Theta 0.8626192190625191
# Less than two values for heap_sort
# heap_sort Theta 0.7339767885765054
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005986599999687314
# Sample mean is:  0.006530236666670438 Sample variance is: 4.4859618520545024e-07
#
#
# Iteration: 92
# quick_sort Theta 0.006570511741330836
# Less than two values for merge_sort
# merge_sort Theta 0.23637535514682284
# Less than two values for heap_sort
# heap_sort Theta 0.8551924932363044
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007017399999767804
# Sample mean is:  0.006535590109891288 Sample variance is: 4.462458986852972e-07
#
#
# Iteration: 93
# quick_sort Theta 0.00695551494745931
# Less than two values for merge_sort
# merge_sort Theta 0.7430793456390518
# Less than two values for heap_sort
# heap_sort Theta 0.4233599511744026
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007054499999867403
# Sample mean is:  0.006541230434782333 Sample variance is: 4.442904068903088e-07
#
#
# Iteration: 94
# quick_sort Theta 0.006470749048002041
# Less than two values for merge_sort
# merge_sort Theta 0.927674947632199
# Less than two values for heap_sort
# heap_sort Theta 0.6097844411331683
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005921699999817065
# Sample mean is:  0.006534568817202061 Sample variance is: 4.4359578837547954e-07
#
#
# Iteration: 95
# quick_sort Theta 0.006403850878600425
# Less than two values for merge_sort
# merge_sort Theta 0.8133780590111078
# Less than two values for heap_sort
# heap_sort Theta 0.8134865912307511
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00587150000001202
# Sample mean is:  0.006527514893614933 Sample variance is: 4.4350416317531833e-07
#
#
# Iteration: 96
# quick_sort Theta 0.006597809597590058
# Less than two values for merge_sort
# merge_sort Theta 0.4588203570762528
# Less than two values for heap_sort
# heap_sort Theta 0.024928255445996306
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005846700000347482
# Sample mean is:  0.006520348421054223 Sample variance is: 4.436633812223493e-07
#
#
# Iteration: 97
# quick_sort Theta 0.006802373927541033
# Less than two values for merge_sort
# merge_sort Theta 0.7737131134698508
# Less than two values for heap_sort
# heap_sort Theta 0.47720059631241674
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00590059999967707
# Sample mean is:  0.006513892708331544 Sample variance is: 4.4300112920993654e-07
#
#
# Iteration: 98
# quick_sort Theta 0.00656767960986551
# Less than two values for merge_sort
# merge_sort Theta 0.6278713984719603
# Less than two values for heap_sort
# heap_sort Theta 0.8248252355904834
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005954100000053586
# Sample mean is:  0.006508121649483318 Sample variance is: 4.4163139880136904e-07
#
#
# Iteration: 99
# quick_sort Theta 0.006438175393620339
# Less than two values for merge_sort
# merge_sort Theta 0.2948272073918159
# Less than two values for heap_sort
# heap_sort Theta 0.5528733072497777
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006909599999744387
# Sample mean is:  0.006512218367343125 Sample variance is: 4.3875291638707455e-07
#
#
# Iteration: 100
# quick_sort Theta 0.00694967304471537
# Less than two values for merge_sort
# merge_sort Theta 0.15879233925285707
# Less than two values for heap_sort
# heap_sort Theta 0.6749280867425468
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007028200000149809
# Sample mean is:  0.00651743030302804 Sample variance is: 4.369831675580038e-07
#
#
# Iteration: 101
# quick_sort Theta 0.0063028174856723075
# Less than two values for merge_sort
# merge_sort Theta 0.5331714644992165
# Less than two values for heap_sort
# heap_sort Theta 0.8416369084230136
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007064699999773438
# Sample mean is:  0.006522902999995495 Sample variance is: 4.355784266800841e-07
#
#
# Iteration: 102
# quick_sort Theta 0.006617594757437999
# Less than two values for merge_sort
# merge_sort Theta 0.6864645647110243
# Less than two values for heap_sort
# heap_sort Theta 0.48204455000131774
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006985700000313955
# Sample mean is:  0.006527485148513499 Sample variance is: 4.333653774942874e-07
#
#
# Iteration: 103
# quick_sort Theta 0.006211179704709443
# Less than two values for merge_sort
# merge_sort Theta 0.6472276248469317
# Less than two values for heap_sort
# heap_sort Theta 0.5871199671053348
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006509199999982229
# Sample mean is:  0.006527305882351428 Sample variance is: 4.2911994309481806e-07
#
#
# Iteration: 104
# quick_sort Theta 0.00630776779302947
# Less than two values for merge_sort
# merge_sort Theta 0.9681159550298846
# Less than two values for heap_sort
# heap_sort Theta 0.026397860127383543
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006781600000067556
# Sample mean is:  0.006529774757280711 Sample variance is: 4.255754550835394e-07
#
#
# Iteration: 105
# quick_sort Theta 0.00703145472824591
# Less than two values for merge_sort
# merge_sort Theta 0.7428367571315727
# Less than two values for heap_sort
# heap_sort Theta 0.75647447699297
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0066157000001112465
# Sample mean is:  0.006530600961538697 Sample variance is: 4.2155369258806317e-07
#
#
# Iteration: 106
# quick_sort Theta 0.007031527568219264
# Less than two values for merge_sort
# merge_sort Theta 0.6976882128363551
# Less than two values for heap_sort
# heap_sort Theta 0.4637026620915734
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005895900000268739
# Sample mean is:  0.006524556190478982 Sample variance is: 4.2133897826088873e-07
#
#
# Iteration: 107
# quick_sort Theta 0.006345349809453205
# Less than two values for merge_sort
# merge_sort Theta 0.9419972827115037
# Less than two values for heap_sort
# heap_sort Theta 0.20913349457228247
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006604600000173377
# Sample mean is:  0.006525311320759119 Sample variance is: 4.1742395552225726e-07
#
#
# Iteration: 108
# quick_sort Theta 0.006430782978001935
# Less than two values for merge_sort
# merge_sort Theta 0.9165317059627999
# Less than two values for heap_sort
# heap_sort Theta 0.40236608030675935
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007359199999882549
# Sample mean is:  0.006533104672900459 Sample variance is: 4.1996084884491967e-07
#
#
# Iteration: 109
# quick_sort Theta 0.006355951762338019
# Less than two values for merge_sort
# merge_sort Theta 0.5439318516771512
# Less than two values for heap_sort
# heap_sort Theta 0.877731685065949
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007120199999917531
# Sample mean is:  0.00653854074074321 Sample variance is: 4.1923426166096165e-07
#
#
# Iteration: 110
# quick_sort Theta 0.006311692285923196
# Less than two values for merge_sort
# merge_sort Theta 0.3631853934203352
# Less than two values for heap_sort
# heap_sort Theta 0.12135806659652837
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007039900000108901
# Sample mean is:  0.006543140366975922 Sample variance is: 4.1767298441407505e-07
#
#
# Iteration: 111
# quick_sort Theta 0.0062761244952397564
# Less than two values for merge_sort
# merge_sort Theta 0.9452083102774849
# Less than two values for heap_sort
# heap_sort Theta 0.3094780695174434
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006589500000245607
# Sample mean is:  0.006543561818187465 Sample variance is: 4.1389531798552254e-07
#
#
# Iteration: 112
# quick_sort Theta 0.006292008105180407
# Less than two values for merge_sort
# merge_sort Theta 0.285401505918229
# Less than two values for heap_sort
# heap_sort Theta 0.6917962992472891
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071703999997225765
# Sample mean is:  0.006549209009012106 Sample variance is: 4.136745154000939e-07
#
#
# Iteration: 113
# quick_sort Theta 0.0061249052372549075
# Less than two values for merge_sort
# merge_sort Theta 0.5187292049449457
# Less than two values for heap_sort
# heap_sort Theta 0.8193976376040703
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0062720000000808795
# Sample mean is:  0.00654673392857522 Sample variance is: 4.1066098151292965e-07
#
#
# Iteration: 114
# quick_sort Theta 0.0068242892121527
# Less than two values for merge_sort
# merge_sort Theta 0.5823535167417415
# Less than two values for heap_sort
# heap_sort Theta 0.2765362221467971
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007046300000183692
# Sample mean is:  0.00655115486726202 Sample variance is: 4.0921581980865355e-07
#
#
# Iteration: 115
# quick_sort Theta 0.00676972066574059
# Less than two values for merge_sort
# merge_sort Theta 0.7693966489939883
# Less than two values for heap_sort
# heap_sort Theta 0.8550711395129693
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005792299999939132
# Sample mean is:  0.006544498245618837 Sample variance is: 4.1063330647634766e-07
#
#
# Iteration: 116
# quick_sort Theta 0.006912865036103095
# Less than two values for merge_sort
# merge_sort Theta 0.49430535265569486
# Less than two values for heap_sort
# heap_sort Theta 0.375977442432192
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007152399999995396
# Sample mean is:  0.006549784347830807 Sample variance is: 4.102480700040806e-07
#
#
# Iteration: 117
# quick_sort Theta 0.006578431508343169
# Less than two values for merge_sort
# merge_sort Theta 0.13789331758939938
# Less than two values for heap_sort
# heap_sort Theta 0.31916887994402243
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007146599999941827
# Sample mean is:  0.006554929310349005 Sample variance is: 4.0975557223201367e-07
#
#
# Iteration: 118
# quick_sort Theta 0.00663098063345857
# Less than two values for merge_sort
# merge_sort Theta 0.7250045685207962
# Less than two values for heap_sort
# heap_sort Theta 0.2605554925560871
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006524599999920611
# Sample mean is:  0.0065546700854735495 Sample variance is: 4.062611827681446e-07
# Iteration: 119
# quick_sort Theta 0.006320393702024677
# Less than two values for merge_sort
# merge_sort Theta 0.47727283367760986
# Less than two values for heap_sort
# heap_sort Theta 0.8054900747708602
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006980000000112341
# Sample mean is:  0.006558274576275573 Sample variance is: 4.0433839679995267e-07
#
#
# Iteration: 120
# quick_sort Theta 0.0065263666530618394
# Less than two values for merge_sort
# merge_sort Theta 0.3520594455432615
# Less than two values for heap_sort
# heap_sort Theta 0.3216942718784198
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007080900000346446
# Sample mean is:  0.006562666386561883 Sample variance is: 4.032165788619022e-07
#
#
# Iteration: 121
# quick_sort Theta 0.006986963949117577
# Less than two values for merge_sort
# merge_sort Theta 0.26204159190200815
# Less than two values for heap_sort
# heap_sort Theta 0.9779611874208968
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005927899999733199
# Sample mean is:  0.006557376666671643 Sample variance is: 4.0318619595026537e-07
#
#
# Iteration: 122
# quick_sort Theta 0.006593298170565136
# Less than two values for merge_sort
# merge_sort Theta 0.21951879243399497
# Less than two values for heap_sort
# heap_sort Theta 0.22854308782395738
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006992699999955221
# Sample mean is:  0.0065609743801698555 Sample variance is: 4.014073037181878e-07
#
#
# Iteration: 123
# quick_sort Theta 0.006629016472711583
# Less than two values for merge_sort
# merge_sort Theta 0.9823972998935786
# Less than two values for heap_sort
# heap_sort Theta 0.14397198301171477
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007031999999981053
# Sample mean is:  0.006564835245906012 Sample variance is: 3.9992074030936775e-07
#
#
# Iteration: 124
# quick_sort Theta 0.00664069945410729
# Less than two values for merge_sort
# merge_sort Theta 0.8863201336979643
# Less than two values for heap_sort
# heap_sort Theta 0.6631755634125706
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007038100000045233
# Sample mean is:  0.0065686829268339735 Sample variance is: 3.9847551929662565e-07
#
#
# Iteration: 125
# quick_sort Theta 0.006533162607994147
# Less than two values for merge_sort
# merge_sort Theta 0.8332458171952029
# Less than two values for heap_sort
# heap_sort Theta 0.7258993931666009
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005798300000151357
# Sample mean is:  0.006562470161296211 Sample variance is: 4.0000961708638104e-07
#
#
# Iteration: 126
# quick_sort Theta 0.006800602918044649
# Less than two values for merge_sort
# merge_sort Theta 0.011914153164777619
# Less than two values for heap_sort
# heap_sort Theta 0.5011943514515068
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005876499999885709
# Sample mean is:  0.006556982400004927 Sample variance is: 4.0054386512446414e-07
#
#
# Iteration: 127
# quick_sort Theta 0.006718070172458961
# Less than two values for merge_sort
# merge_sort Theta 0.6377046537227207
# Less than two values for heap_sort
# heap_sort Theta 0.703890324824886
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071428999999625375
# Sample mean is:  0.00656163253968713 Sample variance is: 4.000679204429844e-07
#
#
# Iteration: 128
# quick_sort Theta 0.006761613118087254
# Less than two values for merge_sort
# merge_sort Theta 0.1906879744171881
# Less than two values for heap_sort
# heap_sort Theta 0.7942189344292429
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005803699999887613
# Sample mean is:  0.006555664566932803 Sample variance is: 4.0140548338547915e-07
#
#
# Iteration: 129
# quick_sort Theta 0.0069794247636506155
# Less than two values for merge_sort
# merge_sort Theta 0.24596474827761894
# Less than two values for heap_sort
# heap_sort Theta 0.9653574999069567
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005885900000066613
# Sample mean is:  0.006550432031254161 Sample variance is: 4.0174669060931947e-07
#
#
# Iteration: 130
# quick_sort Theta 0.006586065433427331
# Less than two values for merge_sort
# merge_sort Theta 0.0012244605644169404
# Less than two values for heap_sort
# heap_sort Theta 0.8413661284998946
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0077662999997301085
# Sample mean is:  0.007130899999992835 Sample variance is: 4.037331596661277e-07
#
#
# Iteration: 131
# quick_sort Theta 0.006080340160083746
# merge_sort Theta 0.010335163076588626
# Less than two values for heap_sort
# heap_sort Theta 0.5952247450190616
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005846499999734078
# Sample mean is:  0.006544975193800517 Sample variance is: 4.024438407776625e-07
#
#
# Iteration: 132
# quick_sort Theta 0.005837702463277896
# merge_sort Theta 0.00797172191571712
# Less than two values for heap_sort
# heap_sort Theta 0.697420318345579
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006532099999731145
# Sample mean is:  0.006544876153846137 Sample variance is: 3.993493842752473e-07
#
#
# Iteration: 133
# quick_sort Theta 0.006840438359900952
# merge_sort Theta 0.006362509090984197
# Less than two values for heap_sort
# heap_sort Theta 0.0351077514414011
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007675299999846175
# Sample mean is:  0.007312366666610615 Sample variance is: 3.350157419641554e-07
#
#
# Iteration: 134
# quick_sort Theta 0.006918026294230816
# merge_sort Theta 0.005120072390072875
# Less than two values for heap_sort
# heap_sort Theta 0.2651433599338189
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007787900000039372
# Sample mean is:  0.007431249999967804 Sample variance is: 2.9366154732346637e-07
#
#
# Iteration: 135
# quick_sort Theta 0.006454280844261945
# merge_sort Theta 0.008871415649926563
# Less than two values for heap_sort
# heap_sort Theta 0.9397222116184895
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006867699999929755
# Sample mean is:  0.006547340458014714 Sample variance is: 3.970903790475783e-07
#
#
# Iteration: 136
# quick_sort Theta 0.0067414378807654106
# merge_sort Theta 0.006105191888845303
# Less than two values for heap_sort
# heap_sort Theta 0.2269437915223772
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0076164000001881504
# Sample mean is:  0.007468280000011873 Sample variance is: 2.4041412147182815e-07
#
#
# Iteration: 137
# quick_sort Theta 0.00706670730549652
# merge_sort Theta 0.008104085129247686
# Less than two values for heap_sort
# heap_sort Theta 0.09631781700385467
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059363000000303145
# Sample mean is:  0.0065427113636360446 Sample variance is: 3.9688925403467684e-07
#
#
# Iteration: 138
# quick_sort Theta 0.00668495052835855
# merge_sort Theta 0.007660452043584507
# Less than two values for heap_sort
# heap_sort Theta 0.39605029258443036
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006993099999817787
# Sample mean is:  0.006546097744359216 Sample variance is: 3.9541884412619173e-07
#
#
# Iteration: 139
# quick_sort Theta 0.006862037085598825
# merge_sort Theta 0.011010328344833828
# ...
# quick_sort Theta 0.005639957037528318
# merge_sort Theta 0.004120844529293754
# heap_sort Theta 0.013643422465254157
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025642999999035965
# Sample mean is:  0.004208498643829528 Sample variance is: 4.514918347104338e-06
#
#
# Iteration: 1944
# quick_sort Theta 0.00605706717319449
# merge_sort Theta 0.004302807037233935
# heap_sort Theta 0.011692744560781808
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025828999996519997
# Sample mean is:  0.00420733915834866 Sample variance is: 4.51358151953431e-06
#
#
# Iteration: 1945
# quick_sort Theta 0.006004218274204032
# merge_sort Theta 0.004190783492330822
# heap_sort Theta 0.009214981288817712
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025670999998510524
# Sample mean is:  0.004206170064151584 Sample variance is: 4.512280653806194e-06
#
#
# Iteration: 1946
# quick_sort Theta 0.005151938107569919
# merge_sort Theta 0.004109922239988876
# heap_sort Theta 0.010603995327510602
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025866999999379914
# Sample mean is:  0.004205016595444879 Sample variance is: 4.510933456247104e-06
#
#
# Iteration: 1947
# quick_sort Theta 0.005402114728711156
# merge_sort Theta 0.004319504961563803
# heap_sort Theta 0.010221961416622967
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025451999999859254
# Sample mean is:  0.0042038352313199965 Sample variance is: 4.509682279611185e-06
#
#
# Iteration: 1948
# quick_sort Theta 0.006287950930530207
# merge_sort Theta 0.004126943464974701
# heap_sort Theta 0.009326935723006876
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002566099999967264
# Sample mean is:  0.004202670412521026 Sample variance is: 4.5083811322026624e-06
#
#
# Iteration: 1949
# quick_sort Theta 0.0064972657929102135
# merge_sort Theta 0.004247804066515684
# heap_sort Theta 0.011052477402540601
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002556899999945017
# Sample mean is:  0.004201500710735258 Sample variance is: 4.5071005736085736e-06
#
#
# Iteration: 1950
# quick_sort Theta 0.005775297539600291
# merge_sort Theta 0.004290887137547883
# heap_sort Theta 0.009907694390368286
# Chosen algorithm is:  merge_sort with reward: 0.003607600000123057
# Sample mean is:  0.004201078906253289 Sample variance is: 4.504149839922833e-06
#
#
# Iteration: 1951
# quick_sort Theta 0.006009806365484992
# merge_sort Theta 0.004370920775475161
# heap_sort Theta 0.006482243908130025
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002568399999745452
# Sample mean is:  0.004199920156142212 Sample variance is: 4.502843664411809e-06
#
#
# Iteration: 1952
# quick_sort Theta 0.005931515573804768
# merge_sort Theta 0.004451424784713977
# heap_sort Theta 0.009708250491514043
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025802000000112457
# Sample mean is:  0.004198771418442829 Sample variance is: 4.501509472274333e-06
#
#
# Iteration: 1953
# quick_sort Theta 0.005587738361746718
# merge_sort Theta 0.004210198125855437
# heap_sort Theta 0.009816266247207361
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002497500000117725
# Sample mean is:  0.004197565698089657 Sample variance is: 4.500368978800882e-06
#
#
# Iteration: 1954
# quick_sort Theta 0.005993535634796475
# merge_sort Theta 0.0039099671802897825
# heap_sort Theta 0.011823606185822847
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002574099999947066
# Sample mean is:  0.004196415934847346 Sample variance is: 4.4990470278752875e-06
#
#
# Iteration: 1955
# quick_sort Theta 0.005695010879379129
# merge_sort Theta 0.0039720484853967555
# heap_sort Theta 0.010268393932126006
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024156999998012907
# Sample mean is:  0.004195155697101383 Sample variance is: 4.498105526168292e-06
#
#
# Iteration: 1956
# quick_sort Theta 0.0059467587722224794
# merge_sort Theta 0.0045762008785559735
# heap_sort Theta 0.009457901014050763
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002482700000200566
# Sample mean is:  0.004193944625179954 Sample variance is: 4.496996845178665e-06
#
#
# Iteration: 1957
# quick_sort Theta 0.005845408801121768
# merge_sort Theta 0.003621328662039918
# heap_sort Theta 0.009433330484574325
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002500999999938358
# Sample mean is:  0.004192748197882963 Sample variance is: 4.495842809259085e-06
#
#
# Iteration: 1958
# quick_sort Theta 0.005350109502670733
# merge_sort Theta 0.004083975997301743
# heap_sort Theta 0.008763840243664955
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025399000001016248
# Sample mean is:  0.004191580932206564 Sample variance is: 4.494595729486967e-06
#
#
# Iteration: 1959
# quick_sort Theta 0.005937167284220003
# merge_sort Theta 0.004205877424237224
# heap_sort Theta 0.008729806327238679
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002583299999969313
# Sample mean is:  0.004190445942134413 Sample variance is: 4.493247914698414e-06
#
#
# Iteration: 1960
# quick_sort Theta 0.006050616092087584
# merge_sort Theta 0.004200156307098193
# heap_sort Theta 0.009381246578066103
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002520600000025297
# Sample mean is:  0.0041892683356872275 Sample variance is: 4.492044227204995e-06
#
#
# Iteration: 1961
# quick_sort Theta 0.005856990308819981
# merge_sort Theta 0.004403431548656452
# heap_sort Theta 0.01082181514415437
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024932999999691674
# Sample mean is:  0.00418807315010885 Sample variance is: 4.4909041548805815e-06
#
#
# Iteration: 1962
# quick_sort Theta 0.0058160567418586925
# merge_sort Theta 0.004140856809250236
# heap_sort Theta 0.010194559018170068
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024823000003380002
# Sample mean is:  0.004186871901411828 Sample variance is: 4.48978916109595e-06
#
#
# Iteration: 1963
# quick_sort Theta 0.005594921946379078
# merge_sort Theta 0.004303432571295313
# heap_sort Theta 0.010328683982682356
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024846000001161883
# Sample mean is:  0.004185673962002049 Sample variance is: 4.4886673463501726e-06
#
#
# Iteration: 1964
# quick_sort Theta 0.005237860633649088
# merge_sort Theta 0.004348294538789292
# heap_sort Theta 0.009974984041823415
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025590999998712505
# Sample mean is:  0.004184530098456247 Sample variance is: 4.487370029141503e-06
#
#
# Iteration: 1965
# quick_sort Theta 0.00604843930555621
# merge_sort Theta 0.0039082271930646895
# heap_sort Theta 0.009469990259616819
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0033269999998992716
# Sample mean is:  0.004183927477164218 Sample variance is: 4.484732974380359e-06
#
#
# Iteration: 1966
# quick_sort Theta 0.006148454646589383
# merge_sort Theta 0.004089630493319717
# heap_sort Theta 0.009459403700755866
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002485900000010588
# Sample mean is:  0.004182735042138127 Sample variance is: 4.483606948784397e-06
#
#
# Iteration: 1967
# quick_sort Theta 0.0057716842913105686
# merge_sort Theta 0.004697403379382802
# heap_sort Theta 0.007882104191119852
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024823999997352075
# Sample mean is:  0.004181541824564512 Sample variance is: 4.482488003828597e-06
#
#
# Iteration: 1968
# quick_sort Theta 0.0058986918852285426
# merge_sort Theta 0.004190570433607418
# heap_sort Theta 0.010628126820646365
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025823000000855245
# Sample mean is:  0.004180420336609056 Sample variance is: 4.481136876815196e-06
#
#
# Iteration: 1969
# quick_sort Theta 0.005933026002074947
# merge_sort Theta 0.004462234334611138
# heap_sort Theta 0.00870035595401026
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025248000001738546
# Sample mean is:  0.0041792601261420375 Sample variance is: 4.479916148681741e-06
#
#
# Iteration: 1970
# quick_sort Theta 0.006101309121172872
# merge_sort Theta 0.004247264940942422
# heap_sort Theta 0.009543533789400243
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002369999999700667
# Sample mean is:  0.0041779931372579755 Sample variance is: 4.479069659706937e-06
#
#
# Iteration: 1971
# quick_sort Theta 0.005780373740224756
# merge_sort Theta 0.0041070994624663815
# heap_sort Theta 0.009511293542195319
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002560799999628216
# Sample mean is:  0.004176861441570341 Sample variance is: 4.477764141032473e-06
#
#
# Iteration: 1972
# quick_sort Theta 0.005987345115373569
# merge_sort Theta 0.0041798137074023425
# heap_sort Theta 0.009356845184253754
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002499900000202615
# Sample mean is:  0.004175688741261692 Sample variance is: 4.476598035411214e-06
#
#
# Iteration: 1973
# quick_sort Theta 0.005181006242774779
# merge_sort Theta 0.0043048451505786145
# heap_sort Theta 0.009732260247177054
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002553699999680248
# Sample mean is:  0.004174555276033473 Sample variance is: 4.475306917993023e-06
#
#
# Iteration: 1974
# quick_sort Theta 0.005921414448305184
# merge_sort Theta 0.003500741229535421
# heap_sort Theta 0.009964751202075083
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002479399999629095
# Sample mean is:  0.004173371508382352 Sample variance is: 4.474186972338796e-06
#
#
# Iteration: 1975
# quick_sort Theta 0.0058819278120797154
# merge_sort Theta 0.004106835368465992
# heap_sort Theta 0.011048212051586877
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002552899999955116
# Sample mean is:  0.004172240683882404 Sample variance is: 4.472895910558198e-06
#
#
# Iteration: 1976
# quick_sort Theta 0.005153843571242932
# merge_sort Theta 0.004391274041726452
# heap_sort Theta 0.010329105292953653
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024831999999150867
# Sample mean is:  0.0041710628312436535 Sample variance is: 4.471764789972781e-06
#
#
# Iteration: 1977
# quick_sort Theta 0.006085601595878373
# merge_sort Theta 0.004375583293964397
# heap_sort Theta 0.00880834624945121
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002009999999700085
# Sample mean is:  0.004169556864113658 Sample variance is: 4.471900799228751e-06
#
#
# Iteration: 1978
# quick_sort Theta 0.0054356165228310865
# merge_sort Theta 0.003987090305064088
# heap_sort Theta 0.00926866481875888
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024836000002324
# Sample mean is:  0.004168382799445217 Sample variance is: 4.470764706140487e-06
#
#
# Iteration: 1979
# quick_sort Theta 0.005900404919641604
# merge_sort Theta 0.003481759363828312
# heap_sort Theta 0.010670605316089963
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025465999997322797
# Sample mean is:  0.004167254210162188 Sample variance is: 4.46948257977766e-06
#
#
# Iteration: 1980
# quick_sort Theta 0.0056205757250419085
# merge_sort Theta 0.004029844170561737
# heap_sort Theta 0.008351456668283108
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0022580999998353946
# Sample mean is:  0.004165926564675173 Sample variance is: 4.46890737292026e-06
#
#
# Iteration: 1981
# quick_sort Theta 0.005873585889786914
# merge_sort Theta 0.0043769876527379745
# heap_sort Theta 0.007811258247440058
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003319400000236783
# Sample mean is:  0.004165338290481679 Sample variance is: 4.466299452045797e-06
#
#
# Iteration: 1982
# quick_sort Theta 0.005523814816107921
# merge_sort Theta 0.0038823420402156294
# heap_sort Theta 0.009737338685714152
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025467000000389817
# Sample mean is:  0.004164214236113316 Sample variance is: 4.465016029147047e-06
#
#
# Iteration: 1983
# quick_sort Theta 0.005398690334768441
# merge_sort Theta 0.004075169920077954
# heap_sort Theta 0.008637333172358302
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002407499999662832
# Sample mean is:  0.004162995142264287 Sample variance is: 4.464057588675069e-06
#
#
# Iteration: 1984
# quick_sort Theta 0.005432383985695383
# merge_sort Theta 0.004044559616372418
# heap_sort Theta 0.010353033863463295
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025640000003477326
# Sample mean is:  0.0041618862690729445 Sample variance is: 4.462733701568517e-06
#
#
# Iteration: 1985
# quick_sort Theta 0.005504371824654444
# merge_sort Theta 0.003957003151026807
# heap_sort Theta 0.009712593453715262
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025354999997944105
# Sample mean is:  0.004160759182261248 Sample variance is: 4.4614728322108e-06
#
#
# Iteration: 1986
# quick_sort Theta 0.006108220884743514
# merge_sort Theta 0.0038904625612907018
# heap_sort Theta 0.009857852959802916
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025448000001233595
# Sample mean is:  0.004159640096955058 Sample variance is: 4.4601903134088255e-06
#
#
# Iteration: 1987
# quick_sort Theta 0.0055470418772068306
# merge_sort Theta 0.004323535709237983
# heap_sort Theta 0.009900637860411479
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002539399999932357
# Sample mean is:  0.004158518823531513 Sample variance is: 4.458919151420197e-06
#
#
# Iteration: 1988
# quick_sort Theta 0.005521832789170874
# merge_sort Theta 0.004327821416711202
# heap_sort Theta 0.007894157438160208
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002522700000099576
# Sample mean is:  0.004157387551869388 Sample variance is: 4.4576848039210235e-06
#
#
# Iteration: 1989
# quick_sort Theta 0.0055452392744686566
# merge_sort Theta 0.003886335477931215
# heap_sort Theta 0.009203729556455284
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002466699999786215
# Sample mean is:  0.004156219143056614 Sample variance is: 4.456578213859248e-06
#
#
# Iteration: 1990
# quick_sort Theta 0.005569444784219569
# merge_sort Theta 0.004232786622013249
# heap_sort Theta 0.008345860121448147
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025325000001430453
# Sample mean is:  0.004155097790057365 Sample variance is: 4.455319971372283e-06
#
#
# Iteration: 1991
# quick_sort Theta 0.006064747182774587
# merge_sort Theta 0.00425066923779854
# heap_sort Theta 0.009860012746078698
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002505899999960093
# Sample mean is:  0.00415395962733128 Sample variance is: 4.4541209764268285e-06
#
#
# Iteration: 1992
# quick_sort Theta 0.005737580202823119
# merge_sort Theta 0.004009602686724234
# heap_sort Theta 0.0070308488542842875
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024710999996386818
# Sample mean is:  0.004152799034484595 Sample variance is: 4.453000936726998e-06
#
#
# Iteration: 1993
# quick_sort Theta 0.005915799920152637
# merge_sort Theta 0.004662634922792342
# heap_sort Theta 0.010271270623888438
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002510300000267307
# Sample mean is:  0.004151667057203949 Sample variance is: 4.4517900083114824e-06
#
#
# Iteration: 1994
# quick_sort Theta 0.005596152509406936
# merge_sort Theta 0.004126626591807799
# heap_sort Theta 0.010473155391306298
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025979000001825625
# Sample mean is:  0.004150596969699114 Sample variance is: 4.450385558857254e-06
#
#
# Iteration: 1995
# quick_sort Theta 0.005869977776284204
# merge_sort Theta 0.004002587042741137
# heap_sort Theta 0.010300039245883661
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025215999999090855
# Sample mean is:  0.0041494758430853556 Sample variance is: 4.449147719391922e-06
#
#
# Iteration: 1996
# quick_sort Theta 0.005626984322249992
# merge_sort Theta 0.003944666816698003
# heap_sort Theta 0.01045404319715651
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0035735000001295703
# Sample mean is:  0.004149079711143846 Sample variance is: 4.446315788367058e-06
#
#
# Iteration: 1997
# quick_sort Theta 0.006090367970518059
# merge_sort Theta 0.003857787961725041
# heap_sort Theta 0.01141010079028508
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0024817000003167777
# Sample mean is:  0.004147933745706852 Sample variance is: 4.445169347509457e-06
#
#
# Iteration: 1998
# quick_sort Theta 0.006080978394699068
# merge_sort Theta 0.0038413444499150683
# heap_sort Theta 0.009550464284854164
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002483499999925698
# Sample mean is:  0.0041467905906616715 Sample variance is: 4.4440177456143695e-06
#
#
# Iteration: 1999
# quick_sort Theta 0.005828798209844191
# merge_sort Theta 0.004432956775643579
# heap_sort Theta 0.009149821047565981
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025753999998414656
# Sample mean is:  0.00414571207961787 Sample variance is: 4.442661229403797e-06

# %%
sample_mean_TS_stationary, sample_count_TS_stationary,rewards_TS_stationary,cum_rewards_TS_stationary,n_TS_stationary = list_iteration_results_TS_stationary
plot_history(rewards_TS_stationary,cum_rewards_TS_stationary, sample_count_TS_stationary, sample_mean_TS_stationary)
print("Total reward", np.round(total_reward_TS_stationary,4))
# Out:
# Average rewards per algo {'quick_sort': 0.005747554953271663, 'merge_sort': 0.00414571207961787, 'heap_sort': 0.009654600000033042}
# Count per chosen algo {'quick_sort': 535, 'merge_sort': 1457, 'heap_sort': 8}
# Total reward 9.1925

# %%
array_rewards = np.array(rewards_TS_stationary)
algo = rpt.Pelt(model="rbf").fit(array_rewards)
result = algo.predict(100)
result
# Out:
# [500, 1000, 1500, 2000]

# %%
array_rewards_ma = moving_average(array_rewards, 3)*10
R, maxes = oncd.online_changepoint_detection(array_rewards_ma, partial(oncd.constant_hazard, 250), oncd.StudentT(0.1, .01, 1, 0))
Nw=3
for i, elem in enumerate(R[Nw,Nw:-1]):
    if elem > 0.2 and i!=0:
        print(i,elem)
        
fig, ax = plt.subplots(figsize=[18, 16])
ax = fig.add_subplot(3, 1, 1)
ax.plot(array_rewards_ma)
ax = fig.add_subplot(3, 1, 2, sharex=ax)
sparsity = 5  # only plot every fifth data for faster display
ax.pcolor(np.array(range(0, len(R[:,0]), sparsity)), 
          np.array(range(0, len(R[:,0]), sparsity)), 
          -np.log(R[0:-1:sparsity, 0:-1:sparsity]), 
          cmap=cm.Greys, vmin=0, vmax=30)
ax = fig.add_subplot(3, 1, 3, sharex=ax)
Nw=10;
ax.plot(R[Nw,Nw:-1])
# Out:
# 498 0.2142996570762441
# 499 0.6351803897595449
# 998 0.5014152859713604
# 999 0.39281717562090024
# 1499 0.7519001451519853
# C:\Users\iRacheva\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Online changepoint detection: Bayesian Online change detection algorithm (https://arxiv.org/abs/0710.3742, https://nbviewer.jupyter.org/github/hildensia/bayesian_changepoint_detection/blob/master/Example%20Code.ipynb)

# %%
def TS_obcp(list_distributions, n_samples, var_multiplier = 5):
    # initialize
    total_reward = 0
    num_choices = len(choices)
    sample_count = [0 for i in range(num_choices)]
    sample_rewards = [0 for i in range(num_choices)]
    sample_mean = [0.0 for i in range(num_choices)]
    sample_var = [0.0 for i in range(num_choices)]
    arm_rewards = {0: [], 1:[], 2:[]}
    rewards = []
    cum_rewards = []
    var_multiplier = var_multiplier
    list_iteration_results = []

    for n, elem in enumerate(list_distributions):
        dist_type = elem
        distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
        print("\n")
        print("Iteration:", n)
        theta = {}
        for i in range(len(choices)):
            if sample_count[i] >= 2:
                theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=np.sqrt(sample_var[i]/sample_count[i])*var_multiplier)
                print(choices_names[i],"Theta", theta[i])

            else:
                print("Less than two values for",choices_names[i])
                theta[i] = uniform.rvs(loc=0, scale=1)
                print(choices_names[i],"Theta", theta[i])

        choice = np.argmin([theta[i] for i in range(len(choices))])
        alg = choices[choice]
        alg_name = choices_names[choice]
        start_time = time.perf_counter()
        sorted_dist = alg(distribion[dist_type])
        reward = ((time.perf_counter() - start_time))*(1)
        print("\n")
        print("Chosen algorithm is: ", alg_name, "with reward:", reward)
        arm_rewards[choice].append(reward)
        sample_count[choice] += 1
        sample_rewards[choice] += reward
        sample_mean[choice] = np.mean(arm_rewards[choice])
        sample_var[choice] = np.var(arm_rewards[choice]).astype('float64')
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
        total_reward += reward
        rewards.append(reward)
        cum_rewards.append(sum(rewards)/len(rewards))

        array_rewards = np.array(rewards)
        #print(array_rewards)   
        if(len(array_rewards)>4):
            array_rewards_ma = moving_average(array_rewards, 3)*1000
            R, maxes = oncd.online_changepoint_detection(array_rewards_ma, partial(oncd.constant_hazard, 250), oncd.StudentT(0.1, .01, 1, 0))
            Nw=3
            #print("R",R)
            for i, elem in enumerate(R[Nw,Nw:-1]):
                if elem > 0.2 and i!=0:
                        print("RESTART EXPERIMENT AT ITERATION:", n)

                        list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
                        sample_count = [0 for i in range(num_choices)]
                        sample_rewards = [0 for i in range(num_choices)]
                        sample_mean = [0.0 for i in range(num_choices)]
                        sample_var = [0.0 for i in range(num_choices)]
                        arm_rewards = {0: [], 1:[], 2:[]}
                        rewards = []
                        cum_rewards = []
                        n_consecutive_list = []


    list_iteration_results.append([sample_mean, sample_count,rewards,cum_rewards,n])
    return list_iteration_results, total_reward

# %%
list_iteration_results_obcp, total_reward_obcp = TS_obcp(list_distributions=list_distributions, n_samples=n_samples)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.31537090677993607
# Less than two values for merge_sort
# merge_sort Theta 0.5136395057510844
# Less than two values for heap_sort
# heap_sort Theta 0.7204992795133516
#
#
# Chosen algorithm is:  quick_sort with reward: 0.009403800000200135
# Sample mean is:  0.009403800000200135 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.7367356805592924
# Less than two values for merge_sort
# merge_sort Theta 0.1254692060884569
# Less than two values for heap_sort
# heap_sort Theta 0.46341885333714294
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0070602999999209715
# Sample mean is:  0.0070602999999209715 Sample variance is: 0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.37108957876604454
# Less than two values for merge_sort
# merge_sort Theta 0.16020434437483178
# Less than two values for heap_sort
# heap_sort Theta 0.7054818873573165
#
#
# Chosen algorithm is:  merge_sort with reward: 0.009916900000007445
# Sample mean is:  0.008488599999964208 Sample variance is: 2.04004089012351e-06
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.5986202751951127
# merge_sort Theta 0.020197525152251736
# Less than two values for heap_sort
# heap_sort Theta 0.08317111121542797
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007932099999834463
# Sample mean is:  0.00830309999992096 Sample variance is: 1.4288477601144301e-06
#
#
# Iteration: 4
# Less than two values for quick_sort
# quick_sort Theta 0.677921567000193
# merge_sort Theta 0.01761620127551488
# Less than two values for heap_sort
# heap_sort Theta 0.5882859543911503
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006739399999787565
# Sample mean is:  0.007912174999887611 Sample variance is: 1.5301028870390435e-06
#
#
# Iteration: 5
# Less than two values for quick_sort
# quick_sort Theta 0.633262191981006
# merge_sort Theta 0.0025513172943557004
# Less than two values for heap_sort
# heap_sort Theta 0.44329693747961674
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007961700000123528
# Sample mean is:  0.007922079999934795 Sample variance is: 1.2244747457349735e-06
#
#
# Iteration: 6
# Less than two values for quick_sort
# quick_sort Theta 0.09404568100902821
# merge_sort Theta 0.008552295177412543
# Less than two values for heap_sort
# heap_sort Theta 0.5389562303315134
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006967700000132027
# Sample mean is:  0.007763016666634333 Sample variance is: 1.1469013414490796e-06
#
#
# Iteration: 7
# Less than two values for quick_sort
# quick_sort Theta 0.9043871253942379
# merge_sort Theta 0.004361418208692734
# Less than two values for heap_sort
# heap_sort Theta 0.7841266037204513
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007948800000121992
# Sample mean is:  0.007789557142846856 Sample variance is: 9.872846739361646e-07
#
#
# Iteration: 8
# Less than two values for quick_sort
# quick_sort Theta 0.3898019936298235
# merge_sort Theta 0.008190035483700758
# Less than two values for heap_sort
# heap_sort Theta 0.24443678688287407
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006808200000250508
# Sample mean is:  0.0076668875000223125 Sample variance is: 9.692089785890514e-07
#
#
# Iteration: 9
# Less than two values for quick_sort
# quick_sort Theta 0.19753317168226836
# merge_sort Theta 0.010244712636767062
# Less than two values for heap_sort
# heap_sort Theta 0.9583593063287158
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006559999999808497
# Sample mean is:  0.007543899999998555 Sample variance is: 9.825264933759064e-07
#
#
# Iteration: 10
# Less than two values for quick_sort
# quick_sort Theta 0.3583197620493789
# merge_sort Theta 0.007773214086302373
# Less than two values for heap_sort
# heap_sort Theta 0.8162464749234816
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007615999999870837
# Sample mean is:  0.007551109999985784 Sample variance is: 8.847417009366583e-07
#
#
# Iteration: 11
# Less than two values for quick_sort
# quick_sort Theta 0.9032945519349307
# merge_sort Theta 0.007689698287219566
# Less than two values for heap_sort
# heap_sort Theta 0.7520538326762629
#
#
# Chosen algorithm is:  merge_sort with reward: 0.009866999999758264
# Sample mean is:  0.007761645454510554 Sample variance is: 1.2475624133346628e-06
#
#
# Iteration: 12
# Less than two values for quick_sort
# quick_sort Theta 0.09336588472990837
# merge_sort Theta 0.009907566351561923
# Less than two values for heap_sort
# heap_sort Theta 0.47518156747499507
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00935429999981352
# Sample mean is:  0.007894366666619135 Sample variance is: 1.3373630004693864e-06
#
#
# Iteration: 13
# Less than two values for quick_sort
# quick_sort Theta 0.4789761674061497
# merge_sort Theta 0.005885171834420962
# Less than two values for heap_sort
# heap_sort Theta 0.44019013858995015
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007110200000170153
# Sample mean is:  0.007834046153815367 Sample variance is: 1.2781516946891172e-06
#
#
# Iteration: 14
# Less than two values for quick_sort
# quick_sort Theta 0.0944383337475676
# merge_sort Theta 0.007103872158562377
# Less than two values for heap_sort
# heap_sort Theta 0.016059125463708246
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006834999999682623
# Sample mean is:  0.007762685714234456 Sample variance is: 1.2530552054518156e-06
#
#
# Iteration: 15
# Less than two values for quick_sort
# quick_sort Theta 0.36890011482877605
# merge_sort Theta 0.009039780110654561
# Less than two values for heap_sort
# heap_sort Theta 0.38573649326150217
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006783700000141835
# Sample mean is:  0.007697419999961615 Sample variance is: 1.2291527801886466e-06
#
#
# Iteration: 16
# Less than two values for quick_sort
# quick_sort Theta 0.6251738762351091
# merge_sort Theta 0.006792794639722141
# Less than two values for heap_sort
# heap_sort Theta 0.39771476134569117
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006716400000186695
# Sample mean is:  0.007636106249975683 Sample variance is: 1.2087213704869175e-06
#
#
# Iteration: 17
# Less than two values for quick_sort
# quick_sort Theta 0.4594333140229103
# merge_sort Theta 0.008699345008461727
# Less than two values for heap_sort
# heap_sort Theta 0.3343079608127758
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006747599999926024
# Sample mean is:  0.0075838411764433495 Sample variance is: 1.1813263199808943e-06
#
#
# Iteration: 18
# Less than two values for quick_sort
# quick_sort Theta 0.8208821516246704
# merge_sort Theta 0.0072793516411943536
# Less than two values for heap_sort
# heap_sort Theta 0.638239063625838
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006873900000300637
# Sample mean is:  0.0075443999999909766 Sample variance is: 1.1421423887810587e-06
#
#
# Iteration: 19
# Less than two values for quick_sort
# quick_sort Theta 0.643170890350172
# merge_sort Theta 0.007454664982180771
# Less than two values for heap_sort
# heap_sort Theta 0.19298134766631247
#
#
# Chosen algorithm is:  merge_sort with reward: 0.008300499999677413
# Sample mean is:  0.007584194736816579 Sample variance is: 1.110534810899133e-06
#
#
# Iteration: 20
# Less than two values for quick_sort
# quick_sort Theta 0.8440872917907511
# merge_sort Theta 0.007449157085451668
# Less than two values for heap_sort
# heap_sort Theta 0.6945575364041442
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006636200000230019
# Sample mean is:  0.00753679499998725 Sample variance is: 1.097696036332478e-06
#
#
# Iteration: 21
# Less than two values for quick_sort
# quick_sort Theta 0.696833300864161
# merge_sort Theta 0.008566358798704482
# Less than two values for heap_sort
# heap_sort Theta 0.051154970607870776
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00724030000037601
# Sample mean is:  0.007522676190481954 Sample variance is: 1.049411612144059e-06
#
#
# Iteration: 22
# Less than two values for quick_sort
# quick_sort Theta 0.6775282418030709
# merge_sort Theta 0.006978785935404865
# Less than two values for heap_sort
# heap_sort Theta 0.6351629653961474
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00724099999979444
# Sample mean is:  0.007509872727268885 Sample variance is: 1.0051535863945457e-06
#
#
# Iteration: 23
# Less than two values for quick_sort
# quick_sort Theta 0.0025069327055305957
# merge_sort Theta 0.007472338018525246
# Less than two values for heap_sort
# heap_sort Theta 0.2870844088955258
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00736189999997805
# Sample mean is:  0.008382850000089093 Sample variance is: 1.0423389027267382e-06
#
#
# Iteration: 24
# quick_sort Theta 0.009912448610891862
# merge_sort Theta 0.00782424963383375
# Less than two values for heap_sort
# heap_sort Theta 0.0016345796581958005
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010198299999956362
# Sample mean is:  0.010198299999956362 Sample variance is: 0.0
#
#
# Iteration: 25
# quick_sort Theta 0.006282317650315009
# merge_sort Theta 0.008870265680768047
# Less than two values for heap_sort
# heap_sort Theta 0.023237475206436375
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006453099999816914
# Sample mean is:  0.007739599999998366 Sample variance is: 1.5224337270512642e-06
#
#
# Iteration: 26
# quick_sort Theta 0.004141807807766839
# merge_sort Theta 0.006460094172688056
# Less than two values for heap_sort
# heap_sort Theta 0.8329954006799358
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006121699999766861
# Sample mean is:  0.00733512499994049 Sample variance is: 1.6326253723039056e-06
#
#
# Iteration: 27
# quick_sort Theta 0.0067302478748706325
# merge_sort Theta 0.008762252060891172
# Less than two values for heap_sort
# heap_sort Theta 0.3276239447136281
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006604600000173377
# Sample mean is:  0.007189019999987068 Sample variance is: 1.3914869818886829e-06
#
#
# Iteration: 28
# quick_sort Theta 0.006097342603760455
# merge_sort Theta 0.007287773079662291
# Less than two values for heap_sort
# heap_sort Theta 0.6489943889762857
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006473299999925075
# Sample mean is:  0.007069733333310069 Sample variance is: 1.2307190291417828e-06
#
#
# Iteration: 29
# quick_sort Theta 0.008093490800766642
# merge_sort Theta 0.008587744984279935
# Less than two values for heap_sort
# heap_sort Theta 0.3155984182606729
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00621259999979884
# Sample mean is:  0.006947285714237036 Sample variance is: 1.144862541478598e-06
#
#
# Iteration: 30
# quick_sort Theta 0.008956137805334911
# merge_sort Theta 0.007189149944014157
# Less than two values for heap_sort
# heap_sort Theta 0.8482404338743467
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006694400000014866
# Sample mean is:  0.007474417391301319 Sample variance is: 9.8910703521991e-07
#
#
# Iteration: 31
# quick_sort Theta 0.005158740286933752
# merge_sort Theta 0.006727198511056479
# Less than two values for heap_sort
# heap_sort Theta 0.41618151538775916
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007794900000135385
# Sample mean is:  0.00705323749997433 Sample variance is: 1.0803351901002227e-06
#
#
# Iteration: 32
# quick_sort Theta 0.0097816493247002
# merge_sort Theta 0.007452758147631555
# Less than two values for heap_sort
# heap_sort Theta 0.6006132603717337
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007849099999930331
# Sample mean is:  0.007490029166660861 Sample variance is: 9.534999752729139e-07
#
#
# Iteration: 33
# quick_sort Theta 0.007992581022320434
# merge_sort Theta 0.008556842154894162
# Less than two values for heap_sort
# heap_sort Theta 0.29946779092619125
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0074371000000610366
# Sample mean is:  0.007095888888872853 Sample variance is: 9.748510745555382e-07
#
#
# Iteration: 34
# quick_sort Theta 0.00535722931024592
# merge_sort Theta 0.006696520146197982
# Less than two values for heap_sort
# heap_sort Theta 0.3060366576865663
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007242199999836885
# Sample mean is:  0.007110519999969256 Sample variance is: 8.792925918072217e-07
#
#
# Iteration: 35
# quick_sort Theta 0.007438048212512334
# merge_sort Theta 0.0092340477682184
# Less than two values for heap_sort
# heap_sort Theta 0.889906480513978
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005950100000063685
# Sample mean is:  0.007005027272705113 Sample variance is: 9.106440566991971e-07
#
#
# Iteration: 36
# quick_sort Theta 0.005142220532373223
# merge_sort Theta 0.006933584678512092
# Less than two values for heap_sort
# heap_sort Theta 0.33420711719330676
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005863699999736127
# Sample mean is:  0.0069099166666243645 Sample variance is: 9.342633532537851e-07
#
#
# Iteration: 37
# quick_sort Theta 0.00668068247199851
# merge_sort Theta 0.006510468901782398
# Less than two values for heap_sort
# heap_sort Theta 0.3040269895466928
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006682400000045163
# Sample mean is:  0.007457723999996233 Sample variance is: 9.404069472995024e-07
#
#
# Iteration: 38
# quick_sort Theta 0.008269162713921982
# merge_sort Theta 0.007891057982594828
# Less than two values for heap_sort
# heap_sort Theta 0.7892227137425937
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00661790000003748
# Sample mean is:  0.007425423076920896 Sample variance is: 9.303211901144151e-07
#
#
# Iteration: 39
# quick_sort Theta 0.006204839520487565
# merge_sort Theta 0.007814194666881654
# Less than two values for heap_sort
# heap_sort Theta 0.11089786572868698
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005999700000302255
# Sample mean is:  0.006839899999984202 Sample variance is: 9.212249447538279e-07
#
#
# Iteration: 40
# quick_sort Theta 0.004268188070643494
# merge_sort Theta 0.00829166902537528
# Less than two values for heap_sort
# heap_sort Theta 0.4420509592484625
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007168600000113656
# Sample mean is:  0.00686337857142202 Sample variance is: 8.625893261035867e-07
#
#
# Iteration: 41
# quick_sort Theta 0.004391738550466133
# merge_sort Theta 0.008190654635561324
# Less than two values for heap_sort
# heap_sort Theta 0.18291973040560539
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007189500000094995
# Sample mean is:  0.006885120000000218 Sample variance is: 8.117010270627069e-07
#
#
# Iteration: 42
# quick_sort Theta 0.0060910621589607755
# merge_sort Theta 0.008155338115657697
# Less than two values for heap_sort
# heap_sort Theta 0.49503041631505784
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007083799999691109
# Sample mean is:  0.006897537499980899 Sample variance is: 7.632826274578407e-07
#
#
# Iteration: 43
# quick_sort Theta 0.006541904876467096
# merge_sort Theta 0.00650020676481468
# Less than two values for heap_sort
# heap_sort Theta 0.701805503800603
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00666559999990568
# Sample mean is:  0.007397281481475888 Sample variance is: 9.164555339887601e-07
#
#
# Iteration: 44
# quick_sort Theta 0.007078486514001913
# merge_sort Theta 0.008656005923516445
# Less than two values for heap_sort
# heap_sort Theta 0.1562094714103257
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006985900000017864
# Sample mean is:  0.0069027352941007205 Sample variance is: 7.188159223914784e-07
#
#
# Iteration: 45
# quick_sort Theta 0.007285516088234468
# merge_sort Theta 0.007521660421470679
# Less than two values for heap_sort
# heap_sort Theta 0.7082631067730787
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006773799999791663
# Sample mean is:  0.006895572222194662 Sample variance is: 6.797539676660737e-07
#
#
# Iteration: 46
# quick_sort Theta 0.005932454181510675
# merge_sort Theta 0.008703568234125264
# Less than two values for heap_sort
# heap_sort Theta 0.8210870033183986
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006926100000328006
# Sample mean is:  0.006897178947359575 Sample variance is: 6.4402391123567e-07
#
#
# Iteration: 47
# quick_sort Theta 0.0071754839736660764
# merge_sort Theta 0.007575927008336997
# Less than two values for heap_sort
# heap_sort Theta 0.720176298245966
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00613389999989522
# Sample mean is:  0.006859014999986357 Sample variance is: 6.394959663768955e-07
#
#
# Iteration: 48
# quick_sort Theta 0.007011384742787157
# merge_sort Theta 0.007676397321026461
# Less than two values for heap_sort
# heap_sort Theta 0.34213723151243625
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006620999999995547
# Sample mean is:  0.006847680952367747 Sample variance is: 6.116129902102235e-07
#
#
# Iteration: 49
# quick_sort Theta 0.005764510045682772
# merge_sort Theta 0.007158441887521263
# Less than two values for heap_sort
# heap_sort Theta 0.34817057454038514
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005869799999800307
# Sample mean is:  0.006803231818160136 Sample variance is: 6.253026359140529e-07
#
#
# Iteration: 50
# quick_sort Theta 0.0053659608864427555
# merge_sort Theta 0.006057647150768102
# Less than two values for heap_sort
# heap_sort Theta 0.36952997279580924
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006013800000346237
# Sample mean is:  0.006768908695646488 Sample variance is: 6.240332530472661e-07
#
#
# Iteration: 51
# quick_sort Theta 0.006965680844677736
# merge_sort Theta 0.007509865070259787
# Less than two values for heap_sort
# heap_sort Theta 0.5373131100158972
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006018600000061269
# Sample mean is:  0.006737645833330437 Sample variance is: 6.205112983880541e-07
#
#
# Iteration: 52
# quick_sort Theta 0.005251119989060485
# merge_sort Theta 0.007406443204835323
# Less than two values for heap_sort
# heap_sort Theta 0.8461872753746631
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006871800000226358
# Sample mean is:  0.006743012000006274 Sample variance is: 5.963819443275606e-07
#
#
# Iteration: 53
# quick_sort Theta 0.005563812365226951
# merge_sort Theta 0.006808221793292467
# Less than two values for heap_sort
# heap_sort Theta 0.35130418937480723
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007160399999975198
# Sample mean is:  0.006759065384620464 Sample variance is: 5.798869561773164e-07
#
#
# Iteration: 54
# quick_sort Theta 0.005603269530455872
# merge_sort Theta 0.00869234781330582
# Less than two values for heap_sort
# heap_sort Theta 0.6308888226177117
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0068278999997346546
# Sample mean is:  0.006761614814809878 Sample variance is: 5.585786509556406e-07
#
#
# Iteration: 55
# quick_sort Theta 0.0076362854425044546
# merge_sort Theta 0.007020642901420074
# Less than two values for heap_sort
# heap_sort Theta 0.7091059360273068
#
#
# Chosen algorithm is:  merge_sort with reward: 0.008163999999851512
# Sample mean is:  0.007424664285703589 Sample variance is: 9.039700643225069e-07
#
#
# Iteration: 56
# quick_sort Theta 0.008188890441277357
# merge_sort Theta 0.007346866443368875
# Less than two values for heap_sort
# heap_sort Theta 0.2973681336608033
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00842659999989337
# Sample mean is:  0.007459213793089444 Sample variance is: 9.062213996910908e-07
#
#
# Iteration: 57
# quick_sort Theta 0.00747628986007859
# merge_sort Theta 0.006429977750381625
# Less than two values for heap_sort
# heap_sort Theta 0.7335464637460533
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007098799999766925
# Sample mean is:  0.007447199999978693 Sample variance is: 8.801996252237174e-07
#
#
# Iteration: 58
# quick_sort Theta 0.007725948300470073
# merge_sort Theta 0.007044417793432312
# Less than two values for heap_sort
# heap_sort Theta 0.1493261860175119
#
#
# Chosen algorithm is:  merge_sort with reward: 0.009346800000002986
# Sample mean is:  0.007508477419334315 Sample variance is: 9.64453752612722e-07
#
#
# Iteration: 59
# quick_sort Theta 0.006630945710184471
# merge_sort Theta 0.007379579856002741
# Less than two values for heap_sort
# heap_sort Theta 0.238380213524094
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0067269999999552965
# Sample mean is:  0.006760378571422214 Sample variance is: 5.386706774597762e-07
#
#
# Iteration: 60
# quick_sort Theta 0.0054358320204887164
# merge_sort Theta 0.007480616975858536
# Less than two values for heap_sort
# heap_sort Theta 0.6095595827887857
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007235300000047573
# Sample mean is:  0.006776755172409296 Sample variance is: 5.276052321898093e-07
#
#
# Iteration: 61
# quick_sort Theta 0.006825738992444984
# merge_sort Theta 0.00752310586945062
# Less than two values for heap_sort
# heap_sort Theta 0.10284505597209093
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0069293999999899825
# Sample mean is:  0.006781843333328652 Sample variance is: 5.107691831815123e-07
#
#
# Iteration: 62
# quick_sort Theta 0.007021150229240819
# merge_sort Theta 0.006512965151722464
# Less than two values for heap_sort
# heap_sort Theta 0.18843111041393779
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007341499999711232
# Sample mean is:  0.007503259374971094 Sample variance is: 9.351586404398474e-07
#
#
# Iteration: 63
# quick_sort Theta 0.006781443745632537
# merge_sort Theta 0.007430360684186722
# Less than two values for heap_sort
# heap_sort Theta 0.49315099137655327
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007035900000119
# Sample mean is:  0.006790038709676728 Sample variance is: 4.963076837221905e-07
# Iteration: 64
# quick_sort Theta 0.006342493035899248
# merge_sort Theta 0.007080720960811836
# Less than two values for heap_sort
# heap_sort Theta 0.560744670482982
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007204900000033376
# Sample mean is:  0.006803003125000373 Sample variance is: 4.860084266110751e-07
#
#
# Iteration: 65
# quick_sort Theta 0.007119651432185021
# merge_sort Theta 0.007738534902827348
# Less than two values for heap_sort
# heap_sort Theta 0.9694129127037827
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071418000002267945
# Sample mean is:  0.006813269696976931 Sample variance is: 4.7465377853674675e-07
#
#
# Iteration: 66
# quick_sort Theta 0.007188444404880453
# merge_sort Theta 0.007478995993520164
# Less than two values for heap_sort
# heap_sort Theta 0.6233000876185685
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006472799999755807
# Sample mean is:  0.0068032558823527805 Sample variance is: 4.640024972354523e-07
#
#
# Iteration: 67
# quick_sort Theta 0.006858578246230499
# merge_sort Theta 0.00855327893477008
# Less than two values for heap_sort
# heap_sort Theta 0.5578823332076248
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00719200000003184
# Sample mean is:  0.0068143628571436105 Sample variance is: 4.549396892548659e-07
#
#
# Iteration: 68
# quick_sort Theta 0.006878606987840769
# merge_sort Theta 0.007580205205853364
# Less than two values for heap_sort
# heap_sort Theta 0.5073539846796059
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005965999999716587
# Sample mean is:  0.006790797222215083 Sample variance is: 4.6173934589991667e-07
#
#
# Iteration: 69
# quick_sort Theta 0.007646068527469621
# merge_sort Theta 0.006850185854516316
# Less than two values for heap_sort
# heap_sort Theta 0.8655885005677096
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007703299999775481
# Sample mean is:  0.007509321212086378 Sample variance is: 9.079963676352498e-07
#
#
# Iteration: 70
# quick_sort Theta 0.007407989544957093
# merge_sort Theta 0.007766297248856707
# Less than two values for heap_sort
# heap_sort Theta 0.1528184087009381
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006049600000096689
# Sample mean is:  0.006770764864860532 Sample variance is: 4.6370653640133384e-07
#
#
# Iteration: 71
# quick_sort Theta 0.007080275388611137
# merge_sort Theta 0.0076497357552405484
# Less than two values for heap_sort
# heap_sort Theta 0.18952037826108448
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006889600000249629
# Sample mean is:  0.006773892105265507 Sample variance is: 4.5186557921619403e-07
#
#
# Iteration: 72
# quick_sort Theta 0.00637112382145276
# merge_sort Theta 0.006799171371146628
# Less than two values for heap_sort
# heap_sort Theta 0.21453909167967578
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006315699999959179
# Sample mean is:  0.006762143589744833 Sample variance is: 4.4552433175691745e-07
#
#
# Iteration: 73
# quick_sort Theta 0.007272721313165563
# merge_sort Theta 0.006783616931986757
# Less than two values for heap_sort
# heap_sort Theta 0.48042147338973507
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007120400000076188
# Sample mean is:  0.007497882352909609 Sample variance is: 8.856085595923435e-07
#
#
# Iteration: 74
# quick_sort Theta 0.007678916698216562
# merge_sort Theta 0.008862070518322218
# Less than two values for heap_sort
# heap_sort Theta 0.06529268332402216
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006189700000049925
# Sample mean is:  0.00674783250000246 Sample variance is: 4.4237370775794997e-07
#
#
# Iteration: 75
# quick_sort Theta 0.007418031710836305
# merge_sort Theta 0.0076492795552003875
# Less than two values for heap_sort
# heap_sort Theta 0.5069436342735847
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006215899999915564
# Sample mean is:  0.006734858536585706 Sample variance is: 4.3831705419927777e-07
#
#
# Iteration: 76
# quick_sort Theta 0.006519920471906083
# merge_sort Theta 0.0071223776027194196
# Less than two values for heap_sort
# heap_sort Theta 0.7485879052111305
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006653599999935977
# Sample mean is:  0.006732923809522617 Sample variance is: 4.280344037823543e-07
#
#
# Iteration: 77
# quick_sort Theta 0.008108057497021096
# merge_sort Theta 0.008431207783293166
# Less than two values for heap_sort
# heap_sort Theta 0.4653158983676291
#
#
# Chosen algorithm is:  quick_sort with reward: 0.008952200000294397
# Sample mean is:  0.006784534883726612 Sample variance is: 5.299556405028906e-07
#
#
# Iteration: 78
# quick_sort Theta 0.006668774749785325
# merge_sort Theta 0.007119246184114387
# Less than two values for heap_sort
# heap_sort Theta 0.6400755598328565
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071689000001242675
# Sample mean is:  0.006793270454553832 Sample variance is: 5.211925326279517e-07
#
#
# Iteration: 79
# quick_sort Theta 0.006055040585438466
# merge_sort Theta 0.007432289173477387
# Less than two values for heap_sort
# heap_sort Theta 0.1018691425908923
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0072172000000136904
# Sample mean is:  0.006802691111119606 Sample variance is: 5.135154222330627e-07
#
#
# Iteration: 80
# quick_sort Theta 0.007145988731481846
# merge_sort Theta 0.006332189340766912
# Less than two values for heap_sort
# heap_sort Theta 0.9212369339341521
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006916899999851012
# Sample mean is:  0.007481282857107934 Sample variance is: 8.696739287592783e-07
#
#
# Iteration: 81
# quick_sort Theta 0.0068129060711468485
# merge_sort Theta 0.00759788972962751
# Less than two values for heap_sort
# heap_sort Theta 0.8135474137002697
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006758800000170595
# Sample mean is:  0.0068017369565337585 Sample variance is: 5.023930119826818e-07
#
#
# Iteration: 82
# quick_sort Theta 0.006924961775710427
# merge_sort Theta 0.00851632162252503
# Less than two values for heap_sort
# heap_sort Theta 0.6290377039140301
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007061000000248896
# Sample mean is:  0.006807253191506421 Sample variance is: 4.931035259823603e-07
#
#
# Iteration: 83
# quick_sort Theta 0.006011435223951995
# merge_sort Theta 0.00807498582654078
# Less than two values for heap_sort
# heap_sort Theta 0.9421379477514636
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007139700000152516
# Sample mean is:  0.0068141791666865474 Sample variance is: 4.850850850709274e-07
#
#
# Iteration: 84
# quick_sort Theta 0.006732859970027831
# merge_sort Theta 0.007601795067610423
# Less than two values for heap_sort
# heap_sort Theta 0.944428694597734
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006034099999851605
# Sample mean is:  0.006798259183689917 Sample variance is: 4.873507906706608e-07
#
#
# Iteration: 85
# quick_sort Theta 0.006728107281169284
# merge_sort Theta 0.00834919294222778
# Less than two values for heap_sort
# heap_sort Theta 0.27020715794024064
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0063289999998232815
# Sample mean is:  0.006788874000012584 Sample variance is: 4.819197768174539e-07
#
#
# Iteration: 86
# quick_sort Theta 0.006926447247641188
# merge_sort Theta 0.006851426904444972
# Less than two values for heap_sort
# heap_sort Theta 0.3396384597910369
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007821400000011636
# Sample mean is:  0.0074907305555219255 Sample variance is: 8.486403848133372e-07
#
#
# Iteration: 87
# quick_sort Theta 0.006068754108078886
# merge_sort Theta 0.010527020825669408
# Less than two values for heap_sort
# heap_sort Theta 0.8428941055748963
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0068280000000413565
# Sample mean is:  0.006789641176483736 Sample variance is: 4.7249979741577087e-07
#
#
# Iteration: 88
# quick_sort Theta 0.006436292394630054
# merge_sort Theta 0.0074558038625001715
# Less than two values for heap_sort
# heap_sort Theta 0.5317698659930374
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006360299999869312
# Sample mean is:  0.006781384615394997 Sample variance is: 4.668899737016989e-07
#
#
# Iteration: 89
# quick_sort Theta 0.0056931946700904965
# merge_sort Theta 0.007840792356269189
# Less than two values for heap_sort
# heap_sort Theta 0.35794090856758387
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006052299999737443
# Sample mean is:  0.006767628301892025 Sample variance is: 4.6792100929686194e-07
#
#
# Iteration: 90
# quick_sort Theta 0.006866051911906624
# merge_sort Theta 0.00846565650303024
# Less than two values for heap_sort
# heap_sort Theta 0.27696853131404064
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006895400000303198
# Sample mean is:  0.0067699944444551945 Sample variance is: 4.595525328443442e-07
#
#
# Iteration: 91
# quick_sort Theta 0.007016524633923292
# merge_sort Theta 0.0066606183914144895
# Less than two values for heap_sort
# heap_sort Theta 0.9630866140867398
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006677500000023429
# Sample mean is:  0.007468751351319264 Sample variance is: 8.430952332225239e-07
#
#
# Iteration: 92
# quick_sort Theta 0.00567199448853171
# merge_sort Theta 0.007587823514518472
# Less than two values for heap_sort
# heap_sort Theta 0.42159300499951624
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006084200000259443
# Sample mean is:  0.006757525454560726 Sample variance is: 4.595927205325452e-07
#
#
# Iteration: 93
# quick_sort Theta 0.006018849508984049
# merge_sort Theta 0.007379162597985074
# Less than two values for heap_sort
# heap_sort Theta 0.04777398815211442
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006023200000072393
# Sample mean is:  0.006744412500016291 Sample variance is: 4.608429343945348e-07
#
#
# Iteration: 94
# quick_sort Theta 0.0065599506592375345
# merge_sort Theta 0.006611622778339897
# Less than two values for heap_sort
# heap_sort Theta 0.6634431306546933
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005969999999706488
# Sample mean is:  0.00673082631580033 Sample variance is: 4.630946971200296e-07
#
#
# Iteration: 95
# quick_sort Theta 0.006515323091656453
# merge_sort Theta 0.006955086532504066
# Less than two values for heap_sort
# heap_sort Theta 0.8298738171712411
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006088499999805208
# Sample mean is:  0.0067197517241452415 Sample variance is: 4.621011608690101e-07
#
#
# Iteration: 96
# quick_sort Theta 0.007179456446270967
# merge_sort Theta 0.007355544386440356
# Less than two values for heap_sort
# heap_sort Theta 0.7083830801525955
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006825899999967078
# Sample mean is:  0.006721550847464256 Sample variance is: 4.544566747970208e-07
#
#
# Iteration: 97
# quick_sort Theta 0.006912312446507449
# merge_sort Theta 0.0068887583049760635
# Less than two values for heap_sort
# heap_sort Theta 0.48778985384970897
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007654300000012881
# Sample mean is:  0.007473634210495412 Sample variance is: 8.217906821669345e-07
#
#
# Iteration: 98
# quick_sort Theta 0.006430426905033948
# merge_sort Theta 0.007473465726688509
# Less than two values for heap_sort
# heap_sort Theta 0.7726592110562317
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006024899999829358
# Sample mean is:  0.006709940000003674 Sample variance is: 4.54836291830158e-07
#
#
# Iteration: 99
# quick_sort Theta 0.006552505746421504
# merge_sort Theta 0.009018581536121116
# Less than two values for heap_sort
# heap_sort Theta 0.5839204571115449
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005982700000004115
# Sample mean is:  0.006698018032790567 Sample variance is: 4.559079573110292e-07
#
#
# Iteration: 100
# quick_sort Theta 0.007168316630560018
# merge_sort Theta 0.007750314473254347
# Less than two values for heap_sort
# heap_sort Theta 0.6994976474844926
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007090399999924557
# Sample mean is:  0.006704346774195954 Sample variance is: 4.5099783419520306e-07
#
#
# Iteration: 101
# quick_sort Theta 0.006633395721281003
# merge_sort Theta 0.007776392651789208
# Less than two values for heap_sort
# heap_sort Theta 0.7366839945020796
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007967999999891617
# Sample mean is:  0.006724404761905408 Sample variance is: 4.68783156413391e-07
#
#
# Iteration: 102
# quick_sort Theta 0.006992309740088998
# merge_sort Theta 0.006725010210098867
# Less than two values for heap_sort
# heap_sort Theta 0.7030726115872067
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007859299999836367
# Sample mean is:  0.007483523076888769 Sample variance is: 8.044351339986722e-07
#
#
# Iteration: 103
# quick_sort Theta 0.00684946174427114
# merge_sort Theta 0.00880809948577944
# Less than two values for heap_sort
# heap_sort Theta 0.5200554629185747
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007020099999863305
# Sample mean is:  0.006729024999998501 Sample variance is: 4.628032553967539e-07
#
#
# Iteration: 104
# quick_sort Theta 0.007392029718706897
# merge_sort Theta 0.0075512680723628135
# Less than two values for heap_sort
# heap_sort Theta 0.16884436508039624
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006675199999790493
# Sample mean is:  0.006728196923072223 Sample variance is: 4.557270908430602e-07
#
#
# Iteration: 105
# quick_sort Theta 0.007826598811527218
# merge_sort Theta 0.006457977291703206
# Less than two values for heap_sort
# heap_sort Theta 0.34804105940349794
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00714830000015354
# Sample mean is:  0.007475142499970389 Sample variance is: 7.870633843586163e-07
#
#
# Iteration: 106
# quick_sort Theta 0.0064115159538997765
# merge_sort Theta 0.006184535359225949
# Less than two values for heap_sort
# heap_sort Theta 0.45931033566489465
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007334500000069966
# Sample mean is:  0.007471712195094769 Sample variance is: 7.683373961090186e-07
#
#
# Iteration: 107
# quick_sort Theta 0.006549813618827981
# merge_sort Theta 0.007618413586114266
# Less than two values for heap_sort
# heap_sort Theta 0.3351471582204284
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006214300000010553
# Sample mean is:  0.006720410606056138 Sample variance is: 4.527628725450699e-07
#
#
# Iteration: 108
# quick_sort Theta 0.007818962251432197
# merge_sort Theta 0.007606651678792369
# Less than two values for heap_sort
# heap_sort Theta 0.26286670293751413
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006659300000137591
# Sample mean is:  0.007452369047595788 Sample variance is: 7.653841001444733e-07
#
#
# Iteration: 109
# quick_sort Theta 0.007023097449538997
# merge_sort Theta 0.007745121522131746
# Less than two values for heap_sort
# heap_sort Theta 0.4216409790588852
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007142999999814492
# Sample mean is:  0.006726717910440591 Sample variance is: 4.486308355784417e-07
#
#
# Iteration: 110
# quick_sort Theta 0.006029289584731105
# merge_sort Theta 0.008055035736951694
# Less than two values for heap_sort
# heap_sort Theta 0.7484928459434043
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005894599999919592
# Sample mean is:  0.006714480882344694 Sample variance is: 4.520662286840482e-07
#
#
# Iteration: 111
# quick_sort Theta 0.007104827932292092
# merge_sort Theta 0.008271031113851307
# Less than two values for heap_sort
# heap_sort Theta 0.25975867628734517
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059090999998261395
# Sample mean is:  0.006702808695641526 Sample variance is: 4.547788602958512e-07
#
#
# Iteration: 112
# quick_sort Theta 0.006344580167956903
# merge_sort Theta 0.007570252454696264
# Less than two values for heap_sort
# heap_sort Theta 0.8072211538166627
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0085426999999072
# Sample mean is:  0.006729092857131036 Sample variance is: 4.959511624537386e-07
#
#
# Iteration: 113
# quick_sort Theta 0.007171207127505305
# merge_sort Theta 0.008330264696841734
# Less than two values for heap_sort
# heap_sort Theta 0.15523876953112403
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006447299999763345
# Sample mean is:  0.006725123943646984 Sample variance is: 4.900685940106173e-07
#
#
# Iteration: 114
# quick_sort Theta 0.007303633685641325
# merge_sort Theta 0.0073450594554556395
# Less than two values for heap_sort
# heap_sort Theta 0.6445749069619554
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005953699999736273
# Sample mean is:  0.00671440972220378 Sample variance is: 4.914124981809853e-07
#
#
# Iteration: 115
# quick_sort Theta 0.006644849845594369
# merge_sort Theta 0.006277721399728506
# Less than two values for heap_sort
# heap_sort Theta 0.7092614880792135
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007322299999941606
# Sample mean is:  0.007449344186022435 Sample variance is: 7.47968760985149e-07
#
#
# Iteration: 116
# quick_sort Theta 0.006230479575202648
# merge_sort Theta 0.006697552406138611
# Less than two values for heap_sort
# heap_sort Theta 0.5552518246650204
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007065899999815883
# Sample mean is:  0.006719224657513534 Sample variance is: 4.863500394703844e-07
#
#
# Iteration: 117
# quick_sort Theta 0.006134057167402208
# merge_sort Theta 0.006772410748044793
# Less than two values for heap_sort
# heap_sort Theta 0.5011679009322083
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007173799999691255
# Sample mean is:  0.0067253675675429635 Sample variance is: 4.825324217246685e-07
#
#
# Iteration: 118
# quick_sort Theta 0.005923841123231278
# merge_sort Theta 0.00663127852528003
# Less than two values for heap_sort
# heap_sort Theta 0.604675906178796
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00593750000007276
# Sample mean is:  0.006714862666643361 Sample variance is: 4.84264773877048e-07
#
#
# Iteration: 119
# quick_sort Theta 0.007069240912985176
# merge_sort Theta 0.008190155280211213
# Less than two values for heap_sort
# heap_sort Theta 0.1962791584542437
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006913899999744899
# Sample mean is:  0.006717481578921013 Sample variance is: 4.784072715714658e-07
#
#
# Iteration: 120
# quick_sort Theta 0.00777458808363694
# merge_sort Theta 0.0070203345817415885
# Less than two values for heap_sort
# heap_sort Theta 0.47471433038596156
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00795590000006996
# Sample mean is:  0.0074608568181598785 Sample variance is: 7.3666872100824e-07
#
#
# Iteration: 121
# quick_sort Theta 0.00738071176186016
# merge_sort Theta 0.008423464669384267
# Less than two values for heap_sort
# heap_sort Theta 0.5415796786736341
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006772199999886652
# Sample mean is:  0.006718192207764722 Sample variance is: 4.722325696173526e-07
#
#
# Iteration: 122
# quick_sort Theta 0.006697356617666338
# merge_sort Theta 0.005563669178547573
# Less than two values for heap_sort
# heap_sort Theta 0.20168535319302738
#
#
# Chosen algorithm is:  merge_sort with reward: 0.009661599999617465
# Sample mean is:  0.0075097622221922695 Sample variance is: 8.255348009029753e-07
#
#
# Iteration: 123
# quick_sort Theta 0.006508990589500889
# merge_sort Theta 0.007367701338725269
# Less than two values for heap_sort
# heap_sort Theta 0.5111724250524852
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006625800000165327
# Sample mean is:  0.006717007692282679 Sample variance is: 4.6628634282770407e-07
#
#
# Iteration: 124
# quick_sort Theta 0.006790677839186596
# merge_sort Theta 0.008052859478253219
# Less than two values for heap_sort
# heap_sort Theta 0.8292533362478176
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0060274000002209505
# Sample mean is:  0.0067082784809907575 Sample variance is: 4.663275161804948e-07
#
#
# Iteration: 125
# quick_sort Theta 0.00559183178513746
# merge_sort Theta 0.005303035312463895
# Less than two values for heap_sort
# heap_sort Theta 0.5985860874936678
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0067179000002397515
# Sample mean is:  0.007492547826062867 Sample variance is: 8.20923486722193e-07
#
#
# Iteration: 126
# quick_sort Theta 0.0068713910667968755
# merge_sort Theta 0.00621145658529721
# Less than two values for heap_sort
# heap_sort Theta 0.7698821070768722
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007441199999902892
# Sample mean is:  0.007491455319123293 Sample variance is: 8.035119338428897e-07
#
#
# Iteration: 127
# quick_sort Theta 0.006155112207155098
# merge_sort Theta 0.007399606577820989
# Less than two values for heap_sort
# heap_sort Theta 0.451202748301345
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006305500000053144
# Sample mean is:  0.006703243749979037 Sample variance is: 4.6250095502070814e-07
#
#
# Iteration: 128
# quick_sort Theta 0.007238954284404181
# merge_sort Theta 0.007617223163149786
# Less than two values for heap_sort
# heap_sort Theta 0.6659532966038464
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005906400000185386
# Sample mean is:  0.0066934061728210915 Sample variance is: 4.6453330063420305e-07
#
#
# Iteration: 129
# quick_sort Theta 0.007546718062250537
# merge_sort Theta 0.007158111113073518
# Less than two values for heap_sort
# heap_sort Theta 0.7299536917816349
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007894699999724253
# Sample mean is:  0.007499856249969146 Sample variance is: 7.900891569244397e-07
#
#
# Iteration: 130
# quick_sort Theta 0.0066185844194315375
# merge_sort Theta 0.007022698149593295
# Less than two values for heap_sort
# heap_sort Theta 0.5981926794102114
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005907599999773083
# Sample mean is:  0.0066838231707107496 Sample variance is: 4.6630680866775807e-07
#
#
# Iteration: 131
# quick_sort Theta 0.006473617879599451
# merge_sort Theta 0.008025122160168666
# Less than two values for heap_sort
# heap_sort Theta 0.714360716780555
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00710960000014893
# Sample mean is:  0.006688953012029282 Sample variance is: 4.628465066466322e-07
#
#
# Iteration: 132
# quick_sort Theta 0.007209132575126548
# merge_sort Theta 0.006938745366262174
# Less than two values for heap_sort
# heap_sort Theta 0.9105955894443847
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007080500000029133
# Sample mean is:  0.0074912979591540444 Sample variance is: 7.77480616816219e-07
#
#
# Iteration: 133
# quick_sort Theta 0.006839834835860314
# merge_sort Theta 0.007863433495943501
# Less than two values for heap_sort
# heap_sort Theta 0.5647501162496257
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006511199999749806
# Sample mean is:  0.006686836904740241 Sample variance is: 4.577080957214282e-07
#
#
# Iteration: 134
# quick_sort Theta 0.006441481184083393
# merge_sort Theta 0.007694570287277409
# Less than two values for heap_sort
# heap_sort Theta 0.15978325544680472
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005956900000001042
# Sample mean is:  0.0066782494117433085 Sample variance is: 4.585178776169712e-07
#
#
# Iteration: 135
# quick_sort Theta 0.006137926629681294
# merge_sort Theta 0.00824838909751735
# Less than two values for heap_sort
# heap_sort Theta 0.05003089986731257
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007099299999936193
# Sample mean is:  0.006683145348815319 Sample variance is: 4.5522374137297914e-07
#
#
# Iteration: 136
# quick_sort Theta 0.0069554836200970685
# merge_sort Theta 0.009741288184137902
# Less than two values for heap_sort
# heap_sort Theta 0.6321027903044989
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006810200000018085
# Sample mean is:  0.006684605747105006 Sample variance is: 4.501747022077374e-07
#
#
# Iteration: 137
# quick_sort Theta 0.006553487749246594
# merge_sort Theta 0.006674238630286109
# Less than two values for heap_sort
# heap_sort Theta 0.9350023390732173
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006769499999791151
# Sample mean is:  0.006685570454521894 Sample variance is: 4.451400480465576e-07
#
#
# Iteration: 138
# quick_sort Theta 0.0069686972845896655
# merge_sort Theta 0.007905020881368536
# Less than two values for heap_sort
# heap_sort Theta 0.6756233097442236
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006227800000033312
# Sample mean is:  0.006680426966269214 Sample variance is: 4.424665559566817e-07
#
#
# Iteration: 139
# quick_sort Theta 0.006477705896310438
# merge_sort Theta 0.008434399899316396
# Less than two values for heap_sort
# heap_sort Theta 0.4259976587673068
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005876299999727053
# Sample mean is:  0.006671492222196523 Sample variance is: 4.4465509988685506e-07
#
#
# Iteration: 140
# quick_sort Theta 0.006842614404670661
# merge_sort Theta 0.007992399424772935
# Less than two values for heap_sort
# heap_sort Theta 0.5163577437725055
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007083299999976589
# Sample mean is:  0.006676017582391908 Sample variance is: 4.4161187974869675e-07
#
#
# Iteration: 141
# quick_sort Theta 0.005851494641784562
# merge_sort Theta 0.008060397832792842
# Less than two values for heap_sort
# heap_sort Theta 0.9379022823843002
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006021299999702023
# Sample mean is:  0.006668901086927887 Sample variance is: 4.4142040082073105e-07
#
#
# Iteration: 142
# quick_sort Theta 0.006924956816007369
# merge_sort Theta 0.00754507059669368
# Less than two values for heap_sort
# heap_sort Theta 0.42571892156317237
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0071520999999847845
# Sample mean is:  0.0066740967741650585 Sample variance is: 4.3915750015764544e-07
#
#
# Iteration: 143
# quick_sort Theta 0.0066408476580691565
# merge_sort Theta 0.0075105778503120986
# Less than two values for heap_sort
# heap_sort Theta 0.6495841805612892
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006562000000030821
# Sample mean is:  0.00667290425529129 Sample variance is: 4.346178672756756e-07
#
#
# Iteration: 144
# quick_sort Theta 0.0062773871992955555
# merge_sort Theta 0.007150045447605717
# Less than two values for heap_sort
# heap_sort Theta 0.31412004962457507
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005929800000103569
# Sample mean is:  0.006665082105236682 Sample variance is: 4.3579442931580314e-07
#
#
# Iteration: 145
# quick_sort Theta 0.006636629865365566
# merge_sort Theta 0.007942182032812248
# Less than two values for heap_sort
# heap_sort Theta 0.7746740463176967
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006937400000424532
# Sample mean is:  0.006667918749978223 Sample variance is: 4.320193265824525e-07
#
#
# Iteration: 146
# quick_sort Theta 0.006688132025590863
# merge_sort Theta 0.008326621698090689
# Less than two values for heap_sort
# heap_sort Theta 0.7299310842727241
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005932600000051025
# Sample mean is:  0.00666033814430887 Sample variance is: 4.3308221499407675e-07
#
#
# Iteration: 147
# quick_sort Theta 0.007055075806198541
# merge_sort Theta 0.00823077888600409
# Less than two values for heap_sort
# heap_sort Theta 0.9169064702370348
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006434200000057899
# Sample mean is:  0.006658030612224676 Sample variance is: 4.2917950503762657e-07
#
#
# Iteration: 148
# quick_sort Theta 0.006527481411638263
# merge_sort Theta 0.007564562930295509
# Less than two values for heap_sort
# heap_sort Theta 0.07686278159367366
#
#
# Chosen algorithm is:  quick_sort with reward: 0.007233699999687815
# Sample mean is:  0.006663845454522284 Sample variance is: 4.281579728348074e-07
#
#
# Iteration: 149
# quick_sort Theta 0.006258247897193469
# merge_sort Theta 0.007083035780406665
# Less than two values for heap_sort
# heap_sort Theta 0.6733711453038084
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0065987999996650615
# Sample mean is:  0.006663194999973711 Sample variance is: 4.239182791273153e-07
#
#
# Iteration: 150
# quick_sort Theta 0.006273424053313102
# merge_sort Theta 0.007713730475823912
# Less than two values for heap_sort
# heap_sort Theta 0.5323362319238237
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006683500000235654
# Sample mean is:  0.0066633960395802655 Sample variance is: 4.1972511013522676e-07
#
#
# Iteration: 151
# quick_sort Theta 0.006389916093467702
# ...
# heap_sort Theta 0.005470445704328859
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0031794000001355016
# Sample mean is:  0.0030863029345438945 Sample variance is: 2.4948223481339747e-07
#
#
# Iteration: 1950
# Less than two values for quick_sort
# quick_sort Theta 0.03548356459713953
# merge_sort Theta 0.0030188088743888972
# heap_sort Theta 0.005475396604828716
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002981599999657192
# Sample mean is:  0.0030860671171229785 Sample variance is: 2.4894497305435335e-07
#
#
# Iteration: 1951
# Less than two values for quick_sort
# quick_sort Theta 0.4226339346432888
# merge_sort Theta 0.0032786523622528544
# heap_sort Theta 0.005449589240241814
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002950900000087131
# Sample mean is:  0.003085763370792561 Sample variance is: 2.4842651040257274e-07
#
#
# Iteration: 1952
# Less than two values for quick_sort
# quick_sort Theta 0.5990553793772978
# merge_sort Theta 0.0031105674749480564
# heap_sort Theta 0.005460183965203426
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0026755999997476465
# Sample mean is:  0.003084843721978559 Sample variance is: 2.4824586079334994e-07
#
#
# Iteration: 1953
# Less than two values for quick_sort
# quick_sort Theta 0.2620850199334199
# merge_sort Theta 0.002948107736852774
# heap_sort Theta 0.005474393123892377
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0031029000001581153
# Sample mean is:  0.0030848841163369023 Sample variance is: 2.476912286658703e-07
#
#
# Iteration: 1954
# Less than two values for quick_sort
# quick_sort Theta 0.26736820004163553
# merge_sort Theta 0.002988375585864168
# heap_sort Theta 0.005488443930666857
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030953000000408792
# Sample mean is:  0.003084907366077313 Sample variance is: 2.471385880850686e-07
#
#
# Iteration: 1955
# Less than two values for quick_sort
# quick_sort Theta 0.22280229373243354
# merge_sort Theta 0.0029839503643575922
# heap_sort Theta 0.005492276334550208
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030842999999549647
# Sample mean is:  0.0030849060133688 Sample variance is: 2.465881688868213e-07
#
#
# Iteration: 1956
# Less than two values for quick_sort
# quick_sort Theta 0.6508528324374325
# merge_sort Theta 0.0030119150320666536
# heap_sort Theta 0.00542639278657567
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0028038000000378815
# Sample mean is:  0.003084281333339176 Sample variance is: 2.462154062657796e-07
#
#
# Iteration: 1957
# Less than two values for quick_sort
# quick_sort Theta 0.14794172394913485
# merge_sort Theta 0.003157110435613122
# heap_sort Theta 0.005130323304722295
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002534300000206713
# Sample mean is:  0.003083061862534004 Sample variance is: 2.463386731712103e-07
#
#
# Iteration: 1958
# Less than two values for quick_sort
# quick_sort Theta 0.07075011175002743
# merge_sort Theta 0.0029631883032295915
# heap_sort Theta 0.005469471070980474
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0017889999999169959
# Sample mean is:  0.0030801988938114 Sample variance is: 2.494903381545528e-07
#
#
# Iteration: 1959
# Less than two values for quick_sort
# quick_sort Theta 0.48733853164648666
# merge_sort Theta 0.0030465191203975523
# heap_sort Theta 0.00546586295581218
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030496999997922103
# Sample mean is:  0.0030801315673345364 Sample variance is: 2.4894163570642644e-07
#
#
# Iteration: 1960
# Less than two values for quick_sort
# quick_sort Theta 0.12011921616623977
# merge_sort Theta 0.0027906273132887647
# heap_sort Theta 0.005486701753651397
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002949199999875418
# Sample mean is:  0.0030798431718114987 Sample variance is: 2.4843098301826126e-07
#
#
# Iteration: 1961
# Less than two values for quick_sort
# quick_sort Theta 0.04794390238767676
# merge_sort Theta 0.002912032722305087
# heap_sort Theta 0.00552226440886471
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030224999995880353
# Sample mean is:  0.0030797171428615573 Sample variance is: 2.47892191874267e-07
#
#
# Iteration: 1962
# Less than two values for quick_sort
# quick_sort Theta 0.053635358750018014
# merge_sort Theta 0.0032055053550522025
# heap_sort Theta 0.005448750038329323
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003048699999908422
# Sample mean is:  0.0030796491228112215 Sample variance is: 2.473506738073702e-07
#
#
# Iteration: 1963
# Less than two values for quick_sort
# quick_sort Theta 0.06382920641388867
# merge_sort Theta 0.003255127915907174
# heap_sort Theta 0.005462569010155705
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0033616999999139807
# Sample mean is:  0.003080266301973372 Sample variance is: 2.469831200820815e-07
#
#
# Iteration: 1964
# Less than two values for quick_sort
# quick_sort Theta 0.931059412681629
# merge_sort Theta 0.0031659223964498693
# heap_sort Theta 0.005455560970618944
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030363999999281077
# Sample mean is:  0.003080170524021308 Sample variance is: 2.464480478789122e-07
#
#
# Iteration: 1965
# Less than two values for quick_sort
# quick_sort Theta 0.9698749385081183
# merge_sort Theta 0.002911362008853861
# heap_sort Theta 0.005468443513053662
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0034215999999105406
# Sample mean is:  0.003080914379088605 Sample variance is: 2.461645447527277e-07
#
#
# Iteration: 1966
# Less than two values for quick_sort
# quick_sort Theta 0.6233738913999661
# merge_sort Theta 0.0031124947964832547
# heap_sort Theta 0.005464899229662009
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002937400000064372
# Sample mean is:  0.0030806023913081174 Sample variance is: 2.4567408183425253e-07
#
#
# Iteration: 1967
# Less than two values for quick_sort
# quick_sort Theta 0.007762904130179216
# merge_sort Theta 0.003064778462882837
# heap_sort Theta 0.005449545003705813
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030121999998300453
# Sample mean is:  0.003080454013018577 Sample variance is: 2.451512936691675e-07
#
#
# Iteration: 1968
# Less than two values for quick_sort
# quick_sort Theta 0.1252969788358893
# merge_sort Theta 0.0033823060160758163
# heap_sort Theta 0.005228259186350971
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003133300000172312
# Sample mean is:  0.0030805683982721562 Sample variance is: 2.446266948810451e-07
# Iteration: 1969
# Less than two values for quick_sort
# quick_sort Theta 0.07422234573811737
# merge_sort Theta 0.0030631779297645425
# heap_sort Theta 0.005455161497055779
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0020661999997173552
# Sample mean is:  0.003078377537800116 Sample variance is: 2.463158832470864e-07
#
#
# Iteration: 1970
# Less than two values for quick_sort
# quick_sort Theta 0.9391488022959715
# merge_sort Theta 0.003133091595400712
# heap_sort Theta 0.005457176694094652
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030375999999705527
# Sample mean is:  0.003078289655175483 Sample variance is: 2.45788605964128e-07
#
#
# Iteration: 1971
# Less than two values for quick_sort
# quick_sort Theta 0.4745186377093972
# merge_sort Theta 0.0030381961196915353
# heap_sort Theta 0.005481451478411283
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030923999997867213
# Sample mean is:  0.003078320000002604 Sample variance is: 2.452604555720526e-07
#
#
# Iteration: 1972
# Less than two values for quick_sort
# quick_sort Theta 0.7040988916689844
# merge_sort Theta 0.003117892174394292
# heap_sort Theta 0.005436285335903327
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0016771000000517233
# Sample mean is:  0.003075313090131465 Sample variance is: 2.489384463240715e-07
#
#
# Iteration: 1973
# Less than two values for quick_sort
# quick_sort Theta 0.5909094491370217
# merge_sort Theta 0.003116885809402431
# heap_sort Theta 0.00543688987918111
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003190900000390684
# Sample mean is:  0.0030755605995752746 Sample variance is: 2.4843393514344486e-07
#
#
# Iteration: 1974
# Less than two values for quick_sort
# quick_sort Theta 0.07662193360711778
# merge_sort Theta 0.0030125891737406503
# heap_sort Theta 0.005482730818957112
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00305270000035307
# Sample mean is:  0.003075511752141039 Sample variance is: 2.479042076972305e-07
#
#
# Iteration: 1975
# Less than two values for quick_sort
# quick_sort Theta 0.9598956767303741
# merge_sort Theta 0.003054341503518518
# heap_sort Theta 0.005457629006845405
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002668999999968946
# Sample mean is:  0.003074644989343231 Sample variance is: 2.477272252829302e-07
#
#
# Iteration: 1976
# Less than two values for quick_sort
# quick_sort Theta 0.3640805991278607
# merge_sort Theta 0.0032513499782524063
# heap_sort Theta 0.005426054983647561
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0025720000003275345
# Sample mean is:  0.003073575531919793 Sample variance is: 2.477365597558766e-07
#
#
# Iteration: 1977
# Less than two values for quick_sort
# quick_sort Theta 0.5156510874167385
# merge_sort Theta 0.0029775965199628543
# heap_sort Theta 0.005501904972680331
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030369000000973756
# Sample mean is:  0.0030734976645486207 Sample variance is: 2.4721342956277965e-07
#
#
# Iteration: 1978
# Less than two values for quick_sort
# quick_sort Theta 0.8003811200100177
# merge_sort Theta 0.003093372899717213
# heap_sort Theta 0.005447935431779547
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005513900000096328
# Sample mean is:  0.003078668008479866 Sample variance is: 2.59280659245785e-07
#
#
# Iteration: 1979
# Less than two values for quick_sort
# quick_sort Theta 0.8211638993811731
# merge_sort Theta 0.0030199496631361233
# heap_sort Theta 0.005440835392424805
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0033155000000988366
# Sample mean is:  0.003079168710364895 Sample variance is: 2.5885082869775917e-07
#
#
# Iteration: 1980
# Less than two values for quick_sort
# quick_sort Theta 0.4046785486077519
# merge_sort Theta 0.002982368153312504
# heap_sort Theta 0.004946789032076083
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0032377000002270506
# Sample mean is:  0.0030795031645629166 Sample variance is: 2.5835763949883973e-07
#
#
# Iteration: 1981
# Less than two values for quick_sort
# quick_sort Theta 0.7643697092786769
# merge_sort Theta 0.003030339553264271
# heap_sort Theta 0.005475994164723271
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0035984999999527645
# Sample mean is:  0.0030805957894795267 Sample variance is: 2.5837960372362263e-07
#
#
# Iteration: 1982
# Less than two values for quick_sort
# quick_sort Theta 0.773669065095042
# merge_sort Theta 0.0030310940247171413
# heap_sort Theta 0.005450002397905141
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030263000003287743
# Sample mean is:  0.0030804817226955964 Sample variance is: 2.5784296976490374e-07
#
#
# Iteration: 1983
# Less than two values for quick_sort
# quick_sort Theta 0.7600530919068773
# merge_sort Theta 0.002875697877032106
# heap_sort Theta 0.005383897699401258
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030246000001170614
# Sample mean is:  0.0030803645702373607 Sample variance is: 2.573089514220783e-07
#
#
# Iteration: 1984
# Less than two values for quick_sort
# quick_sort Theta 0.29048523471337684
# merge_sort Theta 0.003152099371444049
# heap_sort Theta 0.005483696012907256
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003178400000251713
# Sample mean is:  0.003080569665279232 Sample variance is: 2.5679071269307285e-07
#
#
# Iteration: 1985
# Less than two values for quick_sort
# quick_sort Theta 0.28002543078886666
# merge_sort Theta 0.0031705191721654977
# heap_sort Theta 0.005467153053534913
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0031013000002531044
# Sample mean is:  0.0030806129436403464 Sample variance is: 2.562555104736995e-07
#
#
# Iteration: 1986
# Less than two values for quick_sort
# quick_sort Theta 0.5410217330680303
# merge_sort Theta 0.003162135101097362
# heap_sort Theta 0.0054657089121494555
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0029794000001857057
# Sample mean is:  0.0030804020833414825 Sample variance is: 2.557429421563193e-07
#
#
# Iteration: 1987
# Less than two values for quick_sort
# quick_sort Theta 0.46974710117606266
# merge_sort Theta 0.0032640835357783528
# heap_sort Theta 0.005459400666800042
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00305030000026818
# Sample mean is:  0.003080339501048191 Sample variance is: 2.5521313198873436e-07
#
#
# Iteration: 1988
# Less than two values for quick_sort
# quick_sort Theta 0.38245910489974166
# merge_sort Theta 0.002969182268505928
# heap_sort Theta 0.005467062710869659
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003186299999924813
# Sample mean is:  0.0030805593361081006 Sample variance is: 2.5470688966819674e-07
#
#
# Iteration: 1989
# Less than two values for quick_sort
# quick_sort Theta 0.011766713191182387
# merge_sort Theta 0.0029676079409206536
# heap_sort Theta 0.00546787834421784
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003205600000001141
# Sample mean is:  0.003080818219470198 Sample variance is: 2.542118501381991e-07
#
#
# Iteration: 1990
# Less than two values for quick_sort
# quick_sort Theta 0.5578098597525467
# merge_sort Theta 0.00307442466864951
# heap_sort Theta 0.005461522878225201
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0026745000000119035
# Sample mean is:  0.003079978719016772 Sample variance is: 2.5402701861133146e-07
#
#
# Iteration: 1991
# Less than two values for quick_sort
# quick_sort Theta 0.26258399279971567
# merge_sort Theta 0.003047719285615898
# heap_sort Theta 0.005465628309561509
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003011499999956868
# Sample mean is:  0.003079837525781597 Sample variance is: 2.535129003590034e-07
#
#
# Iteration: 1992
# Less than two values for quick_sort
# quick_sort Theta 0.4931827513079149
# merge_sort Theta 0.003041911673914993
# heap_sort Theta 0.005345233319649118
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003315699999802746
# Sample mean is:  0.003080322839514151 Sample variance is: 2.531055006450008e-07
#
#
# Iteration: 1993
# Less than two values for quick_sort
# quick_sort Theta 0.9276177954181837
# merge_sort Theta 0.0030707142035652033
# heap_sort Theta 0.005398817569080837
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003073100000165141
# Sample mean is:  0.003080308008221853 Sample variance is: 2.525858837284489e-07
#
#
# Iteration: 1994
# Less than two values for quick_sort
# quick_sort Theta 0.543965550430496
# merge_sort Theta 0.0029601561277708566
# heap_sort Theta 0.00545053916636994
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002976499999931548
# Sample mean is:  0.0030800952868933894 Sample variance is: 2.520903266314803e-07
# Iteration: 1995
# Less than two values for quick_sort
# quick_sort Theta 0.8031078317877204
# merge_sort Theta 0.0030967866325690824
# heap_sort Theta 0.005464645338092894
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003144200000406272
# Sample mean is:  0.0030802263803770555 Sample variance is: 2.5158319101584197e-07
#
#
# Iteration: 1996
# Less than two values for quick_sort
# quick_sort Theta 0.3781133305190685
# merge_sort Theta 0.0028202839055335256
# heap_sort Theta 0.005456480767418485
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002984299999752693
# Sample mean is:  0.0030800306122533323 Sample variance is: 2.5108849693452833e-07
#
#
# Iteration: 1997
# Less than two values for quick_sort
# quick_sort Theta 0.49263077568699976
# merge_sort Theta 0.0031690409064953507
# heap_sort Theta 0.0055625966356915
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003082499999891297
# Sample mean is:  0.0030800356415560575 Sample variance is: 2.505771274610487e-07
#
#
# Iteration: 1998
# Less than two values for quick_sort
# quick_sort Theta 0.09986603401005434
# merge_sort Theta 0.00309173105374912
# heap_sort Theta 0.00546643226454708
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002696199999718374
# Sample mean is:  0.0030792554878124848 Sample variance is: 2.5036666652948566e-07
#
#
# Iteration: 1999
# Less than two values for quick_sort
# quick_sort Theta 0.2611531984280884
# merge_sort Theta 0.003145799424973452
# heap_sort Theta 0.00541400761175658
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003176900000198657
# Sample mean is:  0.0030794535497037346 Sample variance is: 2.4987812382078957e-07

# %%
for elem in list_iteration_results_obcp:
    sample_mean, sample_count,rewards,cum_rewards,n = elem
    print("Up to iteration", n)
    plot_history(rewards,cum_rewards, sample_count, sample_mean)
print("Total reward", np.round(total_reward_obcp,4))
# Out:
# Up to iteration 503
# Average rewards per algo {'quick_sort': 0.006745129840548671, 'merge_sort': 0.007447001785700584, 'heap_sort': 0.010333666666712007}
# Count per chosen algo {'quick_sort': 439, 'merge_sort': 56, 'heap_sort': 9}
# Up to iteration 796
# Average rewards per algo {'quick_sort': 0.003422784931514848, 'merge_sort': 0.0, 'heap_sort': 0.006574100000307226}
# Count per chosen algo {'quick_sort': 292, 'merge_sort': 0, 'heap_sort': 1}
# Up to iteration 927
# Average rewards per algo {'quick_sort': 0.003459214285742616, 'merge_sort': 0.0028413000000000466, 'heap_sort': 0.005952708943106138}
# Count per chosen algo {'quick_sort': 7, 'merge_sort': 1, 'heap_sort': 123}
# Up to iteration 1003
# Average rewards per algo {'quick_sort': 0.003626228947304729, 'merge_sort': 0.0, 'heap_sort': 0.0}
# Count per chosen algo {'quick_sort': 76, 'merge_sort': 0, 'heap_sort': 0}
# Up to iteration 1503
# Average rewards per algo {'quick_sort': 0.006677905278590576, 'merge_sort': 0.007386542763155926, 'heap_sort': 0.010160471428662277}
# Count per chosen algo {'quick_sort': 341, 'merge_sort': 152, 'heap_sort': 7}
# Up to iteration 1774
# Average rewards per algo {'quick_sort': 0.0, 'merge_sort': 0.002621725000039987, 'heap_sort': 0.006300927340815294}
# Count per chosen algo {'quick_sort': 0, 'merge_sort': 4, 'heap_sort': 267}
# Up to iteration 1999
# Average rewards per algo {'quick_sort': 0.0033787537037521056, 'merge_sort': 0.002830062416104671, 'heap_sort': 0.006296836363658672}
# Count per chosen algo {'quick_sort': 54, 'merge_sort': 149, 'heap_sort': 22}
# Total reward 11.4185
