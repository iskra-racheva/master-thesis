# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import math
from scipy.stats import t
from scipy.stats import uniform
# %matplotlib inline
# %run ./master_experminet-functions.ipynb
# load functions for the creation of the different distributions

# %%
# define arms
def quick_sort(df):
    sorted_df = df.sort_values(kind="quicksort")
    return sorted_df
def merge_sort(df):
    sorted_df = df.sort_values(kind="mergesort")
    return sorted_df
def heap_sort(df):
    sorted_df = df.sort_values(kind="heapsort")
    return sorted_df

# %%
n_samples = 100000
choices = [quick_sort,merge_sort,heap_sort]
choices_names = ["quick_sort","merge_sort","heap_sort"]
dist_types = ["Uniform","Normal","Uniform_Sorted","Uniform_Reverse_Sorted","Uniform_Nearly_Sorted","Zipf"]

# %%
list_distributions = 1000*["Uniform_Sorted"] + 1000*["Normal"] # at first quick sort -> then merge sort 
#list_distributions = 500*["Uniform"] + 500*["Normal"]+ 500*["Uniform_Sorted"]+500*["Uniform_Reverse_Sorted"]
list_distributions_1 = 1000*["Uniform"] + 1000*["Normal"] # quick sort should be faster 
list_distributions_2 = 1000*["Uniform_Sorted"]+1000*["Uniform_Reverse_Sorted"] # merge sort should be faster

# %%
def plot_history(rewards,cum_rewards,chosen_arms ):

    fig = plt.figure(figsize=[30,8])
    ax2 = fig.add_subplot(121)
    ax2.plot(cum_rewards, label="avg rewards")
    ax2.set_title("Cummulative Rewards")
    labels = list(chosen_arms.keys())
    ax3 = fig.add_subplot(122)
    ax3.bar([i for i in range(len(chosen_arms.values()))], chosen_arms.values(), label=[i for i in ((list(chosen_arms.keys())))])
    ax3.set_title("Chosen Actions")

# %% [markdown]
# ## Thompson Sampling

# %% [markdown]
# # Probabs sampled from t Student distribution

# %%
a = 5
b = [1,2,3]
c = sum([(a-i)**2 for i in b])
c
# Out:
# 29

# %% [markdown]
# ### Quick sort should be the fastest

# %%
# initialize
total_reward = 0
num_choices = len(choices)
sample_count = [0 for i in range(num_choices)]
sample_rewards = [0 for i in range(num_choices)]
sample_mean = [0.0 for i in range(num_choices)]
sample_var = [0.0 for i in range(num_choices)]
arm_rewards = {0: [], 1:[], 2:[]}
rewards = []
cum_rewards = []
var_multiplier = 1000


for n, elem in enumerate(list_distributions_1):
    dist_type = elem
    distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
    print("\n")
    print("Iteration:", n)
    theta = {}
    for i in range(len(choices)):
        if sample_count[i] >= 2:
            theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=sample_var[i]/(sample_count[i]*(sample_count[i]-1)))
            print(choices_names[i],"Theta", theta[i])

        else:
            print("Less than two values for",choices_names[i])
            theta[i] = uniform.rvs(loc=0, scale=1)
            print(choices_names[i],"Theta", theta[i])
    
    choice = np.argmin([theta[i] for i in range(len(choices))])
    alg = choices[choice]
    alg_name = choices_names[choice]
    start_time = time.time()
    sorted_dist = alg(distribion[dist_type])
    reward = ((time.time() - start_time))*(1)
    print("Chosen algorithm is: ", alg_name, "with reward:", reward)
    arm_rewards[choice].append(reward)
    sample_count[choice] += 1
    sample_rewards[choice] += reward
    #sample_mean[choice]  += (1/sample_count[choice])*(reward-sample_mean[choice]) #this is alternative variation for non-stationary but does not work right now
    sample_mean[choice] = sample_rewards[choice]/sample_count[choice]
    sample_var[choice] = sum([(sample_mean[choice]-i)**2 for i in arm_rewards[choice]])*var_multiplier
    if sample_count[choice] >= 2:
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice]/(sample_count[choice]-1))
    else:
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
    total_reward += reward
    rewards.append(reward)
    cum_rewards.append(sum(rewards)/len(rewards))
    
    
q_values = {"quick_sort": sample_mean[0], "merge_sort": sample_mean[1], "heap_sort":sample_mean[2]} ## 
arm_counts = {"quick_sort": sample_count[0], "merge_sort": sample_count[1], "heap_sort":sample_count[2]} ## 

print("Total reward", np.round(total_reward,4))
print("Average rewards per algo", q_values)
print("Count per chosen algo", arm_counts)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.12686860447763326
# Less than two values for merge_sort
# merge_sort Theta 0.546081258615242
# Less than two values for heap_sort
# heap_sort Theta 0.3242264439244327
# Chosen algorithm is:  quick_sort with reward: 0.0169522762298584
# Sample mean is:  0.0169522762298584 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.5230701146443436
# Less than two values for merge_sort
# merge_sort Theta 0.8848031811173974
# Less than two values for heap_sort
# heap_sort Theta 0.10817893096417486
# Chosen algorithm is:  heap_sort with reward: 0.022942304611206055
# Sample mean is:  0.022942304611206055 Sample variance is: 0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.4154740922180994
# Less than two values for merge_sort
# merge_sort Theta 0.3133271425830978
# Less than two values for heap_sort
# heap_sort Theta 0.1574012963709187
# Chosen algorithm is:  heap_sort with reward: 0.022938251495361328
# Sample mean is:  0.02294027805328369 Sample variance is: 8.213874025386758e-09
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.1922104597601869
# Less than two values for merge_sort
# merge_sort Theta 0.381394098878711
# heap_sort Theta 0.022940310838901534
# Chosen algorithm is:  heap_sort with reward: 0.022937774658203125
# Sample mean is:  0.022939443588256836 Sample variance is: 6.195932655828074e-09
#
#
# Iteration: 4
# Less than two values for quick_sort
# quick_sort Theta 0.6657949898365935
# Less than two values for merge_sort
# merge_sort Theta 0.410841066721812
# heap_sort Theta 0.02293944083336228
# Chosen algorithm is:  heap_sort with reward: 0.02197551727294922
# Sample mean is:  0.02269846200942993 Sample variance is: 0.0002322926159574005
#
#
# Iteration: 5
# Less than two values for quick_sort
# quick_sort Theta 0.8121537209723695
# Less than two values for merge_sort
# merge_sort Theta 0.384640599308272
# heap_sort Theta 0.02270235997580446
# Chosen algorithm is:  heap_sort with reward: 0.021944522857666016
# Sample mean is:  0.02254767417907715 Sample variance is: 0.000287904310880549
#
#
# Iteration: 6
# Less than two values for quick_sort
# quick_sort Theta 0.8817528129867472
# Less than two values for merge_sort
# merge_sort Theta 0.7442163645602122
# heap_sort Theta 0.02263123854277611
# Chosen algorithm is:  heap_sort with reward: 0.028923749923706055
# Sample mean is:  0.023610353469848633 Sample variance is: 0.007006047098911949
#
#
# Iteration: 7
# Less than two values for quick_sort
# quick_sort Theta 0.8934470379185441
# Less than two values for merge_sort
# merge_sort Theta 0.39134079660956445
# heap_sort Theta 0.024520292646204967
# Chosen algorithm is:  heap_sort with reward: 0.022909879684448242
# Sample mean is:  0.023510285786220005 Sample variance is: 0.005908467371574217
#
#
# Iteration: 8
# Less than two values for quick_sort
# quick_sort Theta 0.5956044154434622
# Less than two values for merge_sort
# merge_sort Theta 0.21484355624235174
# heap_sort Theta 0.023801462847483745
# Chosen algorithm is:  heap_sort with reward: 0.021941661834716797
# Sample mean is:  0.023314207792282104 Sample variance is: 0.005371973241860165
#
#
# Iteration: 9
# Less than two values for quick_sort
# quick_sort Theta 0.6400436512640475
# Less than two values for merge_sort
# merge_sort Theta 0.6470614708239482
# heap_sort Theta 0.02284396581760738
# Chosen algorithm is:  heap_sort with reward: 0.021941423416137695
# Sample mean is:  0.023161676194932725 Sample variance is: 0.004909869580337221
#
#
# Iteration: 10
# Less than two values for quick_sort
# quick_sort Theta 0.30332669292765146
# Less than two values for merge_sort
# merge_sort Theta 0.2696892299719875
# heap_sort Theta 0.02142666288860243
# Chosen algorithm is:  heap_sort with reward: 0.022939205169677734
# Sample mean is:  0.023139429092407227 Sample variance is: 0.004369277851563109
#
#
# Iteration: 11
# Less than two values for quick_sort
# quick_sort Theta 0.5760623819413115
# Less than two values for merge_sort
# merge_sort Theta 0.36696535523804097
# heap_sort Theta 0.023447206015276088
# Chosen algorithm is:  heap_sort with reward: 0.021942853927612305
# Sample mean is:  0.023030649531971325 Sample variance is: 0.004062512986861706
#
#
# Iteration: 12
# Less than two values for quick_sort
# quick_sort Theta 0.4069453620502983
# Less than two values for merge_sort
# merge_sort Theta 0.46861200904929445
# heap_sort Theta 0.023060210895746936
# Chosen algorithm is:  heap_sort with reward: 0.028684616088867188
# Sample mean is:  0.023501813411712646 Sample variance is: 0.0063571384432944715
#
#
# Iteration: 13
# Less than two values for quick_sort
# quick_sort Theta 0.6847611641109432
# Less than two values for merge_sort
# merge_sort Theta 0.23621122162144415
# heap_sort Theta 0.023053743542692913
# Chosen algorithm is:  heap_sort with reward: 0.022931575775146484
# Sample mean is:  0.023457948978130635 Sample variance is: 0.005852390057288386
#
#
# Iteration: 14
# Less than two values for quick_sort
# quick_sort Theta 0.9679225077312057
# Less than two values for merge_sort
# merge_sort Theta 0.5778351712755054
# heap_sort Theta 0.02294633832377179
# Chosen algorithm is:  heap_sort with reward: 0.02194070816040039
# Sample mean is:  0.023349574634007046 Sample variance is: 0.005566636185226792
#
#
# Iteration: 15
# Less than two values for quick_sort
# quick_sort Theta 0.09030492727009465
# Less than two values for merge_sort
# merge_sort Theta 0.03767521351430991
# heap_sort Theta 0.023600985673628262
# Chosen algorithm is:  heap_sort with reward: 0.02097177505493164
# Sample mean is:  0.023191054662068684 Sample variance is: 0.005545948037403529
#
#
# Iteration: 16
# Less than two values for quick_sort
# quick_sort Theta 0.4797253852884562
# Less than two values for merge_sort
# merge_sort Theta 0.38297099675874
# heap_sort Theta 0.022936430134012153
# Chosen algorithm is:  heap_sort with reward: 0.022936582565307617
# Sample mean is:  0.023175150156021118 Sample variance is: 0.005180265421245167
#
#
# Iteration: 17
# Less than two values for quick_sort
# quick_sort Theta 0.3457391286747138
# Less than two values for merge_sort
# merge_sort Theta 0.28770106514911675
# heap_sort Theta 0.022948977276287655
# Chosen algorithm is:  heap_sort with reward: 0.023967266082763672
# Sample mean is:  0.023221745210535386 Sample variance is: 0.0048934075172055325
#
#
# Iteration: 18
# Less than two values for quick_sort
# quick_sort Theta 0.055198017045213876
# Less than two values for merge_sort
# merge_sort Theta 0.1596600882952398
# heap_sort Theta 0.02341709814658724
# Chosen algorithm is:  heap_sort with reward: 0.022937536239624023
# Sample mean is:  0.02320595582326253 Sample variance is: 0.004610047501701582
#
#
# Iteration: 19
# Less than two values for quick_sort
# quick_sort Theta 0.15797449989756418
# Less than two values for merge_sort
# merge_sort Theta 0.6631811561819633
# heap_sort Theta 0.023339770191828063
# Chosen algorithm is:  heap_sort with reward: 0.022941112518310547
# Sample mean is:  0.02319201670194927 Sample variance is: 0.00435762543456378
#
#
# Iteration: 20
# Less than two values for quick_sort
# quick_sort Theta 0.11785826222189832
# Less than two values for merge_sort
# merge_sort Theta 0.6199736040128596
# heap_sort Theta 0.0231044168278198
# Chosen algorithm is:  heap_sort with reward: 0.02297377586364746
# Sample mean is:  0.02318110466003418 Sample variance is: 0.004130658180656608
#
#
# Iteration: 21
# Less than two values for quick_sort
# quick_sort Theta 0.8012554381048843
# Less than two values for merge_sort
# merge_sort Theta 0.17984897858621807
# heap_sort Theta 0.023247498737468533
# Chosen algorithm is:  heap_sort with reward: 0.022925853729248047
# Sample mean is:  0.02316894985380627 Sample variance is: 0.003927227797226979
#
#
# Iteration: 22
# Less than two values for quick_sort
# quick_sort Theta 0.37610090454330414
# Less than two values for merge_sort
# merge_sort Theta 0.06754009915199366
# heap_sort Theta 0.02332850527791329
# Chosen algorithm is:  heap_sort with reward: 0.023910045623779297
# Sample mean is:  0.02320263602516868 Sample variance is: 0.0037651816288432486
#
#
# Iteration: 23
# Less than two values for quick_sort
# quick_sort Theta 0.2201182297592621
# Less than two values for merge_sort
# merge_sort Theta 0.9469566165413738
# heap_sort Theta 0.023003130139294576
# Chosen algorithm is:  heap_sort with reward: 0.02294135093688965
# Sample mean is:  0.023191275803939156 Sample variance is: 0.0035970052657571983
#
#
# Iteration: 24
# Less than two values for quick_sort
# quick_sort Theta 0.4232153547249312
# Less than two values for merge_sort
# merge_sort Theta 0.498540609649911
# heap_sort Theta 0.023209052984627172
# Chosen algorithm is:  heap_sort with reward: 0.025959253311157227
# Sample mean is:  0.023306608200073242 Sample variance is: 0.003759851210816123
#
#
# Iteration: 25
# Less than two values for quick_sort
# quick_sort Theta 0.7411899912629267
# Less than two values for merge_sort
# merge_sort Theta 0.8659587919801027
# heap_sort Theta 0.02361878479041181
# Chosen algorithm is:  heap_sort with reward: 0.022973060607910156
# Sample mean is:  0.023293266296386717 Sample variance is: 0.0036076409035482957
#
#
# Iteration: 26
# Less than two values for quick_sort
# quick_sort Theta 0.09123883403300403
# Less than two values for merge_sort
# merge_sort Theta 0.9214030741287188
# heap_sort Theta 0.023418976759305103
# Chosen algorithm is:  heap_sort with reward: 0.022942304611206055
# Sample mean is:  0.023279767770033617 Sample variance is: 0.0034680727329627053
#
#
# Iteration: 27
# Less than two values for quick_sort
# quick_sort Theta 0.1861125613444352
# Less than two values for merge_sort
# merge_sort Theta 0.5151766904590482
# heap_sort Theta 0.023210239076954624
# Chosen algorithm is:  heap_sort with reward: 0.024933338165283203
# Sample mean is:  0.023341011118005822 Sample variance is: 0.003435955507269258
#
#
# Iteration: 28
# Less than two values for quick_sort
# quick_sort Theta 0.18069748352259096
# Less than two values for merge_sort
# merge_sort Theta 0.46735865970503176
# heap_sort Theta 0.023155996775036384
# Chosen algorithm is:  heap_sort with reward: 0.023936748504638672
# Sample mean is:  0.02336228745324271 Sample variance is: 0.0033213730042400626
#
#
# Iteration: 29
# Less than two values for quick_sort
# quick_sort Theta 0.5038499505398971
# Less than two values for merge_sort
# merge_sort Theta 0.9087632841395523
# heap_sort Theta 0.02327857257151452
# Chosen algorithm is:  heap_sort with reward: 0.024905920028686523
# Sample mean is:  0.023415516162740773 Sample variance is: 0.0032849181097329623
#
#
# Iteration: 30
# Less than two values for quick_sort
# quick_sort Theta 0.8300456557097922
# Less than two values for merge_sort
# merge_sort Theta 0.29414007299741296
# heap_sort Theta 0.023389818776826013
# Chosen algorithm is:  heap_sort with reward: 0.03589582443237305
# Sample mean is:  0.023831526438395183 Sample variance is: 0.008363581554968032
#
#
# Iteration: 31
# Less than two values for quick_sort
# quick_sort Theta 0.40144725152938665
# Less than two values for merge_sort
# merge_sort Theta 0.9860846017262088
# heap_sort Theta 0.0239332220080947
# Chosen algorithm is:  heap_sort with reward: 0.03490710258483887
# Sample mean is:  0.02418880308828046 Sample variance is: 0.012041840244286485
#
#
# Iteration: 32
# Less than two values for quick_sort
# quick_sort Theta 0.7710726380478656
# Less than two values for merge_sort
# merge_sort Theta 0.9240245265941611
# heap_sort Theta 0.024242769802756758
# Chosen algorithm is:  heap_sort with reward: 0.03391122817993164
# Sample mean is:  0.024492628872394562 Sample variance is: 0.014607317211754886
#
#
# Iteration: 33
# Less than two values for quick_sort
# quick_sort Theta 0.7953709074412104
# Less than two values for merge_sort
# merge_sort Theta 0.7493007267234119
# heap_sort Theta 0.024452096744151535
# Chosen algorithm is:  heap_sort with reward: 0.03989911079406738
# Sample mean is:  0.024959491960930103 Sample variance is: 0.021343556282306678
#
#
# Iteration: 34
# Less than two values for quick_sort
# quick_sort Theta 0.2896719023356764
# Less than two values for merge_sort
# merge_sort Theta 0.10569986559274269
# heap_sort Theta 0.024947466057975307
# Chosen algorithm is:  heap_sort with reward: 0.03391098976135254
# Sample mean is:  0.02522277130800135 Sample variance is: 0.02305352634571444
#
#
# Iteration: 35
# Less than two values for quick_sort
# quick_sort Theta 0.7561725862170638
# Less than two values for merge_sort
# merge_sort Theta 0.4249808849984269
# heap_sort Theta 0.024891408823618816
# Chosen algorithm is:  heap_sort with reward: 0.022939682006835938
# Sample mean is:  0.02515754018511091 Sample variance is: 0.0225244099319676
#
#
# Iteration: 36
# Less than two values for quick_sort
# quick_sort Theta 0.693918953749958
# Less than two values for merge_sort
# merge_sort Theta 0.6907126973938368
# heap_sort Theta 0.024687330032038268
# Chosen algorithm is:  heap_sort with reward: 0.0229644775390625
# Sample mean is:  0.02509662177827623 Sample variance is: 0.02201445324496872
#
#
# Iteration: 37
# Less than two values for quick_sort
# quick_sort Theta 0.43244940935216114
# Less than two values for merge_sort
# merge_sort Theta 0.523044448744416
# heap_sort Theta 0.02464410927876187
# Chosen algorithm is:  heap_sort with reward: 0.021939992904663086
# Sample mean is:  0.025011307484394795 Sample variance is: 0.02167224621822876
#
#
# Iteration: 38
# Less than two values for quick_sort
# quick_sort Theta 0.29815732799187855
# Less than two values for merge_sort
# merge_sort Theta 0.5809993963913964
# heap_sort Theta 0.024895951692737193
# Chosen algorithm is:  heap_sort with reward: 0.021970272064208984
# Sample mean is:  0.024931280236495167 Sample variance is: 0.02132987552939506
#
#
# Iteration: 39
# Less than two values for quick_sort
# quick_sort Theta 0.4126171672106663
# Less than two values for merge_sort
# merge_sort Theta 0.7804799249132582
# heap_sort Theta 0.025590381867574733
# Chosen algorithm is:  heap_sort with reward: 0.023948192596435547
# Sample mean is:  0.024906072861109026 Sample variance is: 0.020793344074644074
#
#
# Iteration: 40
# Less than two values for quick_sort
# quick_sort Theta 0.06668894833011285
# Less than two values for merge_sort
# merge_sort Theta 0.11976469704498782
# heap_sort Theta 0.024772216707286212
# Chosen algorithm is:  heap_sort with reward: 0.02494645118713379
# Sample mean is:  0.024907082319259644 Sample variance is: 0.020260222166293775
#
#
# Iteration: 41
# Less than two values for quick_sort
# quick_sort Theta 0.35547425127353327
# Less than two values for merge_sort
# merge_sort Theta 0.8665298095417874
# heap_sort Theta 0.024228902976732445
# Chosen algorithm is:  heap_sort with reward: 0.024938106536865234
# Sample mean is:  0.024907839007493927 Sample variance is: 0.01975374008779687
#
#
# Iteration: 42
# Less than two values for quick_sort
# quick_sort Theta 0.3689580189060223
# Less than two values for merge_sort
# merge_sort Theta 0.28696896099141034
# heap_sort Theta 0.02379498185107448
# Chosen algorithm is:  heap_sort with reward: 0.023945331573486328
# Sample mean is:  0.024884922163827077 Sample variance is: 0.01929399918146345
#
#
# Iteration: 43
# Less than two values for quick_sort
# quick_sort Theta 0.8340461667874267
# Less than two values for merge_sort
# merge_sort Theta 0.0019258232850665191
# heap_sort Theta 0.02401512604477359
# Chosen algorithm is:  merge_sort with reward: 0.0169525146484375
# Sample mean is:  0.0169525146484375 Sample variance is: 0.0
#
#
# Iteration: 44
# Less than two values for quick_sort
# quick_sort Theta 0.6750547317177602
# Less than two values for merge_sort
# merge_sort Theta 0.8790654505741248
# heap_sort Theta 0.024722184170591514
# Chosen algorithm is:  heap_sort with reward: 0.03192281723022461
# Sample mean is:  0.025048594142115393 Sample variance is: 0.019986524457074314
#
#
# Iteration: 45
# Less than two values for quick_sort
# quick_sort Theta 0.1566925983305152
# Less than two values for merge_sort
# merge_sort Theta 0.11292987698523682
# heap_sort Theta 0.025429248770846163
# Chosen algorithm is:  heap_sort with reward: 0.02692890167236328
# Sample mean is:  0.02509132840416648 Sample variance is: 0.019602075117457995
#
#
# Iteration: 46
# Less than two values for quick_sort
# quick_sort Theta 0.5623203830936792
# Less than two values for merge_sort
# merge_sort Theta 0.6782742504371005
# heap_sort Theta 0.02514118467095619
# Chosen algorithm is:  heap_sort with reward: 0.02293872833251953
# Sample mean is:  0.02504349284701877 Sample variance is: 0.019259544233986473
#
#
# Iteration: 47
# Less than two values for quick_sort
# quick_sort Theta 0.06307291147818228
# Less than two values for merge_sort
# merge_sort Theta 0.1625205162209279
# heap_sort Theta 0.024833597381959577
# Chosen algorithm is:  heap_sort with reward: 0.02294135093688965
# Sample mean is:  0.024997794109842052 Sample variance is: 0.018927619592779273
#
#
# Iteration: 48
# Less than two values for quick_sort
# quick_sort Theta 0.3127816581193412
# Less than two values for merge_sort
# merge_sort Theta 0.5676180211350318
# heap_sort Theta 0.025049145261629425
# Chosen algorithm is:  heap_sort with reward: 0.023936748504638672
# Sample mean is:  0.02497521867143347 Sample variance is: 0.018540103171340857
#
#
# Iteration: 49
# Less than two values for quick_sort
# quick_sort Theta 0.6076190582146886
# Less than two values for merge_sort
# merge_sort Theta 0.3784712621362315
# heap_sort Theta 0.025615328736199646
# Chosen algorithm is:  heap_sort with reward: 0.023973464965820312
# Sample mean is:  0.02495434880256653 Sample variance is: 0.018166539359572683
#
#
# Iteration: 50
# Less than two values for quick_sort
# quick_sort Theta 0.8087466691189188
# Less than two values for merge_sort
# merge_sort Theta 0.8630836479567001
# heap_sort Theta 0.025178253004502354
# Chosen algorithm is:  heap_sort with reward: 0.023970603942871094
# Sample mean is:  0.024934272376858458 Sample variance is: 0.01780781987017295
#
#
# Iteration: 51
# Less than two values for quick_sort
# quick_sort Theta 0.4401631419453145
# Less than two values for merge_sort
# merge_sort Theta 0.46001886988375396
# heap_sort Theta 0.024469607431841827
# Chosen algorithm is:  heap_sort with reward: 0.022933483123779297
# Sample mean is:  0.024894256591796875 Sample variance is: 0.017524458127568046
#
#
# Iteration: 52
# Less than two values for quick_sort
# quick_sort Theta 0.5190152447749268
# Less than two values for merge_sort
# merge_sort Theta 0.01905994113598286
# heap_sort Theta 0.024556253242249068
# Chosen algorithm is:  merge_sort with reward: 0.015955448150634766
# Sample mean is:  0.016453981399536133 Sample variance is: 0.0004970708005203051
#
#
# Iteration: 53
# Less than two values for quick_sort
# quick_sort Theta 0.40145265160373134
# merge_sort Theta 0.016147472087840207
# heap_sort Theta 0.025118451417062763
# Chosen algorithm is:  merge_sort with reward: 0.015959978103637695
# Sample mean is:  0.016289313634236652 Sample variance is: 0.0003298818190463256
#
#
# Iteration: 54
# Less than two values for quick_sort
# quick_sort Theta 0.3497149562182714
# merge_sort Theta 0.01604714829378345
# heap_sort Theta 0.025619922360586325
# Chosen algorithm is:  merge_sort with reward: 0.015952348709106445
# Sample mean is:  0.0162050724029541 Sample variance is: 0.00024830755288955214
#
#
# Iteration: 55
# Less than two values for quick_sort
# quick_sort Theta 0.17527851530897132
# merge_sort Theta 0.016110521382513517
# heap_sort Theta 0.024488703049647446
# Chosen algorithm is:  merge_sort with reward: 0.016958236694335938
# Sample mean is:  0.01635570526123047 Sample variance is: 0.0002996819546297047
#
#
# Iteration: 56
# Less than two values for quick_sort
# quick_sort Theta 0.9662566466022111
# merge_sort Theta 0.016424388087600807
# heap_sort Theta 0.025079001963273156
# Chosen algorithm is:  merge_sort with reward: 0.018950462341308594
# Sample mean is:  0.016788164774576824 Sample variance is: 0.0013618729478063567
#
#
# Iteration: 57
# Less than two values for quick_sort
# quick_sort Theta 0.24389411181033904
# merge_sort Theta 0.01649199642766336
# heap_sort Theta 0.02437527296337386
# Chosen algorithm is:  merge_sort with reward: 0.01598811149597168
# Sample mean is:  0.0166738714490618 Sample variance is: 0.001226334872972941
#
#
# Iteration: 58
# Less than two values for quick_sort
# quick_sort Theta 0.6079190525683396
# merge_sort Theta 0.016855733931074444
# heap_sort Theta 0.02465034836882056
# Chosen algorithm is:  merge_sort with reward: 0.013997077941894531
# Sample mean is:  0.016339272260665894 Sample variance is: 0.0019467971118355568
#
#
# Iteration: 59
# Less than two values for quick_sort
# quick_sort Theta 0.051636628287940134
# merge_sort Theta 0.016373179850423403
# heap_sort Theta 0.0247764147692525
# Chosen algorithm is:  merge_sort with reward: 0.015959739685058594
# Sample mean is:  0.016297101974487305 Sample variance is: 0.001719452470183569
#
#
# Iteration: 60
# Less than two values for quick_sort
# quick_sort Theta 0.8108486005123722
# merge_sort Theta 0.016138362300591305
# heap_sort Theta 0.02535287191288193
# Chosen algorithm is:  merge_sort with reward: 0.015958070755004883
# Sample mean is:  0.016263198852539063 Sample variance is: 0.0015398964124971018
#
#
# Iteration: 61
# Less than two values for quick_sort
# quick_sort Theta 0.47137000357248626
# merge_sort Theta 0.01617484913338934
# heap_sort Theta 0.025384677777539718
# Chosen algorithm is:  merge_sort with reward: 0.014991521835327148
# Sample mean is:  0.016147591850974342 Sample variance is: 0.0015329215381660274
#
#
# Iteration: 62
# Less than two values for quick_sort
# quick_sort Theta 0.13264569369853074
# merge_sort Theta 0.01642183202051147
# heap_sort Theta 0.024715090291927796
# Chosen algorithm is:  merge_sort with reward: 0.017953872680664062
# Sample mean is:  0.016298115253448486 Sample variance is: 0.0016654525710051034
#
#
# Iteration: 63
# Less than two values for quick_sort
# quick_sort Theta 0.26994833798651596
# merge_sort Theta 0.01634376273199181
# heap_sort Theta 0.02478062068103304
# Chosen algorithm is:  merge_sort with reward: 0.01695704460144043
# Sample mean is:  0.016348802126370944 Sample variance is: 0.0015600639248812235
#
#
# Iteration: 64
# Less than two values for quick_sort
# quick_sort Theta 0.28439511777926896
# merge_sort Theta 0.016572006388388922
# heap_sort Theta 0.024737557929498163
# Chosen algorithm is:  merge_sort with reward: 0.015985727310180664
# Sample mean is:  0.016322868210928782 Sample variance is: 0.001449474959164925
#
#
# Iteration: 65
# Less than two values for quick_sort
# quick_sort Theta 0.48970231314654855
# merge_sort Theta 0.016258631478144735
# heap_sort Theta 0.02567257592212579
# Chosen algorithm is:  merge_sort with reward: 0.014959335327148438
# Sample mean is:  0.01623196601867676 Sample variance is: 0.0014698891618536438
#
#
# Iteration: 66
# Less than two values for quick_sort
# quick_sort Theta 0.35534603532987274
# merge_sort Theta 0.016384466310636843
# heap_sort Theta 0.024711448639811583
# Chosen algorithm is:  merge_sort with reward: 0.01496124267578125
# Sample mean is:  0.01615254580974579 Sample variance is: 0.0014728176644496216
#
#
# Iteration: 67
# Less than two values for quick_sort
# quick_sort Theta 0.9333364371075216
# merge_sort Theta 0.01611018602055009
# heap_sort Theta 0.02493416348154057
# Chosen algorithm is:  merge_sort with reward: 0.015967130661010742
# Sample mean is:  0.016141639036290786 Sample variance is: 0.0013827888414438992
#
#
# Iteration: 68
# Less than two values for quick_sort
# quick_sort Theta 0.843910088604902
# merge_sort Theta 0.01607876495455738
# heap_sort Theta 0.025255011469249834
# Chosen algorithm is:  merge_sort with reward: 0.015958547592163086
# Sample mean is:  0.016131467289394803 Sample variance is: 0.0013033106811874504
#
#
# Iteration: 69
# Less than two values for quick_sort
# quick_sort Theta 0.328820098167831
# merge_sort Theta 0.0161617153067901
# heap_sort Theta 0.0254077092225027
# Chosen algorithm is:  merge_sort with reward: 0.014960527420043945
# Sample mean is:  0.016069838875218442 Sample variance is: 0.0013030676994765609
#
#
# Iteration: 70
# Less than two values for quick_sort
# quick_sort Theta 0.9200633962198861
# merge_sort Theta 0.01619296042439607
# heap_sort Theta 0.024571415742952837
# Chosen algorithm is:  merge_sort with reward: 0.016956329345703125
# Sample mean is:  0.016114163398742675 Sample variance is: 0.0012737784566908025
#
#
# Iteration: 71
# Less than two values for quick_sort
# quick_sort Theta 0.2508352702785398
# merge_sort Theta 0.016149796089539196
# heap_sort Theta 0.025001389050200218
# Chosen algorithm is:  merge_sort with reward: 0.015992403030395508
# Sample mean is:  0.016108365285964238 Sample variance is: 0.0012107955142038832
#
#
# Iteration: 72
# Less than two values for quick_sort
# quick_sort Theta 0.09707572529032704
# merge_sort Theta 0.01618773869029203
# heap_sort Theta 0.024993183598281784
# Chosen algorithm is:  merge_sort with reward: 0.0159604549407959
# Sample mean is:  0.01610164208845659 Sample variance is: 0.0011541330154200707
#
#
# Iteration: 73
# Less than two values for quick_sort
# quick_sort Theta 0.9209878692791234
# merge_sort Theta 0.01615864054881594
# heap_sort Theta 0.025592429742172792
# Chosen algorithm is:  merge_sort with reward: 0.014987468719482422
# Sample mean is:  0.016053199768066406 Sample variance is: 0.0011556455671201218
#
#
# Iteration: 74
# Less than two values for quick_sort
# quick_sort Theta 0.789777264961731
# merge_sort Theta 0.016040456071567722
# heap_sort Theta 0.024949353548845945
# Chosen algorithm is:  merge_sort with reward: 0.014960765838623047
# Sample mean is:  0.016007681687672932 Sample variance is: 0.001155125603105077
#
#
# Iteration: 75
# Less than two values for quick_sort
# quick_sort Theta 0.9445975837998266
# merge_sort Theta 0.015974933427383854
# heap_sort Theta 0.024699194663881895
# Chosen algorithm is:  merge_sort with reward: 0.01595783233642578
# Sample mean is:  0.016005687713623047 Sample variance is: 0.001107094767955156
#
#
# Iteration: 76
# Less than two values for quick_sort
# quick_sort Theta 0.28832542380181747
# merge_sort Theta 0.015995733199503127
# heap_sort Theta 0.024908912531937794
# Chosen algorithm is:  merge_sort with reward: 0.015958786010742188
# Sample mean is:  0.016003883801973783 Sample variance is: 0.0010628955837651468
#
#
# Iteration: 77
# Less than two values for quick_sort
# quick_sort Theta 0.521624502389357
# merge_sort Theta 0.016005766099408986
# heap_sort Theta 0.025033554157237865
# Chosen algorithm is:  merge_sort with reward: 0.015958786010742188
# Sample mean is:  0.01600221351340965 Sample variance is: 0.001022090310714526
#
#
# Iteration: 78
# Less than two values for quick_sort
# quick_sort Theta 0.7275617765705144
# merge_sort Theta 0.016030053267765364
# heap_sort Theta 0.02406473266135668
# Chosen algorithm is:  merge_sort with reward: 0.024932861328125
# Sample mean is:  0.016321165221078054 Sample variance is: 0.003832680485109969
#
#
# Iteration: 79
# Less than two values for quick_sort
# quick_sort Theta 0.43666113819074315
# merge_sort Theta 0.01627595792138569
# heap_sort Theta 0.025048619594962407
# Chosen algorithm is:  merge_sort with reward: 0.01795220375061035
# Sample mean is:  0.016377407928992962 Sample variance is: 0.003787533062827628
#
#
# Iteration: 80
# Less than two values for quick_sort
# quick_sort Theta 0.14112874641141782
# merge_sort Theta 0.016247306845110738
# heap_sort Theta 0.02479890666690011
# Chosen algorithm is:  merge_sort with reward: 0.015991926193237305
# Sample mean is:  0.016364558537801107 Sample variance is: 0.003661881680074302
#
#
# Iteration: 81
# Less than two values for quick_sort
# quick_sort Theta 0.04391650191765428
# merge_sort Theta 0.016494323062642653
# heap_sort Theta 0.024437839018087444
# Chosen algorithm is:  merge_sort with reward: 0.014985084533691406
# Sample mean is:  0.016320059376378215 Sample variance is: 0.0036012043937927217
#
#
# Iteration: 82
# Less than two values for quick_sort
# quick_sort Theta 0.3582139856950576
# merge_sort Theta 0.016474629662503994
# heap_sort Theta 0.024715604727654786
# Chosen algorithm is:  merge_sort with reward: 0.015956401824951172
# Sample mean is:  0.016308695077896118 Sample variance is: 0.0034891692230816732
#
#
# Iteration: 83
# Less than two values for quick_sort
# quick_sort Theta 0.12868513367640133
# merge_sort Theta 0.016326757607406046
# heap_sort Theta 0.025151379243385636
# Chosen algorithm is:  merge_sort with reward: 0.01396489143371582
# Sample mean is:  0.01623767072504217 Sample variance is: 0.003546599821905003
#
#
# Iteration: 84
# Less than two values for quick_sort
# quick_sort Theta 0.2315228482764905
# merge_sort Theta 0.016184678528769546
# heap_sort Theta 0.02519913065411094
# Chosen algorithm is:  merge_sort with reward: 0.017955303192138672
# Sample mean is:  0.016288189327015597 Sample variance is: 0.0035258994909709764
#
#
# Iteration: 85
# Less than two values for quick_sort
# quick_sort Theta 0.6814947743501895
# merge_sort Theta 0.016306900697125093
# heap_sort Theta 0.024930044209104368
# Chosen algorithm is:  merge_sort with reward: 0.014988183975219727
# Sample mean is:  0.016251046316964286 Sample variance is: 0.003470482676614459
#
#
# Iteration: 86
# Less than two values for quick_sort
# quick_sort Theta 0.5448265572255704
# merge_sort Theta 0.016215107538242575
# heap_sort Theta 0.024796202174606173
# Chosen algorithm is:  merge_sort with reward: 0.014963388442993164
# Sample mean is:  0.01621527804268731 Sample variance is: 0.003417383328722295
#
#
# Iteration: 87
# Less than two values for quick_sort
# quick_sort Theta 0.0625916907118571
# merge_sort Theta 0.016192474072220943
# heap_sort Theta 0.02512961600927123
# Chosen algorithm is:  merge_sort with reward: 0.014960050582885742
# Sample mean is:  0.01618135297620619 Sample variance is: 0.003365039689058264
#
#
# Iteration: 88
# Less than two values for quick_sort
# quick_sort Theta 0.5045237643031631
# merge_sort Theta 0.01625336034903858
# heap_sort Theta 0.025128302544050702
# Chosen algorithm is:  merge_sort with reward: 0.01595902442932129
# Sample mean is:  0.016175502224972372 Sample variance is: 0.0032753934594550666
#
#
# Iteration: 89
# Less than two values for quick_sort
# quick_sort Theta 0.5301356706674358
# merge_sort Theta 0.016310889165226716
# heap_sort Theta 0.02450326929716315
# Chosen algorithm is:  merge_sort with reward: 0.014963626861572266
# Sample mean is:  0.016144428497705705 Sample variance is: 0.0032268563792560555
#
#
# Iteration: 90
# Less than two values for quick_sort
# quick_sort Theta 0.2920995332630113
# merge_sort Theta 0.016180365729942824
# heap_sort Theta 0.02566195733810845
# Chosen algorithm is:  merge_sort with reward: 0.013965129852294922
# Sample mean is:  0.016089946031570435 Sample variance is: 0.003262850036742876
#
#
# Iteration: 91
# Less than two values for quick_sort
# quick_sort Theta 0.25027402406085464
# merge_sort Theta 0.016091177106242298
# heap_sort Theta 0.025250767791410247
# Chosen algorithm is:  merge_sort with reward: 0.014961481094360352
# Sample mean is:  0.01606242249651653 Sample variance is: 0.003212338130080708
#
#
# Iteration: 92
# Less than two values for quick_sort
# quick_sort Theta 0.483379012880621
# merge_sort Theta 0.01604556861414551
# heap_sort Theta 0.024512984135225385
# Chosen algorithm is:  merge_sort with reward: 0.01699233055114746
# Sample mean is:  0.016084563164483933 Sample variance is: 0.0031545772050687315
#
#
# Iteration: 93
# Less than two values for quick_sort
# quick_sort Theta 0.8582659846490025
# merge_sort Theta 0.016171182230693623
# heap_sort Theta 0.025548233701356737
# Chosen algorithm is:  merge_sort with reward: 0.01499319076538086
# Sample mean is:  0.01605918241101642 Sample variance is: 0.00310716807779855
#
#
# Iteration: 94
# Less than two values for quick_sort
# quick_sort Theta 0.1913182339906767
# merge_sort Theta 0.016148972750077546
# heap_sort Theta 0.024638238303114148
# Chosen algorithm is:  merge_sort with reward: 0.014989614486694336
# Sample mean is:  0.01603487404910001 Sample variance is: 0.003060907799257655
#
#
# Iteration: 95
# Less than two values for quick_sort
# quick_sort Theta 0.7655535995291387
# merge_sort Theta 0.01620015919469681
# heap_sort Theta 0.024484084474265796
# Chosen algorithm is:  merge_sort with reward: 0.014964818954467773
# Sample mean is:  0.01601109504699707 Sample variance is: 0.0030167865552564108
#
#
# Iteration: 96
# Less than two values for quick_sort
# quick_sort Theta 0.8613919579077804
# merge_sort Theta 0.015963112123319332
# heap_sort Theta 0.02542197194764871
# Chosen algorithm is:  merge_sort with reward: 0.014961957931518555
# Sample mean is:  0.01598828771839971 Sample variance is: 0.002973674868964894
#
#
# Iteration: 97
# Less than two values for quick_sort
# quick_sort Theta 0.8929790464805151
# merge_sort Theta 0.016021223945183814
# heap_sort Theta 0.025048718378137734
# Chosen algorithm is:  merge_sort with reward: 0.014992475509643555
# Sample mean is:  0.015967100224596388 Sample variance is: 0.0029301285281201246
#
#
# Iteration: 98
# Less than two values for quick_sort
# quick_sort Theta 0.9203104247128884
# merge_sort Theta 0.015999969904866546
# heap_sort Theta 0.024050914208106015
# Chosen algorithm is:  merge_sort with reward: 0.01599431037902832
# Sample mean is:  0.01596766710281372 Sample variance is: 0.002867800792791194
#
#
# Iteration: 99
# Less than two values for quick_sort
# quick_sort Theta 0.2679635959886968
# merge_sort Theta 0.015955398477780405
# heap_sort Theta 0.02487694443877388
# Chosen algorithm is:  merge_sort with reward: 0.014929533004760742
# Sample mean is:  0.015946480692649374 Sample variance is: 0.002830049277748322
#
#
# Iteration: 100
# Less than two values for quick_sort
# quick_sort Theta 0.36246099257632347
# merge_sort Theta 0.015995482796827224
# heap_sort Theta 0.024352806932720062
# Chosen algorithm is:  merge_sort with reward: 0.015959501266479492
# Sample mean is:  0.015946741104125976 Sample variance is: 0.0027722965607460295
#
#
# Iteration: 101
# Less than two values for quick_sort
# quick_sort Theta 0.22577144544844985
# merge_sort Theta 0.015920531372743248
# heap_sort Theta 0.025117687261086364
# Chosen algorithm is:  merge_sort with reward: 0.01598525047302246
# Sample mean is:  0.015947496189790612 Sample variance is: 0.002716879707403516
#
#
# Iteration: 102
# Less than two values for quick_sort
# quick_sort Theta 0.5667534063300275
# merge_sort Theta 0.01605094361168331
# heap_sort Theta 0.02501284751155585
# Chosen algorithm is:  merge_sort with reward: 0.015957117080688477
# Sample mean is:  0.015947681206923265 Sample variance is: 0.0026636093363076063
#
#
# Iteration: 103
# Less than two values for quick_sort
# quick_sort Theta 0.16710470097998686
# merge_sort Theta 0.0159730921944229
# heap_sort Theta 0.02463127805480942
# Chosen algorithm is:  merge_sort with reward: 0.014959573745727539
# Sample mean is:  0.01592903766991957 Sample variance is: 0.002630807897856578
#
#
# Iteration: 104
# Less than two values for quick_sort
# quick_sort Theta 0.47716406299914016
# merge_sort Theta 0.0158456253260856
# heap_sort Theta 0.025382618657840358
# Chosen algorithm is:  merge_sort with reward: 0.015956640243530273
# Sample mean is:  0.01592954882869014 Sample variance is: 0.002581184122288951
#
#
# Iteration: 105
# Less than two values for quick_sort
# quick_sort Theta 0.14922469187652898
# merge_sort Theta 0.01597669442036373
# heap_sort Theta 0.02416232067547334
# Chosen algorithm is:  merge_sort with reward: 0.014960765838623047
# Sample mean is:  0.0159119345925071 Sample variance is: 0.002550448788717789
#
#
# Iteration: 106
# Less than two values for quick_sort
# quick_sort Theta 0.6081358189868517
# merge_sort Theta 0.015938951394748654
# heap_sort Theta 0.025404797545512694
# Chosen algorithm is:  merge_sort with reward: 0.01495981216430664
# Sample mean is:  0.015894932406289235 Sample variance is: 0.002520265155385754
#
#
# Iteration: 107
# Less than two values for quick_sort
# quick_sort Theta 0.47842013510050474
# merge_sort Theta 0.01590904207564118
# heap_sort Theta 0.02505023932774756
# Chosen algorithm is:  merge_sort with reward: 0.013964653015136719
# Sample mean is:  0.015861067855567262 Sample variance is: 0.0025406284648174177
#
#
# Iteration: 108
# Less than two values for quick_sort
# quick_sort Theta 0.09069401691031498
# merge_sort Theta 0.015852699897188665
# heap_sort Theta 0.024963640888936857
# Chosen algorithm is:  merge_sort with reward: 0.016953468322753906
# Sample mean is:  0.015879902346380825 Sample variance is: 0.0025166308421740525
#
#
# Iteration: 109
# Less than two values for quick_sort
# quick_sort Theta 0.08203882904038462
# merge_sort Theta 0.01584102078181698
# heap_sort Theta 0.024889918439385105
# Chosen algorithm is:  merge_sort with reward: 0.014988183975219727
# Sample mean is:  0.01586478847568318 Sample variance is: 0.002486717971400461
#
#
# Iteration: 110
# Less than two values for quick_sort
# quick_sort Theta 0.6981015214586717
# merge_sort Theta 0.01585787749944059
# heap_sort Theta 0.02461344889747884
# Chosen algorithm is:  merge_sort with reward: 0.015990257263183594
# Sample mean is:  0.01586687962214152 Sample variance is: 0.002444832582783949
#
#
# Iteration: 111
# Less than two values for quick_sort
# quick_sort Theta 0.07273822237777705
# merge_sort Theta 0.0158786096200896
# heap_sort Theta 0.0247347911582882
# Chosen algorithm is:  merge_sort with reward: 0.014929056167602539
# Sample mean is:  0.015851505467149078 Sample variance is: 0.0024185036162165125
#
#
# Iteration: 112
# Less than two values for quick_sort
# quick_sort Theta 0.752634048460453
# merge_sort Theta 0.01584139885450958
# heap_sort Theta 0.02437443324707132
# Chosen algorithm is:  merge_sort with reward: 0.014960289001464844
# Sample mean is:  0.015837131008025137 Sample variance is: 0.002391666770607229
#
#
# Iteration: 113
# Less than two values for quick_sort
# quick_sort Theta 0.2685157010605136
# merge_sort Theta 0.015852987417174298
# heap_sort Theta 0.02513853761322628
# Chosen algorithm is:  merge_sort with reward: 0.014961719512939453
# Sample mean is:  0.01582323558746822 Sample variance is: 0.002365255710998136
#
#
# Iteration: 114
# Less than two values for quick_sort
# quick_sort Theta 0.6003691310263451
# merge_sort Theta 0.015841773416927746
# heap_sort Theta 0.02395784354992668
# Chosen algorithm is:  merge_sort with reward: 0.01499176025390625
# Sample mean is:  0.015810243785381317 Sample variance is: 0.0023385143325275032
#
#
# Iteration: 115
# Less than two values for quick_sort
# quick_sort Theta 0.0008272180530468631
# merge_sort Theta 0.015820554046296557
# heap_sort Theta 0.025048729884611588
# Chosen algorithm is:  quick_sort with reward: 0.012969493865966797
# Sample mean is:  0.014960885047912598 Sample variance is: 0.007931277679062987
#
#
# Iteration: 116
# quick_sort Theta 0.016038012124365668
# merge_sort Theta 0.01579037117780303
# heap_sort Theta 0.025136078368897526
# Chosen algorithm is:  merge_sort with reward: 0.019983291625976562
# Sample mean is:  0.015874444521390474 Sample variance is: 0.0025698877888494028
#
#
# Iteration: 117
# quick_sort Theta 0.017001737287458844
# merge_sort Theta 0.015859579184021772
# heap_sort Theta 0.025021343550837873
# Chosen algorithm is:  merge_sort with reward: 0.015985965728759766
# Sample mean is:  0.015876134236653645 Sample variance is: 0.0025305394927225924
#
#
# Iteration: 118
# quick_sort Theta 0.012467477992967137
# merge_sort Theta 0.015772585407384528
# heap_sort Theta 0.025691953419960695
# Chosen algorithm is:  quick_sort with reward: 0.011997699737548828
# Sample mean is:  0.013973156611124674 Sample variance is: 0.006892461234050036
#
#
# Iteration: 119
# quick_sort Theta 0.012498674104706469
# merge_sort Theta 0.015910804494487833
# heap_sort Theta 0.025135424580309155
# Chosen algorithm is:  quick_sort with reward: 0.014962911605834961
# Sample mean is:  0.014220595359802246 Sample variance is: 0.004839877893421847
#
#
# Iteration: 120
# quick_sort Theta 0.019977523922366593
# merge_sort Theta 0.015851712552578705
# heap_sort Theta 0.025047196300504417
# Chosen algorithm is:  merge_sort with reward: 0.01894855499267578
# Sample mean is:  0.015921991262862933 Sample variance is: 0.00263309006439196
#
#
# Iteration: 121
# quick_sort Theta 0.01499552495588595
# merge_sort Theta 0.015988421049155387
# heap_sort Theta 0.025097438772717577
# Chosen algorithm is:  quick_sort with reward: 0.014958858489990234
# Sample mean is:  0.014368247985839844 Sample variance is: 0.0037389149099453785
#
#
# Iteration: 122
# quick_sort Theta 0.014647518588768485
# merge_sort Theta 0.015892707777497846
# heap_sort Theta 0.024768764409991022
# Chosen algorithm is:  quick_sort with reward: 0.012994766235351562
# Sample mean is:  0.014139334360758463 Sample variance is: 0.0033055406144436956
#
#
# Iteration: 123
# quick_sort Theta 0.014211025443829038
# merge_sort Theta 0.015907143866318953
# heap_sort Theta 0.024532325322500867
# Chosen algorithm is:  quick_sort with reward: 0.013989448547363281
# Sample mean is:  0.01411792210170201 Sample variance is: 0.0027578265725683843
#
#
# Iteration: 124
# quick_sort Theta 0.014540995062921674
# merge_sort Theta 0.015912562724534687
# heap_sort Theta 0.024984579003504447
# Chosen algorithm is:  quick_sort with reward: 0.012965917587280273
# Sample mean is:  0.013973921537399292 Sample variance is: 0.0025297406480717655
#
#
# Iteration: 125
# quick_sort Theta 0.013994593297914306
# merge_sort Theta 0.015961383105539403
# heap_sort Theta 0.025137277084644645
# Chosen algorithm is:  quick_sort with reward: 0.012967109680175781
# Sample mean is:  0.013862053553263346 Sample variance is: 0.0023261530799345564
#
#
# Iteration: 126
# quick_sort Theta 0.014015932034071301
# merge_sort Theta 0.015998085265261846
# heap_sort Theta 0.024829010594584925
# Chosen algorithm is:  quick_sort with reward: 0.013965845108032227
# Sample mean is:  0.013872432708740234 Sample variance is: 0.0020687688952926286
#
#
# Iteration: 127
# quick_sort Theta 0.013957149964658659
# merge_sort Theta 0.015912678068719866
# heap_sort Theta 0.024874721928307232
# Chosen algorithm is:  quick_sort with reward: 0.012969493865966797
# Sample mean is:  0.013790347359397194 Sample variance is: 0.0019360100561078238
#
#
# Iteration: 128
# quick_sort Theta 0.013912841107963658
# merge_sort Theta 0.01582598072362302
# heap_sort Theta 0.024661367545488738
# Chosen algorithm is:  quick_sort with reward: 0.013961076736450195
# Sample mean is:  0.013804574807484945 Sample variance is: 0.0017624381852652784
#
#
# Iteration: 129
# quick_sort Theta 0.013808759275955257
# merge_sort Theta 0.015880772664216107
# heap_sort Theta 0.024721250408366865
# Chosen algorithm is:  quick_sort with reward: 0.012993574142456055
# Sample mean is:  0.013742190140944261 Sample variance is: 0.001666162342545272
#
#
# Iteration: 130
# quick_sort Theta 0.013837386445373308
# merge_sort Theta 0.01591611587383017
# heap_sort Theta 0.024933149063274186
# Chosen algorithm is:  quick_sort with reward: 0.013962507247924805
# Sample mean is:  0.013757927077157157 Sample variance is: 0.001541463124762491
#
#
# Iteration: 131
# quick_sort Theta 0.013836176784431805
# merge_sort Theta 0.015958684509499787
# heap_sort Theta 0.02484441415955159
# Chosen algorithm is:  quick_sort with reward: 0.013965129852294922
# Sample mean is:  0.013771740595499675 Sample variance is: 0.0014342208151858708
#
#
# Iteration: 132
# quick_sort Theta 0.013927252706761593
# merge_sort Theta 0.015856625409769256
# heap_sort Theta 0.02493389694812676
# Chosen algorithm is:  quick_sort with reward: 0.013962984085083008
# Sample mean is:  0.013783693313598633 Sample variance is: 0.0013408919736927298
#
#
# Iteration: 133
# quick_sort Theta 0.013749830657323865
# merge_sort Theta 0.01596852866695968
# heap_sort Theta 0.024577311112075798
# Chosen algorithm is:  quick_sort with reward: 0.013965129852294922
# Sample mean is:  0.013794366051169002 Sample variance is: 0.0012590226499001158
#
#
# Iteration: 134
# quick_sort Theta 0.013879735535169243
# merge_sort Theta 0.01585083091881162
# heap_sort Theta 0.024631160874364483
# Chosen algorithm is:  quick_sort with reward: 0.012967109680175781
# Sample mean is:  0.013748407363891602 Sample variance is: 0.0012229821108763537
#
#
# Iteration: 135
# quick_sort Theta 0.013813873519285855
# merge_sort Theta 0.015841210180255035
# heap_sort Theta 0.025133590959040674
# Chosen algorithm is:  quick_sort with reward: 0.012998342514038086
# Sample mean is:  0.01370893026653089 Sample variance is: 0.0011846490433766264
#
#
# Iteration: 136
# quick_sort Theta 0.013693704743013695
# merge_sort Theta 0.015945297318642956
# heap_sort Theta 0.02487806403140534
# Chosen algorithm is:  quick_sort with reward: 0.01296377182006836
# Sample mean is:  0.013671672344207764 Sample variance is: 0.0011500621492419479
#
#
# Iteration: 137
# quick_sort Theta 0.013727885064257348
# merge_sort Theta 0.01593909357147314
# heap_sort Theta 0.024599466911359755
# Chosen algorithm is:  quick_sort with reward: 0.013992071151733398
# Sample mean is:  0.013686929430280412 Sample variance is: 0.0010974473939638434
#
#
# Iteration: 138
# quick_sort Theta 0.013591331649244656
# merge_sort Theta 0.015995548309061327
# heap_sort Theta 0.02483858694360573
# Chosen algorithm is:  quick_sort with reward: 0.013964414596557617
# Sample mean is:  0.013699542392383923 Sample variance is: 0.0010486879041378193
#
#
# Iteration: 139
# quick_sort Theta 0.01362567166735111
# merge_sort Theta 0.015898030569796405
# heap_sort Theta 0.02501218497153239
# Chosen algorithm is:  quick_sort with reward: 0.013963460922241211
# Sample mean is:  0.01371101711107337 Sample variance is: 0.0010040486630185997
#
#
# Iteration: 140
# quick_sort Theta 0.013711946965527943
# merge_sort Theta 0.015938802996982145
# heap_sort Theta 0.02584954858720332
# Chosen algorithm is:  quick_sort with reward: 0.012999773025512695
# Sample mean is:  0.013681381940841675 Sample variance is: 0.0009814722128740157
#
#
# Iteration: 141
# quick_sort Theta 0.013696126887236695
# merge_sort Theta 0.0158783052040658
# heap_sort Theta 0.025344565454923182
# Chosen algorithm is:  quick_sort with reward: 0.012934207916259766
# Sample mean is:  0.013651494979858398 Sample variance is: 0.0009629082982579956
#
#
# Iteration: 142
# quick_sort Theta 0.013646579181332538
# merge_sort Theta 0.01589399623974668
# heap_sort Theta 0.024482022440270167
# Chosen algorithm is:  quick_sort with reward: 0.012967586517333984
# Sample mean is:  0.013625190808222843 Sample variance is: 0.0009423816119089259
#
#
# Iteration: 143
# quick_sort Theta 0.013556552844138524
# merge_sort Theta 0.015914096574857407
# heap_sort Theta 0.024318641304116078
# Chosen algorithm is:  quick_sort with reward: 0.013935565948486328
# Sample mean is:  0.013636686183788159 Sample variance is: 0.0009097040441005098
#
#
# Iteration: 144
# quick_sort Theta 0.013585639027107724
# merge_sort Theta 0.01589727943293092
# heap_sort Theta 0.025315416877440697
# Chosen algorithm is:  quick_sort with reward: 0.012967109680175781
# Sample mean is:  0.013612772737230574 Sample variance is: 0.0008920231836617663
#
#
# Iteration: 145
# quick_sort Theta 0.013606031531624117
# merge_sort Theta 0.015883789914647707
# heap_sort Theta 0.02512930259265247
# Chosen algorithm is:  quick_sort with reward: 0.012965917587280273
# Sample mean is:  0.013590467387232286 Sample variance is: 0.0008745935433345388
#
#
# Iteration: 146
# quick_sort Theta 0.013573071836674533
# merge_sort Theta 0.015962497746518763
# heap_sort Theta 0.024415744544024526
# Chosen algorithm is:  quick_sort with reward: 0.01396322250366211
# Sample mean is:  0.013602892557779947 Sample variance is: 0.0008490666911826738
#
#
# Iteration: 147
# quick_sort Theta 0.013585563540570193
# merge_sort Theta 0.015887611612796955
# heap_sort Theta 0.024352178110953727
# Chosen algorithm is:  quick_sort with reward: 0.012963294982910156
# Sample mean is:  0.01358226037794544 Sample variance is: 0.0008339607603296806
# Iteration: 148
# quick_sort Theta 0.013536745893699341
# merge_sort Theta 0.015885391594781133
# heap_sort Theta 0.025020711017648488
# Chosen algorithm is:  quick_sort with reward: 0.01396322250366211
# Sample mean is:  0.013594165444374084 Sample variance is: 0.000811594179732501
#
#
# Iteration: 149
# quick_sort Theta 0.013592779295788818
# merge_sort Theta 0.015855629231580518
# heap_sort Theta 0.025170562087400733
# Chosen algorithm is:  quick_sort with reward: 0.011997699737548828
# Sample mean is:  0.01354578769568241 Sample variance is: 0.0008634652783755292
#
#
# Iteration: 150
# quick_sort Theta 0.013536378641668416
# merge_sort Theta 0.01592573665646921
# heap_sort Theta 0.024532891711622068
# Chosen algorithm is:  quick_sort with reward: 0.01396632194519043
# Sample mean is:  0.013558156350079705 Sample variance is: 0.0008425011066736909
#
#
# Iteration: 151
# quick_sort Theta 0.01358720621871872
# merge_sort Theta 0.015898753648301983
# heap_sort Theta 0.024612065787074287
# Chosen algorithm is:  quick_sort with reward: 0.011969804763793945
# Sample mean is:  0.013512774876185825 Sample variance is: 0.0008898033984070875
#
#
# Iteration: 152
# quick_sort Theta 0.013478821381289124
# merge_sort Theta 0.015956252656763408
# heap_sort Theta 0.024359482442163186
# Chosen algorithm is:  quick_sort with reward: 0.012964248657226562
# Sample mean is:  0.013497538036770292 Sample variance is: 0.000872738250080378
#
#
# Iteration: 153
# quick_sort Theta 0.013486941727522383
# merge_sort Theta 0.01590949361461242
# heap_sort Theta 0.025055756750717306
# Chosen algorithm is:  quick_sort with reward: 0.011996030807495117
# ...
#
#
# Iteration: 1943
# quick_sort Theta 0.014228334545100163
# merge_sort Theta 0.01594418003307695
# heap_sort Theta 0.025283518693521703
# Chosen algorithm is:  quick_sort with reward: 0.01396322250366211
# Sample mean is:  0.014228117420298843 Sample variance is: 0.002233120443614304
#
#
# Iteration: 1944
# quick_sort Theta 0.014226866579349599
# merge_sort Theta 0.01595470256042866
# heap_sort Theta 0.02454959872706354
# Chosen algorithm is:  quick_sort with reward: 0.013991594314575195
# Sample mean is:  0.014227988031291336 Sample variance is: 0.0022319287589577155
#
#
# Iteration: 1945
# quick_sort Theta 0.014229632838747243
# merge_sort Theta 0.015909813015603104
# heap_sort Theta 0.02437687709740486
# Chosen algorithm is:  quick_sort with reward: 0.012990236282348633
# Sample mean is:  0.014227311294413838 Sample variance is: 0.002231545423618981
#
#
# Iteration: 1946
# quick_sort Theta 0.014229324393766722
# merge_sort Theta 0.015886486095050622
# heap_sort Theta 0.02463109992667782
# Chosen algorithm is:  quick_sort with reward: 0.012995004653930664
# Sample mean is:  0.014226637902807017 Sample variance is: 0.0022311551581228736
#
#
# Iteration: 1947
# quick_sort Theta 0.014226498581096687
# merge_sort Theta 0.015894104563203698
# heap_sort Theta 0.024997627262884143
# Chosen algorithm is:  quick_sort with reward: 0.012968301773071289
# Sample mean is:  0.014225950662976468 Sample variance is: 0.00223080072636253
#
#
# Iteration: 1948
# quick_sort Theta 0.014225652928986523
# merge_sort Theta 0.0158789148916093
# heap_sort Theta 0.024177457490838033
# Chosen algorithm is:  quick_sort with reward: 0.013960838317871094
# Sample mean is:  0.014225805950997698 Sample variance is: 0.0022296207402698097
#
#
# Iteration: 1949
# quick_sort Theta 0.01422646473178174
# merge_sort Theta 0.015887145192071107
# heap_sort Theta 0.024916035796244494
# Chosen algorithm is:  quick_sort with reward: 0.013990402221679688
# Sample mean is:  0.014225677525613455 Sample variance is: 0.0022284339301953944
#
#
# Iteration: 1950
# quick_sort Theta 0.01422741831781176
# merge_sort Theta 0.015921758307904092
# heap_sort Theta 0.024744750956789102
# Chosen algorithm is:  quick_sort with reward: 0.01499176025390625
# Sample mean is:  0.014226095237024738 Sample variance is: 0.0022275382012346347
#
#
# Iteration: 1951
# quick_sort Theta 0.014225459468593486
# merge_sort Theta 0.015972406447274327
# heap_sort Theta 0.025221060431647555
# Chosen algorithm is:  quick_sort with reward: 0.012964725494384766
# Sample mean is:  0.014225407842069621 Sample variance is: 0.00222719068126037
#
#
# Iteration: 1952
# quick_sort Theta 0.014226291567285467
# merge_sort Theta 0.015977404124961517
# heap_sort Theta 0.02527533259655486
# Chosen algorithm is:  quick_sort with reward: 0.013966798782348633
# Sample mean is:  0.01422526698746193 Sample variance is: 0.0022260133796463306
#
#
# Iteration: 1953
# quick_sort Theta 0.014224951394372118
# merge_sort Theta 0.015944058375771467
# heap_sort Theta 0.024890252693746815
# Chosen algorithm is:  quick_sort with reward: 0.013959884643554688
# Sample mean is:  0.014225122522386313 Sample variance is: 0.002224839292538666
#
#
# Iteration: 1954
# quick_sort Theta 0.014225029418394064
# merge_sort Theta 0.015846536352465277
# heap_sort Theta 0.024703150489608635
# Chosen algorithm is:  quick_sort with reward: 0.013993978500366211
# Sample mean is:  0.014224996763941252 Sample variance is: 0.0022236572343993267
#
#
# Iteration: 1955
# quick_sort Theta 0.01422495394971519
# merge_sort Theta 0.015938636212721395
# heap_sort Theta 0.024845405873387037
# Chosen algorithm is:  quick_sort with reward: 0.013991594314575195
# Sample mean is:  0.014224869845806742 Sample variance is: 0.0022224770330097703
#
#
# Iteration: 1956
# quick_sort Theta 0.014223713888182088
# merge_sort Theta 0.01587293599218071
# heap_sort Theta 0.025344546878552962
# Chosen algorithm is:  quick_sort with reward: 0.012968301773071289
# Sample mean is:  0.014224186928375907 Sample variance is: 0.0022221266404900096
#
#
# Iteration: 1957
# quick_sort Theta 0.014224010001196151
# merge_sort Theta 0.015972735570209194
# heap_sort Theta 0.02484858452767053
# Chosen algorithm is:  quick_sort with reward: 0.013964176177978516
# Sample mean is:  0.014224045694942775 Sample variance is: 0.002220955685178937
#
#
# Iteration: 1958
# quick_sort Theta 0.014224746178009708
# merge_sort Theta 0.015900072037320065
# heap_sort Theta 0.024237768955447707
# Chosen algorithm is:  quick_sort with reward: 0.014963626861572266
# Sample mean is:  0.014224447204805223 Sample variance is: 0.002220046248822454
#
#
# Iteration: 1959
# quick_sort Theta 0.014224379546272562
# merge_sort Theta 0.015915808002815814
# heap_sort Theta 0.02442931824682875
# Chosen algorithm is:  quick_sort with reward: 0.013962268829345703
# Sample mean is:  0.014224304948497322 Sample variance is: 0.0022188783085158423
#
#
# Iteration: 1960
# quick_sort Theta 0.01422346487659143
# merge_sort Theta 0.015936041258282473
# heap_sort Theta 0.025040116926875022
# Chosen algorithm is:  quick_sort with reward: 0.013964176177978516
# Sample mean is:  0.014224163880834351 Sample variance is: 0.002217711055109973
#
#
# Iteration: 1961
# quick_sort Theta 0.014221568682178673
# merge_sort Theta 0.01590712935179633
# heap_sort Theta 0.024253270441757686
# Chosen algorithm is:  quick_sort with reward: 0.013990163803100586
# Sample mean is:  0.014224037051523928 Sample variance is: 0.0022165380699164846
#
#
# Iteration: 1962
# quick_sort Theta 0.014226406343200087
# merge_sort Theta 0.015898841190463066
# heap_sort Theta 0.02485159114509563
# Chosen algorithm is:  quick_sort with reward: 0.012968778610229492
# Sample mean is:  0.014223357063202532 Sample variance is: 0.002216190255349224
#
#
# Iteration: 1963
# quick_sort Theta 0.014223691536956145
# merge_sort Theta 0.015874999341145658
# heap_sort Theta 0.024796398388960143
# Chosen algorithm is:  quick_sort with reward: 0.013962268829345703
# Sample mean is:  0.014223215705198279 Sample variance is: 0.0022150266258278975
#
#
# Iteration: 1964
# quick_sort Theta 0.014223853411588543
# merge_sort Theta 0.01589374993922549
# heap_sort Theta 0.025425399656969376
# Chosen algorithm is:  quick_sort with reward: 0.013929605484008789
# Sample mean is:  0.014223056825208457 Sample variance is: 0.0022138740181870528
#
#
# Iteration: 1965
# quick_sort Theta 0.014222607934203688
# merge_sort Theta 0.015898137340222798
# heap_sort Theta 0.025310882928237775
# Chosen algorithm is:  quick_sort with reward: 0.012954473495483398
# Sample mean is:  0.014222370733629374 Sample variance is: 0.0022135463987508685
#
#
# Iteration: 1966
# quick_sort Theta 0.0142235929915911
# merge_sort Theta 0.015931033490119408
# heap_sort Theta 0.02502018938933508
# Chosen algorithm is:  quick_sort with reward: 0.01393437385559082
# Sample mean is:  0.014222215059641245 Sample variance is: 0.0022123940736937524
#
#
# Iteration: 1967
# quick_sort Theta 0.014220780713370585
# merge_sort Theta 0.01586831936384253
# heap_sort Theta 0.02519489778427195
# Chosen algorithm is:  quick_sort with reward: 0.014959335327148438
# Sample mean is:  0.01422261328777064 Sample variance is: 0.0022114917270305377
#
#
# Iteration: 1968
# quick_sort Theta 0.014221194389460968
# merge_sort Theta 0.015966099040306457
# heap_sort Theta 0.024577310741682297
# Chosen algorithm is:  quick_sort with reward: 0.013963937759399414
# Sample mean is:  0.014222473614159207 Sample variance is: 0.002210333102055815
#
#
# Iteration: 1969
# quick_sort Theta 0.014223302634762527
# merge_sort Theta 0.01590311748000151
# heap_sort Theta 0.025244479264562154
# Chosen algorithm is:  quick_sort with reward: 0.012966394424438477
# Sample mean is:  0.0142217957516715 Sample variance is: 0.0022099910666237657
#
#
# Iteration: 1970
# quick_sort Theta 0.014220660887290338
# merge_sort Theta 0.015876655026144763
# heap_sort Theta 0.024762334308687683
# Chosen algorithm is:  quick_sort with reward: 0.013964176177978516
# Sample mean is:  0.014221656798287631 Sample variance is: 0.0022088342080058515
#
#
# Iteration: 1971
# quick_sort Theta 0.014224777058118657
# merge_sort Theta 0.01598554663531228
# heap_sort Theta 0.025051092142820138
# Chosen algorithm is:  quick_sort with reward: 0.013964653015136719
# Sample mean is:  0.014221518251773804 Sample variance is: 0.0022076784265223424
#
#
# Iteration: 1972
# quick_sort Theta 0.01422236002565549
# merge_sort Theta 0.01586835979075217
# heap_sort Theta 0.025440636708638414
# Chosen algorithm is:  quick_sort with reward: 0.015958070755004883
# Sample mean is:  0.01422245389428632 Sample variance is: 0.0022081130957286067
#
#
# Iteration: 1973
# quick_sort Theta 0.01422426953303489
# merge_sort Theta 0.0158882878261826
# heap_sort Theta 0.02446564398442417
# Chosen algorithm is:  quick_sort with reward: 0.013969182968139648
# Sample mean is:  0.014222317507142462 Sample variance is: 0.002206957922519212
#
#
# Iteration: 1974
# quick_sort Theta 0.014221106649210152
# merge_sort Theta 0.01593461166465972
# heap_sort Theta 0.024651930263209106
# Chosen algorithm is:  quick_sort with reward: 0.013994932174682617
# Sample mean is:  0.014222195125370415 Sample variance is: 0.002205797296961384
#
#
# Iteration: 1975
# quick_sort Theta 0.014221566901615008
# merge_sort Theta 0.015940706655666426
# heap_sort Theta 0.024993306269221527
# Chosen algorithm is:  quick_sort with reward: 0.012965202331542969
# Sample mean is:  0.014221518959262923 Sample variance is: 0.00220546004381329
#
#
# Iteration: 1976
# quick_sort Theta 0.014219939458729224
# merge_sort Theta 0.01598349220344155
# heap_sort Theta 0.024817949841984047
# Chosen algorithm is:  quick_sort with reward: 0.012995481491088867
# Sample mean is:  0.014220859799333798 Sample variance is: 0.0022050818295447443
#
#
# Iteration: 1977
# quick_sort Theta 0.014220867271884102
# merge_sort Theta 0.015937209755517216
# heap_sort Theta 0.02475476849083367
# Chosen algorithm is:  quick_sort with reward: 0.012964248657226562
# Sample mean is:  0.014220184564974793 Sample variance is: 0.0022047448086984574
#
#
# Iteration: 1978
# quick_sort Theta 0.014219798355235009
# merge_sort Theta 0.01594615039937114
# heap_sort Theta 0.025594151386280403
# Chosen algorithm is:  quick_sort with reward: 0.013992071151733398
# Sample mean is:  0.014220062055085836 Sample variance is: 0.0022035880451167582
#
#
# Iteration: 1979
# quick_sort Theta 0.014221222347640996
# merge_sort Theta 0.015948202873037352
# heap_sort Theta 0.025349099435571707
# Chosen algorithm is:  quick_sort with reward: 0.014961719512939453
# Sample mean is:  0.014220460153560259 Sample variance is: 0.002202699845593117
#
#
# Iteration: 1980
# quick_sort Theta 0.01422059037456545
# merge_sort Theta 0.015885886436013685
# heap_sort Theta 0.02481001257075472
# Chosen algorithm is:  quick_sort with reward: 0.014930009841918945
# Sample mean is:  0.014220840813264315 Sample variance is: 0.002201787602339048
#
#
# Iteration: 1981
# quick_sort Theta 0.014220703024582036
# merge_sort Theta 0.015902621227160803
# heap_sort Theta 0.024556707161796226
# Chosen algorithm is:  quick_sort with reward: 0.012998580932617188
# Sample mean is:  0.014220185446036086 Sample variance is: 0.002201407414884349
#
#
# Iteration: 1982
# quick_sort Theta 0.01421955522343281
# merge_sort Theta 0.015869718557689486
# heap_sort Theta 0.02482854060897958
# Chosen algorithm is:  quick_sort with reward: 0.013964176177978516
# Sample mean is:  0.014220048249215047 Sample variance is: 0.002200262159231146
#
#
# Iteration: 1983
# quick_sort Theta 0.014220179141511706
# merge_sort Theta 0.015908965866352265
# heap_sort Theta 0.025161545727439293
# Chosen algorithm is:  quick_sort with reward: 0.013962745666503906
# Sample mean is:  0.014219910433155748 Sample variance is: 0.0021991184866692005
#
#
# Iteration: 1984
# quick_sort Theta 0.014219301744073109
# merge_sort Theta 0.01593810406265451
# heap_sort Theta 0.024635767673510046
# Chosen algorithm is:  quick_sort with reward: 0.013996124267578125
# Sample mean is:  0.014219790633281243 Sample variance is: 0.0021979674073717742
#
#
# Iteration: 1985
# quick_sort Theta 0.014221801162457857
# merge_sort Theta 0.015966761165655517
# heap_sort Theta 0.025219491897460106
# Chosen algorithm is:  quick_sort with reward: 0.016954660415649414
# Sample mean is:  0.014221253912993585 Sample variance is: 0.0022007926447591758
#
#
# Iteration: 1986
# quick_sort Theta 0.014218571382902516
# merge_sort Theta 0.01590859277017882
# heap_sort Theta 0.024540981942007857
# Chosen algorithm is:  quick_sort with reward: 0.012990713119506836
# Sample mean is:  0.014220595869788511 Sample variance is: 0.002200424869612394
#
#
# Iteration: 1987
# quick_sort Theta 0.014223008139039955
# merge_sort Theta 0.01594221364017627
# heap_sort Theta 0.024992879038663377
# Chosen algorithm is:  quick_sort with reward: 0.012997150421142578
# Sample mean is:  0.014219941970564223 Sample variance is: 0.00220004818185098
#
#
# Iteration: 1988
# quick_sort Theta 0.014218372691066497
# merge_sort Theta 0.015926295070665633
# heap_sort Theta 0.024603987439279405
# Chosen algorithm is:  quick_sort with reward: 0.012969017028808594
# Sample mean is:  0.01421927374142867 Sample variance is: 0.0021997082187957006
#
#
# Iteration: 1989
# quick_sort Theta 0.014220096615216709
# merge_sort Theta 0.015997340189500702
# heap_sort Theta 0.025322497314990117
# Chosen algorithm is:  quick_sort with reward: 0.012966394424438477
# Sample mean is:  0.014218604825616073 Sample variance is: 0.00219937123177292
#
#
# Iteration: 1990
# quick_sort Theta 0.014218898872529053
# merge_sort Theta 0.015903895590846956
# heap_sort Theta 0.024101460698438958
# Chosen algorithm is:  quick_sort with reward: 0.014928102493286133
# Sample mean is:  0.014218983426292525 Sample variance is: 0.0021984655975456715
#
#
# Iteration: 1991
# quick_sort Theta 0.014219069802581566
# merge_sort Theta 0.015933359977193886
# heap_sort Theta 0.025009202065125358
# Chosen algorithm is:  quick_sort with reward: 0.013993501663208008
# Sample mean is:  0.014218863169352213 Sample variance is: 0.0021973195726322186
#
#
# Iteration: 1992
# quick_sort Theta 0.014218892869205838
# merge_sort Theta 0.015909355534141887
# heap_sort Theta 0.025062334509670565
# Chosen algorithm is:  quick_sort with reward: 0.012967824935913086
# Sample mean is:  0.014218196304622236 Sample variance is: 0.0021969819421338794
#
#
# Iteration: 1993
# quick_sort Theta 0.01421871498329155
# merge_sort Theta 0.015857558839779042
# heap_sort Theta 0.02535807492821177
# Chosen algorithm is:  quick_sort with reward: 0.01296234130859375
# Sample mean is:  0.014217527228971714 Sample variance is: 0.0021966511050160414
#
#
# Iteration: 1994
# quick_sort Theta 0.014217105605253147
# merge_sort Theta 0.01592396120311591
# heap_sort Theta 0.02446609615807809
# Chosen algorithm is:  quick_sort with reward: 0.012964010238647461
# Sample mean is:  0.014216859754535972 Sample variance is: 0.0021963174966247007
#
#
# Iteration: 1995
# quick_sort Theta 0.014217292723796694
# merge_sort Theta 0.015907997063205892
# heap_sort Theta 0.024828824297986125
# Chosen algorithm is:  quick_sort with reward: 0.012967824935913086
# Sample mean is:  0.014216195020731489 Sample variance is: 0.0021959782741571123
#
#
# Iteration: 1996
# quick_sort Theta 0.014216849991949877
# merge_sort Theta 0.015924972330303665
# heap_sort Theta 0.025586668964320755
# Chosen algorithm is:  quick_sort with reward: 0.013963937759399414
# Sample mean is:  0.014216060841337164 Sample variance is: 0.0021948434266871744
#
#
# Iteration: 1997
# quick_sort Theta 0.014215731577498012
# merge_sort Theta 0.015944184448369172
# heap_sort Theta 0.024538370190582224
# Chosen algorithm is:  quick_sort with reward: 0.012966394424438477
# Sample mean is:  0.014215396478542428 Sample variance is: 0.0021945061886525763
#
#
# Iteration: 1998
# quick_sort Theta 0.014216208574550445
# merge_sort Theta 0.015904182597324762
# heap_sort Theta 0.02467688551477687
# Chosen algorithm is:  quick_sort with reward: 0.012975454330444336
# Sample mean is:  0.014214737635743225 Sample variance is: 0.002194156445651528
#
#
# Iteration: 1999
# quick_sort Theta 0.01421437923098224
# merge_sort Theta 0.015936962994558882
# heap_sort Theta 0.02483995216630597
# Chosen algorithm is:  quick_sort with reward: 0.012968778610229492
# Sample mean is:  0.014214075947466267 Sample variance is: 0.002193815017920984
# Total reward 29.0766
# Average rewards per algo {'quick_sort': 0.014214075947466267, 'merge_sort': 0.015921991262862933, 'heap_sort': 0.024894256591796875}
# Count per chosen algo {'quick_sort': 1883, 'merge_sort': 67, 'heap_sort': 50}

# %%
plot_history(rewards,cum_rewards, arm_counts)

# %% [markdown]
# ### Merge sort should be the fastest

# %%
# initialize
total_reward = 0
num_choices = len(choices)
sample_count = [0 for i in range(num_choices)]
sample_rewards = [0 for i in range(num_choices)]
sample_mean = [0.0 for i in range(num_choices)]
sample_var = [0.0 for i in range(num_choices)]
arm_rewards = {0: [], 1:[], 2:[]}
rewards = []
cum_rewards = []
var_multiplier = 1000


for n, elem in enumerate(list_distributions_2):
    dist_type = elem
    distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
    print("\n")
    print("Iteration:", n)
    theta = {}
    for i in range(len(choices)):
        if sample_count[i] >= 2:
            theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=sample_var[i]/(sample_count[i]*(sample_count[i]-1)))
            print(choices_names[i],"Theta", theta[i])

        else:
            print("Less than two values for",choices_names[i])
            theta[i] = uniform.rvs(loc=0, scale=1)
            print(choices_names[i],"Theta", theta[i])
    choice = np.argmin([theta[i] for i in range(len(choices))])
    alg = choices[choice]
    alg_name = choices_names[choice]
    start_time = time.time()
    sorted_dist = alg(distribion[dist_type])
    reward = ((time.time() - start_time))*(1)
    print("\n")
    print("Chosen algorithm is: ", alg_name, "with reward:", reward)
    arm_rewards[choice].append(reward)
    sample_count[choice] += 1
    sample_rewards[choice] += reward
    #sample_mean[choice]  += (1/sample_count[choice])*(reward-sample_mean[choice]) #this is alternative variation for non-stationary but does not work right now
    sample_mean[choice] = sample_rewards[choice]/sample_count[choice]
    sample_var[choice] = sum([(sample_mean[choice]-i)**2 for i in arm_rewards[choice]])*var_multiplier
    if sample_count[choice] >= 2:
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice]/(sample_count[choice]-1))
    else:
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
    total_reward += reward
    rewards.append(reward)
    cum_rewards.append(sum(rewards)/len(rewards))
    
    
q_values = {"quick_sort": sample_mean[0], "merge_sort": sample_mean[1], "heap_sort":sample_mean[2]} ## 
arm_counts = {"quick_sort": sample_count[0], "merge_sort": sample_count[1], "heap_sort":sample_count[2]} ## 

print("Total reward", np.round(total_reward,4))
print("Average rewards per algo", q_values)
print("Count per chosen algo", arm_counts)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.4041872107528063
# Less than two values for merge_sort
# merge_sort Theta 0.6911540906981121
# Less than two values for heap_sort
# heap_sort Theta 0.4151544073803797
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006983518600463867
# Sample mean is:  0.006983518600463867 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.5007297310317637
# Less than two values for merge_sort
# merge_sort Theta 0.9734351134173095
# Less than two values for heap_sort
# heap_sort Theta 0.4991393686650808
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972023010253906
# Sample mean is:  0.010972023010253906 Sample variance is: 0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.9472452699850503
# Less than two values for merge_sort
# merge_sort Theta 0.9656179363216744
# Less than two values for heap_sort
# heap_sort Theta 0.7622828647018026
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011968135833740234
# Sample mean is:  0.01147007942199707 Sample variance is: 0.0004961203785569523
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.905220001785279
# Less than two values for merge_sort
# merge_sort Theta 0.25657687886894553
# heap_sort Theta 0.006419310986976609
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010970115661621094
# Sample mean is:  0.011303424835205078 Sample variance is: 0.00033138144317490514
#
#
# Iteration: 4
# Less than two values for quick_sort
# quick_sort Theta 0.6830675518057034
# Less than two values for merge_sort
# merge_sort Theta 0.7911173170462036
# heap_sort Theta 0.011207939106587676
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010998964309692383
# Sample mean is:  0.011227309703826904 Sample variance is: 0.00024409501501547007
#
#
# Iteration: 5
# Less than two values for quick_sort
# quick_sort Theta 0.4537723685268744
# Less than two values for merge_sort
# merge_sort Theta 0.7650353292283348
# heap_sort Theta 0.011236963671501718
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010003089904785156
# Sample mean is:  0.010982465744018555 Sample variance is: 0.0004828140845347661
#
#
# Iteration: 6
# Less than two values for quick_sort
# quick_sort Theta 0.5849306701812588
# Less than two values for merge_sort
# merge_sort Theta 0.7887756568683357
# heap_sort Theta 0.0110323718259115
#
#
# Chosen algorithm is:  heap_sort with reward: 0.013003826141357422
# Sample mean is:  0.011319359143575033 Sample variance is: 0.0010672342436161368
#
#
# Iteration: 7
# Less than two values for quick_sort
# quick_sort Theta 0.8500006740831172
# Less than two values for merge_sort
# merge_sort Theta 0.10891380238862791
# heap_sort Theta 0.011264383079525831
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012626409530639648
# Sample mean is:  0.011506080627441406 Sample variance is: 0.0011334162574409372
#
#
# Iteration: 8
# Less than two values for quick_sort
# quick_sort Theta 0.4721353479857502
# Less than two values for merge_sort
# merge_sort Theta 0.3381983266628793
# heap_sort Theta 0.011672183560603473
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011967658996582031
# Sample mean is:  0.011563777923583984 Sample variance is: 0.0009981314730924038
#
#
# Iteration: 9
# Less than two values for quick_sort
# quick_sort Theta 0.6118134274595151
# Less than two values for merge_sort
# merge_sort Theta 0.14811998350647815
# heap_sort Theta 0.0113751767611
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010005950927734375
# Sample mean is:  0.01139068603515625 Sample variance is: 0.0011430122555111666
#
#
# Iteration: 10
# Less than two values for quick_sort
# quick_sort Theta 0.12805595888138177
# Less than two values for merge_sort
# merge_sort Theta 0.3153608663902062
# heap_sort Theta 0.01123036944730017
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011971712112426758
# Sample mean is:  0.0114487886428833 Sample variance is: 0.0010497700240345391
#
#
# Iteration: 11
# Less than two values for quick_sort
# quick_sort Theta 0.15652440076182472
# Less than two values for merge_sort
# merge_sort Theta 0.06770298351270054
# heap_sort Theta 0.011378338871647492
#
#
# Chosen algorithm is:  heap_sort with reward: 0.00997614860534668
# Sample mean is:  0.011314912275834517 Sample variance is: 0.0011419447198270725
#
#
# Iteration: 12
# Less than two values for quick_sort
# quick_sort Theta 0.24883610654255062
# Less than two values for merge_sort
# merge_sort Theta 0.9225363813141898
# heap_sort Theta 0.011203900338153619
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01097416877746582
# Sample mean is:  0.011286516984303793 Sample variance is: 0.0010478070744525348
#
#
# Iteration: 13
# Less than two values for quick_sort
# quick_sort Theta 0.9193504889962251
# Less than two values for merge_sort
# merge_sort Theta 0.25589805213766237
# heap_sort Theta 0.011284279259700998
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012969732284545898
# Sample mean is:  0.011415995084322415 Sample variance is: 0.0011784293372457818
#
#
# Iteration: 14
# Less than two values for quick_sort
# quick_sort Theta 0.33528909206508095
# Less than two values for merge_sort
# merge_sort Theta 0.23336380549942126
# heap_sort Theta 0.011346808680887294
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012985706329345703
# Sample mean is:  0.011528117316109794 Sample variance is: 0.0012637804547421686
#
#
# Iteration: 15
# Less than two values for quick_sort
# quick_sort Theta 0.8543179828370394
# Less than two values for merge_sort
# merge_sort Theta 0.2977628787368778
# heap_sort Theta 0.011426952028907629
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010998964309692383
# Sample mean is:  0.0114928404490153 Sample variance is: 0.001192177282540624
#
#
# Iteration: 16
# Less than two values for quick_sort
# quick_sort Theta 0.4110386497280658
# Less than two values for merge_sort
# merge_sort Theta 0.3994550945990428
# heap_sort Theta 0.011490246907530912
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01099705696105957
# Sample mean is:  0.011461853981018066 Sample variance is: 0.0011280613762210123
#
#
# Iteration: 17
# Less than two values for quick_sort
# quick_sort Theta 0.8870115105646253
# Less than two values for merge_sort
# merge_sort Theta 0.9548744510657473
# heap_sort Theta 0.011423215060991513
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011969566345214844
# Sample mean is:  0.011491719414206111 Sample variance is: 0.0010727205898988627
#
#
# Iteration: 18
# Less than two values for quick_sort
# quick_sort Theta 0.5889616505386117
# Less than two values for merge_sort
# merge_sort Theta 0.6997222315005244
# heap_sort Theta 0.01138299157431803
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011001110076904297
# Sample mean is:  0.011464463339911567 Sample variance is: 0.0010229914632754371
#
#
# Iteration: 19
# Less than two values for quick_sort
# quick_sort Theta 0.3229654963419658
# Less than two values for merge_sort
# merge_sort Theta 0.0786041829475258
# heap_sort Theta 0.011402852212572177
#
#
# Chosen algorithm is:  heap_sort with reward: 0.013965368270874023
# Sample mean is:  0.01159608991522538 Sample variance is: 0.001295344155452597
#
#
# Iteration: 20
# Less than two values for quick_sort
# quick_sort Theta 0.4405229390010086
# Less than two values for merge_sort
# merge_sort Theta 0.6950328320815372
# heap_sort Theta 0.011724794807652055
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011969566345214844
# Sample mean is:  0.011614763736724853 Sample variance is: 0.0012341423794587651
#
#
# Iteration: 21
# Less than two values for quick_sort
# quick_sort Theta 0.5403596316575032
# Less than two values for merge_sort
# merge_sort Theta 0.6237404127503734
# heap_sort Theta 0.01163657236672446
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010999679565429688
# Sample mean is:  0.011585474014282227 Sample variance is: 0.0011904509051419154
#
#
# Iteration: 22
# Less than two values for quick_sort
# quick_sort Theta 0.6050004882672301
# Less than two values for merge_sort
# merge_sort Theta 0.3211944931136187
# heap_sort Theta 0.01153571644804459
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011000871658325195
# Sample mean is:  0.011558901179920544 Sample variance is: 0.0011492973083741202
#
#
# Iteration: 23
# Less than two values for quick_sort
# quick_sort Theta 0.3937191889017062
# Less than two values for merge_sort
# merge_sort Theta 0.8809154878371245
# heap_sort Theta 0.011538332807455459
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010973453521728516
# Sample mean is:  0.011533446933912195 Sample variance is: 0.0011119586503464736
#
#
# Iteration: 24
# Less than two values for quick_sort
# quick_sort Theta 0.7083339505970992
# Less than two values for merge_sort
# merge_sort Theta 0.9779392679056688
# heap_sort Theta 0.01152303703627385
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011006355285644531
# Sample mean is:  0.011511484781901041 Sample variance is: 0.0010751886889736036
#
#
# Iteration: 25
# Less than two values for quick_sort
# quick_sort Theta 0.06869555622432488
# Less than two values for merge_sort
# merge_sort Theta 0.3939549800285539
# heap_sort Theta 0.011458875339743262
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011990547180175781
# Sample mean is:  0.011530647277832031 Sample variance is: 0.0010395691915239997
# Iteration: 26
# Less than two values for quick_sort
# quick_sort Theta 0.4683759676806942
# Less than two values for merge_sort
# merge_sort Theta 0.6357615251129225
# heap_sort Theta 0.01147803497319865
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011996030807495117
# Sample mean is:  0.011548546644357534 Sample variance is: 0.0010063164942354119
#
#
# Iteration: 27
# Less than two values for quick_sort
# quick_sort Theta 0.7591252352808922
# Less than two values for merge_sort
# merge_sort Theta 0.8741924206277436
# heap_sort Theta 0.011538102888608395
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010969400405883789
# Sample mean is:  0.011527096783673321 Sample variance is: 0.0009800346198189434
#
#
# Iteration: 28
# Less than two values for quick_sort
# quick_sort Theta 0.5842507216923583
# Less than two values for merge_sort
# merge_sort Theta 0.29717391389958403
# heap_sort Theta 0.011488654519785455
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010998010635375977
# Sample mean is:  0.011508200849805559 Sample variance is: 0.0009537346181757068
#
#
# Iteration: 29
# Less than two values for quick_sort
# quick_sort Theta 0.12717798397689706
# Less than two values for merge_sort
# merge_sort Theta 0.22369764822217297
# heap_sort Theta 0.01154355783676051
#
#
# Chosen algorithm is:  heap_sort with reward: 0.009975910186767578
# Sample mean is:  0.011455363240735284 Sample variance is: 0.001000635242562208
#
#
# Iteration: 30
# Less than two values for quick_sort
# quick_sort Theta 0.9793426237602085
# Less than two values for merge_sort
# merge_sort Theta 0.5983197810776967
# heap_sort Theta 0.011445810625158155
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011968374252319336
# Sample mean is:  0.011472463607788086 Sample variance is: 0.0009749032556257965
#
#
# Iteration: 31
# Less than two values for quick_sort
# quick_sort Theta 0.41862269173052336
# Less than two values for merge_sort
# merge_sort Theta 0.2752653654241357
# heap_sort Theta 0.011462493059684999
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010971307754516602
# Sample mean is:  0.011456297289940619 Sample variance is: 0.0009505083252533755
#
#
# Iteration: 32
# Less than two values for quick_sort
# quick_sort Theta 0.5327248591009508
# Less than two values for merge_sort
# merge_sort Theta 0.4829924360239497
# heap_sort Theta 0.011429351688430386
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011970996856689453
# Sample mean is:  0.01147238165140152 Sample variance is: 0.0009281253802495917
#
#
# Iteration: 33
# Less than two values for quick_sort
# quick_sort Theta 0.02202042819226724
# Less than two values for merge_sort
# merge_sort Theta 0.2859186728734394
# heap_sort Theta 0.01145976491394246
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010970354080200195
# Sample mean is:  0.01145716869469845 Sample variance is: 0.0009067587858212253
#
#
# Iteration: 34
# Less than two values for quick_sort
# quick_sort Theta 0.9847074711264813
# Less than two values for merge_sort
# merge_sort Theta 0.395106163670365
# heap_sort Theta 0.011485788587486414
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011942386627197266
# Sample mean is:  0.01147143981036018 Sample variance is: 0.0008862058480927819
#
#
# Iteration: 35
# Less than two values for quick_sort
# quick_sort Theta 0.3739838091629494
# Less than two values for merge_sort
# merge_sort Theta 0.4342521273646964
# heap_sort Theta 0.01147822723541953
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010973691940307617
# Sample mean is:  0.011457218442644392 Sample variance is: 0.0008672196256974676
#
#
# Iteration: 36
# Less than two values for quick_sort
# quick_sort Theta 0.7921652073121639
# Less than two values for merge_sort
# merge_sort Theta 0.954706091915965
# heap_sort Theta 0.011455166155958308
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972738265991211
# Sample mean is:  0.01144376065995958 Sample variance is: 0.0008489619510386083
#
#
# Iteration: 37
# Less than two values for quick_sort
# quick_sort Theta 0.8578817190535567
# Less than two values for merge_sort
# merge_sort Theta 0.919646401564709
# heap_sort Theta 0.01145492286315936
#
#
# Chosen algorithm is:  heap_sort with reward: 0.009976387023925781
# Sample mean is:  0.01140410191303975 Sample variance is: 0.0008835738742891682
#
#
# Iteration: 38
# Less than two values for quick_sort
# quick_sort Theta 0.8011496382739206
# Less than two values for merge_sort
# merge_sort Theta 0.018935948907760736
# heap_sort Theta 0.011420833895320646
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011971235275268555
# Sample mean is:  0.011419026475203665 Sample variance is: 0.0008681577164281942
#
#
# Iteration: 39
# Less than two values for quick_sort
# quick_sort Theta 0.8963283989010982
# Less than two values for merge_sort
# merge_sort Theta 0.2573778601033849
# heap_sort Theta 0.011415060264558227
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01296687126159668
# Sample mean is:  0.011458714803059896 Sample variance is: 0.0009067428320856399
#
#
# Iteration: 40
# Less than two values for quick_sort
# quick_sort Theta 0.5891962637823188
# Less than two values for merge_sort
# merge_sort Theta 0.022115114230693456
# heap_sort Theta 0.011456980497782715
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011962175369262695
# Sample mean is:  0.011471301317214966 Sample variance is: 0.0008898298294213466
#
#
# Iteration: 41
# Less than two values for quick_sort
# quick_sort Theta 0.6333667541019473
# Less than two values for merge_sort
# merge_sort Theta 0.5074289127921812
# heap_sort Theta 0.011441327394658413
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011932134628295898
# Sample mean is:  0.011482541154070599 Sample variance is: 0.0008727637749200035
#
#
# Iteration: 42
# Less than two values for quick_sort
# quick_sort Theta 0.20750111307718555
# Less than two values for merge_sort
# merge_sort Theta 0.759440497290646
# heap_sort Theta 0.011460064127511929
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011967658996582031
# Sample mean is:  0.011494091578892298 Sample variance is: 0.0008570801707500852
#
#
# Iteration: 43
# Less than two values for quick_sort
# quick_sort Theta 0.9743349316617436
# Less than two values for merge_sort
# merge_sort Theta 0.5062315398798102
# heap_sort Theta 0.011497846210742606
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01000666618347168
# Sample mean is:  0.011459500290626702 Sample variance is: 0.0008881254606445026
#
#
# Iteration: 44
# Less than two values for quick_sort
# quick_sort Theta 0.4695133610703285
# Less than two values for merge_sort
# merge_sort Theta 0.5026250025231155
# heap_sort Theta 0.011476804672578458
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972023010253906
# Sample mean is:  0.011448421261527321 Sample variance is: 0.0008728721551389356
#
#
# Iteration: 45
# Less than two values for quick_sort
# quick_sort Theta 0.10840160871349036
# Less than two values for merge_sort
# merge_sort Theta 0.3650304102862285
# heap_sort Theta 0.011474029790105759
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011972665786743164
# Sample mean is:  0.011460071139865451 Sample variance is: 0.0008591415365512461
#
#
# Iteration: 46
# Less than two values for quick_sort
# quick_sort Theta 0.1286495661958078
# Less than two values for merge_sort
# merge_sort Theta 0.7424051112023756
# heap_sort Theta 0.011458619395483892
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012998104095458984
# Sample mean is:  0.011493506638900093 Sample variance is: 0.0008914744018076578
#
#
# Iteration: 47
# Less than two values for quick_sort
# quick_sort Theta 0.2575386084884299
# Less than two values for merge_sort
# merge_sort Theta 0.5608287225599156
# heap_sort Theta 0.011480093920269377
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01099705696105957
# Sample mean is:  0.011482943879797104 Sample variance is: 0.0008773384018612781
#
#
# Iteration: 48
# Less than two values for quick_sort
# quick_sort Theta 0.4949849279253723
# Less than two values for merge_sort
# merge_sort Theta 0.5029526206483466
# heap_sort Theta 0.011482047769929862
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01099848747253418
# Sample mean is:  0.011472851037979126 Sample variance is: 0.0008635611692398015
#
#
# Iteration: 49
# Less than two values for quick_sort
# quick_sort Theta 0.5563444513004479
# Less than two values for merge_sort
# merge_sort Theta 0.33988369804743424
# heap_sort Theta 0.01147545477223105
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010970592498779297
# Sample mean is:  0.011462600863709742 Sample variance is: 0.0008507185491023903
#
#
# Iteration: 50
# Less than two values for quick_sort
# quick_sort Theta 0.9667190721798995
# Less than two values for merge_sort
# merge_sort Theta 0.7116078971707751
# heap_sort Theta 0.011462325647472855
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01194000244140625
# Sample mean is:  0.011472148895263672 Sample variance is: 0.000837915191387227
#
#
# Iteration: 51
# Less than two values for quick_sort
# quick_sort Theta 0.5672755360993781
# Less than two values for merge_sort
# merge_sort Theta 0.08842217239529593
# heap_sort Theta 0.011474295500108122
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01099848747253418
# Sample mean is:  0.011462861416386623 Sample variance is: 0.0008255560080179554
#
#
# Iteration: 52
# Less than two values for quick_sort
# quick_sort Theta 0.06717435261538363
# Less than two values for merge_sort
# merge_sort Theta 0.87462299176576
# heap_sort Theta 0.011448689615122284
# Chosen algorithm is:  heap_sort with reward: 0.011970281600952148
# Sample mean is:  0.011472619496859036 Sample variance is: 0.0008143200823060385
#
#
# Iteration: 53
# Less than two values for quick_sort
# quick_sort Theta 0.03322972815770797
# Less than two values for merge_sort
# merge_sort Theta 0.8576456095413616
# heap_sort Theta 0.011463424431507637
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011003494262695312
# Sample mean is:  0.011463768077346514 Sample variance is: 0.0008028125049747239
#
#
# Iteration: 54
# Less than two values for quick_sort
# quick_sort Theta 0.8519983206461218
# Less than two values for merge_sort
# merge_sort Theta 0.7368780802386797
# heap_sort Theta 0.011442886123989573
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011968374252319336
# Sample mean is:  0.011473112636142306 Sample variance is: 0.0007923804212912371
#
#
# Iteration: 55
# Less than two values for quick_sort
# quick_sort Theta 0.7625459122461424
# Less than two values for merge_sort
# merge_sort Theta 0.058122774372497577
# heap_sort Theta 0.011466413782671603
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010999441146850586
# Sample mean is:  0.011464500427246093 Sample variance is: 0.0007817860675998046
#
#
# Iteration: 56
# Less than two values for quick_sort
# quick_sort Theta 0.6256481415220467
# Less than two values for merge_sort
# merge_sort Theta 0.33782291598077585
# heap_sort Theta 0.011488735386172119
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010973691940307617
# Sample mean is:  0.011455735989979334 Sample variance is: 0.0007718734356553914
#
#
# Iteration: 57
# Less than two values for quick_sort
# quick_sort Theta 0.69115047230522
# Less than two values for merge_sort
# merge_sort Theta 0.1982990090298603
# heap_sort Theta 0.011458643221847122
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972976684570312
# Sample mean is:  0.011447266528480932 Sample variance is: 0.0007621786927974172
#
#
# Iteration: 58
# Less than two values for quick_sort
# quick_sort Theta 0.6755998313814202
# Less than two values for merge_sort
# merge_sort Theta 0.07426565581201483
# heap_sort Theta 0.01144014275801451
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011964797973632812
# Sample mean is:  0.011456189484431827 Sample variance is: 0.0007534250470717204
#
#
# Iteration: 59
# Less than two values for quick_sort
# quick_sort Theta 0.08055364859925906
# Less than two values for merge_sort
# merge_sort Theta 0.5330990506817161
# heap_sort Theta 0.011446664822153398
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012936115264892578
# Sample mean is:  0.011481272972236245 Sample variance is: 0.0007775566603188761
#
#
# Iteration: 60
# Less than two values for quick_sort
# quick_sort Theta 0.5555241395418674
# Less than two values for merge_sort
# merge_sort Theta 0.3203157296791881
# heap_sort Theta 0.011490897277752633
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011970043182373047
# Sample mean is:  0.011489419142405193 Sample variance is: 0.0007683593391780794
#
#
# Iteration: 61
# Less than two values for quick_sort
# quick_sort Theta 0.7843845378092846
# Less than two values for merge_sort
# merge_sort Theta 0.9030061490954646
# heap_sort Theta 0.011482997529325625
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011967658996582031
# Sample mean is:  0.011497259140014648 Sample variance is: 0.0007593027495052714
#
#
# Iteration: 62
# Less than two values for quick_sort
# quick_sort Theta 0.05940473430627424
# Less than two values for merge_sort
# merge_sort Theta 0.4153748349257921
# heap_sort Theta 0.011511096585462913
#
#
# Chosen algorithm is:  heap_sort with reward: 0.00997304916381836
# Sample mean is:  0.011472675108140516 Sample variance is: 0.0007843263900854899
#
#
# Iteration: 63
# Less than two values for quick_sort
# quick_sort Theta 0.9061062024438792
# Less than two values for merge_sort
# merge_sort Theta 0.5461137481797403
# heap_sort Theta 0.011489730689782686
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010997772216796875
# Sample mean is:  0.011465136967008077 Sample variance is: 0.0007752558494581016
#
#
# Iteration: 64
# Less than two values for quick_sort
# quick_sort Theta 0.40001826477920654
# Less than two values for merge_sort
# merge_sort Theta 0.6128837633439151
# heap_sort Theta 0.011455785754021555
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011969566345214844
# Sample mean is:  0.011473018676042557 Sample variance is: 0.0007669259666414744
#
#
# Iteration: 65
# Less than two values for quick_sort
# quick_sort Theta 0.42991497243794263
# Less than two values for merge_sort
# merge_sort Theta 0.4530931398141026
# heap_sort Theta 0.011467536503020024
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010998725891113281
# Sample mean is:  0.011465721863966721 Sample variance is: 0.0007584035737332545
#
#
# Iteration: 66
# Less than two values for quick_sort
# quick_sort Theta 0.47602653233621606
# Less than two values for merge_sort
# merge_sort Theta 0.32656026284931483
# heap_sort Theta 0.011487201501261235
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012937545776367188
# Sample mean is:  0.01148802222627582 Sample variance is: 0.0007795580329467754
#
#
# Iteration: 67
# Less than two values for quick_sort
# quick_sort Theta 0.990489104245805
# Less than two values for merge_sort
# merge_sort Theta 0.09059110886652977
# heap_sort Theta 0.01147877184120431
#
#
# Chosen algorithm is:  heap_sort with reward: 0.013961076736450195
# Sample mean is:  0.011524933487621706 Sample variance is: 0.0008590301089467657
#
#
# Iteration: 68
# Less than two values for quick_sort
# quick_sort Theta 0.768366331814258
# Less than two values for merge_sort
# merge_sort Theta 0.33237876570255387
# heap_sort Theta 0.011537459406142639
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972023010253906
# Sample mean is:  0.011516802451189826 Sample variance is: 0.0008507044992721581
#
#
# Iteration: 69
# Less than two values for quick_sort
# quick_sort Theta 0.8105639742089572
# Less than two values for merge_sort
# merge_sort Theta 0.6746528029200718
# heap_sort Theta 0.011524690150024981
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011968135833740234
# Sample mean is:  0.01152334351470505 Sample variance is: 0.0008411463393105466
#
#
# Iteration: 70
# Less than two values for quick_sort
# quick_sort Theta 0.21031711488552585
# Less than two values for merge_sort
# merge_sort Theta 0.9189256349250494
# heap_sort Theta 0.011518454831514069
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011966705322265625
# Sample mean is:  0.011529677254813058 Sample variance is: 0.0008317639511167774
#
#
# Iteration: 71
# Less than two values for quick_sort
# quick_sort Theta 0.07539009045819856
# Less than two values for merge_sort
# merge_sort Theta 0.915119191446301
# heap_sort Theta 0.011512136298132483
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972738265991211
# Sample mean is:  0.01152183304370289 Sample variance is: 0.0008242503559617681
#
#
# Iteration: 72
# Less than two values for quick_sort
# quick_sort Theta 0.6266921952740119
# Less than two values for merge_sort
# merge_sort Theta 0.6683259219460783
# heap_sort Theta 0.011503572178335046
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01293802261352539
# Sample mean is:  0.01154150234328376 Sample variance is: 0.000840496652930784
#
#
# Iteration: 73
# Less than two values for quick_sort
# quick_sort Theta 0.945002138154326
# Less than two values for merge_sort
# merge_sort Theta 0.41788660952921963
# heap_sort Theta 0.011553462248373038
#
#
# Chosen algorithm is:  heap_sort with reward: 0.00997614860534668
# Sample mean is:  0.01152005914139421 Sample variance is: 0.0008623892845378901
#
#
# Iteration: 74
# Less than two values for quick_sort
# quick_sort Theta 0.2800467406414767
# Less than two values for merge_sort
# merge_sort Theta 0.8380167857385393
# heap_sort Theta 0.011522165769112466
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011968374252319336
# Sample mean is:  0.011526117453704009 Sample variance is: 0.000853291765650092
#
#
# Iteration: 75
# Less than two values for quick_sort
# quick_sort Theta 0.48541788649093776
# Less than two values for merge_sort
# merge_sort Theta 0.4040279949935077
# heap_sort Theta 0.011527884807584543
#
#
# Chosen algorithm is:  heap_sort with reward: 0.012004613876342773
# Sample mean is:  0.01153249740600586 Sample variance is: 0.0008448135801970507
#
#
# Iteration: 76
# Less than two values for quick_sort
# quick_sort Theta 0.28853746505669176
# Less than two values for merge_sort
# merge_sort Theta 0.09052663520824278
# heap_sort Theta 0.011515278358632513
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010965585708618164
# Sample mean is:  0.011525038041566548 Sample variance is: 0.0008377782000834802
#
#
# Iteration: 77
# Less than two values for quick_sort
# quick_sort Theta 0.4670024696599482
# Less than two values for merge_sort
# merge_sort Theta 0.8955653176228736
# heap_sort Theta 0.011525762503981254
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010972023010253906
# Sample mean is:  0.011517856028172877 Sample variance is: 0.0008307265640757494
#
#
# Iteration: 78
# Less than two values for quick_sort
# quick_sort Theta 0.02728795260477268
# Less than two values for merge_sort
# merge_sort Theta 0.6962786971683033
# heap_sort Theta 0.011529594313216752
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010998010635375977
# Sample mean is:  0.01151119134364984 Sample variance is: 0.0008234025129431869
# Iteration: 79
# Less than two values for quick_sort
# quick_sort Theta 0.026922857290873292
# Less than two values for merge_sort
# merge_sort Theta 0.2195131015786087
# heap_sort Theta 0.011522308361033632
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01296544075012207
# Sample mean is:  0.011529599563984931 Sample variance is: 0.0008396162139660734
#
#
# Iteration: 80
# Less than two values for quick_sort
# quick_sort Theta 0.6178250463921489
# Less than two values for merge_sort
# merge_sort Theta 0.9221450253457613
# heap_sort Theta 0.011529094643648003
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010977983474731445
# Sample mean is:  0.011522704362869262 Sample variance is: 0.0008327916644987714
#
#
# Iteration: 81
# Less than two values for quick_sort
# quick_sort Theta 0.6489778789042258
# Less than two values for merge_sort
# merge_sort Theta 0.8307968049953792
# heap_sort Theta 0.011512503858648014
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01099705696105957
# Sample mean is:  0.011516214888772847 Sample variance is: 0.000825792943890429
#
#
# Iteration: 82
# Less than two values for quick_sort
# quick_sort Theta 0.09791296298249563
# Less than two values for merge_sort
# merge_sort Theta 0.5197684705929697
# heap_sort Theta 0.011506058237962176
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01096963882446289
# Sample mean is:  0.01150954932701297 Sample variance is: 0.0008192412057876269
#
#
# Iteration: 83
# Less than two values for quick_sort
# quick_sort Theta 0.7968049451803949
# Less than two values for merge_sort
# merge_sort Theta 0.6558398033096232
# heap_sort Theta 0.011511307404425188
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010999441146850586
# Sample mean is:  0.011503403445324266 Sample variance is: 0.000812385523899301
#
#
# Iteration: 84
# Less than two values for quick_sort
# quick_sort Theta 0.5233029770133949
# Less than two values for merge_sort
# merge_sort Theta 0.6385325883658685
# heap_sort Theta 0.011507510188482815
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011966228485107422
# Sample mean is:  0.011508913267226447 Sample variance is: 0.0008051478300439981
#
#
# Iteration: 85
# Less than two values for quick_sort
# quick_sort Theta 0.08968390033111306
# Less than two values for merge_sort
# merge_sort Theta 0.530768029258386
# heap_sort Theta 0.0115114411957618
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011004209518432617
# Sample mean is:  0.011502975576064165 Sample variance is: 0.0007985595118179716
#
#
# Iteration: 86
# Less than two values for quick_sort
# quick_sort Theta 0.09093966777372853
# Less than two values for merge_sort
# merge_sort Theta 0.9275092483820688
# heap_sort Theta 0.011493865888173258
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010970830917358398
# Sample mean is:  0.011496787847474564 Sample variance is: 0.0007924574607503554
#
#
# Iteration: 87
# Less than two values for quick_sort
# quick_sort Theta 0.26795284404527364
# Less than two values for merge_sort
# merge_sort Theta 0.9147885821460073
# heap_sort Theta 0.011498740014703955
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010971784591674805
# Sample mean is:  0.011490753327292958 Sample variance is: 0.000786410981856256
#
#
# Iteration: 88
# Less than two values for quick_sort
# quick_sort Theta 0.8208188731065565
# Less than two values for merge_sort
# merge_sort Theta 0.5324911077879926
# heap_sort Theta 0.01150024354895625
#
#
# Chosen algorithm is:  heap_sort with reward: 0.011996030807495117
# Sample mean is:  0.01149649511684071 Sample variance is: 0.0007802729721227924
#
#
# Iteration: 89
# Less than two values for quick_sort
# quick_sort Theta 0.6007138300189976
# Less than two values for merge_sort
# merge_sort Theta 0.45983810049907814
# heap_sort Theta 0.011498573169540647
#
#
# Chosen algorithm is:  heap_sort with reward: 0.01099848747253418
# Sample mean is:  0.011490899525331647 Sample variance is: 0.0007741928811491449
#
#
# Iteration: 90
# Less than two values for quick_sort
# quick_sort Theta 0.006872213329613186
# Less than two values for merge_sort
# merge_sort Theta 0.6616966380891486
# heap_sort Theta 0.011489827509856955
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004340171813964844
# Sample mean is:  0.0056618452072143555 Sample variance is: 0.003493641116847357
#
#
# Iteration: 91
# quick_sort Theta 0.01280934614976904
# Less than two values for merge_sort
# merge_sort Theta 0.19666600515546273
# heap_sort Theta 0.011494469586702992
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010998725891113281
# Sample mean is:  0.011485430929395888 Sample variance is: 0.0007681855834675137
#
#
# Iteration: 92
# quick_sort Theta 0.03020346901693547
# Less than two values for merge_sort
# merge_sort Theta 0.3710206252007163
# heap_sort Theta 0.011487448033736887
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010970115661621094
# Sample mean is:  0.011479768124255505 Sample variance is: 0.0007625683180429249
#
#
# Iteration: 93
# quick_sort Theta 0.00438540522865309
# Less than two values for merge_sort
# merge_sort Theta 0.24994014514686058
# heap_sort Theta 0.011476651329573179
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00501561164855957
# Sample mean is:  0.005446434020996094 Sample variance is: 0.0018860264958675543
#
#
# Iteration: 94
# quick_sort Theta 0.00633586940759494
# Less than two values for merge_sort
# merge_sort Theta 0.8339290271742607
# heap_sort Theta 0.011486232044464017
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005011796951293945
# Sample mean is:  0.005337774753570557 Sample variance is: 0.0013045783428348539
#
#
# Iteration: 95
# quick_sort Theta 0.005385215085371439
# Less than two values for merge_sort
# merge_sort Theta 0.9110641257966401
# heap_sort Theta 0.01148485362407419
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004018545150756836
# Sample mean is:  0.005073928833007812 Sample variance is: 0.0013265071061141496
#
#
# Iteration: 96
# quick_sort Theta 0.004949771221592429
# Less than two values for merge_sort
# merge_sort Theta 0.17858579899251925
# heap_sort Theta 0.011485099591623235
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049893856048583984
# Sample mean is:  0.00505983829498291 Sample variance is: 0.0010623969444623071
#
#
# Iteration: 97
# quick_sort Theta 0.00471875736636969
# Less than two values for merge_sort
# merge_sort Theta 0.11907517959410574
# heap_sort Theta 0.01149925869435462
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006953716278076172
# Sample mean is:  0.005330392292567662 Sample variance is: 0.0013977270463155515
#
#
# Iteration: 98
# quick_sort Theta 0.00527377424205217
# Less than two values for merge_sort
# merge_sort Theta 0.33160913492718347
# heap_sort Theta 0.011495189471477959
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004992008209228516
# Sample mean is:  0.0052880942821502686 Sample variance is: 0.0012123647274669175
#
#
# Iteration: 99
# quick_sort Theta 0.005120506144089716
# Less than two values for merge_sort
# merge_sort Theta 0.7832068442246521
# heap_sort Theta 0.011473787434109714
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004985332489013672
# Sample mean is:  0.005254454082912869 Sample variance is: 0.0010710041035761403
#
#
# Iteration: 100
# quick_sort Theta 0.005164948865267905
# Less than two values for merge_sort
# merge_sort Theta 0.7387247259911389
# heap_sort Theta 0.01147882797387486
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004986763000488281
# Sample mean is:  0.00522768497467041 Sample variance is: 0.0009591694991842007
#
#
# Iteration: 101
# quick_sort Theta 0.005178768691857772
# Less than two values for merge_sort
# merge_sort Theta 0.9680125352303679
# heap_sort Theta 0.01149161934361504
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049839019775390625
# Sample mean is:  0.005205522884022106 Sample variance is: 0.0008686552901467209
#
#
# Iteration: 102
# quick_sort Theta 0.005252352092389196
# Less than two values for merge_sort
# merge_sort Theta 0.417974866114336
# heap_sort Theta 0.011483456802389914
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005014657974243164
# Sample mean is:  0.00518961747487386 Sample variance is: 0.0007927224118881867
#
#
# Iteration: 103
# quick_sort Theta 0.005221090849193707
# Less than two values for merge_sort
# merge_sort Theta 0.33035456383065176
# heap_sort Theta 0.011478557363990312
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004988670349121094
# Sample mean is:  0.005174160003662109 Sample variance is: 0.0007297683453089121
#
#
# Iteration: 104
# quick_sort Theta 0.0050034402071964384
# Less than two values for merge_sort
# merge_sort Theta 0.8013160574975523
# heap_sort Theta 0.011478758365536941
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005017995834350586
# Sample mean is:  0.005163005420139858 Sample variance is: 0.0006753742650164563
#
#
# Iteration: 105
# quick_sort Theta 0.005290404529352186
# Less than two values for merge_sort
# merge_sort Theta 0.015210994842359105
# heap_sort Theta 0.011477532447028756
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049550533294677734
# Sample mean is:  0.005149141947428385 Sample variance is: 0.0006300161842210357
#
#
# Iteration: 106
# quick_sort Theta 0.005110660960376964
# Less than two values for merge_sort
# merge_sort Theta 0.8732325647990432
# heap_sort Theta 0.011483651955750185
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049839019775390625
# Sample mean is:  0.005138814449310303 Sample variance is: 0.0005897216207510306
#
#
# Iteration: 107
# quick_sort Theta 0.005103255029702757
# Less than two values for merge_sort
# merge_sort Theta 0.95236059946645
# heap_sort Theta 0.011489646735578745
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004988193511962891
# Sample mean is:  0.00512995439417222 Sample variance is: 0.0005541985292639392
# Iteration: 108
# quick_sort Theta 0.005162376746424302
# Less than two values for merge_sort
# merge_sort Theta 0.35031805914973413
# heap_sort Theta 0.011478743543640259
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006014823913574219
# Sample mean is:  0.005179113811916775 Sample variance is: 0.0005650982861315321
#
#
# Iteration: 109
# quick_sort Theta 0.005153495367346164
# Less than two values for merge_sort
# merge_sort Theta 0.9147052579407775
# heap_sort Theta 0.011489287860081503
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0050122737884521484
# Sample mean is:  0.005170332758050216 Sample variance is: 0.0005351689681351433
#
#
# Iteration: 110
# quick_sort Theta 0.005231513685195281
# Less than two values for merge_sort
# merge_sort Theta 0.17199448917467042
# heap_sort Theta 0.011495714656640432
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005952358245849609
# Sample mean is:  0.005209434032440186 Sample variance is: 0.000537580373516951
#
#
# Iteration: 111
# quick_sort Theta 0.005173215211177404
# Less than two values for merge_sort
# merge_sort Theta 0.9296318439023968
# heap_sort Theta 0.011461249060221161
#
#
# Chosen algorithm is:  quick_sort with reward: 0.006020069122314453
# Sample mean is:  0.005248035703386579 Sample variance is: 0.0005419932238380299
#
#
# Iteration: 112
# quick_sort Theta 0.005309124020321854
# Less than two values for merge_sort
# merge_sort Theta 0.3404574448302806
# heap_sort Theta 0.011481644079068713
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004987478256225586
# Sample mean is:  0.00523619218306108 Sample variance is: 0.0005192699401242974
#
#
# Iteration: 113
# quick_sort Theta 0.005206815529436136
# Less than two values for merge_sort
# merge_sort Theta 0.4968136983510705
# heap_sort Theta 0.011472006886433527
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004985809326171875
# Sample mean is:  0.005225305971891984 Sample variance is: 0.0004983924816809558
#
#
# Iteration: 114
# quick_sort Theta 0.005218966982706486
# Less than two values for merge_sort
# merge_sort Theta 0.12462420231270999
# heap_sort Theta 0.011478396167164069
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049893856048583984
# Sample mean is:  0.005215475956598918 Sample variance is: 0.00047904234416288694
#
#
# Iteration: 115
# quick_sort Theta 0.005231391295026756
# Less than two values for merge_sort
# merge_sort Theta 0.08085606213645724
# heap_sort Theta 0.011487447907255434
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004992246627807617
# Sample mean is:  0.005206546783447266 Sample variance is: 0.00046107549981873786
#
#
# Iteration: 116
# quick_sort Theta 0.005241368201208706
# Less than two values for merge_sort
# merge_sort Theta 0.2975536948956029
# heap_sort Theta 0.011469006065726551
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049896240234375
# Sample mean is:  0.005198203600369967 Sample variance is: 0.00044444230612638273
#
#
# Iteration: 117
# quick_sort Theta 0.00518540766409886
# Less than two values for merge_sort
# merge_sort Theta 0.21313793645853918
# heap_sort Theta 0.011485845336980193
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005981922149658203
# Sample mean is:  0.005227230213306568 Sample variance is: 0.0004500970662567925
#
#
# Iteration: 118
# quick_sort Theta 0.0052334965296241655
# Less than two values for merge_sort
# merge_sort Theta 0.09210787675524224
# heap_sort Theta 0.01148403428382879
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004987955093383789
# Sample mean is:  0.005218684673309326 Sample variance is: 0.0004354715396512229
#
#
# Iteration: 119
# quick_sort Theta 0.005202512016623138
# Less than two values for merge_sort
# merge_sort Theta 0.5553829640997784
# heap_sort Theta 0.011488978741375422
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049877166748046875
# Sample mean is:  0.005210720259567787 Sample variance is: 0.0004217585093648253
#
#
# Iteration: 120
# quick_sort Theta 0.005210286219317991
# Less than two values for merge_sort
# merge_sort Theta 0.742556326156161
# heap_sort Theta 0.011475382582638055
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004985809326171875
# Sample mean is:  0.00520322322845459 Sample variance is: 0.0004089012767555436
#
#
# Iteration: 121
# quick_sort Theta 0.00518078576327967
# Less than two values for merge_sort
# merge_sort Theta 0.45786022971772045
# heap_sort Theta 0.011476479305613452
#
#
# Chosen algorithm is:  quick_sort with reward: 0.003991365432739258
# Sample mean is:  0.00516413104149603 Sample variance is: 0.00044264540571431645
#
#
# Iteration: 122
# quick_sort Theta 0.005164668935014613
# Less than two values for merge_sort
# merge_sort Theta 0.5522796906882036
# heap_sort Theta 0.011474419195488965
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005022287368774414
# Sample mean is:  0.00515969842672348 Sample variance is: 0.0004289952600181147
#
#
# Iteration: 123
# quick_sort Theta 0.005206416992466374
# Less than two values for merge_sort
# merge_sort Theta 0.03857890876599768
# heap_sort Theta 0.01147586494172438
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004986763000488281
# Sample mean is:  0.0051544579592618074 Sample variance is: 0.00041649542061670457
#
#
# Iteration: 124
# quick_sort Theta 0.005161898966352863
# Less than two values for merge_sort
# merge_sort Theta 0.9853156054997944
# heap_sort Theta 0.011487952231459226
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005982875823974609
# Sample mean is:  0.00517882319057689 Sample variance is: 0.0004240589401639574
#
#
# Iteration: 125
# quick_sort Theta 0.005166674319897915
# Less than two values for merge_sort
# merge_sort Theta 0.9957564514348632
# heap_sort Theta 0.01148875869393661
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0059969425201416016
# Sample mean is:  0.005202198028564453 Sample variance is: 0.00043071002517749795
#
#
# Iteration: 126
# quick_sort Theta 0.00520008053291844
# Less than two values for merge_sort
# merge_sort Theta 0.8186159017849205
# heap_sort Theta 0.011479939207040747
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005985260009765625
# Sample mean is:  0.005223949750264485 Sample variance is: 0.0004354369707471048
#
#
# Iteration: 127
# quick_sort Theta 0.005247026398319753
# Less than two values for merge_sort
# merge_sort Theta 0.8012446300256904
# heap_sort Theta 0.01146427173066467
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00501704216003418
# Sample mean is:  0.005218357653231235 Sample variance is: 0.0004244985466589475
#
#
# Iteration: 128
# quick_sort Theta 0.005201496883708088
# Less than two values for merge_sort
# merge_sort Theta 0.6374904583099625
# heap_sort Theta 0.011474932432679727
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049855709075927734
# Sample mean is:  0.005212231686240749 Sample variance is: 0.00041445165688506607
#
#
# Iteration: 129
# quick_sort Theta 0.0052225983231131935
# Less than two values for merge_sort
# merge_sort Theta 0.558247196068743
# heap_sort Theta 0.011495808917021419
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004987478256225586
# Sample mean is:  0.005206468777778821 Sample variance is: 0.0004048402677791406
#
#
# Iteration: 130
# quick_sort Theta 0.005204261956130174
# Less than two values for merge_sort
# merge_sort Theta 0.695467231320667
# heap_sort Theta 0.01148229925778677
#
#
# Chosen algorithm is:  quick_sort with reward: 0.00598454475402832
# Sample mean is:  0.005225920677185058 Sample variance is: 0.0004095948037129113
#
#
# Iteration: 131
# quick_sort Theta 0.005231065612765221
# Less than two values for merge_sort
# merge_sort Theta 0.0011190545255482798
# heap_sort Theta 0.011496975288384701
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003020763397216797
# Sample mean is:  0.003020763397216797 Sample variance is: 0.0
#
#
# Iteration: 132
# quick_sort Theta 0.005220127876216905
# Less than two values for merge_sort
# merge_sort Theta 0.9655659439439509
# heap_sort Theta 0.011479298068184214
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005957841873168945
# Sample mean is:  0.00524377241367247 Sample variance is: 0.0004124209979403442
#
#
# Iteration: 133
# quick_sort Theta 0.005235069348250629
# Less than two values for merge_sort
# merge_sort Theta 0.9805481349699694
# heap_sort Theta 0.01148327797149392
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0050165653228759766
# Sample mean is:  0.005238362721034459 Sample variance is: 0.00040359106973647784
#
#
# Iteration: 134
# quick_sort Theta 0.005231201197053914
# Less than two values for merge_sort
# merge_sort Theta 0.9911018744421508
# heap_sort Theta 0.011471732934596284
#
#
# Chosen algorithm is:  quick_sort with reward: 0.005023002624511719
# Sample mean is:  0.005233354346696721 Sample variance is: 0.00039506036253307325
#
#
# Iteration: 135
# quick_sort Theta 0.005229091912498496
# Less than two values for merge_sort
# merge_sort Theta 0.8498945136410491
# heap_sort Theta 0.011464898814697738
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004022359848022461
# Sample mean is:  0.0052058317444541235 Sample variance is: 0.0004192026321465912
#
#
# Iteration: 136
# quick_sort Theta 0.005206376074833653
# Less than two values for merge_sort
# merge_sort Theta 0.2685521229192077
# heap_sort Theta 0.011476281647825609
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004016399383544922
# Sample mean is:  0.005179399914211697 Sample variance is: 0.0004411141738462057
#
#
# Iteration: 137
# quick_sort Theta 0.00517185520642926
# Less than two values for merge_sort
# merge_sort Theta 0.0444901782244983
# heap_sort Theta 0.011483846161048063
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004985332489013672
# Sample mean is:  0.005175181057142175 Sample variance is: 0.0004321303793783842
#
#
# Iteration: 138
# quick_sort Theta 0.0051762377685429925
# Less than two values for merge_sort
# merge_sort Theta 0.9550721316306002
# heap_sort Theta 0.011493287541828823
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049855709075927734
# Sample mean is:  0.0051711467986411234 Sample variance is: 0.00042350117705395034
#
#
# Iteration: 139
# quick_sort Theta 0.005159426652453724
# Less than two values for merge_sort
# merge_sort Theta 0.4224368616626346
# heap_sort Theta 0.011483110864669679
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0039861202239990234
# Sample mean is:  0.005146458745002747 Sample variance is: 0.0004437465133500435
#
#
# Iteration: 140
# quick_sort Theta 0.005155134303833462
# Less than two values for merge_sort
# merge_sort Theta 0.22784178253773135
# heap_sort Theta 0.01147907412910976
# Chosen algorithm is:  quick_sort with reward: 0.004960060119628906
# Sample mean is:  0.005142654691423688 Sample variance is: 0.00043521086467990244
#
#
# Iteration: 141
# quick_sort Theta 0.005139380316097003
# Less than two values for merge_sort
# merge_sort Theta 0.5070265744594025
# heap_sort Theta 0.011468288002485385
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049893856048583984
# Sample mean is:  0.005139589309692383 Sample variance is: 0.00042679883855661113
#
#
# Iteration: 142
# quick_sort Theta 0.005144487031780571
# Less than two values for merge_sort
# merge_sort Theta 0.7158226405670439
# heap_sort Theta 0.01147733635692875
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0049896240234375
# Sample mean is:  0.005136648813883464 Sample variance is: 0.0004187038340811947
#
#
# Iteration: 143
# quick_sort Theta 0.005115841618413386
# Less than two values for merge_sort
# merge_sort Theta 0.013255400184203903
# heap_sort Theta 0.011477793571824945
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004988670349121094
# Sample mean is:  0.005133803074176495 Sample variance is: 0.0004109150631745141
#
#
# Iteration: 144
# ...
# Sample mean is:  0.00407936351430109 Sample variance is: 0.000594535963325709
#
#
# Iteration: 1944
# quick_sort Theta 0.005139189711784054
# merge_sort Theta 0.004079155637969918
# heap_sort Theta 0.011487963485226627
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004984140396118164
# Sample mean is:  0.004079869824811341 Sample variance is: 0.0005946611744928409
#
#
# Iteration: 1945
# quick_sort Theta 0.005130371580204913
# merge_sort Theta 0.004080437607050511
# heap_sort Theta 0.011479438123184863
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.0040798189922733865 Sample variance is: 0.0005943330239270886
#
#
# Iteration: 1946
# quick_sort Theta 0.005135385584323052
# merge_sort Theta 0.004080088107173076
# heap_sort Theta 0.01147186878385856
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004988670349121094
# Sample mean is:  0.004080327014272742 Sample variance is: 0.0005944623393904168
#
#
# Iteration: 1947
# quick_sort Theta 0.005150060245271613
# merge_sort Theta 0.004080531643717034
# heap_sort Theta 0.011477991019848614
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003026247024536133
# Sample mean is:  0.0040797381427700955 Sample variance is: 0.0005947507695568201
#
#
# Iteration: 1948
# quick_sort Theta 0.005125871419166355
# merge_sort Theta 0.0040795422986903045
# heap_sort Theta 0.011474344356845556
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003960371017456055
# Sample mean is:  0.004079671494458921 Sample variance is: 0.000594426462174387
#
#
# Iteration: 1949
# quick_sort Theta 0.00511576440852128
# merge_sort Theta 0.004079684580124051
# heap_sort Theta 0.01147060773322519
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399017333984375
# Sample mean is:  0.004079621551292283 Sample variance is: 0.0005940990355901797
#
#
# Iteration: 1950
# quick_sort Theta 0.005127320083705349
# merge_sort Theta 0.0040799359333011
# heap_sort Theta 0.011481930837904171
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004989147186279297
# Sample mean is:  0.0040801288160078365 Sample variance is: 0.000594228877373017
#
#
# Iteration: 1951
# quick_sort Theta 0.005134590566068818
# merge_sort Theta 0.004080011916120094
# heap_sort Theta 0.011476588645361144
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003018617630004883
# Sample mean is:  0.00407953711523526 Sample variance is: 0.0005945255583677991
#
#
# Iteration: 1952
# quick_sort Theta 0.005125583120172598
# merge_sort Theta 0.004079829718273671
# heap_sort Theta 0.011488422388253863
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004079486799107288 Sample variance is: 0.0005941987061598449
#
#
# Iteration: 1953
# quick_sort Theta 0.005135263276636303
# merge_sort Theta 0.004079746114740673
# heap_sort Theta 0.011491737730228673
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005018949508666992
# Sample mean is:  0.004080009885248469 Sample variance is: 0.0005943590961635064
#
#
# Iteration: 1954
# quick_sort Theta 0.00512342878173835
# merge_sort Theta 0.004080134582945791
# heap_sort Theta 0.011474479027757011
# Chosen algorithm is:  merge_sort with reward: 0.004960298538208008
# Sample mean is:  0.004080499750942937 Sample variance is: 0.0005944593844670424
#
#
# Iteration: 1955
# quick_sort Theta 0.005122282853636586
# merge_sort Theta 0.004080400760530237
# heap_sort Theta 0.011492317015866426
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004019021987915039
# Sample mean is:  0.0040804655586386945 Sample variance is: 0.0005941306799755639
#
#
# Iteration: 1956
# quick_sort Theta 0.005123562438256821
# merge_sort Theta 0.004080704668544918
# heap_sort Theta 0.011482728305151194
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399470329284668
# Sample mean is:  0.0040804178864509285 Sample variance is: 0.0005938043286951329
#
#
# Iteration: 1957
# quick_sort Theta 0.005126533733325466
# merge_sort Theta 0.004080390772041464
# heap_sort Theta 0.01147564771006534
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004958152770996094
# Sample mean is:  0.004080905516942342 Sample variance is: 0.0005939022643196782
#
#
# Iteration: 1958
# quick_sort Theta 0.005129013253345325
# merge_sort Theta 0.004080662187602839
# heap_sort Theta 0.011476783122847401
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004080854608640613 Sample variance is: 0.0005935769861882678
#
#
# Iteration: 1959
# quick_sort Theta 0.00512368059923806
# merge_sort Theta 0.004080401650293322
# heap_sort Theta 0.011488335636015094
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003943681716918945
# Sample mean is:  0.004080778486059191 Sample variance is: 0.0005932578462516109
#
#
# Iteration: 1960
# quick_sort Theta 0.0051270427110812885
# merge_sort Theta 0.004081327893270308
# heap_sort Theta 0.011485952958497098
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039904117584228516
# Sample mean is:  0.004080728365855288 Sample variance is: 0.0005929331535601647
#
#
# Iteration: 1961
# quick_sort Theta 0.005130936014304257
# merge_sort Theta 0.004079890556994603
# heap_sort Theta 0.011474708098979606
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988027572631836
# Sample mean is:  0.004080676979606273 Sample variance is: 0.0005926090578973586
#
#
# Iteration: 1962
# quick_sort Theta 0.005128342145671758
# merge_sort Theta 0.004080809177618169
# heap_sort Theta 0.011479342931738546
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00498652458190918
# Sample mean is:  0.004081178834233588 Sample variance is: 0.0005927351644477379
#
#
# Iteration: 1963
# quick_sort Theta 0.005119160994916589
# merge_sort Theta 0.0040810648417795034
# heap_sort Theta 0.011478179322057771
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003957033157348633
# Sample mean is:  0.004081110093548713 Sample variance is: 0.0005924153131739356
#
#
# Iteration: 1964
# quick_sort Theta 0.005137276765195524
# merge_sort Theta 0.004080931431206876
# heap_sort Theta 0.011470713287278866
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00595545768737793
# Sample mean is:  0.004082147363938214 Sample variance is: 0.0005940314922348765
#
#
# Iteration: 1965
# quick_sort Theta 0.005129196924818132
# merge_sort Theta 0.004082386687601012
# heap_sort Theta 0.011498238729987275
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.004082096361480983 Sample variance is: 0.0005937074562300576
#
#
# Iteration: 1966
# quick_sort Theta 0.005138262094349187
# merge_sort Theta 0.004082669851463577
# heap_sort Theta 0.011479162854730978
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004984617233276367
# Sample mean is:  0.004082595267435541 Sample variance is: 0.0005938293512492785
#
#
# Iteration: 1967
# quick_sort Theta 0.0051278226533674875
# merge_sort Theta 0.004082706777943317
# heap_sort Theta 0.01146715621567395
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0040149688720703125
# Sample mean is:  0.0040825579047861675 Sample variance is: 0.0005935036140748173
#
#
# Iteration: 1968
# quick_sort Theta 0.005120499122270545
# merge_sort Theta 0.0040826844509719
# heap_sort Theta 0.011480822430166439
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003958225250244141
# Sample mean is:  0.004082489250642301 Sample variance is: 0.0005931842474775566
#
#
# Iteration: 1969
# quick_sort Theta 0.0051245122814218185
# merge_sort Theta 0.004082686943655716
# heap_sort Theta 0.011473246788583689
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004016876220703125
# Sample mean is:  0.0040824530403608785 Sample variance is: 0.0005928590782044225
#
#
# Iteration: 1970
# quick_sort Theta 0.005126074024981924
# merge_sort Theta 0.004081792460971191
# heap_sort Theta 0.011482888234924661
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005954265594482422
# Sample mean is:  0.004083485479717812 Sample variance is: 0.0005944644262323554
#
#
# Iteration: 1971
# quick_sort Theta 0.005130170706677357
# merge_sort Theta 0.00408366084692107
# heap_sort Theta 0.011476769303677243
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991365432739258
# Sample mean is:  0.004083434696891474 Sample variance is: 0.0005941412144280002
#
#
# Iteration: 1972
# quick_sort Theta 0.005137746064822129
# merge_sort Theta 0.004083356944549679
# heap_sort Theta 0.01148530294790637
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0038623809814453125
# Sample mean is:  0.0040833129042107865 Sample variance is: 0.0005938406061633697
#
#
# Iteration: 1973
# quick_sort Theta 0.005130521181751107
# merge_sort Theta 0.004083601191335131
# heap_sort Theta 0.01148060999184137
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003987789154052734
# Sample mean is:  0.004083260303026779 Sample variance is: 0.0005935184459187519
#
#
# Iteration: 1974
# quick_sort Theta 0.005131786681957135
# merge_sort Theta 0.004083201995344605
# heap_sort Theta 0.011479712100391407
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005021333694458008
# Sample mean is:  0.004083776578971431 Sample variance is: 0.0005936759233070062
#
#
# Iteration: 1975
# quick_sort Theta 0.005140862169219217
# merge_sort Theta 0.004083685435258044
# heap_sort Theta 0.011489406774439772
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.0040837245674678856 Sample variance is: 0.0005933541072192403
#
#
# Iteration: 1976
# quick_sort Theta 0.005140248536584878
# merge_sort Theta 0.004083810564289375
# heap_sort Theta 0.011489142843034272
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003992319107055664
# Sample mean is:  0.004083674317077335 Sample variance is: 0.000593032322982612
#
#
# Iteration: 1977
# quick_sort Theta 0.005137444120483085
# merge_sort Theta 0.004083692395121569
# heap_sort Theta 0.011496609823772513
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.004083622287917923 Sample variance is: 0.0005927112287152952
#
#
# Iteration: 1978
# quick_sort Theta 0.005138757435194848
# merge_sort Theta 0.0040832933777486
# heap_sort Theta 0.011483979283544778
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399017333984375
# Sample mean is:  0.00408357097053842 Sample variance is: 0.0005923903587601426
#
#
# Iteration: 1979
# quick_sort Theta 0.005129348805943242
# merge_sort Theta 0.004083561679214894
# heap_sort Theta 0.011466433722504416
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004015684127807617
# Sample mean is:  0.004083533711019907 Sample variance is: 0.0005920675777251214
#
#
# Iteration: 1980
# quick_sort Theta 0.005126273330589285
# merge_sort Theta 0.00408320155986434
# heap_sort Theta 0.011468930754133383
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004083481975394295 Sample variance is: 0.0005917475023585235
#
#
# Iteration: 1981
# quick_sort Theta 0.005127486797438154
# merge_sort Theta 0.004083308965379457
# heap_sort Theta 0.011476745321431064
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991842269897461
# Sample mean is:  0.004083431734327684 Sample variance is: 0.0005914275055012474
#
#
# Iteration: 1982
# quick_sort Theta 0.005126644818668092
# merge_sort Theta 0.004083709540981587
# heap_sort Theta 0.011482793081558315
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004012346267700195
# Sample mean is:  0.004083392783387067 Sample variance is: 0.000591106026811125
#
#
# Iteration: 1983
# quick_sort Theta 0.005120288446572617
# merge_sort Theta 0.004083328954920067
# heap_sort Theta 0.011477426285142108
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039865970611572266
# Sample mean is:  0.004083339773681574 Sample variance is: 0.0005907872642105307
#
#
# Iteration: 1984
# quick_sort Theta 0.005128984215304815
# merge_sort Theta 0.004083338897319408
# heap_sort Theta 0.011469888048542506
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0035758018493652344
# Sample mean is:  0.0040830619751460965 Sample variance is: 0.0005906047157368835
#
#
# Iteration: 1985
# quick_sort Theta 0.005132055318974092
# merge_sort Theta 0.0040833490328609145
# heap_sort Theta 0.011476829108290312
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003992557525634766
# Sample mean is:  0.004083012465053366 Sample variance is: 0.0005902859318609986
#
#
# Iteration: 1986
# quick_sort Theta 0.005136878205360095
# merge_sort Theta 0.0040833349387516815
# heap_sort Theta 0.011484255005174623
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990888595581055
# Sample mean is:  0.004082962096617351 Sample variance is: 0.0005899676584667454
# Iteration: 1987
# quick_sort Theta 0.005133845864631138
# merge_sort Theta 0.004082600222667225
# heap_sort Theta 0.011495407291484573
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004985332489013672
# Sample mean is:  0.0040834551951924305 Sample variance is: 0.000590090053058914
#
#
# Iteration: 1988
# quick_sort Theta 0.0051249701334617785
# merge_sort Theta 0.004083684390379722
# heap_sort Theta 0.011484021086561715
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039882659912109375
# Sample mean is:  0.0040834032076424685 Sample variance is: 0.0005897725481315073
#
#
# Iteration: 1989
# quick_sort Theta 0.005136054874035143
# merge_sort Theta 0.0040834001969418865
# heap_sort Theta 0.011485025089073677
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0029926300048828125
# Sample mean is:  0.004082807807422621 Sample variance is: 0.0005900998906684387
#
#
# Iteration: 1990
# quick_sort Theta 0.005133553763398853
# merge_sort Theta 0.0040829325489935946
# heap_sort Theta 0.011502405628416486
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989696502685547
# Sample mean is:  0.004082757010202361 Sample variance is: 0.0005897825135366766
#
#
# Iteration: 1991
# quick_sort Theta 0.0051294069462633285
# merge_sort Theta 0.004082374063983917
# heap_sort Theta 0.011485865439495844
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00402379035949707
# Sample mean is:  0.004082724858266317 Sample variance is: 0.0005894626513743523
#
#
# Iteration: 1992
# quick_sort Theta 0.005134460794105931
# merge_sort Theta 0.004082542587262671
# heap_sort Theta 0.011478791610658234
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.004082674291543155 Sample variance is: 0.0005891459352505523
#
#
# Iteration: 1993
# quick_sort Theta 0.005143633472333701
# merge_sort Theta 0.004082755411300393
# heap_sort Theta 0.011478157109826576
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991127014160156
# Sample mean is:  0.004082624429191639 Sample variance is: 0.0005888294395579044
#
#
# Iteration: 1994
# quick_sort Theta 0.005136675727592367
# merge_sort Theta 0.004082560737842608
# heap_sort Theta 0.01147575025025588
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990888595581055
# Sample mean is:  0.004082574491339919 Sample variance is: 0.0005885133074459846
#
#
# Iteration: 1995
# quick_sort Theta 0.005122031806961471
# merge_sort Theta 0.004082552468551397
# heap_sort Theta 0.011483766648338185
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004989147186279297
# Sample mean is:  0.004083067730020517 Sample variance is: 0.0005886400976403455
#
#
# Iteration: 1996
# quick_sort Theta 0.005126437509279263
# merge_sort Theta 0.004083412924920045
# heap_sort Theta 0.011483738322143616
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991842269897461
# Sample mean is:  0.004083018124006312 Sample variance is: 0.0005883243617652683
#
#
# Iteration: 1997
# quick_sort Theta 0.005127325740379529
# merge_sort Theta 0.00408278508033661
# heap_sort Theta 0.011480878323588994
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003983020782470703
# Sample mean is:  0.004082963777625043 Sample variance is: 0.0005880098808909082
#
#
# Iteration: 1998
# quick_sort Theta 0.005129242509699489
# merge_sort Theta 0.004083044388412175
# heap_sort Theta 0.011483739825777134
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989696502685547
# Sample mean is:  0.004082913116421925 Sample variance is: 0.0005876950353358281
#
#
# Iteration: 1999
# quick_sort Theta 0.005121639556296681
# merge_sort Theta 0.004082708977942257
# heap_sort Theta 0.011492410231224597
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002994537353515625
# Sample mean is:  0.004082322250101129 Sample variance is: 0.0005880188939351548
# Total reward 8.908
# Average rewards per algo {'quick_sort': 0.005130511611255247, 'merge_sort': 0.004082322250101129, 'heap_sort': 0.011479768124255505}
# Count per chosen algo {'quick_sort': 67, 'merge_sort': 1842, 'heap_sort': 91}

# %%
plot_history(rewards,cum_rewards, arm_counts)

# %% [markdown]
# ### Quick sort should be the fastest at first an then at iteration 1000 merge sort should be faster

# %%
# initialize
total_reward = 0
num_choices = len(choices)
sample_count = [0 for i in range(num_choices)]
sample_rewards = [0 for i in range(num_choices)]
sample_mean = [0.0 for i in range(num_choices)]
sample_var = [0.0 for i in range(num_choices)]
arm_rewards = {0: [], 1:[], 2:[]}
rewards = []
cum_rewards = []
var_multiplier = 1000
alpha = 0.6


for n, elem in enumerate(list_distributions):
    dist_type = elem
    distribion = create_df_distribution(n_samples=n_samples, dist_type=dist_type)
    print("\n")
    print("Iteration:", n)
    theta = {}
    for i in range(len(choices)):
        if sample_count[i] >= 2:
            theta[i] = t.rvs(df=sample_count[i]-1,loc=sample_mean[i],scale=sample_var[i]/(sample_count[i]*(sample_count[i]-1)))
            print(choices_names[i],"Theta", theta[i])

        else:
            print("Less than two values for",choices_names[i])
            theta[i] = uniform.rvs(loc=0, scale=1)
            print(choices_names[i],"Theta", theta[i])
    
    choice = np.argmin([theta[i] for i in range(len(choices))])
    alg = choices[choice]
    alg_name = choices_names[choice]
    start_time = time.time()
    sorted_dist = alg(distribion[dist_type])
    reward = ((time.time() - start_time))*(1)
    print("\n")
    print("Chosen algorithm is: ", alg_name, "with reward:", reward)
    arm_rewards[choice].append(reward)
    sample_count[choice] += 1
    sample_rewards[choice] += reward
    #sample_mean[choice]  += alpha*(reward-sample_mean[choice])
    #sample_mean[choice]  += (1/sample_count[choice])*(reward-sample_mean[choice]) #this is alternative variation for non-stationary but does not work right now
    sample_mean[choice] = sample_rewards[choice]/sample_count[choice]
    sample_var[choice] = sum([(sample_mean[choice]-i)**2 for i in arm_rewards[choice]])*var_multiplier
    if sample_count[choice] >= 2:
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice]/(sample_count[choice]-1))
    else:
        print("Sample mean is: ", sample_mean[choice], "Sample variance is:", sample_var[choice])
    total_reward += reward
    rewards.append(reward)
    cum_rewards.append(sum(rewards)/len(rewards))
    
    
q_values = {"quick_sort": sample_mean[0], "merge_sort": sample_mean[1], "heap_sort":sample_mean[2]} ## 
arm_counts = {"quick_sort": sample_count[0], "merge_sort": sample_count[1], "heap_sort":sample_count[2]} ## 

print("Total reward", np.round(total_reward,4))
print("Average rewards per algo", q_values)
print("Count per chosen algo", arm_counts)
# Out:
# Iteration: 0
# Less than two values for quick_sort
# quick_sort Theta 0.5566185532505074
# Less than two values for merge_sort
# merge_sort Theta 0.5209834303583104
# Less than two values for heap_sort
# heap_sort Theta 0.865613353853742
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006981372833251953
# Sample mean is:  0.006981372833251953 Sample variance is: 0.0
#
#
# Iteration: 1
# Less than two values for quick_sort
# quick_sort Theta 0.1410646671519168
# Less than two values for merge_sort
# merge_sort Theta 0.7184034010781136
# Less than two values for heap_sort
# heap_sort Theta 0.3155477135014969
#
#
# Chosen algorithm is:  quick_sort with reward: 0.0050203800201416016
# Sample mean is:  0.0050203800201416016 Sample variance is: 0.0
#
#
# Iteration: 2
# Less than two values for quick_sort
# quick_sort Theta 0.9616125785363159
# Less than two values for merge_sort
# merge_sort Theta 0.3836215728511211
# Less than two values for heap_sort
# heap_sort Theta 0.689064336762226
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049860477447509766
# Sample mean is:  0.005983710289001465 Sample variance is: 0.001990661104400715
#
#
# Iteration: 3
# Less than two values for quick_sort
# quick_sort Theta 0.6424361679712486
# merge_sort Theta 0.013000455545928585
# Less than two values for heap_sort
# heap_sort Theta 0.8179642666216125
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039882659912109375
# Sample mean is:  0.005318562189737956 Sample variance is: 0.002322596534061934
#
#
# Iteration: 4
# Less than two values for quick_sort
# quick_sort Theta 0.26344024419038203
# merge_sort Theta 0.004625405633159987
# Less than two values for heap_sort
# heap_sort Theta 0.3423568143861393
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003983974456787109
# Sample mean is:  0.004984915256500244 Sample variance is: 0.001993678793610343
#
#
# Iteration: 5
# Less than two values for quick_sort
# quick_sort Theta 0.6443033238552262
# merge_sort Theta 0.004635252667906449
# Less than two values for heap_sort
# heap_sort Theta 0.4442420240653706
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004015684127807617
# Sample mean is:  0.004791069030761719 Sample variance is: 0.0016831408913731138
#
#
# Iteration: 6
# Less than two values for quick_sort
# quick_sort Theta 0.20421164486735055
# merge_sort Theta 0.004567256256710465
# Less than two values for heap_sort
# heap_sort Theta 0.3751570178036995
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004981517791748047
# Sample mean is:  0.0048228104909261065 Sample variance is: 0.0013525578348586955
#
#
# Iteration: 7
# Less than two values for quick_sort
# quick_sort Theta 0.8333988193102603
# merge_sort Theta 0.004265755283885966
# Less than two values for heap_sort
# heap_sort Theta 0.00041064587232531036
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010973691940307617
# Sample mean is:  0.010973691940307617 Sample variance is: 0.0
#
#
# Iteration: 8
# Less than two values for quick_sort
# quick_sort Theta 0.14714710932879682
# merge_sort Theta 0.004721387087877929
# Less than two values for heap_sort
# heap_sort Theta 0.2587896878259742
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049898624420166016
# Sample mean is:  0.004846675055367606 Sample variance is: 0.0011311181511007903
#
#
# Iteration: 9
# Less than two values for quick_sort
# quick_sort Theta 0.27801564662318135
# merge_sort Theta 0.004855950496341064
# Less than two values for heap_sort
# heap_sort Theta 0.040431897518453
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003987789154052734
# Sample mean is:  0.004739314317703247 Sample variance is: 0.0010617404677353598
#
#
# Iteration: 10
# Less than two values for quick_sort
# quick_sort Theta 0.609130570535324
# merge_sort Theta 0.004632344426944805
# Less than two values for heap_sort
# heap_sort Theta 0.7660901416032735
#
#
# Chosen algorithm is:  merge_sort with reward: 0.009970664978027344
# Sample mean is:  0.005320575502183702 Sample variance is: 0.003969803990521035
#
#
# Iteration: 11
# Less than two values for quick_sort
# quick_sort Theta 0.35228454953676547
# merge_sort Theta 0.0039903537714350325
# Less than two values for heap_sort
# heap_sort Theta 0.3210058124628794
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003993988037109375
# Sample mean is:  0.00518791675567627 Sample variance is: 0.003704698088490153
#
#
# Iteration: 12
# Less than two values for quick_sort
# quick_sort Theta 0.12159137733681802
# merge_sort Theta 0.005330159778724138
# Less than two values for heap_sort
# heap_sort Theta 0.12284251119428768
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00401759147644043
# Sample mean is:  0.005081523548473011 Sample variance is: 0.003458742939570088
#
#
# Iteration: 13
# Less than two values for quick_sort
# quick_sort Theta 0.6831880591320906
# merge_sort Theta 0.005018726681371612
# Less than two values for heap_sort
# heap_sort Theta 0.7060197505538033
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0029938220977783203
# Sample mean is:  0.004907548427581787 Sample variance is: 0.0035075198755149277
#
#
# Iteration: 14
# Less than two values for quick_sort
# quick_sort Theta 0.2103228200623497
# merge_sort Theta 0.004494828381287113
# Less than two values for heap_sort
# heap_sort Theta 0.06124166164439537
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002992391586303711
# Sample mean is:  0.004760228670560396 Sample variance is: 0.0034973669930702905
#
#
# Iteration: 15
# Less than two values for quick_sort
# quick_sort Theta 0.01996391026248956
# merge_sort Theta 0.0047277940501508865
# Less than two values for heap_sort
# heap_sort Theta 0.971996510077635
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991842269897461
# Sample mean is:  0.004705343927655902 Sample variance is: 0.0032705114528858094
#
#
# Iteration: 16
# Less than two values for quick_sort
# quick_sort Theta 0.35804114722733027
# merge_sort Theta 0.004852144865090641
# Less than two values for heap_sort
# heap_sort Theta 0.026672458718842607
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991127014160156
# Sample mean is:  0.004657729466756185 Sample variance is: 0.003070910545266954
#
#
# Iteration: 17
# Less than two values for quick_sort
# quick_sort Theta 0.23528177843790876
# merge_sort Theta 0.004579647257461356
# Less than two values for heap_sort
# heap_sort Theta 0.3053707494099348
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.0046159327030181885 Sample variance is: 0.0028941346869260087
#
#
# Iteration: 18
# Less than two values for quick_sort
# quick_sort Theta 0.9257843497030268
# merge_sort Theta 0.005028177228244213
# Less than two values for heap_sort
# heap_sort Theta 0.4062177086812977
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005984783172607422
# Sample mean is:  0.004696453318876379 Sample variance is: 0.002823471951822231
#
#
# Iteration: 19
# Less than two values for quick_sort
# quick_sort Theta 0.8050396060835113
# merge_sort Theta 0.004814886061929269
# Less than two values for heap_sort
# heap_sort Theta 0.146970961859892
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004018306732177734
# Sample mean is:  0.0046587785085042315 Sample variance is: 0.002682934410479314
#
#
# Iteration: 20
# Less than two values for quick_sort
# quick_sort Theta 0.6780214582030217
# merge_sort Theta 0.004759120390095938
# Less than two values for heap_sort
# heap_sort Theta 0.8223015537905107
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004988908767700195
# Sample mean is:  0.0046761537853040195 Sample variance is: 0.002539618603419534
#
#
# Iteration: 21
# Less than two values for quick_sort
# quick_sort Theta 0.49360338368031376
# merge_sort Theta 0.00457111019582416
# Less than two values for heap_sort
# heap_sort Theta 0.6943376538465658
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0040130615234375
# Sample mean is:  0.004642999172210694 Sample variance is: 0.002427939033784816
#
#
# Iteration: 22
# Less than two values for quick_sort
# quick_sort Theta 0.2750491182768635
# merge_sort Theta 0.004384832083960734
# Less than two values for heap_sort
# heap_sort Theta 0.7846063148104838
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990888595581055
# Sample mean is:  0.004611946287609282 Sample variance is: 0.0023267919965790146
#
#
# Iteration: 23
# Less than two values for quick_sort
# quick_sort Theta 0.9393449375333601
# merge_sort Theta 0.004572333764365248
# Less than two values for heap_sort
# heap_sort Theta 0.027324394611891734
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991365432739258
# Sample mean is:  0.004583738066933372 Sample variance is: 0.002233497859395719
# Iteration: 24
# Less than two values for quick_sort
# quick_sort Theta 0.7243768994649463
# merge_sort Theta 0.004482426081197968
# Less than two values for heap_sort
# heap_sort Theta 0.781904438125071
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0059833526611328125
# Sample mean is:  0.004644590875376825 Sample variance is: 0.0022171457082186675
#
#
# Iteration: 25
# Less than two values for quick_sort
# quick_sort Theta 0.2477457576092551
# merge_sort Theta 0.0045270820828411775
# Less than two values for heap_sort
# heap_sort Theta 0.5201767975158457
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003958225250244141
# Sample mean is:  0.004615992307662964 Sample variance is: 0.002140377142537723
#
#
# Iteration: 26
# Less than two values for quick_sort
# quick_sort Theta 0.6969055754898464
# merge_sort Theta 0.0047369293402264225
# Less than two values for heap_sort
# heap_sort Theta 0.9400225977760963
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039882659912109375
# Sample mean is:  0.004590883255004883 Sample variance is: 0.002066956374733308
#
#
# Iteration: 27
# Less than two values for quick_sort
# quick_sort Theta 0.14513801075620059
# merge_sort Theta 0.004729028027264525
# Less than two values for heap_sort
# heap_sort Theta 0.7287443369295968
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004990816116333008
# Sample mean is:  0.004606265288132887 Sample variance is: 0.001990429900265903
#
#
# Iteration: 28
# Less than two values for quick_sort
# quick_sort Theta 0.1626875989291212
# merge_sort Theta 0.004542756487774429
# Less than two values for heap_sort
# heap_sort Theta 0.9557732976773379
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0050122737884521484
# Sample mean is:  0.004621302639996564 Sample variance is: 0.001919980196780774
#
#
# Iteration: 29
# Less than two values for quick_sort
# quick_sort Theta 0.41732384524052846
# merge_sort Theta 0.004544613221712382
# Less than two values for heap_sort
# heap_sort Theta 0.5097509257914277
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991603851318359
# Sample mean is:  0.004598813397543771 Sample variance is: 0.0018630312678530412
#
#
# Iteration: 30
# Less than two values for quick_sort
# quick_sort Theta 0.08138646972100716
# merge_sort Theta 0.0045892344777469715
# Less than two values for heap_sort
# heap_sort Theta 0.49433666769596896
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989696502685547
# Sample mean is:  0.004577809366686591 Sample variance is: 0.001809288346913522
#
#
# Iteration: 31
# Less than two values for quick_sort
# quick_sort Theta 0.56523569895705
# merge_sort Theta 0.004554743477546919
# Less than two values for heap_sort
# heap_sort Theta 0.899749928598391
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399017333984375
# Sample mean is:  0.0045582214991251625 Sample variance is: 0.001758409630239798
#
#
# Iteration: 32
# Less than two values for quick_sort
# quick_sort Theta 0.4917917980234058
# merge_sort Theta 0.004570302034086569
# Less than two values for heap_sort
# heap_sort Theta 0.13557567519889513
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049877166748046875
# Sample mean is:  0.004572076182211599 Sample variance is: 0.0017057464954446635
#
#
# Iteration: 33
# Less than two values for quick_sort
# quick_sort Theta 0.4834182595209131
# merge_sort Theta 0.004527838729928857
# Less than two values for heap_sort
# heap_sort Theta 0.48130466386081894
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039904117584228516
# Sample mean is:  0.004553899168968201 Sample variance is: 0.0016612953368808708
#
#
# Iteration: 34
# Less than two values for quick_sort
# quick_sort Theta 0.9432723830533767
# merge_sort Theta 0.00455304065176097
# Less than two values for heap_sort
# heap_sort Theta 0.2439619594643595
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0029935836791992188
# Sample mean is:  0.004506616881399444 Sample variance is: 0.0016831551432885865
#
#
# Iteration: 35
# Less than two values for quick_sort
# quick_sort Theta 0.6755091158061274
# merge_sort Theta 0.004430204139072904
# Less than two values for heap_sort
# heap_sort Theta 0.9511941452278075
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004983425140380859
# Sample mean is:  0.004520640653722426 Sample variance is: 0.0016388370924424844
#
#
# Iteration: 36
# Less than two values for quick_sort
# quick_sort Theta 0.45260515109433497
# merge_sort Theta 0.004519039614696742
# Less than two values for heap_sort
# heap_sort Theta 0.4711451683435486
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003992557525634766
# Sample mean is:  0.004505552564348494 Sample variance is: 0.0015986037669217467
#
#
# Iteration: 37
# Less than two values for quick_sort
# quick_sort Theta 0.7287739092252757
# merge_sort Theta 0.004514768078576044
# Less than two values for heap_sort
# heap_sort Theta 0.6543128435097422
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049855709075927734
# Sample mean is:  0.00451888640721639 Sample variance is: 0.0015593298627436536
#
#
# Iteration: 38
# Less than two values for quick_sort
# quick_sort Theta 0.31206565387169005
# merge_sort Theta 0.004493125919514968
# Less than two values for heap_sort
# heap_sort Theta 0.7900834764429977
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991365432739258
# Sample mean is:  0.004504629083581873 Sample variance is: 0.0015235361815912228
#
#
# Iteration: 39
# Less than two values for quick_sort
# quick_sort Theta 0.7719349366814392
# merge_sort Theta 0.004530022355740147
# Less than two values for heap_sort
# heap_sort Theta 0.6825962801900973
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.004491084500362999 Sample variance is: 0.0014893308459484776
#
#
# Iteration: 40
# Less than two values for quick_sort
# quick_sort Theta 0.1688613296992033
# merge_sort Theta 0.00450538533388184
# Less than two values for heap_sort
# heap_sort Theta 0.4858294816599982
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005985736846923828
# Sample mean is:  0.004529408919505584 Sample variance is: 0.0015074196119518794
#
#
# Iteration: 41
# Less than two values for quick_sort
# quick_sort Theta 0.015281098096381562
# merge_sort Theta 0.004505244964260343
# Less than two values for heap_sort
# heap_sort Theta 0.5385530019726023
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991365432739258
# Sample mean is:  0.004515957832336426 Sample variance is: 0.0014760050968713287
#
#
# Iteration: 42
# Less than two values for quick_sort
# quick_sort Theta 0.19330200477988257
# merge_sort Theta 0.004496657341419386
# Less than two values for heap_sort
# heap_sort Theta 0.7881393741426487
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004503110559975229 Sample variance is: 0.001445872118141579
#
#
# Iteration: 43
# Less than two values for quick_sort
# quick_sort Theta 0.8991757924498531
# merge_sort Theta 0.004505608052498625
# Less than two values for heap_sort
# heap_sort Theta 0.5552859137981343
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990650177001953
# Sample mean is:  0.004490909122285389 Sample variance is: 0.0014168596979597294
#
#
# Iteration: 44
# Less than two values for quick_sort
# quick_sort Theta 0.11209963780066168
# merge_sort Theta 0.004566148936226492
# Less than two values for heap_sort
# heap_sort Theta 0.7996676725203767
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0040209293365478516
# Sample mean is:  0.004479979359826376 Sample variance is: 0.001388261710665052
#
#
# Iteration: 45
# Less than two values for quick_sort
# quick_sort Theta 0.361011931409555
# merge_sort Theta 0.0045212586835493545
# Less than two values for heap_sort
# heap_sort Theta 0.7428571986011469
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990888595581055
# Sample mean is:  0.004468863660638983 Sample variance is: 0.0013614131404137571
#
#
# Iteration: 46
# Less than two values for quick_sort
# quick_sort Theta 0.8122384294258483
# merge_sort Theta 0.004507846159385982
# Less than two values for heap_sort
# heap_sort Theta 0.23614906847746897
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004458204905192057 Sample variance is: 0.0013355843407225618
#
#
# Iteration: 47
# Less than two values for quick_sort
# quick_sort Theta 0.0982285138173814
# merge_sort Theta 0.00447602619776819
# Less than two values for heap_sort
# heap_sort Theta 0.7582289220573051
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.004448004390882409 Sample variance is: 0.001310691011346847
#
#
# Iteration: 48
# Less than two values for quick_sort
# quick_sort Theta 0.8654696578452116
# merge_sort Theta 0.004451597948820547
# Less than two values for heap_sort
# heap_sort Theta 0.7449216283376846
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.004438258231954372 Sample variance is: 0.0012866621463424566
# Iteration: 49
# Less than two values for quick_sort
# quick_sort Theta 0.791717483926907
# merge_sort Theta 0.004487800474766687
# Less than two values for heap_sort
# heap_sort Theta 0.12680772742303426
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003957986831665039
# Sample mean is:  0.004428252577781677 Sample variance is: 0.0012640917855350757
#
#
# Iteration: 50
# Less than two values for quick_sort
# quick_sort Theta 0.10498891067726968
# merge_sort Theta 0.00439701711662718
# Less than two values for heap_sort
# heap_sort Theta 0.8035356187824672
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006983757019042969
# Sample mean is:  0.004480405729644152 Sample variance is: 0.0013710341512134254
#
#
# Iteration: 51
# Less than two values for quick_sort
# quick_sort Theta 0.9864068295856833
# merge_sort Theta 0.004474646755667471
# Less than two values for heap_sort
# heap_sort Theta 0.42780201690174624
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988504409790039
# Sample mean is:  0.00447056770324707 Sample variance is: 0.0013478932005826358
#
#
# Iteration: 52
# Less than two values for quick_sort
# quick_sort Theta 0.38949750331943866
# merge_sort Theta 0.004443202601444294
# Less than two values for heap_sort
# heap_sort Theta 0.9017139663446909
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990650177001953
# Sample mean is:  0.004461157555673637 Sample variance is: 0.0013254514313160261
#
#
# Iteration: 53
# Less than two values for quick_sort
# quick_sort Theta 0.5051630989121767
# merge_sort Theta 0.004455439996451178
# Less than two values for heap_sort
# heap_sort Theta 0.9187142537879077
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0040187835693359375
# Sample mean is:  0.004452650363628681 Sample variance is: 0.0013032255480221998
#
#
# Iteration: 54
# Less than two values for quick_sort
# quick_sort Theta 0.7520138623239647
# merge_sort Theta 0.004475897058799747
# Less than two values for heap_sort
# heap_sort Theta 0.507216972902774
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0040166378021240234
# Sample mean is:  0.004444423711524819 Sample variance is: 0.0012817504419089542
#
#
# Iteration: 55
# Less than two values for quick_sort
# quick_sort Theta 0.5784460087883352
# merge_sort Theta 0.004494309100708604
# Less than two values for heap_sort
# heap_sort Theta 0.8455292132390176
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990888595581055
# Sample mean is:  0.004436024913081416 Sample variance is: 0.0012613756213327154
#
#
# Iteration: 56
# Less than two values for quick_sort
# quick_sort Theta 0.5644377736605922
# merge_sort Theta 0.004428190301703541
# Less than two values for heap_sort
# heap_sort Theta 0.6836565514417796
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003992319107055664
# Sample mean is:  0.004427957534790039 Sample variance is: 0.0012415963561175484
#
#
# Iteration: 57
# Less than two values for quick_sort
# quick_sort Theta 0.06683152003626092
# merge_sort Theta 0.004443847148025443
# Less than two values for heap_sort
# heap_sort Theta 0.43706666171856723
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004015445709228516
# Sample mean is:  0.004420591252190726 Sample variance is: 0.0012220605555980564
#
#
# Iteration: 58
# Less than two values for quick_sort
# quick_sort Theta 0.07678117219059677
# merge_sort Theta 0.004410447301642419
# Less than two values for heap_sort
# heap_sort Theta 0.3096314021878426
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003987312316894531
# Sample mean is:  0.004412989867360969 Sample variance is: 0.0012035315656024764
#
#
# Iteration: 59
# Less than two values for quick_sort
# quick_sort Theta 0.03965100313949654
# merge_sort Theta 0.004381408835194043
# Less than two values for heap_sort
# heap_sort Theta 0.04335006799533658
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004014492034912109
# Sample mean is:  0.004406119215077367 Sample variance is: 0.0011851549167747814
#
#
# Iteration: 60
# Less than two values for quick_sort
# quick_sort Theta 0.2810893908574684
# merge_sort Theta 0.004448364551153715
# Less than two values for heap_sort
# heap_sort Theta 0.31946102319688474
#
#
# Chosen algorithm is:  merge_sort with reward: 0.007978200912475586
# Sample mean is:  0.004466662972660388 Sample variance is: 0.0013809884596671703
#
#
# Iteration: 61
# Less than two values for quick_sort
# quick_sort Theta 0.7953774662561187
# merge_sort Theta 0.004480400703458676
# Less than two values for heap_sort
# heap_sort Theta 0.8661116361982839
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049860477447509766
# Sample mean is:  0.004475319385528564 Sample variance is: 0.0013620778846296746
#
#
# Iteration: 62
# Less than two values for quick_sort
# quick_sort Theta 0.7414888289832309
# merge_sort Theta 0.004473630548427326
# Less than two values for heap_sort
# heap_sort Theta 0.9692042017662901
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004017353057861328
# Sample mean is:  0.004467811740812708 Sample variance is: 0.0013428148350324647
#
#
# Iteration: 63
# Less than two values for quick_sort
# quick_sort Theta 0.9732008827722306
# merge_sort Theta 0.004474333505961583
# Less than two values for heap_sort
# heap_sort Theta 0.19747522408231233
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039937496185302734
# Sample mean is:  0.004460165577550088 Sample variance is: 0.0013244262334647086
#
#
# Iteration: 64
# Less than two values for quick_sort
# quick_sort Theta 0.08438658531997034
# merge_sort Theta 0.004474227488188733
# Less than two values for heap_sort
# heap_sort Theta 0.24245653129582756
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004985332489013672
# Sample mean is:  0.004468501560271732 Sample variance is: 0.001307442302321669
#
#
# Iteration: 65
# Less than two values for quick_sort
# quick_sort Theta 0.9717313832988684
# merge_sort Theta 0.004483100168299757
# Less than two values for heap_sort
# heap_sort Theta 0.9390984404203786
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049877166748046875
# Sample mean is:  0.00447661429643631 Sample variance is: 0.0012909015051407312
#
#
# Iteration: 66
# Less than two values for quick_sort
# quick_sort Theta 0.27110337721642386
# merge_sort Theta 0.004473034207992369
# Less than two values for heap_sort
# heap_sort Theta 0.4446250055892167
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989458084106445
# Sample mean is:  0.0044691195854773885 Sample variance is: 0.0012743822641261627
#
#
# Iteration: 67
# Less than two values for quick_sort
# quick_sort Theta 0.9175423532007234
# merge_sort Theta 0.0044520069692903005
# Less than two values for heap_sort
# heap_sort Theta 0.07022806701490536
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004984617233276367
# Sample mean is:  0.004476930155898585 Sample variance is: 0.001258802713819701
#
#
# Iteration: 68
# Less than two values for quick_sort
# quick_sort Theta 0.8015631320414677
# merge_sort Theta 0.004482054220915183
# Less than two values for heap_sort
# heap_sort Theta 0.7945526092324292
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049855709075927734
# Sample mean is:  0.004484521808908947 Sample variance is: 0.0012435913695222854
#
#
# Iteration: 69
# Less than two values for quick_sort
# quick_sort Theta 0.36890263533296264
# merge_sort Theta 0.004506742408778966
# Less than two values for heap_sort
# heap_sort Theta 0.24159704411806948
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004991054534912109
# Sample mean is:  0.004491970819585463 Sample variance is: 0.0012288034719895372
#
#
# Iteration: 70
# Less than two values for quick_sort
# quick_sort Theta 0.8413792341487327
# merge_sort Theta 0.004488896993656752
# Less than two values for heap_sort
# heap_sort Theta 0.6202289311970753
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004023551940917969
# Sample mean is:  0.004485182140184485 Sample variance is: 0.001213912778288213
#
#
# Iteration: 71
# Less than two values for quick_sort
# quick_sort Theta 0.31658298667230966
# merge_sort Theta 0.004490335085920005
# Less than two values for heap_sort
# heap_sort Theta 0.48979893461550594
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004478096961975098 Sample variance is: 0.0011998338219905565
#
#
# Iteration: 72
# Less than two values for quick_sort
# quick_sort Theta 0.15756596745136686
# merge_sort Theta 0.004497157595632284
# Less than two values for heap_sort
# heap_sort Theta 0.5888751681230445
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049855709075927734
# Sample mean is:  0.00448524448233591 Sample variance is: 0.001186320519178147
#
#
# Iteration: 73
# Less than two values for quick_sort
# quick_sort Theta 0.3854526227314644
# merge_sort Theta 0.004480645770687941
# Less than two values for heap_sort
# heap_sort Theta 0.8722253698689757
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.004478365182876587 Sample variance is: 0.0011730191622670875
#
#
# Iteration: 74
# Less than two values for quick_sort
# quick_sort Theta 0.5245220288546448
# merge_sort Theta 0.004495498465336605
# Less than two values for heap_sort
# heap_sort Theta 0.26629398835547313
# Chosen algorithm is:  merge_sort with reward: 0.005956888198852539
# Sample mean is:  0.004498618922821463 Sample variance is: 0.0011866728501259132
#
#
# Iteration: 75
# Less than two values for quick_sort
# quick_sort Theta 0.08690370993647767
# merge_sort Theta 0.00451014664817878
# Less than two values for heap_sort
# heap_sort Theta 0.17515917905265188
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991365432739258
# Sample mean is:  0.00449176414592846 Sample variance is: 0.0011738941671611456
#
#
# Iteration: 76
# Less than two values for quick_sort
# quick_sort Theta 0.6158809961082499
# merge_sort Theta 0.004487731598011147
# Less than two values for heap_sort
# heap_sort Theta 0.023356731692329102
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003995656967163086
# Sample mean is:  0.004485149383544922 Sample variance is: 0.0011613123635740791
#
#
# Iteration: 77
# Less than two values for quick_sort
# quick_sort Theta 0.6416196109338748
# merge_sort Theta 0.0044744637145578935
# Less than two values for heap_sort
# heap_sort Theta 0.047123107178396295
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0040204524993896484
# Sample mean is:  0.0044790349508586685 Sample variance is: 0.0011486695565441042
#
#
# Iteration: 78
# Less than two values for quick_sort
# quick_sort Theta 0.05733090570372601
# merge_sort Theta 0.0044807348519476965
# Less than two values for heap_sort
# heap_sort Theta 0.5202582224175154
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004990577697753906
# Sample mean is:  0.004485678363156009 Sample variance is: 0.00113695387280702
#
#
# Iteration: 79
# Less than two values for quick_sort
# quick_sort Theta 0.6740549562663342
# merge_sort Theta 0.004459392798424265
# Less than two values for heap_sort
# heap_sort Theta 0.9878111212441189
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003991603851318359
# Sample mean is:  0.004479344074542706 Sample variance is: 0.0011253178486496983
#
#
# Iteration: 80
# Less than two values for quick_sort
# quick_sort Theta 0.5738144565800011
# merge_sort Theta 0.00446871262984508
# Less than two values for heap_sort
# heap_sort Theta 0.9877834982274756
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399017333984375
# Sample mean is:  0.004473152039926263 Sample variance is: 0.001113919658866539
#
#
# Iteration: 81
# Less than two values for quick_sort
# quick_sort Theta 0.37796995500478014
# merge_sort Theta 0.004465414115197458
# Less than two values for heap_sort
# heap_sort Theta 0.09469695656625399
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988742828369141
# Sample mean is:  0.004467096924781799 Sample variance is: 0.0011027525635731446
#
#
# Iteration: 82
# Less than two values for quick_sort
# quick_sort Theta 0.7349562816096724
# merge_sort Theta 0.004459568691554145
# Less than two values for heap_sort
# heap_sort Theta 0.8850122828365358
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039904117584228516
# Sample mean is:  0.004461211922727985 Sample variance is: 0.0010917734497115253
#
#
# Iteration: 83
# Less than two values for quick_sort
# quick_sort Theta 0.45378322723456943
# merge_sort Theta 0.004442436049818919
# Less than two values for heap_sort
# heap_sort Theta 0.8294803249939738
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004455455919591392 Sample variance is: 0.0010810115540600801
#
#
# Iteration: 84
# Less than two values for quick_sort
# quick_sort Theta 0.4509710475497595
# merge_sort Theta 0.004448250492948956
# Less than two values for heap_sort
# heap_sort Theta 0.23501408252471934
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049591064453125
# Sample mean is:  0.004461523998214538 Sample variance is: 0.0010708846773163042
#
#
# Iteration: 85
# Less than two values for quick_sort
# quick_sort Theta 0.8147193976601967
# merge_sort Theta 0.004451938270146288
# Less than two values for heap_sort
# heap_sort Theta 0.06741827030040104
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.004455909842536563 Sample variance is: 0.0010606300267824262
#
#
# Iteration: 86
# Less than two values for quick_sort
# quick_sort Theta 0.031150013792223152
# merge_sort Theta 0.00448422941418768
# Less than two values for heap_sort
# heap_sort Theta 0.9496739858110643
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004019260406494141
# Sample mean is:  0.004450772790347828 Sample variance is: 0.0010502465697856723
#
#
# Iteration: 87
# Less than two values for quick_sort
# quick_sort Theta 0.6855253836471809
# merge_sort Theta 0.004449290224564091
# Less than two values for heap_sort
# heap_sort Theta 0.8785651549751119
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004987239837646484
# Sample mean is:  0.004457010779269906 Sample variance is: 0.0010412372032863025
#
#
# Iteration: 88
# Less than two values for quick_sort
# quick_sort Theta 0.3532782839022348
# merge_sort Theta 0.004474621574183483
# Less than two values for heap_sort
# heap_sort Theta 0.2685255707447246
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039904117584228516
# Sample mean is:  0.004451647572133733 Sample variance is: 0.001031632261144102
#
#
# Iteration: 89
# Less than two values for quick_sort
# quick_sort Theta 0.8106649430800157
# merge_sort Theta 0.004450156749883685
# Less than two values for heap_sort
# heap_sort Theta 0.9153782618299565
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002992868423461914
# Sample mean is:  0.004435070536353372 Sample variance is: 0.001043956653205164
#
#
# Iteration: 90
# Less than two values for quick_sort
# quick_sort Theta 0.004446798300078991
# merge_sort Theta 0.004451146180455499
# Less than two values for heap_sort
# heap_sort Theta 0.23795266787536484
#
#
# Chosen algorithm is:  quick_sort with reward: 0.004956722259521484
# Sample mean is:  0.004988551139831543 Sample variance is: 2.0261552435840713e-06
#
#
# Iteration: 91
# quick_sort Theta 0.005000140736360323
# merge_sort Theta 0.004435751900901548
# Less than two values for heap_sort
# heap_sort Theta 0.9933016528211648
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.004430058297146572 Sample variance is: 0.0010343294156448313
#
#
# Iteration: 92
# quick_sort Theta 0.004988321254083339
# merge_sort Theta 0.004427409575588791
# Less than two values for heap_sort
# heap_sort Theta 0.8489729529652983
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049877166748046875
# Sample mean is:  0.0044362545013427734 Sample variance is: 0.0010261631019970532
#
#
# Iteration: 93
# quick_sort Theta 0.004989207609727594
# merge_sort Theta 0.00443946100127802
# Less than two values for heap_sort
# heap_sort Theta 0.32331473231197483
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0049517154693603516
# Sample mean is:  0.004441918907584725 Sample variance is: 0.0010176810700773622
#
#
# Iteration: 94
# quick_sort Theta 0.004988451478263001
# merge_sort Theta 0.004453223910293001
# Less than two values for heap_sort
# heap_sort Theta 0.27197634920499514
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004987001419067383
# Sample mean is:  0.004447843717492145 Sample variance is: 0.0010097272718793677
#
#
# Iteration: 95
# quick_sort Theta 0.004989436936450243
# merge_sort Theta 0.004428923811298993
# Less than two values for heap_sort
# heap_sort Theta 0.34096958162190416
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004990339279174805
# Sample mean is:  0.004453677003101636 Sample variance is: 0.001001916506999073
#
#
# Iteration: 96
# quick_sort Theta 0.0049911056040602775
# merge_sort Theta 0.004446902484857463
# Less than two values for heap_sort
# heap_sort Theta 0.3653756161998658
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039937496185302734
# Sample mean is:  0.004448784158584919 Sample variance is: 0.0009933935644065776
#
#
# Iteration: 97
# quick_sort Theta 0.0049905124164745405
# merge_sort Theta 0.004465868787053324
# Less than two values for heap_sort
# heap_sort Theta 0.25501061085294163
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988504409790039
# Sample mean is:  0.004443939108597605 Sample variance is: 0.0009850556261550142
#
#
# Iteration: 98
# quick_sort Theta 0.004978680963125028
# merge_sort Theta 0.004448453236537216
# Less than two values for heap_sort
# heap_sort Theta 0.4349355933716026
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990650177001953
# Sample mean is:  0.004439217348893483 Sample variance is: 0.0009768269409754409
#
#
# Iteration: 99
# quick_sort Theta 0.005010664790128153
# merge_sort Theta 0.0044361654636927055
# Less than two values for heap_sort
# heap_sort Theta 0.5926035306710677
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030198097229003906
# Sample mean is:  0.004424584280584276 Sample variance is: 0.0009874219490900464
#
#
# Iteration: 100
# quick_sort Theta 0.004987785505547257
# merge_sort Theta 0.0044272315861183
# Less than two values for heap_sort
# heap_sort Theta 0.1090438739867251
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003985881805419922
# Sample mean is:  0.004420107724715253 Sample variance is: 0.000979206217507421
# Iteration: 101
# quick_sort Theta 0.004988110906355363
# merge_sort Theta 0.0044151810496907504
# Less than two values for heap_sort
# heap_sort Theta 0.3837671838450839
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.004415752911808515 Sample variance is: 0.00097109179247859
#
#
# Iteration: 102
# quick_sort Theta 0.004997409030726071
# merge_sort Theta 0.004416845065498454
# Less than two values for heap_sort
# heap_sort Theta 0.25088942994289254
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003014087677001953
# Sample mean is:  0.0044017362594604495 Sample variance is: 0.0009809294387784092
#
#
# Iteration: 103
# quick_sort Theta 0.004987126287390914
# merge_sort Theta 0.004397756533673926
# Less than two values for heap_sort
# heap_sort Theta 0.27868152531420354
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00498652458190918
# Sample mean is:  0.004407526242851031 Sample variance is: 0.0009745060590646088
#
#
# Iteration: 104
# quick_sort Theta 0.004989398812567041
# merge_sort Theta 0.004389028698172751
# Less than two values for heap_sort
# heap_sort Theta 0.14699486801426132
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004019975662231445
# Sample mean is:  0.00440372672735476 Sample variance is: 0.0009663299886590377
#
#
# Iteration: 105
# quick_sort Theta 0.004988907919289491
# merge_sort Theta 0.004419038030061945
# Less than two values for heap_sort
# heap_sort Theta 0.7061511588135211
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0029947757720947266
# Sample mean is:  0.004390047591866799 Sample variance is: 0.0009761293962537068
#
#
# Iteration: 106
# quick_sort Theta 0.0049897501215661845
# merge_sort Theta 0.00439851591777076
# Less than two values for heap_sort
# heap_sort Theta 0.5212522801201033
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0037796497344970703
# Sample mean is:  0.004384178381699782 Sample variance is: 0.0009702349651344586
#
#
# Iteration: 107
# quick_sort Theta 0.004987059188074049
# merge_sort Theta 0.004371930428847336
# Less than two values for heap_sort
# heap_sort Theta 0.24768035410582967
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.004380414599464053 Sample variance is: 0.0009623932187327858
#
#
# Iteration: 108
# quick_sort Theta 0.004987275789454874
# merge_sort Theta 0.004389591493685965
# Less than two values for heap_sort
# heap_sort Theta 0.6177381893304333
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004018068313598633
# Sample mean is:  0.004376996238276643 Sample variance is: 0.0009544661995105733
#
#
# Iteration: 109
# quick_sort Theta 0.004989924235226456
# merge_sort Theta 0.004373221879019732
# Less than two values for heap_sort
# heap_sort Theta 0.19219455733638624
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003990650177001953
# Sample mean is:  0.004373385527423609 Sample variance is: 0.000946856785318454
#
#
# Iteration: 110
# quick_sort Theta 0.004983466129403961
# merge_sort Theta 0.004380155832357188
# Less than two values for heap_sort
# heap_sort Theta 0.35454913340708705
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004984617233276367
# Sample mean is:  0.004379045080255579 Sample variance is: 0.0009414669546155512
#
#
# Iteration: 111
# quick_sort Theta 0.004989056274811949
# merge_sort Theta 0.004375656373752344
# Less than two values for heap_sort
# heap_sort Theta 0.0912733142916533
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002996206283569336
# Sample mean is:  0.004366358485790567 Sample variance is: 0.0009502931830227831
#
#
# Iteration: 112
# quick_sort Theta 0.004997198187770895
# merge_sort Theta 0.0043633406763865035
# Less than two values for heap_sort
# heap_sort Theta 0.13521117332440657
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004987955093383789
# Sample mean is:  0.0043720093640414156 Sample variance is: 0.0009450874636906545
#
#
# Iteration: 113
# quick_sort Theta 0.004987582531023437
# merge_sort Theta 0.004378027434558828
# Less than two values for heap_sort
# heap_sort Theta 0.05668728939017231
#
#
# Chosen algorithm is:  merge_sort with reward: 0.006982564926147461
# Sample mean is:  0.004395527882618947 Sample variance is: 0.0009978921589603555
#
#
# Iteration: 114
# quick_sort Theta 0.004996350886202657
# merge_sort Theta 0.004398320834665979
# Less than two values for heap_sort
# heap_sort Theta 0.5057603550491304
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003992319107055664
# Sample mean is:  0.004391927804265704 Sample variance is: 0.0009903537226950043
#
#
# Iteration: 115
# quick_sort Theta 0.0049888648215814305
# merge_sort Theta 0.0043902429392460056
# Less than two values for heap_sort
# heap_sort Theta 0.6212470183602438
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989696502685547
# Sample mean is:  0.004388368235225171 Sample variance is: 0.000982943048830608
#
#
# Iteration: 116
# quick_sort Theta 0.004988066889585507
# merge_sort Theta 0.004389270506004653
# Less than two values for heap_sort
# heap_sort Theta 0.8739883972490146
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989696502685547
# Sample mean is:  0.004384871114764297 Sample variance is: 0.0009756386408520472
#
#
# Iteration: 117
# quick_sort Theta 0.004987776364842583
# merge_sort Theta 0.004385514454095632
# Less than two values for heap_sort
# heap_sort Theta 0.8017174685712842
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989696502685547
# Sample mean is:  0.0043814348137897 Sample variance is: 0.0009684383460649845
#
#
# Iteration: 118
# quick_sort Theta 0.004988087699205404
# merge_sort Theta 0.004369597972703019
# Less than two values for heap_sort
# heap_sort Theta 0.45891256690925886
#
#
# Chosen algorithm is:  merge_sort with reward: 0.005984067916870117
# Sample mean is:  0.004395250616402462 Sample variance is: 0.0009821588056685621
#
#
# Iteration: 119
# quick_sort Theta 0.004972228505799097
# merge_sort Theta 0.004392672047210678
# Less than two values for heap_sort
# heap_sort Theta 0.7860564369684941
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003021240234375
# Sample mean is:  0.004383506937923594 Sample variance is: 0.0009898278555659542
#
#
# Iteration: 120
# quick_sort Theta 0.004990451530157536
# merge_sort Theta 0.004385833685747966
# Less than two values for heap_sort
# heap_sort Theta 0.9453536761035246
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004987478256225586
# Sample mean is:  0.004388625338926154 Sample variance is: 0.0009844591558254797
#
#
# Iteration: 121
# quick_sort Theta 0.004989311358260891
# merge_sort Theta 0.0043782380543762045
# Less than two values for heap_sort
# heap_sort Theta 0.001334589809459663
#
#
# Chosen algorithm is:  heap_sort with reward: 0.010968446731567383
# Sample mean is:  0.0109710693359375 Sample variance is: 1.375610736431554e-08
#
#
# Iteration: 122
# quick_sort Theta 0.0049862284552379755
# merge_sort Theta 0.004378430196071758
# heap_sort Theta 0.010971081932480253
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988742828369141
# Sample mean is:  0.004385264981694582 Sample variance is: 0.0009774600297096975
#
#
# Iteration: 123
# quick_sort Theta 0.004981192139414616
# merge_sort Theta 0.004382454659633372
# heap_sort Theta 0.010971063546717886
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003988981246948242
# Sample mean is:  0.0043819626172383625 Sample variance is: 0.0009705547532004081
#
#
# Iteration: 124
# quick_sort Theta 0.004989310247646514
# merge_sort Theta 0.004389179609212392
# heap_sort Theta 0.010971067263228614
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039882659912109375
# Sample mean is:  0.004378708926114169 Sample variance is: 0.0009637477641414687
#
#
# Iteration: 125
# quick_sort Theta 0.004990011143169565
# merge_sort Theta 0.004385770298695028
# heap_sort Theta 0.01097106531761948
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004375516391191326 Sample variance is: 0.0009570263646530762
#
#
# Iteration: 126
# quick_sort Theta 0.004993185850970815
# merge_sort Theta 0.004388718717053334
# heap_sort Theta 0.010971063436910658
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004987001419067383
# Sample mean is:  0.004380487814182188 Sample variance is: 0.0009522218369804315
#
#
# Iteration: 127
# quick_sort Theta 0.0049878726222175275
# merge_sort Theta 0.0043682808986522026
# heap_sort Theta 0.01097109574849893
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989219665527344
# Sample mean is:  0.004377332425886585 Sample variance is: 0.0009457147989660796
#
#
# Iteration: 128
# quick_sort Theta 0.004987476548183488
# merge_sort Theta 0.004374097311294234
# heap_sort Theta 0.010971071480292131
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.00437423324584961 Sample variance is: 0.000939288681329051
#
#
# Iteration: 129
# quick_sort Theta 0.004988239327740694
# merge_sort Theta 0.004380574310376903
# heap_sort Theta 0.010971064538850463
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003984689712524414
# Sample mean is:  0.004371141630505759 Sample variance is: 0.0009329786906431445
#
#
# Iteration: 130
# quick_sort Theta 0.004987733346513752
# merge_sort Theta 0.004368207427399616
# heap_sort Theta 0.01097107072183309
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004987239837646484
# Sample mean is:  0.004375992797491119 Sample variance is: 0.0009285628931424825
#
#
# Iteration: 131
# quick_sort Theta 0.004967335999784068
# merge_sort Theta 0.004384134709977279
# heap_sort Theta 0.010971045915219791
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003984212875366211
# Sample mean is:  0.004372932016849518 Sample variance is: 0.0009224505267002493
#
#
# Iteration: 132
# quick_sort Theta 0.004989474526028124
# merge_sort Theta 0.004383585289855787
# heap_sort Theta 0.010971042727827323
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0039899349212646484
# Sample mean is:  0.0043699630471163015 Sample variance is: 0.0009163809887451043
#
#
# Iteration: 133
# quick_sort Theta 0.004987783095836271
# merge_sort Theta 0.004371346184340015
# heap_sort Theta 0.010971098990368522
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0029969215393066406
# Sample mean is:  0.00435940118936392 Sample variance is: 0.0009237791292437823
#
#
# Iteration: 134
# quick_sort Theta 0.0049890606514436655
# merge_sort Theta 0.0043579465856443175
# heap_sort Theta 0.010971090999447859
#
#
# Chosen algorithm is:  merge_sort with reward: 0.002025127410888672
# Sample mean is:  0.004341582305558765 Sample variance is: 0.0009582672891699777
#
#
# Iteration: 135
# quick_sort Theta 0.004988403667997474
# merge_sort Theta 0.004344896288859184
# heap_sort Theta 0.010971068717759798
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004018068313598633
# Sample mean is:  0.00433913144198331 Sample variance is: 0.0009517451603544429
#
#
# Iteration: 136
# quick_sort Theta 0.004988061516456447
# merge_sort Theta 0.004331188573396399
# heap_sort Theta 0.010971085395404668
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00396275520324707
# Sample mean is:  0.004336301545451458 Sample variance is: 0.0009456000755583678
#
#
# Iteration: 137
# quick_sort Theta 0.004990925379459666
# merge_sort Theta 0.004330524583708697
# heap_sort Theta 0.010971069904187072
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003997325897216797
# Sample mean is:  0.004333771876434782 Sample variance is: 0.0009393477967489169
#
#
# Iteration: 138
# quick_sort Theta 0.004984255213330065
# merge_sort Theta 0.0043312021418492426
# heap_sort Theta 0.010971089774532056
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399017333984375
# Sample mean is:  0.004331226702089663 Sample variance is: 0.0009332122567445748
#
#
# Iteration: 139
# quick_sort Theta 0.0049888841892654036
# merge_sort Theta 0.004337040659446116
# heap_sort Theta 0.010971083322704729
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0030164718627929688
# Sample mean is:  0.0043215593870948345 Sample variance is: 0.0009390097225337389
#
#
# Iteration: 140
# quick_sort Theta 0.004987649086981889
# merge_sort Theta 0.004313112292609959
# heap_sort Theta 0.010971067270572602
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003989458084106445
# Sample mean is:  0.0043191352899927295 Sample variance is: 0.0009329102850859935
#
#
# Iteration: 141
# quick_sort Theta 0.004989181549424861
# merge_sort Theta 0.004307537516308568
# heap_sort Theta 0.010971049090115063
#
#
# Chosen algorithm is:  merge_sort with reward: 0.00399017333984375
# Sample mean is:  0.004316751507745273 Sample variance is: 0.0009268848946181321
#
#
# Iteration: 142
# quick_sort Theta 0.004998496169404785
# merge_sort Theta 0.004304797519580834
# heap_sort Theta 0.010971072630746818
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004016876220703125
# Sample mean is:  0.004314594131579502 Sample variance is: 0.0009208152812077223
#
#
# Iteration: 143
# quick_sort Theta 0.004986831974225141
# merge_sort Theta 0.004314726937537802
# heap_sort Theta 0.010971265724510062
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004021167755126953
# Sample mean is:  0.0043124982288905555 Sample variance is: 0.0009148057039707372
#
#
# Iteration: 144
# quick_sort Theta 0.004988122015566799
# merge_sort Theta 0.004309600801031152
# heap_sort Theta 0.010971068381091749
#
#
# Chosen algorithm is:  merge_sort with reward: 0.004959583282470703
# Sample mean is:  0.004317087484589705 Sample variance is: 0.0009112410162837798
#
#
# Iteration: 145
# quick_sort Theta 0.004988723157251027
# merge_sort Theta 0.004317290151402512
# heap_sort Theta 0.010971071405670418
#
#
# Chosen algorithm is:  merge_sort with reward: 0.003029346466064453
# Sample mean is:  0.004308018885867696 Sample variance is: 0.0009164563205955093
#
#
# Iteration: 146
# quick_sort Theta 0.004989382797863024
# merge_sort Theta 0.004317773433671912
# heap_sort Theta 0.010971067856915508
#
#
# ...
# quick_sort Theta 0.01298191185505514
# merge_sort Theta 0.009813799061248027
# heap_sort Theta 0.01097106514137105
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014997005462646484
# Sample mean is:  0.009817906311438786 Sample variance is: 0.032726521024194044
#
#
# Iteration: 1944
# quick_sort Theta 0.012979567887360816
# merge_sort Theta 0.009837991804389375
# heap_sort Theta 0.010971056312864921
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595902442932129
# Sample mean is:  0.009821089887445983 Sample variance is: 0.03272909740386081
#
#
# Iteration: 1945
# quick_sort Theta 0.011524417678165165
# merge_sort Theta 0.009801969659000225
# heap_sort Theta 0.010971116225621655
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014958381652832031
# Sample mean is:  0.009823751696650847 Sample variance is: 0.03272580502168777
#
#
# Iteration: 1946
# quick_sort Theta 0.013292258082348346
# merge_sort Theta 0.009829498478651376
# heap_sort Theta 0.010971066933688545
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01495814323425293
# Sample mean is:  0.00982641062546369 Sample variance is: 0.03272250062762455
#
#
# Iteration: 1947
# quick_sort Theta 0.012957564033410163
# merge_sort Theta 0.009814834509327864
# heap_sort Theta 0.010970983817661886
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014959573745727539
# Sample mean is:  0.009829067542192605 Sample variance is: 0.03271919313130391
#
#
# Iteration: 1948
# quick_sort Theta 0.012269354520284811
# merge_sort Theta 0.009846371316641062
# heap_sort Theta 0.010971067376932006
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595926284790039
# Sample mean is:  0.009832238879650292 Sample variance is: 0.03272169864912834
#
#
# Iteration: 1949
# quick_sort Theta 0.01453069646809411
# merge_sort Theta 0.009844313719065275
# heap_sort Theta 0.010971064383707691
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014959573745727539
# Sample mean is:  0.009834890035217033 Sample variance is: 0.03271836407634894
#
#
# Iteration: 1950
# quick_sort Theta 0.013656646202294825
# merge_sort Theta 0.009812770988973207
# heap_sort Theta 0.010971076685137056
#
#
# Chosen algorithm is:  merge_sort with reward: 0.013993024826049805
# Sample mean is:  0.00983703894208568 Sample variance is: 0.0327103820626043
#
#
# Iteration: 1951
# quick_sort Theta 0.01304158009086879
# merge_sort Theta 0.00984276916720145
# heap_sort Theta 0.010971069375761054
#
#
# Chosen algorithm is:  merge_sort with reward: 0.013962507247924805
# Sample mean is:  0.009839169865797373 Sample variance is: 0.032702268530625876
#
#
# Iteration: 1952
# quick_sort Theta 0.01206310955542715
# merge_sort Theta 0.009818081299459847
# heap_sort Theta 0.010971050216224567
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014938831329345703
# Sample mean is:  0.009841802628556046 Sample variance is: 0.03269880306177947
#
#
# Iteration: 1953
# quick_sort Theta 0.013273597483692763
# merge_sort Theta 0.009851228427920591
# heap_sort Theta 0.010970981532626017
#
#
# Chosen algorithm is:  merge_sort with reward: 0.016947507858276367
# Sample mean is:  0.009845469143122466 Sample variance is: 0.03270797507550068
#
#
# Iteration: 1954
# quick_sort Theta 0.014937019291986727
# merge_sort Theta 0.00984771772077276
# heap_sort Theta 0.01097107146573735
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015955448150634766
# Sample mean is:  0.009848620241114993 Sample variance is: 0.03271035103796423
#
#
# Iteration: 1955
# quick_sort Theta 0.014669433040248519
# merge_sort Theta 0.009824697508212311
# heap_sort Theta 0.010971064519512568
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015957355499267578
# Sample mean is:  0.009851769073722288 Sample variance is: 0.03271271672132242
#
#
# Iteration: 1956
# quick_sort Theta 0.0120749479445985
# merge_sort Theta 0.009855184748021205
# heap_sort Theta 0.010971069171048625
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01653289794921875
# Sample mean is:  0.009855211180304203 Sample variance is: 0.03271885165388528
#
#
# Iteration: 1957
# quick_sort Theta 0.013673197616899238
# merge_sort Theta 0.009828171349706514
# heap_sort Theta 0.010971062285551978
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014994382858276367
# Sample mean is:  0.009857857509695539 Sample variance is: 0.03271559489651316
#
#
# Iteration: 1958
# quick_sort Theta 0.013281815282988805
# merge_sort Theta 0.009860625627356435
# heap_sort Theta 0.010971051595548193
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014991521835327148
# Sample mean is:  0.009860499642647484 Sample variance is: 0.03271231237884483
#
#
# Iteration: 1959
# quick_sort Theta 0.014138679851759773
# merge_sort Theta 0.009853988134733371
# heap_sort Theta 0.010971060684880296
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014926671981811523
# Sample mean is:  0.009863105698377507 Sample variance is: 0.03270867912463163
#
#
# Iteration: 1960
# quick_sort Theta 0.014451263241696084
# merge_sort Theta 0.009835128922679032
# heap_sort Theta 0.01097108218473252
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595449447631836
# Sample mean is:  0.009866237517800613 Sample variance is: 0.03271093080209544
#
#
# Iteration: 1961
# quick_sort Theta 0.014547576267321206
# merge_sort Theta 0.00987301899203479
# heap_sort Theta 0.010971074132534158
#
#
# Chosen algorithm is:  merge_sort with reward: 0.016954898834228516
# Sample mean is:  0.00986988020090258 Sample variance is: 0.03271993458960705
#
#
# Iteration: 1962
# quick_sort Theta 0.013265407036602627
# merge_sort Theta 0.009880041748265995
# heap_sort Theta 0.010971081857081226
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014924287796020508
# Sample mean is:  0.009872476198640186 Sample variance is: 0.03271624187651219
#
#
# Iteration: 1963
# quick_sort Theta 0.012499604233057914
# merge_sort Theta 0.009855502352985648
# heap_sort Theta 0.01097105586809326
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014962434768676758
# Sample mean is:  0.009875089113717206 Sample variance is: 0.03271273809466246
#
#
# Iteration: 1964
# quick_sort Theta 0.013216009937136045
# merge_sort Theta 0.00986388541092136
# heap_sort Theta 0.010971097968028112
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015937328338623047
# Sample mean is:  0.009878199549440607 Sample variance is: 0.03271480131340984
#
#
# Iteration: 1965
# quick_sort Theta 0.01209591385847445
# merge_sort Theta 0.009876135661782044
# heap_sort Theta 0.010971070553313504
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014957666397094727
# Sample mean is:  0.009880804404234275 Sample variance is: 0.03271124715787857
#
#
# Iteration: 1966
# quick_sort Theta 0.014254042243492976
# merge_sort Theta 0.00987516214351715
# heap_sort Theta 0.010971073286458626
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014980792999267578
# Sample mean is:  0.00988341844246853 Sample variance is: 0.03270780372451772
#
#
# Iteration: 1967
# quick_sort Theta 0.013417542905517811
# merge_sort Theta 0.00986572371571092
# heap_sort Theta 0.010971079663641031
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015959501266479492
# Sample mean is:  0.009886531189816897 Sample variance is: 0.03270995239978631
#
#
# Iteration: 1968
# quick_sort Theta 0.012551389348206243
# merge_sort Theta 0.009870223681552794
# heap_sort Theta 0.010971063223145297
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01795172691345215
# Sample mean is:  0.009890660834324647 Sample variance is: 0.03272650164326459
#
#
# Iteration: 1969
# quick_sort Theta 0.01342748011744788
# merge_sort Theta 0.009900356130458374
# heap_sort Theta 0.010971067700400253
#
#
# Chosen algorithm is:  merge_sort with reward: 0.0159912109375
# Sample mean is:  0.009893782917284306 Sample variance is: 0.03272879102549406
#
#
# Iteration: 1970
# quick_sort Theta 0.013758019536247564
# merge_sort Theta 0.009914492510002544
# heap_sort Theta 0.010971072238237865
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015927791595458984
# Sample mean is:  0.009896869366736059 Sample variance is: 0.03273066505110326
#
#
# Iteration: 1971
# quick_sort Theta 0.013046666419520413
# merge_sort Theta 0.009893615123695874
# heap_sort Theta 0.010971081112278094
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595616340637207
# Sample mean is:  0.00989996716532483 Sample variance is: 0.03273269349546903
#
#
# Iteration: 1972
# quick_sort Theta 0.012422143243431254
# merge_sort Theta 0.009879893462237718
# heap_sort Theta 0.010971018503426825
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014960289001464844
# Sample mean is:  0.009902552919967722 Sample variance is: 0.03272904374027413
#
#
# Iteration: 1973
# quick_sort Theta 0.011927702986697788
# merge_sort Theta 0.009885435763216053
# heap_sort Theta 0.01097107604563319
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014991044998168945
# Sample mean is:  0.00990515174125383 Sample variance is: 0.032725543732000636
#
#
# Iteration: 1974
# quick_sort Theta 0.014331653210352794
# merge_sort Theta 0.00992611453491534
# heap_sort Theta 0.010971068998616315
# Chosen algorithm is:  merge_sort with reward: 0.014282703399658203
# Sample mean is:  0.0099073863260718 Sample variance is: 0.03271861198163249
#
#
# Iteration: 1975
# quick_sort Theta 0.012526203785446272
# merge_sort Theta 0.00992530193734502
# heap_sort Theta 0.01097106587324347
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015956401824951172
# Sample mean is:  0.009910472558469188 Sample variance is: 0.03272057895858834
#
#
# Iteration: 1976
# quick_sort Theta 0.013992418220791992
# merge_sort Theta 0.009905989825680705
# heap_sort Theta 0.010971064862784161
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014961719512939453
# Sample mean is:  0.009913048411072182 Sample variance is: 0.032716896053266366
#
#
# Iteration: 1977
# quick_sort Theta 0.013781552074958035
# merge_sort Theta 0.009911659430740957
# heap_sort Theta 0.010971105941516538
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015961647033691406
# Sample mean is:  0.00991613128498789 Sample variance is: 0.03271885933841551
#
#
# Iteration: 1978
# quick_sort Theta 0.011073126002347083
# merge_sort Theta 0.009931597746349457
# heap_sort Theta 0.010971079414248918
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014961481094360352
# Sample mean is:  0.009918701509037495 Sample variance is: 0.03271515073886457
#
#
# Iteration: 1979
# quick_sort Theta 0.014377965324375503
# merge_sort Theta 0.009909382936154204
# heap_sort Theta 0.010971063192153423
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014960527420043945
# Sample mean is:  0.009921268630173445 Sample variance is: 0.03271142782230837
#
#
# Iteration: 1980
# quick_sort Theta 0.013610452893829127
# merge_sort Theta 0.009917485896803045
# heap_sort Theta 0.010971070823787586
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015960693359375
# Sample mean is:  0.009924342128763369 Sample variance is: 0.03271333447254966
#
#
# Iteration: 1981
# quick_sort Theta 0.014041512357874332
# merge_sort Theta 0.009901330256325442
# heap_sort Theta 0.010971055813751605
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595616340637207
# Sample mean is:  0.009927410196554624 Sample variance is: 0.03271519250176894
#
#
# Iteration: 1982
# quick_sort Theta 0.013083303350761024
# merge_sort Theta 0.009911504470969853
# heap_sort Theta 0.01097109440121455
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595783233642578
# Sample mean is:  0.00993047599327037 Sample variance is: 0.032717040065673025
#
#
# Iteration: 1983
# quick_sort Theta 0.011696799576089377
# merge_sort Theta 0.009917623270810227
# heap_sort Theta 0.010971061315880713
#
#
# Chosen algorithm is:  merge_sort with reward: 0.013961315155029297
# Sample mean is:  0.009932524183901345 Sample variance is: 0.032708663028741064
#
#
# Iteration: 1984
# quick_sort Theta 0.010875076250894044
# merge_sort Theta 0.009951329722635256
# heap_sort Theta 0.010971061863386734
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014961481094360352
# Sample mean is:  0.009935078250387103 Sample variance is: 0.0327048870634403
#
#
# Iteration: 1985
# quick_sort Theta 0.012032854533896117
# merge_sort Theta 0.009920272698093209
# heap_sort Theta 0.010971065539323303
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014958620071411133
# Sample mean is:  0.00993762827161605 Sample variance is: 0.03270108730479424
#
#
# Iteration: 1986
# quick_sort Theta 0.01398305961870928
# merge_sort Theta 0.009917591126499713
# heap_sort Theta 0.010971085163485234
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01595616340637207
# Sample mean is:  0.00994068181557077 Sample variance is: 0.03270286562966831
#
#
# Iteration: 1987
# quick_sort Theta 0.013321748377847309
# merge_sort Theta 0.009929682580670089
# heap_sort Theta 0.010971061834224036
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015956640243530273
# Sample mean is:  0.009943732504428763 Sample variance is: 0.032704626429952345
#
#
# Iteration: 1988
# quick_sort Theta 0.013785799659716054
# merge_sort Theta 0.009932740486586732
# heap_sort Theta 0.010971069809526062
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01598811149597168
# Sample mean is:  0.009946796051814238 Sample variance is: 0.03270655917524751
#
#
# Iteration: 1989
# quick_sort Theta 0.01336814236141082
# merge_sort Theta 0.00994590027578562
# heap_sort Theta 0.010971073314147947
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014959573745727539
# Sample mean is:  0.009949335452874984 Sample variance is: 0.03270271155820773
#
#
# Iteration: 1990
# quick_sort Theta 0.012957852141454979
# merge_sort Theta 0.009940141509224208
# heap_sort Theta 0.010971067086173793
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014961957931518555
# Sample mean is:  0.009951873489573031 Sample variance is: 0.03269886705483146
#
#
# Iteration: 1991
# quick_sort Theta 0.013201685652671004
# merge_sort Theta 0.009936081537188295
# heap_sort Theta 0.010971068505250182
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015990018844604492
# Sample mean is:  0.009954929231149465 Sample variance is: 0.03270076167825522
#
#
# Iteration: 1992
# quick_sort Theta 0.012492625852389845
# merge_sort Theta 0.00996799263892258
# heap_sort Theta 0.010971071842563285
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014960289001464844
# Sample mean is:  0.00995746102668326 Sample variance is: 0.032696885257306095
#
#
# Iteration: 1993
# quick_sort Theta 0.012446991957671308
# merge_sort Theta 0.009958368248131885
# heap_sort Theta 0.010971072521198137
#
#
# Chosen algorithm is:  merge_sort with reward: 0.01695704460144043
# Sample mean is:  0.00996099974436514 Sample variance is: 0.032705116170514095
#
#
# Iteration: 1994
# quick_sort Theta 0.013034022716310371
# merge_sort Theta 0.00994703121868698
# heap_sort Theta 0.01097107315128231
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015966176986694336
# Sample mean is:  0.009964034194714979 Sample variance is: 0.03270680414580707
#
#
# Iteration: 1995
# quick_sort Theta 0.014119626502223046
# merge_sort Theta 0.009973505133241613
# heap_sort Theta 0.010971061967050175
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014863014221191406
# Sample mean is:  0.009966508427051582 Sample variance is: 0.03270239842571546
#
#
# Iteration: 1996
# quick_sort Theta 0.013078989932822025
# merge_sort Theta 0.009978259449210802
# heap_sort Theta 0.01097107203429042
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015990018844604492
# Sample mean is:  0.00996954906835272 Sample variance is: 0.03270419739742781
#
#
# Iteration: 1997
# quick_sort Theta 0.01487439459978647
# merge_sort Theta 0.009960618230803412
# heap_sort Theta 0.010971070080256695
#
#
# Chosen algorithm is:  merge_sort with reward: 0.014963150024414062
# Sample mean is:  0.009972068544112589 Sample variance is: 0.032700269720423406
#
#
# Iteration: 1998
# quick_sort Theta 0.014825664388543424
# merge_sort Theta 0.009976162638493127
# heap_sort Theta 0.010971039893784774
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015958309173583984
# Sample mean is:  0.009975087324056851 Sample variance is: 0.03270184224111483
#
#
# Iteration: 1999
# quick_sort Theta 0.012678661481019675
# merge_sort Theta 0.009973004806816115
# heap_sort Theta 0.010971058511173222
#
#
# Chosen algorithm is:  merge_sort with reward: 0.015955448150634766
# Sample mean is:  0.009978101618828313 Sample variance is: 0.03270337771605411
# Total reward 20.0011
# Average rewards per algo {'quick_sort': 0.01304434026990618, 'merge_sort': 0.009978101618828313, 'heap_sort': 0.0109710693359375}
# Count per chosen algo {'quick_sort': 14, 'merge_sort': 1984, 'heap_sort': 2}

# %%
plot_history(rewards,cum_rewards, arm_counts)

# %% [markdown]
# ## As we can see little to no expoloration is done, even with the variation multiplier.
