# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import special
from sklearn.datasets import make_blobs
import time
import scipy.stats as stats
from random import choice, shuffle
from string import ascii_lowercase, digits
from datetime import datetime
import random
import timeit

from scipy.stats import beta
from scipy.stats import betabinom, binom

# %%
# Set Parameters
n_samples = 500000
num_bins = 20
length_strings = 3
p=0.5
n_binomial = 100
n_discrete = 10
lambda_param = 4

# %%
def plot_distribution(dist, n_samples, title, num_bins):
    weights = np.ones_like(dist)/float(len(dist))
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))
    fig.suptitle(title,fontsize=20)
    count, bins, ignored = ax1.hist(dist, num_bins, weights=weights)
    #ax1.plot(bins, np.ones_like(bins), linewidth=2, color='r')
    ax1.set_title('Probability Distribution',fontsize=18)
    ax1.set_ylabel('Frequency',fontsize=16)
    ax1.set_xlabel('Value',fontsize=16)
    plt.setp(ax1.get_yticklabels(), fontsize=14)
    plt.setp(ax1.get_xticklabels(), fontsize=14)
    y = np.arange(0,n_samples)
    ax2.scatter(y,dist,s=10)
    ax2.set_title('Sample Values',fontsize=18)
    ax2.set_ylabel('Sample Value',fontsize=16)
    ax2.set_xlabel('Sample Number',fontsize=16)
    plt.setp(ax2.get_xticklabels(), fontsize=14)
    plt.setp(ax2.get_yticklabels(), fontsize=14)

# %%
def poission_distribution(n_samples=n_samples, lambda_param=lambda_param, display = True):
    poission =  np.random.poisson(lambda_param, n_samples)
    if display==True:
        plot_distribution(poission, n_samples, "Poisson Distribution",15)
    return poission
poission = poission_distribution()

# %%
def discrete_binomial_distribution(n_samples=n_samples, p=p, n=n_binomial, display = True):
    discrete_binomial_distribution = binom.rvs(n, p, size=n_samples)
    if display==True:
        plot_distribution(discrete_binomial_distribution, n_samples, "Discrete Binomial Distribution", num_bins)
        
    return discrete_binomial_distribution
discrete_binomial = discrete_binomial_distribution()

# %%
def discrete_uniform_distribution(n_samples=n_samples, n=n_discrete, display = True):
    discrete_uniform_distribution = np.random.randint(n, size=n_samples)
    
    if display == True:
        plot_distribution(discrete_uniform_distribution, n_samples, "Discrete Uniform Distribution", num_bins)
        
    return discrete_uniform_distribution
discrete_uniform = discrete_uniform_distribution()

# %%
def create_dates(n_samples=n_samples):
    sample_dates = pd.date_range(end = datetime.today(), periods = n_samples, freq="30min").to_pydatetime().tolist()
    shuffle(sample_dates)
    return sample_dates
sample_dates = create_dates(n_samples=n_samples)

# %%
sample_dates
# Out:
# [datetime.datetime(2008, 5, 13, 20, 18, 37, 986073),
#  datetime.datetime(2008, 11, 24, 6, 48, 37, 986073),
#  datetime.datetime(1996, 10, 17, 11, 48, 37, 986073),
#  datetime.datetime(2011, 2, 28, 16, 18, 37, 986073),
#  datetime.datetime(2008, 12, 29, 12, 48, 37, 986073),
#  datetime.datetime(2016, 10, 25, 8, 48, 37, 986073),
#  datetime.datetime(1993, 9, 27, 17, 48, 37, 986073),
#  datetime.datetime(2001, 7, 1, 18, 48, 37, 986073),
#  datetime.datetime(2021, 5, 25, 17, 18, 37, 986073),
#  datetime.datetime(2006, 12, 6, 1, 18, 37, 986073),
#  datetime.datetime(2015, 3, 14, 3, 18, 37, 986073),
#  datetime.datetime(2011, 4, 7, 20, 48, 37, 986073),
#  datetime.datetime(2009, 5, 5, 11, 18, 37, 986073),
#  datetime.datetime(2012, 4, 13, 23, 48, 37, 986073),
#  datetime.datetime(2003, 3, 16, 20, 48, 37, 986073),
#  datetime.datetime(1999, 4, 8, 20, 18, 37, 986073),
#  datetime.datetime(1996, 5, 14, 1, 18, 37, 986073),
#  datetime.datetime(1995, 9, 26, 21, 18, 37, 986073),
#  datetime.datetime(2019, 4, 30, 19, 48, 37, 986073),
#  datetime.datetime(2009, 7, 11, 14, 48, 37, 986073),
#  datetime.datetime(1994, 5, 27, 12, 48, 37, 986073),
#  datetime.datetime(2015, 10, 15, 1, 48, 37, 986073),
#  datetime.datetime(1996, 12, 8, 3, 18, 37, 986073),
#  datetime.datetime(2021, 8, 3, 6, 48, 37, 986073),
#  datetime.datetime(2002, 3, 19, 8, 18, 37, 986073),
#  datetime.datetime(2013, 11, 2, 7, 48, 37, 986073),
#  datetime.datetime(1994, 10, 2, 3, 18, 37, 986073),
#  datetime.datetime(2009, 2, 2, 19, 48, 37, 986073),
#  datetime.datetime(2004, 3, 11, 15, 18, 37, 986073),
#  datetime.datetime(2003, 11, 7, 10, 48, 37, 986073),
#  datetime.datetime(2006, 1, 11, 13, 18, 37, 986073),
#  datetime.datetime(2002, 12, 21, 13, 48, 37, 986073),
#  datetime.datetime(2003, 12, 8, 12, 18, 37, 986073),
#  datetime.datetime(1993, 2, 26, 7, 48, 37, 986073),
#  datetime.datetime(2000, 4, 21, 11, 18, 37, 986073),
#  datetime.datetime(2001, 6, 4, 4, 48, 37, 986073),
#  datetime.datetime(1999, 3, 20, 17, 18, 37, 986073),
#  datetime.datetime(2001, 10, 27, 16, 18, 37, 986073),
#  datetime.datetime(2014, 11, 22, 12, 48, 37, 986073),
#  datetime.datetime(2008, 7, 5, 21, 48, 37, 986073),
#  datetime.datetime(2005, 6, 13, 18, 48, 37, 986073),
#  datetime.datetime(2017, 10, 17, 19, 18, 37, 986073),
#  datetime.datetime(2012, 4, 21, 23, 48, 37, 986073),
#  datetime.datetime(2009, 12, 14, 4, 48, 37, 986073),
#  datetime.datetime(2010, 9, 4, 17, 48, 37, 986073),
#  datetime.datetime(2009, 2, 24, 7, 48, 37, 986073),
#  datetime.datetime(2001, 12, 6, 6, 48, 37, 986073),
#  datetime.datetime(2018, 8, 14, 14, 48, 37, 986073),
#  datetime.datetime(2013, 2, 1, 22, 48, 37, 986073),
#  datetime.datetime(2015, 10, 10, 4, 48, 37, 986073),
#  datetime.datetime(1996, 7, 31, 17, 48, 37, 986073),
#  datetime.datetime(2018, 9, 16, 22, 18, 37, 986073),
#  datetime.datetime(2005, 11, 18, 8, 48, 37, 986073),
#  datetime.datetime(2000, 6, 9, 23, 48, 37, 986073),
#  datetime.datetime(2012, 8, 10, 12, 18, 37, 986073),
#  datetime.datetime(2002, 4, 8, 2, 48, 37, 986073),
#  datetime.datetime(2003, 9, 11, 10, 48, 37, 986073),
#  datetime.datetime(2009, 2, 21, 12, 18, 37, 986073),
#  datetime.datetime(2017, 8, 31, 10, 48, 37, 986073),
#  datetime.datetime(2000, 4, 8, 3, 18, 37, 986073),
#  datetime.datetime(2006, 12, 8, 10, 18, 37, 986073),
#  datetime.datetime(2019, 11, 29, 22, 48, 37, 986073),
#  datetime.datetime(1999, 8, 5, 13, 18, 37, 986073),
#  datetime.datetime(1994, 2, 15, 23, 48, 37, 986073),
#  datetime.datetime(2013, 12, 11, 7, 18, 37, 986073),
#  datetime.datetime(2007, 9, 20, 10, 18, 37, 986073),
#  datetime.datetime(2003, 7, 15, 20, 18, 37, 986073),
#  datetime.datetime(2004, 1, 5, 2, 48, 37, 986073),
#  datetime.datetime(1998, 11, 16, 0, 48, 37, 986073),
#  datetime.datetime(1996, 7, 18, 13, 48, 37, 986073),
#  datetime.datetime(2012, 5, 5, 5, 48, 37, 986073),
#  datetime.datetime(1993, 7, 9, 14, 48, 37, 986073),
#  datetime.datetime(1995, 7, 18, 3, 48, 37, 986073),
#  datetime.datetime(2000, 7, 22, 12, 48, 37, 986073),
#  datetime.datetime(1995, 4, 11, 22, 18, 37, 986073),
#  datetime.datetime(2012, 6, 24, 19, 18, 37, 986073),
#  datetime.datetime(2005, 2, 13, 19, 48, 37, 986073),
#  datetime.datetime(2013, 1, 11, 2, 18, 37, 986073),
#  datetime.datetime(2008, 10, 13, 15, 48, 37, 986073),
#  datetime.datetime(2010, 2, 18, 11, 18, 37, 986073),
#  datetime.datetime(2011, 6, 13, 15, 18, 37, 986073),
#  datetime.datetime(2005, 2, 1, 13, 18, 37, 986073),
#  datetime.datetime(2014, 4, 17, 9, 48, 37, 986073),
#  datetime.datetime(1996, 5, 8, 15, 18, 37, 986073),
#  datetime.datetime(2017, 3, 7, 0, 48, 37, 986073),
#  datetime.datetime(2004, 3, 7, 3, 48, 37, 986073),
#  datetime.datetime(2016, 3, 19, 19, 18, 37, 986073),
#  datetime.datetime(1997, 2, 24, 23, 18, 37, 986073),
#  datetime.datetime(2014, 5, 29, 22, 48, 37, 986073),
#  datetime.datetime(1998, 6, 25, 1, 48, 37, 986073),
#  datetime.datetime(1994, 11, 3, 16, 48, 37, 986073),
#  datetime.datetime(2001, 3, 23, 0, 18, 37, 986073),
#  datetime.datetime(2004, 8, 18, 17, 18, 37, 986073),
#  datetime.datetime(1996, 12, 26, 17, 48, 37, 986073),
#  datetime.datetime(1998, 6, 25, 19, 18, 37, 986073),
#  datetime.datetime(2018, 9, 26, 13, 18, 37, 986073),
#  datetime.datetime(2017, 12, 26, 17, 18, 37, 986073),
#  datetime.datetime(1996, 7, 1, 4, 48, 37, 986073),
#  datetime.datetime(1994, 8, 30, 13, 48, 37, 986073),
#  datetime.datetime(2007, 9, 23, 19, 48, 37, 986073),
#  datetime.datetime(2006, 2, 17, 0, 48, 37, 986073),
#  datetime.datetime(2010, 7, 23, 10, 18, 37, 986073),
#  datetime.datetime(2012, 11, 4, 14, 48, 37, 986073),
#  datetime.datetime(2015, 11, 14, 8, 48, 37, 986073),
#  datetime.datetime(2010, 3, 28, 3, 48, 37, 986073),
#  datetime.datetime(2017, 5, 2, 23, 18, 37, 986073),
#  datetime.datetime(2019, 9, 7, 15, 48, 37, 986073),
#  datetime.datetime(2019, 3, 12, 12, 18, 37, 986073),
#  datetime.datetime(2019, 11, 11, 3, 48, 37, 986073),
#  datetime.datetime(2011, 7, 27, 1, 18, 37, 986073),
#  datetime.datetime(2011, 3, 18, 0, 18, 37, 986073),
#  datetime.datetime(2001, 10, 31, 2, 48, 37, 986073),
#  datetime.datetime(2001, 11, 25, 15, 48, 37, 986073),
#  datetime.datetime(2016, 8, 9, 19, 48, 37, 986073),
#  datetime.datetime(2002, 10, 18, 15, 48, 37, 986073),
#  datetime.datetime(2010, 12, 15, 11, 18, 37, 986073),
#  datetime.datetime(2003, 10, 29, 14, 18, 37, 986073),
#  datetime.datetime(1999, 9, 30, 16, 48, 37, 986073),
#  datetime.datetime(2015, 3, 28, 13, 18, 37, 986073),
#  datetime.datetime(1996, 4, 4, 22, 48, 37, 986073),
#  datetime.datetime(2017, 5, 5, 21, 48, 37, 986073),
#  datetime.datetime(2013, 1, 19, 21, 48, 37, 986073),
#  datetime.datetime(1999, 5, 3, 13, 48, 37, 986073),
#  datetime.datetime(1994, 8, 2, 0, 18, 37, 986073),
#  datetime.datetime(1995, 9, 26, 13, 18, 37, 986073),
#  datetime.datetime(1995, 2, 9, 7, 18, 37, 986073),
#  datetime.datetime(1996, 4, 28, 13, 48, 37, 986073),
#  datetime.datetime(2003, 8, 13, 12, 18, 37, 986073),
#  datetime.datetime(2001, 11, 22, 16, 48, 37, 986073),
#  datetime.datetime(2016, 5, 14, 4, 18, 37, 986073),
#  datetime.datetime(2013, 3, 29, 5, 48, 37, 986073),
#  datetime.datetime(1994, 3, 6, 5, 18, 37, 986073),
#  datetime.datetime(2004, 3, 21, 4, 48, 37, 986073),
#  datetime.datetime(2014, 7, 20, 9, 18, 37, 986073),
#  datetime.datetime(2007, 5, 18, 2, 48, 37, 986073),
#  datetime.datetime(2000, 9, 24, 10, 18, 37, 986073),
#  datetime.datetime(2021, 4, 20, 2, 18, 37, 986073),
#  datetime.datetime(1994, 5, 30, 23, 48, 37, 986073),
#  datetime.datetime(2014, 10, 25, 12, 48, 37, 986073),
#  datetime.datetime(2001, 9, 24, 16, 18, 37, 986073),
#  datetime.datetime(1997, 6, 17, 21, 48, 37, 986073),
#  datetime.datetime(2013, 1, 11, 23, 48, 37, 986073),
#  datetime.datetime(2004, 7, 29, 10, 18, 37, 986073),
#  datetime.datetime(2007, 5, 28, 22, 48, 37, 986073),
#  datetime.datetime(2007, 4, 7, 7, 48, 37, 986073),
#  datetime.datetime(2017, 11, 26, 5, 48, 37, 986073),
#  datetime.datetime(1994, 10, 26, 18, 48, 37, 986073),
#  datetime.datetime(2014, 7, 30, 7, 18, 37, 986073),
#  datetime.datetime(2000, 3, 14, 1, 48, 37, 986073),
#  datetime.datetime(1999, 9, 16, 17, 18, 37, 986073),
#  datetime.datetime(2005, 4, 8, 11, 18, 37, 986073),
#  datetime.datetime(2016, 1, 5, 19, 48, 37, 986073),
#  datetime.datetime(1996, 11, 21, 21, 18, 37, 986073),
#  datetime.datetime(2020, 4, 21, 17, 48, 37, 986073),
#  datetime.datetime(2011, 3, 26, 8, 18, 37, 986073),
#  datetime.datetime(2017, 4, 18, 20, 18, 37, 986073),
#  datetime.datetime(2017, 8, 28, 5, 18, 37, 986073),
#  datetime.datetime(2005, 1, 25, 20, 18, 37, 986073),
#  datetime.datetime(2003, 12, 27, 19, 48, 37, 986073),
#  datetime.datetime(2013, 11, 8, 5, 48, 37, 986073),
#  datetime.datetime(2006, 3, 28, 6, 18, 37, 986073),
#  datetime.datetime(2012, 3, 2, 19, 48, 37, 986073),
#  datetime.datetime(2020, 8, 25, 7, 18, 37, 986073),
#  datetime.datetime(2016, 1, 11, 21, 18, 37, 986073),
#  datetime.datetime(2006, 11, 4, 17, 48, 37, 986073),
#  datetime.datetime(1997, 4, 1, 5, 48, 37, 986073),
#  datetime.datetime(2010, 10, 4, 22, 48, 37, 986073),
#  datetime.datetime(2007, 3, 12, 11, 18, 37, 986073),
#  datetime.datetime(2020, 3, 17, 5, 48, 37, 986073),
#  datetime.datetime(2015, 11, 26, 17, 18, 37, 986073),
#  datetime.datetime(2015, 6, 27, 21, 48, 37, 986073),
#  datetime.datetime(1999, 5, 4, 0, 48, 37, 986073),
#  datetime.datetime(1995, 4, 2, 17, 18, 37, 986073),
#  datetime.datetime(2007, 10, 10, 17, 18, 37, 986073),
#  datetime.datetime(2014, 10, 4, 1, 18, 37, 986073),
#  datetime.datetime(2020, 10, 10, 2, 48, 37, 986073),
#  datetime.datetime(2002, 12, 28, 21, 48, 37, 986073),
#  datetime.datetime(1998, 11, 5, 16, 18, 37, 986073),
#  datetime.datetime(1998, 9, 9, 3, 18, 37, 986073),
#  datetime.datetime(2007, 10, 14, 9, 18, 37, 986073),
#  datetime.datetime(2015, 3, 13, 20, 48, 37, 986073),
#  datetime.datetime(2010, 6, 6, 10, 18, 37, 986073),
#  datetime.datetime(2007, 5, 5, 15, 18, 37, 986073),
#  datetime.datetime(2020, 9, 9, 3, 18, 37, 986073),
#  datetime.datetime(1997, 1, 9, 1, 18, 37, 986073),
#  datetime.datetime(2019, 10, 11, 5, 18, 37, 986073),
#  datetime.datetime(2012, 6, 4, 9, 18, 37, 986073),
#  datetime.datetime(2000, 8, 1, 22, 48, 37, 986073),
#  datetime.datetime(1999, 9, 26, 17, 48, 37, 986073),
#  datetime.datetime(2005, 8, 23, 18, 48, 37, 986073),
#  datetime.datetime(2010, 1, 15, 9, 48, 37, 986073),
#  datetime.datetime(2010, 12, 20, 13, 18, 37, 986073),
#  datetime.datetime(1999, 8, 10, 19, 48, 37, 986073),
#  datetime.datetime(1994, 2, 15, 0, 48, 37, 986073),
#  datetime.datetime(1997, 4, 4, 19, 18, 37, 986073),
#  datetime.datetime(1998, 1, 20, 13, 18, 37, 986073),
#  datetime.datetime(2016, 10, 5, 18, 48, 37, 986073),
#  datetime.datetime(2009, 7, 7, 23, 48, 37, 986073),
#  datetime.datetime(2000, 9, 13, 21, 48, 37, 986073),
#  datetime.datetime(2011, 12, 27, 19, 48, 37, 986073),
#  datetime.datetime(2014, 4, 20, 16, 48, 37, 986073),
#  datetime.datetime(1993, 7, 1, 20, 48, 37, 986073),
#  datetime.datetime(2013, 6, 22, 22, 48, 37, 986073),
#  datetime.datetime(2005, 9, 2, 17, 18, 37, 986073),
#  datetime.datetime(1996, 8, 29, 19, 48, 37, 986073),
#  datetime.datetime(2003, 5, 9, 5, 48, 37, 986073),
#  datetime.datetime(2003, 2, 18, 1, 18, 37, 986073),
#  datetime.datetime(2008, 6, 9, 17, 18, 37, 986073),
#  datetime.datetime(2001, 5, 9, 19, 48, 37, 986073),
#  datetime.datetime(1995, 9, 3, 14, 48, 37, 986073),
#  datetime.datetime(2014, 5, 25, 3, 48, 37, 986073),
#  datetime.datetime(2018, 1, 20, 12, 48, 37, 986073),
#  datetime.datetime(2005, 2, 25, 5, 48, 37, 986073),
#  datetime.datetime(2017, 1, 15, 2, 18, 37, 986073),
#  datetime.datetime(1996, 2, 8, 12, 18, 37, 986073),
#  datetime.datetime(1997, 10, 31, 9, 48, 37, 986073),
#  datetime.datetime(2014, 12, 16, 21, 48, 37, 986073),
#  datetime.datetime(2013, 7, 25, 14, 18, 37, 986073),
#  datetime.datetime(2019, 9, 2, 0, 18, 37, 986073),
#  datetime.datetime(1997, 3, 21, 19, 48, 37, 986073),
#  datetime.datetime(2003, 8, 31, 16, 18, 37, 986073),
#  datetime.datetime(2003, 8, 10, 6, 48, 37, 986073),
#  datetime.datetime(2007, 3, 18, 11, 18, 37, 986073),
#  datetime.datetime(1999, 7, 22, 21, 18, 37, 986073),
#  datetime.datetime(2002, 10, 19, 0, 48, 37, 986073),
#  datetime.datetime(1995, 6, 15, 1, 18, 37, 986073),
#  datetime.datetime(2000, 12, 26, 12, 48, 37, 986073),
#  datetime.datetime(2002, 7, 18, 20, 18, 37, 986073),
#  datetime.datetime(2021, 8, 7, 6, 18, 37, 986073),
#  datetime.datetime(2013, 8, 11, 23, 18, 37, 986073),
#  datetime.datetime(1997, 2, 15, 21, 48, 37, 986073),
#  datetime.datetime(2010, 12, 5, 0, 48, 37, 986073),
#  datetime.datetime(1995, 11, 27, 16, 18, 37, 986073),
#  datetime.datetime(2019, 6, 22, 10, 48, 37, 986073),
#  datetime.datetime(2016, 7, 19, 4, 48, 37, 986073),
#  datetime.datetime(1996, 6, 11, 12, 48, 37, 986073),
#  datetime.datetime(2016, 4, 7, 11, 48, 37, 986073),
#  datetime.datetime(2002, 5, 22, 22, 48, 37, 986073),
#  datetime.datetime(2006, 5, 28, 12, 18, 37, 986073),
#  datetime.datetime(1998, 9, 20, 7, 18, 37, 986073),
#  datetime.datetime(2015, 4, 17, 2, 48, 37, 986073),
#  datetime.datetime(2008, 8, 31, 18, 18, 37, 986073),
#  datetime.datetime(2016, 9, 30, 12, 48, 37, 986073),
#  datetime.datetime(2008, 10, 1, 3, 18, 37, 986073),
#  datetime.datetime(2012, 4, 19, 10, 48, 37, 986073),
#  datetime.datetime(2008, 8, 2, 10, 18, 37, 986073),
#  datetime.datetime(2006, 8, 14, 16, 18, 37, 986073),
#  datetime.datetime(2017, 2, 12, 2, 48, 37, 986073),
#  datetime.datetime(2005, 12, 23, 16, 18, 37, 986073),
#  datetime.datetime(2016, 3, 13, 22, 48, 37, 986073),
#  datetime.datetime(1995, 11, 23, 9, 48, 37, 986073),
#  datetime.datetime(1995, 6, 14, 16, 18, 37, 986073),
#  datetime.datetime(2009, 3, 1, 11, 48, 37, 986073),
#  datetime.datetime(1994, 7, 29, 3, 48, 37, 986073),
#  datetime.datetime(2013, 10, 4, 3, 48, 37, 986073),
#  datetime.datetime(2001, 4, 15, 23, 48, 37, 986073),
#  datetime.datetime(2002, 7, 10, 0, 18, 37, 986073),
#  datetime.datetime(2017, 1, 21, 12, 48, 37, 986073),
#  datetime.datetime(2009, 1, 15, 12, 18, 37, 986073),
#  datetime.datetime(2018, 10, 7, 4, 18, 37, 986073),
#  datetime.datetime(1993, 2, 16, 4, 48, 37, 986073),
#  datetime.datetime(2011, 12, 27, 7, 18, 37, 986073),
#  datetime.datetime(2015, 8, 27, 21, 18, 37, 986073),
#  datetime.datetime(2007, 5, 14, 18, 18, 37, 986073),
#  datetime.datetime(1998, 3, 13, 22, 48, 37, 986073),
#  datetime.datetime(2009, 6, 18, 8, 48, 37, 986073),
#  datetime.datetime(2020, 9, 28, 12, 18, 37, 986073),
#  datetime.datetime(1995, 9, 25, 23, 48, 37, 986073),
#  datetime.datetime(2010, 11, 25, 20, 18, 37, 986073),
#  datetime.datetime(1995, 11, 17, 6, 48, 37, 986073),
#  datetime.datetime(2018, 6, 2, 7, 18, 37, 986073),
#  datetime.datetime(1995, 4, 7, 19, 48, 37, 986073),
#  datetime.datetime(2011, 2, 8, 10, 18, 37, 986073),
#  datetime.datetime(2002, 4, 18, 22, 48, 37, 986073),
#  datetime.datetime(2015, 2, 26, 9, 48, 37, 986073),
#  datetime.datetime(2008, 11, 10, 0, 48, 37, 986073),
#  datetime.datetime(2004, 2, 19, 2, 18, 37, 986073),
#  datetime.datetime(2017, 10, 10, 0, 18, 37, 986073),
#  datetime.datetime(1996, 9, 10, 23, 48, 37, 986073),
#  datetime.datetime(2019, 2, 3, 14, 48, 37, 986073),
#  datetime.datetime(2012, 3, 13, 2, 18, 37, 986073),
#  datetime.datetime(2009, 6, 19, 6, 18, 37, 986073),
#  datetime.datetime(2012, 12, 23, 17, 18, 37, 986073),
#  datetime.datetime(2020, 6, 24, 21, 48, 37, 986073),
#  datetime.datetime(2001, 10, 21, 10, 48, 37, 986073),
#  datetime.datetime(2015, 4, 11, 12, 18, 37, 986073),
#  datetime.datetime(2002, 5, 16, 3, 48, 37, 986073),
#  datetime.datetime(1997, 11, 14, 23, 18, 37, 986073),
#  datetime.datetime(2014, 11, 27, 6, 18, 37, 986073),
#  datetime.datetime(2014, 5, 14, 2, 18, 37, 986073),
#  datetime.datetime(2020, 4, 29, 14, 48, 37, 986073),
#  datetime.datetime(2015, 4, 6, 6, 48, 37, 986073),
#  datetime.datetime(2013, 4, 8, 11, 18, 37, 986073),
#  datetime.datetime(2001, 3, 11, 14, 48, 37, 986073),
#  datetime.datetime(2014, 7, 7, 11, 18, 37, 986073),
#  datetime.datetime(1999, 1, 4, 0, 48, 37, 986073),
#  datetime.datetime(2013, 9, 25, 0, 18, 37, 986073),
#  datetime.datetime(2020, 11, 26, 13, 48, 37, 986073),
#  datetime.datetime(1996, 8, 3, 20, 18, 37, 986073),
#  datetime.datetime(2006, 6, 4, 23, 48, 37, 986073),
#  datetime.datetime(1995, 11, 24, 23, 48, 37, 986073),
#  datetime.datetime(2002, 3, 30, 12, 18, 37, 986073),
#  datetime.datetime(2003, 9, 14, 20, 18, 37, 986073),
#  datetime.datetime(1996, 5, 24, 0, 18, 37, 986073),
#  datetime.datetime(2009, 10, 1, 1, 18, 37, 986073),
#  datetime.datetime(2005, 4, 24, 22, 48, 37, 986073),
#  datetime.datetime(2020, 9, 22, 21, 18, 37, 986073),
#  datetime.datetime(2013, 10, 3, 18, 18, 37, 986073),
#  datetime.datetime(1998, 5, 19, 11, 48, 37, 986073),
#  datetime.datetime(1995, 11, 11, 15, 48, 37, 986073),
#  datetime.datetime(2011, 10, 13, 18, 18, 37, 986073),
#  datetime.datetime(1996, 4, 15, 15, 18, 37, 986073),
#  datetime.datetime(2005, 12, 16, 20, 48, 37, 986073),
#  datetime.datetime(2013, 6, 9, 19, 18, 37, 986073),
#  datetime.datetime(2016, 3, 11, 22, 18, 37, 986073),
#  datetime.datetime(1996, 5, 23, 11, 18, 37, 986073),
#  datetime.datetime(2000, 1, 6, 6, 48, 37, 986073),
#  datetime.datetime(2020, 4, 15, 15, 18, 37, 986073),
#  datetime.datetime(2003, 10, 24, 1, 18, 37, 986073),
#  datetime.datetime(2000, 7, 23, 16, 18, 37, 986073),
#  datetime.datetime(2000, 7, 28, 23, 48, 37, 986073),
#  datetime.datetime(2016, 9, 10, 6, 18, 37, 986073),
#  datetime.datetime(2009, 8, 13, 18, 48, 37, 986073),
#  datetime.datetime(2009, 5, 10, 1, 48, 37, 986073),
#  datetime.datetime(1999, 11, 10, 9, 48, 37, 986073),
#  datetime.datetime(1993, 12, 31, 9, 18, 37, 986073),
#  datetime.datetime(2007, 1, 16, 15, 18, 37, 986073),
#  datetime.datetime(2006, 2, 5, 2, 48, 37, 986073),
#  datetime.datetime(1999, 3, 24, 9, 48, 37, 986073),
#  datetime.datetime(2016, 5, 16, 9, 48, 37, 986073),
#  datetime.datetime(2005, 6, 18, 1, 18, 37, 986073),
#  datetime.datetime(1995, 2, 17, 0, 18, 37, 986073),
#  datetime.datetime(2002, 7, 27, 17, 18, 37, 986073),
#  datetime.datetime(2002, 8, 16, 23, 18, 37, 986073),
#  datetime.datetime(2013, 6, 28, 14, 48, 37, 986073),
#  datetime.datetime(2010, 2, 4, 3, 48, 37, 986073),
#  datetime.datetime(2002, 10, 22, 12, 48, 37, 986073),
#  datetime.datetime(1996, 11, 13, 8, 48, 37, 986073),
#  datetime.datetime(1998, 11, 25, 21, 48, 37, 986073),
#  datetime.datetime(1995, 3, 31, 13, 18, 37, 986073),
#  datetime.datetime(2021, 3, 4, 18, 18, 37, 986073),
#  datetime.datetime(2017, 3, 22, 14, 18, 37, 986073),
#  datetime.datetime(2013, 3, 22, 18, 48, 37, 986073),
#  datetime.datetime(2010, 11, 28, 9, 48, 37, 986073),
#  datetime.datetime(2003, 1, 26, 3, 48, 37, 986073),
#  datetime.datetime(2000, 6, 6, 0, 18, 37, 986073),
#  datetime.datetime(2006, 2, 1, 13, 18, 37, 986073),
#  datetime.datetime(1997, 6, 9, 2, 18, 37, 986073),
#  datetime.datetime(1998, 8, 23, 7, 18, 37, 986073),
#  datetime.datetime(2016, 12, 18, 6, 48, 37, 986073),
#  datetime.datetime(2008, 8, 6, 23, 48, 37, 986073),
#  datetime.datetime(2017, 2, 21, 12, 48, 37, 986073),
#  datetime.datetime(2015, 3, 18, 6, 48, 37, 986073),
#  datetime.datetime(1997, 5, 7, 2, 48, 37, 986073),
#  datetime.datetime(2013, 3, 1, 12, 48, 37, 986073),
#  datetime.datetime(2009, 12, 15, 23, 18, 37, 986073),
#  datetime.datetime(2013, 8, 25, 7, 18, 37, 986073),
#  datetime.datetime(2011, 1, 12, 13, 18, 37, 986073),
#  datetime.datetime(2009, 3, 17, 22, 18, 37, 986073),
#  datetime.datetime(2000, 4, 24, 15, 48, 37, 986073),
#  datetime.datetime(2007, 11, 8, 8, 18, 37, 986073),
#  datetime.datetime(2001, 8, 2, 11, 18, 37, 986073),
#  datetime.datetime(2018, 12, 16, 17, 18, 37, 986073),
#  datetime.datetime(1998, 5, 9, 0, 18, 37, 986073),
#  datetime.datetime(2016, 12, 23, 19, 48, 37, 986073),
#  datetime.datetime(2003, 2, 6, 19, 48, 37, 986073),
#  datetime.datetime(1995, 7, 23, 20, 18, 37, 986073),
#  datetime.datetime(2008, 4, 17, 23, 48, 37, 986073),
#  datetime.datetime(2014, 7, 9, 15, 18, 37, 986073),
#  datetime.datetime(2019, 3, 3, 19, 48, 37, 986073),
#  datetime.datetime(2011, 7, 14, 15, 18, 37, 986073),
#  datetime.datetime(1996, 8, 19, 2, 48, 37, 986073),
#  datetime.datetime(2010, 4, 1, 16, 18, 37, 986073),
#  datetime.datetime(1999, 9, 25, 3, 48, 37, 986073),
#  datetime.datetime(2005, 11, 17, 6, 18, 37, 986073),
#  datetime.datetime(1996, 2, 25, 14, 48, 37, 986073),
#  datetime.datetime(2017, 9, 3, 6, 48, 37, 986073),
#  datetime.datetime(2006, 12, 7, 8, 18, 37, 986073),
#  datetime.datetime(2009, 5, 14, 18, 48, 37, 986073),
#  datetime.datetime(2017, 4, 3, 4, 18, 37, 986073),
#  datetime.datetime(2013, 10, 8, 14, 18, 37, 986073),
#  datetime.datetime(1997, 12, 1, 18, 48, 37, 986073),
#  datetime.datetime(1993, 7, 14, 4, 18, 37, 986073),
#  datetime.datetime(2004, 11, 7, 14, 18, 37, 986073),
#  datetime.datetime(1993, 5, 5, 11, 18, 37, 986073),
#  datetime.datetime(2013, 5, 27, 1, 18, 37, 986073),
#  datetime.datetime(2014, 11, 21, 0, 48, 37, 986073),
#  datetime.datetime(2005, 6, 22, 21, 18, 37, 986073),
#  datetime.datetime(1997, 7, 12, 10, 18, 37, 986073),
#  datetime.datetime(1994, 11, 29, 19, 18, 37, 986073),
#  datetime.datetime(2005, 3, 25, 0, 18, 37, 986073),
#  datetime.datetime(2002, 7, 13, 10, 18, 37, 986073),
#  datetime.datetime(2016, 6, 28, 16, 18, 37, 986073),
#  datetime.datetime(2005, 7, 7, 2, 48, 37, 986073),
#  datetime.datetime(2006, 7, 27, 8, 48, 37, 986073),
#  datetime.datetime(2011, 12, 12, 19, 18, 37, 986073),
#  datetime.datetime(2003, 1, 27, 10, 48, 37, 986073),
#  datetime.datetime(2000, 5, 7, 1, 18, 37, 986073),
#  datetime.datetime(2012, 3, 5, 17, 48, 37, 986073),
#  datetime.datetime(2010, 1, 4, 12, 18, 37, 986073),
#  datetime.datetime(2001, 4, 17, 7, 48, 37, 986073),
#  datetime.datetime(2012, 9, 5, 16, 48, 37, 986073),
#  datetime.datetime(2009, 9, 27, 15, 48, 37, 986073),
#  datetime.datetime(1997, 2, 19, 19, 18, 37, 986073),
#  datetime.datetime(2016, 5, 24, 10, 48, 37, 986073),
#  datetime.datetime(1999, 5, 12, 20, 18, 37, 986073),
#  datetime.datetime(2009, 7, 26, 0, 48, 37, 986073),
#  datetime.datetime(2016, 8, 6, 18, 48, 37, 986073),
#  datetime.datetime(2010, 11, 18, 1, 48, 37, 986073),
#  datetime.datetime(1999, 1, 1, 9, 18, 37, 986073),
#  datetime.datetime(2012, 1, 24, 11, 18, 37, 986073),
#  datetime.datetime(2002, 6, 23, 7, 18, 37, 986073),
#  datetime.datetime(1996, 10, 25, 22, 18, 37, 986073),
#  datetime.datetime(2002, 9, 7, 1, 48, 37, 986073),
#  datetime.datetime(2000, 1, 22, 5, 18, 37, 986073),
#  datetime.datetime(1998, 1, 7, 22, 48, 37, 986073),
#  datetime.datetime(2001, 6, 19, 16, 18, 37, 986073),
#  datetime.datetime(2003, 8, 20, 19, 18, 37, 986073),
#  datetime.datetime(2004, 6, 27, 13, 18, 37, 986073),
#  datetime.datetime(1998, 10, 12, 15, 18, 37, 986073),
#  datetime.datetime(2018, 8, 22, 3, 18, 37, 986073),
#  datetime.datetime(2010, 1, 24, 21, 18, 37, 986073),
#  datetime.datetime(1994, 6, 5, 13, 48, 37, 986073),
#  datetime.datetime(1995, 1, 6, 15, 48, 37, 986073),
#  datetime.datetime(2013, 6, 24, 2, 18, 37, 986073),
#  datetime.datetime(1998, 5, 25, 1, 18, 37, 986073),
#  datetime.datetime(2008, 5, 8, 12, 48, 37, 986073),
#  datetime.datetime(2008, 9, 28, 16, 48, 37, 986073),
#  datetime.datetime(1999, 12, 11, 1, 48, 37, 986073),
#  datetime.datetime(2012, 12, 14, 10, 18, 37, 986073),
#  datetime.datetime(2011, 7, 26, 6, 48, 37, 986073),
#  datetime.datetime(2013, 4, 23, 1, 48, 37, 986073),
#  datetime.datetime(2014, 1, 28, 2, 48, 37, 986073),
#  datetime.datetime(2019, 2, 20, 21, 48, 37, 986073),
#  datetime.datetime(1997, 10, 5, 12, 18, 37, 986073),
#  datetime.datetime(2011, 8, 26, 19, 48, 37, 986073),
#  datetime.datetime(2012, 9, 23, 15, 48, 37, 986073),
#  datetime.datetime(2021, 3, 14, 3, 48, 37, 986073),
#  datetime.datetime(2011, 4, 11, 9, 18, 37, 986073),
#  datetime.datetime(2006, 7, 22, 18, 18, 37, 986073),
#  datetime.datetime(2013, 6, 26, 18, 18, 37, 986073),
#  datetime.datetime(2018, 11, 30, 7, 18, 37, 986073),
#  datetime.datetime(1996, 6, 21, 23, 18, 37, 986073),
#  datetime.datetime(2014, 1, 10, 1, 18, 37, 986073),
#  datetime.datetime(2009, 7, 20, 11, 18, 37, 986073),
#  datetime.datetime(2001, 2, 4, 4, 18, 37, 986073),
#  datetime.datetime(1994, 4, 22, 9, 48, 37, 986073),
#  datetime.datetime(2011, 10, 4, 20, 48, 37, 986073),
#  datetime.datetime(1993, 12, 18, 15, 48, 37, 986073),
#  datetime.datetime(2005, 9, 12, 1, 48, 37, 986073),
#  datetime.datetime(2000, 10, 6, 16, 18, 37, 986073),
#  datetime.datetime(2017, 2, 28, 12, 18, 37, 986073),
#  datetime.datetime(2015, 12, 8, 5, 18, 37, 986073),
#  datetime.datetime(2020, 11, 30, 21, 18, 37, 986073),
#  datetime.datetime(2008, 11, 12, 6, 18, 37, 986073),
#  datetime.datetime(2007, 12, 22, 4, 48, 37, 986073),
#  datetime.datetime(2006, 12, 30, 13, 18, 37, 986073),
#  datetime.datetime(2018, 6, 13, 22, 48, 37, 986073),
#  datetime.datetime(2020, 8, 15, 17, 18, 37, 986073),
#  datetime.datetime(2002, 4, 12, 14, 48, 37, 986073),
#  datetime.datetime(2001, 8, 28, 10, 48, 37, 986073),
#  datetime.datetime(1994, 12, 27, 12, 18, 37, 986073),
#  datetime.datetime(2017, 3, 13, 5, 48, 37, 986073),
#  datetime.datetime(2017, 4, 24, 2, 48, 37, 986073),
#  datetime.datetime(1998, 2, 7, 23, 18, 37, 986073),
#  datetime.datetime(2003, 7, 28, 9, 48, 37, 986073),
#  datetime.datetime(1994, 4, 22, 23, 18, 37, 986073),
#  datetime.datetime(2011, 9, 4, 14, 18, 37, 986073),
#  datetime.datetime(1995, 1, 18, 3, 18, 37, 986073),
#  datetime.datetime(2000, 6, 24, 11, 48, 37, 986073),
#  datetime.datetime(2009, 1, 25, 17, 48, 37, 986073),
#  datetime.datetime(2014, 10, 14, 15, 48, 37, 986073),
#  datetime.datetime(2010, 11, 2, 13, 18, 37, 986073),
#  datetime.datetime(2016, 10, 15, 4, 48, 37, 986073),
#  datetime.datetime(2008, 11, 28, 18, 48, 37, 986073),
#  datetime.datetime(2012, 1, 31, 19, 48, 37, 986073),
#  datetime.datetime(2006, 3, 24, 16, 18, 37, 986073),
#  datetime.datetime(2005, 7, 19, 0, 48, 37, 986073),
#  datetime.datetime(1995, 2, 9, 1, 48, 37, 986073),
#  datetime.datetime(2005, 1, 13, 8, 18, 37, 986073),
#  datetime.datetime(1998, 7, 26, 20, 48, 37, 986073),
#  datetime.datetime(1997, 2, 22, 17, 18, 37, 986073),
#  datetime.datetime(2002, 7, 5, 6, 48, 37, 986073),
#  datetime.datetime(2003, 12, 16, 10, 48, 37, 986073),
#  datetime.datetime(1999, 11, 14, 13, 18, 37, 986073),
#  datetime.datetime(2021, 2, 9, 14, 48, 37, 986073),
#  datetime.datetime(2002, 9, 17, 17, 48, 37, 986073),
#  datetime.datetime(2009, 10, 28, 12, 48, 37, 986073),
#  datetime.datetime(1999, 2, 16, 13, 48, 37, 986073),
#  datetime.datetime(2007, 10, 11, 2, 18, 37, 986073),
#  datetime.datetime(2010, 7, 27, 4, 48, 37, 986073),
#  datetime.datetime(2013, 1, 16, 23, 48, 37, 986073),
#  datetime.datetime(2007, 11, 4, 23, 18, 37, 986073),
#  datetime.datetime(2012, 7, 12, 5, 48, 37, 986073),
#  datetime.datetime(2011, 9, 6, 11, 48, 37, 986073),
#  datetime.datetime(2012, 9, 20, 16, 18, 37, 986073),
#  datetime.datetime(2004, 6, 21, 21, 18, 37, 986073),
#  datetime.datetime(2010, 6, 8, 13, 48, 37, 986073),
#  datetime.datetime(1998, 10, 14, 3, 48, 37, 986073),
#  datetime.datetime(2006, 7, 23, 12, 48, 37, 986073),
#  datetime.datetime(1998, 4, 15, 10, 18, 37, 986073),
#  datetime.datetime(2003, 7, 5, 17, 48, 37, 986073),
#  datetime.datetime(2007, 3, 28, 4, 48, 37, 986073),
#  datetime.datetime(1994, 12, 14, 15, 18, 37, 986073),
#  datetime.datetime(2005, 2, 8, 22, 18, 37, 986073),
#  datetime.datetime(2001, 12, 29, 22, 48, 37, 986073),
#  datetime.datetime(2014, 12, 19, 0, 48, 37, 986073),
#  datetime.datetime(2008, 5, 5, 15, 18, 37, 986073),
#  datetime.datetime(1998, 1, 8, 1, 18, 37, 986073),
#  datetime.datetime(2006, 8, 28, 4, 18, 37, 986073),
#  datetime.datetime(2011, 10, 17, 21, 18, 37, 986073),
#  datetime.datetime(2015, 7, 14, 17, 48, 37, 986073),
#  datetime.datetime(2019, 3, 20, 15, 18, 37, 986073),
#  datetime.datetime(2013, 2, 11, 6, 48, 37, 986073),
#  datetime.datetime(2003, 1, 27, 2, 18, 37, 986073),
#  datetime.datetime(2000, 10, 7, 19, 18, 37, 986073),
#  datetime.datetime(1998, 8, 13, 21, 18, 37, 986073),
#  datetime.datetime(2007, 1, 4, 21, 18, 37, 986073),
#  datetime.datetime(2004, 11, 28, 18, 48, 37, 986073),
#  datetime.datetime(1998, 5, 4, 7, 48, 37, 986073),
#  datetime.datetime(2010, 10, 6, 19, 18, 37, 986073),
#  datetime.datetime(1998, 6, 22, 8, 18, 37, 986073),
#  datetime.datetime(2011, 11, 25, 9, 48, 37, 986073),
#  datetime.datetime(2015, 9, 21, 1, 18, 37, 986073),
#  datetime.datetime(1994, 9, 5, 23, 18, 37, 986073),
#  datetime.datetime(1994, 1, 13, 6, 48, 37, 986073),
#  datetime.datetime(2021, 3, 8, 2, 48, 37, 986073),
#  datetime.datetime(1999, 4, 4, 15, 18, 37, 986073),
#  datetime.datetime(2008, 8, 11, 16, 48, 37, 986073),
#  datetime.datetime(2002, 4, 3, 4, 18, 37, 986073),
#  datetime.datetime(2017, 2, 25, 20, 18, 37, 986073),
#  datetime.datetime(1994, 7, 15, 9, 18, 37, 986073),
#  datetime.datetime(2017, 1, 20, 19, 18, 37, 986073),
#  datetime.datetime(2005, 6, 22, 12, 18, 37, 986073),
#  datetime.datetime(1996, 3, 15, 2, 48, 37, 986073),
#  datetime.datetime(2015, 3, 31, 7, 48, 37, 986073),
#  datetime.datetime(1998, 6, 12, 22, 48, 37, 986073),
#  datetime.datetime(1999, 10, 20, 20, 18, 37, 986073),
#  datetime.datetime(2002, 11, 11, 5, 48, 37, 986073),
#  datetime.datetime(2019, 4, 19, 14, 18, 37, 986073),
#  datetime.datetime(1993, 5, 28, 2, 18, 37, 986073),
#  datetime.datetime(2003, 10, 5, 17, 48, 37, 986073),
#  datetime.datetime(2006, 3, 5, 14, 48, 37, 986073),
#  datetime.datetime(2000, 12, 16, 5, 48, 37, 986073),
#  datetime.datetime(1999, 11, 22, 19, 18, 37, 986073),
#  datetime.datetime(2020, 12, 15, 9, 48, 37, 986073),
#  datetime.datetime(2009, 5, 28, 14, 18, 37, 986073),
#  datetime.datetime(2010, 4, 13, 4, 48, 37, 986073),
#  datetime.datetime(2012, 1, 3, 4, 48, 37, 986073),
#  datetime.datetime(2010, 5, 22, 16, 18, 37, 986073),
#  datetime.datetime(2020, 11, 19, 4, 48, 37, 986073),
#  datetime.datetime(2016, 3, 28, 8, 48, 37, 986073),
#  datetime.datetime(2003, 5, 24, 18, 48, 37, 986073),
#  datetime.datetime(2014, 2, 3, 8, 48, 37, 986073),
#  datetime.datetime(2014, 10, 7, 1, 18, 37, 986073),
#  datetime.datetime(2008, 11, 14, 20, 18, 37, 986073),
#  datetime.datetime(2019, 9, 19, 20, 18, 37, 986073),
#  datetime.datetime(2015, 5, 8, 0, 18, 37, 986073),
#  datetime.datetime(2005, 6, 27, 4, 48, 37, 986073),
#  datetime.datetime(2007, 3, 7, 17, 18, 37, 986073),
#  datetime.datetime(1995, 6, 30, 20, 18, 37, 986073),
#  datetime.datetime(1997, 12, 22, 13, 48, 37, 986073),
#  datetime.datetime(2011, 7, 9, 16, 18, 37, 986073),
#  datetime.datetime(2019, 11, 20, 4, 48, 37, 986073),
#  datetime.datetime(1994, 9, 7, 17, 18, 37, 986073),
#  datetime.datetime(2011, 10, 1, 3, 18, 37, 986073),
#  datetime.datetime(2002, 8, 4, 6, 48, 37, 986073),
#  datetime.datetime(1994, 10, 2, 9, 48, 37, 986073),
#  datetime.datetime(2014, 10, 19, 15, 18, 37, 986073),
#  datetime.datetime(1995, 10, 10, 18, 48, 37, 986073),
#  datetime.datetime(2000, 5, 6, 12, 48, 37, 986073),
#  datetime.datetime(1996, 5, 12, 2, 48, 37, 986073),
#  datetime.datetime(1999, 12, 23, 4, 18, 37, 986073),
#  datetime.datetime(1996, 12, 21, 14, 18, 37, 986073),
#  datetime.datetime(1999, 6, 7, 13, 48, 37, 986073),
#  datetime.datetime(1993, 2, 15, 16, 48, 37, 986073),
#  datetime.datetime(2016, 6, 24, 5, 18, 37, 986073),
#  datetime.datetime(2000, 12, 29, 2, 48, 37, 986073),
#  datetime.datetime(1996, 12, 9, 19, 48, 37, 986073),
#  datetime.datetime(2014, 6, 25, 16, 18, 37, 986073),
#  datetime.datetime(2007, 1, 7, 4, 48, 37, 986073),
#  datetime.datetime(1997, 5, 28, 21, 48, 37, 986073),
#  datetime.datetime(2013, 2, 26, 7, 18, 37, 986073),
#  datetime.datetime(2001, 3, 22, 0, 18, 37, 986073),
#  datetime.datetime(2009, 4, 27, 22, 18, 37, 986073),
#  datetime.datetime(2004, 11, 22, 9, 48, 37, 986073),
#  datetime.datetime(2008, 6, 28, 11, 48, 37, 986073),
#  datetime.datetime(1997, 11, 24, 14, 48, 37, 986073),
#  datetime.datetime(2014, 8, 15, 22, 48, 37, 986073),
#  datetime.datetime(2016, 12, 5, 13, 18, 37, 986073),
#  datetime.datetime(2010, 12, 9, 8, 48, 37, 986073),
#  datetime.datetime(1993, 7, 20, 1, 18, 37, 986073),
#  datetime.datetime(2004, 10, 15, 1, 48, 37, 986073),
#  datetime.datetime(1994, 4, 5, 2, 48, 37, 986073),
#  datetime.datetime(1993, 3, 24, 8, 18, 37, 986073),
#  datetime.datetime(1995, 12, 14, 14, 48, 37, 986073),
#  datetime.datetime(2007, 3, 30, 9, 48, 37, 986073),
#  datetime.datetime(2001, 6, 27, 11, 18, 37, 986073),
#  datetime.datetime(2018, 8, 4, 21, 18, 37, 986073),
#  datetime.datetime(2000, 2, 24, 13, 18, 37, 986073),
#  datetime.datetime(2012, 3, 31, 10, 18, 37, 986073),
#  datetime.datetime(2004, 5, 20, 18, 48, 37, 986073),
#  datetime.datetime(1999, 2, 7, 4, 18, 37, 986073),
#  datetime.datetime(2020, 12, 2, 17, 18, 37, 986073),
#  datetime.datetime(2002, 3, 30, 12, 48, 37, 986073),
#  datetime.datetime(2015, 5, 6, 14, 18, 37, 986073),
#  datetime.datetime(1994, 7, 16, 0, 18, 37, 986073),
#  datetime.datetime(2003, 9, 30, 16, 18, 37, 986073),
#  datetime.datetime(2008, 7, 6, 8, 18, 37, 986073),
#  datetime.datetime(2017, 2, 10, 2, 18, 37, 986073),
#  datetime.datetime(2000, 10, 21, 21, 18, 37, 986073),
#  datetime.datetime(2021, 2, 9, 9, 48, 37, 986073),
#  datetime.datetime(1999, 11, 16, 6, 48, 37, 986073),
#  datetime.datetime(2010, 10, 20, 10, 18, 37, 986073),
#  datetime.datetime(2007, 11, 15, 20, 48, 37, 986073),
#  datetime.datetime(2008, 5, 12, 0, 18, 37, 986073),
#  datetime.datetime(1997, 3, 18, 17, 48, 37, 986073),
#  datetime.datetime(2012, 9, 9, 3, 18, 37, 986073),
#  datetime.datetime(2015, 6, 11, 15, 48, 37, 986073),
#  datetime.datetime(2018, 2, 28, 1, 18, 37, 986073),
#  datetime.datetime(2015, 1, 1, 6, 18, 37, 986073),
#  datetime.datetime(2000, 8, 7, 1, 48, 37, 986073),
#  datetime.datetime(2001, 5, 15, 12, 48, 37, 986073),
#  datetime.datetime(2017, 5, 26, 13, 18, 37, 986073),
#  datetime.datetime(2000, 7, 1, 20, 18, 37, 986073),
#  datetime.datetime(2004, 2, 19, 15, 48, 37, 986073),
#  datetime.datetime(2007, 7, 26, 11, 48, 37, 986073),
#  datetime.datetime(2005, 8, 27, 8, 48, 37, 986073),
#  datetime.datetime(2016, 4, 22, 18, 18, 37, 986073),
#  datetime.datetime(2002, 10, 5, 12, 18, 37, 986073),
#  datetime.datetime(2003, 2, 20, 13, 18, 37, 986073),
#  datetime.datetime(2006, 6, 26, 18, 48, 37, 986073),
#  datetime.datetime(2011, 9, 4, 15, 48, 37, 986073),
#  datetime.datetime(2006, 3, 26, 6, 18, 37, 986073),
#  datetime.datetime(1999, 9, 20, 6, 18, 37, 986073),
#  datetime.datetime(2010, 5, 29, 9, 18, 37, 986073),
#  datetime.datetime(2019, 12, 24, 16, 48, 37, 986073),
#  datetime.datetime(2004, 1, 27, 11, 18, 37, 986073),
#  datetime.datetime(1993, 3, 27, 5, 18, 37, 986073),
#  datetime.datetime(1998, 6, 26, 3, 18, 37, 986073),
#  datetime.datetime(2019, 12, 20, 4, 18, 37, 986073),
#  datetime.datetime(1993, 11, 7, 14, 48, 37, 986073),
#  datetime.datetime(2010, 5, 30, 20, 18, 37, 986073),
#  datetime.datetime(2012, 10, 25, 21, 18, 37, 986073),
#  datetime.datetime(2000, 8, 26, 10, 18, 37, 986073),
#  datetime.datetime(2017, 8, 4, 16, 18, 37, 986073),
#  datetime.datetime(1996, 12, 15, 23, 18, 37, 986073),
#  datetime.datetime(2011, 12, 16, 10, 48, 37, 986073),
#  datetime.datetime(2007, 10, 27, 4, 48, 37, 986073),
#  datetime.datetime(2009, 3, 4, 13, 18, 37, 986073),
#  datetime.datetime(1994, 5, 26, 17, 18, 37, 986073),
#  datetime.datetime(2013, 11, 13, 18, 48, 37, 986073),
#  datetime.datetime(2003, 4, 3, 14, 18, 37, 986073),
#  datetime.datetime(2002, 6, 29, 14, 18, 37, 986073),
#  datetime.datetime(2020, 4, 23, 19, 48, 37, 986073),
#  datetime.datetime(2006, 1, 21, 23, 18, 37, 986073),
#  datetime.datetime(2004, 11, 12, 18, 48, 37, 986073),
#  datetime.datetime(2015, 4, 21, 8, 48, 37, 986073),
#  datetime.datetime(2010, 12, 12, 15, 48, 37, 986073),
#  datetime.datetime(1998, 7, 16, 11, 18, 37, 986073),
#  datetime.datetime(2003, 12, 15, 15, 18, 37, 986073),
#  datetime.datetime(2004, 2, 5, 7, 48, 37, 986073),
#  datetime.datetime(2001, 6, 18, 14, 48, 37, 986073),
#  datetime.datetime(1997, 4, 22, 12, 18, 37, 986073),
#  datetime.datetime(2017, 3, 14, 13, 48, 37, 986073),
#  datetime.datetime(2012, 4, 30, 20, 18, 37, 986073),
#  datetime.datetime(1993, 11, 28, 8, 48, 37, 986073),
#  datetime.datetime(2009, 9, 8, 12, 48, 37, 986073),
#  datetime.datetime(2002, 7, 25, 2, 48, 37, 986073),
#  datetime.datetime(2001, 11, 2, 2, 18, 37, 986073),
#  datetime.datetime(2003, 7, 15, 6, 18, 37, 986073),
#  datetime.datetime(2000, 4, 13, 1, 18, 37, 986073),
#  datetime.datetime(2011, 9, 20, 15, 18, 37, 986073),
#  datetime.datetime(2005, 4, 23, 22, 18, 37, 986073),
#  datetime.datetime(1999, 9, 23, 21, 18, 37, 986073),
#  datetime.datetime(2011, 12, 5, 15, 48, 37, 986073),
#  datetime.datetime(1993, 3, 31, 13, 18, 37, 986073),
#  datetime.datetime(1999, 1, 21, 23, 18, 37, 986073),
#  datetime.datetime(1996, 11, 29, 11, 48, 37, 986073),
#  datetime.datetime(2004, 6, 10, 11, 18, 37, 986073),
#  datetime.datetime(2010, 9, 21, 9, 48, 37, 986073),
#  datetime.datetime(1996, 10, 7, 4, 48, 37, 986073),
#  datetime.datetime(2015, 7, 6, 17, 48, 37, 986073),
#  datetime.datetime(1993, 4, 8, 17, 48, 37, 986073),
#  datetime.datetime(2019, 6, 21, 22, 18, 37, 986073),
#  datetime.datetime(2013, 7, 29, 18, 48, 37, 986073),
#  datetime.datetime(2018, 8, 2, 13, 18, 37, 986073),
#  datetime.datetime(2000, 10, 21, 20, 48, 37, 986073),
#  datetime.datetime(2001, 4, 13, 8, 18, 37, 986073),
#  datetime.datetime(2014, 7, 17, 22, 48, 37, 986073),
#  datetime.datetime(2012, 11, 7, 19, 18, 37, 986073),
#  datetime.datetime(2020, 10, 5, 15, 18, 37, 986073),
#  datetime.datetime(1998, 11, 5, 12, 48, 37, 986073),
#  datetime.datetime(1999, 3, 20, 16, 48, 37, 986073),
#  datetime.datetime(2006, 5, 9, 23, 48, 37, 986073),
#  datetime.datetime(2018, 7, 23, 10, 18, 37, 986073),
#  datetime.datetime(2015, 4, 5, 4, 18, 37, 986073),
#  datetime.datetime(2001, 5, 26, 7, 18, 37, 986073),
#  datetime.datetime(1994, 4, 24, 11, 48, 37, 986073),
#  datetime.datetime(1996, 10, 27, 19, 18, 37, 986073),
#  datetime.datetime(2007, 5, 1, 20, 48, 37, 986073),
#  datetime.datetime(2012, 6, 16, 10, 48, 37, 986073),
#  datetime.datetime(2013, 7, 11, 22, 48, 37, 986073),
#  datetime.datetime(2008, 4, 22, 15, 48, 37, 986073),
#  datetime.datetime(2021, 4, 10, 8, 18, 37, 986073),
#  datetime.datetime(2010, 1, 17, 6, 48, 37, 986073),
#  datetime.datetime(2002, 6, 25, 4, 48, 37, 986073),
#  datetime.datetime(1996, 8, 20, 3, 18, 37, 986073),
#  datetime.datetime(2003, 7, 1, 14, 18, 37, 986073),
#  datetime.datetime(2008, 10, 11, 10, 18, 37, 986073),
#  datetime.datetime(2003, 3, 15, 12, 48, 37, 986073),
#  datetime.datetime(2013, 12, 3, 14, 18, 37, 986073),
#  datetime.datetime(2009, 7, 11, 5, 18, 37, 986073),
#  datetime.datetime(2013, 12, 19, 8, 18, 37, 986073),
#  datetime.datetime(2012, 9, 1, 2, 18, 37, 986073),
#  datetime.datetime(2012, 5, 9, 7, 18, 37, 986073),
#  datetime.datetime(2013, 4, 9, 9, 18, 37, 986073),
#  datetime.datetime(2007, 10, 23, 1, 48, 37, 986073),
#  datetime.datetime(1998, 11, 12, 22, 48, 37, 986073),
#  datetime.datetime(2007, 12, 15, 18, 48, 37, 986073),
#  datetime.datetime(2015, 10, 31, 23, 48, 37, 986073),
#  datetime.datetime(2000, 3, 30, 13, 18, 37, 986073),
#  datetime.datetime(2013, 10, 27, 6, 18, 37, 986073),
#  datetime.datetime(2017, 12, 25, 2, 18, 37, 986073),
#  datetime.datetime(2013, 5, 13, 2, 18, 37, 986073),
#  datetime.datetime(1999, 1, 28, 13, 48, 37, 986073),
#  datetime.datetime(2019, 4, 4, 3, 18, 37, 986073),
#  datetime.datetime(2020, 6, 2, 10, 18, 37, 986073),
#  datetime.datetime(2020, 8, 27, 14, 48, 37, 986073),
#  datetime.datetime(2018, 7, 31, 2, 48, 37, 986073),
#  datetime.datetime(1998, 6, 2, 6, 18, 37, 986073),
#  datetime.datetime(2010, 7, 1, 10, 18, 37, 986073),
#  datetime.datetime(1996, 11, 25, 14, 18, 37, 986073),
#  datetime.datetime(2021, 7, 6, 6, 48, 37, 986073),
#  datetime.datetime(2007, 12, 10, 4, 48, 37, 986073),
#  datetime.datetime(1994, 1, 24, 20, 48, 37, 986073),
#  datetime.datetime(2001, 12, 17, 11, 48, 37, 986073),
#  datetime.datetime(2018, 1, 21, 10, 48, 37, 986073),
#  datetime.datetime(2018, 5, 20, 9, 48, 37, 986073),
#  datetime.datetime(2007, 2, 28, 13, 48, 37, 986073),
#  datetime.datetime(1996, 10, 6, 11, 18, 37, 986073),
#  datetime.datetime(2000, 4, 14, 23, 48, 37, 986073),
#  datetime.datetime(2020, 5, 21, 15, 48, 37, 986073),
#  datetime.datetime(2020, 4, 10, 9, 48, 37, 986073),
#  datetime.datetime(2011, 6, 2, 14, 48, 37, 986073),
#  datetime.datetime(2012, 2, 29, 14, 18, 37, 986073),
#  datetime.datetime(2001, 3, 13, 5, 48, 37, 986073),
#  datetime.datetime(2005, 2, 16, 11, 48, 37, 986073),
#  datetime.datetime(2000, 4, 8, 10, 18, 37, 986073),
#  datetime.datetime(2003, 11, 21, 9, 48, 37, 986073),
#  datetime.datetime(2014, 10, 16, 5, 48, 37, 986073),
#  datetime.datetime(1999, 8, 15, 19, 18, 37, 986073),
#  datetime.datetime(2008, 5, 22, 0, 48, 37, 986073),
#  datetime.datetime(2021, 5, 13, 20, 18, 37, 986073),
#  datetime.datetime(1996, 4, 15, 1, 48, 37, 986073),
#  datetime.datetime(2021, 6, 19, 5, 48, 37, 986073),
#  datetime.datetime(1995, 1, 2, 7, 18, 37, 986073),
#  datetime.datetime(1994, 7, 3, 3, 18, 37, 986073),
#  datetime.datetime(2021, 4, 7, 4, 18, 37, 986073),
#  datetime.datetime(2021, 1, 8, 20, 48, 37, 986073),
#  datetime.datetime(2003, 7, 25, 21, 18, 37, 986073),
#  datetime.datetime(1995, 1, 19, 4, 48, 37, 986073),
#  datetime.datetime(2007, 6, 13, 6, 18, 37, 986073),
#  datetime.datetime(2001, 7, 19, 11, 48, 37, 986073),
#  datetime.datetime(2003, 12, 13, 6, 18, 37, 986073),
#  datetime.datetime(2004, 1, 10, 18, 48, 37, 986073),
#  datetime.datetime(2015, 7, 5, 1, 48, 37, 986073),
#  datetime.datetime(2011, 12, 29, 20, 48, 37, 986073),
#  datetime.datetime(2007, 2, 6, 13, 48, 37, 986073),
#  datetime.datetime(2015, 8, 12, 18, 48, 37, 986073),
#  datetime.datetime(2013, 7, 26, 19, 18, 37, 986073),
#  datetime.datetime(2015, 12, 6, 11, 48, 37, 986073),
#  datetime.datetime(2012, 12, 10, 12, 48, 37, 986073),
#  datetime.datetime(2017, 9, 18, 16, 48, 37, 986073),
#  datetime.datetime(2001, 7, 5, 3, 48, 37, 986073),
#  datetime.datetime(1997, 3, 23, 8, 18, 37, 986073),
#  datetime.datetime(2020, 5, 17, 13, 48, 37, 986073),
#  datetime.datetime(2011, 6, 13, 22, 18, 37, 986073),
#  datetime.datetime(2015, 12, 5, 12, 18, 37, 986073),
#  datetime.datetime(2014, 9, 21, 4, 48, 37, 986073),
#  datetime.datetime(2004, 7, 29, 2, 18, 37, 986073),
#  datetime.datetime(2011, 2, 21, 9, 48, 37, 986073),
#  datetime.datetime(1998, 10, 10, 15, 48, 37, 986073),
#  datetime.datetime(1994, 2, 18, 23, 18, 37, 986073),
#  datetime.datetime(2018, 12, 28, 23, 18, 37, 986073),
#  datetime.datetime(2015, 6, 9, 5, 48, 37, 986073),
#  datetime.datetime(2018, 9, 11, 17, 48, 37, 986073),
#  datetime.datetime(1999, 12, 31, 15, 18, 37, 986073),
#  datetime.datetime(2020, 1, 4, 11, 18, 37, 986073),
#  datetime.datetime(1999, 6, 8, 19, 18, 37, 986073),
#  datetime.datetime(2014, 12, 4, 7, 48, 37, 986073),
#  datetime.datetime(1994, 8, 13, 0, 18, 37, 986073),
#  datetime.datetime(2021, 7, 14, 7, 48, 37, 986073),
#  datetime.datetime(1994, 1, 4, 14, 18, 37, 986073),
#  datetime.datetime(2003, 3, 20, 22, 48, 37, 986073),
#  datetime.datetime(2014, 2, 7, 16, 48, 37, 986073),
#  datetime.datetime(1997, 5, 23, 0, 18, 37, 986073),
#  datetime.datetime(2000, 7, 1, 22, 18, 37, 986073),
#  datetime.datetime(2021, 1, 30, 18, 18, 37, 986073),
#  datetime.datetime(2019, 12, 31, 19, 18, 37, 986073),
#  datetime.datetime(2003, 4, 4, 22, 18, 37, 986073),
#  datetime.datetime(2012, 5, 14, 13, 18, 37, 986073),
#  datetime.datetime(2014, 8, 24, 0, 48, 37, 986073),
#  datetime.datetime(1995, 9, 27, 22, 18, 37, 986073),
#  datetime.datetime(1997, 5, 6, 18, 18, 37, 986073),
#  datetime.datetime(2013, 8, 3, 4, 48, 37, 986073),
#  datetime.datetime(2006, 6, 7, 18, 18, 37, 986073),
#  datetime.datetime(2014, 6, 25, 12, 48, 37, 986073),
#  datetime.datetime(2007, 4, 18, 22, 48, 37, 986073),
#  datetime.datetime(2009, 8, 16, 12, 48, 37, 986073),
#  datetime.datetime(2021, 5, 22, 8, 48, 37, 986073),
#  datetime.datetime(1995, 1, 31, 22, 48, 37, 986073),
#  datetime.datetime(2000, 3, 8, 5, 48, 37, 986073),
#  datetime.datetime(2011, 9, 4, 11, 48, 37, 986073),
#  datetime.datetime(2002, 4, 30, 1, 48, 37, 986073),
#  datetime.datetime(2000, 7, 10, 7, 18, 37, 986073),
#  datetime.datetime(2020, 1, 11, 18, 18, 37, 986073),
#  datetime.datetime(2010, 10, 23, 12, 18, 37, 986073),
#  datetime.datetime(1993, 9, 18, 16, 18, 37, 986073),
#  datetime.datetime(2016, 9, 10, 2, 48, 37, 986073),
#  datetime.datetime(2003, 2, 24, 22, 48, 37, 986073),
#  datetime.datetime(2014, 3, 9, 2, 18, 37, 986073),
#  datetime.datetime(2013, 6, 13, 11, 48, 37, 986073),
#  datetime.datetime(2019, 2, 14, 13, 48, 37, 986073),
#  datetime.datetime(1998, 12, 27, 15, 48, 37, 986073),
#  datetime.datetime(2021, 6, 18, 12, 18, 37, 986073),
#  datetime.datetime(2006, 1, 30, 20, 48, 37, 986073),
#  datetime.datetime(1999, 9, 6, 6, 18, 37, 986073),
#  datetime.datetime(2017, 9, 30, 16, 48, 37, 986073),
#  datetime.datetime(2020, 6, 1, 5, 18, 37, 986073),
#  datetime.datetime(2004, 11, 24, 14, 48, 37, 986073),
#  datetime.datetime(2013, 10, 22, 7, 48, 37, 986073),
#  datetime.datetime(1996, 9, 8, 2, 18, 37, 986073),
#  datetime.datetime(2014, 2, 13, 14, 18, 37, 986073),
#  datetime.datetime(2000, 11, 4, 15, 18, 37, 986073),
#  datetime.datetime(2010, 12, 21, 7, 48, 37, 986073),
#  datetime.datetime(2020, 12, 19, 12, 48, 37, 986073),
#  datetime.datetime(1999, 4, 26, 18, 18, 37, 986073),
#  datetime.datetime(2003, 8, 24, 2, 48, 37, 986073),
#  datetime.datetime(2003, 3, 14, 8, 18, 37, 986073),
#  datetime.datetime(2010, 10, 5, 7, 18, 37, 986073),
#  datetime.datetime(2002, 4, 2, 2, 18, 37, 986073),
#  datetime.datetime(2011, 8, 3, 1, 48, 37, 986073),
#  datetime.datetime(2007, 10, 3, 18, 48, 37, 986073),
#  datetime.datetime(2008, 12, 8, 3, 48, 37, 986073),
#  datetime.datetime(2002, 9, 30, 22, 18, 37, 986073),
#  datetime.datetime(2010, 3, 8, 17, 48, 37, 986073),
#  datetime.datetime(2014, 2, 11, 14, 18, 37, 986073),
#  datetime.datetime(1994, 10, 9, 14, 18, 37, 986073),
#  datetime.datetime(2020, 3, 13, 8, 18, 37, 986073),
#  datetime.datetime(2001, 12, 10, 8, 48, 37, 986073),
#  datetime.datetime(2019, 11, 28, 1, 18, 37, 986073),
#  datetime.datetime(1996, 4, 19, 20, 48, 37, 986073),
#  datetime.datetime(2014, 3, 24, 2, 18, 37, 986073),
#  datetime.datetime(1998, 9, 28, 6, 48, 37, 986073),
#  datetime.datetime(2000, 3, 23, 15, 18, 37, 986073),
#  datetime.datetime(2018, 6, 12, 1, 48, 37, 986073),
#  datetime.datetime(1996, 2, 11, 19, 18, 37, 986073),
#  datetime.datetime(2019, 11, 2, 13, 18, 37, 986073),
#  datetime.datetime(2004, 4, 5, 15, 48, 37, 986073),
#  datetime.datetime(1999, 5, 30, 12, 48, 37, 986073),
#  datetime.datetime(2001, 7, 29, 15, 48, 37, 986073),
#  datetime.datetime(1998, 4, 5, 11, 48, 37, 986073),
#  datetime.datetime(2014, 1, 22, 21, 48, 37, 986073),
#  datetime.datetime(2000, 7, 17, 16, 18, 37, 986073),
#  datetime.datetime(2006, 12, 10, 3, 18, 37, 986073),
#  datetime.datetime(2006, 5, 14, 10, 48, 37, 986073),
#  datetime.datetime(2014, 8, 8, 19, 48, 37, 986073),
#  datetime.datetime(2016, 4, 29, 10, 18, 37, 986073),
#  datetime.datetime(2012, 12, 14, 16, 18, 37, 986073),
#  datetime.datetime(2004, 5, 29, 10, 48, 37, 986073),
#  datetime.datetime(2011, 11, 13, 0, 48, 37, 986073),
#  datetime.datetime(2003, 10, 16, 11, 18, 37, 986073),
#  datetime.datetime(2010, 10, 2, 21, 18, 37, 986073),
#  datetime.datetime(2012, 12, 1, 2, 48, 37, 986073),
#  datetime.datetime(2007, 1, 21, 8, 18, 37, 986073),
#  datetime.datetime(2004, 10, 14, 19, 18, 37, 986073),
#  datetime.datetime(2000, 5, 10, 5, 48, 37, 986073),
#  datetime.datetime(2016, 9, 16, 15, 18, 37, 986073),
#  datetime.datetime(2008, 11, 7, 15, 48, 37, 986073),
#  datetime.datetime(2018, 8, 13, 15, 48, 37, 986073),
#  datetime.datetime(2009, 1, 31, 18, 18, 37, 986073),
#  datetime.datetime(1994, 12, 8, 18, 48, 37, 986073),
#  datetime.datetime(2020, 7, 3, 16, 18, 37, 986073),
#  datetime.datetime(2016, 7, 1, 0, 48, 37, 986073),
#  datetime.datetime(2004, 11, 9, 7, 48, 37, 986073),
#  datetime.datetime(2010, 1, 25, 6, 48, 37, 986073),
#  datetime.datetime(2016, 9, 15, 17, 48, 37, 986073),
#  datetime.datetime(1994, 7, 12, 0, 48, 37, 986073),
#  datetime.datetime(2008, 1, 20, 13, 48, 37, 986073),
#  datetime.datetime(1998, 10, 24, 5, 48, 37, 986073),
#  datetime.datetime(2001, 8, 11, 4, 18, 37, 986073),
#  datetime.datetime(1994, 9, 17, 22, 48, 37, 986073),
#  datetime.datetime(2020, 11, 6, 2, 18, 37, 986073),
#  datetime.datetime(2006, 8, 5, 7, 18, 37, 986073),
#  datetime.datetime(2014, 1, 12, 12, 18, 37, 986073),
#  datetime.datetime(2021, 2, 17, 1, 18, 37, 986073),
#  datetime.datetime(1993, 12, 5, 14, 18, 37, 986073),
#  datetime.datetime(2015, 12, 28, 13, 18, 37, 986073),
#  datetime.datetime(2003, 12, 6, 18, 48, 37, 986073),
#  datetime.datetime(2001, 12, 14, 0, 48, 37, 986073),
#  datetime.datetime(1994, 6, 3, 16, 18, 37, 986073),
#  datetime.datetime(2016, 11, 26, 4, 48, 37, 986073),
#  datetime.datetime(2008, 7, 3, 21, 18, 37, 986073),
#  datetime.datetime(2011, 9, 12, 8, 18, 37, 986073),
#  datetime.datetime(2008, 1, 10, 21, 18, 37, 986073),
#  datetime.datetime(2014, 3, 23, 22, 48, 37, 986073),
#  datetime.datetime(2008, 11, 28, 6, 18, 37, 986073),
#  datetime.datetime(2007, 12, 4, 14, 18, 37, 986073),
#  datetime.datetime(2007, 2, 27, 3, 48, 37, 986073),
#  datetime.datetime(2004, 10, 31, 10, 48, 37, 986073),
#  datetime.datetime(1995, 4, 15, 17, 18, 37, 986073),
#  datetime.datetime(2000, 9, 15, 1, 18, 37, 986073),
#  datetime.datetime(1993, 5, 12, 17, 18, 37, 986073),
#  datetime.datetime(2007, 6, 9, 17, 48, 37, 986073),
#  datetime.datetime(2021, 5, 22, 22, 48, 37, 986073),
#  datetime.datetime(1997, 8, 11, 7, 18, 37, 986073),
#  datetime.datetime(2021, 2, 20, 16, 18, 37, 986073),
#  datetime.datetime(2004, 10, 24, 8, 48, 37, 986073),
#  datetime.datetime(2016, 12, 11, 20, 18, 37, 986073),
#  datetime.datetime(2006, 6, 26, 8, 48, 37, 986073),
#  datetime.datetime(1994, 2, 15, 17, 48, 37, 986073),
#  datetime.datetime(2011, 4, 5, 1, 48, 37, 986073),
#  datetime.datetime(1998, 8, 2, 8, 48, 37, 986073),
#  datetime.datetime(2002, 10, 5, 21, 18, 37, 986073),
#  datetime.datetime(2020, 11, 26, 14, 18, 37, 986073),
#  datetime.datetime(1999, 11, 16, 15, 48, 37, 986073),
#  datetime.datetime(2007, 5, 26, 19, 48, 37, 986073),
#  datetime.datetime(2020, 5, 29, 14, 18, 37, 986073),
#  datetime.datetime(2012, 12, 29, 12, 18, 37, 986073),
#  datetime.datetime(1994, 2, 17, 3, 18, 37, 986073),
#  datetime.datetime(2015, 10, 6, 6, 48, 37, 986073),
#  datetime.datetime(1999, 12, 25, 3, 48, 37, 986073),
#  datetime.datetime(2009, 11, 9, 11, 48, 37, 986073),
#  datetime.datetime(2002, 12, 5, 4, 18, 37, 986073),
#  datetime.datetime(1998, 9, 2, 6, 18, 37, 986073),
#  datetime.datetime(2010, 7, 16, 10, 48, 37, 986073),
#  datetime.datetime(1999, 4, 10, 6, 18, 37, 986073),
#  datetime.datetime(2008, 11, 8, 6, 48, 37, 986073),
#  datetime.datetime(1996, 9, 6, 6, 48, 37, 986073),
#  datetime.datetime(2019, 6, 13, 6, 48, 37, 986073),
#  datetime.datetime(2011, 9, 14, 11, 48, 37, 986073),
#  datetime.datetime(2005, 9, 17, 9, 18, 37, 986073),
#  datetime.datetime(1997, 11, 6, 20, 48, 37, 986073),
#  datetime.datetime(2020, 8, 5, 21, 18, 37, 986073),
#  datetime.datetime(2000, 3, 11, 12, 18, 37, 986073),
#  datetime.datetime(2002, 2, 26, 22, 18, 37, 986073),
#  datetime.datetime(1994, 4, 13, 9, 48, 37, 986073),
#  datetime.datetime(2003, 11, 30, 1, 48, 37, 986073),
#  datetime.datetime(2012, 4, 9, 12, 18, 37, 986073),
#  datetime.datetime(2013, 11, 19, 9, 48, 37, 986073),
#  datetime.datetime(2002, 5, 24, 10, 48, 37, 986073),
#  datetime.datetime(2016, 2, 14, 16, 48, 37, 986073),
#  datetime.datetime(2012, 10, 6, 9, 48, 37, 986073),
#  datetime.datetime(2014, 9, 13, 15, 48, 37, 986073),
#  datetime.datetime(2011, 11, 2, 10, 18, 37, 986073),
#  datetime.datetime(1993, 6, 24, 21, 18, 37, 986073),
#  datetime.datetime(1993, 5, 18, 10, 48, 37, 986073),
#  datetime.datetime(2016, 3, 27, 5, 18, 37, 986073),
#  datetime.datetime(2020, 9, 6, 16, 48, 37, 986073),
#  datetime.datetime(1995, 3, 7, 2, 48, 37, 986073),
#  datetime.datetime(2006, 2, 15, 21, 48, 37, 986073),
#  datetime.datetime(2021, 2, 13, 21, 48, 37, 986073),
#  datetime.datetime(2005, 2, 11, 8, 18, 37, 986073),
#  datetime.datetime(2008, 4, 6, 13, 18, 37, 986073),
#  datetime.datetime(2002, 5, 16, 19, 18, 37, 986073),
#  datetime.datetime(2005, 10, 15, 14, 18, 37, 986073),
#  datetime.datetime(2016, 11, 26, 6, 18, 37, 986073),
#  datetime.datetime(1999, 9, 12, 6, 18, 37, 986073),
#  datetime.datetime(1995, 2, 28, 22, 18, 37, 986073),
#  datetime.datetime(2014, 1, 24, 14, 48, 37, 986073),
#  datetime.datetime(2012, 3, 14, 11, 18, 37, 986073),
#  datetime.datetime(2021, 5, 1, 6, 18, 37, 986073),
#  datetime.datetime(2008, 12, 26, 21, 48, 37, 986073),
#  datetime.datetime(2011, 5, 20, 4, 48, 37, 986073),
#  datetime.datetime(1996, 1, 15, 18, 18, 37, 986073),
#  datetime.datetime(2006, 8, 9, 10, 18, 37, 986073),
#  datetime.datetime(2019, 4, 3, 1, 18, 37, 986073),
#  datetime.datetime(1998, 8, 7, 12, 18, 37, 986073),
#  datetime.datetime(1995, 4, 26, 14, 48, 37, 986073),
#  datetime.datetime(2020, 6, 24, 18, 18, 37, 986073),
#  datetime.datetime(2005, 12, 25, 23, 48, 37, 986073),
#  datetime.datetime(2001, 9, 27, 20, 18, 37, 986073),
#  datetime.datetime(1996, 10, 22, 14, 48, 37, 986073),
#  datetime.datetime(1999, 10, 15, 22, 18, 37, 986073),
#  datetime.datetime(2010, 9, 4, 6, 18, 37, 986073),
#  datetime.datetime(2018, 10, 16, 22, 18, 37, 986073),
#  datetime.datetime(2002, 5, 24, 4, 48, 37, 986073),
#  datetime.datetime(2012, 10, 10, 7, 18, 37, 986073),
#  datetime.datetime(2008, 6, 9, 5, 18, 37, 986073),
#  datetime.datetime(2004, 8, 6, 10, 18, 37, 986073),
#  datetime.datetime(2017, 8, 12, 18, 18, 37, 986073),
#  datetime.datetime(1997, 1, 13, 0, 48, 37, 986073),
#  datetime.datetime(2003, 3, 14, 15, 48, 37, 986073),
#  datetime.datetime(1998, 4, 2, 23, 48, 37, 986073),
#  datetime.datetime(1993, 3, 31, 5, 48, 37, 986073),
#  datetime.datetime(1998, 7, 31, 11, 18, 37, 986073),
#  datetime.datetime(2020, 1, 8, 0, 48, 37, 986073),
#  datetime.datetime(1998, 9, 22, 1, 48, 37, 986073),
#  datetime.datetime(2005, 11, 7, 17, 18, 37, 986073),
#  ...]

# %%
def create_strings(n_samples=n_samples, length_strings=length_strings):
    chars = ascii_lowercase + digits
    sample_strings = [''.join(choice(chars) for _ in range(length_strings)) for _ in range(n_samples)]
    #print(lst)
    return sample_strings
samples_strings = create_strings(n_samples=n_samples, length_strings=length_strings)

# %%
samples_strings
# Out:
# ['7cu',
#  '29n',
#  'v1q',
#  'rr1',
#  'xgt',
#  'c9l',
#  'et1',
#  '13q',
#  'o7v',
#  'all',
#  'vqb',
#  'yq2',
#  'pzd',
#  'm3n',
#  'sto',
#  'wtt',
#  'o0p',
#  'kjl',
#  '124',
#  'fue',
#  'vzn',
#  'hfl',
#  'h7o',
#  'hyd',
#  '0n0',
#  '2cc',
#  't1s',
#  '4j0',
#  '357',
#  'ke4',
#  'eyq',
#  '0hl',
#  's9v',
#  '9mv',
#  'qdq',
#  '2rs',
#  'zuv',
#  'jep',
#  'hef',
#  '718',
#  'pvd',
#  '69m',
#  '396',
#  '6xs',
#  'dyc',
#  'uuk',
#  'lp7',
#  'rku',
#  '0o3',
#  'b49',
#  'qa6',
#  'u9c',
#  'mkd',
#  'h1j',
#  'gyr',
#  'qxg',
#  '8pw',
#  'b86',
#  'j0p',
#  '212',
#  'fq8',
#  'yun',
#  '4tr',
#  '7fv',
#  'c3b',
#  'rkk',
#  'u6l',
#  '0yw',
#  '3kx',
#  'zcr',
#  'he8',
#  'jza',
#  '111',
#  'e4r',
#  '9w0',
#  '30c',
#  'r82',
#  'v0w',
#  'sns',
#  'm08',
#  '7ui',
#  '2hg',
#  '8b4',
#  'yen',
#  'mi2',
#  '7te',
#  'gok',
#  'x78',
#  'uaz',
#  'j2t',
#  'tpb',
#  'egr',
#  '85f',
#  'csi',
#  'jxg',
#  '44k',
#  '5h2',
#  'efl',
#  '901',
#  'roe',
#  'zij',
#  'fsl',
#  '796',
#  'qnn',
#  '409',
#  '80f',
#  'zk7',
#  'gtp',
#  '0v7',
#  'sql',
#  'kze',
#  'b3m',
#  'sd8',
#  'pdu',
#  't6y',
#  'g1a',
#  'eb2',
#  'jze',
#  '551',
#  'o7s',
#  'cba',
#  'eob',
#  '199',
#  '6gc',
#  'gdx',
#  'gva',
#  'z32',
#  'm9n',
#  'zpx',
#  '2z3',
#  'ghy',
#  '4lv',
#  'jjg',
#  '2hg',
#  'u6w',
#  '68x',
#  't3g',
#  'l05',
#  '29d',
#  'nbl',
#  '62b',
#  'lkw',
#  'wm7',
#  'k8e',
#  'prl',
#  'zi1',
#  '3ti',
#  'vij',
#  'ysv',
#  'g5l',
#  'fmx',
#  '21v',
#  'p7a',
#  'jql',
#  'cza',
#  '654',
#  '0ic',
#  '4xf',
#  'onw',
#  'o22',
#  'wqg',
#  'i48',
#  '347',
#  'sak',
#  'axq',
#  '2kb',
#  '2by',
#  '3ox',
#  'tc0',
#  'lr8',
#  'fs2',
#  'o46',
#  'f32',
#  'lnp',
#  'z23',
#  'paq',
#  'tk9',
#  'iuv',
#  'abb',
#  'ig8',
#  'rt3',
#  'd86',
#  'zso',
#  '5tf',
#  'fvt',
#  'qqt',
#  'dm0',
#  'f22',
#  'v13',
#  'n8z',
#  '00l',
#  'khi',
#  '0p2',
#  'ahg',
#  'mqe',
#  'sz1',
#  'kkk',
#  'gyi',
#  'l1d',
#  'vhq',
#  'pdr',
#  '6az',
#  '0mj',
#  'r2x',
#  '82d',
#  '1c8',
#  'rfl',
#  '2rh',
#  'iqj',
#  '3yg',
#  'jz5',
#  'gaw',
#  'erv',
#  'rg0',
#  'y1p',
#  '5gi',
#  'clp',
#  'l9u',
#  '0uu',
#  '4ks',
#  'fve',
#  '9r9',
#  'ibc',
#  'o60',
#  'gvx',
#  'yxa',
#  'ws9',
#  'eml',
#  'vds',
#  '4ln',
#  'jfd',
#  '1ji',
#  'epg',
#  'sbl',
#  'hmg',
#  'imf',
#  '0r1',
#  'igq',
#  'k8r',
#  'sq8',
#  'm1p',
#  'jtu',
#  '0jg',
#  '863',
#  'gmx',
#  'lgb',
#  'ho6',
#  'zmp',
#  '5h2',
#  'pxf',
#  'ofk',
#  '3nb',
#  'fh9',
#  'mvu',
#  'f5k',
#  'smg',
#  'nzi',
#  'dib',
#  'kvq',
#  'qmr',
#  '6bs',
#  'lh2',
#  'hu1',
#  'eae',
#  '18m',
#  'i7h',
#  'ar3',
#  '0b6',
#  'jj4',
#  'nkc',
#  'qkc',
#  'flw',
#  '7xr',
#  '5y2',
#  'oyp',
#  'bl0',
#  'hte',
#  'kd8',
#  'tgi',
#  '1pv',
#  '18b',
#  'i6m',
#  'sau',
#  'cnq',
#  '0i1',
#  'a5j',
#  'dzt',
#  '2pb',
#  'nwj',
#  '3lp',
#  '3rm',
#  'u34',
#  'bzi',
#  'wn1',
#  '7fx',
#  'apg',
#  'tav',
#  'mj5',
#  'gt0',
#  'y5f',
#  's4k',
#  'has',
#  'jj2',
#  'efz',
#  'uwd',
#  'zqp',
#  'eyw',
#  'at8',
#  'b7y',
#  'oo3',
#  'ag6',
#  'c9s',
#  'iu9',
#  'fao',
#  'zok',
#  'm6b',
#  '28z',
#  'fo4',
#  't5i',
#  'c0o',
#  'xyy',
#  '636',
#  '5el',
#  'oau',
#  '6ww',
#  '5ms',
#  '7lf',
#  'ozb',
#  '5qw',
#  'fbh',
#  '5vf',
#  '3ok',
#  'pwp',
#  'iwv',
#  'frt',
#  '7x3',
#  'gv1',
#  'hlp',
#  'tgz',
#  'bex',
#  '5cp',
#  'hoi',
#  '81x',
#  '85p',
#  'orf',
#  '7z7',
#  'pr3',
#  'k44',
#  '7oo',
#  'y1a',
#  '6el',
#  'nf8',
#  '0aq',
#  'fj1',
#  '6vm',
#  'pa1',
#  'sb8',
#  '0xw',
#  'ae5',
#  'dr6',
#  '25f',
#  '2az',
#  's5v',
#  'pep',
#  'lmd',
#  '3p7',
#  '2fe',
#  '4cj',
#  'fpt',
#  'ksq',
#  'mtg',
#  '6q2',
#  'fse',
#  '0oz',
#  'j6w',
#  'u15',
#  '5bh',
#  'zzv',
#  'iku',
#  '4z2',
#  'eik',
#  'bs2',
#  'e44',
#  'fri',
#  'nqx',
#  'csf',
#  '9ey',
#  'i6d',
#  'h9s',
#  'rvh',
#  'u4v',
#  'wfe',
#  'kl7',
#  '4ns',
#  '28h',
#  'dpp',
#  'wl6',
#  'diw',
#  'biu',
#  'vjr',
#  '52s',
#  'dyt',
#  'xp6',
#  '6mx',
#  'z4z',
#  'vkf',
#  '3iz',
#  'p6j',
#  'tca',
#  'fbp',
#  'le9',
#  'cuh',
#  'ihi',
#  'k6s',
#  '3ca',
#  'b8e',
#  'r1n',
#  'hn6',
#  'apx',
#  'jru',
#  'igm',
#  'kfe',
#  '8q3',
#  'l5i',
#  'mhs',
#  '0dp',
#  'vhp',
#  'kfn',
#  '6iw',
#  'kzz',
#  'shh',
#  'f8l',
#  't18',
#  'd0q',
#  'g7t',
#  'lt9',
#  'jm8',
#  'j1u',
#  'ane',
#  'joi',
#  'ok1',
#  'lwt',
#  'dca',
#  'tuc',
#  'aje',
#  '9xz',
#  'zh5',
#  'j69',
#  '4ql',
#  'w5q',
#  'c5x',
#  'vgf',
#  'wqx',
#  'ube',
#  '931',
#  '7hl',
#  '6qk',
#  'd07',
#  '08u',
#  '4h0',
#  'fhl',
#  'f5s',
#  'ud8',
#  'fzp',
#  'tca',
#  'quk',
#  '9of',
#  '3on',
#  'g8k',
#  'grw',
#  'x3c',
#  'eb9',
#  'r9d',
#  '63g',
#  'buj',
#  '9cw',
#  'n07',
#  'kyt',
#  '8vf',
#  'f5z',
#  '3hb',
#  'aaw',
#  'ege',
#  'kxu',
#  '3vl',
#  'dqg',
#  'u50',
#  'zq1',
#  'kei',
#  '5fd',
#  'bew',
#  'xjg',
#  'y88',
#  '2uz',
#  '8k4',
#  'e76',
#  'fwh',
#  'dze',
#  'h0m',
#  'tzz',
#  'frf',
#  'who',
#  'q1d',
#  'rys',
#  'xq5',
#  'kdh',
#  '7pe',
#  'o4f',
#  'w1u',
#  '8uy',
#  '9k3',
#  'yvo',
#  'zgh',
#  'o8s',
#  '1a1',
#  'mwu',
#  '985',
#  'v6s',
#  '16r',
#  '2yf',
#  'sl1',
#  '1zk',
#  'qnb',
#  'pjq',
#  'mp0',
#  't1g',
#  'znb',
#  '1va',
#  'h32',
#  'pvn',
#  'reh',
#  'wtp',
#  'qkn',
#  'ra9',
#  'up1',
#  '6ku',
#  'u43',
#  'juj',
#  'mh6',
#  'f7m',
#  'j9q',
#  'tw3',
#  '7ok',
#  'tqq',
#  'se8',
#  '0e5',
#  'bud',
#  'j6b',
#  'pxg',
#  'kj0',
#  'f25',
#  '569',
#  '4x8',
#  'poh',
#  'lql',
#  'o04',
#  'mq3',
#  'ntv',
#  'u06',
#  'vct',
#  'wt2',
#  'mpk',
#  'abc',
#  'nes',
#  'bzi',
#  '4j2',
#  'nrz',
#  '2ql',
#  'gln',
#  'a7v',
#  'kel',
#  '7ix',
#  'kmp',
#  '7e2',
#  'vin',
#  '7jk',
#  'dcm',
#  'gzf',
#  'mpt',
#  '82h',
#  'ce1',
#  'dyf',
#  'cpt',
#  'al4',
#  'w5s',
#  'vhj',
#  '43b',
#  '6un',
#  'hix',
#  '01j',
#  'ow8',
#  'jil',
#  'hp7',
#  'em7',
#  '7es',
#  '9wb',
#  'ub1',
#  'y1m',
#  '42c',
#  '88z',
#  'ds3',
#  'tv4',
#  'yw2',
#  '9ju',
#  'mj1',
#  'o4i',
#  'atv',
#  'njf',
#  '3ql',
#  '9fi',
#  'tmh',
#  'h5k',
#  '3qe',
#  'w9q',
#  'fl8',
#  'nyu',
#  '1bt',
#  '0vd',
#  'uze',
#  '762',
#  'sio',
#  'jut',
#  'hki',
#  'byz',
#  'cm4',
#  '1mq',
#  'zao',
#  's32',
#  'rls',
#  'cn8',
#  'p6c',
#  'vnd',
#  '38e',
#  'ab8',
#  '2qt',
#  '73o',
#  'bil',
#  'ndy',
#  '2lq',
#  '671',
#  '8s7',
#  'vkx',
#  't4h',
#  'nk4',
#  '2fc',
#  'g0w',
#  'ntj',
#  '4n4',
#  'f69',
#  'mi2',
#  'w8p',
#  'h77',
#  'wm7',
#  '3hv',
#  'xxi',
#  '7hp',
#  'pf7',
#  'vd2',
#  'sjc',
#  'snb',
#  '6xk',
#  'q9m',
#  '2m6',
#  '8zy',
#  'thi',
#  'gq6',
#  'z8w',
#  'wa4',
#  'l3t',
#  '435',
#  '21s',
#  '86e',
#  'x5x',
#  'cw5',
#  'xft',
#  '4bh',
#  'eyy',
#  'kdt',
#  'uzn',
#  'cn8',
#  'myy',
#  '26c',
#  'i6i',
#  '6s4',
#  'rpz',
#  'cww',
#  '24p',
#  '7bb',
#  'wza',
#  'sch',
#  'tz9',
#  'j39',
#  'xiu',
#  '1a0',
#  'rsc',
#  'a6m',
#  'ecg',
#  'gyr',
#  's7f',
#  'q7t',
#  '2ct',
#  'a7e',
#  'f0h',
#  '89x',
#  '8vb',
#  '1lq',
#  'heu',
#  '86m',
#  'a2m',
#  'm43',
#  '4if',
#  'lld',
#  'fss',
#  'qv3',
#  'anf',
#  '9tq',
#  'cew',
#  '4iw',
#  'jge',
#  'bdm',
#  'cqd',
#  'tik',
#  'vzv',
#  'i2r',
#  'mnt',
#  'dx3',
#  'myd',
#  '1vl',
#  'mjx',
#  'keb',
#  'hei',
#  'srn',
#  'tcz',
#  'wud',
#  'zno',
#  'evd',
#  'io4',
#  'g9f',
#  'hiu',
#  'ahu',
#  'qpa',
#  'pqv',
#  'lxi',
#  'rup',
#  'qdv',
#  'ivc',
#  'd7w',
#  't8o',
#  'acw',
#  'wae',
#  '62g',
#  'kd5',
#  'chv',
#  'rkd',
#  'rdh',
#  'ze6',
#  'dmz',
#  '67o',
#  '81d',
#  'h3u',
#  'lv9',
#  'fcd',
#  '69f',
#  'wjl',
#  'f88',
#  '2r1',
#  'yhl',
#  'zdo',
#  'x0w',
#  '30t',
#  'tqp',
#  'qh8',
#  'xpz',
#  'mbp',
#  'ann',
#  'sdm',
#  'f13',
#  '9tt',
#  'za3',
#  '1vc',
#  'kt3',
#  '80f',
#  'ynu',
#  'h80',
#  'ei8',
#  'pln',
#  'yh5',
#  '5bf',
#  '9ly',
#  'puk',
#  'f18',
#  'xuv',
#  'wyh',
#  'gkh',
#  '0zg',
#  'fxa',
#  '0pk',
#  'g2n',
#  'sqy',
#  'j5n',
#  '6x9',
#  'dsg',
#  'k5j',
#  'rgg',
#  '4c0',
#  '9fm',
#  'dn4',
#  'zqf',
#  'y1o',
#  'xmi',
#  'r5o',
#  '832',
#  'g4m',
#  'gz5',
#  'j01',
#  'kri',
#  'upt',
#  'kap',
#  'q4m',
#  'xlo',
#  '32d',
#  'zw1',
#  '578',
#  'xta',
#  'mi4',
#  'ovj',
#  '79t',
#  'vdn',
#  '8ds',
#  'y0m',
#  'bka',
#  'ugj',
#  '40l',
#  'eg1',
#  'b8a',
#  '3j7',
#  '3uz',
#  '44a',
#  '2wn',
#  'qj6',
#  '713',
#  'vf9',
#  'j88',
#  'ob3',
#  'cfw',
#  'u6x',
#  'ecd',
#  'fgn',
#  'ev6',
#  'l6a',
#  '7gh',
#  'p7s',
#  '65s',
#  'evt',
#  'c44',
#  'tlb',
#  'cub',
#  'w3f',
#  'tci',
#  'wfw',
#  'szq',
#  'qut',
#  'wlw',
#  'e9h',
#  'ive',
#  'awl',
#  '97e',
#  'fqi',
#  'u0s',
#  'djc',
#  'snd',
#  '84g',
#  'yt1',
#  'c3a',
#  'uq2',
#  'ppd',
#  'vmx',
#  'ysy',
#  '46b',
#  'g5q',
#  'our',
#  'a8b',
#  'g9l',
#  'f10',
#  'ea8',
#  '1e7',
#  'djo',
#  'hfp',
#  'ebk',
#  '0dz',
#  '915',
#  '70q',
#  'iqd',
#  'fbv',
#  'w9m',
#  'fpj',
#  '044',
#  'e5i',
#  'hh1',
#  '7d6',
#  '6de',
#  't7t',
#  'lnd',
#  'aah',
#  'yu4',
#  'e4q',
#  '5iv',
#  'ijl',
#  'jtu',
#  'f71',
#  'vlz',
#  'hcs',
#  'mxu',
#  'u1i',
#  'pb0',
#  'mnm',
#  'fna',
#  '7xx',
#  '658',
#  'ifv',
#  'r72',
#  'zwy',
#  '4vq',
#  'ghq',
#  'ojl',
#  'ont',
#  'yys',
#  '7sv',
#  'ect',
#  '4xx',
#  'haf',
#  'gmp',
#  'pa1',
#  '18g',
#  'hrs',
#  '2bp',
#  'qt6',
#  'lv2',
#  'dlu',
#  'kvp',
#  '3pq',
#  '2oz',
#  'f92',
#  'e6n',
#  'vd5',
#  'yxz',
#  'm9x',
#  '7u5',
#  'vud',
#  'jtt',
#  'zov',
#  'gdr',
#  '800',
#  'dj5',
#  '833',
#  '2fu',
#  'ubb',
#  'x03',
#  '2qt',
#  'ml2',
#  '6zz',
#  '6sl',
#  'ffo',
#  '3ah',
#  'obi',
#  'hvi',
#  '32i',
#  '5r0',
#  '4r6',
#  '7fq',
#  'ogm',
#  '5pf',
#  '0a1',
#  '37x',
#  'he0',
#  'sr8',
#  '7j7',
#  'bh3',
#  'zr5',
#  '4of',
#  '0zn',
#  'k8x',
#  '30k',
#  '0nm',
#  'ukd',
#  'xdr',
#  'd47',
#  'yqz',
#  'pk0',
#  'lsj',
#  'sxc',
#  't4j',
#  't12',
#  'nvh',
#  'v5c',
#  '8bb',
#  'd7b',
#  'pcg',
#  '2x1',
#  'd12',
#  ...]

# %%
# Create uniform distribution
def uniform_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1.):
    sample_uniform = (np.random.uniform(low,high,n_samples))
    if display==True:
        plot_distribution(sample_uniform, n_samples, "Continuous Uniform Distribution", num_bins)
    return sample_uniform

sample_uniform=uniform_distribution()

# %%
def normal_distribution(n_samples=n_samples, num_bins=num_bins, display = True, mu=0., sigma=1.):
    # Normal distribution
    sample_normal = np.random.normal(mu, sigma, n_samples)
    if display == True:
        plot_distribution(sample_normal, n_samples, "Normal Distribution", num_bins)
    return sample_normal

sample_normal = normal_distribution()

# %%
def uniform_sorted_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1.):
    #Sorted Uniform distribution
    sample_uniform_sorted = np.sort(np.random.uniform(low,high,n_samples))
    if display == True:
        plot_distribution(sample_uniform_sorted, n_samples, "Sorted Continuous Uniform Distribution", num_bins)
    return sample_uniform_sorted
sample_uniform_sorted = uniform_sorted_distribution()

# %%
def uniform_reverse_sorted_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1.):
    # Reverse Sorted Uniform distribution
    sample_uniform_reverse_sorted = np.sort(np.random.uniform(low,high,n_samples))[::-1]
    if display == True:
        plot_distribution(sample_uniform_reverse_sorted, n_samples, "Reverse Sorted Continuous Uniform Distribution", num_bins)
    return sample_uniform_reverse_sorted
sample_uniform_reverse_sorted = uniform_reverse_sorted_distribution()

# %%
def uniform_nearly_sorted_distribution(n_samples=n_samples, num_bins=num_bins, display = True, low=0., high=1., mean_noise= 0., std_noice = 0.01):
    # Nearly Uniform distribution
    sample_uniform_nearly_sorted = np.sort(np.random.uniform(low,high,n_samples))
    noise = np.random.normal(mean_noise,std_noice,n_samples)
    sample_uniform_nearly_sorted = sample_uniform_nearly_sorted + noise
    if display==True:
        plot_distribution(sample_uniform_nearly_sorted, n_samples, "Nearly Sorted Continuous Uniform Distribution", num_bins)
    return sample_uniform_nearly_sorted
sample_uniform_nearly_sorted = uniform_nearly_sorted_distribution()

# %%
def zipf_distribution(n_samples=n_samples, num_bins=num_bins, display = True, a=2.):
    # ZipF Distribution
    sample_zipf = np.random.zipf(a, n_samples)
    if display==True:
        # Plot
        
        weights = np.ones_like(sample_zipf[sample_zipf<50])/float(len(sample_zipf[sample_zipf<50]))
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))
        fig.suptitle('Zipf Distribution')
        count, bins, ignored = ax1.hist(sample_zipf[sample_zipf<50], 20, weights=weights)
        #ax1.plot(bins, np.ones_like(bins), linewidth=2, color='r')
        ax1.set_title('Probability Distribution',fontsize=18)
        ax1.set_ylabel('Frequency',fontsize=16)
        ax1.set_xlabel('Value',fontsize=16)
        plt.setp(ax1.get_yticklabels(), fontsize=14)
        plt.setp(ax1.get_xticklabels(), fontsize=14)
        y = np.arange(0,n_samples)
        ax2.scatter(y,sample_zipf,s=10)
        ax2.set_title('Sample Values',fontsize=18)
        ax2.set_ylabel('Sample Value',fontsize=16)
        ax2.set_xlabel('Sample Number',fontsize=16)
        plt.setp(ax2.get_xticklabels(), fontsize=14)
        plt.setp(ax2.get_yticklabels(), fontsize=14)

    return sample_zipf
sample_zipf = zipf_distribution()

# %%
def create_df_distribution(n_samples=n_samples, dist_type="Uniform"):
    df_distribion = pd.DataFrame().astype(np.float64)
    if dist_type == "Uniform":
        sample_uniform= uniform_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform"] = sample_uniform
    if dist_type == "Normal":
        sample_normal = normal_distribution(display=False, n_samples=n_samples)
        df_distribion["Normal"] = sample_normal
    if dist_type == "Uniform_Sorted":
        sample_uniform_sorted = uniform_sorted_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform_Sorted"] = sample_uniform_sorted
    if dist_type == "Uniform_Reverse_Sorted":
        sample_uniform_reverse_sorted = uniform_reverse_sorted_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform_Reverse_Sorted"] = sample_uniform_reverse_sorted
    if dist_type == "Uniform_Nearly_Sorted":
        sample_uniform_nearly_sorted = uniform_nearly_sorted_distribution(display=False, n_samples=n_samples)
        df_distribion["Uniform_Nearly_Sorted"] = sample_uniform_nearly_sorted
    if dist_type == "Zipf":
        sample_zipf = zipf_distribution(display=False, n_samples=n_samples)
        df_distribion["Zipf"] = sample_zipf
    if dist_type == "Dates":
        sample_dates = create_dates(n_samples=n_samples)
        df_distribion["Dates"] = sample_dates
    if dist_type == "Strings":
        sample_strings = create_strings(n_samples=n_samples)
        df_distribion["Strings"] = sample_strings
    if dist_type == "Discrete_Uniform":
        sample_discrete = discrete_uniform_distribution(n_samples=n_samples, n=n_discrete, display=False)
        df_distribion["Discrete_Uniform"] = sample_discrete
    if dist_type == "Discrete_Binomial":
        sample_bionmial = discrete_binomial_distribution(n_samples=n_samples, p=p, n=n_binomial, display=False)
        df_distribion["Discrete_Binomial"] = sample_bionmial
    if dist_type == "Poisson":
        poisson =  poission_distribution(n_samples=n_samples, lambda_param=lambda_param, display = False)
        df_distribion["Poisson"] = poisson
              
    return df_distribion

# %%
def quick_sort(df, columns):
    sorted_df = df.sort_values(columns, kind="quicksort")
    return sorted_df
def merge_sort(df, columns):
    sorted_df = df.sort_values(columns, kind="mergesort")
    return sorted_df
def heap_sort(df, columns):
    sorted_df = df.sort_values(columns, kind="heapsort")
    return sorted_df

choices = [quick_sort,merge_sort,heap_sort]
choices_names = ["quicksort","mergesort","heapsort"]

# %%
def evaluate_sorts(distribution_type="Uniform", second_col = None, repetitions=50):
    if second_col == None:
        measures = pd.DataFrame().astype(np.float64)
        for i, sorting_algorithm in enumerate(choices):
            algorithm_times = []
            for n in range(repetitions):
                distribion = create_df_distribution(n_samples=n_samples, dist_type=distribution_type)
                start_time = time.perf_counter()
                #sorted_df = distribion.sort_values([distribution_type],kind=sorting_algorithm)
                sorted_df = sorting_algorithm(distribion, [distribution_type])
                exeuction_time = (time.perf_counter() - start_time)
                algorithm_times.append(exeuction_time)
            measures[choices_names[i]] = algorithm_times
            print("The time of",choices_names[i], "is", np.mean(algorithm_times))
            print("It has a STD of", np.std(algorithm_times))
    else:
        measures = pd.DataFrame().astype(np.float64)
        for i, sorting_algorithm in enumerate(choices):
            algorithm_times = []
            for n in range(repetitions):
                distribion_1 = create_df_distribution(n_samples=n_samples, dist_type=distribution_type)
                distribion_2 = create_df_distribution(n_samples=n_samples, dist_type=second_col)
                df_distribions = pd.concat([distribion_1, distribion_2], axis=1)
                #print(df_distribions)
                start_time = time.perf_counter()
                #sorted_df = df_distribions.sort_values([distribution_type, second_col],kind=sorting_algorithm)
                sorted_df = sorting_algorithm(df_distribions, [distribution_type, second_col])
                exeuction_time = (time.perf_counter() - start_time)
                algorithm_times.append(exeuction_time)
            measures[choices_names[i]] = algorithm_times
            print("The time of",choices_names[i], "is", np.mean(algorithm_times))
            print("It has a STD of", np.std(algorithm_times))
    return measures

# %%
print("Discrete_Uniform")
df_discrete_uniform = evaluate_sorts(distribution_type="Discrete_Uniform")
# Out:
# Discrete_Uniform
# The time of quicksort is 0.04317895799999931
# It has a STD of 0.005017788988034434
# The time of mergesort is 0.06757047400000048
# It has a STD of 0.004637589272233321
# The time of heapsort is 0.05990883199999985
# It has a STD of 0.0011841608175312106

# %%
print("Discrete_Binomial")
df_discrete_binomial = evaluate_sorts(distribution_type="Discrete_Binomial")
# Out:
# Discrete_Binomial
# The time of quicksort is 0.04173701600000044
# It has a STD of 0.00039140841245849926
# The time of mergesort is 0.07578803600000014
# It has a STD of 0.005566656709615601
# The time of heapsort is 0.07347028600000187
# It has a STD of 0.008186568350976515

# %%
print("Poisson")
df_poisson= evaluate_sorts(distribution_type="Poisson")
# Out:
# Poisson
# The time of quicksort is 0.03865498800000012
# It has a STD of 0.0046514674876905636
# The time of mergesort is 0.06939235799999978
# It has a STD of 0.002838520316791937
# The time of heapsort is 0.06008697200000029
# It has a STD of 0.0020679377581580374

# %%
print("Dates")
df_dates = evaluate_sorts(distribution_type="Dates")
# Out:
# Dates
# The time of quicksort is 0.10019484800024657
# It has a STD of 0.015449644431895691
# The time of mergesort is 0.10281818399962503
# It has a STD of 0.011442862876830587
# The time of heapsort is 0.24590920800023014
# It has a STD of 0.026509046241834446

# %%
print("Strings")
df_strings = evaluate_sorts(distribution_type="Strings")
# Out:
# Strings
# The time of quicksort is 0.873709862
# It has a STD of 0.042578193854090854
# The time of mergesort is 0.7858995099999992
# It has a STD of 0.01611067018978775
# The time of heapsort is 1.6738927120000004
# It has a STD of 0.054760339373535194

# %%
print("Uniform")
df_uniform = evaluate_sorts(distribution_type="Uniform")
# Out:
# Uniform
# The time of quicksort is 0.08711071400000264
# It has a STD of 0.0015722087142580757
# The time of mergesort is 0.09591967000000523
# It has a STD of 0.001211630860667229
# The time of heapsort is 0.2041973159999975
# It has a STD of 0.003042190518452189

# %%
print("Normal")
df_normal = evaluate_sorts(distribution_type="Normal")
# Out:
# Normal
# The time of quicksort is 0.08784811600000467
# It has a STD of 0.0043707920313086545
# The time of mergesort is 0.09569460400000025
# It has a STD of 0.0016696842428432686
# The time of heapsort is 0.20250450199999478
# It has a STD of 0.0020225278476694738

# %%
print("Uniform_Sorted")
df_uniform_sorted = evaluate_sorts(distribution_type="Uniform_Sorted")
# Out:
# Uniform_Sorted
# The time of quicksort is 0.028782136000004357
# It has a STD of 0.0012190186941610013
# The time of mergesort is 0.022832142000008843
# It has a STD of 0.0014926335606697799
# The time of heapsort is 0.06275941200000261
# It has a STD of 0.0005479798779649352

# %%
print("Uniform_Reverse_Sorted")
df_uniform_reverse_sorted = evaluate_sorts(distribution_type="Uniform_Reverse_Sorted")
# Out:
# Uniform_Reverse_Sorted
# The time of quicksort is 0.03265550200000007
# It has a STD of 0.002600550768550636
# The time of mergesort is 0.022700465999992047
# It has a STD of 0.00045171069573160316
# The time of heapsort is 0.06673941800000875
# It has a STD of 0.0012049477515143757

# %%
print("Uniform_Nearly_Sorted")
df_uniform_nearly_sorted = evaluate_sorts(distribution_type="Uniform_Nearly_Sorted")
# Out:
# Uniform_Nearly_Sorted
# The time of quicksort is 0.06232929800000193
# It has a STD of 0.0004287817950919297
# The time of mergesort is 0.06688421999999036
# It has a STD of 0.00029500260948016945
# The time of heapsort is 0.1045242959999996
# It has a STD of 0.004345385255132742

# %%
print("Zipf")
df_zipf = evaluate_sorts(distribution_type="Zipf")
# Out:
# Zipf
# The time of quicksort is 0.034740265999996606
# It has a STD of 0.0005747654410528794
# The time of mergesort is 0.05473486400000411
# It has a STD of 0.00016822381729867257
# The time of heapsort is 0.049853896000001896
# It has a STD of 0.003485935738651705

# %%
print("Zipf + Normal")
df_zipf_normal = evaluate_sorts(distribution_type="Zipf", second_col="Discrete_Binomial")
# Out:
# Zipf + Normal
# The time of quicksort is 0.07838377999999693
# It has a STD of 0.0038595866243452803
# The time of mergesort is 0.07718482800000175
# It has a STD of 0.0013494052140233682
# The time of heapsort is 0.0798271519999912
# It has a STD of 0.00927572317427543

# %%
print("Zipf + Discrete_Binomial")
df_zipf_binomial = evaluate_sorts(distribution_type="Zipf", second_col="Discrete_Binomial")
# Out:
# Zipf + Discrete_Binomial
# The time of quicksort is 0.07930603599999131
# It has a STD of 0.016568883466823635
# The time of mergesort is 0.07557868000000098
# It has a STD of 0.0006553142256927058
# The time of heapsort is 0.075490563999997
# It has a STD of 0.0007353017796092808

# %%
print("Zipf + Discrete_Uniform")
df_zipf_discrete_uniform = evaluate_sorts(distribution_type="Zipf", second_col="Discrete_Uniform")
# Out:
# Zipf + Discrete_Uniform
# The time of quicksort is 0.07507922399999871
# It has a STD of 0.001585543241368991
# The time of mergesort is 0.07522826400000213
# It has a STD of 0.0009299110202182346
# The time of heapsort is 0.0760485540000036
# It has a STD of 0.005289334619361407

# %%
print("Zipf + Poisson")
df_zipf_poisson = evaluate_sorts(distribution_type="Zipf", second_col="Poisson")
# Out:
# Zipf + Poisson
# The time of quicksort is 0.08647422599955462
# It has a STD of 0.012351939146176666
# The time of mergesort is 0.08535371799967834
# It has a STD of 0.010320223885112405
# The time of heapsort is 0.0881023220003408
# It has a STD of 0.012686061916756041

# %%
print("Zipf + Dates")
df_zipf_dates = evaluate_sorts(distribution_type="Zipf", second_col="Dates")
# Out:
# Zipf + Dates
# The time of quicksort is 0.44652848199984874
# It has a STD of 0.035999318890220136
# The time of mergesort is 0.44452437999992983
# It has a STD of 0.027280060126678836
# The time of heapsort is 0.4582541519998631
# It has a STD of 0.032461239758521256

# %%
print("Zipf + Strings")
df_zipf_strings = evaluate_sorts(distribution_type="Zipf", second_col="Strings")
# Out:
# Zipf + Strings
# The time of quicksort is 0.3366160360003414
# It has a STD of 0.019886728940348
# The time of mergesort is 0.35107503800056294
# It has a STD of 0.047544626682761146
# The time of heapsort is 0.32990914599984533
# It has a STD of 0.012608824117154454

# %%
print("Discrete_Uniform + Poisson")
df_discrete_poisson = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Poisson")
# Out:
# Discrete_Uniform + Poisson
# The time of quicksort is 0.06919975599943427
# It has a STD of 0.0017742956166999122
# The time of mergesort is 0.07056561799967312
# It has a STD of 0.00456518036966199
# The time of heapsort is 0.06903678399918135
# It has a STD of 0.0008114398058453715

# %%
print("Discrete_Uniform + Strings")
df_discrete_strings = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Strings")
# Out:
# Discrete_Uniform + Strings
# The time of quicksort is 0.3540768380003283
# It has a STD of 0.015375859329222507
# The time of mergesort is 0.3850173599999107
# It has a STD of 0.05437923923269224
# The time of heapsort is 0.3650326620003034
# It has a STD of 0.01841408246782602

# %%
print("Discrete_Uniform + Uniform_Reverse_Sorted")
df_discrete_uniform_reverse_sorted = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Uniform_Reverse_Sorted")
# Out:
# Discrete_Uniform + Uniform_Reverse_Sorted
# The time of quicksort is 0.32403089400046153
# It has a STD of 0.0271770517820134
# The time of mergesort is 0.3222341079998296
# It has a STD of 0.019867696181534607
# The time of heapsort is 0.33077907400002005
# It has a STD of 0.021874837406570886

# %%
print("Discrete_Uniform + Uniform_Nearly_Sorted")
df_discrete_uniform_nearly_sorted = evaluate_sorts(distribution_type="Discrete_Uniform", second_col="Uniform_Nearly_Sorted")
# Out:
# Discrete_Uniform + Uniform_Nearly_Sorted
# The time of quicksort is 0.37446235000068556
# It has a STD of 0.014883963950722825
# The time of mergesort is 0.3738333379996766
# It has a STD of 0.013214885463825486
# The time of heapsort is 0.38498806599993257
# It has a STD of 0.015229079905266847

# %%
def calculate_stats(df_dist, sort_algo):
    df_sort_algo = df_dist[sort_algo]
    std_sort_algo = np.std(df_sort_algo) 
    mean_sort_algo = np.mean(df_sort_algo) 
    return df_sort_algo, std_sort_algo,mean_sort_algo

def plot_runtimes(sort_dist, std_sort_algo, mean_sort_algo,algo_name):
    # Plot
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    fig.suptitle(algo_name)
    count, bins, ignored = ax1.hist(sort_dist, 20)
    ax2.plot(sort_dist)
    plt.show()
def plot_runtimes_together(df, bins = 5,title=None):
    weights_quicksort = np.ones_like(df["quicksort"])/float(len(df["quicksort"]))
    weights_mergesort = np.ones_like(df["mergesort"])/float(len(df["mergesort"]))
    weights_heapsort = np.ones_like(df["heapsort"])/float(len(df["heapsort"]))
    plt.figure(figsize=(16,6))
    plt.hist(df["quicksort"], bins, alpha = 0.5, label='quick sort',weights=weights_quicksort)
    plt.hist(df["mergesort"], bins, alpha = 0.5, label='merge sort',weights=weights_mergesort)
    plt.hist(df["heapsort"], bins, alpha = 0.5, label='heap sort',weights=weights_heapsort)
    plt.legend(loc='upper right',fontsize=26)
    plt.title(title,fontsize=26)
    plt.ylabel("Frequency",fontsize=26)
    plt.xlabel("Runtime in seconds",fontsize=26)
    plt.xticks(fontsize=26)
    plt.yticks(fontsize=26)
    plt.show()

# %%
plot_runtimes_together(df_normal, title="Sorting a single column: normal distribution")
plot_runtimes_together(df_uniform, title="Sorting a single column: continious uniform distribution")
plot_runtimes_together(df_uniform_sorted, title="Sorting a single column: continious uniform sorted distribution")
plot_runtimes_together(df_uniform_reverse_sorted, title="Sorting a single column: continious uniform reverse sorted distribution")
plot_runtimes_together(df_uniform_nearly_sorted, title="Sorting a single column: continious uniform nearly sorted distribution")
plot_runtimes_together(df_dates, title="Sorting a single column: dates")
plot_runtimes_together(df_strings, title="Sorting a single column: strings")

# %%
plot_runtimes_together(df_discrete_uniform, title="Sorting a single column: discrete uniform distribution")
plot_runtimes_together(df_discrete_binomial, title="Sorting a single column: binomial distribution")
plot_runtimes_together(df_poisson, title="Sorting a single column: Poisson distribution")
plot_runtimes_together(df_zipf, title="Sorting a single column: Zipf distribution")

# %%
plot_runtimes_together(df_zipf_normal, title="Sorting by two columns: Zipf + normal distribution")
plot_runtimes_together(df_zipf_binomial, title="Sorting by two columns: Zipf + binomial distribution")
plot_runtimes_together(df_zipf_discrete_uniform, title="Sorting by two columns: Zipf + discrete uniform distribution")
plot_runtimes_together(df_zipf_poisson, title="Sorting by two columns: Zipf + Poisson distribution")
plot_runtimes_together(df_zipf_dates, title="Sorting by two columns: Zipf + dates")

# %%
plot_runtimes_together(df_discrete_poisson, title="Sorting by two columns: discrete uniform distribution + Poisson distributon")
plot_runtimes_together(df_discrete_strings, title="Sorting by two columns: discrete uniform distribution + strings")
plot_runtimes_together(df_discrete_uniform_reverse_sorted, title="Sorting by two columns: discrete uniform distribution + reverse sorted uniform distribution")
plot_runtimes_together(df_discrete_uniform_nearly_sorted, title="Sorting by two columns: discrete uniform distribution + nearly sorted uniform distribution")
